# %%
import pandas

# %%
final = pandas.read_csv("restaurant_almost_final.csv")
final
# Out:
#        Unnamed: 0             business_id           city  postal_code  stars  \
# 0               0  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 1               1  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 2               2  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 3               3  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 4               4  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# ...           ...                     ...            ...          ...    ...
# 21996       21996  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21997       21997  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21998       21998  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21999       21999  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 22000       22000  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
#
#        review_count      Type      hours day_of_the_week
# 0                 8    Coffee   7:0-18:0          Friday
# 1                 8    Coffee   7:0-18:0          Monday
# 2                 8    Coffee   7:0-18:0        Saturday
# 3                 8    Coffee   7:0-18:0          Sunday
# 4                 8    Coffee   7:0-18:0        Thursday
# ...             ...       ...        ...             ...
# 21996            77  American  16:0-21:0        Saturday
# 21997            77  American    0:0-0:0          Sunday
# 21998            77  American  16:0-21:0        Thursday
# 21999            77  American  16:0-21:0         Tuesday
# 22000            77  American  16:0-21:0       Wednesday
#
# [22001 rows x 9 columns]

# %%
final[['opening','closing']] = final.hours.str.split('-',expand=True)
final['opening'] = final['opening'].str.replace(":",".")
final['closing'] = final['closing'].str.replace(":",".")
final
# Out:
#        Unnamed: 0             business_id           city  postal_code  stars  \
# 0               0  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 1               1  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 2               2  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 3               3  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 4               4  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# ...           ...                     ...            ...          ...    ...
# 21996       21996  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21997       21997  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21998       21998  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21999       21999  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 22000       22000  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
#
#        review_count      Type      hours day_of_the_week opening closing
# 0                 8    Coffee   7:0-18:0          Friday     7.0    18.0
# 1                 8    Coffee   7:0-18:0          Monday     7.0    18.0
# 2                 8    Coffee   7:0-18:0        Saturday     7.0    18.0
# 3                 8    Coffee   7:0-18:0          Sunday     7.0    18.0
# 4                 8    Coffee   7:0-18:0        Thursday     7.0    18.0
# ...             ...       ...        ...             ...     ...     ...
# 21996            77  American  16:0-21:0        Saturday    16.0    21.0
# 21997            77  American    0:0-0:0          Sunday     0.0     0.0
# 21998            77  American  16:0-21:0        Thursday    16.0    21.0
# 21999            77  American  16:0-21:0         Tuesday    16.0    21.0
# 22000            77  American  16:0-21:0       Wednesday    16.0    21.0
#
# [22001 rows x 11 columns]

# %%
final["opening"]=final.opening.astype(float)
final["closing"]=final.closing.astype(float)

final["hours_per_day"]=abs(final['closing'] - final["opening"])
final
# Out:
#        Unnamed: 0             business_id           city  postal_code  stars  \
# 0               0  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 1               1  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 2               2  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 3               3  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 4               4  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# ...           ...                     ...            ...          ...    ...
# 21996       21996  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21997       21997  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21998       21998  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 21999       21999  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
# 22000       22000  _nSL2u-ZzX6kkAF2D2EZgQ         Goleta        93117    3.5
#
#        review_count      Type      hours day_of_the_week  opening  closing  \
# 0                 8    Coffee   7:0-18:0          Friday      7.0     18.0
# 1                 8    Coffee   7:0-18:0          Monday      7.0     18.0
# 2                 8    Coffee   7:0-18:0        Saturday      7.0     18.0
# 3                 8    Coffee   7:0-18:0          Sunday      7.0     18.0
# 4                 8    Coffee   7:0-18:0        Thursday      7.0     18.0
# ...             ...       ...        ...             ...      ...      ...
# 21996            77  American  16:0-21:0        Saturday     16.0     21.0
# 21997            77  American    0:0-0:0          Sunday      0.0      0.0
# 21998            77  American  16:0-21:0        Thursday     16.0     21.0
# 21999            77  American  16:0-21:0         Tuesday     16.0     21.0
# 22000            77  American  16:0-21:0       Wednesday     16.0     21.0
#
#        hours_per_day
# 0               11.0
# 1               11.0
# 2               11.0
# 3               11.0
# 4               11.0
# ...              ...
# 21996            5.0
# 21997            0.0
# 21998            5.0
# 21999            5.0
# 22000            5.0
#
# [22001 rows x 12 columns]

# %%
total=final.groupby(["business_id"])["hours_per_day"].sum()
total.columns=['business_id','hours_per_day']
total=total.reset_index()
total
# Out:
#                 business_id  hours_per_day
# 0    -3AooxIkg38UyUdlz5oXdw          489.3
# 1    -BdYhP-12elmFV7oB1iv4A          315.0
# 2    -nwNPb3G-0L95igrhkvMtw          475.3
# 3    -r6nmLB5Vi2TLQCxh0_dtw          294.0
# 4    04Ss49U_QKYLotcJMAH8cA          392.0
# ..                      ...            ...
# 444  z9-8KvMAlVK46De-G3sNJQ          588.0
# 445  zJpZ-uQ_F0XVgK1u98uWSg          197.4
# 446  zZrDoiQIUmiVkifJx0h_KA          539.0
# 447  zeAfmYy9b1gfUJLRBHm6vQ          522.2
# 448  ziXR7sUrbKRCNeDqfjibUg          679.0
#
# [449 rows x 2 columns]

# %%
final_hours=pandas.merge(total,final,on ="business_id")
final_hours["hours_per_week"]=final_hours["hours_per_day_x"]
final_hours=final_hours.drop(columns=["Unnamed: 0","hours","day_of_the_week","opening","closing","hours_per_day_y","hours_per_day_x"])

# %%
final_hours=final_hours.drop_duplicates()
final_hours
# Out:
#                   business_id           city  postal_code  stars  \
# 0      -3AooxIkg38UyUdlz5oXdw  Santa Barbara        93101    3.0
# 49     -BdYhP-12elmFV7oB1iv4A  Santa Barbara        93109    5.0
# 98     -nwNPb3G-0L95igrhkvMtw  Santa Barbara        93101    2.5
# 147    -r6nmLB5Vi2TLQCxh0_dtw  Santa Barbara        93101    4.0
# 196    04Ss49U_QKYLotcJMAH8cA  Santa Barbara        93101    4.0
# ...                       ...            ...          ...    ...
# 21756  z9-8KvMAlVK46De-G3sNJQ  Santa Barbara        93101    4.0
# 21805  zJpZ-uQ_F0XVgK1u98uWSg  Santa Barbara        93101    4.5
# 21854  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101    4.5
# 21903  zeAfmYy9b1gfUJLRBHm6vQ  Santa Barbara        93105    4.0
# 21952  ziXR7sUrbKRCNeDqfjibUg  Santa Barbara        93101    4.0
#
#        review_count       Type  hours_per_week
# 0               436    Italian           489.3
# 49               41   American           315.0
# 98               46  Fast Food           475.3
# 147             215       Deli           294.0
# 196              97       Deli           392.0
# ...             ...        ...             ...
# 21756           239    Healthy           588.0
# 21805            13    Mexican           197.4
# 21854             8     Coffee           539.0
# 21903           240    Italian           522.2
# 21952           262    Mexican           679.0
#
# [449 rows x 7 columns]

# %%
final_hours.to_csv('restaurant6.csv')
