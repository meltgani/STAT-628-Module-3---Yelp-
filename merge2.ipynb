# %%
import pandas as pd
import json

# %%
rest=pd.read_csv("restaurantfinal.csv")
rest
# Out:
#      Unnamed: 0     X             business_id           city  postal_code  \
# 0             1     0  -3AooxIkg38UyUdlz5oXdw  Santa Barbara        93101
# 1             2     7  -BdYhP-12elmFV7oB1iv4A  Santa Barbara        93109
# 2             3    14  -nwNPb3G-0L95igrhkvMtw  Santa Barbara        93101
# 3             4    21  -r6nmLB5Vi2TLQCxh0_dtw  Santa Barbara        93101
# 4             5    28  04Ss49U_QKYLotcJMAH8cA  Santa Barbara        93101
# ..          ...   ...                     ...            ...          ...
# 444         445  3108  z9-8KvMAlVK46De-G3sNJQ  Santa Barbara        93101
# 445         446  3115  zJpZ-uQ_F0XVgK1u98uWSg  Santa Barbara        93101
# 446         447  3122  zZrDoiQIUmiVkifJx0h_KA  Santa Barbara        93101
# 447         448  3129  zeAfmYy9b1gfUJLRBHm6vQ  Santa Barbara        93105
# 448         449  3136  ziXR7sUrbKRCNeDqfjibUg  Santa Barbara        93101
#
#      stars  review_count       Type  hours_per_week    weight
# ...

# %%
rest=rest.drop(columns=["Unnamed: 0",'X','city','postal_code','stars','review_count','Type'])
rest
# Out:
#                 business_id  hours_per_week    weight
# 0    -3AooxIkg38UyUdlz5oXdw            69.9  1.776346
# 1    -BdYhP-12elmFV7oB1iv4A            45.0  0.167042
# 2    -nwNPb3G-0L95igrhkvMtw            67.9  0.187413
# 3    -r6nmLB5Vi2TLQCxh0_dtw            42.0  0.875950
# 4    04Ss49U_QKYLotcJMAH8cA            56.0  0.395196
# ..                      ...             ...       ...
# 444  z9-8KvMAlVK46De-G3sNJQ            84.0  0.973731
# 445  zJpZ-uQ_F0XVgK1u98uWSg            28.2  0.052964
# 446  zZrDoiQIUmiVkifJx0h_KA            77.0  0.032594
# 447  zeAfmYy9b1gfUJLRBHm6vQ            74.6  0.977805
# 448  ziXR7sUrbKRCNeDqfjibUg            97.0  1.067437
#
# [449 rows x 3 columns]

# %%
attributes=pd.read_csv("business_data_ready.csv")
attributes
# Out:
#      Unnamed: 0.1  Unnamed: 0             business_id  \
# 0               0           0  -3AooxIkg38UyUdlz5oXdw
# 1               1           1  -BdYhP-12elmFV7oB1iv4A
# 2               2           2  -nwNPb3G-0L95igrhkvMtw
# 3               3           3  -r6nmLB5Vi2TLQCxh0_dtw
# 4               4           4  04Ss49U_QKYLotcJMAH8cA
# ..            ...         ...                     ...
# 444           444         444  z9-8KvMAlVK46De-G3sNJQ
# 445           445         445  zJpZ-uQ_F0XVgK1u98uWSg
# 446           446         446  zZrDoiQIUmiVkifJx0h_KA
# 447           447         447  zeAfmYy9b1gfUJLRBHm6vQ
# 448           448         448  ziXR7sUrbKRCNeDqfjibUg
#
#                            name                              address  \
# 0              Chase Restaurant                        1012 State St
# 1               Corner Tap Room                        1905 Cliff Dr
# 2                 Panda Express                      605 Paseo Nuevo
# ...

# %%
final=pd.merge(attributes,rest,on ="business_id")
final
# Out:
#      Unnamed: 0.1  Unnamed: 0             business_id  \
# 0               0           0  -3AooxIkg38UyUdlz5oXdw
# 1               1           1  -BdYhP-12elmFV7oB1iv4A
# 2               2           2  -nwNPb3G-0L95igrhkvMtw
# 3               3           3  -r6nmLB5Vi2TLQCxh0_dtw
# 4               4           4  04Ss49U_QKYLotcJMAH8cA
# ..            ...         ...                     ...
# 444           444         444  z9-8KvMAlVK46De-G3sNJQ
# 445           445         445  zJpZ-uQ_F0XVgK1u98uWSg
# 446           446         446  zZrDoiQIUmiVkifJx0h_KA
# 447           447         447  zeAfmYy9b1gfUJLRBHm6vQ
# 448           448         448  ziXR7sUrbKRCNeDqfjibUg
#
#                            name                              address  \
# 0              Chase Restaurant                        1012 State St
# 1               Corner Tap Room                        1905 Cliff Dr
# 2                 Panda Express                      605 Paseo Nuevo
# ...

# %%
final=final.replace("Santa  Barbara", "Santa Barbara")

# %%
final.city.unique()
# Out:
# array(['Santa Barbara', 'Goleta', 'Carpinteria', 'Montecito',
#        'Isla Vista', 'Truckee', 'Summerland'], dtype=object)

# %%
final=final.drop(columns=['hours_per_week_x','Unnamed: 0.1','Unnamed: 0'])
final
# Out:
#                 business_id                        name  \
# 0    -3AooxIkg38UyUdlz5oXdw            Chase Restaurant
# 1    -BdYhP-12elmFV7oB1iv4A             Corner Tap Room
# 2    -nwNPb3G-0L95igrhkvMtw               Panda Express
# 3    -r6nmLB5Vi2TLQCxh0_dtw  South Coast Deli- Carrillo
# 4    04Ss49U_QKYLotcJMAH8cA     Ike’s Love & Sandwiches
# ..                      ...                         ...
# 444  z9-8KvMAlVK46De-G3sNJQ       Blenders In The Grass
# 445  zJpZ-uQ_F0XVgK1u98uWSg    Gloria's Gourmet Kitchen
# 446  zZrDoiQIUmiVkifJx0h_KA    Old Town Coffee Downtown
# 447  zeAfmYy9b1gfUJLRBHm6vQ                Presto Pasta
# 448  ziXR7sUrbKRCNeDqfjibUg      Rudy's Restaurant No 1
#
#                                  address           city state  postal_code  \
# 0                          1012 State St  Santa Barbara    CA        93101
# 1                          1905 Cliff Dr  Santa Barbara    CA        93109
# ...

# %%
final.to_csv('businessfinal.csv')
