# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
stop_words = list(stopwords.words('english'))

# %%
import pandas as pd

# %%
business_df = pd.read_csv("Final_Business_0_1.csv")

# %%
business_df.drop("Unnamed: 0",axis = 1, inplace =True)

# %%
review = pd.read_csv("review.csv")

# %%
review1 = review[review.business_id.isin(business_df.business_id.values)]

# %%
len(review1.business_id.unique())
# Out:
# 449

# %%
business_df.Type.unique()
# Out:
# array(['Italian', 'American', 'Fast Food', 'Deli', 'Bakery', 'Mexican',
#        'Coffee', 'Breakfast', 'Japanese', 'Healthy', 'Pizza'],
#       dtype=object)

# %%
Italian = business_df[business_df.Type=="Italian"]

# %%
Italian_review = review1[review1.business_id.isin(Italian.business_id.values)]

# %%
Italian_review
# Out:
#         Unnamed: 0               review_id                 user_id  \
# 65            2203  T2-x-y3sJG_lhkr7bP0y-A  YBPsBCc8bNQTeHowfpYQ7A
# 102           3799  28fWpA_2vOy7oRBD5hyfEQ  oX7o1TH0PHUWp9r9ry9_vw
# 164           5768  PkZwJzq3GzqG18AJrQAeIw  FG6D3LU4TDh-B5jMyg67cg
# 210           7124  8boW2L-WhH8Jjaatr9BP6A  8c_TVSmFW0lFhzDlGgXYIQ
# 222           7419  QhmQu9vULM78rO0dYrTbIw  BwzpY9MiW3AVtyfiVOEQvQ
# ...            ...                     ...                     ...
# 204815     6987918  t9gdT9Qhtgfs4mXapVutcg  4DyMRBKrokax6d8LCI3GAw
# 204831     6988358  WSbA-C3O0NmpLw6TnE3jAw  XkIdd2k-E_0oNWdN9TYnDA
# 204845     6988891  PHuQeJh_w4g9OZ2ACcKtfA  zPPNyikI-w9w9v66aXIikw
# 204849     6989090  yhpNUVcsr15gDON1Gp4fBQ  83210-qORiXnpY8xumztQg
# 204865     6989708  F03-EH1AuqjWBdnIzfRL9w  y6v0WKg8pcQAYMjYJE1cxg
#
#                    business_id  stars  useful  funny  cool  \
# 65      S3QHy1sshUeZwXOYviVsXQ      2       0      0     0
# 102     -3AooxIkg38UyUdlz5oXdw      4       2      1     2
# 164     S3QHy1sshUeZwXOYviVsXQ      5       0      0     0
# 210     S3QHy1sshUeZwXOYviVsXQ      4       2      0     0
# 222     -3AooxIkg38UyUdlz5oXdw      5       0      0     1
# ...                        ...    ...     ...    ...   ...
# 204815  Qkg16mN-8QR66gjzg6gMyw      5      13      7    11
# 204831  Qkg16mN-8QR66gjzg6gMyw      1       2      1     0
# 204845  lNkxXDcNoHBpWDNPoZesYw      5       5      1     4
# 204849  Qkg16mN-8QR66gjzg6gMyw      5       1      0     1
# 204865  54oLdsGU9B8HxFTqCCqV-A      3       6      5     7
#
#                                                      text                 date
# 65      I'm being generous by giving this restaurant 2...  2015-02-16 06:14:56
# 102     Wow. Wow. We've been trying to go here for a w...  2018-04-27 23:52:59
# 164     Great vibe, great food.  Stands out even in a ...  2016-06-22 20:24:24
# 210     Great Food! Lots of Gluten free options!\nGrea...  2013-01-02 23:00:12
# 222     There are not enough superlatives! Awesome foo...  2015-05-13 23:30:43
# ...                                                   ...                  ...
# 204815  Personally, I like Convivo because their menu ...  2019-01-15 22:22:51
# 204831  I searched happy hour near me,and I was led to...  2019-10-13 00:42:45
# 204845  How could you not give Carusos a five star rev...  2021-12-17 05:13:57
# 204849  Beautiful restaurant, great food, and excellen...  2021-11-09 03:17:22
# 204865  2 Stars for Value - $24 for Ravioli and $24 fo...  2021-03-14 17:10:41
#
# [9252 rows x 10 columns]

# %%
Italian_review["text"] = Italian_review["text"].str.lower()
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def cleaning_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in stop_words])
Italian_review['text'] = Italian_review['text'].apply(lambda text: cleaning_stopwords(text))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
Italian_review.iloc[0].text
# Out:
# "i'm generous giving restaurant 2 stars. service appalling fact food actually ok place's saving grace. think saw waiter total 3 times entire evening. never greeted seated. ask maitre'd could get water could rude offended asked. finally ordered, water. asking water three separate times finally arrived. point received food, never saw waiter again. asked bus boy another glass wine never came. finally waiter brought finished meal told want more, gave attitude saying seen ticket. problem! never asked wanted dessert, presented check point waiter told us need leave tip since clearly displeased experience. going get tip first place. getting tipped requires providing service hardly did. would say, expect lot mediocre italian place."

# %%
import string
import re
english_punctuations = string.punctuation
punctuations_list = english_punctuations
def cleaning_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)
Italian_review['text']= Italian_review['text'].apply(lambda x: cleaning_punctuations(x))

def cleaning_repeating_char(text):
    return re.sub(r'(.)1+', r'1', text)
Italian_review['text'] = Italian_review['text'].apply(lambda x: cleaning_repeating_char(x))

def cleaning_URLs(data):
    return re.sub('((www.[^s]+)|(https?://[^s]+))',' ',data)
Italian_review['text'] = Italian_review['text'].apply(lambda x: cleaning_URLs(x))

def cleaning_numbers(data):
    return re.sub('[0-9]+', '', data)
Italian_review['text'] = Italian_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Italian_review['text'].iloc[0]
# Out:
# 'im generous giving restaurant  stars service appalling fact food actually ok places saving grace think saw waiter total  times entire evening never greeted seated ask maitred could get water could rude offended asked finally ordered water asking water three separate times finally arrived point received food never saw waiter again asked bus boy another glass wine never came finally waiter brought finished meal told want more gave attitude saying seen ticket problem never asked wanted dessert presented check point waiter told us need leave tip since clearly displeased experience going get tip first place getting tipped requires providing service hardly did would say expect lot mediocre italian place'

# %%
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize

# %%
Italian_review_text = Italian_review.text.str.cat(sep = " ")
tokens = word_tokenize(Italian_review_text)
fdist = FreqDist(tokens)
fdist.most_common()
bigrams_list = ["_".join(item) for item in nltk.bigrams(tokens)]
trigrams_list = ["_".join(item) for item in nltk.trigrams(tokens)]
FreqDist(bigrams_list).most_common()
FreqDist(trigrams_list).most_common()
# Out:
# [('ive_ever_had', 147),
#  ('restaurant_santa_barbara', 93),
#  ('food_great_service', 88),
#  ('definitely_come_back', 81),
#  ('wait_go_back', 81),
#  ('best_italian_food', 79),
#  ('olio_e_limone', 78),
#  ('visit_santa_barbara', 76),
#  ('cant_wait_go', 75),
#  ('great_food_great', 70),
#  ('restaurants_santa_barbara', 69),
#  ('service_great_food', 68),
#  ('would_go_back', 65),
#  ('back_next_time', 63),
#  ('authentic_italian_food', 63),
#  ('cant_go_wrong', 62),
#  ('visiting_santa_barbara', 60),
#  ('seated_right_away', 54),
#  ('downtown_santa_barbara', 54),
#  ('definitely_go_back', 53),
#  ('best_ive_ever', 51),
#  ('would_highly_recommend', 51),
#  ('good_italian_food', 51),
#  ('time_santa_barbara', 50),
#  ('would_definitely_recommend', 49),
#  ('would_come_back', 48),
#  ('food_good_service', 46),
#  ('highly_recommend_place', 46),
#  ('great_wine_list', 46),
#  ('olive_oil_cake', 46),
#  ('would_definitely_come', 42),
#  ('trip_santa_barbara', 41),
#  ('definitely_coming_back', 41),
#  ('made_us_feel', 40),
#  ('best_ever_had', 38),
#  ('al_burro_e', 37),
#  ('service_good_food', 36),
#  ('one_favorite_restaurants', 36),
#  ('squid_ink_pasta', 36),
#  ('thai_curry_sauce', 36),
#  ('dinner_last_night', 35),
#  ('ravioli_al_burro', 35),
#  ('burro_e_salvia', 35),
#  ('food_excellent_service', 35),
#  ('next_time_im', 34),
#  ('favorite_italian_restaurant', 34),
#  ('one_best_restaurants', 34),
#  ('warm_seafood_salad', 34),
#  ('italian_restaurant_santa', 33),
#  ('food_santa_barbara', 33),
#  ('highly_recommend_restaurant', 33),
#  ('one_best_italian', 33),
#  ('prime_rib_ravioli', 33),
#  ('great_food_service', 32),
#  ('wait_come_back', 32),
#  ('good_food_good', 32),
#  ('great_service_great', 32),
#  ('cant_say_enough', 32),
#  ('never_go_back', 31),
#  ('best_italian_restaurant', 31),
#  ('come_back_again', 31),
#  ('food_amazing_service', 31),
#  ('table_next_us', 31),
#  ('mushroom_stuffed_chicken', 31),
#  ('angel_hair_pasta', 30),
#  ('service_top_notch', 30),
#  ('santa_barbara_great', 29),
#  ('place_great_food', 28),
#  ('cant_wait_come', 28),
#  ('santa_barbara_area', 28),
#  ('bread_olive_oil', 28),
#  ('gluten_free_pasta', 28),
#  ('im_santa_barbara', 27),
#  ('italian_food_ive', 27),
#  ('santa_barbara_food', 27),
#  ('pane_e_vino', 27),
#  ('chicken_penne_pasta', 27),
#  ('santa_barbara_inn', 27),
#  ('great_wine_selection', 26),
#  ('back_santa_barbara', 26),
#  ('food_pretty_good', 26),
#  ('go_santa_barbara', 26),
#  ('go_back_again', 26),
#  ('definitely_recommend_place', 26),
#  ('would_recommend_place', 25),
#  ('food_really_good', 25),
#  ('place_santa_barbara', 25),
#  ('brown_butter_sage', 25),
#  ('can_not_wait', 25),
#  ('definitely_going_back', 24),
#  ('favorite_restaurant_santa', 24),
#  ('lived_santa_barbara', 24),
#  ('excellent_food_service', 24),
#  ('one_favorite_places', 24),
#  ('great_dining_experience', 24),
#  ('ive_ever_eaten', 24),
#  ('olive_oil_balsamic', 24),
#  ('next_time_were', 24),
#  ('great_customer_service', 23),
#  ('love_love_love', 23),
#  ('go_back_try', 23),
#  ('italian_food_place', 23),
#  ('lemon_grass_crusted', 23),
#  ('one_best_meals', 22),
#  ('night_santa_barbara', 22),
#  ('recommend_place_anyone', 22),
#  ('italian_food_santa', 22),
#  ('definitely_back_next', 22),
#  ('eat_santa_barbara', 22),
#  ('delicious_italian_food', 22),
#  ('garlic_bread_good', 22),
#  ('salmon_thai_curry', 22),
#  ('service_excellent_food', 21),
#  ('taken_care_of', 21),
#  ('santa_barbara_place', 21),
#  ('overall_great_experience', 21),
#  ('delicious_highly_recommend', 21),
#  ('great_italian_food', 21),
#  ('next_time_santa', 21),
#  ('worth_every_penny', 21),
#  ('save_room_dessert', 21),
#  ('butter_sage_sauce', 21),
#  ('extensive_wine_list', 21),
#  ('sun_dried_tomatoes', 21),
#  ('butternut_squash_ravioli', 21),
#  ('garlic_cheese_bread', 21),
#  ('ordered_tuna_cones', 21),
#  ('really_really_good', 20),
#  ('italian_santa_barbara', 20),
#  ('great_service_food', 20),
#  ('favorite_restaurants_santa', 20),
#  ('good_service_great', 20),
#  ('banana_bread_pudding', 20),
#  ('would_definitely_go', 20),
#  ('wrapped_tiger_prawns', 20),
#  ('complimentary_garlic_bread', 20),
#  ('nothing_write_home', 19),
#  ('food_service_great', 19),
#  ('come_santa_barbara', 19),
#  ('places_santa_barbara', 19),
#  ('try_something_new', 19),
#  ('tomato_cream_sauce', 19),
#  ('italian_food_ever', 19),
#  ('quality_food_service', 19),
#  ('best_italian_restaurants', 19),
#  ('chocolate_banana_bread', 19),
#  ('food_absolutely_delicious', 19),
#  ('flat_iron_steak', 19),
#  ('santa_barbara_would', 19),
#  ('stuffed_chicken_breast', 19),
#  ('phyllo_wrapped_tiger', 19),
#  ('want_go_back', 18),
#  ('ive_long_time', 18),
#  ('every_time_go', 18),
#  ('good_food_service', 18),
#  ('come_back_try', 18),
#  ('santa_barbara_years', 18),
#  ('delicious_food_great', 18),
#  ('ever_go_back', 18),
#  ('come_back_next', 18),
#  ('best_part_meal', 18),
#  ('really_good_food', 18),
#  ('crusted_fresh_salmon', 18),
#  ('italian_restaurant_town', 17),
#  ('well_worth_it', 17),
#  ('good_service_good', 17),
#  ('us_right_away', 17),
#  ('service_delicious_food', 17),
#  ('santa_barbara_restaurant', 17),
#  ('first_time_here', 17),
#  ('time_visit_santa', 17),
#  ('santa_barbara_weekend', 17),
#  ('food_die_for', 17),
#  ('weve_ever_had', 17),
#  ('cant_wait_return', 17),
#  ('white_wine_sauce', 17),
#  ('love_come_back', 17),
#  ('curried_chicken_salad', 17),
#  ('garlic_bread_delicious', 17),
#  ('wild_mushroom_stuffed', 17),
#  ('lobster_mashed_potatoes', 17),
#  ('little_italian_restaurant', 16),
#  ('spicy_tomato_sauce', 16),
#  ('food_great_atmosphere', 16),
#  ('staff_friendly_attentive', 16),
#  ('would_recommend_restaurant', 16),
#  ('authentic_italian_restaurant', 16),
#  ('food_delicious_service', 16),
#  ('food_ive_ever', 16),
#  ('santa_barbara_go', 16),
#  ('went_last_night', 16),
#  ('next_time_town', 16),
#  ('good_wine_list', 16),
#  ('us_feel_like', 16),
#  ('would_definitely_return', 16),
#  ('braised_short_ribs', 16),
#  ('food_always_good', 16),
#  ('would_love_come', 16),
#  ('garlic_bread_amazing', 16),
#  ('like_water_chocolate', 16),
#  ('never_came_back', 15),
#  ('go_somewhere_else', 15),
#  ('service_bit_slow', 15),
#  ('got_seated_right', 15),
#  ('let_us_know', 15),
#  ('chase_bar_grill', 15),
#  ('food_mediocre_best', 15),
#  ('were_santa_barbara', 15),
#  ('food_service_atmosphere', 15),
#  ('well_definitely_back', 15),
#  ('italian_food_great', 15),
#  ('happy_hour_menu', 15),
#  ('go_back_next', 15),
#  ('one_best_ive', 15),
#  ('ive_never_bad', 15),
#  ('high_quality_food', 15),
#  ('keep_coming_back', 15),
#  ('give_place_stars', 15),
#  ('sauce_tasted_like', 15),
#  ('try_something_else', 15),
#  ('new_favorite_restaurant', 15),
#  ('ravioli_brown_butter', 15),
#  ('staff_super_friendly', 15),
#  ('new_years_eve', 15),
#  ('good_food_great', 15),
#  ('makes_feel_like', 15),
#  ('able_seat_us', 15),
#  ('best_ive_had', 15),
#  ('food_service_ambiance', 15),
#  ('im_pretty_sure', 15),
#  ('every_time_visit', 15),
#  ('grass_crusted_fresh', 15),
#  ('street_santa_barbara', 14),
#  ('great_happy_hour', 14),
#  ('pasta_al_dente', 14),
#  ('perfectly_al_dente', 14),
#  ('santa_barbara_again', 14),
#  ('went_first_time', 14),
#  ('highly_recommend_it', 14),
#  ('cant_remember_name', 14),
#  ('amazing_service_great', 14),
#  ('never_bad_meal', 14),
#  ('great_food_good', 14),
#  ('well_taken_care', 14),
#  ('great_date_night', 14),
#  ('dinner_santa_barbara', 14),
#  ('wonderful_dining_experience', 14),
#  ('santa_barbara_eat', 14),
#  ('took_care_us', 14),
#  ('can_not_say', 14),
#  ('write_home_about', 14),
#  ('vanilla_ice_cream', 14),
#  ('roasted_red_peppers', 14),
#  ('santa_barbara_first', 14),
#  ('chicken_salad_sandwich', 14),
#  ('ive_ever_tasted', 14),
#  ('im_giving_stars', 14),
#  ('bread_die_for', 14),
#  ('santa_barbara_love', 14),
#  ('lemon_grass_salmon', 14),
#  ('crusted_filet_mignon', 14),
#  ('warm_chocolate_torte', 14),
#  ('look_forward_coming', 13),
#  ('forward_coming_back', 13),
#  ('excellent_customer_service', 13),
#  ('id_go_back', 13),
#  ('time_im_santa', 13),
#  ('take_drink_order', 13),
#  ('would_recommend_anyone', 13),
#  ('wait_staff_attentive', 13),
#  ('santa_barbara_definitely', 13),
#  ('took_minutes_get', 13),
#  ('really_good_italian', 13),
#  ('best_restaurants_santa', 13),
#  ('would_give_stars', 13),
#  ('next_time_visit', 13),
#  ('probably_come_back', 13),
#  ('recommend_making_reservation', 13),
#  ('better_italian_food', 13),
#  ('decided_give_try', 13),
#  ('restaurant_ive_ever', 13),
#  ('italian_food_sb', 13),
#  ('ciotola_di_mare', 13),
#  ('really_good_too', 13),
#  ('busy_saturday_night', 13),
#  ('wine_list_great', 13),
#  ('place_good_food', 13),
#  ('old_school_italian', 13),
#  ('grilled_filet_mignon', 13),
#  ('love_place_food', 13),
#  ('tables_close_together', 13),
#  ('say_enough_good', 13),
#  ('enough_good_things', 13),
#  ('santa_barbara_went', 13),
#  ('santa_barbara_service', 13),
#  ('wait_staff_friendly', 13),
#  ('herb_grilled_filet', 13),
#  ('local_santa_barbara', 13),
#  ('salmon_filet_thai', 13),
#  ('cajun_shrimp_pasta', 13),
#  ('ordered_black_spaghetti', 13),
#  ('fennel_sausage_pizza', 13),
#  ('state_street_santa', 12),
#  ('return_next_time', 12),
#  ('waste_time_money', 12),
#  ('us_feel_welcome', 12),
#  ('stay_santa_barbara', 12),
#  ('even_though_restaurant', 12),
#  ('good_care_us', 12),
#  ('italian_food_service', 12),
#  ('every_single_time', 12),
#  ('santa_barbara_always', 12),
#  ('delicious_service_great', 12),
#  ('staff_friendly_food', 12),
#  ('looking_forward_trying', 12),
#  ('made_feel_like', 12),
#  ('came_santa_barbara', 12),
#  ('service_amazing_food', 12),
#  ('would_give_place', 12),
#  ('go_wrong_anything', 12),
#  ('food_good_great', 12),
#  ('good_italian_restaurant', 12),
#  ('really_liked_it', 12),
#  ('wine_list_extensive', 12),
#  ('food_even_better', 12),
#  ('love_italian_food', 12),
#  ('every_single_bite', 12),
#  ('food_good_wine', 12),
#  ('make_feel_like', 12),
#  ('spot_santa_barbara', 12),
#  ('quality_italian_food', 12),
#  ('food_reasonable_prices', 12),
#  ('great_service_excellent', 12),
#  ('also_really_good', 12),
#  ('stuffed_squash_blossoms', 12),
#  ('meal_santa_barbara', 12),
#  ('santa_barbara_ive', 12),
#  ('gem_santa_barbara', 12),
#  ('italian_restaurants_santa', 12),
#  ('verdi_alla_bolognese', 12),
#  ('santa_barbara_favorite', 12),
#  ('pappardelle_alla_boscaiola', 12),
#  ('amazing_food_great', 12),
#  ('found_place_yelp', 12),
#  ('ordered_chicken_piccata', 12),
#  ('water_chocolate_surprise', 12),
#  ('chipotle_cream_sauce', 12),
#  ('sauteed_chicken_penne', 12),
#  ('filet_thai_curry', 12),
#  ('filet_mignon_pizza', 12),
#  ('give_another_try', 12),
#  ('right_across_street', 12),
#  ('cheesy_garlic_bread', 12),
#  ('tuna_cones_appetizer', 12),
#  ('braised_beef_short', 12),
#  ('santa_barbara_toma', 12),
#  ('pretty_good_too', 11),
#  ('first_time_last', 11),
#  ('coming_back_soon', 11),
#  ('would_come_again', 11),
#  ('food_service_excellent', 11),
#  ('every_time_come', 11),
#  ('probably_best_italian', 11),
#  ('asked_would_like', 11),
#  ('food_delicious_staff', 11),
#  ('favorite_santa_barbara', 11),
#  ('favorite_restaurant_sb', 11),
#  ('great_food_amazing', 11),
#  ('spaghetti_meat_sauce', 11),
#  ('worst_service_ever', 11),
#  ('perfect_date_night', 11),
#  ('able_get_table', 11),
#  ('wish_could_give', 11),
#  ('indoor_outdoor_seating', 11),
#  ('service_great_atmosphere', 11),
#  ('places_eat_santa', 11),
#  ('santa_barbara_dinner', 11),
#  ('service_little_slow', 11),
#  ('santa_barbara_amazing', 11),
#  ('italian_restaurant_sb', 11),
#  ('upper_state_street', 11),
#  ('right_next_us', 11),
#  ('came_back_said', 11),
#  ('amazing_food_service', 11),
#  ('best_pasta_ive', 11),
#  ('food_good_nothing', 11),
#  ('cant_wait_try', 11),
#  ('staff_always_friendly', 11),
#  ('sage_brown_butter', 11),
#  ('super_friendly_staff', 11),
#  ('pasta_cooked_perfectly', 11),
#  ('definitely_recommend_restaurant', 11),
#  ('good_customer_service', 11),
#  ('four_seasons_biltmore', 11),
#  ('service_great_too', 11),
#  ('came_check_us', 11),
#  ('could_give_stars', 11),
#  ('best_santa_barbara', 11),
#  ('delicious_authentic_italian', 11),
#  ('one_best_dining', 11),
#  ('best_dining_experiences', 11),
#  ('atmosphere_great_food', 11),
#  ('wine_list_good', 11),
#  ('time_im_town', 11),
#  ('two_pasta_dishes', 11),
#  ('give_place_try', 11),
#  ('come_back_place', 11),
#  ('go_wrong_here', 11),
#  ('definitely_come_again', 11),
#  ('look_forward_returning', 11),
#  ('santa_barbara_make', 11),
#  ('brown_butter_ravioli', 11),
#  ('portions_reasonable_prices', 11),
#  ('yummy_garlic_bread', 11),
#  ('go_back_place', 11),
#  ('located_state_street', 11),
#  ('penne_pasta_chipotle', 11),
#  ('pasta_chipotle_cream', 11),
#  ('blue_cheese_stuffed', 11),
#  ('free_garlic_bread', 11),
#  ('tuna_cones_must', 11),
#  ('grilled_romaine_salad', 11),
#  ('started_tuna_cones', 11),
#  ('across_street_beach', 11),
#  ('ahi_tuna_cones', 11),
#  ('beef_short_rib', 11),
#  ('say_one_best', 10),
#  ('best_meals_ive', 10),
#  ('service_food_quality', 10),
#  ('overall_good_experience', 10),
#  ('good_service_excellent', 10),
#  ('ate_last_night', 10),
#  ('used_love_place', 10),
#  ('couple_next_us', 10),
#  ('make_us_feel', 10),
#  ('service_food_good', 10),
#  ('great_food_excellent', 10),
#  ('im_glad_did', 10),
#  ('would_think_would', 10),
#  ('great_service_good', 10),
#  ('definitely_recommend_it', 10),
#  ('santa_barbara_visit', 10),
#  ('walking_state_street', 10),
#  ('wine_list_excellent', 10),
#  ('italian_restaurants_sb', 10),
#  ('came_take_order', 10),
#  ('ordered_medium_rare', 10),
#  ('service_impeccable_food', 10),
#  ('food_reasonable_price', 10),
#  ('santa_barbara_decided', 10),
#  ('could_care_less', 10),
#  ('pasta_ive_ever', 10),
#  ('food_ever_had', 10),
#  ('poor_customer_service', 10),
#  ('bad_taste_mouth', 10),
#  ('wrong_anything_menu', 10),
#  ('sauce_die_for', 10),
#  ('service_always_great', 10),
#  ('never_going_back', 10),
#  ('good_wine_selection', 10),
#  ('chocolate_bread_pudding', 10),
#  ('make_sure_get', 10),
#  ('nice_wine_list', 10),
#  ('would_recommend_it', 10),
#  ('told_us_would', 10),
#  ('let_start_saying', 10),
#  ('service_outstanding_food', 10),
#  ('not_say_enough', 10),
#  ('santa_barbara_excellent', 10),
#  ('sage_butter_sauce', 10),
#  ('fine_dining_experience', 10),
#  ('even_though_reservation', 10),
#  ('recommend_restaurant_anyone', 10),
#  ('service_pretty_good', 10),
#  ('one_best_dishes', 10),
#  ('friendly_staff_great', 10),
#  ('came_highly_recommended', 10),
#  ('absolutely_delicious_service', 10),
#  ('craving_italian_food', 10),
#  ('im_gon_na', 10),
#  ('light_cream_sauce', 10),
#  ('treated_us_like', 10),
#  ('time_were_santa', 10),
#  ('ive_ever_to', 10),
#  ('highly_highly_recommend', 10),
#  ('prix_fixe_menu', 10),
#  ('tagliatelle_verdi_alla', 10),
#  ('browned_butter_sage', 10),
#  ('order_something_else', 10),
#  ('santa_barbara_restaurants', 10),
#  ('recommend_making_reservations', 10),
#  ('reason_im_giving', 10),
#  ('good_garlic_bread', 10),
#  ('restaurant_great_food', 10),
#  ('make_sure_make', 10),
#  ('give_another_shot', 10),
#  ('shredded_phyllo_wrapped', 10),
#  ('penne_pasta_homemade', 10),
#  ('pasta_homemade_chipotle', 10),
#  ('homemade_chipotle_cream', 10),
#  ('phyllo_wrapped_prawns', 10),
#  ('fresh_salmon_filet', 10),
#  ('make_sure_ask', 10),
#  ('garlic_baked_brie', 10),
#  ('oil_cake_dessert', 10),
#  ('chicken_mushroom_risotto', 10),
#  ('chocolate_caramel_bar', 10),
#  ('gluten_free_options', 9),
#  ('took_forever_get', 9),
#  ('absolutely_love_place', 9),
#  ('service_hit_miss', 9),
#  ('probably_one_best', 9),
#  ('got_chicken_piccata', 9),
#  ('authentic_italian_cuisine', 9),
#  ('definitely_worth_it', 9),
#  ('food_wonderful_service', 9),
#  ('service_mediocre_food', 9),
#  ('best_italian_santa', 9),
#  ('right_state_street', 9),
#  ('even_though_place', 9),
#  ('santa_barbara_local', 9),
#  ('brought_us_bread', 9),
#  ('took_great_care', 9),
#  ('ill_definitely_back', 9),
#  ('highly_recommend_great', 9),
#  ('santa_barbara_must', 9),
#  ('great_authentic_italian', 9),
#  ('first_time_restaurant', 9),
#  ('place_date_night', 9),
#  ('every_time_santa', 9),
#  ('last_night_santa', 9),
#  ('really_looking_forward', 9),
#  ('maybe_next_time', 9),
#  ('memorial_day_weekend', 9),
#  ('food_fantastic_service', 9),
#  ('long_story_short', 9),
#  ('chicken_caesar_salad', 9),
#  ('last_saturday_night', 9),
#  ('oil_balsamic_vinegar', 9),
#  ('left_bad_taste', 9),
#  ('really_enjoyed_food', 9),
#  ('im_looking_forward', 9),
#  ('really_wanted_like', 9),
#  ('italian_food_town', 9),
#  ('brown_butter_sauce', 9),
#  ('stop_santa_barbara', 9),
#  ('great_food_delicious', 9),
#  ('italian_restaurant_ive', 9),
#  ('get_pay_for', 9),
#  ('way_make_sure', 9),
#  ('back_next_visit', 9),
#  ('looking_italian_restaurant', 9),
#  ('im_huge_fan', 9),
#  ('go_ca_dario', 9),
#  ('santa_barbara_county', 9),
#  ('clams_mussels_shrimp', 9),
#  ('place_really_good', 9),
#  ('service_attentive_friendly', 9),
#  ('service_food_great', 9),
#  ('food_great_ambiance', 9),
#  ('salami_goat_cheese', 9),
#  ('valentines_day_dinner', 9),
#  ('spaghetti_allo_scoglio', 9),
#  ('four_seasons_hotel', 9),
#  ('great_little_place', 9),
#  ('main_course_ordered', 9),
#  ('great_service_delicious', 9),
#  ('waited_another_minutes', 9),
#  ('decided_try_place', 9),
#  ('santa_barbara_got', 9),
#  ('id_come_back', 9),
#  ('friendly_food_delicious', 9),
#  ('forward_going_back', 9),
#  ('back_great_food', 9),
#  ('excellent_wine_list', 9),
#  ('pasta_meat_sauce', 9),
#  ('excellent_food_good', 9),
#  ('service_really_good', 9),
#  ('tasted_like_came', 9),
#  ('food_incredible_service', 9),
#  ('excellent_food_great', 9),
#  ('find_santa_barbara', 9),
#  ('told_us_could', 9),
#  ('couple_weeks_ago', 9),
#  ('ambiance_great_service', 9),
#  ('delicious_garlic_bread', 9),
#  ('creme_brulee_dessert', 9),
#  ('ravioli_die_for', 9),
#  ('food_good_price', 9),
#  ('good_portion_sizes', 9),
#  ('called_make_reservation', 9),
#  ('santa_barbara_looking', 9),
#  ('italian_restaurant_one', 9),
#  ('one_best_ever', 9),
#  ('food_absolutely_amazing', 9),
#  ('back_next_trip', 9),
#  ('food_tasted_good', 9),
#  ('fresh_baked_bread', 9),
#  ('phyllo_wrapped_shrimp', 9),
#  ('come_back_santa', 9),
#  ('coconut_curry_sauce', 9),
#  ('chile_crusted_filet', 9),
#  ('piece_garlic_bread', 9),
#  ('garlic_bread_also', 9),
#  ('braised_short_rib', 9),
#  ('play_bocce_ball', 9),
#  ('italian_food_best', 8),
#  ('cute_little_place', 8),
#  ('santa_barbara_husband', 8),
#  ('ordered_spaghetti_meatballs', 8),
#  ('best_italian_sb', 8),
#  ('place_first_time', 8),
#  ('service_friendly_staff', 8),
#  ('sitting_next_us', 8),
#  ('service_fantastic_food', 8),
#  ('last_night_food', 8),
#  ('seated_next_us', 8),
#  ('staff_great_food', 8),
#  ('food_friendly_service', 8),
#  ('back_anytime_soon', 8),
#  ('got_caesar_salad', 8),
#  ('time_even_though', 8),
#  ('ive_never_seen', 8),
#  ('service_even_better', 8),
#  ('restaurant_many_times', 8),
#  ('well_worth_wait', 8),
#  ('really_enjoyed_meal', 8),
#  ('olive_oil_vinegar', 8),
#  ('pasta_really_good', 8),
#  ('went_valentines_day', 8),
#  ('beautiful_santa_barbara', 8),
#  ('one_santa_barbaras', 8),
#  ('took_another_minutes', 8),
#  ('every_time_im', 8),
#  ('feel_right_home', 8),
#  ('would_order_again', 8),
#  ('ordered_caesar_salad', 8),
#  ('great_place_date', 8),
#  ('chicken_piccata_fettuccine', 8),
#  ('definitely_would_recommend', 8),
#  ('outdoor_dining_area', 8),
#  ('cacio_e_pepe', 8),
#  ('worst_dining_experience', 8),
#  ('gave_us_great', 8),
#  ('food_amazing_staff', 8),
#  ('family_owned_restaurant', 8),
#  ('santa_barbara_last', 8),
#  ('restaurant_state_street', 8),
#  ('dinner_saturday_night', 8),
#  ('great_location_great', 8),
#  ('day_santa_barbara', 8),
#  ('took_long_time', 8),
#  ('time_go_santa', 8),
#  ('would_go_again', 8),
#  ('dining_experience_food', 8),
#  ('die_for_service', 8),
#  ('italian_comfort_food', 8),
#  ('food_great_wine', 8),
#  ('went_way_make', 8),
#  ('asked_could_get', 8),
#  ('nothing_short_amazing', 8),
#  ('pollo_nel_coccio', 8),
#  ('good_nothing_special', 8),
#  ('filled_spinach_ricotta', 8),
#  ('ordered_pasta_dish', 8),
#  ('butter_sage_ravioli', 8),
#  ('squid_ink_spaghetti', 8),
#  ('santa_barbara_best', 8),
#  ('ravioli_sage_butter', 8),
#  ('wanted_like_place', 8),
#  ('making_us_feel', 8),
#  ('best_pasta_ever', 8),
#  ('great_service_too', 8),
#  ('ordered_something_different', 8),
#  ('santa_barbara_highly', 8),
#  ('gave_us_free', 8),
#  ('overall_food_good', 8),
#  ('busy_friday_night', 8),
#  ('sun_dried_tomato', 8),
#  ('lunch_santa_barbara', 8),
#  ('ive_ever_seen', 8),
#  ('staff_friendly_helpful', 8),
#  ('next_visit_santa', 8),
#  ('ill_back_sure', 8),
#  ('make_eye_contact', 8),
#  ('santa_barbara_want', 8),
#  ('really_enjoyed_it', 8),
#  ('really_good_service', 8),
#  ('ever_had_service', 8),
#  ('every_last_bite', 8),
#  ('lemon_cream_sauce', 8),
#  ('next_time_sb', 8),
#  ('santa_barbara_get', 8),
#  ('excellent_service_great', 8),
#  ('time_were_town', 8),
#  ('visit_next_time', 8),
#  ('wine_list_fantastic', 8),
#  ('santa_barbara_everything', 8),
#  ('celebrate_special_occasion', 8),
#  ('great_food_even', 8),
#  ('white_wine_butter', 8),
#  ('around_santa_barbara', 8),
#  ('curry_chicken_salad', 8),
#  ('beef_short_ribs', 8),
#  ('good_italian_restaurants', 8),
#  ('go_back_sure', 8),
#  ('looking_good_food', 8),
#  ('im_sure_would', 8),
#  ('great_food_nice', 8),
#  ('favorite_italian_place', 8),
#  ('italian_place_santa', 8),
#  ('amazing_food_amazing', 8),
#  ('short_rib_tender', 8),
#  ('cooked_al_dente', 8),
#  ('night_first_time', 8),
#  ('wanted_love_place', 8),
#  ('forward_next_visit', 8),
#  ('food_came_quickly', 8),
#  ('go_back_soon', 8),
#  ('italian_restaurants_town', 8),
#  ('return_santa_barbara', 8),
#  ('favorite_place_eat', 8),
#  ('santa_barbara_really', 8),
#  ('day_wine_tasting', 8),
#  ('place_state_street', 8),
#  ('ordered_rack_lamb', 8),
#  ('come_back_here', 8),
#  ('love_place_great', 8),
#  ('garlic_bread_great', 8),
#  ('great_garlic_bread', 8),
#  ('service_highly_recommend', 8),
#  ('great_place_great', 8),
#  ('first_time_santa', 8),
#  ('good_service_food', 8),
#  ('ive_santa_barbara', 8),
#  ('dining_experience_great', 8),
#  ('weekend_santa_barbara', 8),
#  ('sure_make_reservation', 8),
#  ('highly_recommend_anyone', 8),
#  ('broccoli_green_beans', 8),
#  ('vanilla_creme_brulee', 8),
#  ('highly_recommend_opal', 8),
#  ('opal_one_favorite', 8),
#  ('lemongrass_crusted_salmon', 8),
#  ('ordered_prime_rib', 8),
#  ('grass_crusted_salmon', 8),
#  ('herb_crusted_filet', 8),
#  ('ever_santa_barbara', 8),
#  ('want_come_back', 8),
#  ('roasted_garlic_baked', 8),
#  ('sundried_chicken_farfalle', 8),
#  ('amazing_garlic_bread', 8),
#  ('love_garlic_bread', 8),
#  ('chicken_sundried_tomatoes', 8),
#  ('santa_barbara_spicy', 8),
#  ('spicy_shrimp_pasta', 8),
#  ('food_great_price', 8),
#  ('sea_bass_special', 8),
#  ('highly_recommend_toma', 8),
#  ('cheese_stuffed_olives', 8),
#  ('olives_stuffed_blue', 8),
#  ('stuffed_blue_cheese', 8),
#  ('tuna_cones_grilled', 8),
#  ('ordered_glass_wine', 7),
#  ('mare_e_monti', 7),
#  ('go_back_went', 7),
#  ('attentive_food_delicious', 7),
#  ('looking_place_eat', 7),
#  ('well_thought_out', 7),
#  ('caesar_salad_good', 7),
#  ('good_staff_friendly', 7),
#  ('service_excellent_great', 7),
#  ('food_terrible_service', 7),
#  ('santa_barbara_anniversary', 7),
#  ('asked_speak_manager', 7),
#  ('looked_really_good', 7),
#  ('ordered_chicken_alfredo', 7),
#  ('went_santa_barbara', 7),
#  ('back_every_time', 7),
#  ('attentive_wait_staff', 7),
#  ('lunch_next_day', 7),
#  ('definitely_back_soon', 7),
#  ('stumbled_upon_place', 7),
#  ('restaurants_state_street', 7),
#  ('food_consistently_good', 7),
#  ('wait_staff_great', 7),
#  ('place_food_amazing', 7),
#  ('reservation_saturday_night', 7),
#  ('customer_service_great', 7),
#  ('back_would_recommend', 7),
#  ('food_service_good', 7),
#  ('breakfast_lunch_dinner', 7),
#  ('going_back_place', 7),
#  ('great_care_us', 7),
#  ('tried_seat_us', 7),
#  ('state_street_food', 7),
#  ('service_food_atmosphere', 7),
#  ('service_great_location', 7),
#  ('santa_barbara_try', 7),
#  ('good_would_go', 7),
#  ('next_time_ill', 7),
#  ('santa_barbaras_best', 7),
#  ('like_olive_garden', 7),
#  ('seat_us_right', 7),
#  ('friendly_staff_good', 7),
#  ('time_im_sb', 7),
#  ('heard_great_things', 7),
#  ('santa_barbara_came', 7),
#  ('food_wine_service', 7),
#  ('one_favorite_spots', 7),
#  ('everything_ordered_delicious', 7),
#  ('last_night_town', 7),
#  ('service_food_excellent', 7),
#  ('grilled_octopus_appetizer', 7),
#  ('get_act_together', 7),
#  ('probably_go_back', 7),
#  ('saturday_night_pm', 7),
#  ('server_told_us', 7),
#  ('service_good_well', 7),
#  ('fettuccine_alfredo_chicken', 7),
#  ('would_never_go', 7),
#  ('hes_ever_had', 7),
#  ('ive_ever_restaurant', 7),
#  ('santa_barbara_like', 7),
#  ('happy_hour_great', 7),
#  ('restaurant_great_service', 7),
#  ('food_came_quick', 7),
#  ('overall_pleasant_experience', 7),
#  ('nice_dining_experience', 7),
#  ('food_quality_service', 7),
#  ('lucky_enough_get', 7),
#  ('yummy_italian_food', 7),
#  ('beautiful_outdoor_patio', 7),
#  ('favorite_italian_food', 7),
#  ('best_pasta_dish', 7),
#  ('salmon_cooked_perfectly', 7),
#  ('thin_crust_pizza', 7),
#  ('goat_cheese_stuffed', 7),
#  ('server_friendly_attentive', 7),
#  ('times_every_time', 7),
#  ('recommend_coming_here', 7),
#  ('service_good_attentive', 7),
#  ('caramel_ice_cream', 7),
#  ('porcini_mushroom_sauce', 7),
#  ('one_best_things', 7),
#  ('chicken_curry_salad', 7),
#  ('restaurant_four_seasons', 7),
#  ('nice_italian_restaurant', 7),
#  ('special_dining_experience', 7),
#  ('excellent_italian_food', 7),
#  ('food_ok_service', 7),
#  ('pumpkin_ravioli_sage', 7),
#  ('best_meal_ive', 7),
#  ('great_place_lunch', 7),
#  ('food_top_notch', 7),
#  ('labor_day_weekend', 7),
#  ('pretty_good_service', 7),
#  ('good_portion_size', 7),
#  ('garlic_olive_oil', 7),
#  ('right_next_door', 7),
#  ('food_atmosphere_service', 7),
#  ('excellent_dining_experience', 7),
#  ('inside_four_seasons', 7),
#  ('barbara_first_time', 7),
#  ('meal_ive_ever', 7),
#  ('favorite_dish_night', 7),
#  ('vacation_santa_barbara', 7),
#  ('nice_staff_friendly', 7),
#  ('santa_barbara_family', 7),
#  ('barbara_highly_recommend', 7),
#  ('great_italian_restaurant', 7),
#  ('good_would_definitely', 7),
#  ('santa_barbara_many', 7),
#  ('two_glasses_wine', 7),
#  ('free_valet_parking', 7),
#  ('id_definitely_recommend', 7),
#  ('recommend_place_looking', 7),
#  ('based_yelp_reviews', 7),
#  ('drive_santa_barbara', 7),
#  ('next_trip_sb', 7),
#  ('next_time_area', 7),
#  ('looking_authentic_italian', 7),
#  ('totally_worth_it', 7),
#  ('mushroom_cream_sauce', 7),
#  ('italian_food_good', 7),
#  ('service_ambiance_food', 7),
#  ('great_service_really', 7),
#  ('pricey_worth_it', 7),
#  ('everything_absolutely_delicious', 7),
#  ('dining_experiences_ive', 7),
#  ('give_place_another', 7),
#  ('ordered_sea_bass', 7),
#  ('new_zealand_lamb', 7),
#  ('favorite_restaurants_sb', 7),
#  ('definitely_one_best', 7),
#  ('times_last_years', 7),
#  ('super_friendly_service', 7),
#  ('food_great_prices', 7),
#  ('fine_dining_establishment', 7),
#  ('one_favorite_dishes', 7),
#  ('santa_barbara_far', 7),
#  ('green_bell_pepper', 7),
#  ('great_lunch_dinner', 7),
#  ('able_accommodate_us', 7),
#  ('let_tell_you', 7),
#  ('absolutely_loved_it', 7),
#  ('santa_barbara_prices', 7),
#  ('ordered_seafood_pasta', 7),
#  ('hands_best_italian', 7),
#  ('garlic_bread_best', 7),
#  ('really_liked_place', 7),
#  ('right_state_st', 7),
#  ('ordered_filet_mignon', 7),
#  ('always_look_forward', 7),
#  ('experience_would_recommend', 7),
#  ('garlic_white_wine', 7),
#  ('lasagna_ive_ever', 7),
#  ('late_night_dinner', 7),
#  ('tomato_basil_soup', 7),
#  ('great_food_drinks', 7),
#  ('one_best_places', 7),
#  ('spaghettini_con_fasolari', 7),
#  ('great_quality_food', 7),
#  ('many_italian_restaurants', 7),
#  ('sure_make_reservations', 7),
#  ('pretty_good_food', 7),
#  ('whenever_santa_barbara', 7),
#  ('try_place_out', 7),
#  ('restaurant_across_street', 7),
#  ('die_for_great', 7),
#  ('best_dishes_ive', 7),
#  ('appetizer_main_course', 7),
#  ('experience_great_food', 7),
#  ('santa_barbara_location', 7),
#  ('food_always_excellent', 7),
#  ('home_made_pasta', 7),
#  ('top_notch_food', 7),
#  ('made_dining_experience', 7),
#  ('went_dinner_last', 7),
#  ('favorite_restaurant_town', 7),
#  ('prosciutto_goat_cheese', 7),
#  ('homemade_basil_fettuccine', 7),
#  ('crab_cake_appetizer', 7),
#  ('would_definitely_order', 7),
#  ('stuffed_chicken_risotto', 7),
#  ('time_were_sb', 7),
#  ('opal_last_night', 7),
#  ('santa_barbara_stop', 7),
#  ('anniversary_santa_barbara', 7),
#  ('bay_scallop_salad', 7),
#  ('good_husband_got', 7),
#  ('walked_without_reservation', 7),
#  ('santa_barbara_one', 7),
#  ('great_place_go', 7),
#  ('chocolate_pecan_tart', 7),
#  ('come_back_visit', 7),
#  ('th_wedding_anniversary', 7),
#  ('customer_service_good', 7),
#  ('tonight_first_time', 7),
#  ('go_back_santa', 7),
#  ('must_santa_barbara', 7),
#  ('chocolate_creme_brulee', 7),
#  ('food_fresh_delicious', 7),
#  ('great_atmosphere_great', 7),
#  ('sandwich_ive_ever', 7),
#  ('barbara_spicy_shrimp', 7),
#  ('garlic_bread_pretty', 7),
#  ('bread_caesar_salad', 7),
#  ('italian_cobb_panini', 7),
#  ('decided_try_toma', 7),
#  ('cones_grilled_octopus', 7),
#  ('de_la_vina', 7),
#  ('highly_recommend_arnoldis', 7),
#  ('bocce_ball_courts', 7),
#  ('another_glass_wine', 6),
#  ('never_asked_wanted', 6),
#  ('waiter_told_us', 6),
#  ('cant_wait_get', 6),
#  ('wonderful_italian_food', 6),
#  ('sat_bar_bartender', 6),
#  ('waiter_brought_us', 6),
#  ('long_time_food', 6),
#  ('food_highly_recommend', 6),
#  ('time_food_good', 6),
#  ('throughout_entire_meal', 6),
#  ('food_delicious_would', 6),
#  ('food_good_pasta', 6),
#  ('feel_like_eating', 6),
#  ('food_good_however', 6),
#  ('service_excellent_wine', 6),
#  ('excellent_wine_selection', 6),
#  ('looking_forward_to', 6),
#  ('taking_care_us', 6),
#  ('highly_recommend_going', 6),
#  ('delicious_staff_friendly', 6),
#  ('good_place_go', 6),
#  ('last_night_went', 6),
#  ('really_enjoy_food', 6),
#  ('yum_yum_yum', 6),
#  ('food_great_staff', 6),
#  ...]

# %%
bad_Italian=Italian[Italian.stars<3.5]
bad_Italian_review = Italian_review[Italian_review.business_id.isin(bad_Italian.business_id.values)]
bad_Italian_review_text = bad_Italian_review.text.str.cat(sep = " ")
bad_italian_tokens = word_tokenize(bad_Italian_review_text)
FreqDist(bad_italian_tokens).most_common()
bigrams_list_bad_italian = ["_".join(item) for item in nltk.bigrams(bad_italian_tokens)]
trigrams_list_bad_italian = ["_".join(item) for item in nltk.trigrams(bad_italian_tokens)]
# FreqDist(bigrams_list_bad_italian).most_common()
FreqDist(trigrams_list_bad_italian).most_common()
# Out:
# [('chase_bar_grill', 15),
#  ('food_pretty_good', 7),
#  ('go_somewhere_else', 5),
#  ('food_good_service', 5),
#  ('visiting_santa_barbara', 5),
#  ('ive_ever_had', 5),
#  ('would_go_back', 5),
#  ('made_us_feel', 5),
#  ('table_next_us', 5),
#  ('state_street_santa', 4),
#  ('street_santa_barbara', 4),
#  ('asked_speak_manager', 4),
#  ('service_good_food', 4),
#  ('service_great_food', 4),
#  ('great_service_food', 4),
#  ('french_onion_soup', 4),
#  ('happy_hour_menu', 4),
#  ('definitely_come_back', 4),
#  ('never_came_table', 4),
#  ('olive_oil_balsamic', 4),
#  ('santa_barbara_chase', 3),
#  ('never_came_back', 3),
#  ('never_go_back', 3),
#  ('think_would_go', 3),
#  ('great_happy_hour', 3),
#  ('got_chicken_piccata', 3),
#  ('would_definitely_come', 3),
#  ('would_definitely_recommend', 3),
#  ('definitely_going_back', 3),
#  ('downtown_santa_barbara', 3),
#  ('got_caesar_salad', 3),
#  ('state_street_looking', 3),
#  ('restaurant_santa_barbara', 3),
#  ('spaghetti_meat_sauce', 3),
#  ('would_right_us', 3),
#  ('chase_many_times', 3),
#  ('lobster_mac_cheese', 3),
#  ('took_minutes_get', 3),
#  ('great_customer_service', 3),
#  ('good_food_good', 3),
#  ('beautiful_santa_barbara', 3),
#  ('garlic_mashed_potatoes', 3),
#  ('another_half_hour', 3),
#  ('came_timely_manner', 3),
#  ('would_like_pay', 3),
#  ('like_pay_drinks', 3),
#  ('ordered_first_place', 3),
#  ('looking_forward_trying', 3),
#  ('visit_santa_barbara', 3),
#  ('vegan_chicken_parm', 3),
#  ('us_name_calling', 3),
#  ('another_mins_goes', 3),
#  ('back_santa_barbara', 2),
#  ('horrible_service_waiter', 2),
#  ('came_back_table', 2),
#  ('took_forever_get', 2),
#  ('would_go_somewhere', 2),
#  ('asked_us_wanted', 2),
#  ('sat_bar_bartender', 2),
#  ('waiter_brought_us', 2),
#  ('spicy_tomato_sauce', 2),
#  ('main_course_came', 2),
#  ('food_wonderful_service', 2),
#  ('five_minutes_later', 2),
#  ('santa_barbara_staple', 2),
#  ('night_santa_barbara', 2),
#  ('warm_inviting_atmosphere', 2),
#  ('print_bottom_menu', 2),
#  ('great_chicken_piccata', 2),
#  ('best_chicken_piccata', 2),
#  ('star_food_good', 2),
#  ('feel_like_family', 2),
#  ('dessert_ordered_cannoli', 2),
#  ('ten_minutes_later', 2),
#  ('really_really_good', 2),
#  ('christmas_lights_year', 2),
#  ('sat_front_patio', 2),
#  ('staff_great_food', 2),
#  ('restaurant_front_door', 2),
#  ('see_still_serving', 2),
#  ('make_us_feel', 2),
#  ('us_feel_rushed', 2),
#  ('ordered_chicken_alfredo', 2),
#  ('bar_grill_state', 2),
#  ('grill_state_street', 2),
#  ('id_go_back', 2),
#  ('probably_best_italian', 2),
#  ('best_italian_santa', 2),
#  ('italian_santa_barbara', 2),
#  ('santa_barbara_place', 2),
#  ('made_great_recommendations', 2),
#  ('soon_sat_bar', 2),
#  ('right_state_street', 2),
#  ('came_back_rare', 2),
#  ('go_chicken_picatta', 2),
#  ('chicken_picatta_amazing', 2),
#  ('great_food_great', 2),
#  ('staff_friendly_attentive', 2),
#  ('couple_hours_later', 2),
#  ('last_night_went', 2),
#  ('night_went_dinner', 2),
#  ('food_would_nice', 2),
#  ('lunch_last_week', 2),
#  ('definitely_back_soon', 2),
#  ('thank_you_chase', 2),
#  ('staff_friendly_atmosphere', 2),
#  ('santa_barbara_well', 2),
#  ('place_almost_empty', 2),
#  ('provided_exceptional_service', 2),
#  ('service_todd_bartender', 2),
#  ('service_even_better', 2),
#  ('favorite_santa_barbara', 2),
#  ('ordered_fettuccine_alfredo', 2),
#  ('fettuccine_alfredo_ok', 2),
#  ('food_santa_barbara', 2),
#  ('santa_barbara_came', 2),
#  ('another_couple_came', 2),
#  ('ordered_chicken_marsala', 2),
#  ('ordered_chicken_picatta', 2),
#  ('chicken_piccata_good', 2),
#  ('would_recommend_place', 2),
#  ('recommend_place_anyone', 2),
#  ('went_first_time', 2),
#  ('trip_santa_barbara', 2),
#  ('santa_barbara_day', 2),
#  ('definitely_coming_back', 2),
#  ('eat_food_good', 2),
#  ('bottle_wine_amazing', 2),
#  ('edgar_took_great', 2),
#  ('took_great_care', 2),
#  ('back_next_day', 2),
#  ('good_selection_wine', 2),
#  ('asked_could_sit', 2),
#  ('state_street_food', 2),
#  ('best_ive_ever', 2),
#  ('would_highly_recommend', 2),
#  ('seated_right_away', 2),
#  ('brought_water_bread', 2),
#  ('one_favorite_restaurants', 2),
#  ('favorite_restaurants_santa', 2),
#  ('service_great_atmosphere', 2),
#  ('stuffed_bell_pepper', 2),
#  ('lemon_caper_sauce', 2),
#  ('location_state_street', 2),
#  ('walking_state_street', 2),
#  ('frank_sinatra_playing', 2),
#  ('kind_old_school', 2),
#  ('chicken_picatta_fettuccine', 2),
#  ('caesar_salad_amazing', 2),
#  ('meal_would_go', 2),
#  ('better_italian_restaurants', 2),
#  ('italian_restaurants_sb', 2),
#  ('good_service_good', 2),
#  ('many_years_ago', 2),
#  ('one_favorite_places', 2),
#  ('delicious_highly_recommend', 2),
#  ('salad_glass_wine', 2),
#  ('right_away_first', 2),
#  ('seated_took_another', 2),
#  ('took_another_minutes', 2),
#  ('great_people_watching', 2),
#  ('service_absolutely_terrible', 2),
#  ('food_came_timely', 2),
#  ('italian_restaurant_since', 2),
#  ('chicken_noodle_soup', 2),
#  ('butter_pecan_cheesecake', 2),
#  ('heard_great_things', 2),
#  ('decided_grab_dinner', 2),
#  ('salad_spaghetti_marinara', 2),
#  ('santa_barbara_food', 2),
#  ('used_one_favorite', 2),
#  ('santa_barbara_im', 2),
#  ('pay_drinks_leave', 2),
#  ('felt_like_held', 2),
#  ('like_held_hostage', 2),
#  ('great_dining_experience', 2),
#  ('one_best_restaurants', 2),
#  ('restaurants_santa_barbara', 2),
#  ('alfredo_sauce_noodles', 2),
#  ('almost_ten_minutes', 2),
#  ('asked_could_move', 2),
#  ('could_move_table', 2),
#  ('minutes_later_manager', 2),
#  ('party_next_us', 2),
#  ('way_treat_customers', 2),
#  ('almost_dead_plant', 2),
#  ('never_refilled_water', 2),
#  ('would_give_stars', 2),
#  ('probably_would_go', 2),
#  ('right_next_us', 2),
#  ('dinner_friend_food', 2),
#  ('waste_time_money', 2),
#  ('would_definitely_consider', 2),
#  ('italian_restaurant_first', 2),
#  ('server_told_us', 2),
#  ('lower_state_street', 2),
#  ('state_street_atmosphere', 2),
#  ('example_recent_visit', 2),
#  ('came_back_said', 2),
#  ('gave_us_great', 2),
#  ('told_oh_happy', 2),
#  ('oh_happy_hour', 2),
#  ('can_not_believe', 2),
#  ('restaurant_state_street', 2),
#  ('bad_food_good', 2),
#  ('came_santa_barbara', 2),
#  ('salmon_arugula_salad', 2),
#  ('chicken_caesar_salad', 2),
#  ('bbq_sauce_onion', 2),
#  ('sauce_onion_shreds', 2),
#  ('ive_never_done', 2),
#  ('medium_rare_steak', 2),
#  ('could_care_less', 2),
#  ('food_took_forever', 2),
#  ('took_another_half', 2),
#  ('ive_ever_experienced', 2),
#  ('wonderful_dining_experience', 2),
#  ('side_garlic_mashed', 2),
#  ('outdoor_seating_nice', 2),
#  ('let_know_one', 2),
#  ('food_orders_in', 2),
#  ('chicken_pesto_sandwich', 2),
#  ('go_happy_hour', 2),
#  ('strawberry_basil_cocktail', 2),
#  ('fried_calamari_fresh', 2),
#  ('calamari_fresh_steamed', 2),
#  ('fresh_steamed_clams', 2),
#  ('fried_calamari_slight', 2),
#  ('tomahawk_steak_cooked', 2),
#  ('really_well_steak', 2),
#  ('hell_restaurant_would', 2),
#  ('restaurant_would_one', 2),
#  ('would_one_never', 2),
#  ('one_never_left', 2),
#  ('never_left_restaurant', 2),
#  ('left_restaurant_feeling', 2),
#  ('restaurant_feeling_disrespected', 2),
#  ('feeling_disrespected_frustrated', 2),
#  ('disrespected_frustrated_angry', 2),
#  ('frustrated_angry_audacity', 2),
#  ('angry_audacity_staff', 2),
#  ('audacity_staff_multiple', 2),
#  ('staff_multiple_levels', 2),
#  ('multiple_levels_truly', 2),
#  ('levels_truly_impressive', 2),
#  ('truly_impressive_unwillingness', 2),
#  ('impressive_unwillingness_accept', 2),
#  ('unwillingness_accept_responsibility', 2),
#  ('accept_responsibility_equally', 2),
#  ('responsibility_equally_so', 2),
#  ('equally_so_seated', 2),
#  ('so_seated_reservation', 2),
#  ('seated_reservation_server', 2),
#  ('reservation_server_middle', 2),
#  ('server_middle_aged', 2),
#  ('middle_aged_blonde', 2),
#  ('aged_blonde_lady', 2),
#  ('blonde_lady_look', 2),
#  ('lady_look_happy', 2),
#  ('look_happy_there', 2),
#  ('happy_there_unenthusiastically', 2),
#  ('there_unenthusiastically_took', 2),
#  ('unenthusiastically_took_order', 2),
#  ('took_order_asked', 2),
#  ('order_asked_olive', 2),
#  ('asked_olive_oil', 2),
#  ('oil_balsamic_vinegar', 2),
#  ('balsamic_vinegar_another', 2),
#  ('vinegar_another_member', 2),
#  ('another_member_party', 2),
#  ('member_party_asked', 2),
#  ('party_asked_baked', 2),
#  ('asked_baked_ziti', 2),
#  ('baked_ziti_tomahawk', 2),
#  ('ziti_tomahawk_steak', 2),
#  ('tomahawk_steak_glass', 2),
#  ('steak_glass_white', 2),
#  ('glass_white_wine', 2),
#  ('white_wine_yelp', 2),
#  ('wine_yelp_check', 2),
#  ('yelp_check_discount', 2),
#  ('check_discount_mentioned', 2),
#  ('discount_mentioned_ziti', 2),
#  ('mentioned_ziti_would', 2),
#  ('ziti_would_take', 2),
#  ('would_take_longer', 2),
#  ('take_longer_check', 2),
#  ('longer_check_marked', 2),
#  ('check_marked_used', 2),
#  ('marked_used_box', 2),
#  ('used_box_yelp', 2),
#  ('box_yelp_acknowledging', 2),
#  ('yelp_acknowledging_orders', 2),
#  ('acknowledging_orders_runner', 2),
#  ('orders_runner_brought', 2),
#  ('runner_brought_bread', 2),
#  ('brought_bread_table', 2),
#  ('bread_table_kindly', 2),
#  ('table_kindly_reminded', 2),
#  ('kindly_reminded_olive', 2),
#  ('reminded_olive_oil', 2),
#  ('oil_balsamic_asked', 2),
#  ('balsamic_asked_for', 2),
#  ('asked_for_took', 2),
#  ('for_took_minutes', 2),
#  ('took_minutes_flagging', 2),
#  ('minutes_flagging_runners', 2),
#  ('flagging_runners_finally', 2),
#  ('runners_finally_asking', 2),
#  ('finally_asking_hostess', 2),
#  ('asking_hostess_get', 2),
#  ('hostess_get_it', 2),
#  ('get_it_point', 2),
#  ('it_point_food', 2),
#  ('point_food_arrived', 2),
#  ('food_arrived_even', 2),
#  ('arrived_even_interested', 2),
#  ('even_interested_cold', 2),
#  ('interested_cold_bread', 2),
#  ('cold_bread_anymore', 2),
#  ('bread_anymore_server', 2),
#  ('anymore_server_never', 2),
#  ('server_never_came', 2),
#  ('came_table_taking', 2),
#  ('table_taking_order', 2),
#  ('taking_order_putting', 2),
#  ('order_putting_plates', 2),
#  ('putting_plates_finally', 2),
#  ('plates_finally_politely', 2),
#  ('finally_politely_reminded', 2),
#  ('politely_reminded_wine', 2),
#  ('reminded_wine_order', 2),
#  ('wine_order_unapologetically', 2),
#  ('order_unapologetically_asked', 2),
#  ('unapologetically_asked_id', 2),
#  ('asked_id_acted', 2),
#  ('id_acted_never', 2),
#  ('acted_never_ordered', 2),
#  ('never_ordered_first', 2),
#  ('first_place_runner', 2),
#  ('place_runner_served', 2),
#  ('runner_served_tomahawk', 2),
#  ('served_tomahawk_order', 2),
#  ('tomahawk_order_instead', 2),
#  ('order_instead_baked', 2),
#  ('instead_baked_ziti', 2),
#  ('baked_ziti_served', 2),
#  ('ziti_served_baked', 2),
#  ('served_baked_potato', 2),
#  ('baked_potato_politely', 2),
#  ('potato_politely_informed', 2),
#  ('politely_informed_incorrect', 2),
#  ('informed_incorrect_order', 2),
#  ('incorrect_order_she', 2),
#  ('order_she_without', 2),
#  ('she_without_apologizing', 2),
#  ('without_apologizing_explained', 2),
#  ('apologizing_explained_kitchen', 2),
#  ('explained_kitchen_mustve', 2),
#  ('kitchen_mustve_read', 2),
#  ('mustve_read_order', 2),
#  ('read_order_wrong', 2),
#  ('order_wrong_itll', 2),
#  ('wrong_itll_take', 2),
#  ('itll_take_while', 2),
#  ('take_while_admittedly', 2),
#  ('while_admittedly_receiving', 2),
#  ('admittedly_receiving_consistently', 2),
#  ('receiving_consistently_unacceptable', 2),
#  ('consistently_unacceptable_service', 2),
#  ('unacceptable_service_hour', 2),
#  ('service_hour_party', 2),
#  ('hour_party_quite', 2),
#  ('party_quite_upset', 2),
#  ('quite_upset_less', 2),
#  ('upset_less_subtle', 2),
#  ('less_subtle_voicing', 2),
#  ('subtle_voicing_dissatisfaction', 2),
#  ('voicing_dissatisfaction_service', 2),
#  ('dissatisfaction_service_other', 2),
#  ('service_other_later', 2),
#  ('other_later_found', 2),
#  ('later_found_overheard', 2),
#  ('found_overheard_us', 2),
#  ('overheard_us_saying', 2),
#  ('us_saying_the', 2),
#  ('saying_the_worst', 2),
#  ('the_worst_service', 2),
#  ('worst_service_ever', 2),
#  ('service_ever_had', 2),
#  ('ever_had_unfortunate', 2),
#  ('had_unfortunate_overhead', 2),
#  ('unfortunate_overhead_us', 2),
#  ('overhead_us_certainly', 2),
#  ('us_certainly_deserved', 2),
#  ('certainly_deserved_title', 2),
#  ('deserved_title_imagine', 2),
#  ('title_imagine_though', 2),
#  ('imagine_though_things', 2),
#  ('though_things_improve', 2),
#  ('things_improve_met', 2),
#  ('improve_met_uncomfortable', 2),
#  ('met_uncomfortable_glances', 2),
#  ('uncomfortable_glances_stares', 2),
#  ('glances_stares_staff', 2),
#  ('stares_staff_remainder', 2),
#  ('staff_remainder_night', 2),
#  ('remainder_night_another', 2),
#  ('night_another_minutes', 2),
#  ('another_minutes_receiving', 2),
#  ('minutes_receiving_baked', 2),
#  ('receiving_baked_ziti', 2),
#  ('baked_ziti_walked', 2),
#  ('ziti_walked_because', 2),
#  ('walked_because_god', 2),
#  ('because_god_knows', 2),
#  ('god_knows_checking', 2),
#  ('knows_checking_table', 2),
#  ('checking_table_politely', 2),
#  ('table_politely_asked', 2),
#  ('politely_asked_check', 2),
#  ('asked_check_it', 2),
#  ('check_it_responded', 2),
#  ('it_responded_yeah', 2),
#  ('responded_yeah_kitchen', 2),
#  ('yeah_kitchen_making', 2),
#  ('kitchen_making_it', 2),
#  ('making_it_ive', 2),
#  ('it_ive_asked', 2),
#  ('ive_asked_times', 2),
#  ('asked_times_it', 2),
#  ('times_it_stunned', 2),
#  ('it_stunned_baffled', 2),
#  ('stunned_baffled_blatancy', 2),
#  ('baffled_blatancy_rudeness', 2),
#  ('blatancy_rudeness_immediately', 2),
#  ('rudeness_immediately_walked', 2),
#  ('immediately_walked_toward', 2),
#  ('walked_toward_hostess', 2),
#  ('toward_hostess_asked', 2),
#  ('hostess_asked_manager', 2),
#  ('asked_manager_hostess', 2),
#  ('manager_hostess_brought', 2),
#  ('hostess_brought_check', 2),
#  ('brought_check_minutes', 2),
#  ('check_minutes_later', 2),
#  ('minutes_later_said', 2),
#  ('later_said_i', 2),
#  ('said_i_told', 2),
#  ('i_told_give', 2),
#  ('told_give_you', 2),
#  ('give_you_asked', 2),
#  ('you_asked_manager', 2),
#  ('asked_manager_again', 2),
#  ('manager_again_said', 2),
#  ('again_said_way', 2),
#  ('said_way_came', 2),
#  ('way_came_minutes', 2),
#  ('came_minutes_later', 2),
#  ('minutes_later_followed', 2),
#  ('later_followed_assume', 2),
#  ('followed_assume_from', 2),
#  ('assume_from_reviews', 2),
#  ('from_reviews_bartender', 2),
#  ('reviews_bartender_bartender', 2),
#  ('bartender_bartender_puffed', 2),
#  ('bartender_puffed_chest', 2),
#  ('puffed_chest_like', 2),
#  ('chest_like_going', 2),
#  ('like_going_initiate', 2),
#  ('going_initiate_physical', 2),
#  ('initiate_physical_confrontation', 2),
#  ('physical_confrontation_accused', 2),
#  ('confrontation_accused_us', 2),
#  ('accused_us_name', 2),
#  ('name_calling_servers', 2),
#  ('calling_servers_nothing', 2),
#  ('servers_nothing_sort', 2),
#  ('nothing_sort_manager', 2),
#  ('sort_manager_mentioned', 2),
#  ('manager_mentioned_server', 2),
#  ('mentioned_server_overheard', 2),
#  ('server_overheard_im', 2),
#  ('overheard_im_opinion', 2),
#  ('im_opinion_name', 2),
#  ('opinion_name_calling', 2),
#  ('name_calling_opinion', 2),
#  ('calling_opinion_service', 2),
#  ('opinion_service_thing', 2),
#  ('service_thing_manager', 2),
#  ('thing_manager_apologized', 2),
#  ('manager_apologized_gave', 2),
#  ('apologized_gave_many', 2),
#  ('gave_many_excuse', 2),
#  ('many_excuse_poor', 2),
#  ('excuse_poor_service', 2),
#  ('poor_service_made', 2),
#  ('service_made_point', 2),
#  ('made_point_mention', 2),
#  ('point_mention_long', 2),
#  ('mention_long_server', 2),
#  ('long_server_restaurant', 2),
#  ('server_restaurant_industry', 2),
#  ('restaurant_industry_hard', 2),
#  ('industry_hard_outdoor', 2),
#  ('hard_outdoor_dining', 2),
#  ('outdoor_dining_look', 2),
#  ('dining_look_understand', 2),
#  ('look_understand_fb', 2),
#  ('understand_fb_industry', 2),
#  ('fb_industry_rough', 2),
#  ('industry_rough_year', 2),
#  ('rough_year_server', 2),
#  ('year_server_probably', 2),
#  ('server_probably_overworked', 2),
#  ('probably_overworked_underpaid', 2),
#  ('overworked_underpaid_all', 2),
#  ('underpaid_all_excuse', 2),
#  ('all_excuse_unapologetically', 2),
#  ('excuse_unapologetically_bad', 2),
#  ('unapologetically_bad_service', 2),
#  ('bad_service_even', 2),
#  ('service_even_sorry', 2),
#  ('even_sorry_wouldve', 2),
#  ('sorry_wouldve_nice', 2),
#  ('wouldve_nice_and', 2),
#  ('nice_and_im', 2),
#  ('and_im_sorry', 2),
#  ('im_sorry_server', 2),
#  ('sorry_server_business', 2),
#  ('server_business_cant', 2),
#  ('business_cant_figure', 2),
#  ('cant_figure_provide', 2),
#  ('figure_provide_good', 2),
#  ('provide_good_service', 2),
#  ('good_service_charging', 2),
#  ('service_charging_exorbitant', 2),
#  ('charging_exorbitant_prices', 2),
#  ('exorbitant_prices_chase', 2),
#  ('prices_chase_does', 2),
#  ('chase_does_maybe', 2),
#  ('does_maybe_business', 2),
#  ('maybe_business_shame', 2),
#  ('business_shame_terrible', 2),
#  ('shame_terrible_experience', 2),
#  ('terrible_experience_here', 2),
#  ('experience_here_meal', 2),
#  ('here_meal_actually', 2),
#  ('meal_actually_quite', 2),
#  ('actually_quite_decent', 2),
#  ('quite_decent_audacity', 2),
#  ('decent_audacity_staff', 2),
#  ('audacity_staff_left', 2),
#  ('staff_left_bad', 2),
#  ('left_bad_taste', 2),
#  ('bad_taste_mouth', 2),
#  ('taste_mouth_dessert', 2),
#  ('delicious_outdoor_seating', 2),
#  ('manhattan_clam_chowder', 2),
#  ('took_min_drinks', 2),
#  ('min_drinks_come', 2),
#  ('finally_got_sat', 2),
#  ('salmon_angel_hair', 2),
#  ('towards_non_whites', 2),
#  ('wow_wow_weve', 1),
#  ('wow_weve_trying', 1),
#  ('weve_trying_go', 1),
#  ('trying_go_reason', 1),
#  ('go_reason_another', 1),
#  ('reason_another_happened', 1),
#  ('another_happened_used', 1),
#  ('happened_used_access', 1),
#  ('used_access_card', 1),
#  ('access_card_walked', 1),
#  ('card_walked_last', 1),
#  ('walked_last_night', 1),
#  ('last_night_must', 1),
#  ('night_must_say', 1),
#  ('must_say_one', 1),
#  ('say_one_best', 1),
#  ('one_best_meals', 1),
#  ('best_meals_ive', 1),
#  ('meals_ive_awhile', 1),
#  ('ive_awhile_italian', 1),
#  ('awhile_italian_food', 1),
#  ('italian_food_best', 1),
#  ('food_best_ive', 1),
#  ('best_ive_forever', 1),
#  ('ive_forever_long', 1),
#  ('forever_long_time', 1),
#  ('long_time_coming', 1),
#  ('time_coming_back', 1),
#  ('coming_back_deep', 1),
#  ('back_deep_fried', 1),
#  ('deep_fried_ravioli', 1),
#  ('fried_ravioli_appetizer', 1),
#  ('ravioli_appetizer_chicken', 1),
#  ('appetizer_chicken_alfredo', 1),
#  ('chicken_alfredo_eggplant', 1),
#  ('alfredo_eggplant_parmesan', 1),
#  ('eggplant_parmesan_entrees', 1),
#  ('parmesan_entrees_ordered', 1),
#  ('entrees_ordered_glass', 1),
#  ('ordered_glass_wine', 1),
#  ('glass_wine_realize', 1),
#  ('wine_realize_could', 1),
#  ('realize_could_buy', 1),
#  ('could_buy_bottle', 1),
#  ('buy_bottle_later', 1),
#  ('bottle_later_fine', 1),
#  ('later_fine_understand', 1),
#  ('fine_understand_come', 1),
#  ('understand_come_back', 1),
#  ('come_back_served', 1),
#  ('back_served_mario', 1),
#  ('served_mario_best', 1),
#  ('mario_best_enough', 1),
#  ('best_enough_superlatives', 1),
#  ('enough_superlatives_awesome', 1),
#  ('superlatives_awesome_food', 1),
#  ('awesome_food_drink', 1),
#  ('food_drink_personnel', 1),
#  ('drink_personnel_cant', 1),
#  ('personnel_cant_wait', 1),
#  ('cant_wait_get', 1),
#  ('wait_get_back', 1),
#  ('get_back_santa', 1),
#  ('barbara_chase_terry', 1),
#  ('chase_terry_horrible', 1),
#  ('terry_horrible_service', 1),
#  ('service_waiter_never', 1),
#  ('waiter_never_checked', 1),
#  ('never_checked_us', 1),
#  ('checked_us_flag', 1),
#  ('us_flag_tell', 1),
#  ('flag_tell_raviolis', 1),
#  ('tell_raviolis_terrible', 1),
#  ('raviolis_terrible_clump', 1),
#  ('terrible_clump_dough', 1),
#  ('clump_dough_plate', 1),
#  ('dough_plate_cheese', 1),
#  ('plate_cheese_spilled', 1),
#  ('cheese_spilled_raviolis', 1),
#  ('spilled_raviolis_plate', 1),
#  ('raviolis_plate_told', 1),
#  ('plate_told_waiter', 1),
#  ('told_waiter_said', 1),
#  ('waiter_said_huh', 1),
#  ('said_huh_walked', 1),
#  ('huh_walked_away', 1),
#  ('walked_away_came', 1),
#  ('away_came_back', 1),
#  ('came_back_check', 1),
#  ('back_check_asked', 1),
#  ('check_asked_clump', 1),
#  ('asked_clump_dough', 1),
#  ('clump_dough_said', 1),
#  ('dough_said_thats', 1),
#  ('said_thats_make', 1),
#  ('thats_make_them', 1),
#  ('make_them_explain', 1),
#  ('them_explain_raviolis', 1),
#  ('explain_raviolis_filling', 1),
#  ('raviolis_filling_husbands', 1),
#  ('filling_husbands_porkchop', 1),
#  ('husbands_porkchop_dry', 1),
#  ('porkchop_dry_bland', 1),
#  ('dry_bland_waiter', 1),
#  ('bland_waiter_arrogant', 1),
#  ('waiter_arrogant_never', 1),
#  ('arrogant_never_said', 1),
#  ('never_said_sorry', 1),
#  ('said_sorry_never', 1),
#  ('sorry_never_came', 1),
#  ('back_table_took', 1),
#  ('table_took_order', 1),
#  ('took_order_took', 1),
#  ('order_took_forever', 1),
#  ('forever_get_take', 1),
#  ('get_take_order', 1),
#  ('take_order_eat', 1),
#  ('order_eat_pieces', 1),
#  ('eat_pieces_bread', 1),
#  ('pieces_bread_fill', 1),
#  ('bread_fill_up', 1),
#  ('fill_up_walked', 1),
#  ('up_walked_hungry', 1),
#  ('walked_hungry_take', 1),
#  ('hungry_take_bill', 1),
#  ('take_bill_awkward', 1),
#  ('bill_awkward_conversation', 1),
#  ('awkward_conversation_waiter', 1),
#  ('conversation_waiter_never', 1),
#  ('waiter_never_go', 1),
#  ('go_back_pricy', 1),
#  ('back_pricy_quality', 1),
#  ('pricy_quality_food', 1),
#  ('quality_food_given', 1),
#  ('food_given_disappointing', 1),
#  ('given_disappointing_stopped', 1),
#  ('disappointing_stopped_quick', 1),
#  ('stopped_quick_bite', 1),
#  ('quick_bite_lunch', 1),
#  ('bite_lunch_time', 1),
#  ('lunch_time_decor', 1),
#  ('time_decor_okit', 1),
#  ('decor_okit_smallso', 1),
#  ('okit_smallso_one', 1),
#  ('smallso_one_kid', 1),
#  ('one_kid_might', 1),
#  ('kid_might_waiting', 1),
#  ('might_waiting_food', 1),
#  ('waiting_food_frankly', 1),
#  ('food_frankly_bad', 1),
#  ('frankly_bad_chicken', 1),
#  ('bad_chicken_parm', 1),
#  ('chicken_parm_sandwich', 1),
#  ('parm_sandwich_wife', 1),
#  ('sandwich_wife_sort', 1),
#  ('wife_sort_pasta', 1),
#  ('sort_pasta_bad', 1),
#  ('pasta_bad_service', 1),
#  ('bad_service_oknothing', 1),
#  ('service_oknothing_experienced', 1),
#  ('oknothing_experienced_reviewers', 1),
#  ('experienced_reviewers_had', 1),
#  ('reviewers_had_one', 1),
#  ('had_one_kid', 1),
#  ('one_kid_find', 1),
#  ('kid_find_tucked', 1),
#  ('find_tucked_away', 1),
#  ('tucked_away_corner', 1),
#  ('away_corner_big', 1),
#  ('corner_big_strollers', 1),
#  ('big_strollers_mulitple', 1),
#  ('strollers_mulitple_kidsi', 1),
#  ('mulitple_kidsi_think', 1),
#  ('kidsi_think_would', 1),
#  ('somewhere_else_enjoyed', 1),
#  ('else_enjoyed_great', 1),
#  ('enjoyed_great_dinner', 1),
#  ('great_dinner_bar', 1),
#  ('dinner_bar_cold', 1),
#  ('bar_cold_february', 1),
#  ('cold_february_night', 1),
#  ('february_night_fantastic', 1),
#  ('night_fantastic_atmosphere', 1),
#  ('fantastic_atmosphere_great', 1),
#  ('atmosphere_great_wine', 1),
#  ('great_wine_counsel', 1),
#  ('wine_counsel_bartender', 1),
#  ('counsel_bartender_dinner', 1),
#  ('bartender_dinner_great', 1),
#  ('dinner_great_met', 1),
#  ('great_met_locals', 1),
#  ('met_locals_seem', 1),
#  ('locals_seem_regulars', 1),
#  ('seem_regulars_always', 1),
#  ('regulars_always_good', 1),
#  ('always_good_sign', 1),
#  ('good_sign_decor', 1),
#  ('sign_decor_spirited', 1),
#  ('decor_spirited_blend', 1),
#  ('spirited_blend_top', 1),
#  ('blend_top_madonna', 1),
#  ('top_madonna_inn', 1),
#  ('madonna_inn_english', 1),
#  ('inn_english_pub', 1),
#  ('english_pub_holiday', 1),
#  ('pub_holiday_event', 1),
#  ('holiday_event_definitely', 1),
#  ('event_definitely_go', 1),
#  ('definitely_go_back', 1),
#  ('go_back_ive', 1),
#  ('back_ive_eaten', 1),
#  ('ive_eaten_twice', 1),
#  ('eaten_twice_second', 1),
#  ('twice_second_time', 1),
#  ('second_time_last', 1),
#  ('time_last_week', 1),
#  ('last_week_ordered', 1),
#  ('week_ordered_sliders', 1),
#  ('ordered_sliders_second', 1),
#  ('sliders_second_time', 1),
#  ('second_time_made', 1),
#  ('time_made_sick', 1),
#  ('made_sick_beef', 1),
#  ('sick_beef_gone', 1),
#  ('beef_gone_bad', 1),
#  ('gone_bad_got', 1),
#  ('bad_got_stomach', 1),
#  ('got_stomach_ache', 1),
#  ('stomach_ache_thank', 1),
#  ('ache_thank_god', 1),
#  ('thank_god_ate', 1),
#  ('god_ate_one', 1),
#  ('ate_one_case', 1),
#  ('one_case_wondering', 1),
#  ('case_wondering_first', 1),
#  ('wondering_first_time', 1),
#  ('first_time_chicken', 1),
#  ('time_chicken_picatta', 1),
#  ('chicken_picatta_tasted', 1),
#  ('picatta_tasted_great', 1),
#  ('tasted_great_know', 1),
#  ('great_know_happened', 1),
#  ('know_happened_place', 1),
#  ('happened_place_found', 1),
#  ('place_found_santa', 1),
#  ('found_santa_barbara', 1),
#  ('santa_barbara_ucsb', 1),
#  ('barbara_ucsb_graduation', 1),
#  ('ucsb_graduation_weekend', 1),
#  ('graduation_weekend_yikes', 1),
#  ('weekend_yikes_anyway', 1),
#  ('yikes_anyway_looking', 1),
#  ('anyway_looking_place', 1),
#  ('looking_place_eat', 1),
#  ('place_eat_found', 1),
#  ('eat_found_chase', 1),
#  ('found_chase_yelp', 1),
#  ('chase_yelp_headed', 1),
#  ('yelp_headed_out', 1),
#  ('headed_out_bit', 1),
#  ('out_bit_odd', 1),
#  ('bit_odd_experience', 1),
#  ('odd_experience_go', 1),
#  ('experience_go_parked', 1),
#  ('go_parked_back', 1),
#  ('parked_back_easy', 1),
#  ('back_easy_great', 1),
#  ('easy_great_came', 1),
#  ('great_came_in', 1),
#  ('came_in_host', 1),
#  ('in_host_asked', 1),
#  ('host_asked_us', 1),
#  ('us_wanted_table', 1),
#  ('wanted_table_said', 1),
#  ('table_said_yes', 1),
#  ('said_yes_two', 1),
#  ('yes_two_said', 1),
#  ('two_said_minute', 1),
#  ('said_minute_never', 1),
#  ('minute_never_came', 1),
#  ('came_back_walked', 1),
#  ('back_walked_us', 1),
#  ('walked_us_several', 1),
#  ('us_several_times', 1),
#  ('several_times_looked', 1),
#  ('times_looked_like', 1),
#  ('looked_like_table', 1),
#  ('like_table_sorted', 1),
#  ('table_sorted_out', 1),
#  ('sorted_out_sat', 1),
#  ('out_sat_bar', 1),
#  ('bar_bartender_nice', 1),
#  ('bartender_nice_made', 1),
#  ('nice_made_great', 1),
#  ('made_great_lemon', 1),
#  ('great_lemon_drop', 1),
#  ('lemon_drop_menu', 1),
#  ('drop_menu_tough', 1),
#  ('menu_tough_vegetarian', 1),
#  ('tough_vegetarian_sufficed', 1),
#  ('vegetarian_sufficed_salad', 1),
#  ('sufficed_salad_bread', 1),
#  ('salad_bread_bf', 1),
#  ('bread_bf_chicken', 1),
#  ('bf_chicken_piccata', 1),
#  ('chicken_piccata_specialty', 1),
#  ('piccata_specialty_thought', 1),
#  ('specialty_thought_average', 1),
#  ('thought_average_cute', 1),
#  ('average_cute_little', 1),
#  ('cute_little_place', 1),
#  ('little_place_maybe', 1),
#  ('place_maybe_menu', 1),
#  ('maybe_menu_suit', 1),
#  ('menu_suit_better', 1),
#  ('suit_better_always', 1),
#  ('better_always_like', 1),
#  ('always_like_going', 1),
#  ('like_going_chase', 1),
#  ('going_chase_food', 1),
#  ('chase_food_pretty', 1),
#  ('pretty_good_not', 1),
#  ('good_not_great', 1),
#  ('not_great_consistently', 1),
#  ('great_consistently_pretty', 1),
#  ('consistently_pretty_good', 1),
#  ('pretty_good_wife', 1),
#  ('good_wife_really', 1),
#  ('wife_really_likes', 1),
#  ('really_likes_atmosphere', 1),
#  ('likes_atmosphere_end', 1),
#  ('atmosphere_end_going', 1),
#  ('end_going_quite', 1),
#  ('going_quite_frequently', 1),
#  ('quite_frequently_wondering', 1),
#  ('frequently_wondering_atomosphere', 1),
#  ('wondering_atomosphere_got', 1),
#  ('atomosphere_got_whole', 1),
#  ('got_whole_red', 1),
#  ('whole_red_booth', 1),
#  ('red_booth_thing', 1),
#  ('booth_thing_goings', 1),
#  ('thing_goings_twinkle', 1),
#  ('goings_twinkle_lights', 1),
#  ('twinkle_lights_hanging', 1),
#  ('lights_hanging_areas', 1),
#  ('hanging_areas_restaurant', 1),
#  ('areas_restaurant_romantic', 1),
#  ('restaurant_romantic_spot', 1),
#  ('romantic_spot_crowd', 1),
#  ('spot_crowd_full', 1),
#  ('crowd_full_bar', 1),
#  ('full_bar_service', 1),
#  ('bar_service_hit', 1),
#  ('service_hit_miss', 1),
#  ('hit_miss_sometimes', 1),
#  ('miss_sometimes_go', 1),
#  ('sometimes_go_great', 1),
#  ('go_great_times', 1),
#  ('great_times_terrible', 1),
#  ('times_terrible_unique', 1),
#  ('terrible_unique_looking', 1),
#  ('unique_looking_local', 1),
#  ('looking_local_restaruant', 1),
#  ('local_restaruant_thats', 1),
#  ('restaruant_thats_pretty', 1),
#  ('thats_pretty_good', 1),
#  ('pretty_good_weve', 1),
#  ('good_weve_many', 1),
#  ('weve_many_times', 1),
#  ('many_times_continue', 1),
#  ('times_continue_go', 1),
#  ('continue_go_regular', 1),
#  ('go_regular_basis', 1),
#  ('regular_basis_say', 1),
#  ('basis_say_but', 1),
#  ('say_but_outstanding', 1),
#  ('but_outstanding_happened', 1),
#  ('outstanding_happened_upon', 1),
#  ('happened_upon_chase', 1),
#  ('upon_chase_driving', 1),
#  ('chase_driving_state', 1),
#  ('driving_state_street', 1),
#  ('santa_barbara_husband', 1),
#  ('barbara_husband_liked', 1),
#  ('husband_liked_look', 1),
#  ('liked_look_restaurant', 1),
#  ('look_restaurant_not', 1),
#  ('restaurant_not_typical', 1),
#  ('not_typical_criteria', 1),
#  ('typical_criteria_restaurant', 1),
#  ('criteria_restaurant_selection', 1),
#  ('restaurant_selection_reminded', 1),
#  ('selection_reminded_mahogany', 1),
#  ('reminded_mahogany_leather', 1),
#  ('mahogany_leather_highend', 1),
#  ('leather_highend_restaurants', 1),
#  ('highend_restaurants_old', 1),
#  ('restaurants_old_somehow', 1),
#  ('old_somehow_managed', 1),
#  ('somehow_managed_comfortable', 1),
#  ('managed_comfortable_inviting', 1),
#  ('comfortable_inviting_decor', 1),
#  ('inviting_decor_large', 1),
#  ('decor_large_leather', 1),
#  ('large_leather_banquettes', 1),
#  ('leather_banquettes_contemporary', 1),
#  ('banquettes_contemporary_chairs', 1),
#  ('contemporary_chairs_giant', 1),
#  ('chairs_giant_mirrors', 1),
#  ('giant_mirrors_grape', 1),
#  ('mirrors_grape_vines', 1),
#  ('grape_vines_sporting', 1),
#  ('vines_sporting_tiny', 1),
#  ('sporting_tiny_italian', 1),
#  ('tiny_italian_white', 1),
#  ('italian_white_lights', 1),
#  ('white_lights_hanging', 1),
#  ('lights_hanging_ceiling', 1),
#  ('hanging_ceiling_odd', 1),
#  ('ceiling_odd_collection', 1),
#  ('odd_collection_sculptures', 1),
#  ('collection_sculptures_fresh', 1),
#  ('sculptures_fresh_roses', 1),
#  ('fresh_roses_table', 1),
#  ('roses_table_restaurant', 1),
#  ('table_restaurant_impeccably', 1),
#  ('restaurant_impeccably_clean', 1),
#  ('impeccably_clean_lets', 1),
#  ('clean_lets_talk', 1),
#  ('lets_talk_food', 1),
#  ('talk_food_fresh', 1),
#  ('food_fresh_bread', 1),
#  ('fresh_bread_served', 1),
#  ('bread_served_butter', 1),
#  ('served_butter_freshly', 1),
#  ...]

# %%
good_Italian=Italian[Italian.stars>=4.5]
good_Italian_review = Italian_review[Italian_review.business_id.isin(good_Italian.business_id.values)]
good_Italian_review_text = good_Italian_review.text.str.cat(sep = " ")
good_italian_tokens = word_tokenize(good_Italian_review_text)
FreqDist(good_italian_tokens).most_common()
bigrams_list_good_italian = ["_".join(item) for item in nltk.bigrams(good_italian_tokens)]
trigrams_list_good_italian = ["_".join(item) for item in nltk.trigrams(good_italian_tokens)]
# FreqDist(bigrams_list_good_italian).most_common()
FreqDist(trigrams_list_good_italian).most_common()
# Out:
# [('olive_oil_cake', 46),
#  ('ive_ever_had', 38),
#  ('restaurant_santa_barbara', 27),
#  ('wait_go_back', 26),
#  ('best_italian_food', 26),
#  ('back_next_time', 26),
#  ('restaurants_santa_barbara', 24),
#  ('food_great_service', 24),
#  ('visit_santa_barbara', 23),
#  ('cant_wait_go', 23),
#  ('definitely_come_back', 22),
#  ('squid_ink_pasta', 22),
#  ('authentic_italian_food', 22),
#  ('ordered_tuna_cones', 21),
#  ('visiting_santa_barbara', 19),
#  ('next_time_im', 18),
#  ('best_ive_ever', 18),
#  ('great_wine_list', 17),
#  ('best_ever_had', 17),
#  ('lobster_mashed_potatoes', 17),
#  ('time_santa_barbara', 17),
#  ('great_food_great', 17),
#  ('food_excellent_service', 16),
#  ('service_great_food', 16),
#  ('would_highly_recommend', 15),
#  ('trip_santa_barbara', 15),
#  ('highly_recommend_place', 14),
#  ('definitely_back_next', 14),
#  ('warm_chocolate_torte', 14),
#  ('one_best_italian', 13),
#  ('ordered_black_spaghetti', 13),
#  ('one_best_restaurants', 13),
#  ('food_amazing_service', 12),
#  ('cant_say_enough', 12),
#  ('excellent_food_service', 12),
#  ('service_top_notch', 12),
#  ('best_italian_restaurants', 12),
#  ('tuna_cones_appetizer', 12),
#  ('braised_beef_short', 12),
#  ('best_italian_restaurant', 12),
#  ('cant_go_wrong', 12),
#  ('santa_barbara_toma', 12),
#  ('wait_come_back', 11),
#  ('tuna_cones_must', 11),
#  ('made_us_feel', 11),
#  ('can_not_wait', 11),
#  ('grilled_romaine_salad', 11),
#  ('started_tuna_cones', 11),
#  ('ahi_tuna_cones', 11),
#  ('great_food_service', 11),
#  ('food_santa_barbara', 11),
#  ('beef_short_rib', 11),
#  ('would_definitely_recommend', 10),
#  ('braised_short_ribs', 10),
#  ('stuffed_squash_blossoms', 10),
#  ('oil_cake_dessert', 10),
#  ('great_service_great', 10),
#  ('gluten_free_pasta', 10),
#  ('chicken_mushroom_risotto', 10),
#  ('great_wine_selection', 9),
#  ('one_best_meals', 9),
#  ('italian_food_place', 9),
#  ('cant_wait_come', 9),
#  ('would_definitely_come', 9),
#  ('italian_food_ive', 9),
#  ('service_good_food', 9),
#  ('would_go_back', 9),
#  ('blue_cheese_stuffed', 9),
#  ('save_room_dessert', 9),
#  ('new_favorite_restaurant', 9),
#  ('great_dining_experience', 9),
#  ('would_love_come', 9),
#  ('love_come_back', 9),
#  ('braised_short_rib', 9),
#  ('highly_recommend_restaurant', 9),
#  ('im_santa_barbara', 9),
#  ('makes_feel_like', 8),
#  ('place_santa_barbara', 8),
#  ('delicious_food_great', 8),
#  ('come_back_again', 8),
#  ('sea_bass_special', 8),
#  ('highly_recommend_toma', 8),
#  ('cheese_stuffed_olives', 8),
#  ('olives_stuffed_blue', 8),
#  ('stuffed_blue_cheese', 8),
#  ('favorite_restaurant_santa', 8),
#  ('across_street_beach', 8),
#  ('seated_right_away', 8),
#  ('tuna_cones_grilled', 8),
#  ('italian_food_santa', 8),
#  ('upper_state_street', 8),
#  ('squid_ink_spaghetti', 7),
#  ('santa_barbara_must', 7),
#  ('santa_barbara_great', 7),
#  ('staff_super_friendly', 7),
#  ('decided_try_toma', 7),
#  ('santa_barbara_area', 7),
#  ('next_time_were', 7),
#  ('santa_barbara_would', 7),
#  ('would_come_back', 7),
#  ('cant_wait_return', 7),
#  ('definitely_go_back', 7),
#  ('come_back_next', 7),
#  ('place_great_food', 7),
#  ('food_absolutely_delicious', 7),
#  ('well_definitely_back', 7),
#  ('service_excellent_food', 7),
#  ('wait_staff_friendly', 7),
#  ('beef_short_ribs', 7),
#  ('next_time_santa', 7),
#  ('recommend_making_reservations', 7),
#  ('favorite_italian_restaurant', 7),
#  ('italian_restaurant_santa', 7),
#  ('italian_restaurant_town', 7),
#  ('cones_grilled_octopus', 7),
#  ('authentic_italian_restaurant', 7),
#  ('gem_santa_barbara', 6),
#  ('staff_friendly_knowledgeable', 6),
#  ('italian_food_town', 6),
#  ('delicious_highly_recommend', 6),
#  ('definitely_coming_back', 6),
#  ('delicious_italian_food', 6),
#  ('tuna_cone_appetizer', 6),
#  ('black_truffle_butter', 6),
#  ('grilled_octopus_appetizer', 6),
#  ('started_grilled_octopus', 6),
#  ('toma_last_night', 6),
#  ('squash_blossom_appetizer', 6),
#  ('make_sure_make', 6),
#  ('amazing_service_great', 6),
#  ('table_next_us', 6),
#  ('short_rib_tender', 6),
#  ('us_feel_welcome', 6),
#  ('recommend_making_reservation', 6),
#  ('try_tuna_cones', 6),
#  ('ordered_rack_lamb', 6),
#  ('look_forward_returning', 6),
#  ('food_delicious_service', 6),
#  ('truffle_butter_sauce', 6),
#  ('ive_ever_to', 6),
#  ('lived_santa_barbara', 6),
#  ('super_friendly_staff', 5),
#  ('friendly_staff_great', 5),
#  ('santa_barbara_definitely', 5),
#  ('can_not_say', 5),
#  ('santa_barbara_service', 5),
#  ('definitely_going_back', 5),
#  ('santa_barbara_amazing', 5),
#  ('service_fantastic_food', 5),
#  ('make_sure_ask', 5),
#  ('santa_barbara_decided', 5),
#  ('walking_distance_hotel', 5),
#  ('say_enough_good', 5),
#  ('enough_good_things', 5),
#  ('ive_ever_eaten', 5),
#  ('angel_hair_pasta', 5),
#  ('give_place_try', 5),
#  ('rock_shrimp_gnocchi', 5),
#  ('food_service_great', 5),
#  ('must_santa_barbara', 5),
#  ('really_really_good', 5),
#  ('meal_santa_barbara', 5),
#  ('hawaiian_sea_salt', 5),
#  ('italian_santa_barbara', 5),
#  ('italian_food_great', 5),
#  ('goat_cheese_stuffed', 5),
#  ('santa_barbara_again', 5),
#  ('first_time_dining', 5),
#  ('amazing_food_service', 5),
#  ('dinner_last_night', 5),
#  ('definitely_recommend_place', 5),
#  ('amazing_food_amazing', 5),
#  ('back_santa_barbara', 5),
#  ('every_time_visit', 5),
#  ('cones_rack_lamb', 5),
#  ('tuna_tartare_cones', 5),
#  ('time_visit_santa', 5),
#  ('santa_barbara_first', 5),
#  ('food_great_atmosphere', 5),
#  ('one_best_dining', 5),
#  ('best_dining_experiences', 5),
#  ('sesame_seed_cone', 5),
#  ('im_looking_forward', 5),
#  ('santa_barbara_excellent', 5),
#  ('fried_olives_stuffed', 5),
#  ('night_santa_barbara', 5),
#  ('let_start_saying', 5),
#  ('couple_weeks_ago', 5),
#  ('red_onion_confit', 5),
#  ('every_time_go', 5),
#  ('food_service_atmosphere', 5),
#  ('definitely_recommend_restaurant', 5),
#  ('got_black_spaghetti', 5),
#  ('time_im_santa', 5),
#  ('food_good_service', 5),
#  ('loved_tuna_cones', 5),
#  ('santa_barbara_food', 5),
#  ('best_restaurants_santa', 5),
#  ('places_santa_barbara', 5),
#  ('excellent_wine_list', 5),
#  ('come_santa_barbara', 5),
#  ('santa_barbara_place', 5),
#  ('santa_barbara_every', 5),
#  ('time_im_town', 5),
#  ('tuna_cones_delicious', 5),
#  ('ive_long_time', 5),
#  ('bread_olive_oil', 5),
#  ('olives_blue_cheese', 5),
#  ('food_die_for', 5),
#  ('visit_next_time', 5),
#  ('next_time_town', 5),
#  ('roasted_chicken_mushroom', 5),
#  ('black_truffle_sauce', 5),
#  ('italian_food_sb', 5),
#  ('italian_restaurants_sb', 5),
#  ('every_single_bite', 5),
#  ('restaurant_ive_ever', 5),
#  ('ravioli_die_for', 5),
#  ('next_post_office', 5),
#  ('santa_barbara_wonderful', 4),
#  ('loved_every_single', 4),
#  ('stay_santa_barbara', 4),
#  ('come_back_try', 4),
#  ('not_say_enough', 4),
#  ('bakery_next_door', 4),
#  ('come_back_visit', 4),
#  ('downtown_santa_barbara', 4),
#  ('definitely_come_again', 4),
#  ('one_best_ever', 4),
#  ('really_good_food', 4),
#  ('excellent_food_great', 4),
#  ('tomato_cream_sauce', 4),
#  ('delicious_well_definitely', 4),
#  ('great_food_excellent', 4),
#  ('everything_else_menu', 4),
#  ('comes_italian_food', 4),
#  ('would_definitely_return', 4),
#  ('tuna_cones_great', 4),
#  ('definitely_worth_it', 4),
#  ('great_experience_toma', 4),
#  ('sea_salt_butter', 4),
#  ('provided_excellent_service', 4),
#  ('one_favorite_restaurants', 4),
#  ('great_service_excellent', 4),
#  ('first_time_toma', 4),
#  ('came_without_reservation', 4),
#  ('us_right_away', 4),
#  ('local_santa_barbara', 4),
#  ('santa_barbara_last', 4),
#  ('black_spaghetti_seafood', 4),
#  ('caramel_ice_cream', 4),
#  ('service_great_atmosphere', 4),
#  ('best_restaurant_santa', 4),
#  ('steamed_clams_chorizo', 4),
#  ('tuna_cones_octopus', 4),
#  ('spilled_bottle_wine', 4),
#  ('fried_green_olives', 4),
#  ('green_olives_stuffed', 4),
#  ('back_next_trip', 4),
#  ('fried_blue_cheese', 4),
#  ('blue_cheese_olives', 4),
#  ('santa_barbara_favorite', 4),
#  ('definitely_make_reservation', 4),
#  ('food_amazing_staff', 4),
#  ('green_onion_remoulade', 4),
#  ('delicious_italian_restaurant', 4),
#  ('across_santa_barbara', 4),
#  ('santa_barbara_harbor', 4),
#  ('ever_had_great', 4),
#  ('lobster_whipped_potatoes', 4),
#  ('right_across_street', 4),
#  ('ordered_arugula_salad', 4),
#  ('mcconnells_ice_cream', 4),
#  ('go_back_again', 4),
#  ('not_wait_return', 4),
#  ('lasagna_best_ever', 4),
#  ('sure_make_reservation', 4),
#  ('even_though_restaurant', 4),
#  ('th_wedding_anniversary', 4),
#  ('blossoms_grilled_octopus', 4),
#  ('tuna_cones_rack', 4),
#  ('dessert_phyllo_crisp', 4),
#  ('one_best_ive', 4),
#  ('chocolate_torte_dessert', 4),
#  ('ice_cream_trio', 4),
#  ('make_us_feel', 4),
#  ('black_squid_ink', 4),
#  ('one_best_dishes', 4),
#  ('best_dishes_ive', 4),
#  ('walked_without_reservation', 4),
#  ('barbara_must_try', 4),
#  ('back_next_visit', 4),
#  ('ordered_olive_oil', 4),
#  ('service_outstanding_food', 4),
#  ('tuna_cones_good', 4),
#  ('tables_close_together', 4),
#  ('weve_long_time', 4),
#  ('time_were_santa', 4),
#  ('were_santa_barbara', 4),
#  ('santa_barbara_restaurant', 4),
#  ('bread_fried_olives', 4),
#  ('scallops_lobster_mashed', 4),
#  ('food_service_ambiance', 4),
#  ('sure_make_reservations', 4),
#  ('toma_first_time', 4),
#  ('grilled_octopus_black', 4),
#  ('octopus_black_spaghetti', 4),
#  ('right_across_beach', 4),
#  ('santa_barbara_go', 4),
#  ('santa_barbara_everything', 4),
#  ('santa_barbara_eat', 4),
#  ('got_tuna_cones', 4),
#  ('restaurant_across_street', 4),
#  ('made_feel_like', 4),
#  ('service_great_ambiance', 4),
#  ('great_service_good', 4),
#  ('good_service_great', 4),
#  ('vanilla_bean_cream', 4),
#  ('thank_great_evening', 4),
#  ('could_give_stars', 4),
#  ('food_service_excellent', 4),
#  ('wish_could_remember', 4),
#  ('gnocchi_black_spaghetti', 4),
#  ('romantic_date_night', 4),
#  ('santa_barbara_thank', 4),
#  ('food_absolutely_amazing', 4),
#  ('treated_us_like', 4),
#  ('us_feel_like', 4),
#  ('food_highly_recommend', 4),
#  ('tuna_cones_gnocchi', 4),
#  ('excellent_food_excellent', 4),
#  ('loved_every_bite', 4),
#  ('stuffed_goat_cheese', 4),
#  ('favorite_restaurant_sb', 4),
#  ('weekend_santa_barbara', 4),
#  ('wish_could_give', 4),
#  ('cant_wait_visit', 4),
#  ('santa_barbara_weekend', 4),
#  ('die_for_great', 4),
#  ('service_amazing_food', 4),
#  ('let_us_know', 4),
#  ('restaurant_makes_feel', 4),
#  ('really_enjoyed_meal', 4),
#  ('highly_recommend_making', 4),
#  ('reservations_open_table', 4),
#  ('dinner_santa_barbara', 4),
#  ('service_highly_recommend', 4),
#  ('nice_wine_selection', 4),
#  ('italian_restaurants_ive', 4),
#  ('first_time_here', 4),
#  ('open_table_pm', 4),
#  ('probably_best_italian', 4),
#  ('lobster_whipped_potato', 4),
#  ('excellent_service_great', 4),
#  ('boy_glad_did', 4),
#  ('fried_olives_blue', 4),
#  ('food_delicious_staff', 4),
#  ('time_im_sb', 4),
#  ('wine_butter_parsley', 4),
#  ('citrus_olive_oil', 4),
#  ('food_service_amazing', 4),
#  ('looking_authentic_italian', 4),
#  ('spot_santa_barbara', 4),
#  ('toma_restaurant_bar', 4),
#  ('go_back_that', 4),
#  ('ordered_seared_scallops', 4),
#  ('excellent_customer_service', 4),
#  ('italian_restaurant_sb', 4),
#  ('feel_like_italy', 4),
#  ('italian_food_ever', 4),
#  ('drizzled_olive_oil', 4),
#  ('best_authentic_italian', 4),
#  ('ravioli_black_truffle', 4),
#  ('italian_place_santa', 4),
#  ('favorite_italian_food', 4),
#  ('spinach_ravioli_lemon', 4),
#  ('sage_butter_sauce', 4),
#  ('linguine_con_gamberoni', 4),
#  ('pumpkin_ravioli_sage', 4),
#  ('ravioli_sage_butter', 4),
#  ('pumpkin_sage_ravioli', 4),
#  ('truffle_mashed_potatoes', 4),
#  ('mushroom_ravioli_truffle', 4),
#  ('good_via_maestra', 4),
#  ('recommend_via_maestra', 4),
#  ('staff_friendly_welcoming', 3),
#  ('must_try_santa', 3),
#  ('try_santa_barbara', 3),
#  ('favorite_restaurants_santa', 3),
#  ('got_ta_try', 3),
#  ('wow_wow_wow', 3),
#  ('last_night_food', 3),
#  ('wine_cocktail_list', 3),
#  ('able_get_table', 3),
#  ('highly_recommend_pasta', 3),
#  ('selection_italian_wines', 3),
#  ('came_highly_recommended', 3),
#  ('us_make_sure', 3),
#  ('im_pretty_sure', 3),
#  ('wine_list_amazing', 3),
#  ('amazing_italian_food', 3),
#  ('food_pretty_good', 3),
#  ('good_fresh_ingredients', 3),
#  ('wonderful_food_delicious', 3),
#  ('cheese_steak_sandwich', 3),
#  ('portions_good_size', 3),
#  ('portions_reasonable_prices', 3),
#  ('great_service_fantastic', 3),
#  ('wanted_nice_dinner', 3),
#  ('nice_dinner_celebrate', 3),
#  ('food_fresh_delicious', 3),
#  ('yummy_italian_food', 3),
#  ('fast_friendly_service', 3),
#  ('great_location_great', 3),
#  ('friendly_food_delicious', 3),
#  ('well_worth_it', 3),
#  ('favorite_place_eat', 3),
#  ('recommend_place_food', 3),
#  ('outside_soft_inside', 3),
#  ('grilled_chicken_salad', 3),
#  ('nothing_short_amazing', 3),
#  ('delicious_definitely_back', 3),
#  ('home_santa_barbara', 3),
#  ('restaurant_great_food', 3),
#  ('place_friendly_staff', 3),
#  ('cooked_al_dente', 3),
#  ('reason_im_giving', 3),
#  ('had_great_service', 3),
#  ('ended_bringing_half', 3),
#  ('try_everything_else', 3),
#  ('never_go_wrong', 3),
#  ('highly_recommend_going', 3),
#  ('time_every_time', 3),
#  ('pasta_al_dente', 3),
#  ('trips_santa_barbara', 3),
#  ('definitely_go_place', 3),
#  ('little_italian_place', 3),
#  ('whenever_visit_santa', 3),
#  ('creamy_tomato_sauce', 3),
#  ('go_back_place', 3),
#  ('well_overall_great', 3),
#  ('fine_dining_experience', 3),
#  ('service_excellent_great', 3),
#  ('far_best_restaurant', 3),
#  ('place_definitely_worth', 3),
#  ('good_service_excellent', 3),
#  ('service_excellent_wine', 3),
#  ('cant_wait_get', 3),
#  ('excellent_food_first', 3),
#  ('one_best_things', 3),
#  ('service_food_excellent', 3),
#  ('ink_pasta_clams', 3),
#  ('husband_short_ribs', 3),
#  ('tuna_cones_highly', 3),
#  ('cones_highly_recommend', 3),
#  ('coming_back_next', 3),
#  ('everything_ate_delicious', 3),
#  ('rigatoni_short_ribs', 3),
#  ('first_time_trying', 3),
#  ('good_service_good', 3),
#  ('server_friendly_helpful', 3),
#  ('super_friendly_service', 3),
#  ('right_away_tuna', 3),
#  ('away_tuna_cones', 3),
#  ('tuna_cones_artichokes', 3),
#  ('drove_santa_barbara', 3),
#  ('red_sea_salt', 3),
#  ('us_sit_bar', 3),
#  ('made_great_drinks', 3),
#  ('return_santa_barbara', 3),
#  ('super_friendly_food', 3),
#  ('overall_good_experience', 3),
#  ('tried_tuna_cones', 3),
#  ('would_recommend_it', 3),
#  ('come_back_restaurant', 3),
#  ('toma_santa_barbara', 3),
#  ('olio_e_limone', 3),
#  ('salted_caramel_ice', 3),
#  ('good_food_service', 3),
#  ('tuna_sesame_cones', 3),
#  ('make_sure_order', 3),
#  ('every_last_bite', 3),
#  ('santa_barbara_make', 3),
#  ('restaurant_service_great', 3),
#  ('santa_barbara_menu', 3),
#  ('experience_much_better', 3),
#  ('food_simply_amazing', 3),
#  ('every_time_santa', 3),
#  ('love_italian_food', 3),
#  ('atmosphere_service_food', 3),
#  ('nice_wine_list', 3),
#  ('time_were_town', 3),
#  ('next_trip_sb', 3),
#  ('squash_blossoms_scallops', 3),
#  ('black_spaghetti_definitely', 3),
#  ('location_great_service', 3),
#  ('soon_walked_in', 3),
#  ('came_across_toma', 3),
#  ('sesame_seed_cones', 3),
#  ('creme_brûlée_dessert', 3),
#  ('must_visiting_santa', 3),
#  ('night_without_reservation', 3),
#  ('food_incredible_service', 3),
#  ('calamari_tuna_cones', 3),
#  ('dining_experience_toma', 3),
#  ('busy_friday_night', 3),
#  ('mousse_pistachio_pastry', 3),
#  ('served_lobster_mashed', 3),
#  ('new_years_eve', 3),
#  ('experience_great_food', 3),
#  ('perfect_date_night', 3),
#  ('fantastic_food_service', 3),
#  ('santa_barbara_local', 3),
#  ('come_back_soon', 3),
#  ('pasta_cooked_perfectly', 3),
#  ('ever_santa_barbara', 3),
#  ('service_impeccable_food', 3),
#  ('great_date_night', 3),
#  ('food_service_top', 3),
#  ('wonderful_dinner_toma', 3),
#  ('service_good_waiter', 3),
#  ('best_restaurant_sb', 3),
#  ('salad_black_spaghetti', 3),
#  ('really_looking_forward', 3),
#  ('service_even_though', 3),
#  ('anniversary_santa_barbara', 3),
#  ('go_back_try', 3),
#  ('squash_blossoms_grilled', 3),
#  ('food_even_better', 3),
#  ('definitely_one_best', 3),
#  ('cant_wait_back', 3),
#  ('tuna_cones_unique', 3),
#  ('went_birthday_dinner', 3),
#  ('one_santa_barbaras', 3),
#  ('must_try_restaurant', 3),
#  ('wine_list_food', 3),
#  ('best_meals_ever', 3),
#  ('good_food_good', 3),
#  ('top_notch_service', 3),
#  ('staff_friendly_attentive', 3),
#  ('wine_list_good', 3),
#  ('go_back_went', 3),
#  ('memorable_dining_experience', 3),
#  ('definitely_recommend_toma', 3),
#  ('celebrate_special_occasion', 3),
#  ('service_cant_wait', 3),
#  ('want_go_back', 3),
#  ('last_night_santa', 3),
#  ('ordered_squash_blossoms', 3),
#  ('squash_blossoms_good', 3),
#  ('bread_butter_topped', 3),
#  ('onion_confit_natural', 3),
#  ('confit_natural_jus', 3),
#  ('natural_jus_arugula', 3),
#  ('jus_arugula_lemon', 3),
#  ('arugula_lemon_oil', 3),
#  ('tuna_cones_calamari', 3),
#  ('rib_tender_flavorful', 3),
#  ('worth_every_penny', 3),
#  ('forward_coming_back', 3),
#  ('eat_santa_barbara', 3),
#  ('black_spaghetti_great', 3),
#  ('definitely_recommend_it', 3),
#  ('tuna_cones_die', 3),
#  ('cones_die_for', 3),
#  ('santa_barbara_made', 3),
#  ('squash_blossoms_delicious', 3),
#  ('excellent_dining_experience', 3),
#  ('tuna_cones_ahi', 3),
#  ('cones_ahi_sashimi', 3),
#  ('ahi_sashimi_ginger', 3),
#  ('sashimi_ginger_sesame', 3),
#  ('ginger_sesame_soychile', 3),
#  ('squash_blossoms_goat', 3),
#  ('blossoms_goat_cheese', 3),
#  ('come_every_time', 3),
#  ('try_bone_marrow', 3),
#  ('make_reservations_place', 3),
#  ('santa_barbara_los', 3),
#  ('barbara_los_angeles', 3),
#  ('ive_ever_tasted', 3),
#  ('it_highly_recommend', 3),
#  ('highly_recommend_great', 3),
#  ('food_delicious_ordered', 3),
#  ('year_old_daughter', 3),
#  ('food_top_notch', 3),
#  ('bean_cream_berry', 3),
#  ('cream_berry_sauce', 3),
#  ('menu_somewhat_limited', 3),
#  ('started_burrata_salad', 3),
#  ('short_ribs_good', 3),
#  ('never_felt_like', 3),
#  ('got_mushroom_risotto', 3),
#  ('great_service_food', 3),
#  ('day_santa_barbara', 3),
#  ('tuna_cones_amazing', 3),
#  ('go_anywhere_else', 3),
#  ('food_great_staff', 3),
#  ('food_first_time', 3),
#  ('food_tuna_cones', 3),
#  ('go_back_wonderful', 3),
#  ('try_olive_oil', 3),
#  ('area_santa_barbara', 3),
#  ('able_accommodate_us', 3),
#  ('well_taken_care', 3),
#  ('taken_care_of', 3),
#  ('food_fantastic_service', 3),
#  ('wonderful_wine_list', 3),
#  ('great_service_atmosphere', 3),
#  ('dining_experience_food', 3),
#  ('us_like_royalty', 3),
#  ('heirloom_tomato_burrata', 3),
#  ('short_ribs_tender', 3),
#  ('ate_last_night', 3),
#  ('service_attention_detail', 3),
#  ('ive_santa_barbara', 3),
#  ('went_way_make', 3),
#  ('wanted_make_sure', 3),
#  ('recommend_tuna_cones', 3),
#  ('santa_barbara_dining', 3),
#  ('octopus_tuna_cones', 3),
#  ('incredible_tuna_cones', 3),
#  ('santa_barbara_sure', 3),
#  ('appetizers_grilled_octopus', 3),
#  ('santa_barbara_restaurants', 3),
#  ('service_santa_barbara', 3),
#  ('high_quality_food', 3),
#  ('one_favorite_places', 3),
#  ('weve_ever_had', 3),
#  ('clams_black_spaghetti', 3),
#  ('wanted_love_place', 3),
#  ('short_rib_scallops', 3),
#  ('table_without_reservation', 3),
#  ('santa_barbara_ca', 3),
#  ('better_food_service', 3),
#  ('cant_stop_thinking', 3),
#  ('main_course_ordered', 3),
#  ('come_back_place', 3),
#  ('whenever_santa_barbara', 3),
#  ('best_lasagna_ever', 3),
#  ('give_place_stars', 3),
#  ('staff_friendly_helpful', 3),
#  ('look_forward_coming', 3),
#  ('best_italian_sb', 3),
#  ('took_us_table', 3),
#  ('tuna_cones_start', 3),
#  ('italian_restaurant_one', 3),
#  ('favorite_dish_night', 3),
#  ('table_right_away', 3),
#  ('always_made_sure', 3),
#  ('excellent_food_good', 3),
#  ('best_santa_barbara', 3),
#  ('scallops_cooked_perfectly', 3),
#  ('great_italian_food', 3),
#  ('pricey_worth_it', 3),
#  ('came_check_us', 3),
#  ('definitely_one_favorite', 3),
#  ('delicious_definitely_recommend', 3),
#  ('delicious_black_spaghetti', 3),
#  ('table_ready_us', 3),
#  ('extremely_friendly_attentive', 3),
#  ('phyllo_crisp_dessert', 3),
#  ('best_birthday_dinner', 3),
#  ('blue_cheese_inside', 3),
#  ('appetizer_main_course', 3),
#  ('next_visit_santa', 3),
#  ('find_santa_barbara', 3),
#  ('black_spaghetti_clams', 3),
#  ('great_food_fantastic', 3),
#  ('top_notch_food', 3),
#  ('squash_blossoms_divine', 3),
#  ('first_time_santa', 3),
#  ('overall_great_experience', 3),
#  ('santa_barbara_italian', 3),
#  ('ever_had_place', 3),
#  ('delicious_staff_friendly', 3),
#  ('ordered_shrimp_gnocchi', 3),
#  ('would_recommend_place', 3),
#  ('highly_recommend_good', 3),
#  ('amazing_food_great', 3),
#  ('next_time_visit', 3),
#  ('food_ive_ever', 3),
#  ('garlic_white_wine', 3),
#  ('white_wine_butter', 3),
#  ('first_time_ordered', 3),
#  ('hands_one_best', 3),
#  ('enjoyed_every_bite', 3),
#  ('craving_italian_food', 3),
#  ('got_short_rib', 3),
#  ('experience_would_recommend', 3),
#  ('dessert_olive_oil', 3),
#  ('stop_santa_barbara', 3),
#  ('labor_day_weekend', 3),
#  ('real_italian_food', 3),
#  ('one_favorite_dishes', 3),
#  ('raspberry_mousse_light', 3),
#  ('went_toma_last', 3),
#  ('reservations_highly_recommended', 3),
#  ('black_spaghetti_fresh', 3),
#  ('calabrese_salame_garlic', 3),
#  ('toasted_chickpea_sweet', 3),
#  ('chickpea_sweet_pepper', 3),
#  ('sweet_pepper_fennel', 3),
#  ('pepper_fennel_harissa', 3),
#  ('fennel_harissa_preserved', 3),
#  ('harissa_preserved_lemon', 3),
#  ('preserved_lemon_laban', 3),
#  ('lemon_laban_natural', 3),
#  ('laban_natural_jus', 3),
#  ('best_ive_had', 3),
#  ('nothing_write_home', 3),
#  ('delicious_service_amazing', 3),
#  ('love_love_love', 3),
#  ('come_back_santa', 3),
#  ('made_dining_experience', 3),
#  ('quaint_little_place', 3),
#  ('food_drinks_service', 3),
#  ('wine_list_wonderful', 3),
#  ('sauce_sauce_sauce', 3),
#  ('mushroom_truffle_ravioli', 3),
#  ('walk_feel_like', 3),
#  ('love_via_maestra', 3),
#  ('dining_via_maestra', 3),
#  ('great_authentic_italian', 3),
#  ('great_food_authentic', 3),
#  ('mushroom_ravioli_die', 3),
#  ('got_pumpkin_ravioli', 3),
#  ('food_ever_had', 3),
#  ('breakfast_lunch_dinner', 3),
#  ('little_italian_restaurant', 3),
#  ('hands_best_italian', 3),
#  ('best_italian_place', 3),
#  ('work_with_food', 3),
#  ('ravioli_zuccotto_pumpkin', 3),
#  ('ravioli_lemon_cream', 3),
#  ('lemon_cream_sauce', 3),
#  ('great_little_place', 3),
#  ('place_real_italian', 3),
#  ('good_italian_restaurants', 3),
#  ('hidden_gem_santa', 3),
#  ('it_best_italian', 3),
#  ('small_italian_restaurant', 3),
#  ('ordered_pumpkin_ravioli', 3),
#  ('lemon_alfredo_sauce', 3),
#  ('place_limited_seating', 3),
#  ('linguine_con_vongole', 3),
#  ('delicious_pumpkin_ravioli', 3),
#  ('out_best_italian', 3),
#  ('renato_via_maestra', 3),
#  ('salmon_goat_cheese', 3),
#  ('ravioli_con_spinaci', 3),
#  ('absolutely_love_place', 3),
#  ('highly_recommend_lasagna', 3),
#  ('penne_alla_boscaiola', 3),
#  ('italian_restaurant_ive', 3),
#  ('amazing_authentic_italian', 3),
#  ('bowtie_pasta_pesto', 3),
#  ('feel_like_sitting', 3),
#  ('quality_italian_food', 3),
#  ('mushroom_ravioli_black', 3),
#  ('outdoor_indoor_seating', 2),
#  ('outdoor_seating_service', 2),
#  ('us_santa_barbara', 2),
#  ('club_take_out', 2),
#  ('santa_barbara_makes', 2),
#  ('every_single_dish', 2),
#  ('ive_ever_experienced', 2),
#  ('owner_staff_friendly', 2),
#  ('would_absolutely_come', 2),
#  ('food_wine_atmosphere', 2),
#  ('many_places_area', 2),
#  ('bread_bakery_next', 2),
#  ('recommend_place_enough', 2),
#  ('give_five_stars', 2),
#  ('food_great_presentation', 2),
#  ('way_one_best', 2),
#  ('pasta_bit_al', 2),
#  ('bit_al_dente', 2),
#  ('staff_friendly_informative', 2),
#  ('santa_barbara_black', 2),
#  ('come_back_another', 2),
#  ('san_diego_san', 2),
#  ('diego_san_francisco', 2),
#  ('town_santa_barbara', 2),
#  ('beautifully_presented_flavors', 2),
#  ('outside_heat_lamps', 2),
#  ('glad_stopped_in', 2),
#  ('barbara_must_stop', 2),
#  ('food_friendly_staff', 2),
#  ('top_notch_definitely', 2),
#  ('outdoor_seating_area', 2),
#  ('good_food_fresh', 2),
#  ('italian_food_italian', 2),
#  ('next_door_oat', 2),
#  ('highly_recommend_area', 2),
#  ('santa_barbara_looking', 2),
#  ('looking_forward_next', 2),
#  ('visit_go_back', 2),
#  ('wine_selection_amazing', 2),
#  ('came_saturday_night', 2),
#  ('saturday_night_around', 2),
#  ('night_around_pm', 2),
#  ('came_greet_us', 2),
#  ('food_everything_amazing', 2),
#  ('id_go_back', 2),
#  ('also_good_though', 2),
#  ('quite_possibly_best', 2),
#  ('vanilla_ice_cream', 2),
#  ('ice_cream_hazelnut', 2),
#  ('curated_wine_list', 2),
#  ('santa_barbara_friendly', 2),
#  ('recommend_date_night', 2),
#  ('every_time_great', 2),
#  ('perfectly_balanced_flavors', 2),
#  ('little_bit_everything', 2),
#  ('ill_definitely_back', 2),
#  ('definitely_back_im', 2),
#  ('got_two_different', 2),
#  ('good_place_come', 2),
#  ('best_meals_santa', 2),
#  ('meals_santa_barbara', 2),
#  ('amazing_artichoke_appetizer', 2),
#  ('cream_sauce_amazing', 2),
#  ('expensive_italian_restaurant', 2),
#  ('great_food_staff', 2),
#  ('place_eat_food', 2),
#  ('food_high_quality', 2),
#  ('italian_food_totally', 2),
#  ('food_totally_recommend', 2),
#  ('ingredients_listed_menu', 2),
#  ('wait_another_minutes', 2),
#  ('lentil_soup_came', 2),
#  ('totally_go_back', 2),
#  ('ordered_spaghetti_meatballs', 2),
#  ('cheese_ravioli_amazing', 2),
#  ('good_marinara_sauce', 2),
#  ('marinara_sauce_absolutely', 2),
#  ('best_pasta_ive', 2),
#  ('think_owner_manager', 2),
#  ('food_amazing_ordered', 2),
#  ('nice_people_good', 2),
#  ('place_wonderful_food', 2),
#  ('food_delicious_portions', 2),
#  ('italian_sausage_sandwich', 2),
#  ('ordered_cheese_steak', 2),
#  ('sandwich_much_better', 2),
#  ('cooked_perfectly_delicious', 2),
#  ('two_locations_san', 2),
#  ('locations_san_clemente', 2),
#  ('great_prices_great', 2),
#  ('grilled_eggplant_sandwich', 2),
#  ('suggest_calling_ahead', 2),
#  ('eaten_several_times', 2),
#  ('sure_everyone_happy', 2),
#  ('cant_wait_try', 2),
#  ('try_rest_menu', 2),
#  ('skeptic_italian_food', 2),
#  ('italian_food_made', 2),
#  ('live_los_angeles', 2),
#  ('ordered_linguini_shrimp', 2),
#  ('quality_food_prices', 2),
#  ('food_prices_reasonable', 2),
#  ('since_opened_last', 2),
#  ('place_last_night', 2),
#  ('food_great_portions', 2),
#  ('reasonable_prices_well', 2),
#  ('guichos_great_place', 2),
#  ('use_fresh_ingredients', 2),
#  ('hearts_palm_salad', 2),
#  ('could_used_little', 2),
#  ('came_across_gem', 2),
#  ('little_things_make', 2),
#  ('great_attention_detail', 2),
#  ('place_really_nice', 2),
#  ('highly_recommend_go', 2),
#  ('grilled_shrimp_salad', 2),
#  ('absolutely_delicious_highly', 2),
#  ('highly_recommend_guichos', 2),
#  ('recommend_guichos_great', 2),
#  ('food_really_delicious', 2),
#  ('place_yummy_italian', 2),
#  ('friendly_service_great', 2),
#  ('arugula_salad_fresh', 2),
#  ('staff_helpful_friendly', 2),
#  ('back_try_pasta', 2),
#  ('place_food_excellent', 2),
#  ('highly_recommended_excellent', 2),
#  ('great_atmosphere_great', 2),
#  ('atmosphere_great_food', 2),
#  ('great_place_lunch', 2),
#  ('brought_flavors_together', 2),
#  ('get_next_time', 2),
#  ('food_reasonable_price', 2),
#  ('takeout_containers_plastic', 2),
#  ('came_across_place', 2),
#  ('across_place_yelp', 2),
#  ('piping_hot_delicious', 2),
#  ('pasta_dishes_great', 2),
#  ('food_great_ambiance', 2),
#  ('like_fine_dining', 2),
#  ('atmosphere_cant_wait', 2),
#  ('really_good_place', 2),
#  ('come_back_area', 2),
#  ('area_good_food', 2),
#  ('really_feel_like', 2),
#  ('tried_first_time', 2),
#  ('first_time_last', 2),
#  ('time_last_night', 2),
#  ('ordered_steak_sandwich', 2),
#  ('highly_recommended_place', 2),
#  ('creamy_red_sauce', 2),
#  ('fresh_italian_food', 2),
#  ('santa_barbara_two', 2),
#  ('toasted_bread_delicious', 2),
#  ('bread_delicious_well', 2),
#  ('italian_restaurant_great', 2),
#  ('pretty_good_too', 2),
#  ('try_place_out', 2),
#  ('pasta_dishes_nice', 2),
#  ('italian_food_nothing', 2),
#  ('reasonable_prices_got', 2),
#  ('leftovers_spaghetti_meatballs', 2),
#  ('restrictions_highly_recommend', 2),
#  ('hubby_likes_lasagna', 2),
#  ('everything_tasted_amazing', 2),
#  ('food_consistently_good', 2),
#  ('person_ordered_it', 2),
#  ('friendly_staff_good', 2),
#  ('staff_good_food', 2),
#  ('good_even_better', 2),
#  ('best_lasagna_ive', 2),
#  ('lasagna_ive_ever', 2),
#  ('food_delicious_best', 2),
#  ('every_time_im', 2),
#  ('im_glad_found', 2),
#  ('found_place_yelp', 2),
#  ('spent_lot_time', 2),
#  ('feel_like_welcome', 2),
#  ('meatball_sandwich_best', 2),
#  ('large_ended_bringing', 2),
#  ('bringing_half_home', 2),
#  ('great_food_got', 2),
#  ('great_quality_food', 2),
#  ('got_penne_pasta', 2),
#  ('go_wrong_with', 2),
#  ('picky_comes_italian', 2),
#  ('sandwich_ive_ever', 2),
#  ('absolutely_best_italian', 2),
#  ('indoor_outdoor_seating', 2),
#  ('tell_us_oh', 2),
#  ('people_behind_us', 2),
#  ('would_like_see', 2),
#  ('really_enjoyed_food', 2),
#  ('santa_barbara_try', 2),
#  ('go_place_im', 2),
#  ('person_taking_order', 2),
#  ('big_enough_share', 2),
#  ('sauce_absolutely_delicious', 2),
#  ('come_back_whenever', 2),
#  ('back_whenever_visit', 2),
#  ('everything_made_order', 2),
#  ('really_enjoyed_it', 2),
#  ('right_service_great', 2),
#  ('italian_food_always', 2),
#  ('food_always_good', 2),
#  ('menu_great_food', 2),
#  ('overall_great_spot', 2),
#  ('definitely_return_town', 2),
#  ('tiger_shrimp_linguine', 2),
#  ('service_exceptional_food', 2),
#  ('top_quality_ingredients', 2),
#  ('toma_walking_distance', 2),
#  ('go_back_would', 2),
#  ('pretty_close_together', 2),
#  ('date_night_dinner', 2),
#  ('two_main_courses', 2),
#  ('sem_comentários_restaurante', 2),
#  ('comentários_restaurante_fino', 2),
#  ('restaurante_fino_delicioso', 2),
#  ('fino_delicioso_amamos', 2),
#  ('delicioso_amamos_atendimento', 2),
#  ('amamos_atendimento_extremamente', 2),
#  ('atendimento_extremamente_cordial', 2),
#  ('extremamente_cordial_e', 2),
#  ('cordial_e_os', 2),
#  ('e_os_cones', 2),
#  ('os_cones_de', 2),
#  ('cones_de_atum', 2),
#  ('de_atum_de', 2),
#  ('atum_de_entrada', 2),
#  ('de_entrada_são', 2),
#  ('entrada_são_simplesmente', 2),
#  ('são_simplesmente_imperdíveis', 2),
#  ('water_glass_never', 2),
#  ('glass_never_empty', 2),
#  ('side_mushroom_risotto', 2),
#  ('wait_get_back', 2),
#  ('experience_toma_great', 2),
#  ('cooked_perfection_sauce', 2),
#  ('best_things_ive', 2),
#  ...]

# %% [markdown]
# ### Amrican restaurant

# %%
American = business_df[business_df.Type=="American"]
American_review = review1[review1.business_id.isin(American.business_id.values)]
American_review["text"] = American_review["text"].str.lower()
American_review['text'] = American_review['text'].apply(lambda text: cleaning_stopwords(text))
American_review['text']= American_review['text'].apply(lambda x: cleaning_punctuations(x))
American_review['text'] = American_review['text'].apply(lambda x: cleaning_repeating_char(x))
American_review['text'] = American_review['text'].apply(lambda x: cleaning_URLs(x))
American_review['text'] = American_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_American=American[American.stars<3.5]
bad_American_review = American_review[American_review.business_id.isin(bad_American.business_id.values)]
bad_American_review_text = bad_American_review.text.str.cat(sep = " ")
bad_American_tokens = word_tokenize(bad_American_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_bad_American = ["_".join(item) for item in nltk.bigrams(bad_American_tokens)]
trigrams_list_bad_American = ["_".join(item) for item in nltk.trigrams(bad_American_tokens)]
FreqDist(bigrams_list_bad_American).most_common()
# FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('public_market', 52),
#  ('santa_barbara', 36),
#  ('happy_hour', 26),
#  ('pretty_good', 25),
#  ('food_good', 25),
#  ('beer_selection', 23),
#  ('great_service', 21),
#  ('come_back', 19),
#  ('customer_service', 16),
#  ('every_time', 15),
#  ('chicken_sandwich', 15),
#  ('first_time', 14),
#  ('coral_tree', 13),
#  ('really_good', 13),
#  ('good_service', 13),
#  ('service_food', 13),
#  ('ice_cream', 13),
#  ('bring_food', 13),
#  ('coming_back', 12),
#  ('looked_like', 12),
#  ('go_back', 11),
#  ('year_old', 11),
#  ('lemon_pepper', 11),
#  ('going_back', 10),
#  ('great_place', 10),
#  ('super_friendly', 10),
#  ('last_time', 10),
#  ('food_came', 10),
#  ('food_decent', 10),
#  ('food_service', 10),
#  ('chips_salsa', 10),
#  ('mango_habanero', 10),
#  ('best_western', 10),
#  ('beer_garden', 10),
#  ('ive_ever', 9),
#  ('next_time', 9),
#  ('seems_like', 9),
#  ('onion_rings', 9),
#  ('order_food', 9),
#  ('food_great', 9),
#  ('love_place', 8),
#  ('food_took', 8),
#  ('long_time', 8),
#  ('well_done', 8),
#  ('got_food', 8),
#  ('hit_miss', 8),
#  ('service_great', 8),
#  ('good_food', 8),
#  ('last_night', 8),
#  ('decided_go', 8),
#  ('ive_never', 8),
#  ('recommend_place', 8),
#  ('fried_chicken', 8),
#  ('fast_food', 7),
#  ('somewhere_else', 7),
#  ('place_go', 7),
#  ('take_order', 7),
#  ('everything_else', 7),
#  ('get_food', 7),
#  ('even_though', 7),
#  ('something_like', 7),
#  ('got_there', 7),
#  ('make_sure', 7),
#  ('food_pretty', 7),
#  ('minutes_later', 7),
#  ('food_cold', 7),
#  ('chicken_crispers', 7),
#  ('big_fan', 7),
#  ('service_really', 7),
#  ('would_like', 7),
#  ('food_ok', 7),
#  ('waste_time', 7),
#  ('great_job', 7),
#  ('friendly_staff', 7),
#  ('state_street', 7),
#  ('looks_like', 7),
#  ('pretty_much', 6),
#  ('would_definitely', 6),
#  ('get_one', 6),
#  ('craft_beers', 6),
#  ('second_time', 6),
#  ('time_come', 6),
#  ('time_go', 6),
#  ('im_big', 6),
#  ('always_great', 6),
#  ('staff_friendly', 6),
#  ('one_thing', 6),
#  ('service_good', 6),
#  ('feel_like', 6),
#  ('excellent_service', 6),
#  ('us_got', 6),
#  ('came_out', 6),
#  ('bad_experience', 6),
#  ('chicken_wings', 6),
#  ('come_out', 6),
#  ('would_recommend', 6),
#  ('waited_minutes', 6),
#  ('would_come', 6),
#  ('sent_back', 6),
#  ('im_sorry', 6),
#  ('much_better', 6),
#  ('thank_you', 6),
#  ('ordered_chicken', 6),
#  ('great_food', 6),
#  ('hash_browns', 6),
#  ('mac_n', 6),
#  ('n_cheese', 6),
#  ('tasted_like', 5),
#  ('service_slow', 5),
#  ('tree_cafe', 5),
#  ('want_eat', 5),
#  ('also_great', 5),
#  ('good_place', 5),
#  ('quick_bite', 5),
#  ('time_food', 5),
#  ('wait_staff', 5),
#  ('selection_beer', 5),
#  ('dining_area', 5),
#  ('sit_bar', 5),
#  ('couple_times', 5),
#  ('service_always', 5),
#  ('always_good', 5),
#  ('really_bad', 5),
#  ('waiting_minutes', 5),
#  ('could_see', 5),
#  ('super_busy', 5),
#  ('fries_came', 5),
#  ('ordered_food', 5),
#  ('nothing_special', 5),
#  ('service_ever', 5),
#  ('drink_order', 5),
#  ('even_get', 5),
#  ('would_go', 5),
#  ('chilis_goleta', 5),
#  ('bar_area', 5),
#  ('behind_bar', 5),
#  ('chicken_pasta', 5),
#  ('menu_items', 5),
#  ('worst_service', 5),
#  ('bar_tender', 5),
#  ('medium_rare', 5),
#  ('little_bit', 5),
#  ('food_first', 5),
#  ('right_away', 5),
#  ('came_back', 5),
#  ('table_next', 5),
#  ('burger_fries', 5),
#  ('next_door', 5),
#  ('checked_us', 5),
#  ('buffalo_wings', 5),
#  ('really_nice', 5),
#  ('definitely_recommend', 5),
#  ('staff_nice', 5),
#  ('im_sure', 5),
#  ('also_ordered', 5),
#  ('back_patio', 5),
#  ('service_excellent', 5),
#  ('great_beer', 5),
#  ('good_beer', 5),
#  ('room_service', 5),
#  ('wings_great', 5),
#  ('people_waiting', 5),
#  ('great_fries', 5),
#  ('online_ordering', 5),
#  ('watch_sports', 5),
#  ('definitely_worth', 4),
#  ('also_pretty', 4),
#  ('lunch_time', 4),
#  ('im_really', 4),
#  ('good_got', 4),
#  ('variety_food', 4),
#  ('french_fries', 4),
#  ('give_place', 4),
#  ('one_star', 4),
#  ('there_food', 4),
#  ('food_menu', 4),
#  ('something_else', 4),
#  ('best_place', 4),
#  ('half_hour', 4),
#  ('places_eat', 4),
#  ('took_long', 4),
#  ('can_not', 4),
#  ('chocolate_cake', 4),
#  ('time_money', 4),
#  ('way_back', 4),
#  ('come_chilis', 4),
#  ('im_giving', 4),
#  ('ordered_drinks', 4),
#  ('drinks_food', 4),
#  ('chicken_enchilada', 4),
#  ('pulled_pork', 4),
#  ('server_came', 4),
#  ('come_here', 4),
#  ('eat_it', 4),
#  ('last_visit', 4),
#  ('came_table', 4),
#  ('go_here', 4),
#  ('boneless_wings', 4),
#  ('us_ordered', 4),
#  ('im_pretty', 4),
#  ('cheese_fries', 4),
#  ('eat_here', 4),
#  ('crispy_chicken', 4),
#  ('bad_reviews', 4),
#  ('dining_experience', 4),
#  ('grilled_chicken', 4),
#  ('like_place', 4),
#  ('ranch_salad', 4),
#  ('actually_really', 4),
#  ('let_know', 4),
#  ('back_im', 4),
#  ('sat_bar', 4),
#  ('used_great', 4),
#  ('like_chilis', 4),
#  ('eating_here', 4),
#  ('decent_place', 4),
#  ('top_notch', 4),
#  ('date_night', 4),
#  ('never_back', 4),
#  ('service_definitely', 4),
#  ('would_give', 4),
#  ('give_us', 4),
#  ('could_find', 4),
#  ('experience_good', 4),
#  ('food_excellent', 4),
#  ('never_seen', 4),
#  ('would_get', 4),
#  ('went_lunch', 4),
#  ('order_taken', 4),
#  ('time_here', 4),
#  ('two_entrees', 4),
#  ('got_seated', 4),
#  ('place_watch', 4),
#  ('server_never', 4),
#  ('service_ive', 4),
#  ('mozzarella_sticks', 4),
#  ('never_bad', 4),
#  ('appetizer_two', 4),
#  ('walked_away', 4),
#  ('took_minutes', 4),
#  ('next_us', 4),
#  ('chain_restaurants', 4),
#  ('poor_quality', 4),
#  ('service_terrible', 4),
#  ('food_would', 4),
#  ('placed_order', 4),
#  ('ordered_beer', 4),
#  ('highly_recommend', 4),
#  ('beer_tap', 4),
#  ('got_home', 4),
#  ('good_also', 4),
#  ('way_better', 4),
#  ('multiple_times', 4),
#  ('corn_fritters', 4),
#  ('fries_good', 4),
#  ('great_location', 4),
#  ('waited_waited', 4),
#  ('never_came', 4),
#  ('anything_else', 4),
#  ('bar_food', 4),
#  ('behind_counter', 4),
#  ('selection_beers', 4),
#  ('selection_good', 4),
#  ('looking_forward', 4),
#  ('wingstop_sb', 4),
#  ('pick_up', 4),
#  ('corned_beef', 4),
#  ('beef_hash', 4),
#  ('food_places', 4),
#  ('cash_register', 4),
#  ('coffee_shop', 4),
#  ('clue_number', 4),
#  ('beers_tap', 4),
#  ('food_vendors', 4),
#  ('several_times', 4),
#  ('atmosphere_garden', 4),
#  ('selection_excellent', 4),
#  ('too_seems', 4),
#  ('able_bring', 4),
#  ('market_garden', 4),
#  ('back_beer', 4),
#  ('outside_food', 4),
#  ('world_series', 4),
#  ('barbara_public', 4),
#  ('ordered_hot', 3),
#  ('one_get', 3),
#  ('stir_fry', 3),
#  ('reasonably_priced', 3),
#  ('outdoor_tables', 3),
#  ('one_go', 3),
#  ('chicken_burrito', 3),
#  ('back_again', 3),
#  ('outdoor_seating', 3),
#  ('id_come', 3),
#  ('better_places', 3),
#  ('run_better', 3),
#  ('garden_burger', 3),
#  ('two_stars', 3),
#  ('going_somewhere', 3),
#  ('go_place', 3),
#  ('lemon_poppy', 3),
#  ('poppy_seed', 3),
#  ('go_every', 3),
#  ('service_super', 3),
#  ('definitely_come', 3),
#  ('get_order', 3),
#  ('order_wrong', 3),
#  ('service_pretty', 3),
#  ('nice_place', 3),
#  ('pretty_sure', 3),
#  ('really_liked', 3),
#  ('food_go', 3),
#  ('place_eat', 3),
#  ('last_year', 3),
#  ('every_single', 3),
#  ('fish_chips', 3),
#  ('chicken_fingers', 3),
#  ('think_place', 3),
#  ('great_selection', 3),
#  ('food_come', 3),
#  ('sandwich_fries', 3),
#  ('years_ago', 3),
#  ('dont_go', 3),
#  ('minute_wait', 3),
#  ('without_even', 3),
#  ('quality_food', 3),
#  ('molten_chocolate', 3),
#  ('chilis_bad', 3),
#  ('get_decent', 3),
#  ('decent_ribs', 3),
#  ('ancho_salmon', 3),
#  ('find_something', 3),
#  ('really_care', 3),
#  ('ate_lunch', 3),
#  ('never_got', 3),
#  ('cold_fries', 3),
#  ('asked_wanted', 3),
#  ('service_took', 3),
#  ('took_away', 3),
#  ('togo_order', 3),
#  ('said_would', 3),
#  ('order_still', 3),
#  ('order_got', 3),
#  ('everything_made', 3),
#  ('made_us', 3),
#  ('manager_came', 3),
#  ('food_ordered', 3),
#  ('got_order', 3),
#  ('main_dining', 3),
#  ('would_rated', 3),
#  ('decent_service', 3),
#  ('service_even', 3),
#  ('enchilada_soup', 3),
#  ('around_us', 3),
#  ('visit_food', 3),
#  ('love_chilis', 3),
#  ('fries_side', 3),
#  ('credit_card', 3),
#  ('across_street', 3),
#  ('friends_ordered', 3),
#  ('service_little', 3),
#  ('service_consistently', 3),
#  ('food_okay', 3),
#  ('three_stars', 3),
#  ('bit_slow', 3),
#  ('catch_name', 3),
#  ('college_students', 3),
#  ('bill_left', 3),
#  ('save_money', 3),
#  ('never_going', 3),
#  ('really_enjoyed', 3),
#  ('corn_cob', 3),
#  ('months_ago', 3),
#  ('reviews_service', 3),
#  ('prices_reasonable', 3),
#  ('here_food', 3),
#  ('service_decent', 3),
#  ('kitchen_must', 3),
#  ('ever_encountered', 3),
#  ('job_theyre', 3),
#  ('either_way', 3),
#  ('two_dollars', 3),
#  ('portions_perfect', 3),
#  ('especially_since', 3),
#  ('since_busy', 3),
#  ('goleta_location', 3),
#  ('back_get', 3),
#  ('go_restaurant', 3),
#  ('needless_say', 3),
#  ('speak_manager', 3),
#  ('us_even', 3),
#  ('sandwich_also', 3),
#  ('anywhere_else', 3),
#  ('pleasantly_surprised', 3),
#  ('cant_remember', 3),
#  ('hamburgers_chicken', 3),
#  ('fan_chilis', 3),
#  ('like_it', 3),
#  ('friendly_attentive', 3),
#  ('good_too', 3),
#  ('chilis_chain', 3),
#  ('terrible_service', 3),
#  ('service_mediocre', 3),
#  ('chain_food', 3),
#  ('location_great', 3),
#  ('like_food', 3),
#  ('food_terrible', 3),
#  ('cant_go', 3),
#  ('go_wrong', 3),
#  ('watered_down', 3),
#  ('good_overall', 3),
#  ('open_seating', 3),
#  ('experience_chilis', 3),
#  ('ive_coming', 3),
#  ('wait_minutes', 3),
#  ('service_poor', 3),
#  ('asked_one', 3),
#  ('never_again', 3),
#  ('never_go', 3),
#  ('back_place', 3),
#  ('twenty_minutes', 3),
#  ('many_people', 3),
#  ('go_chilis', 3),
#  ('chilis_much', 3),
#  ('chilis_service', 3),
#  ('feel_well', 3),
#  ('try_something', 3),
#  ('blah_blah', 3),
#  ('good_one', 3),
#  ('past_years', 3),
#  ('many_times', 3),
#  ('gave_us', 3),
#  ('wait_times', 3),
#  ('bowl_chili', 3),
#  ('loaded_mashed', 3),
#  ('mashed_potatoes', 3),
#  ('one_friends', 3),
#  ('chilis_tonight', 3),
#  ('enjoyed_it', 3),
#  ('figured_would', 3),
#  ('typical_chilis', 3),
#  ('another_one', 3),
#  ('keep_coming', 3),
#  ('experiences_chilis', 3),
#  ('bad_food', 3),
#  ('overall_im', 3),
#  ('remember_name', 3),
#  ('restaurant_clean', 3),
#  ('seated_right', 3),
#  ('got_drinks', 3),
#  ('getting_food', 3),
#  ('food_order', 3),
#  ('im_glad', 3),
#  ('get_eat', 3),
#  ('selection_decent', 3),
#  ('yelp_reviews', 3),
#  ('forgot_us', 3),
#  ('worst_chilis', 3),
#  ('chilis_food', 3),
#  ('ordered_wings', 3),
#  ('bell_peppers', 3),
#  ('horrible_service', 3),
#  ('minutes_got', 3),
#  ('came_cold', 3),
#  ('cajun_chicken', 3),
#  ('good_happy', 3),
#  ('two_people', 3),
#  ('one_favorite', 3),
#  ('told_us', 3),
#  ('food_also', 3),
#  ('wait_time', 3),
#  ('even_warm', 3),
#  ('came_around', 3),
#  ('never_checked', 3),
#  ('good_thing', 3),
#  ('another_minutes', 3),
#  ('usually_good', 3),
#  ('ten_minutes', 3),
#  ('amount_time', 3),
#  ('poor_service', 3),
#  ('minutes_come', 3),
#  ('shitty_service', 3),
#  ('friend_ordered', 3),
#  ('walking_around', 3),
#  ('molten_cake', 3),
#  ('time_decided', 3),
#  ('ahead_time', 3),
#  ('good_like', 3),
#  ('three_us', 3),
#  ('pretzel_sticks', 3),
#  ('time_got', 3),
#  ('service_horrible', 3),
#  ('food_served', 3),
#  ('like_eating', 3),
#  ('place_dinner', 3),
#  ('good_enough', 3),
#  ('id_rather', 3),
#  ('good_job', 3),
#  ('would_expect', 3),
#  ('go_service', 3),
#  ('favorite_places', 3),
#  ('went_chilis', 3),
#  ('garlic_bread', 3),
#  ('clean_great', 3),
#  ('mediocre_best', 3),
#  ('big_party', 3),
#  ('garlic_toast', 3),
#  ('chicken_breast', 3),
#  ('best_part', 3),
#  ('bar_tenders', 3),
#  ('friends_came', 3),
#  ('large_portions', 3),
#  ('minutes_food', 3),
#  ('chilis_one', 3),
#  ('food_drinks', 3),
#  ('night_dinner', 3),
#  ('family_members', 3),
#  ('wife_ordered', 3),
#  ('stay_away', 3),
#  ('good_customer', 3),
#  ('long_day', 3),
#  ('like_home', 3),
#  ('chilis_place', 3),
#  ('plenty_seating', 3),
#  ('food_items', 3),
#  ('order_beer', 3),
#  ('food_well', 3),
#  ('honey_chipotle', 3),
#  ('mins_late', 3),
#  ('extremely_rude', 3),
#  ('group_people', 3),
#  ('im_happy', 3),
#  ('cheese_curds', 3),
#  ('place_get', 3),
#  ('caesar_salad', 3),
#  ('steak_sandwich', 3),
#  ('it_ordered', 3),
#  ('watching_sports', 3),
#  ('order_online', 3),
#  ('love_wingstop', 3),
#  ('make_feel', 3),
#  ('hot_wings', 3),
#  ('online_order', 3),
#  ('staff_super', 3),
#  ('wing_stop', 3),
#  ('want_get', 3),
#  ('im_going', 3),
#  ('place_order', 3),
#  ('back_soon', 3),
#  ('louisiana_rub', 3),
#  ('french_toast', 3),
#  ('old_fashioned', 3),
#  ('scrambled_eggs', 3),
#  ('eggs_bacon', 3),
#  ('grocery_store', 3),
#  ('took_back', 3),
#  ('say_im', 3),
#  ('side_bacon', 3),
#  ('pepper_tree', 3),
#  ('beer_wine', 3),
#  ('garden_one', 3),
#  ('grab_beer', 3),
#  ('perfect_place', 3),
#  ('cheese_mac', 3),
#  ('place_great', 3),
#  ('well_half', 3),
#  ('half_stars', 3),
#  ('stars_really', 3),
#  ('really_yelp', 3),
#  ('yelp_round', 3),
#  ('round_hey', 3),
#  ('hey_atmosphere', 3),
#  ('garden_good', 3),
#  ('good_fine', 3),
#  ('fine_anchor', 3),
#  ('anchor_sb', 3),
#  ('sb_public', 3),
#  ('market_sure', 3),
#  ('sure_beer', 3),
#  ('excellent_taps', 3),
#  ('taps_great', 3),
#  ('great_local', 3),
#  ('local_offering', 3),
#  ('offering_well', 3),
#  ('well_excellent', 3),
#  ('excellent_regional', 3),
#  ('regional_choices', 3),
#  ('choices_even', 3),
#  ('even_fair', 3),
#  ('fair_selection', 3),
#  ('selection_actual', 3),
#  ('actual_quality', 3),
#  ('quality_imports', 3),
#  ('imports_means', 3),
#  ('means_affligem', 3),
#  ('affligem_st', 3),
#  ('st_bernardus', 3),
#  ('bernardus_heineken', 3),
#  ('heineken_stella', 3),
#  ('stella_food', 3),
#  ('food_wise', 3),
#  ('wise_things', 3),
#  ('things_cool', 3),
#  ('cool_amazing', 3),
#  ('amazing_fried', 3),
#  ('sandwich_thought', 3),
#  ('thought_great', 3),
#  ('came_quite', 3),
#  ('quite_ordinary', 3),
#  ('ordinary_ok', 3),
#  ('ok_biggie', 3),
#  ('biggie_chicken', 3),
#  ('chicken_good', 3),
#  ('good_awesome', 3),
#  ('awesome_fries', 3),
#  ('fries_too', 3),
#  ('like_missed', 3),
#  ('missed_opportunity', 3),
#  ('opportunity_wife', 3),
#  ('wife_stone', 3),
#  ('stone_fruit', 3),
#  ('fruit_heirloom', 3),
#  ('heirloom_burrata', 3),
#  ('burrata_caprese', 3),
#  ('caprese_salad', 3),
#  ('salad_cheese', 3),
#  ('cheese_tomatoes', 3),
#  ('tomatoes_awesome', 3),
#  ('awesome_fruits', 3),
#  ('fruits_bit', 3),
#  ('bit_underripe', 3),
#  ('underripe_top', 3),
#  ('top_everything', 3),
#  ('everything_though', 3),
#  ('though_know', 3),
#  ('know_pseudo', 3),
#  ('pseudo_reasons', 3),
#  ('reasons_policies', 3),
#  ('policies_would', 3),
#  ('would_great', 3),
#  ('great_able', 3),
#  ('bring_awesome', 3),
#  ('awesome_foods', 3),
#  ('foods_purveyors', 3),
#  ('purveyors_public', 3),
#  ('garden_pair', 3),
#  ('pair_amazing', 3),
#  ('amazing_beers', 3),
#  ('beers_sigh', 3),
#  ('sigh_come', 3),
#  ('beer_mostly', 3),
#  ('things_menu', 3),
#  ('menu_looked', 3),
#  ('looked_good', 3),
#  ('selection_great', 3),
#  ('buffalo_cauliflower', 3),
#  ('avocado_toast', 3),
#  ('chimichurri_fries', 3),
#  ('end_bar', 3),
#  ('garden_food', 3),
#  ('bar_great', 3),
#  ('first_opened', 3),
#  ('watch_game', 3),
#  ('get_it', 3),
#  ('hot_chocolate', 2),
#  ('hot_water', 2),
#  ('breakfast_burrito', 2),
#  ('burrito_pretty', 2),
#  ('good_bad', 2),
#  ('food_make', 2),
#  ('ranges_gross', 2),
#  ('worth_money', 2),
#  ('lunch_great', 2),
#  ('one_end', 2),
#  ('lunch_rush', 2),
#  ('prepared_wait', 2),
#  ('ucsb_student', 2),
#  ('bring_lunch', 2),
#  ('drink_coffee', 2),
#  ('get_coffee', 2),
#  ('breakfast_served', 2),
#  ('another_reviewer', 2),
#  ('place_one', 2),
#  ('one_know', 2),
#  ('fresh_food', 2),
#  ('food_campus', 2),
#  ('go_arbor', 2),
#  ('sandwiches_salads', 2),
#  ('ordered_burger', 2),
#  ('take_orders', 2),
#  ('without_changing', 2),
#  ('changing_gloves', 2),
#  ('food_court', 2),
#  ('get_lost', 2),
#  ('coral_trees', 2),
#  ('veggie_patty', 2),
#  ('got_chicken', 2),
#  ('friendly_made', 2),
#  ('extra_charge', 2),
#  ('delicious_also', 2),
#  ('really_like', 2),
#  ('cup_coffee', 2),
#  ('bottom_cup', 2),
#  ('order_fries', 2),
#  ('veganvegetarian_options', 2),
#  ('whole_wheat', 2),
#  ('wheat_bun', 2),
#  ('really_busy', 2),
#  ('ordered_vegetarian', 2),
#  ('lacked_flavor', 2),
#  ('feeling_hungry', 2),
#  ('ordered_side', 2),
#  ('breakfast_potatoes', 2),
#  ('steak_fries', 2),
#  ('place_two', 2),
#  ('wide_variety', 2),
#  ('eat_somewhere', 2),
#  ('suggest_going', 2),
#  ('place_campus', 2),
#  ('seed_muffins', 2),
#  ('time_like', 2),
#  ('like_little', 2),
#  ('little_watery', 2),
#  ('fact_im', 2),
#  ('ive_also', 2),
#  ('places_campus', 2),
#  ('definitely_try', 2),
#  ('fries_go', 2),
#  ('one_pretty', 2),
#  ('slow_slow', 2),
#  ('waiting_place', 2),
#  ('togo_orders', 2),
#  ('chicken_pita', 2),
#  ('go_sit', 2),
#  ('sit_outside', 2),
#  ('place_grab', 2),
#  ('bacon_toast', 2),
#  ('good_though', 2),
#  ('ever_had', 2),
#  ('inside_seating', 2),
#  ('outside_seating', 2),
#  ('fine_really', 2),
#  ('try_food', 2),
#  ('always_get', 2),
#  ('cheese_bacon', 2),
#  ('tri_tip', 2),
#  ('let_alone', 2),
#  ('if_want', 2),
#  ('etc_best', 2),
#  ('eat_campus', 2),
#  ('buy_one', 2),
#  ('two_hours', 2),
#  ('found_place', 2),
#  ('single_one', 2),
#  ('seemed_like', 2),
#  ('best_places', 2),
#  ('lunch_run', 2),
#  ('opposite_side', 2),
#  ('small_suggest', 2),
#  ('first_last', 2),
#  ('go_regularly', 2),
#  ('attentive_food', 2),
#  ('last_several', 2),
#  ('wait_seated', 2),
#  ('wait_service', 2),
#  ('computer_screen', 2),
#  ('arrived_first', 2),
#  ('table_even', 2),
#  ('dinner_ordered', 2),
#  ('wanted_refill', 2),
#  ('came_eat', 2),
#  ('white_queso', 2),
#  ('spinach_dip', 2),
#  ('came_today', 2),
#  ('took_forever', 2),
#  ('asked_medium', 2),
#  ('tasted_great', 2),
#  ('star_rating', 2),
#  ('problem_chilis', 2),
#  ('signature_dish', 2),
#  ('particular_chilis', 2),
#  ('wanted_different', 2),
#  ('los_agaves', 2),
#  ('love_ancho', 2),
#  ('salmon_two', 2),
#  ('two_times', 2),
#  ('times_gone', 2),
#  ('gone_told', 2),
#  ('told_order', 2),
#  ('order_enough', 2),
#  ('enough_out', 2),
#  ('out_good', 2),
#  ('good_business', 2),
#  ('bad_service', 2),
#  ('football_season', 2),
#  ('best_beer', 2),
#  ('cant_expect', 2),
#  ('get_right', 2),
#  ('time_would', 2),
#  ('would_fix', 2),
#  ('bar_bartender', 2),
#  ('bar_tables', 2),
#  ('oh_look', 2),
#  ('look_receipt', 2),
#  ('side_island', 2),
#  ('got_burger', 2),
#  ('warm_bun', 2),
#  ('fries_well', 2),
#  ('one_nice', 2),
#  ('half_meal', 2),
#  ('one_too', 2),
#  ('busy_bar', 2),
#  ('time_three', 2),
#  ('said_nothing', 2),
#  ('wanted_dessert', 2),
#  ('thank_time', 2),
#  ('seriously_chilis', 2),
#  ('chilis_always', 2),
#  ('wrote_review', 2),
#  ('ordered_togo', 2),
#  ('would_take', 2),
#  ('guys_even', 2),
#  ('even_busy', 2),
#  ('food_top', 2),
#  ('drove_way', 2),
#  ('buns_foil', 2),
#  ('wanted_money', 2),
#  ('money_back', 2),
#  ('came_said', 2),
#  ('deal_great', 2),
#  ('ok_im', 2),
#  ('bbq_chicken', 2),
#  ('way_thru', 2),
#  ('chicken_made', 2),
#  ('make_right', 2),
#  ('came_apologized', 2),
#  ('bar_bartenders', 2),
#  ('goleta_one', 2),
#  ('know_us', 2),
#  ('give_stars', 2),
#  ('lots_tvs', 2),
#  ('always_fresh', 2),
#  ('good_home', 2),
#  ('home_made', 2),
#  ('something_unique', 2),
#  ('service_waiter', 2),
#  ('waiter_victor', 2),
#  ('even_better', 2),
#  ('lunch_dinner', 2),
#  ('seated_quickly', 2),
#  ('quickly_food', 2),
#  ('went_beyond', 2),
#  ('seated_minutes', 2),
#  ('minutes_one', 2),
#  ('one_came', 2),
#  ('made_sure', 2),
#  ('sure_well', 2),
#  ('taken_care', 2),
#  ('care_of', 2),
#  ('wednesday_night', 2),
#  ('bus_tables', 2),
#  ('ask_things', 2),
#  ('chilis_went', 2),
#  ('weeks_ago', 2),
#  ('back_even', 2),
#  ('three_times', 2),
#  ('times_friends', 2),
#  ('get_boneless', 2),
#  ('one_ordered', 2),
#  ('right_order', 2),
#  ('eye_contact', 2),
#  ('quick_easy', 2),
#  ('prices_fair', 2),
#  ('enjoy_meals', 2),
#  ('like_spicy', 2),
#  ('spicy_food', 2),
#  ('chicken_salad', 2),
#  ('texas_cheese', 2),
#  ('reason_im', 2),
#  ('stars_service', 2),
#  ('service_kinda', 2),
#  ('went_around', 2),
#  ('whole_restaurant', 2),
#  ('slow_waiter', 2),
#  ('great_friendly', 2),
#  ('chilis_good', 2),
#  ('dinner_chilis', 2),
#  ('friend_manager', 2),
#  ('manager_chilis', 2),
#  ('chilis_feel', 2),
#  ('feel_really', 2),
#  ('bad_review', 2),
#  ('chilis_every', 2),
#  ('service_hit', 2),
#  ('got_fed', 2),
#  ('paid_bill', 2),
#  ('thing_say', 2),
#  ('great_price', 2),
#  ('weekend_night', 2),
#  ('ok_waiting', 2),
#  ('minutes_get', 2),
#  ('kids_food', 2),
#  ('food_arrived', 2),
#  ('husband_got', 2),
#  ('flag_someone', 2),
#  ('kids_meals', 2),
#  ('rarely_go', 2),
#  ('margarita_chicken', 2),
#  ('thing_could', 2),
#  ('it_also', 2),
#  ('also_margarita', 2),
#  ('time_eating', 2),
#  ('plan_coming', 2),
#  ('meal_deal', 2),
#  ('negative_reviews', 2),
#  ('went_group', 2),
#  ('almost_empty', 2),
#  ('back_service', 2),
#  ('decent_experienced', 2),
#  ('experienced_much', 2),
#  ('much_mostly', 2),
#  ('mostly_order', 2),
#  ('order_takeout', 2),
#  ('takeout_kitchen', 2),
#  ('must_certainly', 2),
#  ('certainly_laziest', 2),
#  ('laziest_ever', 2),
#  ('encountered_joking', 2),
#  ('joking_i', 2),
#  ('i_restaurant', 2),
#  ('restaurant_experience', 2),
#  ('experience_could', 2),
#  ('could_run', 2),
#  ('better_kitchen', 2),
#  ('kitchen_reasons', 2),
#  ('reasons_why', 2),
#  ('why_occasionally', 2),
#  ('occasionally_food', 2),
#  ('food_arrive', 2),
#  ('arrive_without', 2),
#  ('without_sides', 2),
#  ('sides_forgot', 2),
#  ('forgot_sides', 2),
#  ('sides_like', 2),
#  ('like_job', 2),
#  ('theyre_helping', 2),
#  ('helping_buddy', 2),
#  ('buddy_move', 2),
#  ('move_exchange', 2),
#  ('exchange_money', 2),
#  ('money_maybe', 2),
#  ('maybe_cheap', 2),
#  ('cheap_beer', 2),
#  ('beer_portion', 2),
#  ('portion_sizing', 2),
#  ('sizing_entirely', 2),
#  ('entirely_arbitrary', 2),
#  ('arbitrary_could', 2),
#  ('could_dozen', 2),
#  ('dozen_onion', 2),
#  ('rings_could', 2),
#  ('could_four', 2),
#  ('four_onion', 2),
#  ('rings_knows', 2),
#  ('knows_flip', 2),
#  ('flip_coin', 2),
#  ('coin_costs', 2),
#  ('costs_six', 2),
#  ('six_dollars', 2),
#  ('dollars_either', 2),
#  ('way_oh', 2),
#  ('oh_yeah', 2),
#  ('yeah_order', 2),
#  ('order_bowl', 2),
#  ('bowl_instead', 2),
#  ('instead_cup', 2),
#  ('give_bowl', 2),
#  ('bowl_effectively', 2),
#  ('effectively_took', 2),
#  ('took_advantage', 2),
#  ('advantage_ordering', 2),
#  ('ordering_takeout', 2),
#  ('takeout_steal', 2),
#  ('steal_two', 2),
#  ('dollars_me', 2),
#  ('me_even', 2),
#  ('even_like', 2),
#  ('place_cheap', 2),
#  ('cheap_horrid', 2),
#  ('horrid_waste', 2),
#  ('waste_commercial', 2),
#  ('commercial_space', 2),
#  ('lunch_boyfriend', 2),
#  ('boyfriend_week', 2),
#  ('week_ordered', 2),
#  ('food_lunch', 2),
#  ('lunch_combos', 2),
#  ('combos_pork', 2),
#  ('pork_tacos', 2),
#  ('tacos_house', 2),
#  ...]

# %%
good_American=American[American.stars>=4.5]
good_American_review = American_review[American_review.business_id.isin(good_American.business_id.values)]
good_American_review_text = good_American_review.text.str.cat(sep = " ")
good_American_tokens = word_tokenize(good_American_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_good_American = ["_".join(item) for item in nltk.bigrams(good_American_tokens)]
trigrams_list_good_American = ["_".join(item) for item in nltk.trigrams(good_American_tokens)]
# FreqDist(bigrams_list_good_American).most_common()
FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('fried_chicken_sandwich', 7),
#  ('mac_n_cheese', 6),
#  ('coral_tree_cafe', 5),
#  ('food_good_service', 5),
#  ('definitely_recommend_place', 5),
#  ('also_pretty_good', 4),
#  ('im_big_fan', 4),
#  ('table_next_us', 4),
#  ('would_definitely_recommend', 4),
#  ('great_beer_selection', 4),
#  ('beer_selection_excellent', 4),
#  ('too_seems_like', 4),
#  ('public_market_garden', 4),
#  ('santa_barbara_public', 4),
#  ('barbara_public_market', 4),
#  ('going_somewhere_else', 3),
#  ('lemon_poppy_seed', 3),
#  ('definitely_come_back', 3),
#  ('took_long_time', 3),
#  ('molten_chocolate_cake', 3),
#  ('main_dining_area', 3),
#  ('chicken_enchilada_soup', 3),
#  ('never_going_back', 3),
#  ('service_really_good', 3),
#  ('good_service_food', 3),
#  ('food_pretty_good', 3),
#  ('cant_go_wrong', 3),
#  ('every_time_go', 3),
#  ('worst_service_ever', 3),
#  ('never_go_back', 3),
#  ('great_service_food', 3),
#  ('loaded_mashed_potatoes', 3),
#  ('got_seated_right', 3),
#  ('cajun_chicken_pasta', 3),
#  ('never_bad_experience', 3),
#  ('got_food_first', 3),
#  ('never_checked_us', 3),
#  ('food_would_come', 3),
#  ('minutes_come_out', 3),
#  ('place_go_service', 3),
#  ('ordered_chicken_sandwich', 3),
#  ('good_customer_service', 3),
#  ('beer_selection_good', 3),
#  ('staff_super_friendly', 3),
#  ('corned_beef_hash', 3),
#  ('cheese_mac_n', 3),
#  ('well_half_stars', 3),
#  ('half_stars_really', 3),
#  ('stars_really_yelp', 3),
#  ('really_yelp_round', 3),
#  ('yelp_round_hey', 3),
#  ('round_hey_atmosphere', 3),
#  ('hey_atmosphere_garden', 3),
#  ('atmosphere_garden_good', 3),
#  ('garden_good_fine', 3),
#  ('good_fine_anchor', 3),
#  ('fine_anchor_sb', 3),
#  ('anchor_sb_public', 3),
#  ('sb_public_market', 3),
#  ('public_market_sure', 3),
#  ('market_sure_beer', 3),
#  ('sure_beer_selection', 3),
#  ('selection_excellent_taps', 3),
#  ('excellent_taps_great', 3),
#  ('taps_great_local', 3),
#  ('great_local_offering', 3),
#  ('local_offering_well', 3),
#  ('offering_well_excellent', 3),
#  ('well_excellent_regional', 3),
#  ('excellent_regional_choices', 3),
#  ('regional_choices_even', 3),
#  ('choices_even_fair', 3),
#  ('even_fair_selection', 3),
#  ('fair_selection_actual', 3),
#  ('selection_actual_quality', 3),
#  ('actual_quality_imports', 3),
#  ('quality_imports_means', 3),
#  ('imports_means_affligem', 3),
#  ('means_affligem_st', 3),
#  ('affligem_st_bernardus', 3),
#  ('st_bernardus_heineken', 3),
#  ('bernardus_heineken_stella', 3),
#  ('heineken_stella_food', 3),
#  ('stella_food_wise', 3),
#  ('food_wise_things', 3),
#  ('wise_things_cool', 3),
#  ('things_cool_amazing', 3),
#  ('cool_amazing_fried', 3),
#  ('amazing_fried_chicken', 3),
#  ('chicken_sandwich_thought', 3),
#  ('sandwich_thought_great', 3),
#  ('thought_great_fries', 3),
#  ('great_fries_came', 3),
#  ('fries_came_quite', 3),
#  ('came_quite_ordinary', 3),
#  ('quite_ordinary_ok', 3),
#  ('ordinary_ok_biggie', 3),
#  ('ok_biggie_chicken', 3),
#  ('biggie_chicken_good', 3),
#  ('chicken_good_awesome', 3),
#  ('good_awesome_fries', 3),
#  ('awesome_fries_too', 3),
#  ('fries_too_seems', 3),
#  ('seems_like_missed', 3),
#  ('like_missed_opportunity', 3),
#  ('missed_opportunity_wife', 3),
#  ('opportunity_wife_stone', 3),
#  ('wife_stone_fruit', 3),
#  ('stone_fruit_heirloom', 3),
#  ('fruit_heirloom_burrata', 3),
#  ('heirloom_burrata_caprese', 3),
#  ('burrata_caprese_salad', 3),
#  ('caprese_salad_cheese', 3),
#  ('salad_cheese_tomatoes', 3),
#  ('cheese_tomatoes_awesome', 3),
#  ('tomatoes_awesome_fruits', 3),
#  ('awesome_fruits_bit', 3),
#  ('fruits_bit_underripe', 3),
#  ('bit_underripe_top', 3),
#  ('underripe_top_everything', 3),
#  ('top_everything_though', 3),
#  ('everything_though_know', 3),
#  ('though_know_pseudo', 3),
#  ('know_pseudo_reasons', 3),
#  ('pseudo_reasons_policies', 3),
#  ('reasons_policies_would', 3),
#  ('policies_would_great', 3),
#  ('would_great_able', 3),
#  ('great_able_bring', 3),
#  ('able_bring_awesome', 3),
#  ('bring_awesome_foods', 3),
#  ('awesome_foods_purveyors', 3),
#  ('foods_purveyors_public', 3),
#  ('purveyors_public_market', 3),
#  ('market_garden_pair', 3),
#  ('garden_pair_amazing', 3),
#  ('pair_amazing_beers', 3),
#  ('amazing_beers_sigh', 3),
#  ('beers_sigh_come', 3),
#  ('sigh_come_back', 3),
#  ('come_back_beer', 3),
#  ('back_beer_mostly', 3),
#  ('things_menu_looked', 3),
#  ('menu_looked_good', 3),
#  ('beer_selection_great', 3),
#  ('place_watch_sports', 3),
#  ('burrito_pretty_good', 2),
#  ('definitely_worth_money', 2),
#  ('without_changing_gloves', 2),
#  ('going_back_again', 2),
#  ('whole_wheat_bun', 2),
#  ('suggest_going_somewhere', 2),
#  ('poppy_seed_muffins', 2),
#  ('service_super_friendly', 2),
#  ('go_sit_outside', 2),
#  ('ive_ever_had', 2),
#  ('pretty_good_place', 2),
#  ('etc_best_place', 2),
#  ('buy_one_get', 2),
#  ('one_get_one', 2),
#  ('every_single_one', 2),
#  ('chicken_sandwich_fries', 2),
#  ('love_ancho_salmon', 2),
#  ('ancho_salmon_two', 2),
#  ('salmon_two_times', 2),
#  ('two_times_gone', 2),
#  ('times_gone_told', 2),
#  ('gone_told_order', 2),
#  ('told_order_enough', 2),
#  ('order_enough_out', 2),
#  ('enough_out_good', 2),
#  ('out_good_business', 2),
#  ('beer_selection_beer', 2),
#  ('find_something_like', 2),
#  ('oh_look_receipt', 2),
#  ('fries_well_done', 2),
#  ('wanted_money_back', 2),
#  ('food_decent_service', 2),
#  ('one_came_table', 2),
#  ('taken_care_of', 2),
#  ('service_always_good', 2),
#  ('texas_cheese_fries', 2),
#  ('reason_im_giving', 2),
#  ('friend_manager_chilis', 2),
#  ('manager_chilis_feel', 2),
#  ('chilis_feel_really', 2),
#  ('service_hit_miss', 2),
#  ('paid_bill_left', 2),
#  ('ok_waiting_minutes', 2),
#  ('crispy_chicken_crispers', 2),
#  ('plan_coming_back', 2),
#  ('service_decent_experienced', 2),
#  ('decent_experienced_much', 2),
#  ('experienced_much_mostly', 2),
#  ('much_mostly_order', 2),
#  ('mostly_order_takeout', 2),
#  ('order_takeout_kitchen', 2),
#  ('takeout_kitchen_must', 2),
#  ('kitchen_must_certainly', 2),
#  ('must_certainly_laziest', 2),
#  ('certainly_laziest_ever', 2),
#  ('laziest_ever_encountered', 2),
#  ('ever_encountered_joking', 2),
#  ('encountered_joking_i', 2),
#  ('joking_i_restaurant', 2),
#  ('i_restaurant_experience', 2),
#  ('restaurant_experience_could', 2),
#  ('experience_could_run', 2),
#  ('could_run_better', 2),
#  ('run_better_kitchen', 2),
#  ('better_kitchen_reasons', 2),
#  ('kitchen_reasons_why', 2),
#  ('reasons_why_occasionally', 2),
#  ('why_occasionally_food', 2),
#  ('occasionally_food_arrive', 2),
#  ('food_arrive_without', 2),
#  ('arrive_without_sides', 2),
#  ('without_sides_forgot', 2),
#  ('sides_forgot_sides', 2),
#  ('forgot_sides_like', 2),
#  ('sides_like_job', 2),
#  ('like_job_theyre', 2),
#  ('job_theyre_helping', 2),
#  ('theyre_helping_buddy', 2),
#  ('helping_buddy_move', 2),
#  ('buddy_move_exchange', 2),
#  ('move_exchange_money', 2),
#  ('exchange_money_maybe', 2),
#  ('money_maybe_cheap', 2),
#  ('maybe_cheap_beer', 2),
#  ('cheap_beer_portion', 2),
#  ('beer_portion_sizing', 2),
#  ('portion_sizing_entirely', 2),
#  ('sizing_entirely_arbitrary', 2),
#  ('entirely_arbitrary_could', 2),
#  ('arbitrary_could_dozen', 2),
#  ('could_dozen_onion', 2),
#  ('dozen_onion_rings', 2),
#  ('onion_rings_could', 2),
#  ('rings_could_four', 2),
#  ('could_four_onion', 2),
#  ('four_onion_rings', 2),
#  ('onion_rings_knows', 2),
#  ('rings_knows_flip', 2),
#  ('knows_flip_coin', 2),
#  ('flip_coin_costs', 2),
#  ('coin_costs_six', 2),
#  ('costs_six_dollars', 2),
#  ('six_dollars_either', 2),
#  ('dollars_either_way', 2),
#  ('either_way_oh', 2),
#  ('way_oh_yeah', 2),
#  ('oh_yeah_order', 2),
#  ('yeah_order_bowl', 2),
#  ('order_bowl_instead', 2),
#  ('bowl_instead_cup', 2),
#  ('give_bowl_effectively', 2),
#  ('bowl_effectively_took', 2),
#  ('effectively_took_advantage', 2),
#  ('took_advantage_ordering', 2),
#  ('advantage_ordering_takeout', 2),
#  ('ordering_takeout_steal', 2),
#  ('takeout_steal_two', 2),
#  ('steal_two_dollars', 2),
#  ('two_dollars_me', 2),
#  ('dollars_me_even', 2),
#  ('me_even_like', 2),
#  ('even_like_place', 2),
#  ('like_place_cheap', 2),
#  ('place_cheap_horrid', 2),
#  ('cheap_horrid_waste', 2),
#  ('horrid_waste_commercial', 2),
#  ('waste_commercial_space', 2),
#  ('ate_lunch_boyfriend', 2),
#  ('lunch_boyfriend_week', 2),
#  ('boyfriend_week_ordered', 2),
#  ('week_ordered_food', 2),
#  ('ordered_food_lunch', 2),
#  ('food_lunch_combos', 2),
#  ('lunch_combos_pork', 2),
#  ('combos_pork_tacos', 2),
#  ('pork_tacos_house', 2),
#  ('tacos_house_salad', 2),
#  ('house_salad_bf', 2),
#  ('salad_bf_got', 2),
#  ('bf_got_quesadillas', 2),
#  ('got_quesadillas_chicken', 2),
#  ('quesadillas_chicken_enchilada', 2),
#  ('enchilada_soup_felt', 2),
#  ('soup_felt_portions', 2),
#  ('felt_portions_perfect', 2),
#  ('portions_perfect_size', 2),
#  ('perfect_size_since', 2),
#  ('size_since_want', 2),
#  ('since_want_eat', 2),
#  ('want_eat_much', 2),
#  ('eat_much_work', 2),
#  ('much_work_ordered', 2),
#  ('work_ordered_avocado', 2),
#  ('ordered_avocado_ranch', 2),
#  ('avocado_ranch_salad', 2),
#  ('ranch_salad_im', 2),
#  ('salad_im_big', 2),
#  ('big_fan_ranch', 2),
#  ('fan_ranch_salad', 2),
#  ('ranch_salad_one', 2),
#  ('salad_one_actually', 2),
#  ('one_actually_really', 2),
#  ('actually_really_enjoyed', 2),
#  ('really_enjoyed_tacos', 2),
#  ('enjoyed_tacos_pretty', 2),
#  ('tacos_pretty_good', 2),
#  ('pretty_good_nothing', 2),
#  ('good_nothing_special', 2),
#  ('nothing_special_would', 2),
#  ('special_would_rated', 2),
#  ('would_rated_one', 2),
#  ('rated_one_star', 2),
#  ('one_star_higher', 2),
#  ('star_higher_let', 2),
#  ('higher_let_get', 2),
#  ('let_get_one', 2),
#  ('get_one_chicken', 2),
#  ('one_chicken_one', 2),
#  ('chicken_one_pork', 2),
#  ('one_pork_taco', 2),
#  ('pork_taco_bummed', 2),
#  ('taco_bummed_out', 2),
#  ('bummed_out_tried', 2),
#  ('out_tried_bfs', 2),
#  ('tried_bfs_soup', 2),
#  ('bfs_soup_thought', 2),
#  ('soup_thought_flavorful', 2),
#  ('thought_flavorful_service', 2),
#  ('flavorful_service_really', 2),
#  ('really_good_especially', 2),
#  ('good_especially_since', 2),
#  ('especially_since_busy', 2),
#  ('since_busy_lunch', 2),
#  ('always_great_service', 2),
#  ('worst_customer_service', 2),
#  ('customer_service_ever', 2),
#  ('service_ever_experienced', 2),
#  ('get_drink_order', 2),
#  ('minutes_later_get', 2),
#  ('big_fan_chilis', 2),
#  ('restaurants_santa_barbara', 2),
#  ('come_back_food', 2),
#  ('someone_take_order', 2),
#  ('supposed_use_pay', 2),
#  ('feel_like_im', 2),
#  ('long_wait_times', 2),
#  ('man_whose_order', 2),
#  ('whose_order_consisted', 2),
#  ('good_experiences_chilis', 2),
#  ('little_bit_slow', 2),
#  ('margaritas_strong_like', 2),
#  ('im_pretty_sure', 2),
#  ('first_time_here', 2),
#  ('try_last_night', 2),
#  ('friendly_staff_quick', 2),
#  ('staff_quick_service', 2),
#  ('family_got_seated', 2),
#  ('seated_right_us', 2),
#  ('right_us_got', 2),
#  ('drink_order_taken', 2),
#  ('hit_miss_think', 2),
#  ('fajitas_without_bell', 2),
#  ('without_bell_peppers', 2),
#  ('well_never_back', 2),
#  ('chips_n_salsa', 2),
#  ('ordered_cajun_chicken', 2),
#  ('good_happy_hour', 2),
#  ('fine_dining_experience', 2),
#  ('appetizer_two_entrees', 2),
#  ('ask_three_different', 2),
#  ('hi_welcome_chilis', 2),
#  ('came_us_got', 2),
#  ('send_food_back', 2),
#  ('molten_cake_awesome', 2),
#  ('one_party_members', 2),
#  ('somewhere_else_want', 2),
#  ('next_visit_bad', 2),
#  ('stars_minus_one', 2),
#  ('time_got_home', 2),
#  ('one_last_week', 2),
#  ('give_us_bill', 2),
#  ('every_time_come', 2),
#  ('great_place_dinner', 2),
#  ('great_service_reasonable', 2),
#  ('great_place_go', 2),
#  ('go_service_great', 2),
#  ('service_great_love', 2),
#  ('great_love_hamburgers', 2),
#  ('love_hamburgers_chicken', 2),
#  ('hamburgers_chicken_would', 2),
#  ('chicken_would_definitely', 2),
#  ('recommend_place_nice', 2),
#  ('place_nice_quality', 2),
#  ('nice_quality_food', 2),
#  ('quality_food_way', 2),
#  ('food_way_better', 2),
#  ('way_better_general', 2),
#  ('better_general_fast', 2),
#  ('general_fast_food', 2),
#  ('fast_food_place', 2),
#  ('food_place_people', 2),
#  ('place_people_nice', 2),
#  ('people_nice_would', 2),
#  ('nice_would_definitely', 2),
#  ('one_favorite_places', 2),
#  ('roasted_street_corn', 2),
#  ('restaurant_im_sure', 2),
#  ('comes_bag_heat', 2),
#  ('bag_heat_up', 2),
#  ('chilis_one_places', 2),
#  ('ive_never_bad', 2),
#  ('food_good_complaints', 2),
#  ('us_got_food', 2),
#  ('bacon_looked_like', 2),
#  ('everything_made_fresh', 2),
#  ('would_come_back', 2),
#  ('credit_card_machine', 2),
#  ('food_great_beer', 2),
#  ('loaded_potatoes_broccoli', 2),
#  ('awesome_blossom_petals', 2),
#  ('food_large_portions', 2),
#  ('food_good_beer', 2),
#  ('ordered_cobb_salad', 2),
#  ('best_western_plus', 2),
#  ('try_menu_items', 2),
#  ('restaurant_rd_floor', 2),
#  ('super_friendly_staff', 2),
#  ('mango_habanero_good', 2),
#  ('best_wings_ive', 2),
#  ('great_customer_service', 2),
#  ('la_cumbre_plaza', 2),
#  ('online_ordering_easy', 2),
#  ('definitely_coming_back', 2),
#  ('online_ordering_system', 2),
#  ('home_cooked_style', 2),
#  ('cooked_style_food', 2),
#  ('staying_best_western', 2),
#  ('scrambled_eggs_bacon', 2),
#  ('waste_time_money', 2),
#  ('would_go_back', 2),
#  ('next_best_western', 2),
#  ('interior_looks_like', 2),
#  ('ive_never_seen', 2),
#  ('looked_like_cooked', 2),
#  ('excellent_selection_beer', 2),
#  ('located_public_market', 2),
#  ('stop_public_market', 2),
#  ('amazing_beer_selection', 2),
#  ('bring_food_vendors', 2),
#  ('rest_public_market', 2),
#  ('stout_ice_cream', 2),
#  ('beer_mostly_things', 2),
#  ('mostly_things_menu', 2),
#  ('looked_good_update', 2),
#  ('food_vendors_public', 2),
#  ('vendors_public_market', 2),
#  ('list_craft_beers', 2),
#  ('craft_beers_decent', 2),
#  ('bring_food_places', 2),
#  ('long_buy_drink', 2),
#  ('great_place_watch', 2),
#  ('goes_concept_public', 2),
#  ('concept_public_market', 2),
#  ('corazon_empty_bowl', 2),
#  ('worst_service_ive', 2),
#  ('service_ive_ever', 2),
#  ('husband_ordered_beer', 2),
#  ('charge_bring_food', 2),
#  ('made_wait_extra', 2),
#  ('wait_extra_minutes', 2),
#  ('bring_food_public', 2),
#  ('food_public_market', 2),
#  ('public_market_growing', 2),
#  ('big_fan_multiple', 2),
#  ('fan_multiple_businesses', 2),
#  ('multiple_businesses_one', 2),
#  ('businesses_one_roof', 2),
#  ('big_plus_bring', 2),
#  ('plus_bring_food', 2),
#  ('bring_food_anywhere', 2),
#  ('food_anywhere_market', 2),
#  ('anywhere_market_sit', 2),
#  ('ordered_hot_chocolate', 1),
#  ('hot_chocolate_tasted', 1),
#  ('chocolate_tasted_like', 1),
#  ('tasted_like_hot', 1),
#  ('like_hot_water', 1),
#  ('hot_water_sprinkled', 1),
#  ('water_sprinkled_coco', 1),
#  ('sprinkled_coco_powder', 1),
#  ('coco_powder_know', 1),
#  ('powder_know_mess', 1),
#  ('know_mess_powder', 1),
#  ('mess_powder_hot', 1),
#  ('powder_hot_chocolate', 1),
#  ('hot_chocolate_sip', 1),
#  ('chocolate_sip_threw', 1),
#  ('sip_threw_away', 1),
#  ('threw_away_come', 1),
#  ('away_come_want', 1),
#  ('come_want_breakfast', 1),
#  ('want_breakfast_burrito', 1),
#  ('breakfast_burrito_pretty', 1),
#  ('pretty_good_bad', 1),
#  ('good_bad_stop', 1),
#  ('bad_stop_serving', 1),
#  ('stop_serving_am', 1),
#  ('serving_am_recommend', 1),
#  ('am_recommend_eating', 1),
#  ('recommend_eating_food', 1),
#  ('eating_food_make', 1),
#  ('food_make_ranges', 1),
#  ('make_ranges_gross', 1),
#  ('ranges_gross_disgusting', 1),
#  ('gross_disgusting_definitely', 1),
#  ('disgusting_definitely_worth', 1),
#  ('worth_money_work', 1),
#  ('money_work_ucsb', 1),
#  ('work_ucsb_stop', 1),
#  ('ucsb_stop_frequently', 1),
#  ('stop_frequently_coffee', 1),
#  ('frequently_coffee_small', 1),
#  ('coffee_small_snacks', 1),
#  ('small_snacks_sometimes', 1),
#  ('snacks_sometimes_full', 1),
#  ('sometimes_full_lunch', 1),
#  ('full_lunch_great', 1),
#  ('lunch_great_part', 1),
#  ('great_part_coral', 1),
#  ('part_coral_tree', 1),
#  ('coral_tree_bit', 1),
#  ('tree_bit_everything', 1),
#  ('bit_everything_coffee', 1),
#  ('everything_coffee_shopconvenience', 1),
#  ('coffee_shopconvenience_storebreakfast', 1),
#  ('shopconvenience_storebreakfast_placelunch', 1),
#  ('storebreakfast_placelunch_placestudy', 1),
#  ('placelunch_placestudy_spot', 1),
#  ('placestudy_spot_rolled', 1),
#  ('spot_rolled_one', 1),
#  ('rolled_one_get', 1),
#  ('one_get_packaged', 1),
#  ('get_packaged_snacks', 1),
#  ('packaged_snacks_meals', 1),
#  ('snacks_meals_chips', 1),
#  ('meals_chips_granola', 1),
#  ('chips_granola_bars', 1),
#  ('granola_bars_yogurts', 1),
#  ('bars_yogurts_cold', 1),
#  ('yogurts_cold_bottled', 1),
#  ('cold_bottled_drinks', 1),
#  ('bottled_drinks_salads', 1),
#  ('drinks_salads_wrapped', 1),
#  ('salads_wrapped_cold', 1),
#  ('wrapped_cold_sandwiches', 1),
#  ('cold_sandwiches_etc', 1),
#  ('sandwiches_etc_one', 1),
#  ('etc_one_end', 1),
#  ('one_end_prepared', 1),
#  ('end_prepared_food', 1),
#  ('prepared_food_end', 1),
#  ('food_end_get', 1),
#  ('end_get_line', 1),
#  ('get_line_order', 1),
#  ('line_order_want', 1),
#  ('order_want_move', 1),
#  ('want_move_next', 1),
#  ('move_next_register', 1),
#  ('next_register_pay', 1),
#  ('register_pay_get', 1),
#  ('pay_get_number', 1),
#  ('get_number_bring', 1),
#  ('number_bring_right', 1),
#  ('bring_right_whether', 1),
#  ('right_whether_inside', 1),
#  ('whether_inside_outside', 1),
#  ('inside_outside_lunch', 1),
#  ('outside_lunch_menu', 1),
#  ('lunch_menu_staples', 1),
#  ('menu_staples_salads', 1),
#  ('staples_salads_sandwiches', 1),
#  ('salads_sandwiches_soups', 1),
#  ('sandwiches_soups_pitas', 1),
#  ('soups_pitas_burritos', 1),
#  ('pitas_burritos_stir', 1),
#  ('burritos_stir_fry', 1),
#  ('stir_fry_choices', 1),
#  ('fry_choices_etc', 1),
#  ('choices_etc_lunch', 1),
#  ('etc_lunch_rush', 1),
#  ('lunch_rush_prepared', 1),
#  ('rush_prepared_wait', 1),
#  ('prepared_wait_bit', 1),
#  ('wait_bit_place', 1),
#  ('bit_place_reasonably', 1),
#  ('place_reasonably_priced', 1),
#  ('reasonably_priced_large', 1),
#  ('priced_large_enough', 1),
#  ('large_enough_menu', 1),
#  ('enough_menu_satisfy', 1),
#  ('menu_satisfy_pretty', 1),
#  ('satisfy_pretty_much', 1),
#  ('pretty_much_everyone', 1),
#  ('much_everyone_suits', 1),
#  ('everyone_suits_many', 1),
#  ('suits_many_needs', 1),
#  ('many_needs_tips', 1),
#  ('needs_tips_ask', 1),
#  ('tips_ask_ucsb', 1),
#  ('ask_ucsb_student', 1),
#  ('ucsb_student_think', 1),
#  ('student_think_might', 1),
#  ('think_might_small', 1),
#  ('might_small_discount', 1),
#  ('small_discount_ie', 1),
#  ('discount_ie_pay', 1),
#  ('ie_pay_tax', 1),
#  ('pay_tax_bring', 1),
#  ('tax_bring_lunch', 1),
#  ('bring_lunch_totally', 1),
#  ('lunch_totally_cool', 1),
#  ('totally_cool_sitting', 1),
#  ('cool_sitting_outdoor', 1),
#  ('sitting_outdoor_tables', 1),
#  ('outdoor_tables_drink', 1),
#  ('tables_drink_coffee', 1),
#  ('drink_coffee_lot', 1),
#  ('coffee_lot_get', 1),
#  ('lot_get_frequent', 1),
#  ('get_frequent_flyer', 1),
#  ('frequent_flyer_card', 1),
#  ('flyer_card_stamp', 1),
#  ('card_stamp_every', 1),
#  ('stamp_every_time', 1),
#  ('every_time_get', 1),
#  ('time_get_coffee', 1),
#  ('get_coffee_it', 1),
#  ('coffee_it_works', 1),
#  ('it_works_coffee', 1),
#  ('works_coffee_unfortunately', 1),
#  ('coffee_unfortunately_ten', 1),
#  ('unfortunately_ten_stamps', 1),
#  ('ten_stamps_equals', 1),
#  ('stamps_equals_free', 1),
#  ('equals_free_coffee', 1),
#  ('free_coffee_breakfast', 1),
#  ('coffee_breakfast_served', 1),
#  ('breakfast_served_am', 1),
#  ('served_am_eat', 1),
#  ('am_eat_coral', 1),
#  ('eat_coral_tree', 1),
#  ('coral_tree_nearly', 1),
#  ('tree_nearly_every', 1),
#  ('nearly_every_day', 1),
#  ('every_day_another', 1),
#  ('day_another_reviewer', 1),
#  ('another_reviewer_suggested', 1),
#  ('reviewer_suggested_much', 1),
#  ('suggested_much_regulars', 1),
#  ('much_regulars_place', 1),
#  ('regulars_place_one', 1),
#  ('place_one_know', 1),
#  ('one_know_system', 1),
#  ('know_system_frustrating', 1),
#  ('system_frustrating_newbie', 1),
#  ('frustrating_newbie_regulars', 1),
#  ('newbie_regulars_anyway', 1),
#  ('regulars_anyway_considering', 1),
#  ('anyway_considering_challenge', 1),
#  ('considering_challenge_fresh', 1),
#  ('challenge_fresh_food', 1),
#  ('fresh_food_campus', 1),
#  ('food_campus_coral', 1),
#  ('campus_coral_tree', 1),
#  ('coral_tree_nice', 1),
#  ('tree_nice_job', 1),
#  ('nice_job_basically', 1),
#  ('job_basically_one', 1),
#  ('basically_one_go', 1),
#  ('one_go_ucen', 1),
#  ('go_ucen_different', 1),
#  ('ucen_different_fast', 1),
#  ('different_fast_food', 1),
#  ('fast_food_joints', 1),
#  ('food_joints_deli', 1),
#  ('joints_deli_salad', 1),
#  ('deli_salad_bar', 1),
#  ('salad_bar_engineering', 1),
#  ('bar_engineering_cafeteria', 1),
#  ('engineering_cafeteria_style', 1),
#  ('cafeteria_style_one', 1),
#  ('style_one_go', 1),
#  ('one_go_arbor', 1),
#  ('go_arbor_lot', 1),
#  ('arbor_lot_takeaway', 1),
#  ('lot_takeaway_sandwiches', 1),
#  ('takeaway_sandwiches_or', 1),
#  ('sandwiches_or_stands', 1),
#  ('or_stands_outside', 1),
#  ('stands_outside_arbor', 1),
#  ('outside_arbor_pretzels', 1),
#  ('arbor_pretzels_hotdogs', 1),
#  ('pretzels_hotdogs_burritos', 1),
#  ('hotdogs_burritos_pizza', 1),
#  ('burritos_pizza_one', 1),
#  ('pizza_one_go', 1),
#  ('one_go_coral', 1),
#  ('go_coral_tree', 1),
#  ('coral_tree_coral', 1),
#  ('tree_coral_tree', 1),
#  ('coral_tree_premade', 1),
#  ('tree_premade_sandwiches', 1),
#  ('premade_sandwiches_salads', 1),
#  ('sandwiches_salads_bad', 1),
#  ('salads_bad_affordable', 1),
#  ('bad_affordable_like', 1),
#  ('affordable_like_california', 1),
#  ('like_california_veggie', 1),
#  ('california_veggie_also', 1),
#  ('veggie_also_snacks', 1),
#  ('also_snacks_like', 1),
#  ('snacks_like_veggies', 1),
#  ('like_veggies_fruit', 1),
#  ('veggies_fruit_coral', 1),
#  ('fruit_coral_tree', 1),
#  ('coral_tree_also', 1),
#  ('tree_also_pretty', 1),
#  ('pretty_good_grill', 1),
#  ('good_grill_burritos', 1),
#  ('grill_burritos_burgers', 1),
#  ('burritos_burgers_etc', 1),
#  ('burgers_etc_well', 1),
#  ('etc_well_pitas', 1),
#  ('well_pitas_soups', 1),
#  ('pitas_soups_also', 1),
#  ('soups_also_pastries', 1),
#  ('also_pastries_bagels', 1),
#  ('pastries_bagels_fresh', 1),
#  ('bagels_fresh_fruit', 1),
#  ('fresh_fruit_also', 1),
#  ('fruit_also_coffee', 1),
#  ('also_coffee_espresso', 1),
#  ('coffee_espresso_drinks', 1),
#  ('espresso_drinks_service', 1),
#  ('drinks_service_slow', 1),
#  ('service_slow_fast', 1),
#  ('slow_fast_either', 1),
#  ('fast_either_especially', 1),
#  ('either_especially_lunch', 1),
#  ('especially_lunch_time', 1),
#  ('lunch_time_coming', 1),
#  ('time_coming_right', 1),
#  ('coming_right_right', 1),
#  ('right_right_noon', 1),
#  ('right_noon_hour', 1),
#  ('noon_hour_good', 1),
#  ('hour_good_idea', 1),
#  ('good_idea_although', 1),
#  ('idea_although_another', 1),
#  ('although_another_reviewer', 1),
#  ('another_reviewer_mentioned', 1),
#  ('reviewer_mentioned_frequently', 1),
#  ('mentioned_frequently_run', 1),
#  ('frequently_run_primary', 1),
#  ('run_primary_ingredients', 1),
#  ('primary_ingredients_but', 1),
#  ('ingredients_but_good', 1),
#  ('but_good_location', 1),
#  ('good_location_affordable', 1),
#  ('location_affordable_reasonably', 1),
#  ('affordable_reasonably_fresh', 1),
#  ('reasonably_fresh_is', 1),
#  ('fresh_is_so', 1),
#  ('is_so_im', 1),
#  ('so_im_really', 1),
#  ('im_really_badly', 1),
#  ('really_badly_allergic', 1),
#  ('badly_allergic_dairy', 1),
#  ('allergic_dairy_lactose', 1),
#  ('dairy_lactose_intolerant', 1),
#  ('lactose_intolerant_specified', 1),
#  ('intolerant_specified_ordered', 1),
#  ('specified_ordered_burger', 1),
#  ('ordered_burger_there', 1),
#  ('burger_there_asked', 1),
#  ('there_asked_cheese', 1),
#  ('asked_cheese_last', 1),
#  ('cheese_last_burger', 1),
#  ('last_burger_stock', 1),
#  ('burger_stock_day', 1),
#  ('stock_day_put', 1),
#  ('day_put_cheese', 1),
#  ('put_cheese_justified', 1),
#  ('cheese_justified_saying', 1),
#  ('justified_saying_this', 1),
#  ('saying_this_order', 1),
#  ('this_order_complicated', 1),
#  ('order_complicated_partner', 1),
#  ('complicated_partner_ordered', 1),
#  ('partner_ordered_burgers', 1),
#  ('ordered_burgers_supposed', 1),
#  ('burgers_supposed_bacon', 1),
#  ('supposed_bacon_them', 1),
#  ('bacon_them_price', 1),
#  ('them_price_tag', 1),
#  ('price_tag_match', 1),
#  ('tag_match_added', 1),
#  ('match_added_ingredient', 1),
#  ('added_ingredient_bacon', 1),
#  ('ingredient_bacon_offer', 1),
#  ('bacon_offer_anything', 1),
#  ('offer_anything_experience', 1),
#  ('anything_experience_except', 1),
#  ('experience_except_burger', 1),
#  ('except_burger_fixed', 1),
#  ('burger_fixed_cover', 1),
#  ('fixed_cover_cost', 1),
#  ('cover_cost_meal', 1),
#  ('cost_meal_peanut', 1),
#  ('meal_peanut_case', 1),
#  ('peanut_case_someone', 1),
#  ('case_someone_couldve', 1),
#  ('someone_couldve_died', 1),
#  ('couldve_died_ordered', 1),
#  ('died_ordered_vegetable', 1),
#  ('ordered_vegetable_stir', 1),
#  ('vegetable_stir_fry', 1),
#  ('stir_fry_contained', 1),
#  ('fry_contained_onions', 1),
#  ('contained_onions_carrots', 1),
#  ('onions_carrots_onions', 1),
#  ('carrots_onions_broccoli', 1),
#  ('onions_broccoli_onions', 1),
#  ('broccoli_onions_rice', 1),
#  ('onions_rice_onions', 1),
#  ('rice_onions_seriously', 1),
#  ('onions_seriously_got', 1),
#  ('seriously_got_least', 1),
#  ('got_least_entire', 1),
#  ('least_entire_onion', 1),
#  ('entire_onion_think', 1),
#  ('onion_think_veggies', 1),
#  ('think_veggies_worked', 1),
#  ('veggies_worked_alone', 1),
#  ('worked_alone_rest', 1),
#  ('alone_rest_day', 1),
#  ('rest_day_need', 1),
#  ('day_need_reminder', 1),
#  ('need_reminder_health', 1),
#  ('reminder_health_code', 1),
#  ('health_code_information', 1),
#  ('code_information_saw', 1),
#  ('information_saw_worker', 1),
#  ('saw_worker_take', 1),
#  ('worker_take_trash', 1),
#  ('take_trash_go', 1),
#  ('trash_go_help', 1),
#  ('go_help_run', 1),
#  ('help_run_food', 1),
#  ('run_food_take', 1),
#  ('food_take_orders', 1),
#  ('take_orders_without', 1),
#  ('orders_without_changing', 1),
#  ('changing_gloves_washing', 1),
#  ('gloves_washing_hands', 1),
#  ('washing_hands_beautiful', 1),
#  ('hands_beautiful_uc', 1),
#  ('beautiful_uc_santa', 1),
#  ('uc_santa_barbara', 1),
#  ('santa_barbara_campus', 1),
#  ('barbara_campus_mood', 1),
#  ('campus_mood_head', 1),
#  ('mood_head_food', 1),
#  ('head_food_court', 1),
#  ('food_court_get', 1),
#  ('court_get_lost', 1),
#  ('get_lost_crowdescape', 1),
#  ('lost_crowdescape_quiet', 1),
#  ('crowdescape_quiet_cozy', 1),
#  ('quiet_cozy_coral', 1),
#  ('cozy_coral_tree', 1),
#  ('tree_cafe_little', 1),
#  ('cafe_little_towards', 1),
#  ('little_towards_students', 1),
#  ('towards_students_affair', 1),
#  ('students_affair_building', 1),
#  ('affair_building_enormous', 1),
#  ('building_enormous_campbell', 1),
#  ('enormous_campbell_hall', 1),
#  ('campbell_hall_nestled', 1),
#  ('hall_nestled_lovely', 1),
#  ('nestled_lovely_red', 1),
#  ('lovely_red_coral', 1),
#  ('red_coral_trees', 1),
#  ('coral_trees_sell', 1),
#  ('trees_sell_typical', 1),
#  ('sell_typical_coffees', 1),
#  ('typical_coffees_iced', 1),
#  ('coffees_iced_drinks', 1),
#  ('iced_drinks_well', 1),
#  ('drinks_well_hot', 1),
#  ('well_hot_breakfastbaked', 1),
#  ('hot_breakfastbaked_goods', 1),
#  ('breakfastbaked_goods_hot', 1),
#  ('goods_hot_lunch', 1),
#  ('hot_lunch_soups', 1),
#  ('lunch_soups_sandwichs', 1),
#  ('soups_sandwichs_salads', 1),
#  ('sandwichs_salads_nice', 1),
#  ('salads_nice_getaway', 1),
#  ('nice_getaway_within', 1),
#  ('getaway_within_busy', 1),
#  ('within_busy_school', 1),
#  ('busy_school_ate', 1),
#  ('school_ate_coral', 1),
#  ('ate_coral_tree', 1),
#  ('tree_cafe_today', 1),
#  ('cafe_today_really', 1),
#  ('today_really_good', 1),
#  ('really_good_got', 1),
#  ('good_got_western', 1),
#  ('got_western_burger', 1),
#  ('western_burger_bacon', 1),
#  ('burger_bacon_sub', 1),
#  ('bacon_sub_veggie', 1),
#  ('sub_veggie_patty', 1),
#  ('veggie_patty_made', 1),
#  ('patty_made_combo', 1),
#  ('made_combo_cheaper', 1),
#  ('combo_cheaper_say', 1),
#  ('cheaper_say_ordering', 1),
#  ('say_ordering_habit', 1),
#  ('ordering_habit_really', 1),
#  ('habit_really_good', 1),
#  ('really_good_boyfriend', 1),
#  ('good_boyfriend_got', 1),
#  ('boyfriend_got_chicken', 1),
#  ('got_chicken_burrito', 1),
#  ('chicken_burrito_chicken', 1),
#  ('burrito_chicken_kind', 1),
#  ('chicken_kind_pink', 1),
#  ('kind_pink_really', 1),
#  ('pink_really_friendly', 1),
#  ('really_friendly_made', 1),
#  ('friendly_made_expensive', 1),
#  ('made_expensive_steak', 1),
#  ('expensive_steak_burrito', 1),
#  ('steak_burrito_extra', 1),
#  ('burrito_extra_charge', 1),
#  ('extra_charge_going', 1),
#  ('charge_going_back', 1),
#  ('back_again_perfect', 1),
#  ('again_perfect_spot', 1),
#  ('perfect_spot_lunch', 1),
#  ('spot_lunch_coffee', 1),
#  ('lunch_coffee_break', 1),
#  ('coffee_break_campus', 1),
#  ('break_campus_sandwiches', 1),
#  ('campus_sandwiches_fries', 1),
#  ('sandwiches_fries_delicious', 1),
#  ('fries_delicious_also', 1),
#  ('delicious_also_usual', 1),
#  ('also_usual_snacks', 1),
#  ('usual_snacks_coffee', 1),
#  ('snacks_coffee_menu', 1),
#  ('coffee_menu_sell', 1),
#  ('menu_sell_arbor', 1),
#  ('sell_arbor_even', 1),
#  ('arbor_even_bring', 1),
#  ('even_bring_lunch', 1),
#  ('bring_lunch_take', 1),
#  ('lunch_take_seat', 1),
#  ('take_seat_wherever', 1),
#  ('seat_wherever_plenty', 1),
#  ('wherever_plenty_outdoor', 1),
#  ('plenty_outdoor_seating', 1),
#  ('outdoor_seating_yeah', 1),
#  ('seating_yeah_nope', 1),
#  ('yeah_nope_really', 1),
#  ('nope_really_like', 1),
#  ('really_like_fact', 1),
#  ('like_fact_one', 1),
#  ('fact_one_knows', 1),
#  ('one_knows_make', 1),
#  ('knows_make_decent', 1),
#  ('make_decent_cup', 1),
#  ('decent_cup_coffee', 1),
#  ('cup_coffee_even', 1),
#  ('coffee_even_ended', 1),
#  ('even_ended_switching', 1),
#  ('ended_switching_vanilla', 1),
#  ('switching_vanilla_chai', 1),
#  ('vanilla_chai_powder', 1),
#  ('chai_powder_used', 1),
#  ...]

# %% [markdown]
# ### Fast Food

# %%
Fast_Food = business_df[business_df.Type=='Fast Food']
Fast_Food_review = review1[review1.business_id.isin(Fast_Food.business_id.values)]
Fast_Food_review["text"] = Fast_Food_review["text"].str.lower()
Fast_Food_review['text'] = Fast_Food_review['text'].apply(lambda text: cleaning_stopwords(text))
Fast_Food_review['text']= Fast_Food_review['text'].apply(lambda x: cleaning_punctuations(x))
Fast_Food_review['text'] = Fast_Food_review['text'].apply(lambda x: cleaning_repeating_char(x))
Fast_Food_review['text'] = Fast_Food_review['text'].apply(lambda x: cleaning_URLs(x))
Fast_Food_review['text'] = Fast_Food_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Fast_Food=Fast_Food[Fast_Food.stars<3.5]
bad_Fast_Food_review = Fast_Food_review[Fast_Food_review.business_id.isin(bad_Fast_Food.business_id.values)]
bad_Fast_Food_review_text = bad_Fast_Food_review.text.str.cat(sep = " ")
bad_Fast_Food_tokens = word_tokenize(bad_Fast_Food_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_bad_Fast_Food = ["_".join(item) for item in nltk.bigrams(bad_Fast_Food_tokens)]
trigrams_list_bad_Fast_Food = ["_".join(item) for item in nltk.trigrams(bad_Fast_Food_tokens)]
FreqDist(bigrams_list_bad_Fast_Food).most_common()
# FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('fast_food', 106),
#  ('taco_bell', 97),
#  ('fish_chips', 97),
#  ('customer_service', 79),
#  ('panda_express', 61),
#  ('santa_barbara', 58),
#  ('drive_thru', 55),
#  ('orange_chicken', 37),
#  ('every_time', 30),
#  ('food_good', 28),
#  ('ive_ever', 28),
#  ('char_west', 28),
#  ('clam_chowder', 27),
#  ('ice_cream', 26),
#  ('jack_box', 26),
#  ('carls_jr', 26),
#  ('chicken_sandwich', 26),
#  ('come_back', 25),
#  ('coming_back', 23),
#  ('get_food', 22),
#  ('first_time', 21),
#  ('parking_lot', 20),
#  ('last_time', 20),
#  ('even_though', 20),
#  ('go_back', 20),
#  ('teriyaki_chicken', 19),
#  ('really_good', 19),
#  ('time_go', 17),
#  ('fried_chicken', 16),
#  ('quality_food', 16),
#  ('fish_n', 16),
#  ('chow_mein', 15),
#  ('long_time', 15),
#  ('food_service', 15),
#  ('food_poisoning', 15),
#  ('big_mac', 15),
#  ('never_come', 15),
#  ('n_chips', 15),
#  ('dining_room', 15),
#  ('one_time', 14),
#  ('closing_time', 14),
#  ('feel_like', 14),
#  ('chinese_food', 14),
#  ('im_sure', 14),
#  ('get_order', 14),
#  ('good_food', 14),
#  ('staff_friendly', 14),
#  ('good_service', 14),
#  ('went_back', 13),
#  ('took_order', 13),
#  ('french_fries', 13),
#  ('stay_away', 13),
#  ('next_time', 12),
#  ('got_home', 12),
#  ('never_go', 12),
#  ('make_sure', 12),
#  ('tasted_like', 12),
#  ('take_order', 12),
#  ('chicken_nuggets', 12),
#  ('tartar_sauce', 12),
#  ('ive_never', 11),
#  ('taste_like', 11),
#  ('taking_order', 11),
#  ('pretty_much', 11),
#  ('gave_us', 11),
#  ('felt_like', 11),
#  ('time_come', 10),
#  ('one_person', 10),
#  ('place_eat', 10),
#  ('always_get', 10),
#  ('mashed_potatoes', 10),
#  ('thank_you', 10),
#  ('piece_chicken', 10),
#  ('ever_had', 10),
#  ('food_restaurant', 10),
#  ('service_good', 10),
#  ('could_give', 10),
#  ('friendly_staff', 10),
#  ('back_location', 10),
#  ('horrible_service', 10),
#  ('time_ive', 9),
#  ('love_panda', 9),
#  ('behind_counter', 9),
#  ('fried_rice', 9),
#  ('look_like', 9),
#  ('ever_to', 9),
#  ('looked_like', 9),
#  ('last_night', 9),
#  ('spicy_chicken', 9),
#  ('would_like', 9),
#  ('give_stars', 9),
#  ('order_right', 9),
#  ('back_again', 9),
#  ('great_food', 9),
#  ('late_night', 9),
#  ('burger_fries', 9),
#  ('drive_through', 9),
#  ('highly_recommend', 9),
#  ('stearns_wharf', 9),
#  ('staff_nice', 8),
#  ('food_fresh', 8),
#  ('credit_card', 8),
#  ('decided_go', 8),
#  ('service_ever', 8),
#  ('star_rating', 8),
#  ('looks_like', 8),
#  ('bad_reviews', 8),
#  ('one_star', 8),
#  ('go_here', 8),
#  ('mc_donalds', 8),
#  ('much_better', 8),
#  ('extremely_rude', 8),
#  ('food_quality', 8),
#  ('paid_for', 8),
#  ('order_food', 8),
#  ('bad_experience', 8),
#  ('food_always', 8),
#  ('sour_cream', 8),
#  ('curly_fries', 8),
#  ('food_places', 7),
#  ('good_thing', 7),
#  ('long_line', 7),
#  ('hot_sauce', 7),
#  ('sweet_sour', 7),
#  ('service_always', 7),
#  ('time_got', 7),
#  ('food_go', 7),
#  ('go_place', 7),
#  ('walnut_shrimp', 7),
#  ('taking_orders', 7),
#  ('came_back', 7),
#  ('way_back', 7),
#  ('cash_register', 7),
#  ('horrible_customer', 7),
#  ('people_working', 7),
#  ('seems_like', 7),
#  ('give_us', 7),
#  ('online_order', 7),
#  ('food_place', 7),
#  ('manager_rude', 7),
#  ('restaurant_clean', 7),
#  ('half_hour', 7),
#  ('open_hours', 7),
#  ('food_chain', 7),
#  ('id_rather', 7),
#  ('got_order', 7),
#  ('one_best', 7),
#  ('wheat_germ', 7),
#  ('germ_pancakes', 7),
#  ('great_place', 7),
#  ('pretty_good', 7),
#  ('potato_chips', 7),
#  ('good_fish', 7),
#  ('food_get', 7),
#  ('order_number', 7),
#  ('food_also', 7),
#  ('love_taco', 7),
#  ('great_customer', 6),
#  ('time_went', 6),
#  ('something_else', 6),
#  ('pick_up', 6),
#  ('beef_broccoli', 6),
#  ('many_times', 6),
#  ('around_pm', 6),
#  ('people_front', 6),
#  ('said_would', 6),
#  ('couple_times', 6),
#  ('honey_walnut', 6),
#  ('food_decent', 6),
#  ('always_friendly', 6),
#  ('hard_get', 6),
#  ('minutes_closing', 6),
#  ('spring_rolls', 6),
#  ('writing_review', 6),
#  ('ordered_two', 6),
#  ('three_times', 6),
#  ('one_small', 6),
#  ('eat_here', 6),
#  ('place_clean', 6),
#  ('get_it', 6),
#  ('another_one', 6),
#  ('one_worst', 6),
#  ('save_money', 6),
#  ('water_cup', 6),
#  ('still_waiting', 6),
#  ('worst_panda', 6),
#  ('would_give', 6),
#  ('recommend_place', 6),
#  ('kfc_location', 6),
#  ('can_not', 6),
#  ('worst_customer', 6),
#  ('forgot_give', 6),
#  ('service_food', 6),
#  ('got_food', 6),
#  ('angus_steak', 6),
#  ('year_old', 6),
#  ('open_pm', 6),
#  ('like_that', 6),
#  ('tastes_like', 6),
#  ('going_back', 6),
#  ('food_fast', 6),
#  ('cream_cheese', 6),
#  ('said_no', 6),
#  ('ever_again', 6),
#  ('stars_would', 6),
#  ('soda_machine', 6),
#  ('cream_machine', 6),
#  ('worst_mcdonalds', 6),
#  ('state_street', 6),
#  ('food_made', 6),
#  ('worst_experience', 6),
#  ('breakfast_sandwich', 6),
#  ('waited_minutes', 6),
#  ('come_again', 6),
#  ('food_paid', 6),
#  ('money_back', 6),
#  ('outdoor_seating', 6),
#  ('fish_tacos', 6),
#  ('great_view', 6),
#  ('east_beach', 6),
#  ('beach_grill', 6),
#  ('ordered_fish', 6),
#  ('fish_good', 6),
#  ('quick_bite', 6),
#  ('somewhere_else', 6),
#  ('never_coming', 6),
#  ('next_door', 6),
#  ('come_here', 6),
#  ('food_even', 6),
#  ('fries_cold', 6),
#  ('seem_like', 6),
#  ('taco_bells', 6),
#  ('food_never', 6),
#  ('service_quick', 5),
#  ('time_order', 5),
#  ('order_complete', 5),
#  ('panda_location', 5),
#  ('staff_always', 5),
#  ('line_door', 5),
#  ('people_waiting', 5),
#  ('waiting_line', 5),
#  ('time_food', 5),
#  ('white_rice', 5),
#  ('place_one', 5),
#  ('im_glad', 5),
#  ('goleta_location', 5),
#  ('nice_people', 5),
#  ('good_place', 5),
#  ('really_need', 5),
#  ('make_food', 5),
#  ('rice_chow', 5),
#  ('ive_seen', 5),
#  ('plenty_parking', 5),
#  ('would_expect', 5),
#  ('two_times', 5),
#  ('time_there', 5),
#  ('people_work', 5),
#  ('quick_lunch', 5),
#  ('get_really', 5),
#  ('slow_service', 5),
#  ('go_wrong', 5),
#  ('food_since', 5),
#  ('tried_get', 5),
#  ('go_location', 5),
#  ('location_again', 5),
#  ('minutes_later', 5),
#  ('waiting_mins', 5),
#  ('rude_employees', 5),
#  ('im_still', 5),
#  ('order_online', 5),
#  ('walked_out', 5),
#  ('young_man', 5),
#  ('eat_it', 5),
#  ('half_order', 5),
#  ('another_minutes', 5),
#  ('two_people', 5),
#  ('door_locked', 5),
#  ('food_amazing', 5),
#  ('people_like', 5),
#  ('good_one', 5),
#  ('needless_say', 5),
#  ('food_fine', 5),
#  ('place_could', 5),
#  ('like_it', 5),
#  ('like_this', 5),
#  ('employees_rude', 5),
#  ('placed_order', 5),
#  ('food_ready', 5),
#  ('friendly_helpful', 5),
#  ('one_day', 5),
#  ('avoid_location', 5),
#  ('zero_stars', 5),
#  ('food_food', 5),
#  ('food_went', 5),
#  ('went_get', 5),
#  ('cream_cone', 5),
#  ('wrong_order', 5),
#  ('super_nice', 5),
#  ('wish_could', 5),
#  ('diet_coke', 5),
#  ('order_breakfast', 5),
#  ('iced_coffee', 5),
#  ('think_ill', 5),
#  ('took_forever', 5),
#  ('placing_order', 5),
#  ('go_get', 5),
#  ('upper_state', 5),
#  ('long_lines', 5),
#  ('golden_arches', 5),
#  ('place_order', 5),
#  ('soft_serve', 5),
#  ('food_came', 5),
#  ('go_one', 5),
#  ('whenever_go', 5),
#  ('never_ever', 5),
#  ('seemed_like', 5),
#  ('ever_seen', 5),
#  ('stopped_way', 5),
#  ('took_back', 5),
#  ('never_going', 5),
#  ('eating_here', 5),
#  ('mcdonalds_ever', 5),
#  ('bread_bowl', 5),
#  ('eat_food', 5),
#  ('fried_fish', 5),
#  ('chips_fish', 5),
#  ('fresh_well', 5),
#  ('food_great', 5),
#  ('get_quick', 5),
#  ('got_fish', 5),
#  ('barbara_omelette', 5),
#  ('gordo_burger', 5),
#  ('hot_chocolate', 5),
#  ('friendly_service', 5),
#  ('fries_good', 5),
#  ('order_wrong', 5),
#  ('wasting_time', 5),
#  ('ordered_food', 5),
#  ('gave_attitude', 5),
#  ('also_ordered', 5),
#  ('us_wait', 5),
#  ('fast_service', 5),
#  ('waiting_order', 5),
#  ('bad_experiences', 5),
#  ('always_clean', 5),
#  ('rolled_eyes', 5),
#  ('express_food', 5),
#  ('lo_behold', 5),
#  ('service_great', 5),
#  ('took_minutes', 5),
#  ('shopping_center', 5),
#  ('jack_crack', 5),
#  ('say_least', 4),
#  ('years_ago', 4),
#  ('back_good', 4),
#  ('would_take', 4),
#  ('helping_customers', 4),
#  ('good_experience', 4),
#  ('see_many', 4),
#  ('never_seen', 4),
#  ('even_bother', 4),
#  ('people_behind', 4),
#  ('little_bit', 4),
#  ('calle_real', 4),
#  ('chicken_mashed', 4),
#  ('grilled_chicken', 4),
#  ('n_cheese', 4),
#  ('strip_mall', 4),
#  ('super_busy', 4),
#  ('half_way', 4),
#  ('wait_minutes', 4),
#  ('chicken_breast', 4),
#  ('employees_friendly', 4),
#  ('food_still', 4),
#  ('nice_service', 4),
#  ('home_opened', 4),
#  ('nothing_special', 4),
#  ('love_place', 4),
#  ('going_take', 4),
#  ('take_out', 4),
#  ('out_one', 4),
#  ('good_hard', 4),
#  ('teriyaki_sauce', 4),
#  ('waited_long', 4),
#  ('extra_crispy', 4),
#  ('hire_people', 4),
#  ('help_you', 4),
#  ('ordered_online', 4),
#  ('place_closed', 4),
#  ('worst_service', 4),
#  ('order_drive', 4),
#  ('far_worst', 4),
#  ('also_gave', 4),
#  ('another_customer', 4),
#  ('service_experience', 4),
#  ('service_employees', 4),
#  ('usually_like', 4),
#  ('asked_order', 4),
#  ('walked_away', 4),
#  ('manager_said', 4),
#  ('long_wait', 4),
#  ('fried_food', 4),
#  ('service_ive', 4),
#  ('min_get', 4),
#  ('phone_number', 4),
#  ('make_feel', 4),
#  ('made_feel', 4),
#  ('friendly_food', 4),
#  ('back_there', 4),
#  ('food_restaurants', 4),
#  ('could_go', 4),
#  ('go_panda', 4),
#  ('always_good', 4),
#  ('like_location', 4),
#  ('actually_open', 4),
#  ('doors_locked', 4),
#  ('buy_food', 4),
#  ('said_close', 4),
#  ('keep_coming', 4),
#  ('also_food', 4),
#  ('right_now', 4),
#  ('thought_would', 4),
#  ('good_idea', 4),
#  ('order_asked', 4),
#  ('waste_time', 4),
#  ('paseo_nuevo', 4),
#  ('food_pretty', 4),
#  ('start_saying', 4),
#  ('back_yes', 4),
#  ('said_can', 4),
#  ('like_me', 4),
#  ('staff_rude', 4),
#  ('poor_quality', 4),
#  ('come_want', 4),
#  ('best_ive', 4),
#  ('also_got', 4),
#  ('try_one', 4),
#  ('took_one', 4),
#  ('good_job', 4),
#  ('asked_manager', 4),
#  ('several_times', 4),
#  ('every_single', 4),
#  ('wanted_something', 4),
#  ('overall_great', 4),
#  ('two_stars', 4),
#  ('use_restroom', 4),
#  ('sausage_mcmuffin', 4),
#  ('ignored_me', 4),
#  ('hash_browns', 4),
#  ('nd_time', 4),
#  ('food_expect', 4),
#  ('location_mcdonalds', 4),
#  ('fresh_tasty', 4),
#  ('tasted_fine', 4),
#  ('egg_mcmuffin', 4),
#  ('wait_time', 4),
#  ('number_called', 4),
#  ('order_get', 4),
#  ('im_like', 4),
#  ('good_day', 4),
#  ('decent_amount', 4),
#  ('something_quick', 4),
#  ('cheese_burger', 4),
#  ('food_cold', 4),
#  ('like_food', 4),
#  ('sweet_tea', 4),
#  ('fresh_hot', 4),
#  ('ive_coming', 4),
#  ('baja_blast', 4),
#  ('finally_get', 4),
#  ('order_person', 4),
#  ('bad_attitude', 4),
#  ('opened_door', 4),
#  ('better_food', 4),
#  ('food_served', 4),
#  ('crispy_chicken', 4),
#  ('chicken_tenders', 4),
#  ('place_again', 4),
#  ('super_friendly', 4),
#  ('excellent_service', 4),
#  ('homeless_people', 4),
#  ('three_dollars', 4),
#  ('ever_go', 4),
#  ('like_better', 4),
#  ('order_one', 4),
#  ('ive_tried', 4),
#  ('fuck_place', 4),
#  ('monday_night', 4),
#  ('fries_fresh', 4),
#  ('still_good', 4),
#  ('order_correct', 4),
#  ('chips_good', 4),
#  ('one_word', 4),
#  ('first_place', 4),
#  ('place_right', 4),
#  ('right_pier', 4),
#  ('shrimp_chips', 4),
#  ('could_even', 4),
#  ('side_note', 4),
#  ('five_minutes', 4),
#  ('ive_eaten', 4),
#  ('blueberry_wheat', 4),
#  ('best_thing', 4),
#  ('anything_like', 4),
#  ('rather_go', 4),
#  ('dipping_sauce', 4),
#  ('tasted_fishy', 4),
#  ('little_pricey', 4),
#  ('view_ocean', 4),
#  ('sunday_night', 4),
#  ('place_get', 4),
#  ('tarter_sauce', 4),
#  ('food_got', 4),
#  ('right_next', 4),
#  ('chips_ive', 4),
#  ('onion_rings', 4),
#  ('worst_part', 4),
#  ('inside_restaurant', 4),
#  ('coming_again', 4),
#  ('sure_get', 4),
#  ('fries_burger', 4),
#  ('food_really', 4),
#  ('go_somewhere', 4),
#  ('yelp_review', 4),
#  ('good_amount', 4),
#  ('care_less', 4),
#  ('poor_service', 4),
#  ('would_rather', 4),
#  ('place_sucks', 4),
#  ('really_really', 4),
#  ('nice_little', 4),
#  ('decided_give', 4),
#  ('wait_another', 4),
#  ('second_time', 4),
#  ('said_i', 4),
#  ('service_excellent', 4),
#  ('give_try', 4),
#  ('want_eat', 4),
#  ('dining_area', 4),
#  ('really_fast', 4),
#  ('line_order', 4),
#  ('looking_place', 4),
#  ('go_there', 4),
#  ('panda_ever', 4),
#  ('beijing_beef', 4),
#  ('coming_location', 4),
#  ('really_bad', 4),
#  ('ask_wanted', 4),
#  ('good_fast', 4),
#  ('im_eating', 4),
#  ('rush_hour', 4),
#  ('like_going', 4),
#  ('big_deal', 4),
#  ('im_always', 4),
#  ('say_something', 4),
#  ('mcdonalds_get', 4),
#  ('also_asked', 4),
#  ('asked_refund', 4),
#  ('like_taco', 4),
#  ('chicken_quesadilla', 4),
#  ('taco_got', 4),
#  ('high_school', 4),
#  ('one_thing', 4),
#  ('speak_english', 4),
#  ('give_place', 4),
#  ('thru_window', 4),
#  ('nacho_cheese', 4),
#  ('nice_place', 4),
#  ('food_joint', 4),
#  ('got_charged', 4),
#  ('much_nicer', 4),
#  ('give_receipt', 4),
#  ('wan_na', 4),
#  ('right_away', 4),
#  ('working_drive', 4),
#  ('convenient_fast', 4),
#  ('never_substitute', 4),
#  ('substitute_healthy', 4),
#  ('healthy_home', 4),
#  ('home_meals', 4),
#  ('ive_gone', 4),
#  ('red_sanitation', 4),
#  ('sanitation_bucket', 4),
#  ('nacho_fries', 4),
#  ('beyond_burger', 4),
#  ('cheese_sauce', 4),
#  ('minutes_get', 3),
#  ('could_make', 3),
#  ('broccoli_beef', 3),
#  ('everything_else', 3),
#  ('wait_line', 3),
#  ('serving_food', 3),
#  ('long_would', 3),
#  ('two_hours', 3),
#  ('hours_closing', 3),
#  ('really_clean', 3),
#  ('eat_inside', 3),
#  ('experience_ordering', 3),
#  ('ordering_online', 3),
#  ('ive_lived', 3),
#  ('small_portion', 3),
#  ('pieces_chicken', 3),
#  ('chicken_never', 3),
#  ('wish_would', 3),
#  ('location_clean', 3),
#  ('even_put', 3),
#  ('pretty_nice', 3),
#  ('get_go', 3),
#  ('sitting_long', 3),
#  ('person_working', 3),
#  ('working_food', 3),
#  ('back_forth', 3),
#  ('go_kfc', 3),
#  ('im_fan', 3),
#  ('hungry_ordered', 3),
#  ('chow_mien', 3),
#  ('would_wait', 3),
#  ('restaurant_actually', 3),
#  ('service_slow', 3),
#  ('lunch_rush', 3),
#  ('staff_food', 3),
#  ('kfc_ive', 3),
#  ('sweet_fire', 3),
#  ('fire_chicken', 3),
#  ('peak_hours', 3),
#  ('great_quick', 3),
#  ('get_line', 3),
#  ('one_employees', 3),
#  ('definitely_come', 3),
#  ('gave_chicken', 3),
#  ('me_im', 3),
#  ('experience_panda', 3),
#  ('chow_main', 3),
#  ('want_much', 3),
#  ('like_always', 3),
#  ('went_tonight', 3),
#  ('pm_got', 3),
#  ('orders_even', 3),
#  ('change_order', 3),
#  ('two_items', 3),
#  ('last_two', 3),
#  ('said_oh', 3),
#  ('really_wanted', 3),
#  ('want_get', 3),
#  ('get_back', 3),
#  ('back_car', 3),
#  ('express_again', 3),
#  ('bad_review', 3),
#  ('always_check', 3),
#  ('check_order', 3),
#  ('order_store', 3),
#  ('one_occasion', 3),
#  ('dishes_kept', 3),
#  ('ready_go', 3),
#  ('sour_sauce', 3),
#  ('cant_go', 3),
#  ('mushroom_chicken', 3),
#  ('helpful_food', 3),
#  ('overall_good', 3),
#  ('im_trying', 3),
#  ('also_extremely', 3),
#  ('uber_eats', 3),
#  ('fresh_food', 3),
#  ('stay_business', 3),
#  ('places_eat', 3),
#  ('restaurant_tables', 3),
#  ('know_want', 3),
#  ('employees_time', 3),
#  ('location_pretty', 3),
#  ('asked_wanted', 3),
#  ('next_day', 3),
#  ('already_made', 3),
#  ('couple_years', 3),
#  ('chicken_combo', 3),
#  ('day_went', 3),
#  ('order_chicken', 3),
#  ('going_get', 3),
#  ('small_piece', 3),
#  ('food_going', 3),
#  ('going_make', 3),
#  ('customers_waiting', 3),
#  ('waiting_even', 3),
#  ('mins_get', 3),
#  ('ever_know', 3),
#  ('throw_away', 3),
#  ('multiple_times', 3),
#  ('management_needs', 3),
#  ('egg_rolls', 3),
#  ('it_would', 3),
#  ('service_bad', 3),
#  ('place_horrible', 3),
#  ('know_get', 3),
#  ('place_usually', 3),
#  ('eat_panda', 3),
#  ('time_place', 3),
#  ('service_people', 3),
#  ('waiting_minutes', 3),
#  ('minutes_asked', 3),
#  ('man_working', 3),
#  ('top_off', 3),
#  ('comfort_food', 3),
#  ('food_im', 3),
#  ('always_order', 3),
#  ('usually_go', 3),
#  ('nice_really', 3),
#  ('sauce_ask', 3),
#  ('food_ever', 3),
#  ('chicken_tasted', 3),
#  ('like_fish', 3),
#  ('first_experience', 3),
#  ('ordered_double', 3),
#  ('fortune_cookie', 3),
#  ('fair_share', 3),
#  ('time_here', 3),
#  ('workers_nice', 3),
#  ('years_ive', 3),
#  ('care_customer', 3),
#  ('missing_half', 3),
#  ('back_get', 3),
#  ('food_sitting', 3),
#  ('family_meal', 3),
#  ('making_us', 3),
#  ('point_im', 3),
#  ('food_here', 3),
#  ('food_ordered', 3),
#  ('go_restaurant', 3),
#  ('never_eat', 3),
#  ('wanted_get', 3),
#  ('cant_use', 3),
#  ('steak_dish', 3),
#  ('young_lady', 3),
#  ('guy_took', 3),
#  ('friend_ordered', 3),
#  ('worker_said', 3),
#  ('line_food', 3),
#  ('location_many', 3),
#  ('favorite_part', 3),
#  ('left_food', 3),
#  ('rude_said', 3),
#  ('get_nice', 3),
#  ('back_food', 3),
#  ('back_employees', 3),
#  ('employees_always', 3),
#  ('andrew_litty', 3),
#  ('must_say', 3),
#  ('good_deal', 3),
#  ('drive_goleta', 3),
#  ('poor_excuse', 3),
#  ('cheese_rangoons', 3),
#  ('times_month', 3),
#  ('past_years', 3),
#  ('day_get', 3),
#  ('people_get', 3),
#  ('im_sorry', 3),
#  ('food_time', 3),
#  ('happy_service', 3),
#  ('definitely_coming', 3),
#  ('back_im', 3),
#  ('one_guy', 3),
#  ('treated_poorly', 3),
#  ('talk_manager', 3),
#  ('give_zero', 3),
#  ('portion_sizes', 3),
#  ('mcdonalds_experience', 3),
#  ('food_mcdonalds', 3),
#  ('old_school', 3),
#  ('mess_up', 3),
#  ('one_bite', 3),
#  ('better_one', 3),
#  ('market_place', 3),
#  ('drive_extra', 3),
#  ('mcdonalds_good', 3),
#  ('way_home', 3),
#  ('breakfast_day', 3),
#  ('breakfast_menu', 3),
#  ('mcdonalds_santa', 3),
#  ('four_days', 3),
#  ('five_star', 3),
#  ('get_window', 3),
#  ('single_time', 3),
#  ('negative_stars', 3),
#  ('mcdonalds_food', 3),
#  ('place_needs', 3),
#  ('like_could', 3),
#  ('no_problem', 3),
#  ('staff_courteous', 3),
#  ('double_cheeseburgers', 3),
#  ('chicken_nugget', 3),
#  ('quick_stop', 3),
#  ('super_clean', 3),
#  ('well_kept', 3),
#  ('one_employee', 3),
#  ('behind_us', 3),
#  ('eat_lot', 3),
#  ('sign_said', 3),
#  ('night_food', 3),
#  ('since_wanted', 3),
#  ('could_say', 3),
#  ('waited_line', 3),
#  ('avoid_place', 3),
#  ('made_fresh', 3),
#  ('also_like', 3),
#  ('coffee_place', 3),
#  ('mcdonalds_long', 3),
#  ('mac_sauce', 3),
#  ('location_ever', 3),
#  ('like_sitting', 3),
#  ('either_way', 3),
#  ('open_late', 3),
#  ('manager_asked', 3),
#  ('mcdonalds_fast', 3),
#  ('ever_come', 3),
#  ('go_mcdonalds', 3),
#  ('food_generally', 3),
#  ('food_expected', 3),
#  ('there_food', 3),
#  ('clean_well', 3),
#  ('absolutely_worst', 3),
#  ('mcdonalds_drive', 3),
#  ('anywhere_else', 3),
#  ('back_home', 3),
#  ('ice_tea', 3),
#  ('ordered_sausage', 3),
#  ('green_yellow', 3),
#  ('love_mcdonalds', 3),
#  ('minutes_waiting', 3),
#  ('order_im', 3),
#  ('spend_money', 3),
#  ('co_workers', 3),
#  ('paying_customer', 3),
#  ('menu_items', 3),
#  ('order_took', 3),
#  ('made_order', 3),
#  ('clean_restaurant', 3),
#  ('dave_petersen', 3),
#  ('said_nothing', 3),
#  ('ill_never', 3),
#  ('time_never', 3),
#  ('say_anything', 3),
#  ('trying_make', 3),
#  ('worth_it', 3),
#  ('person_taking', 3),
#  ('another_min', 3),
#  ('us_like', 3),
#  ('fountain_drink', 3),
#  ('location_always', 3),
#  ('issue_food', 3),
#  ('ask_sauces', 3),
#  ('still_took', 3),
#  ('mickey_ds', 3),
#  ('made_sure', 3),
#  ('best_customer', 3),
#  ('low_rating', 3),
#  ('large_fry', 3),
#  ('come_on', 3),
#  ('amount_fries', 3),
#  ('feel_place', 3),
#  ('ordered_breakfast', 3),
#  ('said_cant', 3),
#  ('go_ahead', 3),
#  ('get_out', 3),
#  ('tried_call', 3),
#  ('get_two', 3),
#  ('order_went', 3),
#  ('got_one', 3),
#  ('ever_too', 3),
#  ('ever_encountered', 3),
#  ('food_order', 3),
#  ('customers_service', 3),
#  ('even_got', 3),
#  ('go_elsewhere', 3),
#  ('one_favorite', 3),
#  ('food_given', 3),
#  ('chowder_bread', 3),
#  ('whole_thing', 3),
#  ('many_reviews', 3),
#  ('service_every', 3),
#  ('time_im', 3),
#  ('front_counter', 3),
#  ('eat_again', 3),
#  ('little_salt', 3),
#  ('chips_tasty', 3),
#  ('lunch_break', 3),
#  ('pretty_sure', 3),
#  ('wanted_sandwich', 3),
#  ('best_fish', 3),
#  ('order_fish', 3),
#  ('get_away', 3),
#  ('burger_good', 3),
#  ('good_fries', 3),
#  ('people_nice', 3),
#  ('posted_hours', 3),
#  ('time_happened', 3),
#  ('ive_had', 3),
#  ('every_day', 3),
#  ('ill_come', 3),
#  ('definitely_recommend', 3),
#  ('place_pier', 3),
#  ('better_places', 3),
#  ('thats_good', 3),
#  ('worst_fish', 3),
#  ('fishermans_platter', 3),
#  ('chips_fries', 3),
#  ('really_long', 3),
#  ('quality_fish', 3),
#  ('came_location', 3),
#  ('needs_get', 3),
#  ('get_employees', 3),
#  ('again_food', 3),
#  ('want_work', 3),
#  ('frozen_fish', 3),
#  ('fish_fries', 3),
#  ('must_try', 3),
#  ('probably_go', 3),
#  ('clean_tables', 3),
#  ('good_love', 3),
#  ('good_view', 3),
#  ('nice_view', 3),
#  ('way_much', 3),
#  ('rolling_eyes', 3),
#  ('came_late', 3),
#  ('go_fish', 3),
#  ('im_usually', 3),
#  ('pier_food', 3),
#  ('breakfast_santa', 3),
#  ('really_like', 3),
#  ('battered_fish', 3),
#  ('barely_edible', 3),
#  ('cheese_also', 3),
#  ('get_one', 3),
#  ('kind_place', 3),
#  ('barbara_wharf', 3),
#  ('another_restaurant', 3),
#  ('large_order', 3),
#  ('service_nice', 3),
#  ('nice_staff', 3),
#  ('view_pier', 3),
#  ('here_ordered', 3),
#  ('food_ive', 3),
#  ('enough_me', 3),
#  ('actually_potato', 3),
#  ('cocktail_sauce', 3),
#  ('chips_ok', 3),
#  ('burger_eat', 3),
#  ('place_grab', 3),
#  ('like_dirt', 3),
#  ('almost_every', 3),
#  ('bit_pricey', 3),
#  ('good_way', 3),
#  ('busy_day', 3),
#  ('items_menu', 3),
#  ('again_place', 3),
#  ('it_im', 3),
#  ('know_place', 3),
#  ('went_lunch', 3),
#  ('awful_place', 3),
#  ('would_given', 3),
#  ('tap_water', 3),
#  ('again_worst', 3),
#  ('good_quality', 3),
#  ('service_cashier', 3),
#  ('asked_cashier', 3),
#  ('experience_location', 3),
#  ('customers_like', 3),
#  ('pick_food', 3),
#  ('barbara_really', 3),
#  ('service_friendly', 3),
#  ('good_value', 3),
#  ('fish_fish', 3),
#  ('tri_tip', 3),
#  ('money_go', 3),
#  ('food_taste', 3),
#  ('reading_this', 3),
#  ('regular_fries', 3),
#  ('eat_breakfast', 3),
#  ('told_us', 3),
#  ('home_find', 3),
#  ('reviews_here', 3),
#  ('front_register', 3),
#  ('front_us', 3),
#  ('went_taco', 3),
#  ('pieces_fish', 3),
#  ('something_eat', 3),
#  ('another_place', 3),
#  ('service_super', 3),
#  ('fries_also', 3),
#  ('hours_later', 3),
#  ('treat_customer', 3),
#  ('moneys_worth', 3),
#  ('cant_beat', 3),
#  ('restaurant_one', 3),
#  ('well_im', 3),
#  ('road_trip', 3),
#  ('went_inside', 3),
#  ('minutes_less', 3),
#  ('pay_attention', 3),
#  ('long_story', 3),
#  ('story_short', 3),
#  ('go_order', 3),
#  ('back_said', 3),
#  ...]

# %%
good_Fast_Food=Fast_Food[Fast_Food.stars>=3.5]
good_Fast_Food_review = Fast_Food_review[Fast_Food_review.business_id.isin(good_Fast_Food.business_id.values)]
good_Fast_Food_review_text = good_Fast_Food_review.text.str.cat(sep = " ")
good_Fast_Food_tokens = word_tokenize(good_Fast_Food_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_good_Fast_Food = ["_".join(item) for item in nltk.bigrams(good_Fast_Food_tokens)]
trigrams_list_good_Fast_Food = ["_".join(item) for item in nltk.trigrams(good_Fast_Food_tokens)]
# FreqDist(bigrams_list_good_Fast_Food).most_common()
FreqDist(trigrams_list_good_Fast_Food).most_common()
# Out:
# [('fast_food_restaurant', 18),
#  ('spicy_chicken_sandwich', 18),
#  ('animal_style_fries', 17),
#  ('chicken_fried_steak', 14),
#  ('best_fast_food', 12),
#  ('drive_thru_line', 11),
#  ('fast_food_place', 11),
#  ('late_night_food', 10),
#  ('santa_barbara_local', 9),
#  ('double_double_animal', 9),
#  ('food_great_service', 9),
#  ('cant_go_wrong', 9),
#  ('chick_fil_a', 9),
#  ('buffalo_chicken_fries', 9),
#  ('great_customer_service', 8),
#  ('customer_service_great', 8),
#  ('great_food_great', 8),
#  ('old_farmer_boy', 7),
#  ('double_animal_style', 7),
#  ('mac_n_cheese', 7),
#  ('get_animal_style', 6),
#  ('food_good_service', 6),
#  ('food_always_good', 6),
#  ('sweet_potato_fries', 6),
#  ('deluxe_chicken_sandwich', 6),
#  ('chick_fil_sauce', 6),
#  ('best_late_night', 6),
#  ('love_n_out', 5),
#  ('breakfast_santa_barbara', 5),
#  ('ive_ever_had', 5),
#  ('late_night_snack', 5),
#  ('fast_food_places', 5),
#  ('crab_cake_benedict', 5),
#  ('favorite_fast_food', 5),
#  ('service_great_food', 5),
#  ('fried_chicken_waffles', 5),
#  ('staff_always_friendly', 5),
#  ('country_fried_steak', 5),
#  ('keep_coming_back', 5),
#  ('onions_peppers_fries', 5),
#  ('service_good_food', 5),
#  ('visiting_santa_barbara', 5),
#  ('santa_barbara_food', 5),
#  ('ordered_grilled_chicken', 5),
#  ('grilled_chicken_sandwich', 5),
#  ('deep_fried_oreos', 5),
#  ('burgers_fries_shakes', 4),
#  ('barbara_local_omelette', 4),
#  ('fast_food_burger', 4),
#  ('come_back_again', 4),
#  ('great_burgers_fries', 4),
#  ('santa_barbara_county', 4),
#  ('made_us_feel', 4),
#  ('fast_food_chain', 4),
#  ('good_fast_food', 4),
#  ('got_ta_love', 4),
#  ('crispy_hash_browns', 4),
#  ('fast_food_restaurants', 4),
#  ('one_santa_barbara', 4),
#  ('santa_barbara_usually', 4),
#  ('food_pretty_good', 4),
#  ('food_even_better', 4),
#  ('santa_barbara_weekend', 4),
#  ('fries_strawberry_shake', 4),
#  ('highly_recommend_place', 4),
#  ('nothing_write_home', 4),
#  ('grilled_onions_peppers', 4),
#  ('place_always_clean', 4),
#  ('good_waffle_fries', 4),
#  ('spicy_deluxe_chicken', 4),
#  ('grilled_chicken_nuggets', 4),
#  ('grilled_chicken_club', 4),
#  ('bbq_chicken_fries', 4),
#  ('fried_cinnamon_rolls', 4),
#  ('farmer_boy_restaurant', 3),
#  ('food_great_quality', 3),
#  ('got_santa_barbara', 3),
#  ('ive_ever_eaten', 3),
#  ('location_drive_thru', 3),
#  ('drive_thru_takes', 3),
#  ('favorite_breakfast_spot', 3),
#  ('got_double_double', 3),
#  ('double_double_fries', 3),
#  ('needed_anything_else', 3),
#  ('food_tastes_great', 3),
#  ('first_time_ever', 3),
#  ('iced_tea_santa', 3),
#  ('tea_santa_barbara', 3),
#  ('food_really_good', 3),
#  ('toad_hole_sandwich', 3),
#  ('farmer_boy_one', 3),
#  ('food_santa_barbara', 3),
#  ('new_farmer_boy', 3),
#  ('chicken_biscuits_gravy', 3),
#  ('even_finish_it', 3),
#  ('eat_fast_food', 3),
#  ('would_give_stars', 3),
#  ('doubledouble_animal_style', 3),
#  ('grilled_onions_extra', 3),
#  ('well_done_fries', 3),
#  ('food_excellent_service', 3),
#  ('extra_grilled_onions', 3),
#  ('definitely_come_back', 3),
#  ('great_service_friendly', 3),
#  ('place_friendly_staff', 3),
#  ('bacon_cheese_burger', 3),
#  ('would_highly_recommend', 3),
#  ('always_good_food', 3),
#  ('fried_chicken_biscuit', 3),
#  ('chicken_biscuit_sliders', 3),
#  ('bacon_hash_browns', 3),
#  ('wait_staff_always', 3),
#  ('ordering_drive_thru', 3),
#  ('one_favorite_places', 3),
#  ('good_food_good', 3),
#  ('food_first_time', 3),
#  ('one_best_breakfasts', 3),
#  ('it_great_food', 3),
#  ('fried_steak_eggs', 3),
#  ('back_santa_barbara', 3),
#  ('always_good_service', 3),
#  ('found_farmer_boy', 3),
#  ('excellent_customer_service', 3),
#  ('get_double_double', 3),
#  ('staff_super_friendly', 3),
#  ('definitely_coming_back', 3),
#  ('santa_barbara_decided', 3),
#  ('try_farmer_boy', 3),
#  ('good_service_good', 3),
#  ('support_local_business', 3),
#  ('fries_well_done', 3),
#  ('good_customer_service', 3),
#  ('im_coming_back', 3),
#  ('two_eyed_toad', 3),
#  ('burger_santa_barbara', 3),
#  ('long_time_food', 3),
#  ('pretty_good_im', 3),
#  ('everything_made_fresh', 3),
#  ('ive_ever_to', 3),
#  ('great_highly_recommend', 3),
#  ('food_huge_portions', 3),
#  ('every_time_go', 3),
#  ('write_home_about', 3),
#  ('said_would_take', 3),
#  ('customer_service_friendly', 3),
#  ('well_worth_it', 3),
#  ('late_night_dinner', 3),
#  ('went_drive_thru', 3),
#  ('peppers_fries_strawberry', 3),
#  ('soft_serve_ice', 3),
#  ('serve_ice_cream', 3),
#  ('place_stop_lunch', 3),
#  ('back_again_love', 3),
#  ('fried_chicken_sandwich', 3),
#  ('im_huge_fan', 3),
#  ('fast_food_joints', 3),
#  ('food_cooked_order', 3),
#  ('chicken_sandwich_chicken', 3),
#  ('great_fast_food', 3),
#  ('chickfila_ive_ever', 3),
#  ('ive_ever_seen', 3),
#  ('chicken_sandwiches_good', 3),
#  ('always_get_order', 3),
#  ('sandwich_grilled_chicken', 3),
#  ('order_ahead_time', 3),
#  ('chicken_club_sandwich', 3),
#  ('waffle_fries_crispy', 3),
#  ('fast_food_chicken', 3),
#  ('great_food_good', 3),
#  ('late_night_munchies', 3),
#  ('late_night_delivery', 3),
#  ('east_side_boogie', 3),
#  ('mac_cheese_balls', 3),
#  ('got_buffalo_wings', 3),
#  ('deep_fried_cinnamon', 3),
#  ('got_ta_say', 3),
#  ('eat_taco_bell', 3),
#  ('go_time_cozy', 3),
#  ('time_cozy_dining', 3),
#  ('cozy_dining_space', 3),
#  ('dining_space_accurate', 3),
#  ('space_accurate_fast', 3),
#  ('accurate_fast_orders', 3),
#  ('fast_orders_good', 3),
#  ('orders_good_food', 3),
#  ('good_food_ive', 3),
#  ('food_ive_taco', 3),
#  ('ive_taco_bells', 3),
#  ('taco_bells_one', 3),
#  ('bells_one_best', 3),
#  ('one_best_around', 3),
#  ('best_around_wary', 3),
#  ('around_wary_bathroom', 3),
#  ('wary_bathroom_backsome', 3),
#  ('location_santa_barbara', 2),
#  ('would_think_would', 2),
#  ('cinnamon_roll_table', 2),
#  ('eggs_benedict_delicious', 2),
#  ('santa_barbara_area', 2),
#  ('service_always_friendly', 2),
#  ('could_go_on', 2),
#  ('many_many_years', 2),
#  ('food_good_coffee', 2),
#  ('great_breakfast_options', 2),
#  ('santa_barbara_omelette', 2),
#  ('forward_coming_back', 2),
#  ('keep_going_back', 2),
#  ('im_writing_review', 2),
#  ('one_better_innouts', 2),
#  ('crowded_lunch_dinner', 2),
#  ('food_good_enough', 2),
#  ('best_iced_tea', 2),
#  ('serve_breakfast_day', 2),
#  ('eyed_toad_hole', 2),
#  ('santa_barbara_place', 2),
#  ('wash_hands_cook', 2),
#  ('protein_style_burger', 2),
#  ('wow_one_best', 2),
#  ('one_best_breakfast', 2),
#  ('best_breakfast_ever', 2),
#  ('best_burger_fries', 2),
#  ('never_tried_it', 2),
#  ('still_worth_it', 2),
#  ('beyond_customer_service', 2),
#  ('old_school_diner', 2),
#  ('innout_santa_barbara', 2),
#  ('first_time_back', 2),
#  ('time_back_since', 2),
#  ('husband_got_chicken', 2),
#  ('cheeseburger_grilled_onions', 2),
#  ('great_food_exceptional', 2),
#  ('food_exceptional_service', 2),
#  ('service_good_job', 2),
#  ('food_within_minutes', 2),
#  ('fast_food_goes', 2),
#  ('highly_recommend_great', 2),
#  ('try_chicken_fried', 2),
#  ('best_ive_ever', 2),
#  ('still_really_good', 2),
#  ('anything_less_five', 2),
#  ('less_five_stars', 2),
#  ('always_top_notch', 2),
#  ('farmer_boy_name', 2),
#  ('fresh_french_fries', 2),
#  ('always_incredibly_long', 2),
#  ('eat_regular_basis', 2),
#  ('ok_fast_food', 2),
#  ('fast_food_good', 2),
#  ('french_fries_taste', 2),
#  ('fries_taste_like', 2),
#  ('first_time_pretty', 2),
#  ('fan_fast_food', 2),
#  ('usual_double_double', 2),
#  ('burgers_animal_style', 2),
#  ('always_good_choice', 2),
#  ('home_cooked_food', 2),
#  ('great_service_good', 2),
#  ('great_breakfast_super', 2),
#  ('left_credit_card', 2),
#  ('large_parking_lot', 2),
#  ('pm_took_minutes', 2),
#  ('man_taking_order', 2),
#  ('ask_extra_sauce', 2),
#  ('around_lunch_time', 2),
#  ('facing_parking_lot', 2),
#  ('regular_burgers_fries', 2),
#  ('breakfast_saturday_morning', 2),
#  ('drive_thru_long', 2),
#  ('get_it_food', 2),
#  ('habit_cal_taco', 2),
#  ('new_owners_brought', 2),
#  ('out_ever_to', 2),
#  ('made_fast_food', 2),
#  ('order_animal_style', 2),
#  ('love_animal_style', 2),
#  ('service_friendly_fast', 2),
#  ('nice_place_friendly', 2),
#  ('lunch_dinner_hours', 2),
#  ('times_ive_come', 2),
#  ('farmer_boy_regular', 2),
#  ('prior_ownership_change', 2),
#  ('add_salt_pepper', 2),
#  ('food_go_innout', 2),
#  ('drive_thru_always', 2),
#  ('previous_farmer_boys', 2),
#  ('gourmet_burger_places', 2),
#  ('easy_going_nice', 2),
#  ('santa_barbara_try', 2),
#  ('tasty_grilled_cheese', 2),
#  ('service_food_always', 2),
#  ('eyed_toadinahole_sandwich', 2),
#  ('many_breakfast_spots', 2),
#  ('one_best_fast', 2),
#  ('food_made_fresh', 2),
#  ('innout_best_fast', 2),
#  ('long_drive_thru', 2),
#  ('good_diner_food', 2),
#  ('hash_browns_well', 2),
#  ('place_come_back', 2),
#  ('wall_ketchup_bottles', 2),
#  ('food_place_drive', 2),
#  ('place_drive_thru', 2),
#  ('fries_nothing_spectacular', 2),
#  ('love_innout_burger', 2),
#  ('minutes_get_food', 2),
#  ('going_back_sure', 2),
#  ('best_chicken_fried', 2),
#  ('hash_browns_really', 2),
#  ('eye_n_said', 2),
#  ('pretty_much_everything', 2),
#  ('worth_it_food', 2),
#  ('fast_food_joint', 2),
#  ('ordered_secret_menu', 2),
#  ('clean_drive_thru', 2),
#  ('time_farmer_boy', 2),
#  ('old_fashioned_diner', 2),
#  ('protein_style_grilled', 2),
#  ('style_grilled_onions', 2),
#  ('recommend_place_anyone', 2),
#  ('fried_steak_biscuits', 2),
#  ('steak_biscuits_gravy', 2),
#  ('sunny_side_up', 2),
#  ('keep_good_work', 2),
#  ('food_always_comes', 2),
#  ('style_double_double', 2),
#  ('double_double_grilled', 2),
#  ('x_protein_style', 2),
#  ('super_clean_location', 2),
#  ('service_quick_friendly', 2),
#  ('service_highly_recommend', 2),
#  ('cheese_burger_fries', 2),
#  ('lunch_dinner_rush', 2),
#  ('big_fan_innout', 2),
#  ('time_get_food', 2),
#  ('barbara_usually_get', 2),
#  ('like_greasy_spoon', 2),
#  ('greasy_spoon_diner', 2),
#  ('spoon_diner_s', 2),
#  ('always_make_sure', 2),
#  ('make_sure_ask', 2),
#  ('bbq_bacon_burger', 2),
#  ('back_try_breakfast', 2),
#  ('us_amazing_service', 2),
#  ('crab_cakes_benedict', 2),
#  ('first_time_came', 2),
#  ('animal_style_burger', 2),
#  ('fries_lightly_well', 2),
#  ('lightly_well_done', 2),
#  ('fries_neapolitan_shake', 2),
#  ('lived_santa_barbara', 2),
#  ('santa_barbara_years', 2),
#  ('hotel_across_street', 2),
#  ('food_done_right', 2),
#  ('great_service_food', 2),
#  ('every_time_im', 2),
#  ('good_food_service', 2),
#  ('im_big_fan', 2),
#  ('cinnamon_rolls_still', 2),
#  ('chickenfried_biscuit_sliders', 2),
#  ('customer_service_favorite', 2),
#  ('got_fried_chicken', 2),
#  ('biscuit_sliders_gravy', 2),
#  ('mean_come_on', 2),
#  ('perfect_way_end', 2),
#  ('food_always_awesome', 2),
#  ('too_definitely_back', 2),
#  ('selection_extremely_limited', 2),
#  ('food_got_food', 2),
#  ('part_routine_sb', 2),
#  ('routine_sb_pleasant', 2),
#  ('sb_pleasant_atmosphere', 2),
#  ('pleasant_atmosphere_staff', 2),
#  ('atmosphere_staff_fresh', 2),
#  ('staff_fresh_bfast', 2),
#  ('fresh_bfast_items', 2),
#  ('bfast_items_bagels', 2),
#  ('items_bagels_great', 2),
#  ('bagels_great_chicken', 2),
#  ('great_chicken_biscuits', 2),
#  ('chicken_biscuits_excellent', 2),
#  ('hash_browns_delicious', 2),
#  ('never_disappoints_love', 2),
#  ('first_time_ive', 2),
#  ('ordered_chicken_fried', 2),
#  ('hash_browns_taste', 2),
#  ('good_food_always', 2),
#  ('san_luis_obispo', 2),
#  ('santa_barbara_friendly', 2),
#  ('barbara_friendly_attentive', 2),
#  ('give_place_stars', 2),
#  ('first_innout_experience', 2),
#  ('fast_food_chains', 2),
#  ('really_can_not', 2),
#  ('great_food_even', 2),
#  ('super_friendly_helpful', 2),
#  ('fast_food_great', 2),
#  ('santa_barbara_come', 2),
#  ('overall_good_experience', 2),
#  ('go_somewhere_else', 2),
#  ('recommend_cinnamon_roll', 2),
#  ('bit_wait_weekends', 2),
#  ('worth_it_best', 2),
#  ('line_get_long', 2),
#  ('fries_root_beer', 2),
#  ('drive_thru_today', 2),
#  ('long_goes_pretty', 2),
#  ('goes_pretty_fast', 2),
#  ('tri_tip_sandwich', 2),
#  ('great_place_eat', 2),
#  ('thats_good_thing', 2),
#  ('trip_santa_barbara', 2),
#  ('decided_try_farmer', 2),
#  ('farmer_boy_breakfast', 2),
#  ('would_definitely_recommend', 2),
#  ('well_definitely_back', 2),
#  ('love_it_food', 2),
#  ('nice_gave_us', 2),
#  ('burger_fries_drink', 2),
#  ('need_call_back', 2),
#  ('year_old_son', 2),
#  ('extra_crispy_hash', 2),
#  ('hash_browns_cinnamon', 2),
#  ('leave_negative_review', 2),
#  ('took_minutes_get', 2),
#  ('check_farmer_boy', 2),
#  ('definitely_go_back', 2),
#  ('particular_location_always', 2),
#  ('thought_would_try', 2),
#  ('wish_restaurants_could', 2),
#  ('tasting_fast_food', 2),
#  ('fast_food_fries', 2),
#  ('special_place_heart', 2),
#  ('im_santa_barbara', 2),
#  ('incredibly_friendly_helpful', 2),
#  ('friendly_helpful_food', 2),
#  ('make_sure_try', 2),
#  ('even_though_busy', 2),
#  ('service_excellent_food', 2),
#  ('chicken_fried_biscuit', 2),
#  ('fried_biscuit_sliders', 2),
#  ('amazing_must_try', 2),
#  ('standard_work_process', 2),
#  ('santa_barbara_always', 2),
#  ('double_animal_fries', 2),
#  ('really_good_service', 2),
#  ('coming_back_anytime', 2),
#  ('make_feel_welcome', 2),
#  ('food_quality_service', 2),
#  ('grilled_cheese_sandwich', 2),
#  ('eat_red_meat', 2),
#  ('scrambled_eggs_bacon', 2),
#  ('never_messed_order', 2),
#  ('place_get_burger', 2),
#  ('fast_food_cant', 2),
#  ('cleaning_dining_room', 2),
#  ('fast_food_always', 2),
#  ('line_moves_fast', 2),
#  ('fast_food_employees', 2),
#  ('come_back_try', 2),
#  ('kind_helpful_also', 2),
#  ('gets_busy_staff', 2),
#  ('made_fresh_order', 2),
#  ('hungry_cant_wait', 2),
#  ('come_back_soon', 2),
#  ('favorite_person_time', 2),
#  ('food_came_fresh', 2),
#  ('would_take_hour', 2),
#  ('went_first_time', 2),
#  ('hash_browns_perfectly', 2),
#  ('farmer_boy_takes', 2),
#  ('incredible_santa_barbara', 2),
#  ('tasty_hash_browns', 2),
#  ('goes_long_way', 2),
#  ('great_service_best', 2),
#  ('meal_farmer_boy', 2),
#  ('cant_wait_go', 2),
#  ('fried_steak_home', 2),
#  ('good_service_cant', 2),
#  ('cinnamon_roll_amazing', 2),
#  ('hard_find_good', 2),
#  ('time_time_again', 2),
#  ('eat_lot_innout', 2),
#  ('get_order_correct', 2),
#  ('good_food_great', 2),
#  ('several_times_breakfast', 2),
#  ('would_take_care', 2),
#  ('five_star_review', 2),
#  ('eyed_toad_sandwich', 2),
#  ('staff_extremely_friendly', 2),
#  ('cheese_grilled_onions', 2),
#  ('coming_back_again', 2),
#  ('service_super_slow', 2),
#  ('takes_another_level', 2),
#  ('took_long_time', 2),
#  ('times_never_disappointed', 2),
#  ('service_always_great', 2),
#  ('large_cinnamon_rolls', 2),
#  ('staff_incredibly_friendly', 2),
#  ('quality_food_superb', 2),
#  ('maybe_every_location', 2),
#  ('make_sure_everything', 2),
#  ('never_let_down', 2),
#  ('boy_missing_out', 2),
#  ('took_order_outside', 2),
#  ('drive_thru_get', 2),
#  ('rd_instance_left', 2),
#  ('instance_left_friend', 2),
#  ('order_flying_dutchmen', 2),
#  ('flying_dutchmen_grilled', 2),
#  ('dutchmen_grilled_onions', 2),
#  ('got_flying_dutchmen', 2),
#  ('flying_dutchmen_onions', 2),
#  ('dutchmen_onions_peppers', 2),
#  ('whole_grilled_onions', 2),
#  ('strawberry_shake_cheeseburger', 2),
#  ('mr_michael_said', 2),
#  ('come_back_sb', 2),
#  ('pretty_darn_good', 2),
#  ('bbq_bacon_char', 2),
#  ('santa_barbara_style', 2),
#  ('bbq_sauce_mayo', 2),
#  ('got_order_right', 2),
#  ('potato_fries_good', 2),
#  ('green_bean_fries', 2),
#  ('get_ice_cream', 2),
#  ('dollar_ice_cream', 2),
#  ('ice_cream_cone', 2),
#  ('fries_onion_rings', 2),
#  ('lets_say_ive', 2),
#  ('santa_barbara_char', 2),
#  ('good_ive_never', 2),
#  ('without_pickles_every', 2),
#  ('pickles_every_time', 2),
#  ('go_back_again', 2),
#  ('fries_every_time', 2),
#  ('food_always_fresh', 2),
#  ('never_bad_experience', 2),
#  ('customer_service_trash', 2),
#  ('burger_joint_one', 2),
#  ('burger_cheese_bacon', 2),
#  ('yum_yum_yum', 2),
#  ('santa_barbara_location', 2),
#  ('food_delicious_always', 2),
#  ('chicken_sandwich_ive', 2),
#  ('next_time_ill', 2),
#  ('food_always_great', 2),
#  ('tender_juicy_delicious', 2),
#  ('deep_fried_chicken', 2),
#  ('chicken_breast_made', 2),
#  ('fan_waffle_fries', 2),
#  ('santa_barbara_great', 2),
#  ('love_chickfila_sauce', 2),
#  ('one_upper_state', 2),
#  ('better_fast_food', 2),
#  ('give_another_try', 2),
#  ('chain_fast_food', 2),
#  ('sandwich_chicken_strips', 2),
#  ('free_ice_cream', 2),
#  ('favorite_chicken_sandwich', 2),
#  ('still_taste_pickle', 2),
#  ('make_back_time', 2),
#  ('considering_fast_food', 2),
#  ('great_food_service', 2),
#  ('warm_waffle_fries', 2),
#  ('keep_place_clean', 2),
#  ('really_good_chicken', 2),
#  ('chicken_noodle_soup', 2),
#  ('amazing_customer_service', 2),
#  ('justice_everything_good', 2),
#  ('decided_go_chickfila', 2),
#  ('employees_great_food', 2),
#  ('great_food_fast', 2),
#  ('food_fast_food', 2),
#  ('free_chicken_sandwich', 2),
#  ('waffle_fries_pretty', 2),
#  ('best_spicy_chicken', 2),
#  ('opening_day_busy', 2),
#  ('customer_service_really', 2),
#  ('service_really_good', 2),
#  ('guy_took_order', 2),
#  ('best_service_fast', 2),
#  ('service_fast_food', 2),
#  ('back_home_santa', 2),
#  ('honey_mustard_sauce', 2),
#  ('everyone_super_friendly', 2),
#  ('say_drive_thru', 2),
#  ('bring_food_table', 2),
#  ('quality_food_service', 2),
#  ('take_long_food', 2),
#  ('ordered_spicy_chicken', 2),
#  ('waffle_fries_also', 2),
#  ('every_time_come', 2),
#  ('got_spicy_deluxe', 2),
#  ('chicken_sandwich_meal', 2),
#  ('santa_barbara_chickfila', 2),
#  ('fast_food_food', 2),
#  ('amazing_service_always', 2),
#  ('good_food_little', 2),
#  ('quick_bring_food', 2),
#  ('chickfila_santa_barbara', 2),
#  ('visit_quality_food', 2),
#  ('every_chickfila_ive', 2),
#  ('medium_waffle_fries', 2),
#  ('always_friendly_attentive', 2),
#  ('today_first_time', 2),
#  ('definitely_must_try', 2),
#  ('ive_better_food', 2),
#  ('clean_service_fast', 2),
#  ('service_fast_friendly', 2),
#  ('drive_through_staff', 2),
#  ('totally_worth_it', 2),
#  ('girl_taking_order', 2),
#  ('manager_nice_lady', 2),
#  ('chicken_sandwiches_always', 2),
#  ('food_restaurant_santa', 2),
#  ('restaurant_santa_barbara', 2),
#  ('time_chick_fil', 2),
#  ('get_order_right', 2),
#  ('customer_service_awesome', 2),
#  ('excellent_service_food', 2),
#  ('love_place_much', 2),
#  ('place_much_usually', 2),
#  ('much_usually_long', 2),
#  ('usually_long_wait', 2),
#  ('long_wait_lunch', 2),
#  ('wait_lunch_well', 2),
#  ('lunch_well_worth', 2),
#  ('worth_it_employees', 2),
#  ('it_employees_always', 2),
#  ('employees_always_friendly', 2),
#  ('always_friendly_remembers', 2),
#  ('friendly_remembers_you', 2),
#  ('remembers_you_food', 2),
#  ('you_food_hand', 2),
#  ('food_hand_delicious', 2),
#  ('hand_delicious_ice', 2),
#  ('delicious_ice_cream', 2),
#  ('ice_cream_like', 2),
#  ('cream_like_other', 2),
#  ('like_other_taste', 2),
#  ('other_taste_real', 2),
#  ('taste_real_ingredients', 2),
#  ('real_ingredients_compared', 2),
#  ('ingredients_compared_perhaps', 2),
#  ('compared_perhaps_mcdonalds', 2),
#  ('perhaps_mcdonalds_ice', 2),
#  ('mcdonalds_ice_cream', 2),
#  ('ice_cream_all', 2),
#  ('cream_all_great', 2),
#  ('all_great_place', 2),
#  ('great_place_stop', 2),
#  ('poor_customer_service', 2),
#  ('customer_service_skills', 2),
#  ('first_time_visiting', 2),
#  ('order_right_every', 2),
#  ('go_drive_thru', 2),
#  ('never_go_back', 2),
#  ('someone_else_comes', 2),
#  ('else_comes_around', 2),
#  ('amazing_food_amazing', 2),
#  ('food_amazing_service', 2),
#  ('read_back_me', 2),
#  ('love_chick_fil', 2),
#  ('honey_roasted_bbq', 2),
#  ('roasted_bbq_sauce', 2),
#  ('girl_took_order', 2),
#  ('food_hot_fresh', 2),
#  ('go_chick_fil', 2),
#  ('fast_food_fast', 2),
#  ('food_ive_ever', 2),
#  ('always_super_nice', 2),
#  ('one_chick_fil', 2),
#  ('chicken_sandwich_grilled', 2),
#  ('helpful_food_good', 2),
#  ('give_another_chance', 2),
#  ('place_always_consistent', 2),
#  ('always_consistent_fresh', 2),
#  ('consistent_fresh_tasty', 2),
#  ('fresh_tasty_food', 2),
#  ('tasty_food_chicken', 2),
#  ('food_chicken_sandwiches', 2),
#  ('sandwiches_good_waffle', 2),
#  ('fries_crispy_frosty', 2),
#  ('crispy_frosty_coffee', 2),
#  ('frosty_coffee_drink', 2),
#  ('coffee_drink_refreshing', 2),
#  ('drink_refreshing_ample', 2),
#  ('refreshing_ample_condiments', 2),
#  ('ample_condiments_paper', 2),
#  ('condiments_paper_straws', 2),
#  ('paper_straws_everyone', 2),
#  ('straws_everyone_thanks', 2),
#  ('everyone_thanks_annie', 2),
#  ('thanks_annie_staff', 2),
#  ('annie_staff_taking', 2),
#  ('staff_taking_good', 2),
#  ('taking_good_care', 2),
#  ('good_care_us', 2),
#  ('upper_state_street', 2),
#  ('state_street_las', 2),
#  ('street_las_positas', 2),
#  ('las_positas_la', 2),
#  ('positas_la_cumbre', 2),
#  ('la_cumbre_center', 2),
#  ('cumbre_center_good', 2),
#  ('center_good_parking', 2),
#  ('order_wrong_twice', 2),
#  ('deluxe_spicy_chicken', 2),
#  ('able_get_many', 2),
#  ('get_many_sauces', 2),
#  ('asked_chickfila_sauces', 2),
#  ('agreed_gave_sauces', 2),
#  ('gave_sauces_accordingly', 2),
#  ('come_take_order', 2),
#  ('app_reward_points', 2),
#  ('would_obviously_scan', 2),
#  ('food_amazing_well', 2),
#  ('always_gets_order', 2),
#  ('took_hour_half', 2),
#  ('again_great_food', 2),
#  ('late_night_spot', 2),
#  ('need_late_night', 2),
#  ('late_night_option', 2),
#  ('chicken_fries_burrito', 2),
#  ('comes_through_food', 2),
#  ('late_night_grub', 2),
#  ('fast_delivery_food', 2),
#  ('many_good_things', 2),
#  ('chicken_cheese_fries', 2),
#  ('fries_tasted_like', 2),
#  ('night_delivery_service', 2),
#  ('sb_munchiez_wanting', 2),
#  ('munchiez_wanting_try', 2),
#  ('got_burger_cheese', 2),
#  ('grilled_chicken_panini', 2),
#  ('food_delicious_definitely', 2),
#  ('gave_big_portions', 2),
#  ('asked_phone_number', 2),
#  ('late_night_eats', 2),
#  ('im_sorry_say', 2),
#  ('look_like_pictures', 2),
#  ('cinnamon_rolls_amazing', 2),
#  ('staff_great_food', 2),
#  ('tri_tip_quesadilla', 2),
#  ('cant_wait_try', 2),
#  ('definitely_worth_it', 2),
#  ('late_night_pick', 2),
#  ('night_pick_up', 2),
#  ('knee_surgery_thought', 2),
#  ('surgery_thought_would', 2),
#  ('thought_would_enjoy', 2),
#  ('would_enjoy_nice', 2),
#  ('enjoy_nice_day', 2),
#  ('nice_day_santa', 2),
#  ('day_santa_barbara', 2),
#  ('santa_barbara_order', 2),
#  ('barbara_order_tonight', 2),
#  ('order_tonight_place', 2),
#  ('tonight_place_third', 2),
#  ('place_third_place', 2),
#  ('third_place_search', 2),
#  ('place_search_engine', 2),
#  ('search_engine_ordered', 2),
#  ('engine_ordered_late', 2),
#  ('ordered_late_ordered', 2),
#  ('late_ordered_cheeseburger', 2),
#  ('ordered_cheeseburger_rand', 2),
#  ('cheeseburger_rand_fries', 2),
#  ('rand_fries_wife', 2),
#  ('fries_wife_ordered', 2),
#  ('wife_ordered_wings', 2),
#  ('ordered_wings_say', 2),
#  ('wings_say_minimum', 2),
#  ('say_minimum_fine', 2),
#  ('minimum_fine_soon', 2),
#  ('fine_soon_got', 2),
#  ('soon_got_credit', 2),
#  ('got_credit_card', 2),
#  ('credit_card_number', 2),
#  ('card_number_expiration', 2),
#  ('number_expiration_date', 2),
#  ('expiration_date_hung', 2),
#  ('date_hung_up', 2),
#  ('hung_up_scared', 2),
#  ('up_scared_bit', 2),
#  ('scared_bit_called', 2),
#  ('bit_called_right', 2),
#  ('called_right_back', 2),
#  ('right_back_answered', 2),
#  ('back_answered_said', 2),
#  ('answered_said_done', 2),
#  ('said_done_order', 2),
#  ('done_order_said', 2),
#  ('order_said_oh', 2),
#  ('said_oh_yes', 2),
#  ('oh_yes_within', 2),
#  ('yes_within_minutes', 2),
#  ('within_minutes_hello', 2),
#  ('minutes_hello_never', 2),
#  ('hello_never_hang', 2),
#  ('never_hang_customer', 2),
#  ('hang_customer_without', 2),
#  ('customer_without_saying', 2),
#  ('without_saying_thank', 2),
#  ('saying_thank_time', 2),
#  ('fries_deep_fried', 2),
#  ('late_night_bite', 2),
#  ('hour_half_later', 2),
#  ('even_though_ordered', 2),
#  ('owner_super_nice', 2),
#  ('really_hard_find', 2),
#  ('open_late_night', 2),
#  ('earl_warren_show', 2),
#  ('warren_show_grounds', 2),
#  ('definitely_worth_money', 2),
#  ('tri_tip_panini', 2),
#  ('mac_cheese_bites', 2),
#  ('big_enough_split', 2),
#  ('good_took_forever', 2),
#  ('santa_barbara_late', 2),
#  ('recommend_anyone_looking', 2),
#  ('service_santa_barbara', 2),
#  ('santa_barbara_burger', 2),
#  ('fries_mozzarella_sticks', 2),
#  ('really_good_good', 2),
#  ('ta_say_delicious', 2),
#  ('quality_food_price', 2),
#  ('got_dragon_noodles', 2),
#  ('mini_cinnamon_rolls', 2),
#  ('favorite_late_night', 2),
#  ('late_night_cravings', 2),
#  ('chicken_dragon_noodles', 2),
#  ('got_order_wrong', 2),
#  ('deep_fried_pbj', 2),
#  ('chili_cheese_fries', 2),
#  ('small_parking_lot', 2),
#  ('good_taco_bell', 2),
#  ('taco_bell_worth', 2),
#  ('favorite_taco_bell', 2),
#  ('taco_bell_ive', 2),
#  ('taco_bell_town', 2),
#  ('thanks_taco_bell', 2),
#  ('taco_bell_favorite', 2),
#  ('late_night_staff', 2),
#  ('love_taco_bell', 2),
#  ('potato_soft_tacos', 2),
#  ('come_late_night', 2),
#  ('cheesy_rice_bean', 2),
#  ('rice_bean_burritos', 2),
#  ('bathroom_backsome_abuse', 2),
#  ('backsome_abuse_them', 2),
#  ('parking_lot_back', 2),
#  ('taco_bell_go', 2),
#  ('bell_go_time', 2),
#  ('going_call_police', 2),
#  ('call_police_them', 2),
#  ('taco_bell_always', 2),
#  ('n_out_theres', 1),
#  ('out_theres_mood', 1),
#  ('theres_mood_n', 1),
#  ('mood_n_fulfill', 1),
#  ('n_fulfill_sometimes', 1),
#  ('fulfill_sometimes_say', 1),
#  ('sometimes_say_patties', 1),
#  ('say_patties_animal', 1),
#  ('patties_animal_style', 1),
#  ('animal_style_bruh', 1),
#  ('style_bruh_place', 1),
#  ('bruh_place_rocks', 1),
#  ('place_rocks_never', 1),
#  ('rocks_never_guess', 1),
#  ('never_guess_outside', 1),
#  ('guess_outside_food', 1),
#  ('outside_food_great', 1),
#  ('food_great_great', 1),
#  ('great_great_kids', 1),
#  ('great_kids_too', 1),
#  ('kids_too_always', 1),
#  ('too_always_grab', 1),
#  ('always_grab_brunch', 1),
#  ('grab_brunch_beer', 1),
#  ('brunch_beer_vacationing', 1),
#  ('beer_vacationing_town', 1),
#  ('vacationing_town_suggestion', 1),
#  ('town_suggestion_beers', 1),
#  ('suggestion_beers_taps', 1),
#  ('beers_taps_beers', 1),
#  ('taps_beers_running', 1),
#  ('beers_running_fix', 1),
#  ('running_fix_please', 1),
#  ('fix_please_love', 1),
#  ('please_love_place', 1),
#  ('love_place_started', 1),
#  ('place_started_fan', 1),
#  ('started_fan_la', 1),
#  ('fan_la_years', 1),
#  ('la_years_ago', 1),
#  ('years_ago_food', 1),
#  ('ago_food_still', 1),
#  ('food_still_great', 1),
#  ('still_great_prices', 1),
#  ('great_prices_still', 1),
#  ('prices_still_reasonable', 1),
#  ('still_reasonable_wish', 1),
#  ('reasonable_wish_would', 1),
#  ('wish_would_open', 1),
#  ('would_open_another', 1),
#  ('open_another_location', 1),
#  ('another_location_santa', 1),
#  ('santa_barbara_feel', 1),
#  ('barbara_feel_doubledouble', 1),
#  ('feel_doubledouble_calling', 1),
#  ('doubledouble_calling_now', 1),
#  ('calling_now_couple', 1),
#  ('now_couple_saturdays', 1),
#  ('couple_saturdays_ago', 1),
#  ('saturdays_ago_went', 1),
#  ('ago_went_farmers', 1),
#  ('went_farmers_breakfast', 1),
#  ('farmers_breakfast_ordered', 1),
#  ('breakfast_ordered_miniwaffle', 1),
#  ('ordered_miniwaffle_plate', 1),
#  ('miniwaffle_plate_waiting', 1),
#  ('plate_waiting_quite', 1),
#  ('waiting_quite_time', 1),
#  ('quite_time_noticed', 1),
#  ('time_noticed_diners', 1),
#  ('noticed_diners_receiving', 1),
#  ('diners_receiving_orders', 1),
#  ('receiving_orders_placed', 1),
#  ('orders_placed_orders', 1),
#  ('placed_orders_firsti', 1),
#  ('orders_firsti_asked', 1),
#  ('firsti_asked_waitress', 1),
#  ('asked_waitress_getting', 1),
#  ('waitress_getting_orders', 1),
#  ('getting_orders_said', 1),
#  ('orders_said_shortly', 1),
#  ('said_shortly_finally', 1),
#  ('shortly_finally_received', 1),
#  ('finally_received_orders', 1),
#  ('received_orders_asked', 1),
#  ('orders_asked_sugarfree', 1),
#  ('asked_sugarfree_syrup', 1),
#  ('sugarfree_syrup_said', 1),
#  ('syrup_said_no', 1),
#  ('said_no_itthen', 1),
#  ('no_itthen_asked', 1),
#  ('itthen_asked_manager', 1),
#  ('asked_manager_sugarfree', 1),
#  ('manager_sugarfree_syrupand', 1),
#  ('sugarfree_syrupand_said', 1),
#  ('syrupand_said_yes', 1),
#  ('said_yes_it', 1),
#  ('yes_it_brought', 1),
#  ('it_brought_promptlyi', 1),
#  ('brought_promptlyi_told', 1),
#  ('promptlyi_told_inform', 1),
#  ('told_inform_staff', 1),
#  ('inform_staff_product', 1),
#  ('staff_product_found', 1),
#  ('product_found_waffle', 1),
#  ('found_waffle_thin', 1),
#  ('waffle_thin_tastelessnot', 1),
#  ('thin_tastelessnot_like', 1),
#  ('tastelessnot_like_old', 1),
#  ('like_old_farmer', 1),
#  ('boy_restaurant_also', 1),
#  ('restaurant_also_asked', 1),
#  ('also_asked_orders', 1),
#  ('asked_orders_delayed', 1),
#  ('orders_delayed_manager', 1),
#  ('delayed_manager_said', 1),
#  ('manager_said_working', 1),
#  ('said_working_waffle', 1),
#  ('working_waffle_maker', 1),
#  ('waffle_maker_also', 1),
#  ('maker_also_working', 1),
#  ('also_working_kitchen', 1),
#  ('working_kitchen_systems', 1),
#  ('kitchen_systems_wellwell', 1),
#  ('systems_wellwell_would', 1),
#  ('wellwell_would_think', 1),
#  ('think_would_work', 1),
#  ('would_work_problems', 1),
#  ('work_problems_opening', 1),
#  ('problems_opening_restaurant', 1),
#  ('opening_restaurant_business', 1),
#  ('restaurant_business_many', 1),
#  ('business_many_years', 1),
#  ('many_years_returning', 1),
#  ('years_returning_though', 1),
#  ('returning_though_comp', 1),
#  ('though_comp_meal', 1),
#  ('comp_meal_only', 1),
#  ('meal_only_adore', 1),
#  ('only_adore_inn', 1),
#  ('adore_inn_burgers', 1),
#  ('inn_burgers_get', 1),
#  ('burgers_get_animal', 1),
#  ...]

# %% [markdown]
# ### Deli

# %%
Deli = business_df[business_df.Type=='Deli']
Deli_review = review1[review1.business_id.isin(Deli.business_id.values)]
Deli_review["text"] = Deli_review["text"].str.lower()
Deli_review['text'] = Deli_review['text'].apply(lambda text: cleaning_stopwords(text))
Deli_review['text']= Deli_review['text'].apply(lambda x: cleaning_punctuations(x))
Deli_review['text'] = Deli_review['text'].apply(lambda x: cleaning_repeating_char(x))
Deli_review['text'] = Deli_review['text'].apply(lambda x: cleaning_URLs(x))
Deli_review['text'] = Deli_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Deli=Deli[Deli.stars<3.5]
bad_Deli_review = Deli_review[Deli_review.business_id.isin(bad_Deli.business_id.values)]
bad_Deli_review_text = bad_Deli_review.text.str.cat(sep = " ")
bad_Deli_tokens = word_tokenize(bad_Deli_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_bad_Deli = ["_".join(item) for item in nltk.bigrams(bad_Deli_tokens)]
trigrams_list_bad_Deli = ["_".join(item) for item in nltk.trigrams(bad_Deli_tokens)]
FreqDist(bigrams_list_bad_Deli).most_common()
# FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('jersey_mikes', 72),
#  ('customer_service', 40),
#  ('santa_barbara', 34),
#  ('mikes_way', 24),
#  ('breakfast_burritos', 19),
#  ('sams_go', 16),
#  ('go_back', 15),
#  ('breakfast_burrito', 15),
#  ('south_coast', 14),
#  ('cheese_steak', 13),
#  ('every_time', 13),
#  ('behind_counter', 13),
#  ('coast_deli', 13),
#  ('first_time', 12),
#  ('sandwich_shop', 11),
#  ('across_street', 11),
#  ('really_good', 11),
#  ('white_bread', 10),
#  ('would_like', 10),
#  ('coming_back', 9),
#  ('eat_sandwich', 9),
#  ('roast_beef', 9),
#  ('years_ago', 9),
#  ('good_sandwiches', 9),
#  ('love_jersey', 8),
#  ('ive_ever', 8),
#  ('good_food', 8),
#  ('make_sandwich', 8),
#  ('come_back', 8),
#  ('wheat_bread', 8),
#  ('making_sandwich', 8),
#  ('around_corner', 8),
#  ('much_better', 8),
#  ('italian_deli', 8),
#  ('can_not', 7),
#  ('went_back', 7),
#  ('im_sure', 7),
#  ('walking_distance', 7),
#  ('pick_up', 7),
#  ('friendly_staff', 7),
#  ('grab_go', 7),
#  ('ever_had', 7),
#  ('staff_friendly', 7),
#  ('online_order', 7),
#  ('salad_sandwich', 7),
#  ('honey_mustard', 7),
#  ('ive_never', 6),
#  ('love_place', 6),
#  ('state_street', 6),
#  ('place_eat', 6),
#  ('food_great', 6),
#  ('get_sandwiches', 6),
#  ('like_subway', 6),
#  ('italian_sandwich', 6),
#  ('sandwiches_good', 6),
#  ('food_good', 6),
#  ('making_sandwiches', 6),
#  ('write_review', 6),
#  ('next_time', 6),
#  ('best_sandwiches', 6),
#  ('ordered_sandwich', 6),
#  ('get_sandwich', 6),
#  ('italian_sub', 6),
#  ('last_time', 6),
#  ('staff_always', 6),
#  ('great_food', 6),
#  ('fast_food', 6),
#  ('sandwich_good', 6),
#  ('never_go', 6),
#  ('good_selection', 6),
#  ('pretty_much', 6),
#  ('order_online', 6),
#  ('made_order', 6),
#  ('whole_foods', 6),
#  ('cantwells_market', 6),
#  ('la_quinta', 6),
#  ('grocery_store', 6),
#  ('subway_quiznos', 5),
#  ('oil_vinegar', 5),
#  ('young_man', 5),
#  ('philly_cheese', 5),
#  ('great_place', 5),
#  ('make_food', 5),
#  ('mikes_subs', 5),
#  ('next_day', 5),
#  ('place_clean', 5),
#  ('going_back', 5),
#  ('make_sure', 5),
#  ('feel_like', 5),
#  ('great_customer', 5),
#  ('better_subway', 5),
#  ('deli_sandwiches', 5),
#  ('sandwich_made', 5),
#  ('terrible_customer', 5),
#  ('one_best', 5),
#  ('got_home', 5),
#  ('could_get', 5),
#  ('service_terrible', 5),
#  ('great_sandwiches', 5),
#  ('got_ta', 5),
#  ('quick_lunch', 5),
#  ('said_no', 5),
#  ('placed_order', 5),
#  ('looks_like', 5),
#  ('great_selection', 5),
#  ('cantwells_deli', 5),
#  ('egg_salad', 5),
#  ('sandwiches_made', 5),
#  ('pretty_good', 5),
#  ('came_back', 5),
#  ('bad_experience', 4),
#  ('would_never', 4),
#  ('get_one', 4),
#  ('high_school', 4),
#  ('friendly_helpful', 4),
#  ('nice_place', 4),
#  ('back_great', 4),
#  ('great_little', 4),
#  ('right_front', 4),
#  ('get_food', 4),
#  ('making_food', 4),
#  ('big_kahuna', 4),
#  ('sub_sandwich', 4),
#  ('one_employee', 4),
#  ('multiple_times', 4),
#  ('place_grab', 4),
#  ('sub_place', 4),
#  ('way_much', 4),
#  ('sandwiches_always', 4),
#  ('lettuce_tomatoes', 4),
#  ('really_bad', 4),
#  ('much_meat', 4),
#  ('pastrami_sandwich', 4),
#  ('definitely_recommend', 4),
#  ('highly_recommend', 4),
#  ('shopping_center', 4),
#  ('spend_money', 4),
#  ('ill_never', 4),
#  ('time_im', 4),
#  ('sure_get', 4),
#  ('sub_sandwiches', 4),
#  ('always_get', 4),
#  ('olive_oil', 4),
#  ('second_time', 4),
#  ('always_great', 4),
#  ('go_lunch', 4),
#  ('super_friendly', 4),
#  ('get_order', 4),
#  ('sandwiches_ive', 4),
#  ('jersey_mike', 4),
#  ('bacon_avocado', 4),
#  ('taste_good', 4),
#  ('taste_like', 4),
#  ('great_service', 4),
#  ('order_could', 4),
#  ('best_sub', 4),
#  ('it_love', 4),
#  ('year_old', 4),
#  ('tasty_sandwiches', 4),
#  ('im_happy', 4),
#  ('felt_like', 4),
#  ('everything_else', 4),
#  ('would_love', 4),
#  ('half_price', 4),
#  ('customers_order', 4),
#  ('cash_register', 4),
#  ('said_yes', 4),
#  ('look_like', 4),
#  ('next_door', 4),
#  ('chips_drink', 4),
#  ('used_love', 4),
#  ('size_sandwich', 4),
#  ('even_though', 4),
#  ('place_since', 4),
#  ('items_like', 4),
#  ('could_tell', 4),
#  ('thank_you', 4),
#  ('love_cantwells', 4),
#  ('walk_around', 4),
#  ('corner_market', 4),
#  ('go_there', 4),
#  ('dutch_crunch', 4),
#  ('every_day', 4),
#  ('waste_money', 4),
#  ('little_market', 4),
#  ('well_stocked', 4),
#  ('seating_area', 4),
#  ('deli_sandwich', 4),
#  ('decent_selection', 4),
#  ('order_sandwiches', 4),
#  ('neighborhood_market', 4),
#  ('wine_selection', 4),
#  ('new_owners', 4),
#  ('back_room', 4),
#  ('quality_food', 4),
#  ('days_old', 4),
#  ('sandwich_ive', 4),
#  ('market_deli', 4),
#  ('food_service', 4),
#  ('check_out', 4),
#  ('go_store', 4),
#  ('ive_going', 4),
#  ('tuna_sandwich', 4),
#  ('give_place', 4),
#  ('threw_away', 4),
#  ('go_food', 4),
#  ('eat_here', 4),
#  ('like_it', 4),
#  ('soaking_wet', 4),
#  ('cold_cuts', 4),
#  ('old_tinos', 4),
#  ('tinos_sandwich', 4),
#  ('always_fresh', 3),
#  ('sandwich_mikes', 3),
#  ('never_bad', 3),
#  ('experience_here', 3),
#  ('sandwiches_place', 3),
#  ('never_eat', 3),
#  ('quality_ingredients', 3),
#  ('turkey_cheese', 3),
#  ('lettuce_tomato', 3),
#  ('girl_works', 3),
#  ('new_york', 3),
#  ('steak_sandwich', 3),
#  ('real_deal', 3),
#  ('people_working', 3),
#  ('restaurant_business', 3),
#  ('better_quality', 3),
#  ('get_good', 3),
#  ('owner_abe', 3),
#  ('street_parking', 3),
#  ('usually_get', 3),
#  ('favorite_place', 3),
#  ('guy_making', 3),
#  ('service_quality', 3),
#  ('worth_price', 3),
#  ('get_mikes', 3),
#  ('cant_see', 3),
#  ('meat_cheese', 3),
#  ('nothing_special', 3),
#  ('time_go', 3),
#  ('go_elsewhere', 3),
#  ('working_behind', 3),
#  ('seems_like', 3),
#  ('one_guy', 3),
#  ('grab_quick', 3),
#  ('really_nice', 3),
#  ('back_go', 3),
#  ('back_jersey', 3),
#  ('ordered_hot', 3),
#  ('giant_sandwich', 3),
#  ('decided_get', 3),
#  ('giant_subs', 3),
#  ('looked_like', 3),
#  ('good_subway', 3),
#  ('guys_working', 3),
#  ('still_waiting', 3),
#  ('time_money', 3),
#  ('nothing_really', 3),
#  ('unless_want', 3),
#  ('employees_working', 3),
#  ('everyone_business', 3),
#  ('particular_location', 3),
#  ('time_going', 3),
#  ('decided_go', 3),
#  ('went_pick', 3),
#  ('would_say', 3),
#  ('service_highly', 3),
#  ('short_lady', 3),
#  ('ew_ew', 3),
#  ('three_pickles', 3),
#  ('never_back', 3),
#  ('woman_working', 3),
#  ('ill_go', 3),
#  ('im_huge', 3),
#  ('tasted_good', 3),
#  ('sandwiches_since', 3),
#  ('order_sandwich', 3),
#  ('sandwiches_however', 3),
#  ('time_went', 3),
#  ('service_good', 3),
#  ('would_give', 3),
#  ('wash_hands', 3),
#  ('order_got', 3),
#  ('keep_going', 3),
#  ('time_ive', 3),
#  ('ive_come', 3),
#  ('get_anything', 3),
#  ('anything_would', 3),
#  ('fresh_food', 3),
#  ('like_place', 3),
#  ('right_around', 3),
#  ('mikes_sure', 3),
#  ('regular_customer', 3),
#  ('lunch_time', 3),
#  ('staff_amazing', 3),
#  ('store_always', 3),
#  ('beef_sandwich', 3),
#  ('regular_size', 3),
#  ('always_go', 3),
#  ('go_sams', 3),
#  ('delicious_sandwich', 3),
#  ('sandwich_got', 3),
#  ('bread_fresh', 3),
#  ('food_delicious', 3),
#  ('delicious_place', 3),
#  ('good_service', 3),
#  ('place_get', 3),
#  ('really_great', 3),
#  ('sandwiches_delicious', 3),
#  ('took_order', 3),
#  ('ever_go', 3),
#  ('staff_awesome', 3),
#  ('best_sandwich', 3),
#  ('lunch_dinner', 3),
#  ('best_part', 3),
#  ('sandwich_assembler', 3),
#  ('waiting_minutes', 3),
#  ('customers_present', 3),
#  ('go_goleta', 3),
#  ('would_go', 3),
#  ('make_sandwiches', 3),
#  ('looks_pissed', 3),
#  ('rude_customer', 3),
#  ('service_usually', 3),
#  ('throw_away', 3),
#  ('options_available', 3),
#  ('great_quality', 3),
#  ('pick_sandwiches', 3),
#  ('large_order', 3),
#  ('place_order', 3),
#  ('thin_slices', 3),
#  ('axxess_deal', 3),
#  ('order_asked', 3),
#  ('back_work', 3),
#  ('sandwiches_eat', 3),
#  ('great_meal', 3),
#  ('one_two', 3),
#  ('two_young', 3),
#  ('ive_ordered', 3),
#  ('ordered_couple', 3),
#  ('ready_time', 3),
#  ('sandwich_cut', 3),
#  ('black_hair', 3),
#  ('selection_sandwiches', 3),
#  ('prices_reasonable', 3),
#  ('almost_years', 3),
#  ('right_away', 3),
#  ('long_time', 3),
#  ('people_line', 3),
#  ('minutes_get', 3),
#  ('say_anything', 3),
#  ('treated_like', 3),
#  ('nearly_good', 3),
#  ('spanish_man', 3),
#  ('sandwich_like', 3),
#  ('everything_super', 3),
#  ('local_market', 3),
#  ('market_great', 3),
#  ('chips_cookies', 3),
#  ('go_south', 3),
#  ('deli_around', 3),
#  ('two_sandwiches', 3),
#  ('time_ever', 3),
#  ('half_sandwich', 3),
#  ('new_manager', 3),
#  ('corner_store', 3),
#  ('freshly_made', 3),
#  ('place_great', 3),
#  ('used_get', 3),
#  ('couple_dollars', 3),
#  ('good_breakfast', 3),
#  ('used_go', 3),
#  ('worth_it', 3),
#  ('good_thing', 3),
#  ('makes_sandwich', 3),
#  ('gluten_free', 3),
#  ('anywhere_else', 3),
#  ('sandwiches_really', 3),
#  ('tasted_like', 3),
#  ('quick_sandwich', 3),
#  ('sandwiches_breakfast', 3),
#  ('say_best', 3),
#  ('friendly_great', 3),
#  ('rather_go', 3),
#  ('nice_little', 3),
#  ('used_great', 3),
#  ('past_years', 3),
#  ('finish_one', 3),
#  ('quick_bite', 3),
#  ('deli_items', 3),
#  ('street_place', 3),
#  ('potato_salad', 3),
#  ('place_would', 3),
#  ('grocery_stores', 3),
#  ('quinta_inn', 3),
#  ('love_market', 3),
#  ('time_girl', 3),
#  ('health_food', 3),
#  ('sandwiches_go', 3),
#  ('buy_anything', 3),
#  ('get_refund', 3),
#  ('deli_case', 3),
#  ('around_store', 3),
#  ('two_years', 3),
#  ('id_like', 3),
#  ('around_pm', 3),
#  ('reasonable_prices', 3),
#  ('ham_cheese', 3),
#  ('always_friendly', 3),
#  ('service_great', 3),
#  ('staff_nice', 3),
#  ('told_could', 3),
#  ('front_me', 3),
#  ('place_completely', 3),
#  ('buy_sandwiches', 3),
#  ('location_would', 3),
#  ('counter_said', 3),
#  ('could_see', 3),
#  ('gone_way', 3),
#  ('fast_service', 3),
#  ('back_subway', 3),
#  ('cant_get', 3),
#  ('one_customers', 3),
#  ('ordering_online', 3),
#  ('tried_eat', 3),
#  ('fresh_tuna', 3),
#  ('one_time', 3),
#  ('im_writing', 3),
#  ('writing_review', 3),
#  ('extra_meat', 3),
#  ('go_iv', 3),
#  ('way_better', 3),
#  ('times_last', 3),
#  ('one_favorite', 2),
#  ('favorite_sandwich', 2),
#  ('sandwich_shops', 2),
#  ('love_bread', 2),
#  ('way_go', 2),
#  ('really_like', 2),
#  ('rewards_program', 2),
#  ('get_free', 2),
#  ('clean_people', 2),
#  ('sandwiches_great', 2),
#  ('personal_favorite', 2),
#  ('free_sandwiches', 2),
#  ('place_everyone', 2),
#  ('everyone_giving', 2),
#  ('better_jersey', 2),
#  ('huge_fan', 2),
#  ('delicious_sub', 2),
#  ('young_girl', 2),
#  ('dirty_looks', 2),
#  ('customer_never', 2),
#  ('customer_ever', 2),
#  ('never_return', 2),
#  ('thing_could', 2),
#  ('hate_job', 2),
#  ('job_got', 2),
#  ('tried_philly', 2),
#  ('new_jersey', 2),
#  ('know_real', 2),
#  ('eat_it', 2),
#  ('also_clean', 2),
#  ('dirty_tables', 2),
#  ('good_luck', 2),
#  ('hard_work', 2),
#  ('get_better', 2),
#  ('else_make', 2),
#  ('coming_since', 2),
#  ('sandwiches_burgers', 2),
#  ('always_point', 2),
#  ('watch_game', 2),
#  ('local_spot', 2),
#  ('recommended_place', 2),
#  ('overall_love', 2),
#  ('little_local', 2),
#  ('parking_lot', 2),
#  ('parking_available', 2),
#  ('seem_little', 2),
#  ('food_well', 2),
#  ('food_go', 2),
#  ('good_place', 2),
#  ('eat_first', 2),
#  ('food_seemed', 2),
#  ('sandwich_bread', 2),
#  ('camino_real', 2),
#  ('different_experience', 2),
#  ('mikes_location', 2),
#  ('hot_sub', 2),
#  ('wish_could', 2),
#  ('really_cant', 2),
#  ('way_thank', 2),
#  ('keep_wanting', 2),
#  ('raised_prices', 2),
#  ('prices_sandwiches', 2),
#  ('little_meat', 2),
#  ('hate_this', 2),
#  ('place_much', 2),
#  ('leave_tip', 2),
#  ('lower_prices', 2),
#  ('like_owner', 2),
#  ('times_always', 2),
#  ('come_on', 2),
#  ('get_right', 2),
#  ('stop_eating', 2),
#  ('eating_there', 2),
#  ('vinegar_spices', 2),
#  ('like_lettuce', 2),
#  ('like_driving', 2),
#  ('definitely_recommended', 2),
#  ('decent_place', 2),
#  ('employees_really', 2),
#  ('good_idea', 2),
#  ('forget_put', 2),
#  ('people_work', 2),
#  ('great_subs', 2),
#  ('bit_pricey', 2),
#  ('bacon_sandwich', 2),
#  ('place_staff', 2),
#  ('staff_really', 2),
#  ('sure_still', 2),
#  ('sandwich_later', 2),
#  ('ordered_one', 2),
#  ('pretty_tasty', 2),
#  ('go_big', 2),
#  ('also_employees', 2),
#  ('so_really', 2),
#  ('really_need', 2),
#  ('subway_least', 2),
#  ('least_food', 2),
#  ('sandwich_full', 2),
#  ('subway_cheaper', 2),
#  ('choices_love', 2),
#  ('freshly_sliced', 2),
#  ('reason_stars', 2),
#  ('little_expensive', 2),
#  ('ill_always', 2),
#  ('saying_could', 2),
#  ('sandwich_since', 2),
#  ('pretty_big', 2),
#  ('could_save', 2),
#  ('original_italian', 2),
#  ('onions_lettuce', 2),
#  ('got_italian', 2),
#  ('also_pretty', 2),
#  ('last_half', 2),
#  ('worth_money', 2),
#  ('street_get', 2),
#  ('get_giant', 2),
#  ('difficult_make', 2),
#  ('sandwich_one', 2),
#  ('one_front', 2),
#  ('front_two', 2),
#  ('two_guys', 2),
#  ('counter_taking', 2),
#  ('taking_forever', 2),
#  ('forever_im', 2),
#  ('im_still', 2),
#  ('waiting_sandwich', 2),
#  ('sandwich_write', 2),
#  ('review_im', 2),
#  ('im_looking', 2),
#  ('looking_sit', 2),
#  ('sit_looks', 2),
#  ('meat_sub', 2),
#  ('worth_time', 2),
#  ('money_sad', 2),
#  ('sad_jersey', 2),
#  ('mikes_usually', 2),
#  ('usually_decent', 2),
#  ('said_wow', 2),
#  ('bread_choices', 2),
#  ('would_great', 2),
#  ('wrong_sandwich', 2),
#  ('up_sandwiches', 2),
#  ('sandwiches_chips', 2),
#  ('chips_soda', 2),
#  ('fan_jersey', 2),
#  ('guy_employee', 2),
#  ('were_closed', 2),
#  ('sandwich_making', 2),
#  ('ive_worked', 2),
#  ('could_care', 2),
#  ('care_less', 2),
#  ('job_care', 2),
#  ('rude_unprofessional', 2),
#  ('turned_around', 2),
#  ('get_wrong', 2),
#  ('hit_spot', 2),
#  ('still_open', 2),
#  ('us_making', 2),
#  ('making_us', 2),
#  ('proceeded_make', 2),
#  ('im_saying', 2),
#  ('saying_food', 2),
#  ('food_come', 2),
#  ('service_order', 2),
#  ('could_put', 2),
#  ('portion_meat', 2),
#  ('meat_one', 2),
#  ('one_would', 2),
#  ('happy_experience', 2),
#  ('experience_jersey', 2),
#  ('better_customer', 2),
#  ('first_week', 2),
#  ('staff_seem', 2),
#  ('walked_short', 2),
#  ('lady_glasses', 2),
#  ('without_washing', 2),
#  ('finger_prints', 2),
#  ('something_like', 2),
#  ('far_superior', 2),
#  ('say_quality', 2),
#  ('pickles_south', 2),
#  ('deli_come', 2),
#  ('come_mind', 2),
#  ('warm_sandwiches', 2),
#  ('good_sandwich', 2),
#  ('amazing_bread', 2),
#  ('delicious_ingredients', 2),
#  ('ingredients_fresh', 2),
#  ('fresh_cut', 2),
#  ('front_you', 2),
#  ('way_ok', 2),
#  ('although_think', 2),
#  ('think_food', 2),
#  ('good_job', 2),
#  ('since_first', 2),
#  ('disappointed_jersey', 2),
#  ('made_thin', 2),
#  ('melted_cheese', 2),
#  ('thinly_sliced', 2),
#  ('grilled_onions', 2),
#  ('good_never', 2),
#  ('ordered_regular', 2),
#  ('sandwiches_sandwiches', 2),
#  ('going_jersey', 2),
#  ('sb_jersey', 2),
#  ('red_wine', 2),
#  ('wine_vinegar', 2),
#  ('vinegar_olive', 2),
#  ('ive_locations', 2),
#  ('went_in', 2),
#  ('me_one', 2),
#  ('definitely_returning', 2),
#  ('axxess_card', 2),
#  ('use_it', 2),
#  ('it_ordered', 2),
#  ('tomato_onion', 2),
#  ('made_perfect', 2),
#  ('philly_cheesesteak', 2),
#  ('sandwiches_area', 2),
#  ('give_star', 2),
#  ('preparing_food', 2),
#  ('would_come', 2),
#  ('back_service', 2),
#  ('employees_every', 2),
#  ('came_last', 2),
#  ('place_sit', 2),
#  ('sandwich_im', 2),
#  ('putting_toppings', 2),
#  ('make_money', 2),
#  ('great_sandwich', 2),
#  ('sandwich_though', 2),
#  ('staff_great', 2),
#  ('yummy_sandwiches', 2),
#  ('service_bad', 2),
#  ('orders_wrong', 2),
#  ('order_correct', 2),
#  ('save_money', 2),
#  ('store_goleta', 2),
#  ('like_made', 2),
#  ('order_first', 2),
#  ('said_needed', 2),
#  ('third_time', 2),
#  ('idiot_owners', 2),
#  ('good_sign', 2),
#  ('chicken_bacon', 2),
#  ('recommend_sandwich', 2),
#  ('sub_go', 2),
#  ('new_employees', 2),
#  ('came_lunch', 2),
#  ('sandwich_lettuce', 2),
#  ('love_coming', 2),
#  ('nice_helpful', 2),
#  ('well_thats', 2),
#  ('first_all', 2),
#  ('ok_well', 2),
#  ('time_always', 2),
#  ('order_made', 2),
#  ('theres_good', 2),
#  ('good_chain', 2),
#  ('service_workers', 2),
#  ('asked_for', 2),
#  ('die_for', 2),
#  ('super_good', 2),
#  ('sandwich_wrong', 2),
#  ('wrong_place', 2),
#  ('made_sandwich', 2),
#  ('chicken_wrap', 2),
#  ('made_fresh', 2),
#  ('love_sams', 2),
#  ('ladies_work', 2),
#  ('very_hard', 2),
#  ('get_italian', 2),
#  ('italian_dressing', 2),
#  ('got_good', 2),
#  ('sandwich_ate', 2),
#  ('stars_last', 2),
#  ('sandwich_great', 2),
#  ('are_however', 2),
#  ('always_make', 2),
#  ('sandwich_right', 2),
#  ('mikes_one', 2),
#  ('one_go', 2),
#  ('go_to', 2),
#  ('sandwich_could', 2),
#  ('another_sandwich', 2),
#  ('group_people', 2),
#  ('people_ever', 2),
#  ('order_almost', 2),
#  ('reading_this', 2),
#  ('better_going', 2),
#  ('supporting_local', 2),
#  ('subs_always', 2),
#  ('thank_making', 2),
#  ('sandwich_town', 2),
#  ('good_variety', 2),
#  ('pay_attention', 2),
#  ('dont_ask', 2),
#  ('helpful_staff', 2),
#  ('sandwiches_fries', 2),
#  ('ordered_staff', 2),
#  ('avocado_bacon', 2),
#  ('right_amount', 2),
#  ('long_take', 2),
#  ('either_start', 2),
#  ('lunch_rush', 2),
#  ('food_always', 2),
#  ('always_good', 2),
#  ('good_staff', 2),
#  ('excited_try', 2),
#  ('sandwiches_took', 2),
#  ('ten_minutes', 2),
#  ('food_fresh', 2),
#  ('hot_sandwich', 2),
#  ('want_go', 2),
#  ('go_home', 2),
#  ('theyre_supposed', 2),
#  ('closing_time', 2),
#  ('attitudes_really', 2),
#  ('go_jersey', 2),
#  ('subway_anywhere', 2),
#  ('sandwiches_man', 2),
#  ('order_wrong', 2),
#  ('several_times', 2),
#  ('worked_fast', 2),
#  ('work_lunch', 2),
#  ('ca_visit', 2),
#  ('visit_ucsb', 2),
#  ('dont_know', 2),
#  ('sets_aside', 2),
#  ('out_never', 2),
#  ('please_get', 2),
#  ('get_oil', 2),
#  ('yr_old', 2),
#  ('terrible_service', 2),
#  ('food_coming', 2),
#  ('use_restroom', 2),
#  ('rushed_us', 2),
#  ('time_day', 2),
#  ('day_go', 2),
#  ('come_here', 2),
#  ('amount_meat', 2),
#  ('back_one', 2),
#  ('sandwiches_fresh', 2),
#  ('fresh_delicious', 2),
#  ('food_absolutely', 2),
#  ('eat_again', 2),
#  ('ashley_beaty', 2),
#  ('service_called', 2),
#  ('september_th', 2),
#  ('chips_drinks', 2),
#  ('touch_something', 2),
#  ('one_ever', 2),
#  ('answer_phone', 2),
#  ('get_business', 2),
#  ('god_knows', 2),
#  ('knows_long', 2),
#  ('simple_order', 2),
#  ('quality_service', 2),
#  ('service_im', 2),
#  ('price_im', 2),
#  ('theyve_always', 2),
#  ('one_side', 2),
#  ('side_would', 2),
#  ('cant_use', 2),
#  ('elementary_school', 2),
#  ('wish_would', 2),
#  ('take_forever', 2),
#  ('decent_sandwich', 2),
#  ('nice_people', 2),
#  ('eat_inside', 2),
#  ('service_dog', 2),
#  ('back_again', 2),
#  ('made_online', 2),
#  ('up_said', 2),
#  ('pick_order', 2),
#  ('hes_back', 2),
#  ('work_cashier', 2),
#  ('minutes_asked', 2),
#  ('order_said', 2),
#  ('another_customer', 2),
#  ('asked_again', 2),
#  ('co_worker', 2),
#  ('name_order', 2),
#  ('order_counter', 2),
#  ('minutes_waiting', 2),
#  ('order_pick', 2),
#  ('mikes_great', 2),
#  ('location_always', 2),
#  ('here_go', 2),
#  ('recommend_anybody', 2),
#  ('sandwich_place', 2),
#  ('staff_fast', 2),
#  ('never_issues', 2),
#  ('issues_here', 2),
#  ('couple_times', 2),
#  ('rarely_go', 2),
#  ('gets_busy', 2),
#  ('ill_drive', 2),
#  ('chipotle_cheesesteak', 2),
#  ('went_today', 2),
#  ('without_gloves', 2),
#  ('going_sandwiches', 2),
#  ('go_get', 2),
#  ('new_staff', 2),
#  ('asked_could', 2),
#  ('could_make', 2),
#  ('would_pay', 2),
#  ('beef_pastrami', 2),
#  ('size_sandwiches', 2),
#  ('asked_sandwich', 2),
#  ('like_chips', 2),
#  ('anything_else', 2),
#  ('minutes_closing', 2),
#  ('time_even', 2),
#  ('great_friendly', 2),
#  ('friendly_service', 2),
#  ('got_response', 2),
#  ('response_emailed', 2),
#  ('time_finally', 2),
#  ('finally_got', 2),
#  ('great_price', 2),
#  ('burgers_also', 2),
#  ('charge_much', 2),
#  ('solid_sandwich', 2),
#  ('sandwich_supposed', 2),
#  ('checking_out', 2),
#  ('looking_forward', 2),
#  ('one_employees', 2),
#  ('wearing_mask', 2),
#  ('customers_tried', 2),
#  ('told_get', 2),
#  ('want_spend', 2),
#  ('ham_roast', 2),
#  ('chicken_club', 2),
#  ('since_moved', 2),
#  ('old_son', 2),
#  ('turkey_sub', 2),
#  ('glad_see', 2),
#  ('lunch_ordered', 2),
#  ('right_next', 2),
#  ('hard_make', 2),
#  ('get_it', 2),
#  ('took_minutes', 2),
#  ('place_sandwiches', 2),
#  ('sandwiches_cold', 2),
#  ('lady_making', 2),
#  ('touching_everything', 2),
#  ('want_say', 2),
#  ('always_nice', 2),
#  ('one_get', 2),
#  ('place_looks', 2),
#  ('asked_lady', 2),
#  ('lady_working', 2),
#  ('poor_customer', 2),
#  ('sandwich_ask', 2),
#  ('say_yes', 2),
#  ('sandwichmaking_evildoer', 2),
#  ('looked_said', 2),
#  ('card_pay', 2),
#  ('ahead_me', 2),
#  ('made_feel', 2),
#  ('took_sandwich', 2),
#  ('begin_with', 2),
#  ('made_way', 2),
#  ('way_asked', 2),
#  ('fountain_drink', 2),
#  ('pepsi_coke', 2),
#  ('paid_sandwich', 2),
#  ('call_me', 2),
#  ('extra_charges', 2),
#  ('ask_wanted', 2),
#  ('left_could', 2),
#  ('around_telling', 2),
#  ('im_going', 2),
#  ('need_attitude', 2),
#  ('business_think', 2),
#  ('bread_pudding', 2),
#  ('sat_eat', 2),
#  ('older_gentleman', 2),
#  ('forget_it', 2),
#  ('recommend_place', 2),
#  ('get_turkey', 2),
#  ('also_veggie', 2),
#  ('amazing_service', 2),
#  ('good_always', 2),
#  ('service_nothing', 2),
#  ('better_deal', 2),
#  ('back_here', 2),
#  ('within_walking', 2),
#  ('distance_cantwells', 2),
#  ('cantwells_im', 2),
#  ('super_fresh', 2),
#  ('fresh_really', 2),
#  ('get_lunch', 2),
#  ('great_local', 2),
#  ('ok_small', 2),
#  ('small_market', 2),
#  ('hot_breakfast', 2),
#  ('vegan_snacks', 2),
#  ('saw_two', 2),
#  ('two_stars', 2),
#  ('go_here', 2),
#  ('years_convenient', 2),
#  ('convenient_location', 2),
#  ('sandwich_order', 2),
#  ('eaten_half', 2),
#  ('sandwich_manager', 2),
#  ('half_it', 2),
#  ('would_different', 2),
#  ('shed_charge', 2),
#  ('charge_half', 2),
#  ('andor_new', 2),
#  ('one_day', 2),
#  ('bad_taste', 2),
#  ('taste_mouth', 2),
#  ('sandwiches_also', 2),
#  ('walked_door', 2),
#  ('deli_great', 2),
#  ('sandwich_never', 2),
#  ('go_cantwells', 2),
#  ('impressed_selection', 2),
#  ('selection_freshly', 2),
#  ('lunch_snack', 2),
#  ('deli_place', 2),
#  ('go_even', 2),
#  ('sandwiches_hot', 2),
#  ('hot_cold', 2),
#  ('though_little', 2),
#  ('place_definitely', 2),
#  ('come_close', 2),
#  ('close_house', 2),
#  ('stop_quick', 2),
#  ('prices_high', 2),
#  ('get_breakfast', 2),
#  ('great_coffee', 2),
#  ('employees_super', 2),
#  ('really_hungry', 2),
#  ('whole_thing', 2),
#  ('sweet_bavarian', 2),
#  ('hits_spot', 2),
#  ('new_yorker', 2),
#  ('good_know', 2),
#  ('turkey_ham', 2),
#  ('fresh_crab', 2),
#  ('forever_make', 2),
#  ('service_ever', 2),
#  ('burrito_go', 2),
#  ('block_away', 2),
#  ('service_always', 2),
#  ('right_across', 2),
#  ('disappointed_customer', 2),
#  ('market_back', 2),
#  ('employees_respectful', 2),
#  ('last_year', 2),
#  ('total_waste', 2),
#  ('cant_make', 2),
#  ('lunch_delicious', 2),
#  ('fresh_sandwiches', 2),
#  ('time_wait', 2),
#  ('deli_makes', 2),
#  ('prices_outrageous', 2),
#  ('staff_good', 2),
#  ('lots_yummy', 2),
#  ('someplace_else', 2),
#  ('tritip_sandwich', 2),
#  ('cantwells_definitely', 2),
#  ...]

# %%
good_Deli=Deli[Deli.stars>=4.5]
good_Deli_review = Deli_review[Deli_review.business_id.isin(good_Deli.business_id.values)]
good_Deli_review_text = good_Deli_review.text.str.cat(sep = " ")
good_Deli_tokens = word_tokenize(good_Deli_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_good_Deli = ["_".join(item) for item in nltk.bigrams(good_Deli_tokens)]
trigrams_list_good_Deli = ["_".join(item) for item in nltk.trigrams(good_Deli_tokens)]
# FreqDist(bigrams_list_good_Deli).most_common()
FreqDist(trigrams_list_good_Deli).most_common()
# Out:
# [('south_coast_deli', 123),
#  ('chipotle_turkey_club', 123),
#  ('ive_ever_had', 94),
#  ('crispy_chicken_west', 52),
#  ('gluten_free_bread', 49),
#  ('great_customer_service', 48),
#  ('cant_go_wrong', 46),
#  ('grilled_cheese_tomato', 41),
#  ('definitely_coming_back', 40),
#  ('definitely_come_back', 36),
#  ('prosciutto_brie_sandwich', 35),
#  ('next_time_im', 34),
#  ('staff_super_friendly', 34),
#  ('highly_recommend_place', 34),
#  ('tomato_bisque_soup', 34),
#  ('best_ive_ever', 33),
#  ('downtown_santa_barbara', 32),
#  ('chicken_walnut_pesto', 32),
#  ('gluten_free_options', 32),
#  ('back_next_time', 31),
#  ('diners_driveins_dives', 31),
#  ('one_best_sandwiches', 31),
#  ('pickles_swiss_sandwich', 31),
#  ('would_definitely_recommend', 30),
#  ('sandwich_ive_ever', 29),
#  ('best_sandwiches_ive', 29),
#  ('south_coast_turkey', 29),
#  ('sandwiches_ive_ever', 28),
#  ('visiting_santa_barbara', 27),
#  ('cant_wait_go', 26),
#  ('great_food_great', 26),
#  ('best_pastrami_sandwich', 25),
#  ('best_sandwiches_ever', 25),
#  ('come_back_try', 24),
#  ('sandwich_ever_had', 24),
#  ('would_highly_recommend', 24),
#  ('dill_pickle_popcorn', 24),
#  ('cant_wait_come', 23),
#  ('spicy_crunch_baguette', 23),
#  ('pulled_pork_sandwich', 23),
#  ('chicken_pesto_panini', 23),
#  ('cheese_tomato_bisque', 23),
#  ('wait_come_back', 22),
#  ('service_great_food', 22),
#  ('food_great_service', 22),
#  ('wait_go_back', 22),
#  ('im_santa_barbara', 22),
#  ('best_sandwich_ive', 22),
#  ('best_sandwich_ever', 22),
#  ('pot_roasted_beef', 22),
#  ('beef_au_jus', 22),
#  ('go_back_try', 21),
#  ('roasted_chicken_walnut', 21),
#  ('best_sandwich_shop', 20),
#  ('tomato_basil_soup', 20),
#  ('would_definitely_come', 19),
#  ('deli_santa_barbara', 19),
#  ('super_friendly_staff', 19),
#  ('staff_always_friendly', 19),
#  ('favorite_sandwich_shop', 19),
#  ('de_la_guerra', 19),
#  ('amazing_customer_service', 19),
#  ('roast_beef_hottie', 19),
#  ('place_santa_barbara', 18),
#  ('try_something_else', 18),
#  ('sandwich_santa_barbara', 18),
#  ('pulled_pork_slaw', 18),
#  ('great_sandwich_shop', 17),
#  ('eat_santa_barbara', 17),
#  ('visit_santa_barbara', 17),
#  ('little_sandwich_shop', 17),
#  ('roast_beef_sandwich', 17),
#  ('walnut_pesto_panini', 17),
#  ('keep_coming_back', 17),
#  ('ordered_chipotle_turkey', 17),
#  ('chicken_chipotle_club', 17),
#  ('first_time_here', 16),
#  ('would_come_back', 16),
#  ('sandwiches_ever_had', 16),
#  ('time_santa_barbara', 16),
#  ('sandwiches_santa_barbara', 16),
#  ('best_sandwiches_town', 16),
#  ('basil_tomato_bisque', 16),
#  ('parma_chicken_spinach', 16),
#  ('every_time_come', 16),
#  ('pickles_swiss_great', 16),
#  ('chicken_salad_sandwich', 16),
#  ('pesto_chicken_salad', 16),
#  ('santa_barbara_area', 16),
#  ('pot_roast_sandwich', 16),
#  ('great_service_great', 16),
#  ('pesto_green_beans', 16),
#  ('back_santa_barbara', 15),
#  ('definitely_go_back', 15),
#  ('come_back_again', 15),
#  ('sandwich_shop_sb', 15),
#  ('best_sandwich_place', 15),
#  ('love_pickles_swiss', 15),
#  ('cheese_tomato_soup', 15),
#  ('favorite_sandwich_place', 15),
#  ('even_gave_us', 14),
#  ('best_sandwiches_santa', 14),
#  ('one_favorite_places', 14),
#  ('roasted_beef_au', 14),
#  ('sandwich_pickles_swiss', 14),
#  ('got_chipotle_turkey', 14),
#  ('trip_santa_barbara', 13),
#  ('love_love_love', 13),
#  ('diners_drive_ins', 13),
#  ('high_quality_ingredients', 13),
#  ('got_grilled_cheese', 13),
#  ('definitely_recommend_place', 13),
#  ('cant_wait_try', 13),
#  ('one_best_sandwich', 13),
#  ('fresh_high_quality', 13),
#  ('worth_every_penny', 13),
#  ('metropulos_fine_foods', 13),
#  ('would_recommend_anyone', 13),
#  ('norms_cold_cut', 13),
#  ('chicken_orzo_soup', 13),
#  ('food_always_fresh', 13),
#  ('veggie_malta_melt', 13),
#  ('dars_sky_high', 13),
#  ('mexican_chicken_caesar', 13),
#  ('chicken_caesar_salad', 13),
#  ('well_worth_it', 12),
#  ('sandwiches_great_service', 12),
#  ('best_ever_had', 12),
#  ('pastrami_sandwich_ever', 12),
#  ('drive_ins_dives', 12),
#  ('time_im_santa', 12),
#  ('sandwich_shop_santa', 12),
#  ('shop_santa_barbara', 12),
#  ('every_time_go', 12),
#  ('customer_service_great', 12),
#  ('staff_friendly_helpful', 12),
#  ('chicken_cobb_salad', 12),
#  ('pesto_chicken_sandwich', 12),
#  ('chocolate_chip_cookie', 12),
#  ('recommend_pickles_swiss', 12),
#  ('best_salad_bar', 12),
#  ('probably_one_best', 11),
#  ('chili_cheese_fries', 11),
#  ('italian_cold_cut', 11),
#  ('guys_behind_counter', 11),
#  ('best_sandwich_spot', 11),
#  ('highly_recommend_it', 11),
#  ('places_santa_barbara', 11),
#  ('recommend_anyone_looking', 11),
#  ('come_back_next', 11),
#  ('hot_cold_sandwiches', 11),
#  ('crispy_chicken_cobb', 11),
#  ('excellent_customer_service', 11),
#  ('pickle_flavored_popcorn', 11),
#  ('pot_roast_au', 11),
#  ('good_customer_service', 11),
#  ('roast_beef_au', 11),
#  ('cheese_dip_tomato', 11),
#  ('dip_tomato_bisque', 11),
#  ('sample_tomato_bisque', 11),
#  ('us_sample_tomato', 11),
#  ('chipotle_turkey_sandwich', 11),
#  ('paseo_nuevo_mall', 11),
#  ('buffalo_chicken_sandwich', 11),
#  ('great_salad_bar', 11),
#  ('friendly_staff_great', 10),
#  ('really_good_food', 10),
#  ('great_sandwiches_great', 10),
#  ('sandwich_really_good', 10),
#  ('fries_onion_rings', 10),
#  ('back_try_sandwiches', 10),
#  ('place_go_lunch', 10),
#  ('next_time_ill', 10),
#  ('definitely_going_back', 10),
#  ('keep_good_work', 10),
#  ('santa_barbara_great', 10),
#  ('best_sandwich_santa', 10),
#  ('far_best_sandwich', 10),
#  ('great_place_lunch', 10),
#  ('definitely_worth_it', 10),
#  ('really_good_sandwiches', 10),
#  ('santa_barbara_goleta', 10),
#  ('gave_us_free', 10),
#  ('ordered_crispy_chicken', 10),
#  ('grilled_cheese_dip', 10),
#  ('buffalo_chicken_sammie', 10),
#  ('savoy_cafe_deli', 10),
#  ('back_next_day', 9),
#  ('owner_super_friendly', 9),
#  ('go_wrong_anything', 9),
#  ('cold_cut_sandwich', 9),
#  ('stop_santa_barbara', 9),
#  ('every_single_time', 9),
#  ('way_santa_barbara', 9),
#  ('great_service_friendly', 9),
#  ('santa_barbara_favorite', 9),
#  ('great_food_service', 9),
#  ('great_spot_lunch', 9),
#  ('sandwiches_really_good', 9),
#  ('town_hands_down', 9),
#  ('recommend_place_anyone', 9),
#  ('around_lunch_time', 9),
#  ('outdoor_seating_area', 9),
#  ('sandwiches_highly_recommend', 9),
#  ('quick_bite_eat', 9),
#  ('every_time_im', 9),
#  ('spot_santa_barbara', 9),
#  ('new_favorite_sandwich', 9),
#  ('chicken_west_sandwich', 9),
#  ('turkey_club_sandwich', 9),
#  ('ive_ever_eaten', 9),
#  ('highly_recommend_anyone', 9),
#  ('lunch_santa_barbara', 9),
#  ('stumbled_upon_place', 9),
#  ('indoor_outdoor_seating', 9),
#  ('great_lunch_spot', 9),
#  ('great_place_grab', 9),
#  ('got_crispy_chicken', 9),
#  ('great_friendly_service', 9),
#  ('give_place_stars', 9),
#  ('tomato_bisque_amazing', 9),
#  ('customer_service_always', 9),
#  ('recommend_chipotle_turkey', 9),
#  ('amazing_gluten_free', 9),
#  ('roast_beef_horseradish', 9),
#  ('food_customer_service', 9),
#  ('order_ahead_time', 9),
#  ('santa_barbara_food', 9),
#  ('great_selection_sandwiches', 8),
#  ('time_im_sb', 8),
#  ('go_santa_barbara', 8),
#  ('ordered_moms_plt', 8),
#  ('cant_say_enough', 8),
#  ('make_sure_stop', 8),
#  ('check_place_out', 8),
#  ('pretty_much_everything', 8),
#  ('santa_barbara_go', 8),
#  ('must_try_place', 8),
#  ('stop_next_time', 8),
#  ('give_place_try', 8),
#  ('food_amazing_service', 8),
#  ('next_time_were', 8),
#  ('really_good_too', 8),
#  ('chocolate_chip_cookies', 8),
#  ('try_next_time', 8),
#  ('next_time_santa', 8),
#  ('every_time_visit', 8),
#  ('places_eat_santa', 8),
#  ('sandwich_shop_town', 8),
#  ('looking_good_sandwich', 8),
#  ('im_gon_na', 8),
#  ('get_pay_for', 8),
#  ('made_us_feel', 8),
#  ('favorite_sandwich_spot', 8),
#  ('came_across_place', 8),
#  ('time_im_town', 8),
#  ('would_go_back', 8),
#  ('ive_never_disappointed', 8),
#  ('food_fresh_delicious', 8),
#  ('would_give_stars', 8),
#  ('everything_ive_tried', 8),
#  ('sandwich_place_town', 8),
#  ('chicken_pesto_sandwich', 8),
#  ('next_time_visit', 8),
#  ('hands_best_sandwich', 8),
#  ('good_quality_food', 8),
#  ('try_something_new', 8),
#  ('best_customer_service', 8),
#  ('key_lime_pie', 8),
#  ('would_definitely_go', 8),
#  ('try_items_menu', 8),
#  ('place_grab_lunch', 8),
#  ('sun_dried_tomatoes', 8),
#  ('one_best_ive', 8),
#  ('customer_service_excellent', 8),
#  ('super_friendly_service', 8),
#  ('ordered_pickles_swiss', 8),
#  ('service_great_sandwiches', 8),
#  ('best_tomato_soup', 8),
#  ('time_pickles_swiss', 8),
#  ('white_bean_soup', 8),
#  ('crispy_chicken_sandwich', 8),
#  ('chicken_spinach_sandwich', 8),
#  ('pot_roast_beef', 8),
#  ('gave_us_sample', 8),
#  ('love_south_coast', 8),
#  ('mexican_caesar_salad', 8),
#  ('favorite_place_eat', 8),
#  ('great_little_sandwich', 8),
#  ('gluten_free_pancakes', 8),
#  ('gluten_free_vegan', 8),
#  ('gluten_free_french', 8),
#  ('free_french_toast', 8),
#  ('mango_quinoa_salad', 8),
#  ('friendly_service_great', 7),
#  ('pastrami_chili_cheese', 7),
#  ('worth_it_great', 7),
#  ('service_super_friendly', 7),
#  ('santa_barbara_first', 7),
#  ('pastrami_lettuce_tomato', 7),
#  ('place_diners_driveins', 7),
#  ('moms_plt_pastrami', 7),
#  ('santa_barbara_definitely', 7),
#  ('wrong_anything_menu', 7),
#  ('staff_friendly_accommodating', 7),
#  ('santa_barbara_looking', 7),
#  ('back_try_something', 7),
#  ('one_favorite_sandwich', 7),
#  ('definitely_back_next', 7),
#  ('overall_great_place', 7),
#  ('im_glad_did', 7),
#  ('fast_friendly_service', 7),
#  ('good_would_recommend', 7),
#  ('wish_lived_closer', 7),
#  ('really_really_good', 7),
#  ('im_huge_fan', 7),
#  ('sandwich_spot_sb', 7),
#  ('salad_really_good', 7),
#  ('lived_santa_barbara', 7),
#  ('definitely_worth_stop', 7),
#  ('food_reasonable_prices', 7),
#  ('food_great_people', 7),
#  ('definitely_back_try', 7),
#  ('place_great_food', 7),
#  ('place_best_sandwiches', 7),
#  ('got_ta_love', 7),
#  ('yum_yum_yum', 7),
#  ('place_eat_santa', 7),
#  ('really_friendly_staff', 7),
#  ('anyone_looking_good', 7),
#  ('second_time_went', 7),
#  ('santa_barbara_would', 7),
#  ('found_place_yelp', 7),
#  ('love_place_food', 7),
#  ('santa_barbara_hands', 7),
#  ('barbara_hands_down', 7),
#  ('delicious_highly_recommend', 7),
#  ('tic_tac_toe', 7),
#  ('sandwich_place_santa', 7),
#  ('place_first_time', 7),
#  ('delicious_sandwiches_salads', 7),
#  ('staff_super_nice', 7),
#  ('sandwiches_soups_salads', 7),
#  ('pickles_swiss_one', 7),
#  ('best_tomato_bisque', 7),
#  ('awesome_customer_service', 7),
#  ('always_super_friendly', 7),
#  ('one_favorite_spots', 7),
#  ('new_favorite_spot', 7),
#  ('took_minutes_make', 7),
#  ('best_sandwiches_salads', 7),
#  ('im_pretty_sure', 7),
#  ('best_deli_santa', 7),
#  ('pork_slaw_sandwich', 7),
#  ('cup_tomato_bisque', 7),
#  ('roast_au_jus', 7),
#  ('great_sandwich_place', 7),
#  ('ive_ever_life', 7),
#  ('time_im_area', 7),
#  ('vegan_gluten_free', 7),
#  ('pickle_swiss_sandwich', 7),
#  ('cant_recommend_enough', 7),
#  ('go_south_coast', 7),
#  ('coming_back_again', 7),
#  ('ive_ever_tasted', 7),
#  ('tried_chipotle_turkey', 7),
#  ('first_time_visiting', 7),
#  ('customer_service_food', 7),
#  ('stopped_pickles_swiss', 7),
#  ('pickles_swiss_first', 7),
#  ('first_time_today', 7),
#  ('service_always_great', 7),
#  ('good_fresh_food', 7),
#  ('busy_lunch_time', 7),
#  ('asian_chicken_salad', 7),
#  ('quinoa_mango_salad', 7),
#  ('salad_bar_great', 7),
#  ('best_ive_had', 6),
#  ('great_pastrami_sandwich', 6),
#  ('back_great_food', 6),
#  ('corned_beef_reuben', 6),
#  ('crispy_pastrami_chipotle', 6),
#  ('pastrami_chipotle_mayo', 6),
#  ('chipotle_mayo_lettuce', 6),
#  ('mayo_lettuce_tomato', 6),
#  ('really_cant_go', 6),
#  ('grilled_cheese_sandwich', 6),
#  ('sandwich_next_time', 6),
#  ('decided_give_try', 6),
#  ('pastrami_sandwich_ive', 6),
#  ('parking_lot_across', 6),
#  ('write_home_about', 6),
#  ('best_pastrami_sandwiches', 6),
#  ('pastrami_sandwiches_ever', 6),
#  ('little_hole_wall', 6),
#  ('saw_place_diners', 6),
#  ('would_recommend_place', 6),
#  ('customer_service_awesome', 6),
#  ('came_santa_barbara', 6),
#  ('great_little_place', 6),
#  ('ever_had_ordered', 6),
#  ('place_amazing_food', 6),
#  ('right_across_street', 6),
#  ('try_things_menu', 6),
#  ('santa_barbara_always', 6),
#  ('service_top_notch', 6),
#  ('love_place_great', 6),
#  ('santa_barbara_place', 6),
#  ('today_first_time', 6),
#  ('santa_barbara_really', 6),
#  ('ill_definitely_back', 6),
#  ('santa_barbara_eat', 6),
#  ('amazing_food_service', 6),
#  ('santa_barbara_good', 6),
#  ('us_feel_welcome', 6),
#  ('hands_down_best', 6),
#  ('time_went_thought', 6),
#  ('portion_meat_sandwich', 6),
#  ('go_every_time', 6),
#  ('cute_little_place', 6),
#  ('say_enough_good', 6),
#  ('enough_good_things', 6),
#  ('place_really_good', 6),
#  ('absolutely_love_place', 6),
#  ('love_place_best', 6),
#  ('recommend_place_friends', 6),
#  ('santa_barbara_love', 6),
#  ('well_worth_wait', 6),
#  ('italian_cold_cuts', 6),
#  ('sandwiches_friendly_service', 6),
#  ('place_must_try', 6),
#  ('since_first_opened', 6),
#  ('staff_friendly_sandwiches', 6),
#  ('stop_every_time', 6),
#  ('tomato_red_onion', 6),
#  ('delicious_staff_friendly', 6),
#  ('three_pickles_deli', 6),
#  ('every_sandwich_ive', 6),
#  ('coconut_chocolate_chip', 6),
#  ('ive_never_tried', 6),
#  ('stumbled_across_place', 6),
#  ('cold_brew_coffee', 6),
#  ('back_try_more', 6),
#  ('good_one_best', 6),
#  ('signature_sandwich_pickles', 6),
#  ('offered_us_sample', 6),
#  ('coming_back_try', 6),
#  ('great_sandwiches_good', 6),
#  ('sandwich_chipotle_turkey', 6),
#  ('turkey_club_amazing', 6),
#  ('taken_care_of', 6),
#  ('soup_grilled_cheese', 6),
#  ('free_pickle_popcorn', 6),
#  ('tomato_bisque_best', 6),
#  ('sandwich_shop_goleta', 6),
#  ('first_time_ordered', 6),
#  ('ordered_roasted_chicken', 6),
#  ('far_favorite_place', 6),
#  ('nothing_write_home', 6),
#  ('great_food_friendly', 6),
#  ('customer_service_fantastic', 6),
#  ('sandwiches_pickles_swiss', 6),
#  ('best_gluten_free', 6),
#  ('great_highly_recommend', 6),
#  ('kale_cashew_salad', 6),
#  ('keep_great_work', 6),
#  ('chipotle_chicken_club', 6),
#  ('barbara_pickles_swiss', 6),
#  ('extremely_friendly_helpful', 6),
#  ('ordered_prosciutto_brie', 6),
#  ('super_friendly_helpful', 6),
#  ('back_first_time', 6),
#  ('never_go_wrong', 6),
#  ('swiss_first_time', 6),
#  ('sandwich_tomato_soup', 6),
#  ('favorite_sandwich_shops', 6),
#  ('got_roast_beef', 6),
#  ('would_give_place', 6),
#  ('highly_recommend_chipotle', 6),
#  ('pepper_jack_cheese', 6),
#  ('place_next_time', 6),
#  ('service_excellent_food', 6),
#  ('staff_always_super', 6),
#  ('tomato_soup_delicious', 6),
#  ('got_gluten_free', 6),
#  ('great_service_owner', 6),
#  ('call_order_ahead', 6),
#  ('dill_pickle_flavored', 6),
#  ('super_friendly_great', 6),
#  ('come_back_here', 6),
#  ('sky_high_pastrami', 6),
#  ('online_ordering_system', 6),
#  ('keep_calm_kale', 6),
#  ('never_disappointed_anything', 6),
#  ('food_friendly_staff', 6),
#  ('breakfast_lunch_dinner', 6),
#  ('selection_gluten_free', 6),
#  ('eggplant_parm_sandwich', 6),
#  ('went_back_next', 5),
#  ('great_place_get', 5),
#  ('nortons_pastrami_deli', 5),
#  ('come_back_great', 5),
#  ('took_minutes_get', 5),
#  ('next_time_town', 5),
#  ('spot_quick_lunch', 5),
#  ('got_turkey_club', 5),
#  ('new_york_style', 5),
#  ('service_really_friendly', 5),
#  ('hands_best_pastrami', 5),
#  ('im_going_back', 5),
#  ('plt_pastrami_lettuce', 5),
#  ('stopped_quick_bite', 5),
#  ('classic_pastrami_rye', 5),
#  ('everything_made_fresh', 5),
#  ('go_wrong_place', 5),
#  ('coming_back_more', 5),
#  ('let_tell_you', 5),
#  ('place_highly_recommend', 5),
#  ('highly_recommend_stopping', 5),
#  ('best_pastrami_ive', 5),
#  ('got_moms_plt', 5),
#  ('want_go_back', 5),
#  ('food_good_service', 5),
#  ('try_santa_barbara', 5),
#  ('one_best_pastrami', 5),
#  ('sandwich_fries_drink', 5),
#  ('go_next_time', 5),
#  ('lot_across_street', 5),
#  ('guy_behind_counter', 5),
#  ('sandwiches_south_coast', 5),
#  ('can_not_say', 5),
#  ('not_say_enough', 5),
#  ('let_us_sample', 5),
#  ('ever_santa_barbara', 5),
#  ('looking_forward_trying', 5),
#  ('right_front_you', 5),
#  ('go_three_pickles', 5),
#  ('im_giving_stars', 5),
#  ('great_place_go', 5),
#  ('next_time_sb', 5),
#  ('coming_back_place', 5),
#  ('pretty_darn_good', 5),
#  ('santa_barbara_decided', 5),
#  ('ever_had_great', 5),
#  ('stop_try_it', 5),
#  ('time_visit_sb', 5),
#  ('back_im_area', 5),
#  ('featured_diners_driveins', 5),
#  ('little_pricey_side', 5),
#  ('place_anyone_looking', 5),
#  ('first_time_santa', 5),
#  ('gon_na_try', 5),
#  ('service_always_friendly', 5),
#  ('food_staff_friendly', 5),
#  ('far_one_best', 5),
#  ('ever_had_would', 5),
#  ('moved_santa_barbara', 5),
#  ('excellent_service_food', 5),
#  ('went_thought_first', 5),
#  ('thought_first_time', 5),
#  ('first_time_fluke', 5),
#  ('time_fluke_wasnt', 5),
#  ('fluke_wasnt_looking', 5),
#  ('wasnt_looking_fir', 5),
#  ('looking_fir_really', 5),
#  ('fir_really_great', 5),
#  ('really_great_corned', 5),
#  ('great_corned_beef', 5),
#  ('beef_reuben_sandwich', 5),
#  ('reuben_sandwich_waste', 5),
#  ('sandwich_waste_insane', 5),
#  ('waste_insane_price', 5),
#  ('insane_price_charge', 5),
#  ('price_charge_actually', 5),
#  ('charge_actually_meat', 5),
#  ('actually_meat_prepackaged', 5),
#  ('meat_prepackaged_serving', 5),
#  ('prepackaged_serving_portions', 5),
#  ('serving_portions_fry', 5),
#  ('portions_fry_grill', 5),
#  ('fry_grill_hotdogs', 5),
#  ('results_nothing_skimpy', 5),
#  ('nothing_skimpy_portion', 5),
#  ('skimpy_portion_meat', 5),
#  ('meat_sandwich_litterally', 5),
#  ('sandwich_litterally_dripping', 5),
#  ('litterally_dripping_grease', 5),
#  ('dripping_grease_gross', 5),
#  ('grease_gross_expect', 5),
#  ('really_enjoyed_sandwich', 5),
#  ('santa_barbara_weekend', 5),
#  ('sandwich_place_ever', 5),
#  ('well_definitely_back', 5),
#  ('stopped_way_home', 5),
#  ('ive_coming_since', 5),
#  ('really_good_sandwich', 5),
#  ('spots_santa_barbara', 5),
#  ('sandwich_spot_town', 5),
#  ('sandwich_first_time', 5),
#  ('santa_barbara_amazing', 5),
#  ('fresh_delicious_food', 5),
#  ('eggplant_parmigiana_sandwich', 5),
#  ('perfect_lunch_spot', 5),
#  ('love_sandwiches_here', 5),
#  ('canon_capicolla_club', 5),
#  ('sandwich_prosciutto_brie', 5),
#  ('make_sure_everything', 5),
#  ('everything_really_good', 5),
#  ('always_good_sign', 5),
#  ('way_back_la', 5),
#  ('favorite_lunch_spot', 5),
#  ('love_love_place', 5),
#  ('around_state_street', 5),
#  ('place_absolutely_amazing', 5),
#  ('one_best_places', 5),
#  ('sandwiches_made_fresh', 5),
#  ('made_fresh_ingredients', 5),
#  ('santa_barbara_best', 5),
#  ('pickles_swiss_best', 5),
#  ('good_quality_ingredients', 5),
#  ('chicken_parm_sandwich', 5),
#  ('food_even_better', 5),
#  ('got_spicy_crunch', 5),
#  ('pricey_worth_it', 5),
#  ('atmosphere_friendly_staff', 5),
#  ('sandwich_spot_santa', 5),
#  ('cant_wait_next', 5),
#  ('also_really_good', 5),
#  ('friendly_helpful_staff', 5),
#  ('cookies_die_for', 5),
#  ('buy_one_get', 5),
#  ('one_get_one', 5),
#  ('going_south_coast', 5),
#  ('service_good_food', 5),
#  ('friendly_knowledgeable_staff', 5),
#  ('minutes_two_sandwiches', 5),
#  ('goto_lunch_spot', 5),
#  ('well_highly_recommend', 5),
#  ('food_excellent_service', 5),
#  ('pot_roast_dip', 5),
#  ('tomato_bisque_ive', 5),
#  ('food_always_great', 5),
#  ('thank_pickles_swiss', 5),
#  ('one_favorite_lunch', 5),
#  ('sandwiches_hot_cold', 5),
#  ('tomato_bisque_delicious', 5),
#  ('love_food_service', 5),
#  ('definitely_back_soon', 5),
#  ('tomato_basil_bisque', 5),
#  ('back_best_sandwiches', 5),
#  ('sandwich_place_goleta', 5),
#  ('lunch_first_time', 5),
#  ('delicious_fresh_food', 5),
#  ('ordered_pastrami_melt', 5),
#  ('pickles_swiss_goleta', 5),
#  ('staff_really_friendly', 5),
#  ('cheese_wine_shop', 5),
#  ('great_service_delicious', 5),
#  ('going_back_again', 5),
#  ('time_were_town', 5),
#  ('boars_head_meats', 5),
#  ('pickles_swiss_amazing', 5),
#  ('first_time_trying', 5),
#  ('get_chipotle_turkey', 5),
#  ('us_make_sure', 5),
#  ('sample_tomato_soup', 5),
#  ('different_types_sandwiches', 5),
#  ('back_second_time', 5),
#  ('got_pickles_swiss', 5),
#  ('spinach_feta_salad', 5),
#  ('local_sandwich_shop', 5),
#  ('thanks_pickles_swiss', 5),
#  ('try_pickles_swiss', 5),
#  ('tomato_bisque_grilled', 5),
#  ('bisque_grilled_cheese', 5),
#  ('coming_pickles_swiss', 5),
#  ('sandwich_crispy_chicken', 5),
#  ('sandwich_ive_tried', 5),
#  ('saw_pickles_swiss', 5),
#  ('spicy_chicken_sandwich', 5),
#  ('super_friendly_food', 5),
#  ('place_great_sandwiches', 5),
#  ('sandwich_shops_santa', 5),
#  ('best_sandwich_shops', 5),
#  ('really_good_would', 5),
#  ('cold_hot_sandwiches', 5),
#  ('recommend_lunch_spot', 5),
#  ('im_writing_review', 5),
#  ('better_customer_service', 5),
#  ('seating_inside_outside', 5),
#  ('best_sandwiches_weve', 5),
#  ('stop_pickles_swiss', 5),
#  ('great_salads_sandwiches', 5),
#  ('cajun_turkey_sandwich', 5),
#  ('coast_turkey_sandwich', 5),
#  ('best_deli_ever', 5),
#  ('come_back_sb', 5),
#  ('ill_go_back', 5),
#  ('get_one_free', 5),
#  ('calm_kale_salad', 5),
#  ('viet_nom_nom', 5),
#  ('great_sandwiches_salads', 5),
#  ('ive_ever_to', 5),
#  ('amazing_sandwiches_great', 5),
#  ('fowl_play_salad', 5),
#  ('sofa_king_good', 5),
#  ('eat_every_day', 5),
#  ('paseo_nuevo_shopping', 5),
#  ('nuevo_shopping_center', 5),
#  ('pickles_swiss_go', 5),
#  ('amazing_sandwiches_salads', 5),
#  ('salad_bar_town', 5),
#  ('pesto_pasta_salad', 5),
#  ('organic_salad_bar', 5),
#  ('turkey_chipotle_sandwich', 5),
#  ('blueberry_kale_salad', 5),
#  ('turkey_pasilla_fritter', 5),
#  ('salad_bar_fresh', 5),
#  ('grab_quick_bite', 5),
#  ('always_friendly_helpful', 5),
#  ('strawberry_spinach_salad', 5),
#  ('turkey_club_delicious', 5),
#  ('salad_bar_soups', 5),
#  ('santa_barbara_pickles', 5),
#  ('gluten_free_items', 5),
#  ('salad_soup_bar', 5),
#  ('prices_bit_high', 4),
#  ('new_york_deli', 4),
#  ('great_food_really', 4),
#  ('food_really_good', 4),
#  ('cali_tuna_melt', 4),
#  ('decided_stop_lunch', 4),
#  ('great_quality_food', 4),
#  ('best_pastrami_ever', 4),
#  ('pastrami_ever_had', 4),
#  ('sandwich_also_amazing', 4),
#  ('santa_barbara_way', 4),
#  ('nortons_grilled_chicken', 4),
#  ('thanks_guy_fieri', 4),
#  ('santa_barbara_again', 4),
#  ('pastrami_cole_slaw', 4),
#  ('cole_slaw_swiss', 4),
#  ('russian_dressing_rye', 4),
#  ('little_expensive_side', 4),
#  ('philly_cheese_steak', 4),
#  ('pastrami_sandwich_fries', 4),
#  ('philly_steak_sandwich', 4),
#  ('would_eat_again', 4),
#  ('santa_barbara_get', 4),
#  ('lettuce_tomato_chipotle', 4),
#  ('little_lunch_spot', 4),
#  ('selection_sandwiches_salads', 4),
#  ('it_love_place', 4),
#  ('heard_great_things', 4),
#  ('original_pastrami_sandwich', 4),
#  ('ordered_pastrami_sandwich', 4),
#  ('pastrami_ive_ever', 4),
#  ('super_nice_friendly', 4),
#  ('place_best_pastrami', 4),
#  ('food_came_quickly', 4),
#  ('good_place_stop', 4),
#  ('really_enjoyed_it', 4),
#  ('service_awesome_food', 4),
#  ('great_place_sandwiches', 4),
#  ('great_food_good', 4),
#  ('santa_barbara_perfect', 4),
#  ('chinese_chicken_salad', 4),
#  ('decided_try_place', 4),
#  ('try_place_out', 4),
#  ('every_time_ive', 4),
#  ('glad_found_place', 4),
#  ('pastrami_corned_beef', 4),
#  ('coming_back_soon', 4),
#  ('barbara_decided_stop', 4),
#  ('one_best_ever', 4),
#  ('go_wrong_here', 4),
#  ('owner_super_nice', 4),
#  ('way_like_it', 4),
#  ('food_top_notch', 4),
#  ('forward_going_back', 4),
#  ('food_delicious_would', 4),
#  ('top_notch_food', 4),
#  ('restaurant_santa_barbara', 4),
#  ('good_pastrami_sandwich', 4),
#  ('favorite_place_santa', 4),
#  ('best_sandwhich_ever', 4),
#  ('found_place_accident', 4),
#  ('santa_barbara_years', 4),
#  ('staff_friendly_food', 4),
#  ('great_food_reasonable', 4),
#  ('several_times_week', 4),
#  ('would_love_try', 4),
#  ('go_back_santa', 4),
#  ('toasted_rye_bread', 4),
#  ('ordered_two_sandwiches', 4),
#  ('working_santa_barbara', 4),
#  ('good_sandwich_place', 4),
#  ('sandwiches_ever_eaten', 4),
#  ('anyone_looking_great', 4),
#  ('finally_got_around', 4),
#  ('came_first_time', 4),
#  ('go_back_again', 4),
#  ('back_every_time', 4),
#  ('every_time_get', 4),
#  ('quick_friendly_service', 4),
#  ('great_place_stop', 4),
#  ('next_time_would', 4),
#  ('good_things_place', 4),
#  ('want_come_back', 4),
#  ('best_deli_town', 4),
#  ('sandwich_cant_go', 4),
#  ('could_give_stars', 4),
#  ('give_stars_would', 4),
#  ('highly_recommend_great', 4),
#  ('got_ta_check', 4),
#  ('ever_since_moved', 4),
#  ('id_come_back', 4),
#  ('food_highly_recommend', 4),
#  ('coast_deli_chapala', 4),
#  ('service_great_too', 4),
#  ('grill_hotdogs_results', 4),
#  ('hotdogs_results_nothing', 4),
#  ('too_highly_recommend', 4),
#  ('service_highly_recommend', 4),
#  ('always_make_point', 4),
#  ('cant_wait_return', 4),
#  ('santa_barbara_found', 4),
#  ('delicious_sandwiches_made', 4),
#  ('sandwiches_made_order', 4),
#  ('sandwiches_first_time', 4),
#  ('ive_long_time', 4),
#  ('want_like_place', 4),
#  ('good_sandwich_great', 4),
#  ('sandwich_highly_recommend', 4),
#  ('super_nice_staff', 4),
#  ('tinos_super_deluxe', 4),
#  ('super_deluxe_sub', 4),
#  ('super_deluxe_sandwich', 4),
#  ('sandwich_places_santa', 4),
#  ('cheese_lettuce_tomato', 4),
#  ('highly_recommend_trying', 4),
#  ('favorite_place_get', 4),
#  ('keep_going_back', 4),
#  ('always_make_sure', 4),
#  ('bread_always_fresh', 4),
#  ('forward_coming_back', 4),
#  ('made_feel_like', 4),
#  ('quality_meats_cheeses', 4),
#  ('great_food_also', 4),
#  ('harissa_bomb_sandwich', 4),
#  ('maybe_next_time', 4),
#  ('good_sandwich_went', 4),
#  ('first_time_came', 4),
#  ('santa_barbara_everything', 4),
#  ('place_grab_bite', 4),
#  ('santa_barbara_location', 4),
#  ('gave_us_samples', 4),
#  ('santa_barbara_deli', 4),
#  ('goat_cheese_salad', 4),
#  ('cant_really_go', 4),
#  ('really_go_wrong', 4),
#  ('probably_best_one', 4),
#  ('tried_place_first', 4),
#  ('brie_sandwich_amazing', 4),
#  ('san_luis_obispo', 4),
#  ('super_nice_helpful', 4),
#  ('sandwich_one_best', 4),
#  ('near_funk_zone', 4),
#  ('mixed_greens_tomatoes', 4),
#  ('thinly_sliced_red', 4),
#  ('sliced_red_onions', 4),
#  ('going_back_soon', 4),
#  ('truffle_potato_chips', 4),
#  ('pickles_swiss_favorite', 4),
#  ('everything_super_fresh', 4),
#  ('food_great_staff', 4),
#  ('helpful_highly_recommend', 4),
#  ('definitely_worth_visit', 4),
#  ('one_best_delis', 4),
#  ('sandwich_reasonable_price', 4),
#  ('cant_get_enough', 4),
#  ('customer_service_everyone', 4),
#  ('ive_tried_many', 4),
#  ('santa_barbara_fresh', 4),
#  ('amazing_pickles_swiss', 4),
#  ('swiss_one_favorite', 4),
#  ('best_santa_barbara', 4),
#  ('definitely_one_best', 4),
#  ('quality_customer_service', 4),
#  ('highly_recommend_coming', 4),
#  ('use_boars_head', 4),
#  ('deli_case_items', 4),
#  ('eat_half_lunch', 4),
#  ('save_half_dinner', 4),
#  ('great_selection_drinks', 4),
#  ('love_place_coming', 4),
#  ('made_sure_everything', 4),
#  ('looking_quick_bite', 4),
#  ('quality_ingredients_great', 4),
#  ('can_not_go', 4),
#  ('not_go_wrong', 4),
#  ('good_highly_recommend', 4),
#  ('cute_little_sandwich', 4),
#  ('sandwich_shop_great', 4),
#  ('chop_toss_salad', 4),
#  ('sandwich_shops_town', 4),
#  ('love_place_ive', 4),
#  ('favorite_deli_santa', 4),
#  ('definitely_returning_next', 4),
#  ('really_good_definitely', 4),
#  ('turkey_jack_avo', 4),
#  ('fresh_baked_cookies', 4),
#  ('makes_best_sandwiches', 4),
#  ('tomato_bisque_great', 4),
#  ('santa_barbara_im', 4),
#  ('roast_beef_dip', 4),
#  ('got_ta_try', 4),
#  ('place_awesome_great', 4),
#  ('love_place_sandwiches', 4),
#  ('visit_pickles_swiss', 4),
#  ('service_pickles_swiss', 4),
#  ('free_cup_soup', 4),
#  ('quality_worth_it', 4),
#  ('pickles_swiss_absolutely', 4),
#  ('give_five_stars', 4),
#  ('pricey_get_pay', 4),
#  ('use_quality_ingredients', 4),
#  ('people_behind_counter', 4),
#  ('hands_best_deli', 4),
#  ('really_like_place', 4),
#  ('here_staff_friendly', 4),
#  ('never_bad_experience', 4),
#  ('first_time_coming', 4),
#  ('found_pickles_swiss', 4),
#  ('ill_definitely_coming', 4),
#  ('good_staff_friendly', 4),
#  ('salad_ive_ever', 4),
#  ('definitely_come_again', 4),
#  ('next_time_area', 4),
#  ('best_kept_secret', 4),
#  ('ordered_pot_roast', 4),
#  ('sure_taken_care', 4),
#  ('tomato_soup_grilled', 4),
#  ('customer_service_best', 4),
#  ('make_best_sandwiches', 4),
#  ('come_back_best', 4),
#  ('one_best_lunch', 4),
#  ('theres_plenty_seating', 4),
#  ('also_tomato_bisque', 4),
#  ('id_highly_recommend', 4),
#  ('everyone_behind_counter', 4),
#  ('parking_bit_difficult', 4),
#  ('ordered_pulled_pork', 4),
#  ('since_first_time', 4),
#  ('live_san_diego', 4),
#  ('always_great_experience', 4),
#  ('one_best_salad', 4),
#  ('ordered_roast_beef', 4),
#  ('ingredients_super_fresh', 4),
#  ('sandwiches_found_place', 4),
#  ('first_time_pickles', 4),
#  ('favorite_crispy_chicken', 4),
#  ('sandwich_place_sb', 4),
#  ('food_delicious_fresh', 4),
#  ('ill_come_back', 4),
#  ('tomato_soup_really', 4),
#  ('try_every_sandwich', 4),
#  ('food_fresh_tasty', 4),
#  ('friendly_quick_service', 4),
#  ('best_pulled_pork', 4),
#  ('cheese_basil_tomato', 4),
#  ('ordered_spicy_crunch', 4),
#  ('place_pickles_swiss', 4),
#  ('highly_recommend_lunch', 4),
#  ('pickles_swiss_delicious', 4),
#  ('definitely_recommend_pickles', 4),
#  ('im_big_fan', 4),
#  ('great_little_spot', 4),
#  ('walnut_pesto_sandwich', 4),
#  ('meatball_sandwich_delicious', 4),
#  ('back_try_items', 4),
#  ('try_pickle_popcorn', 4),
#  ('bisque_ive_ever', 4),
#  ('great_sandwiches_amazing', 4),
#  ('everything_tried_delicious', 4),
#  ('food_great_customer', 4),
#  ('one_favorite_sandwiches', 4),
#  ('pickles_swiss_love', 4),
#  ('had_highly_recommend', 4),
#  ('people_working_behind', 4),
#  ('working_behind_counter', 4),
#  ('gave_us_complimentary', 4),
#  ('gluten_free_sandwich', 4),
#  ('everything_tasted_fresh', 4),
#  ('staff_friendly_attentive', 4),
#  ('decided_stop_try', 4),
#  ('vegan_garbanzo_kick', 4),
#  ('staff_helpful_friendly', 4),
#  ('good_gluten_free', 4),
#  ('pickles_swiss_today', 4),
#  ...]

# %% [markdown]
# ### Bakery

# %%
Bakery = business_df[business_df.Type=='Bakery']
Bakery_review = review1[review1.business_id.isin(Bakery.business_id.values)]
Bakery_review["text"] = Bakery_review["text"].str.lower()
Bakery_review['text'] = Bakery_review['text'].apply(lambda text: cleaning_stopwords(text))
Bakery_review['text']= Bakery_review['text'].apply(lambda x: cleaning_punctuations(x))
Bakery_review['text'] = Bakery_review['text'].apply(lambda x: cleaning_repeating_char(x))
Bakery_review['text'] = Bakery_review['text'].apply(lambda x: cleaning_URLs(x))
Bakery_review['text'] = Bakery_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Bakery=Bakery[Bakery.stars<3.5]
bad_Bakery_review = Bakery_review[Bakery_review.business_id.isin(bad_Bakery.business_id.values)]
bad_Bakery_review_text = bad_Bakery_review.text.str.cat(sep = " ")
bad_Bakery_tokens = word_tokenize(bad_Bakery_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_bad_Bakery = ["_".join(item) for item in nltk.bigrams(bad_Bakery_tokens)]
trigrams_list_bad_Bakery = ["_".join(item) for item in nltk.trigrams(bad_Bakery_tokens)]
FreqDist(bigrams_list_bad_Bakery).most_common()
# FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('old_fashioned', 4),
#  ('old_fashion', 3),
#  ('donut_shop', 3),
#  ('early_morning', 2),
#  ('fresh_like', 2),
#  ('egg_sandwich', 2),
#  ('donuts_pastries', 2),
#  ('donuts_good', 2),
#  ('donut_house', 2),
#  ('open_hrs', 2),
#  ('donuts_chocolate', 2),
#  ('fashion_donuts', 2),
#  ('customer_service', 2),
#  ('part_day', 2),
#  ('day_finding', 2),
#  ('good_donut', 2),
#  ('mini_donuts', 2),
#  ('donut_place', 2),
#  ('donut_holes', 2),
#  ('ive_heard', 1),
#  ('heard_many', 1),
#  ('many_great', 1),
#  ('great_things', 1),
#  ('things_winchells', 1),
#  ('winchells_doughnut', 1),
#  ('doughnut_house', 1),
#  ('house_personally', 1),
#  ('personally_tried', 1),
#  ('tried_one', 1),
#  ('one_ordered', 1),
#  ('ordered_dozen', 1),
#  ('dozen_event', 1),
#  ('event_disappointed', 1),
#  ('disappointed_employee', 1),
#  ('employee_sweet', 1),
#  ('sweet_friendly', 1),
#  ('friendly_she', 1),
#  ('she_even', 1),
#  ('even_threw', 1),
#  ('threw_extra', 1),
#  ('extra_dozen', 1),
#  ('dozen_helped', 1),
#  ('helped_bring', 1),
#  ('bring_car', 1),
#  ('car_everyone', 1),
#  ('everyone_enjoyed', 1),
#  ('enjoyed_donuts', 1),
#  ('donuts_help', 1),
#  ('help_eat', 1),
#  ('eat_oneor', 1),
#  ('oneor_three', 1),
#  ('three_definitely', 1),
#  ('definitely_returning', 1),
#  ('returning_highly', 1),
#  ('highly_recommend', 1),
#  ('recommend_ordered', 1),
#  ('ordered_turkey', 1),
#  ('turkey_breast', 1),
#  ('breast_bagel', 1),
#  ('bagel_sandwich', 1),
#  ('sandwich_came', 1),
#  ('came_cucumber', 1),
#  ('cucumber_cheese', 1),
#  ('cheese_red', 1),
#  ('red_onion', 1),
#  ('onion_lettuce', 1),
#  ('lettuce_tomato', 1),
#  ('tomato_jalapeño', 1),
#  ('jalapeño_awesome', 1),
#  ('awesome_sandwich', 1),
#  ('sandwich_highly', 1),
#  ('highly_recommended', 1),
#  ('recommended_home', 1),
#  ('home_town', 1),
#  ('town_shop', 1),
#  ('shop_love', 1),
#  ('love_always', 1),
#  ('always_come', 1),
#  ('come_handy', 1),
#  ('handy_helpful', 1),
#  ('helpful_always', 1),
#  ('always_open', 1),
#  ('open_cheap', 1),
#  ('cheap_soda', 1),
#  ('soda_donut', 1),
#  ('donut_early', 1),
#  ('morning_am', 1),
#  ('am_fresh', 1),
#  ('like_warm', 1),
#  ('warm_amazing', 1),
#  ('amazing_quick', 1),
#  ('quick_stop', 1),
#  ('stop_shop', 1),
#  ('shop_yummy', 1),
#  ('yummy_food', 1),
#  ('food_too', 1),
#  ('too_picked', 1),
#  ('picked_breakfast', 1),
#  ('breakfast_sandwiches', 1),
#  ('sandwiches_day', 1),
#  ('day_ordered', 1),
#  ('ordered_bacon', 1),
#  ('bacon_egg', 1),
#  ('sandwich_bacon', 1),
#  ('bacon_good', 1),
#  ('good_however', 1),
#  ('however_egg', 1),
#  ('sandwich_tasted', 1),
#  ('tasted_made', 1),
#  ('made_powder', 1),
#  ('powder_tasted', 1),
#  ('tasted_fake', 1),
#  ('fake_way', 1),
#  ('way_much', 1),
#  ('much_egg', 1),
#  ('egg_going', 1),
#  ('going_back', 1),
#  ('back_sandwiches', 1),
#  ('sandwiches_must', 1),
#  ('must_say', 1),
#  ('say_though', 1),
#  ('though_donuts', 1),
#  ('pastries_stocked', 1),
#  ('stocked_looking', 1),
#  ('looking_good', 1),
#  ('good_winchells', 1),
#  ('winchells_usually', 1),
#  ('usually_great', 1),
#  ('great_walked', 1),
#  ('walked_place', 1),
#  ('place_disappointed', 1),
#  ('disappointed_donuts', 1),
#  ('donuts_rock', 1),
#  ('rock_hard', 1),
#  ('hard_servers', 1),
#  ('servers_seemed', 1),
#  ('seemed_annoyed', 1),
#  ('annoyed_poncho', 1),
#  ('poncho_villa', 1),
#  ('villa_convention', 1),
#  ('convention_dining', 1),
#  ('dining_room', 1),
#  ('room_took', 1),
#  ('took_two', 1),
#  ('two_bites', 1),
#  ('bites_donuts', 1),
#  ('donuts_spit', 1),
#  ('spit_good', 1),
#  ('good_luck', 1),
#  ('luck_absolutely', 1),
#  ('absolutely_worst', 1),
#  ('worst_doughnuts', 1),
#  ('doughnuts_ive', 1),
#  ('ive_ever', 1),
#  ('ever_had', 1),
#  ('had_dry', 1),
#  ('dry_hard', 1),
#  ('hard_tasteless', 1),
#  ('tasteless_poor', 1),
#  ('poor_selection', 1),
#  ('selection_telling', 1),
#  ('telling_old', 1),
#  ('old_were', 1),
#  ('were_go', 1),
#  ('go_spudnuts', 1),
#  ('spudnuts_ellers', 1),
#  ('ellers_instead', 1),
#  ('instead_ive', 1),
#  ('ive_moved', 1),
#  ('moved_santa', 1),
#  ('santa_barbara', 1),
#  ('barbara_recently', 1),
#  ('recently_looking', 1),
#  ('looking_old', 1),
#  ('fashion_doughnuts', 1),
#  ('doughnuts_flavor', 1),
#  ('flavor_found', 1),
#  ('found_here', 1),
#  ('here_make', 1),
#  ('make_delicious', 1),
#  ('delicious_mouth', 1),
#  ('mouth_watering', 1),
#  ('watering_doughnuts', 1),
#  ('doughnuts_even', 1),
#  ('even_bought', 1),
#  ('bought_mini', 1),
#  ('mini_sized', 1),
#  ('sized_ones', 1),
#  ('ones_toddler', 1),
#  ('toddler_prices', 1),
#  ('prices_comparable', 1),
#  ('comparable_shops', 1),
#  ('shops_much', 1),
#  ('much_tastier', 1),
#  ('tastier_would', 1),
#  ('would_recommend', 1),
#  ('recommend_place', 1),
#  ('place_sweet', 1),
#  ('sweet_fix', 1),
#  ('fix_pretty', 1),
#  ('pretty_damn', 1),
#  ('damn_good', 1),
#  ('good_apple', 1),
#  ('apple_fritters', 1),
#  ('fritters_old', 1),
#  ('fashioned_doughnuts', 1),
#  ('doughnuts_much', 1),
#  ('much_better', 1),
#  ('better_doughnut', 1),
#  ('doughnut_places', 1),
#  ('places_ive', 1),
#  ('ive_to', 1),
#  ('to_location', 1),
#  ('location_nice', 1),
#  ('nice_though', 1),
#  ('though_sits', 1),
#  ('sits_eats', 1),
#  ('eats_doughnuts', 1),
#  ('doughnuts_doughnut', 1),
#  ('doughnut_shop', 1),
#  ('shop_come', 1),
#  ('come_number', 1),
#  ('number_times', 1),
#  ('times_coffee', 1),
#  ('coffee_always', 1),
#  ('always_fresh', 1),
#  ('fresh_hot', 1),
#  ('hot_ive', 1),
#  ('ive_tried', 1),
#  ('tried_number', 1),
#  ('number_donuts', 1),
#  ('good_taste', 1),
#  ('taste_fresh', 1),
#  ('fresh_also', 1),
#  ('also_lots', 1),
#  ('lots_different', 1),
#  ('different_drinks', 1),
#  ('drinks_including', 1),
#  ('including_juices', 1),
#  ('juices_hot', 1),
#  ('hot_chocolate', 1),
#  ('chocolate_coffee', 1),
#  ('coffee_drinks', 1),
#  ('drinks_bagel', 1),
#  ('bagel_sandwiches', 1),
#  ('sandwiches_breakfast', 1),
#  ('breakfast_burritos', 1),
#  ('burritos_people', 1),
#  ('people_friendly', 1),
#  ('friendly_sometimes', 1),
#  ('sometimes_understaffed', 1),
#  ('understaffed_honestly', 1),
#  ('honestly_say', 1),
#  ('say_child', 1),
#  ('child_always', 1),
#  ('always_remember', 1),
#  ('remember_enjoying', 1),
#  ('enjoying_donut', 1),
#  ('house_times', 1),
#  ('times_definitely', 1),
#  ('definitely_changed', 1),
#  ('changed_tonight', 1),
#  ('tonight_camepm', 1),
#  ('camepm_satisfy', 1),
#  ('satisfy_pregnant', 1),
#  ('pregnant_craving', 1),
#  ('craving_expecting', 1),
#  ('expecting_fresh', 1),
#  ('fresh_donuts', 1),
#  ('donuts_since', 1),
#  ('since_open', 1),
#  ('hrs_selections', 1),
#  ('selections_couple', 1),
#  ('couple_left', 1),
#  ('left_overs', 1),
#  ('overs_go', 1),
#  ('go_ask', 1),
#  ('ask_employee', 1),
#  ('employee_batch', 1),
#  ('batch_coming', 1),
#  ('coming_soon', 1),
#  ('soon_gestured', 1),
#  ('gestured_attitude', 1),
#  ('attitude_said', 1),
#  ('said_am', 1),
#  ('am_understand', 1),
#  ('understand_donut', 1),
#  ('house_suppose', 1),
#  ('suppose_open', 1),
#  ('hrs_make', 1),
#  ('make_fresh', 1),
#  ('fresh_batches', 1),
#  ('batches_night', 1),
#  ('night_telling', 1),
#  ('telling_friends', 1),
#  ('friends_stop', 1),
#  ('stop_purchasing', 1),
#  ('purchasing_place', 1),
#  ('place_jr', 1),
#  ('jr_high', 1),
#  ('high_school', 1),
#  ('school_would', 1),
#  ('would_come', 1),
#  ('come_everyday', 1),
#  ('everyday_school', 1),
#  ('school_get', 1),
#  ('get_donuts', 1),
#  ('chocolate_milk', 1),
#  ('milk_many', 1),
#  ('many_years', 1),
#  ('years_later', 1),
#  ('later_feel', 1),
#  ('feel_kid', 1),
#  ('kid_still', 1),
#  ('still_lingers', 1),
#  ('lingers_atmosphere', 1),
#  ('atmosphere_awesome', 1),
#  ('awesome_prices', 1),
#  ('prices_good', 1),
#  ('good_highly', 1),
#  ('highly_suggest', 1),
#  ('suggest_anyone', 1),
#  ('anyone_come', 1),
#  ('come_eat', 1),
#  ('eat_here', 1),
#  ('here_son', 1),
#  ('son_got', 1),
#  ('got_coffee', 1),
#  ('coffee_early', 1),
#  ('early_am', 1),
#  ('am_car', 1),
#  ('car_wouldnt', 1),
#  ('wouldnt_start', 1),
#  ('start_tried', 1),
#  ('tried_jumping', 1),
#  ('jumping_go', 1),
#  ('go_owner', 1),
#  ('owner_came', 1),
#  ('came_wouldnt', 1),
#  ('wouldnt_listen', 1),
#  ('listen_said', 1),
#  ('said_going', 1),
#  ('going_tow', 1),
#  ('tow_didnt', 1),
#  ('didnt_move', 1),
#  ('move_good', 1),
#  ('good_thing', 1),
#  ('thing_aaa', 1),
#  ('aaa_place', 1),
#  ('place_friendly', 1),
#  ('friendly_great', 1),
#  ('great_freshly', 1),
#  ('freshly_baked', 1),
#  ('baked_doughnuts', 1),
#  ('doughnuts_also', 1),
#  ('also_sell', 1),
#  ('sell_juice', 1),
#  ('juice_coffee', 1),
#  ('coffee_compliments', 1),
#  ('compliments_doughnuts', 1),
#  ('doughnuts_well', 1),
#  ('well_would', 1),
#  ('would_try', 1),
#  ('try_get', 1),
#  ('get_early', 1),
#  ('morning_sell', 1),
#  ('sell_freshest', 1),
#  ('freshest_ones', 1),
#  ('ones_quickest', 1),
#  ('quickest_go', 1),
#  ('go_donut', 1),
#  ('shop_sb', 1),
#  ('sb_try', 1),
#  ('try_old', 1),
#  ('chocolate_top', 1),
#  ('top_best', 1),
#  ('best_careful', 1),
#  ('careful_ones', 1),
#  ('ones_morning', 1),
#  ('morning_made', 1),
#  ('made_differently', 1),
#  ('differently_ones', 1),
#  ('ones_evening', 1),
#  ('evening_sure', 1),
#  ('sure_going', 1),
#  ('going_morning', 1),
#  ('morning_love', 1),
#  ('love_place', 1),
#  ('place_walked', 1),
#  ('walked_saw', 1),
#  ('saw_flys', 1),
#  ('flys_donuts', 1),
#  ('donuts_devastated', 1),
#  ('devastated_why', 1),
#  ('why_im', 1),
#  ('im_sorry', 1),
#  ('sorry_hate', 1),
#  ('hate_this', 1),
#  ('this_bough', 1),
#  ('bough_donuts', 1),
#  ('donuts_today', 1),
#  ('today_stale', 1),
#  ('stale_dried', 1),
#  ('dried_out', 1),
#  ('out_threwall', 1),
#  ('threwall_away', 1),
#  ('away_chocolate', 1),
#  ('chocolate_old', 1),
#  ('fashioned_dry', 1),
#  ('dry_even', 1),
#  ('even_get', 1),
#  ('get_thru', 1),
#  ('thru_one', 1),
#  ('one_bite', 1),
#  ('bite_get', 1),
#  ('get_much', 1),
#  ('much_less', 1),
#  ('less_traffic', 1),
#  ('traffic_make', 1),
#  ('make_less', 1),
#  ('less_time', 1),
#  ('time_make', 1),
#  ('make_afternoon', 1),
#  ('afternoon_maple', 1),
#  ('maple_buttermilk', 1),
#  ('buttermilk_bar', 1),
#  ('bar_weighed', 1),
#  ('weighed_ton', 1),
#  ('ton_dry', 1),
#  ('dry_usually', 1),
#  ('usually_apple', 1),
#  ('apple_fritter', 1),
#  ('fritter_save', 1),
#  ('save_day', 1),
#  ('day_go', 1),
#  ('go_unfortunately', 1),
#  ('unfortunately_six', 1),
#  ('six_bought', 1),
#  ('bought_one', 1),
#  ('one_able', 1),
#  ('able_eat', 1),
#  ('eat_chocolate', 1),
#  ('chocolate_crueller', 1),
#  ('crueller_say', 1),
#  ('say_girl', 1),
#  ('girl_helped', 1),
#  ('helped_friendly', 1),
#  ('friendly_wearing', 1),
#  ('wearing_mask', 1),
#  ('mask_washed', 1),
#  ('washed_hands', 1),
#  ('hands_least', 1),
#  ('least_theres', 1),
#  ('theres_that', 1),
#  ('that_well', 1),
#  ('well_extremely', 1),
#  ('extremely_excited', 1),
#  ('excited_try', 1),
#  ('try_tasty', 1),
#  ('tasty_treats', 1),
#  ('treats_clerk', 1),
#  ('clerk_told', 1),
#  ('told_us', 1),
#  ('us_could', 1),
#  ('could_use', 1),
#  ('use_restroom', 1),
#  ('restroom_policyi', 1),
#  ('policyi_think', 1),
#  ('think_could', 1),
#  ('could_made', 1),
#  ('made_exceptionsee', 1),
#  ('exceptionsee_picture', 1),
#  ('picture_donuts', 1),
#  ('donuts_okay', 1),
#  ('okay_store', 1),
#  ('store_cleanest', 1),
#  ('cleanest_customer', 1),
#  ('service_good', 1),
#  ('good_nothing', 1),
#  ('nothing_special', 1),
#  ('special_bad', 1),
#  ('bad_customer', 1),
#  ('service_overall', 1),
#  ('overall_okay', 1),
#  ('okay_experience', 1),
#  ('experience_best', 1),
#  ('best_part', 1),
#  ('finding_winchells', 1),
#  ('winchells_open', 1),
#  ('open_hours', 1),
#  ('hours_day', 1),
#  ('day_worst', 1),
#  ('worst_part', 1),
#  ('finding_definitely', 1),
#  ('definitely_fan', 1),
#  ('fan_old', 1),
#  ('donuts_roommate', 1),
#  ('roommate_huge', 1),
#  ('huge_fans', 1),
#  ('fans_sugary', 1),
#  ('sugary_doughy', 1),
#  ('doughy_creations', 1),
#  ('creations_one', 1),
#  ('one_bonding', 1),
#  ('bonding_experiences', 1),
#  ('experiences_tend', 1),
#  ('tend_travel', 1),
#  ('travel_world', 1),
#  ('world_search', 1),
#  ('search_best', 1),
#  ('best_donuts', 1),
#  ('donuts_enjoys', 1),
#  ('enjoys_simple', 1),
#  ('simple_puffy', 1),
#  ('puffy_style', 1),
#  ('style_cakey', 1),
#  ('cakey_potentially', 1),
#  ('potentially_topped', 1),
#  ('topped_sprinkles', 1),
#  ('sprinkles_kind', 1),
#  ('kind_girl', 1),
#  ('girl_agree', 1),
#  ('agree_know', 1),
#  ('know_good', 1),
#  ('shop_old', 1),
#  ('old_fashioneds', 1),
#  ('fashioneds_winchells', 1),
#  ('winchells_fully', 1),
#  ('fully_stocked', 1),
#  ('stocked_donuts', 1),
#  ('pastries_milks', 1),
#  ('milks_juices', 1),
#  ('juices_arrived', 1),
#  ('arrived_randomly', 1),
#  ('randomly_afternoon', 1),
#  ('afternoon_greeted', 1),
#  ('greeted_spanish', 1),
#  ('spanish_many', 1),
#  ('many_confusing', 1),
#  ('confusing_spanglish', 1),
#  ('spanglish_talks', 1),
#  ('talks_gal', 1),
#  ('gal_working', 1),
#  ('working_speak', 1),
#  ('speak_much', 1),
#  ('much_english', 1),
#  ('english_luckily', 1),
#  ('luckily_donut', 1),
#  ('shop_could', 1),
#  ('could_point', 1),
#  ('point_wanted', 1),
#  ('wanted_least', 1),
#  ('least_purchasing', 1),
#  ('purchasing_taste', 1),
#  ('taste_tasting', 1),
#  ('tasting_came', 1),
#  ('came_conclusion', 1),
#  ('conclusion_mini', 1),
#  ('donuts_definitely', 1),
#  ('definitely_key', 1),
#  ('key_ingredient', 1),
#  ('ingredient_success', 1),
#  ('success_shop', 1),
#  ('shop_an', 1),
#  ('an_sb', 1),
#  ('sb_must', 1),
#  ('must_try', 1),
#  ('try_chocolate', 1),
#  ('chocolate_sprinkles', 1),
#  ('sprinkles_good', 1),
#  ('good_great', 1),
#  ('great_sugar', 1),
#  ('sugar_donut', 1),
#  ('donut_job', 1),
#  ('job_alright', 1),
#  ('alright_old', 1),
#  ('fashioned_rotten', 1),
#  ('rotten_cherry', 1),
#  ('cherry_oozing', 1),
#  ('oozing_sadness', 1),
#  ('sadness_top', 1),
#  ('top_would', 1),
#  ('would_definitely', 1),
#  ('definitely_come', 1),
#  ('come_back', 1),
#  ('back_shop', 1),
#  ('shop_get', 1),
#  ('get_adorable', 1),
#  ('adorable_donut', 1),
#  ('donut_minis', 1),
#  ('minis_thats', 1),
#  ('thats_probably', 1),
#  ('probably_it', 1),
#  ('it_far', 1),
#  ('far_best', 1),
#  ('best_donut', 1),
#  ('place_ever', 1),
#  ('ever_tried', 1),
#  ('tried_drive', 1),
#  ('drive_hour', 1),
#  ('hour_almost', 1),
#  ('almost_every', 1),
#  ('every_day', 1),
#  ('day_grab', 1),
#  ('grab_donut', 1),
#  ('place_mini', 1),
#  ('donuts_amazing', 1),
#  ('amazing_regular', 1),
#  ('regular_donuts', 1),
#  ('holes_oh', 1),
#  ('oh_god', 1),
#  ('god_melt', 1),
#  ('melt_mouth', 1),
#  ('mouth_deliciousness', 1),
#  ('deliciousness_got', 1),
#  ('got_old', 1),
#  ('fashioned_sack', 1),
#  ('sack_donut', 1),
#  ('holes_today', 1),
#  ('today_gloriously', 1),
#  ('gloriously_fresh', 1),
#  ('like_last', 1),
#  ('last_midnight', 1),
#  ('midnight_visit', 1),
#  ('visit_happy', 1),
#  ('happy_donuts', 1),
#  ('donuts_north', 1),
#  ('north_still', 1),
#  ('still_tasty', 1),
#  ('tasty_donuts', 1),
#  ('donuts_man', 1),
#  ('man_rang', 1),
#  ('rang_cheerful', 1),
#  ('cheerful_made', 1),
#  ('made_want', 1),
#  ('want_go', 1),
#  ('go_back', 1),
#  ('back_visit', 1),
#  ('visit_again', 1)]

# %%
good_Bakery=Bakery[Bakery.stars>=4.5]
good_Bakery_review = Bakery_review[Bakery_review.business_id.isin(good_Bakery.business_id.values)]
good_Bakery_review_text = good_Bakery_review.text.str.cat(sep = " ")
good_Bakery_tokens = word_tokenize(good_Bakery_review_text)
# FreqDist(good_American_tokens).most_common()
bigrams_list_good_Bakery = ["_".join(item) for item in nltk.bigrams(good_Bakery_tokens)]
trigrams_list_good_Bakery = ["_".join(item) for item in nltk.trigrams(good_Bakery_tokens)]

# FreqDist(bigrams_list_good_Bakery).most_common()
FreqDist(trigrams_list_good_Bakery).most_common()
# Out:
# [('ive_ever_had', 105),
#  ('kahlua_french_toast', 37),
#  ('best_ive_ever', 36),
#  ('definitely_come_back', 35),
#  ('visit_santa_barbara', 34),
#  ('gluten_free_bakery', 33),
#  ('wait_come_back', 32),
#  ('banana_kahlua_french', 32),
#  ('santa_barbara_area', 31),
#  ('come_back_try', 31),
#  ('cant_go_wrong', 31),
#  ('chocolate_chip_cookie', 31),
#  ('ham_cheese_croissant', 31),
#  ('cant_wait_come', 29),
#  ('cant_wait_go', 29),
#  ('highly_recommend_place', 29),
#  ('fried_egg_sandwich', 29),
#  ('definitely_coming_back', 27),
#  ('wait_go_back', 27),
#  ('banana_french_toast', 27),
#  ('would_definitely_recommend', 25),
#  ('trip_santa_barbara', 24),
#  ('would_highly_recommend', 23),
#  ('little_things_bakery', 23),
#  ('downtown_santa_barbara', 22),
#  ('visiting_santa_barbara', 22),
#  ('well_worth_it', 21),
#  ('squeezed_orange_juice', 21),
#  ('pain_au_chocolat', 20),
#  ('would_come_back', 20),
#  ('back_next_time', 20),
#  ('challah_french_toast', 20),
#  ('best_ever_had', 19),
#  ('fresh_squeezed_orange', 19),
#  ('chocolate_chip_cookies', 19),
#  ('french_toast_breakfast', 18),
#  ('coast_village_road', 17),
#  ('would_go_back', 16),
#  ('place_santa_barbara', 16),
#  ('everything_gluten_free', 16),
#  ('dedicated_gluten_free', 16),
#  ('cant_wait_try', 15),
#  ('definitely_go_back', 15),
#  ('love_love_love', 14),
#  ('way_start_day', 14),
#  ('next_time_im', 14),
#  ('looking_forward_trying', 14),
#  ('indoor_outdoor_seating', 14),
#  ('best_gluten_free', 14),
#  ('mushroom_cheese_croissant', 14),
#  ('great_food_great', 13),
#  ('food_great_service', 13),
#  ('bakery_santa_barbara', 13),
#  ('staff_super_friendly', 13),
#  ('great_customer_service', 13),
#  ('gluten_free_options', 13),
#  ('definitely_recommend_place', 13),
#  ('shop_santa_barbara', 13),
#  ('would_definitely_come', 13),
#  ('customer_service_great', 13),
#  ('go_back_try', 13),
#  ('santa_barbara_great', 12),
#  ('time_santa_barbara', 12),
#  ('rosemary_olive_bread', 12),
#  ('tri_tip_sandwich', 11),
#  ('every_time_visit', 11),
#  ('service_top_notch', 11),
#  ('were_santa_barbara', 11),
#  ('cant_say_enough', 11),
#  ('one_best_ive', 11),
#  ('way_santa_barbara', 11),
#  ('back_next_day', 11),
#  ('walking_state_street', 11),
#  ('high_quality_ingredients', 11),
#  ('lemon_raspberry_cake', 11),
#  ('staff_friendly_helpful', 10),
#  ('back_santa_barbara', 10),
#  ('stop_santa_barbara', 10),
#  ('cream_cheese_frosting', 10),
#  ('spot_santa_barbara', 10),
#  ('best_donuts_town', 10),
#  ('can_not_wait', 10),
#  ('delicious_highly_recommend', 10),
#  ('im_santa_barbara', 10),
#  ('want_go_back', 10),
#  ('one_favorite_places', 10),
#  ('best_ive_had', 10),
#  ('french_toast_delicious', 10),
#  ('best_croissant_ive', 10),
#  ('ordered_breakfast_sandwich', 10),
#  ('place_gluten_free', 10),
#  ('gluten_free_bread', 10),
#  ('gluten_free_desserts', 10),
#  ('tell_gluten_free', 10),
#  ('key_lime_tart', 10),
#  ('berry_patch_cake', 10),
#  ('keep_coming_back', 9),
#  ('croissant_breakfast_sandwich', 9),
#  ('cute_little_bakery', 9),
#  ('super_friendly_staff', 9),
#  ('great_way_start', 9),
#  ('sugar_cat_studio', 9),
#  ('santa_barbara_definitely', 9),
#  ('donuts_santa_barbara', 9),
#  ('delicious_gluten_free', 9),
#  ('outdoor_seating_area', 9),
#  ('staff_friendly_attentive', 9),
#  ('two_days_row', 9),
#  ('let_tell_you', 9),
#  ('grilled_cheese_sandwich', 9),
#  ('eat_gluten_free', 9),
#  ('gluten_free_cakes', 9),
#  ('gluten_free_cake', 9),
#  ('sea_salt_caramel', 9),
#  ('egg_bacon_brioche', 9),
#  ('croissant_almond_croissant', 9),
#  ('egg_bacon_sandwich', 9),
#  ('turkish_delights_baklava', 9),
#  ('hook_press_donuts', 9),
#  ('recommend_place_anyone', 8),
#  ('chipotle_chicken_sandwich', 8),
#  ('want_come_back', 8),
#  ('im_glad_did', 8),
#  ('tres_leches_cake', 8),
#  ('best_santa_barbara', 8),
#  ('ive_ever_tasted', 8),
#  ('next_time_were', 8),
#  ('lived_santa_barbara', 8),
#  ('fresh_squeezed_oj', 8),
#  ('go_back_next', 8),
#  ('best_customer_service', 8),
#  ('gim_me_gim', 8),
#  ('me_gim_me', 8),
#  ('good_customer_service', 8),
#  ('would_definitely_go', 8),
#  ('great_food_service', 8),
#  ('say_enough_good', 8),
#  ('next_time_visit', 8),
#  ('santa_barbara_get', 8),
#  ('eggs_cooked_perfectly', 8),
#  ('great_place_breakfast', 8),
#  ('santa_barbara_ordered', 8),
#  ('wait_line_order', 8),
#  ('give_place_stars', 8),
#  ('chicken_pesto_sandwich', 8),
#  ('croissant_chocolate_croissant', 8),
#  ('highly_recommend_coming', 8),
#  ('came_side_salad', 8),
#  ('get_pay_for', 8),
#  ('sour_cream_coffee', 8),
#  ('cream_coffee_cake', 8),
#  ('know_gluten_free', 8),
#  ('highly_recommend_it', 8),
#  ('come_back_again', 8),
#  ('new_york_cheesecake', 8),
#  ('order_counter_bring', 8),
#  ('best_almond_croissant', 8),
#  ('best_croissants_ive', 8),
#  ('kahlua_banana_french', 8),
#  ('almond_croissant_delicious', 8),
#  ('ordered_almond_croissant', 8),
#  ('croissants_ive_ever', 8),
#  ('chocolate_almond_croissant', 8),
#  ('turkish_delight_baklava', 8),
#  ('chicken_chipotle_sandwich', 7),
#  ('breakfast_burrito_delicious', 7),
#  ('every_time_come', 7),
#  ('can_not_recommend', 7),
#  ('back_try_more', 7),
#  ('place_breakfast_lunch', 7),
#  ('every_time_go', 7),
#  ('best_croissant_ever', 7),
#  ('love_love_place', 7),
#  ('great_little_spot', 7),
#  ('buy_one_get', 7),
#  ('staff_super_nice', 7),
#  ('live_santa_barbara', 7),
#  ('gluten_free_baked', 7),
#  ('made_us_feel', 7),
#  ('best_donuts_ever', 7),
#  ('mexican_hot_cocoa', 7),
#  ('great_place_grab', 7),
#  ('best_donuts_santa', 7),
#  ('makes_feel_like', 7),
#  ('gave_us_free', 7),
#  ('time_visit_santa', 7),
#  ('santa_barbara_love', 7),
#  ('definitely_going_back', 7),
#  ('really_good_too', 7),
#  ('enough_good_things', 7),
#  ('im_looking_forward', 7),
#  ('ham_egg_cheese', 7),
#  ('first_time_here', 7),
#  ('try_something_new', 7),
#  ('egg_cheese_croissant', 7),
#  ('really_wanted_like', 7),
#  ('great_place_go', 7),
#  ('belgian_waffle_breakfast', 7),
#  ('went_back_next', 7),
#  ('good_gluten_free', 7),
#  ('wish_lived_closer', 7),
#  ('place_like_this', 7),
#  ('weve_ever_had', 7),
#  ('overall_great_experience', 7),
#  ('french_toast_amazing', 7),
#  ('make_point_stop', 7),
#  ('ive_long_time', 7),
#  ('gluten_free_food', 7),
#  ('lemon_meringue_tart', 7),
#  ('highly_recommend_stopping', 7),
#  ('first_time_trying', 7),
#  ('boston_cream_pie', 7),
#  ('authentic_french_pastries', 7),
#  ('make_feel_like', 7),
#  ('get_almond_croissant', 7),
#  ('lemon_poppyseed_pancakes', 7),
#  ('ordered_croque_madame', 7),
#  ('almond_croissant_chocolate', 7),
#  ('strawberry_white_chocolate', 7),
#  ('best_almond_croissants', 7),
#  ('pumpkin_spice_latte', 7),
#  ('baklava_turkish_delight', 7),
#  ('would_recommend_place', 6),
#  ('highly_recommend_best', 6),
#  ('definitely_recommend_anyone', 6),
#  ('got_breakfast_burrito', 6),
#  ('recommend_place_enough', 6),
#  ('keep_good_work', 6),
#  ('everything_fresh_delicious', 6),
#  ('baked_goods_well', 6),
#  ('come_back_here', 6),
#  ('cinnamon_roll_french', 6),
#  ('roll_french_toast', 6),
#  ('really_really_good', 6),
#  ('wish_could_give', 6),
#  ('place_first_time', 6),
#  ('supporting_local_business', 6),
#  ('one_get_one', 6),
#  ('little_pricey_worth', 6),
#  ('day_santa_barbara', 6),
#  ('santa_barbara_wedding', 6),
#  ('staff_friendly_food', 6),
#  ('time_were_santa', 6),
#  ('ive_ever_eaten', 6),
#  ('cant_wait_return', 6),
#  ('free_baked_goods', 6),
#  ('santa_barbara_place', 6),
#  ('place_grab_quick', 6),
#  ('grab_quick_bite', 6),
#  ('dream_come_true', 6),
#  ('love_come_back', 6),
#  ('santa_barbara_delicious', 6),
#  ('santa_barbara_also', 6),
#  ('ham_cheese_egg', 6),
#  ('fresh_squeezed_juice', 6),
#  ('santa_barbara_best', 6),
#  ('best_donut_shop', 6),
#  ('area_highly_recommend', 6),
#  ('highly_recommend_great', 6),
#  ('coffee_friendly_staff', 6),
#  ('self_serve_coffee', 6),
#  ('come_santa_barbara', 6),
#  ('santa_barbara_location', 6),
#  ('stumbled_upon_place', 6),
#  ('definitely_worth_visit', 6),
#  ('could_give_stars', 6),
#  ('egg_white_omelette', 6),
#  ('chocolate_chip_scone', 6),
#  ('breakfast_club_sandwich', 6),
#  ('classic_eggs_benedict', 6),
#  ('nice_outdoor_seating', 6),
#  ('excellent_customer_service', 6),
#  ('oat_milk_latte', 6),
#  ('french_toast_good', 6),
#  ('ordered_french_toast', 6),
#  ('churros_ive_ever', 6),
#  ('every_time_im', 6),
#  ('croissant_ive_ever', 6),
#  ('perfect_way_start', 6),
#  ('try_next_time', 6),
#  ('brioche_french_toast', 6),
#  ('breakfast_lunch_menu', 6),
#  ('feel_like_im', 6),
#  ('try_almond_croissant', 6),
#  ('amazing_gluten_free', 6),
#  ('peanut_butter_cookie', 6),
#  ('idea_gluten_free', 6),
#  ('bring_food_table', 6),
#  ('coconut_cream_cake', 6),
#  ('taste_gluten_free', 6),
#  ('blueberry_lemon_tart', 6),
#  ('santa_barbara_would', 6),
#  ('turkey_club_sandwich', 6),
#  ('santa_barbara_went', 6),
#  ('im_big_fan', 6),
#  ('cake_ive_ever', 6),
#  ('almond_milk_latte', 6),
#  ('day_trip_santa', 6),
#  ('place_amazing_food', 6),
#  ('cookies_cream_cheesecake', 6),
#  ('die_for_also', 6),
#  ('santa_barbara_day', 6),
#  ('stand_line_order', 6),
#  ('totally_worth_it', 6),
#  ('counter_bring_food', 6),
#  ('best_french_toast', 6),
#  ('stop_every_time', 6),
#  ('egg_white_omelet', 6),
#  ('sunny_side_egg', 6),
#  ('breakfast_santa_barbara', 6),
#  ('make_us_feel', 6),
#  ('got_almond_croissant', 6),
#  ('bacon_egg_sandwich', 6),
#  ('egg_ham_cheese', 6),
#  ('white_chocolate_cake', 6),
#  ('almond_croissant_good', 6),
#  ('right_amount_sweetness', 6),
#  ('artichoke_goat_cheese', 6),
#  ('whipped_cream_frosting', 6),
#  ('great_little_bakery', 5),
#  ('fresh_baked_bread', 5),
#  ('scrambled_eggs_bacon', 5),
#  ('decided_give_try', 5),
#  ('best_breakfast_burrito', 5),
#  ('ever_had_even', 5),
#  ('one_best_breakfast', 5),
#  ('everything_ive_tried', 5),
#  ('great_little_place', 5),
#  ('ive_never_seen', 5),
#  ('also_got_chocolate', 5),
#  ('best_place_breakfast', 5),
#  ('baked_goods_good', 5),
#  ('food_amazing_service', 5),
#  ('woman_behind_counter', 5),
#  ('corks_n_crowns', 5),
#  ('brunch_santa_barbara', 5),
#  ('next_time_ill', 5),
#  ('delicious_cinnamon_rolls', 5),
#  ('friendly_staff_delicious', 5),
#  ('goat_cheese_muffin', 5),
#  ('get_one_free', 5),
#  ('looked_really_good', 5),
#  ('best_coffee_town', 5),
#  ('go_santa_barbara', 5),
#  ('even_gluten_free', 5),
#  ('super_nice_friendly', 5),
#  ('well_definitely_back', 5),
#  ('baked_goods_looked', 5),
#  ('best_breakfast_sandwich', 5),
#  ('cafe_au_lait', 5),
#  ('prices_little_high', 5),
#  ('go_back_again', 5),
#  ('next_visit_santa', 5),
#  ('thai_tea_oreo', 5),
#  ('montecito_country_mart', 5),
#  ('easy_work_with', 5),
#  ('come_back_more', 5),
#  ('place_visiting_santa', 5),
#  ('looking_forward_next', 5),
#  ('really_cant_go', 5),
#  ('staff_always_friendly', 5),
#  ('staff_extremely_friendly', 5),
#  ('coming_back_more', 5),
#  ('make_sure_stop', 5),
#  ('ever_santa_barbara', 5),
#  ('came_across_place', 5),
#  ('back_every_time', 5),
#  ('everything_looked_delicious', 5),
#  ('great_place_start', 5),
#  ('next_time_town', 5),
#  ('im_writing_review', 5),
#  ('donut_shop_santa', 5),
#  ('upper_state_street', 5),
#  ('good_things_place', 5),
#  ('stopped_way_santa', 5),
#  ('stop_next_time', 5),
#  ('next_time_area', 5),
#  ('place_really_good', 5),
#  ('place_definitely_worth', 5),
#  ('definitely_come_again', 5),
#  ('gem_santa_barbara', 5),
#  ('decided_try_place', 5),
#  ('service_delicious_food', 5),
#  ('along_state_street', 5),
#  ('santa_barbara_service', 5),
#  ('try_place_out', 5),
#  ('forward_going_back', 5),
#  ('time_im_town', 5),
#  ('would_recommend_anyone', 5),
#  ('highly_recommend_spot', 5),
#  ('came_first_time', 5),
#  ('girl_behind_counter', 5),
#  ('ever_had_super', 5),
#  ('ordered_eggs_benedict', 5),
#  ('delicious_would_definitely', 5),
#  ('location_great_food', 5),
#  ('vegan_gluten_free', 5),
#  ('line_order_food', 5),
#  ('last_time_went', 5),
#  ('eggs_benedict_delicious', 5),
#  ('really_enjoyed_it', 5),
#  ('amazing_would_definitely', 5),
#  ('go_wrong_anything', 5),
#  ('wrong_anything_menu', 5),
#  ('best_churros_ive', 5),
#  ('time_im_santa', 5),
#  ('got_avocado_toast', 5),
#  ('ive_ever_seen', 5),
#  ('never_go_back', 5),
#  ('find_place_like', 5),
#  ('guava_cream_cheese', 5),
#  ('restaurant_santa_barbara', 5),
#  ('lemon_poppy_seed', 5),
#  ('best_one_ive', 5),
#  ('ever_had_also', 5),
#  ('busy_saturday_morning', 5),
#  ('absolutely_love_place', 5),
#  ('chocolate_almond_praline', 5),
#  ('completely_gluten_free', 5),
#  ('would_never_know', 5),
#  ('gluten_free_even', 5),
#  ('located_state_street', 5),
#  ('worth_every_penny', 5),
#  ('latte_almond_milk', 5),
#  ('got_french_toast', 5),
#  ('chocolate_sea_salt', 5),
#  ('gluten_free_all', 5),
#  ('salt_caramel_cake', 5),
#  ('love_lilac_patisserie', 5),
#  ('ill_go_back', 5),
#  ('gluten_free_cheesecake', 5),
#  ('key_lime_pie', 5),
#  ('ive_gluten_free', 5),
#  ('pastries_die_for', 5),
#  ('chocolate_mousse_filling', 5),
#  ('coffee_good_too', 5),
#  ('friendly_helpful_staff', 5),
#  ('best_bakery_santa', 5),
#  ('made_feel_like', 5),
#  ('santa_barbara_stopped', 5),
#  ('delicious_baked_goods', 5),
#  ('it_highly_recommend', 5),
#  ('definitely_worth_try', 5),
#  ('hands_down_best', 5),
#  ('one_best_croissants', 5),
#  ('good_almond_croissant', 5),
#  ('ive_outside_france', 5),
#  ('sit_outside_enjoy', 5),
#  ('ordered_banana_kahlua', 5),
#  ('french_toast_really', 5),
#  ('good_french_toast', 5),
#  ('order_food_counter', 5),
#  ('renauds_almond_croissant', 5),
#  ('great_breakfast_place', 5),
#  ('almond_croissant_ever', 5),
#  ('french_toast_eggs', 5),
#  ('best_wedding_cake', 5),
#  ('french_toast_also', 5),
#  ('croissants_almond_croissants', 5),
#  ('like_bananas_foster', 5),
#  ('service_great_food', 5),
#  ('breakfast_two_days', 5),
#  ('croissant_die_for', 5),
#  ('guy_behind_counter', 5),
#  ('norwegian_eggs_benedict', 5),
#  ('give_place_try', 5),
#  ('goat_cheese_sandwich', 5),
#  ('staff_really_nice', 5),
#  ('white_picket_fence', 5),
#  ('raspberry_bavarian_cream', 5),
#  ('lobster_eggs_benedict', 5),
#  ('croissant_cinnamon_roll', 5),
#  ('santa_barbara_weekend', 5),
#  ('benedict_smoked_salmon', 5),
#  ('turkish_delights_amazing', 5),
#  ('baklava_turkish_delights', 5),
#  ('delicious_turkish_delight', 5),
#  ('try_turkish_coffee', 5),
#  ('mexican_hot_chocolate', 5),
#  ('brown_butter_donut', 5),
#  ('right_around_corner', 4),
#  ('one_favorite_spots', 4),
#  ('ill_back_soon', 4),
#  ('santa_barbara_always', 4),
#  ('way_start_morning', 4),
#  ('chorizo_breakfast_burrito', 4),
#  ('pastries_baked_goods', 4),
#  ('santa_barbara_county', 4),
#  ('staff_kind_helpful', 4),
#  ('birria_tacos_weekend', 4),
#  ('place_absolute_gem', 4),
#  ('family_run_business', 4),
#  ('definitely_worth_stop', 4),
#  ('highly_recommend_cake', 4),
#  ('always_fresh_delicious', 4),
#  ('go_back_soon', 4),
#  ('delicious_im_going', 4),
#  ('baked_goods_delicious', 4),
#  ('best_cinnamon_roll', 4),
#  ('come_back_breakfast', 4),
#  ('one_cinnamon_roll', 4),
#  ('outdoor_patio_seating', 4),
#  ('jalapeno_biscuit_sandwich', 4),
#  ('bit_pricey_side', 4),
#  ('best_cinnamon_rolls', 4),
#  ('really_like_place', 4),
#  ('like_french_toast', 4),
#  ('outside_moist_inside', 4),
#  ('chocolate_peanut_butter', 4),
#  ('saturday_farmers_market', 4),
#  ('santa_barbara_come', 4),
#  ('let_start_saying', 4),
#  ('super_cute_place', 4),
#  ('chai_tea_latte', 4),
#  ('time_im_area', 4),
#  ('probably_go_back', 4),
#  ('really_good_definitely', 4),
#  ('lemon_meringue_pie', 4),
#  ('back_great_place', 4),
#  ('cant_wait_see', 4),
#  ('would_love_come', 4),
#  ('forward_next_visit', 4),
#  ('amazing_highly_recommend', 4),
#  ('variety_choose_from', 4),
#  ('make_sure_go', 4),
#  ('best_breakfast_ever', 4),
#  ('also_got_two', 4),
#  ('fresh_squeezed_juices', 4),
#  ('come_back_every', 4),
#  ('bagel_cream_cheese', 4),
#  ('santa_barbara_amazing', 4),
#  ('perfect_amount_sweetness', 4),
#  ('really_good_donuts', 4),
#  ('best_donuts_sb', 4),
#  ('ever_had_definitely', 4),
#  ('upper_state_st', 4),
#  ('lady_helped_us', 4),
#  ('place_start_day', 4),
#  ('breakfast_sandwich_fresh', 4),
#  ('person_behind_counter', 4),
#  ('bacon_egg_cheese', 4),
#  ('come_back_next', 4),
#  ('next_time_santa', 4),
#  ('always_make_point', 4),
#  ('santa_barbara_real', 4),
#  ('croissant_best_ive', 4),
#  ('go_get_one', 4),
#  ('great_friendly_service', 4),
#  ('cream_cheese_bagel', 4),
#  ('come_los_angeles', 4),
#  ('average_donut_shop', 4),
#  ('plan_come_back', 4),
#  ('absolutely_loved_it', 4),
#  ('next_time_want', 4),
#  ('would_love_try', 4),
#  ('first_time_coming', 4),
#  ('let_us_know', 4),
#  ('would_definitely_stop', 4),
#  ('one_upper_state', 4),
#  ('donuts_good_coffee', 4),
#  ('cheese_croissant_sandwich', 4),
#  ('place_highly_recommend', 4),
#  ('donuts_really_good', 4),
#  ('try_chocolate_croissant', 4),
#  ('service_really_good', 4),
#  ('today_first_time', 4),
#  ('everything_tasted_good', 4),
#  ('food_worth_it', 4),
#  ('ordered_breakfast_burrito', 4),
#  ('locations_santa_barbara', 4),
#  ('customer_service_amazing', 4),
#  ('amazing_food_delicious', 4),
#  ('food_absolutely_amazing', 4),
#  ('highly_recommend_anyone', 4),
#  ('great_breakfast_spot', 4),
#  ('staff_friendly_welcoming', 4),
#  ('it_also_ordered', 4),
#  ('service_excellent_food', 4),
#  ('had_cant_wait', 4),
#  ('outside_seating_great', 4),
#  ('favorite_place_breakfast', 4),
#  ('times_every_time', 4),
#  ('plenty_outdoor_seating', 4),
#  ('latte_one_best', 4),
#  ('food_baked_goods', 4),
#  ('good_coffee_too', 4),
#  ('best_eggs_benedict', 4),
#  ('ordered_lobster_benedict', 4),
#  ('service_good_food', 4),
#  ('good_food_nice', 4),
#  ('highly_recommend_try', 4),
#  ('orange_juice_fresh', 4),
#  ('food_customer_service', 4),
#  ('customer_service_top', 4),
#  ('pretty_good_too', 4),
#  ('santa_barbara_must', 4),
#  ('coming_back_again', 4),
#  ('wish_place_like', 4),
#  ('give_another_try', 4),
#  ('best_place_santa', 4),
#  ('eggs_smoked_salmon', 4),
#  ('food_die_for', 4),
#  ('best_croissants_town', 4),
#  ('coffee_almond_croissant', 4),
#  ('croque_madame_delicious', 4),
#  ('croissant_best_ever', 4),
#  ('every_single_thing', 4),
#  ('ever_had_flaky', 4),
#  ('sandwich_croque_monsieur', 4),
#  ('breakfast_lunch_pastries', 4),
#  ('ive_ever_life', 4),
#  ('good_highly_recommend', 4),
#  ('ordered_chocolate_croissant', 4),
#  ('ever_had_ive', 4),
#  ('cute_little_spot', 4),
#  ('ordered_scrambled_eggs', 4),
#  ('gluten_free_diet', 4),
#  ('free_bread_ive', 4),
#  ('bread_ive_ever', 4),
#  ('german_chocolate_cake', 4),
#  ('walking_state_st', 4),
#  ('mention_gluten_free', 4),
#  ('santa_barbara_try', 4),
#  ('really_enjoy_it', 4),
#  ('bakery_gluten_free', 4),
#  ('favorite_santa_barbara', 4),
#  ('hard_time_deciding', 4),
#  ('delicious_also_got', 4),
#  ('decadent_chocolate_cake', 4),
#  ('gluten_free_everything', 4),
#  ('chocolate_decadence_cake', 4),
#  ('best_decision_made', 4),
#  ('wanted_like_place', 4),
#  ('ordered_birthday_cake', 4),
#  ('cake_gluten_free', 4),
#  ('couple_years_ago', 4),
#  ('great_reviews_yelp', 4),
#  ('breakfast_sandwich_really', 4),
#  ('make_sure_try', 4),
#  ('gluten_free_pastries', 4),
#  ('thoroughly_enjoyed_it', 4),
#  ('gluten_free_restaurant', 4),
#  ('go_back_more', 4),
#  ('im_gluten_free', 4),
#  ('place_really_cute', 4),
#  ('drive_santa_barbara', 4),
#  ('food_delicious_staff', 4),
#  ('free_bakery_cafe', 4),
#  ('visited_santa_barbara', 4),
#  ('even_tell_gluten', 4),
#  ('highly_recommend_trying', 4),
#  ('red_velvet_cake', 4),
#  ('gluten_free_delicious', 4),
#  ('really_wanted_try', 4),
#  ('one_best_bakeries', 4),
#  ('entirely_gluten_free', 4),
#  ('heart_santa_barbara', 4),
#  ('came_back_next', 4),
#  ('vegan_carrot_cupcake', 4),
#  ('really_wanted_love', 4),
#  ('cute_little_shop', 4),
#  ('check_place_out', 4),
#  ('also_got_chai', 4),
#  ('got_chai_latte', 4),
#  ('sandwich_quiche_lorraine', 4),
#  ('quiche_ive_ever', 4),
#  ('one_best_cakes', 4),
#  ('strolling_state_street', 4),
#  ('it_customer_service', 4),
#  ('place_great_breakfast', 4),
#  ('bakery_wedding_cake', 4),
#  ('to_die_for', 4),
#  ('cake_ever_had', 4),
#  ('employees_friendly_helpful', 4),
#  ('fresh_whipped_cream', 4),
#  ('street_santa_barbara', 4),
#  ('would_recommend_coming', 4),
#  ('red_velvet_cupcakes', 4),
#  ('tried_french_toast', 4),
#  ('young_french_couple', 4),
#  ('cake_bavarian_cream', 4),
#  ('bavarian_cream_filling', 4),
#  ('dulce_de_leche', 4),
#  ('peach_mint_iced', 4),
#  ('mint_iced_tea', 4),
#  ('place_breakfast_montecito', 4),
#  ('took_one_bite', 4),
#  ('almond_croissant_go', 4),
#  ('smoked_salmon_sandwich', 4),
#  ('french_toast_must', 4),
#  ('delicious_definitely_worth', 4),
#  ('french_bakery_santa', 4),
#  ('treated_us_like', 4),
#  ('gluten_free_chocolate', 4),
#  ('never_came_back', 4),
#  ('roasted_chicken_sandwich', 4),
#  ('food_nice_atmosphere', 4),
#  ('highly_recommended_best', 4),
#  ('make_sure_get', 4),
#  ('almond_croissant_first', 4),
#  ('inside_tables_outside', 4),
#  ('come_back_santa', 4),
#  ('wedding_cake_ever', 4),
#  ('days_santa_barbara', 4),
#  ('great_brunch_spot', 4),
#  ('authentic_french_bakery', 4),
#  ('line_order_counter', 4),
#  ('benedict_french_toast', 4),
#  ('bring_food_you', 4),
#  ('smoked_salmon_avocado', 4),
#  ('salmon_avocado_sandwich', 4),
#  ('definitely_worth_wait', 4),
#  ('almond_croissant_die', 4),
#  ('inside_outside_seating', 4),
#  ('cake_moist_delicious', 4),
#  ('stop_next_visit', 4),
#  ('first_time_visiting', 4),
#  ('eggs_bacon_brioche', 4),
#  ('way_back_la', 4),
#  ('serve_peets_coffee', 4),
#  ('try_santa_barbara', 4),
#  ('egg_smoked_salmon', 4),
#  ('great_spot_breakfast', 4),
#  ('highly_recommend_breakfast', 4),
#  ('im_huge_fan', 4),
#  ('croissant_ever_had', 4),
#  ('santa_barbara_came', 4),
#  ('nice_place_enjoy', 4),
#  ('famous_banana_kahlua', 4),
#  ('nice_little_place', 4),
#  ('love_coming_here', 4),
#  ('hollandaise_sauce_creamy', 4),
#  ('perfect_every_way', 4),
#  ('pass_next_time', 4),
#  ('almond_brioche_croissant', 4),
#  ('passing_santa_barbara', 4),
#  ('service_great_friendly', 4),
#  ('can_not_say', 4),
#  ('not_say_enough', 4),
#  ('weekend_getaway_santa', 4),
#  ('getaway_santa_barbara', 4),
#  ('bacon_egg_brioche', 4),
#  ('ordered_fried_egg', 4),
#  ('try_something_different', 4),
#  ('almond_creme_brioche', 4),
#  ('poppy_seed_pancakes', 4),
#  ('coffee_pretty_good', 4),
#  ('almond_croissant_amazing', 4),
#  ('almond_croissant_flaky', 4),
#  ('delicious_staff_friendly', 4),
#  ('grilled_ham_cheese', 4),
#  ('great_people_watching', 4),
#  ('eggs_benedict_smoked', 4),
#  ('two_poached_eggs', 4),
#  ('discovered_little_gem', 4),
#  ('food_always_fresh', 4),
#  ('egg_cheese_brioche', 4),
#  ('almond_chocolate_croissant', 4),
#  ('egg_cheese_breakfast', 4),
#  ('cheese_breakfast_sandwich', 4),
#  ('breakfast_sandwich_simple', 4),
#  ('brioche_breakfast_sandwich', 4),
#  ('even_though_ordered', 4),
#  ('support_local_businesses', 4),
#  ('thank_little_things', 4),
#  ('samples_turkish_delights', 4),
#  ('turkish_coffee_great', 4),
#  ('pistachio_turkish_delight', 4),
#  ('love_turkish_coffee', 4),
#  ('time_trying_turkish', 4),
#  ('try_turkish_delight', 4),
#  ('chocolate_pistachio_baklava', 4),
#  ('different_types_baklava', 4),
#  ('breakfast_burritos_great', 4),
#  ('best_donut_ive', 4),
#  ('pecan_pie_donut', 4),
#  ('passion_fruit_orange', 4),
#  ('fruit_orange_guava', 4),
#  ('inside_mosaic_locale', 4),
#  ('everything_bagel_donut', 4),
#  ('blood_orange_creamsicle', 4),
#  ('chocolate_four_ways', 4),
#  ('dark_chocolate_glaze', 4),
#  ('yeast_raised_ring', 4),
#  ('ordered_chicken_tamale', 3),
#  ('hidden_gem_goleta', 3),
#  ('service_friendly_staff', 3),
#  ('good_food_good', 3),
#  ('selection_baked_goods', 3),
#  ('breakfast_lunch_place', 3),
#  ('behind_caseys_garage', 3),
#  ('definitely_stop_by', 3),
#  ('feel_like_ate', 3),
#  ('hole_wall_bakery', 3),
#  ('ordered_chorizo_burrito', 3),
#  ('lady_took_order', 3),
#  ('everyone_super_nice', 3),
#  ('sandwich_breakfast_burrito', 3),
#  ('great_service_friendly', 3),
#  ('go_anywhere_else', 3),
#  ('sandwich_ever_had', 3),
#  ('best_breakfast_burritos', 3),
#  ('lady_behind_counter', 3),
#  ('mexican_sweet_bread', 3),
#  ('food_friendly_service', 3),
#  ('delicious_breakfast_burritos', 3),
#  ('wonderful_baked_goods', 3),
#  ('loved_it_great', 3),
#  ('crispy_outside_soft', 3),
#  ('fresh_orange_juice', 3),
#  ('breads_fresh_tasty', 3),
#  ('try_birria_tacos', 3),
#  ('cant_recommend_place', 3),
#  ('santa_barbara_took', 3),
#  ('place_go_first', 3),
#  ('least_twice_week', 3),
#  ('small_family_run', 3),
#  ('feel_like_family', 3),
#  ('weekends_worth_wait', 3),
#  ('even_gave_us', 3),
#  ('cute_little_place', 3),
#  ('ill_definitely_back', 3),
#  ('first_time_today', 3),
#  ('open_till_pm', 3),
#  ('employees_really_nice', 3),
#  ('tell_really_care', 3),
#  ('definitely_visit_im', 3),
#  ('fresh_baked_goods', 3),
#  ('place_hidden_gem', 3),
#  ('came_right_closing', 3),
#  ('mom_pop_shop', 3),
#  ('people_working_super', 3),
#  ('working_super_nice', 3),
#  ('love_place_much', 3),
#  ('outdoor_indoor_seating', 3),
#  ('one_best_places', 3),
#  ('everyone_super_friendly', 3),
#  ('try_anything_else', 3),
#  ('bakery_super_cute', 3),
#  ('place_easy_miss', 3),
#  ('soy_chai_latte', 3),
#  ('tried_cinnamon_roll', 3),
#  ('french_toast_little', 3),
#  ('menu_looked_good', 3),
#  ('real_maple_syrup', 3),
#  ('great_cinnamon_roll', 3),
#  ('overall_excellent_experience', 3),
#  ('santa_barbara_ca', 3),
#  ('little_bit_pricey', 3),
#  ('come_back_coffee', 3),
#  ('blueberry_goat_cheese', 3),
#  ('biscuit_breakfast_sandwich', 3),
#  ('cinnamon_rolls_best', 3),
#  ('top_quality_ingredients', 3),
#  ('go_back_place', 3),
#  ('good_cinnamon_rolls', 3),
#  ('worth_it_best', 3),
#  ('santa_barbara_stop', 3),
#  ('morning_cant_wait', 3),
#  ('owner_took_time', 3),
#  ('place_go_breakfast', 3),
#  ('go_breakfast_spot', 3),
#  ('bacon_cheddar_scone', 3),
#  ('going_back_next', 3),
#  ('breakfast_sandwich_also', 3),
#  ('super_friendly_service', 3),
#  ('friendly_service_well', 3),
#  ('cute_little_restaurant', 3),
#  ('delicious_food_great', 3),
#  ('bakery_items_delicious', 3),
#  ('looks_like_little', 3),
#  ('gluten_free_items', 3),
#  ('le_cordon_bleu', 3),
#  ('definitely_visit_again', 3),
#  ('santa_barbara_husband', 3),
#  ('santa_barbara_well', 3),
#  ('wish_lived_santa', 3),
#  ('back_bay_area', 3),
#  ('atmosphere_delicious_food', 3),
#  ('gluten_free_cupcakes', 3),
#  ('left_wanting_more', 3),
#  ('definitely_order_again', 3),
#  ('quaint_little_bakery', 3),
#  ('gluten_free_products', 3),
#  ('earl_grey_tea', 3),
#  ('decided_try_out', 3),
#  ('best_coffee_americano', 3),
#  ('everything_delicious_place', 3),
#  ('like_santa_barbara', 3),
#  ('us_made_us', 3),
#  ('red_velvet_cream', 3),
#  ('velvet_cream_cheese', 3),
#  ('food_really_good', 3),
#  ('taste_really_good', 3),
#  ('customer_service_ive', 3),
#  ('ever_had_thank', 3),
#  ('gim_me_more', 3),
#  ('ill_coming_back', 3),
#  ('not_recommend_place', 3),
#  ('highly_recommend_delicious', 3),
#  ('think_ive_ever', 3),
#  ('i_think_owner', 3),
#  ('first_time_last', 3),
#  ('better_ones_ive', 3),
#  ('santa_barbara_im', 3),
#  ('amazing_food_amazing', 3),
#  ('forward_trying_place', 3),
#  ('working_behind_counter', 3),
#  ('delicious_order_counter', 3),
#  ('husband_egg_bacon', 3),
#  ('food_okay_service', 3),
#  ('chicken_pot_pie', 3),
#  ('cake_chocolate_chip', 3),
#  ('staff_behind_counter', 3),
#  ('chip_cookie_dough', 3),
#  ('sandwiches_fresh_squeezed', 3),
#  ('amazing_customer_service', 3),
#  ('friendly_customer_service', 3),
#  ('best_breakfast_spot', 3),
#  ('perfectly_cooked_egg', 3),
#  ('trying_something_new', 3),
#  ('made_potato_flour', 3),
#  ('come_every_time', 3),
#  ('every_time_were', 3),
#  ('best_donut_place', 3),
#  ('places_santa_barbara', 3),
#  ('got_breakfast_sandwich', 3),
#  ('morning_first_time', 3),
#  ('state_st_santa', 3),
#  ('st_santa_barbara', 3),
#  ('got_thai_tea', 3),
#  ('quick_bite_eat', 3),
#  ('lox_cream_cheese', 3),
#  ('always_smile_face', 3),
#  ('family_owned_business', 3),
#  ('santa_barbara_couple', 3),
#  ('friendly_service_great', 3),
#  ('back_more_place', 3),
#  ('pastries_look_amazing', 3),
#  ('totally_recommend_place', 3),
#  ('decided_stop_breakfast', 3),
#  ('feel_right_home', 3),
#  ('hope_come_back', 3),
#  ('orange_carrot_juice', 3),
#  ('steady_stream_customers', 3),
#  ('could_ask_for', 3),
#  ('parking_easy_prices', 3),
#  ('overall_great_place', 3),
#  ('place_feel_like', 3),
#  ('feel_like_home', 3),
#  ('santa_barbara_far', 3),
#  ('donuts_ever_had', 3),
#  ('place_visit_santa', 3),
#  ('best_place_ive', 3),
#  ('amazing_super_fresh', 3),
#  ('freshly_squeezed_orange', 3),
#  ('awesome_customer_service', 3),
#  ('free_donut_holes', 3),
#  ('breakfast_sandwich_delicious', 3),
#  ('two_thumbs_up', 3),
#  ('small_donut_shop', 3),
#  ('friendly_service_excellent', 3),
#  ('bagels_ive_ever', 3),
#  ('santa_barbara_visit', 3),
#  ('local_santa_barbara', 3),
#  ('great_service_awesome', 3),
#  ('first_time_santa', 3),
#  ('visit_next_time', 3),
#  ('santa_barbara_grab', 3),
#  ('place_would_go', 3),
#  ('see_fuss_about', 3),
#  ('egg_sandwich_delicious', 3),
#  ('state_street_first', 3),
#  ('next_time_come', 3),
#  ('really_good_food', 3),
#  ('customer_service_always', 3),
#  ('santa_barbara_friend', 3),
#  ('find_santa_barbara', 3),
#  ('santa_barbara_even', 3),
#  ('chocolate_donut_amazing', 3),
#  ('egg_bacon_cheese', 3),
#  ('bacon_cheese_egg', 3),
#  ('took_one_look', 3),
#  ('find_another_place', 3),
#  ('service_always_friendly', 3),
#  ('definitely_back_delicious', 3),
#  ('friendly_service_good', 3),
#  ('also_really_good', 3),
#  ('could_ever_want', 3),
#  ('good_breakfast_sandwiches', 3),
#  ('ive_coming_years', 3),
#  ('pretty_good_nice', 3),
#  ('definitely_stop_again', 3),
#  ('staff_friendly_accommodating', 3),
#  ('great_place_good', 3),
#  ('favorite_donut_shop', 3),
#  ('sit_eat_breakfast', 3),
#  ('service_great_too', 3),
#  ('great_breakfast_sandwiches', 3),
#  ('ordered_egg_bacon', 3),
#  ...]

# %% [markdown]
# ### Mexican

# %%
Mexican = business_df[business_df.Type=='Mexican']
Mexican_review = review1[review1.business_id.isin(Mexican.business_id.values)]
Mexican_review["text"] = Mexican_review["text"].str.lower()
Mexican_review['text'] = Mexican_review['text'].apply(lambda text: cleaning_stopwords(text))
Mexican_review['text']= Mexican_review['text'].apply(lambda x: cleaning_punctuations(x))
Mexican_review['text'] = Mexican_review['text'].apply(lambda x: cleaning_repeating_char(x))
Mexican_review['text'] = Mexican_review['text'].apply(lambda x: cleaning_URLs(x))
Mexican_review['text'] = Mexican_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Mexican=Mexican[Mexican.stars<3.5]
bad_Mexican_review = Mexican_review[Mexican_review.business_id.isin(bad_Mexican.business_id.values)]
bad_Mexican_review_text = bad_Mexican_review.text.str.cat(sep = " ")
bad_Mexican_tokens = word_tokenize(bad_Mexican_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_bad_Mexican = ["_".join(item) for item in nltk.bigrams(bad_Mexican_tokens)]
trigrams_list_bad_Mexican = ["_".join(item) for item in nltk.trigrams(bad_Mexican_tokens)]
FreqDist(bigrams_list_bad_Mexican).most_common()
# FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('mexican_food', 99),
#  ('customer_service', 75),
#  ('salsa_bar', 43),
#  ('santa_barbara', 43),
#  ('rice_beans', 42),
#  ('carne_asada', 37),
#  ('every_time', 32),
#  ('sour_cream', 31),
#  ('food_good', 31),
#  ('love_chipotle', 29),
#  ('taco_tuesday', 26),
#  ('coming_back', 25),
#  ('beans_rice', 23),
#  ('go_back', 21),
#  ('pretty_good', 21),
#  ('first_time', 20),
#  ('ive_ever', 20),
#  ('good_food', 20),
#  ('food_great', 19),
#  ('great_food', 18),
#  ('quality_food', 18),
#  ('come_back', 17),
#  ('authentic_mexican', 17),
#  ('fast_food', 16),
#  ('next_time', 16),
#  ('one_star', 15),
#  ('looked_like', 15),
#  ('gift_card', 14),
#  ('going_back', 14),
#  ('chips_salsa', 14),
#  ('chicken_tacos', 14),
#  ('got_home', 13),
#  ('across_street', 13),
#  ('great_service', 13),
#  ('come_here', 13),
#  ('even_though', 13),
#  ('burrito_bowl', 13),
#  ('mexican_restaurants', 13),
#  ('really_good', 13),
#  ('mexican_restaurant', 13),
#  ('always_good', 12),
#  ('service_good', 12),
#  ('friendly_staff', 12),
#  ('feel_like', 12),
#  ('worst_chipotle', 12),
#  ('make_sure', 12),
#  ('chicken_burrito', 12),
#  ('al_pastor', 12),
#  ('time_go', 12),
#  ('veggie_burrito', 12),
#  ('fish_tacos', 12),
#  ('good_mexican', 12),
#  ('taco_grande', 12),
#  ('chipotle_location', 11),
#  ('food_always', 11),
#  ('one_time', 11),
#  ('chile_relleno', 11),
#  ('last_time', 11),
#  ('always_get', 11),
#  ('chicken_bowl', 11),
#  ('food_poisoning', 10),
#  ('somewhere_else', 10),
#  ('pico_de', 10),
#  ('de_gallo', 10),
#  ('ordered_chicken', 10),
#  ('seems_like', 10),
#  ('good_service', 10),
#  ('back_again', 10),
#  ('would_recommend', 10),
#  ('upper_state', 10),
#  ('long_time', 10),
#  ('strip_mall', 10),
#  ('food_quality', 10),
#  ('one_thing', 9),
#  ('get_food', 9),
#  ('food_go', 9),
#  ('service_great', 9),
#  ('ive_to', 9),
#  ('super_cucas', 9),
#  ('taco_bell', 9),
#  ('chipotle_ive', 9),
#  ('behind_counter', 9),
#  ('thank_you', 9),
#  ('best_mexican', 9),
#  ('tasted_like', 9),
#  ('shredded_beef', 9),
#  ('get_order', 9),
#  ('order_right', 9),
#  ('look_like', 9),
#  ('chicken_taco', 9),
#  ('crispy_tacos', 9),
#  ('good_place', 9),
#  ('good_thing', 9),
#  ('asked_could', 8),
#  ('can_not', 8),
#  ('service_food', 8),
#  ('staff_friendly', 8),
#  ('much_better', 8),
#  ('ive_never', 8),
#  ('chipotle_ever', 8),
#  ('ever_to', 8),
#  ('service_ever', 8),
#  ('food_came', 8),
#  ('black_beans', 8),
#  ('good_too', 8),
#  ('eye_contact', 8),
#  ('food_delicious', 8),
#  ('cheese_enchiladas', 8),
#  ('ever_had', 8),
#  ('love_rudys', 8),
#  ('time_come', 8),
#  ('go_here', 8),
#  ('hard_shell', 8),
#  ('love_place', 8),
#  ('felt_like', 8),
#  ('small_portions', 7),
#  ('time_get', 7),
#  ('got_food', 7),
#  ('order_online', 7),
#  ('two_people', 7),
#  ('go_order', 7),
#  ('cheese_sour', 7),
#  ('never_again', 7),
#  ('la_cumbre', 7),
#  ('ordered_online', 7),
#  ('let_know', 7),
#  ('order_food', 7),
#  ('place_go', 7),
#  ('tastes_like', 7),
#  ('food_service', 7),
#  ('highly_recommend', 7),
#  ('ive_eaten', 7),
#  ('breakfast_burrito', 7),
#  ('food_ordered', 7),
#  ('like_it', 7),
#  ('burrito_chicken', 7),
#  ('taste_like', 7),
#  ('food_would', 7),
#  ('breakfast_burritos', 7),
#  ('crispy_chicken', 7),
#  ('beef_tacos', 7),
#  ('tacos_good', 7),
#  ('service_fast', 7),
#  ('next_door', 7),
#  ('grilled_chicken', 7),
#  ('would_like', 7),
#  ('great_place', 7),
#  ('credit_card', 7),
#  ('could_get', 6),
#  ('food_tasted', 6),
#  ('half_scoop', 6),
#  ('eat_it', 6),
#  ('place_clean', 6),
#  ('friendly_food', 6),
#  ('chipotle_great', 6),
#  ('food_well', 6),
#  ('food_even', 6),
#  ('get_one', 6),
#  ('food_fresh', 6),
#  ('stay_away', 6),
#  ('could_give', 6),
#  ('great_customer', 6),
#  ('brown_rice', 6),
#  ('online_orders', 6),
#  ('ordered_burrito', 6),
#  ('worst_service', 6),
#  ('worst_customer', 6),
#  ('one_best', 6),
#  ('bowl_burrito', 6),
#  ('piece_chicken', 6),
#  ('multiple_times', 6),
#  ('money_back', 6),
#  ('never_go', 6),
#  ('im_sure', 6),
#  ('particular_chipotle', 6),
#  ('think_would', 6),
#  ('place_order', 6),
#  ('portion_sizes', 6),
#  ('chile_verde', 6),
#  ('great_mexican', 6),
#  ('love_it', 6),
#  ('beef_taco', 6),
#  ('gave_us', 6),
#  ('rice_cheese', 6),
#  ('service_horrible', 6),
#  ('food_ok', 6),
#  ('asada_taco', 6),
#  ('told_us', 6),
#  ('fajita_burrito', 6),
#  ('bag_chips', 6),
#  ('combo_burrito', 6),
#  ('rudys_best', 6),
#  ('best_burritos', 6),
#  ('bar_good', 6),
#  ('last_night', 6),
#  ('los_agaves', 6),
#  ('wet_burrito', 6),
#  ('state_street', 6),
#  ('pretty_big', 6),
#  ('several_times', 6),
#  ('gon_na', 6),
#  ('bean_rice', 6),
#  ('food_place', 6),
#  ('time_ive', 6),
#  ('food_really', 6),
#  ('service_always', 6),
#  ('great_salsa', 6),
#  ('decent_food', 6),
#  ('keep_coming', 6),
#  ('horrible_service', 6),
#  ('airport_food', 6),
#  ('garden_burrito', 6),
#  ('el_taco', 6),
#  ('would_take', 6),
#  ('looks_like', 5),
#  ('ive_going', 5),
#  ('going_chipotle', 5),
#  ('go_chipotle', 5),
#  ('like_this', 5),
#  ('burrito_huge', 5),
#  ('never_return', 5),
#  ('people_line', 5),
#  ('eat_here', 5),
#  ('im_town', 5),
#  ('dining_area', 5),
#  ('years_ago', 5),
#  ('food_tastes', 5),
#  ('went_back', 5),
#  ('minutes_later', 5),
#  ('order_ready', 5),
#  ('extra_meat', 5),
#  ('get_home', 5),
#  ('put_burrito', 5),
#  ('online_order', 5),
#  ('came_back', 5),
#  ('ordered_food', 5),
#  ('ever_seen', 5),
#  ('taking_order', 5),
#  ('half_full', 5),
#  ('charged_us', 5),
#  ('take_order', 5),
#  ('never_coming', 5),
#  ('wish_could', 5),
#  ('poor_customer', 5),
#  ('would_go', 5),
#  ('real_mexican', 5),
#  ('get_bowl', 5),
#  ('usually_good', 5),
#  ('food_portions', 5),
#  ('line_long', 5),
#  ('bad_service', 5),
#  ('chicken_enchiladas', 5),
#  ('definitely_back', 5),
#  ('red_sauce', 5),
#  ('freshly_made', 5),
#  ('high_quality', 5),
#  ('delicious_food', 5),
#  ('old_town', 5),
#  ('lunch_break', 5),
#  ('ordered_two', 5),
#  ('make_food', 5),
#  ('food_ive', 5),
#  ('speak_spanish', 5),
#  ('bean_cheese', 5),
#  ('cheese_burrito', 5),
#  ('worth_it', 5),
#  ('two_tacos', 5),
#  ('thats_it', 5),
#  ('falling_apart', 5),
#  ('needless_say', 5),
#  ('took_order', 5),
#  ('watered_down', 5),
#  ('recommend_place', 5),
#  ('waste_time', 5),
#  ('rudys_years', 5),
#  ('soft_tacos', 5),
#  ('like_food', 5),
#  ('time_im', 5),
#  ('portions_good', 5),
#  ('back_location', 5),
#  ('quick_bite', 5),
#  ('bad_customer', 5),
#  ('food_places', 5),
#  ('cheese_enchilada', 5),
#  ('staff_nice', 5),
#  ('mexican_places', 5),
#  ('place_eat', 5),
#  ('place_best', 5),
#  ('street_location', 5),
#  ('said_no', 5),
#  ('taco_salad', 5),
#  ('go_wrong', 5),
#  ('soft_taco', 5),
#  ('cash_register', 5),
#  ('shredded_chicken', 5),
#  ('generous_portions', 5),
#  ('big_portions', 5),
#  ('crunchy_tacos', 5),
#  ('really_bad', 5),
#  ('carnitas_burrito', 5),
#  ('food_decent', 5),
#  ('place_great', 5),
#  ('grilled_cheese', 5),
#  ('barbara_airport', 5),
#  ('next_day', 5),
#  ('crispy_taco', 5),
#  ('zero_stars', 5),
#  ('good_customer', 5),
#  ('tortilla_side', 5),
#  ('food_never', 4),
#  ('get_together', 4),
#  ('hard_time', 4),
#  ('chipotle_experience', 4),
#  ('third_time', 4),
#  ('staff_members', 4),
#  ('mild_salsa', 4),
#  ('coming_here', 4),
#  ('new_manager', 4),
#  ('chipotle_never', 4),
#  ('actually_get', 4),
#  ('like_one', 4),
#  ('food_bad', 4),
#  ('chicken_rice', 4),
#  ('beans_cheese', 4),
#  ('would_think', 4),
#  ('food_prepared', 4),
#  ('want_get', 4),
#  ('care_less', 4),
#  ('chipotle_one', 4),
#  ('chipotle_know', 4),
#  ('super_friendly', 4),
#  ('outdoor_seating', 4),
#  ('food_here', 4),
#  ('chipotle_restaurants', 4),
#  ('order_go', 4),
#  ('day_never', 4),
#  ('stars_would', 4),
#  ('never_come', 4),
#  ('many_times', 4),
#  ('service_quality', 4),
#  ('beans_lettuce', 4),
#  ('reading_reviews', 4),
#  ('red_salsa', 4),
#  ('far_worst', 4),
#  ('pay_extra', 4),
#  ('would_definitely', 4),
#  ('definitely_recommend', 4),
#  ('ever_chipotle', 4),
#  ('minutes_get', 4),
#  ('keep_mind', 4),
#  ('get_it', 4),
#  ('making_food', 4),
#  ('portions_small', 4),
#  ('rice_meat', 4),
#  ('take_out', 4),
#  ('terrible_experience', 4),
#  ('get_chipotle', 4),
#  ('good_work', 4),
#  ('never_ever', 4),
#  ('small_place', 4),
#  ('cant_believe', 4),
#  ('worst_burrito', 4),
#  ('sometimes_get', 4),
#  ('like_place', 4),
#  ('ordered_steak', 4),
#  ('bowl_get', 4),
#  ('another_chipotle', 4),
#  ('received_food', 4),
#  ('pick_up', 4),
#  ('plenty_parking', 4),
#  ('go_one', 4),
#  ('chipotle_good', 4),
#  ('orders_one', 4),
#  ('free_birds', 4),
#  ('white_rice', 4),
#  ('one_employee', 4),
#  ('every_single', 4),
#  ('chipotle_get', 4),
#  ('homemade_tortillas', 4),
#  ('home_made', 4),
#  ('place_needs', 4),
#  ('good_price', 4),
#  ('vegetarian_burrito', 4),
#  ('la_tapatia', 4),
#  ('here_ordered', 4),
#  ('good_cant', 4),
#  ('good_authentic', 4),
#  ('ordered_carne', 4),
#  ('asada_burrito', 4),
#  ('overall_great', 4),
#  ('hand_made', 4),
#  ('excellent_service', 4),
#  ('burrito_good', 4),
#  ('anything_else', 4),
#  ('back_place', 4),
#  ('usually_order', 4),
#  ('good_however', 4),
#  ('really_like', 4),
#  ('good_well', 4),
#  ('food_come', 4),
#  ('second_time', 4),
#  ('corn_tortillas', 4),
#  ('pick_food', 4),
#  ('green_sauce', 4),
#  ('tasting_food', 4),
#  ('chili_verde', 4),
#  ('orders_wrong', 4),
#  ('went_get', 4),
#  ('im_pretty', 4),
#  ('carnitas_tacos', 4),
#  ('got_one', 4),
#  ('chicken_one', 4),
#  ('burrito_meat', 4),
#  ('fresh_salsa', 4),
#  ('always_great', 4),
#  ('order_wrong', 4),
#  ('like_that', 4),
#  ('combination_plate', 4),
#  ('also_like', 4),
#  ('good_size', 4),
#  ('decent_mexican', 4),
#  ('food_served', 4),
#  ('good_salsa', 4),
#  ('food_thats', 4),
#  ('go_to', 4),
#  ('beef_chicken', 4),
#  ('order_chicken', 4),
#  ('family_owned', 4),
#  ('maybe_im', 4),
#  ('good_prices', 4),
#  ('year_ago', 4),
#  ('three_star', 4),
#  ('great_meal', 4),
#  ('asked_wanted', 4),
#  ('time_tried', 4),
#  ('answer_phone', 4),
#  ('friendly_service', 4),
#  ('one_montecito', 4),
#  ('gone_downhill', 4),
#  ('cant_go', 4),
#  ('fresh_hot', 4),
#  ('good_one', 4),
#  ('guacamole_salsa', 4),
#  ('lettuce_cheese', 4),
#  ('taco_tuesdays', 4),
#  ('combo_burritos', 4),
#  ('relleno_burrito', 4),
#  ('love_food', 4),
#  ('would_put', 4),
#  ('basket_chips', 4),
#  ('husband_ordered', 4),
#  ('burrito_rice', 4),
#  ('great_prices', 4),
#  ('green_salsa', 4),
#  ('fast_friendly', 4),
#  ('salsa_chips', 4),
#  ('usually_get', 4),
#  ('could_tell', 4),
#  ('salsa_cups', 4),
#  ('go_rudys', 4),
#  ('burritos_nachos', 4),
#  ('parking_lot', 4),
#  ('fajita_bowl', 4),
#  ('clean_food', 4),
#  ('like_chicken', 4),
#  ('back_good', 4),
#  ('food_awesome', 4),
#  ('drive_back', 4),
#  ('restaurant_food', 4),
#  ('it_get', 4),
#  ('give_place', 4),
#  ('star_food', 4),
#  ('food_excellent', 4),
#  ('always_order', 4),
#  ('coming_years', 4),
#  ('guac_cheese', 4),
#  ('definitely_worth', 4),
#  ('single_time', 4),
#  ('get_airport', 4),
#  ('fried_mac', 4),
#  ('pretty_much', 4),
#  ('mac_n', 4),
#  ('n_cheese', 4),
#  ('decided_try', 4),
#  ('burritos_always', 4),
#  ('flight_delayed', 4),
#  ('food_made', 4),
#  ('make_burrito', 4),
#  ('away_chipotle', 4),
#  ('half_empty', 4),
#  ('el_pollo', 4),
#  ('pollo_loco', 4),
#  ('food_restaurant', 3),
#  ('would_good', 3),
#  ('order_chips', 3),
#  ('chips_queso', 3),
#  ('wan_na', 3),
#  ('went_order', 3),
#  ('many_chipotles', 3),
#  ('get_little', 3),
#  ('rolled_eyes', 3),
#  ('fresh_either', 3),
#  ('like_sitting', 3),
#  ('put_little', 3),
#  ('amount_food', 3),
#  ('making_it', 3),
#  ('used_to', 3),
#  ('little_extra', 3),
#  ('mediocre_food', 3),
#  ('location_chipotle', 3),
#  ('chicken_favorite', 3),
#  ('counter_ask', 3),
#  ('give_less', 3),
#  ('raw_chicken', 3),
#  ('scoop_rice', 3),
#  ('used_like', 3),
#  ('it_im', 3),
#  ('back_lot', 3),
#  ('back_restaurant', 3),
#  ('even_busy', 3),
#  ('time_ill', 3),
#  ('chain_restaurant', 3),
#  ('closest_location', 3),
#  ('two_weeks', 3),
#  ('order_thing', 3),
#  ('line_ordered', 3),
#  ('charged_extra', 3),
#  ('every_chipotle', 3),
#  ('get_full', 3),
#  ('made_order', 3),
#  ('one_burrito', 3),
#  ('feed_two', 3),
#  ('clean_nice', 3),
#  ('nice_staff', 3),
#  ('sat_next', 3),
#  ('usually_eat', 3),
#  ('food_location', 3),
#  ('ordered_bowl', 3),
#  ('scoop_beans', 3),
#  ('full_price', 3),
#  ('stopped_way', 3),
#  ('way_back', 3),
#  ('well_prepared', 3),
#  ('thought_food', 3),
#  ('half_bowl', 3),
#  ('beans_chicken', 3),
#  ('go_somewhere', 3),
#  ('staff_food', 3),
#  ('go_eat', 3),
#  ('go_place', 3),
#  ('times_week', 3),
#  ('favorite_chipotle', 3),
#  ('could_care', 3),
#  ('thought_id', 3),
#  ('want_go', 3),
#  ('last_two', 3),
#  ('times_ive', 3),
#  ('buy_one', 3),
#  ('one_get', 3),
#  ('ill_back', 3),
#  ('walk_door', 3),
#  ('chipotle_seems', 3),
#  ('seems_always', 3),
#  ('bowl_ive', 3),
#  ('trying_eat', 3),
#  ('look_it', 3),
#  ('it_little', 3),
#  ('experience_location', 3),
#  ('refunded_money', 3),
#  ('stomach_ache', 3),
#  ('go_across', 3),
#  ('hard_taco', 3),
#  ('chipotle_many', 3),
#  ('luke_warm', 3),
#  ('everything_else', 3),
#  ('all_employees', 3),
#  ('carnitas_chicken', 3),
#  ('chipotle_fan', 3),
#  ('order_person', 3),
#  ('ordered_extra', 3),
#  ('recommend_it', 3),
#  ('service_ive', 3),
#  ('never_seen', 3),
#  ('get_better', 3),
#  ('got_carnitas', 3),
#  ('im_done', 3),
#  ('back_one', 3),
#  ('carnitas_bowl', 3),
#  ('serving_food', 3),
#  ('another_employee', 3),
#  ('several_minutes', 3),
#  ('minutes_food', 3),
#  ('kind_service', 3),
#  ('never_experienced', 3),
#  ('chipotles_ive', 3),
#  ('fresh_food', 3),
#  ('food_chipotle', 3),
#  ('keep_good', 3),
#  ('burrito_small', 3),
#  ('burrito_service', 3),
#  ('service_industry', 3),
#  ('stale_chips', 3),
#  ('chipotle_customer', 3),
#  ('negative_reviews', 3),
#  ('paying_attention', 3),
#  ('care_food', 3),
#  ('cant_get', 3),
#  ('decent_size', 3),
#  ('meal_ordered', 3),
#  ('place_always', 3),
#  ('everything_ordered', 3),
#  ('thought_would', 3),
#  ('craving_mexican', 3),
#  ('smaller_portions', 3),
#  ('people_like', 3),
#  ('steak_bowl', 3),
#  ('extra_steak', 3),
#  ('give_half', 3),
#  ('give_stars', 3),
#  ('go_another', 3),
#  ('another_minutes', 3),
#  ('refused_give', 3),
#  ('contacted_customer', 3),
#  ('food_taste', 3),
#  ('taste_good', 3),
#  ('line_moving', 3),
#  ('least_people', 3),
#  ('people_waiting', 3),
#  ('online_ordering', 3),
#  ('time_burrito', 3),
#  ('burrito_would', 3),
#  ('place_quality', 3),
#  ('double_meat', 3),
#  ('bad_reviews', 3),
#  ('small_pieces', 3),
#  ('pieces_steak', 3),
#  ('working_front', 3),
#  ('bell_peppers', 3),
#  ('total_disappointment', 3),
#  ('one_person', 3),
#  ('line_door', 3),
#  ('chicken_bowls', 3),
#  ('helping_customers', 3),
#  ('dirty_food', 3),
#  ('clean_table', 3),
#  ('say_anything', 3),
#  ('service_location', 3),
#  ('food_correctly', 3),
#  ('burrito_quesadilla', 3),
#  ('chicken_quesadilla', 3),
#  ('eat_food', 3),
#  ('chips_guacamole', 3),
#  ('service_bad', 3),
#  ('rude_incompetent', 3),
#  ('make_order', 3),
#  ('minutes_closing', 3),
#  ('delicious_authentic', 3),
#  ('again_food', 3),
#  ('wait_food', 3),
#  ('food_comes', 3),
#  ('lunch_hour', 3),
#  ('taste_food', 3),
#  ('time_came', 3),
#  ('time_wait', 3),
#  ('start_saying', 3),
#  ('food_arrived', 3),
#  ('ive_lived', 3),
#  ('im_glad', 3),
#  ('cant_wait', 3),
#  ('wait_try', 3),
#  ('got_enchiladas', 3),
#  ('id_say', 3),
#  ('enchiladas_spicy', 3),
#  ('choose_from', 3),
#  ('made_tortillas', 3),
#  ('burrito_barely', 3),
#  ('asked_extra', 3),
#  ('terrible_service', 3),
#  ('never_going', 3),
#  ('pastor_taco', 3),
#  ('ahead_time', 3),
#  ('full_meat', 3),
#  ('favorite_mexican', 3),
#  ('menu_love', 3),
#  ('two_years', 3),
#  ('tacos_came', 3),
#  ('onion_cilantro', 3),
#  ('place_never', 3),
#  ('la_carte', 3),
#  ('said_yes', 3),
#  ('good_taco', 3),
#  ('looked_good', 3),
#  ('like_much', 3),
#  ('food_food', 3),
#  ('food_actually', 3),
#  ('even_taste', 3),
#  ('spend_money', 3),
#  ('prices_menu', 3),
#  ('food_without', 3),
#  ('place_busy', 3),
#  ('women_working', 3),
#  ('woman_behind', 3),
#  ('look_forward', 3),
#  ('needs_get', 3),
#  ('drive_home', 3),
#  ('worst_food', 3),
#  ('food_ever', 3),
#  ('best_thing', 3),
#  ('rest_away', 3),
#  ('sauce_spicy', 3),
#  ('order_one', 3),
#  ('last_month', 3),
#  ('save_time', 3),
#  ('enjoyed_food', 3),
#  ('could_use', 3),
#  ('taco_instead', 3),
#  ('long_wait', 3),
#  ('refused_serve', 3),
#  ('burrito_tasted', 3),
#  ('tacos_instead', 3),
#  ('carnitas_taco', 3),
#  ('would_never', 3),
#  ('ever_go', 3),
#  ('get_salsa', 3),
#  ('caldo_de', 3),
#  ('pieces_meat', 3),
#  ('large_order', 3),
#  ('debit_card', 3),
#  ('food_got', 3),
#  ('favor_go', 3),
#  ('ordered_veggie', 3),
#  ('burritos_ive', 3),
#  ('days_ago', 3),
#  ('cheese_top', 3),
#  ('montecito_st', 3),
#  ('mess_order', 3),
#  ('years_since', 3),
#  ('place_gone', 3),
#  ('order_refused', 3),
#  ('last_week', 3),
#  ('went_lunch', 3),
#  ('chicken_beef', 3),
#  ('cream_cheese', 3),
#  ('tuesday_deal', 3),
#  ('raised_prices', 3),
#  ('service_sucks', 3),
#  ('delicious_mexican', 3),
#  ('plate_beans', 3),
#  ('good_deal', 3),
#  ('huge_portions', 3),
#  ('shell_tacos', 3),
#  ('things_like', 3),
#  ('rudys_upper', 3),
#  ('asada_tacos', 3),
#  ('better_places', 3),
#  ('still_really', 3),
#  ('long_line', 3),
#  ('thing_would', 3),
#  ('want_good', 3),
#  ('good_portion', 3),
#  ('like_eating', 3),
#  ('chicken_taquitos', 3),
#  ('refried_beans', 3),
#  ('rudys_go', 3),
#  ('casitas_pass', 3),
#  ('chicken_hard', 3),
#  ('state_location', 3),
#  ('location_santa', 3),
#  ('good_good', 3),
#  ('would_expect', 3),
#  ('family_ate', 3),
#  ('really_enjoy', 3),
#  ('los_angeles', 3),
#  ('dont_know', 3),
#  ('right_next', 3),
#  ('place_food', 3),
#  ('got_order', 3),
#  ('location_food', 3),
#  ('better_mexican', 3),
#  ('get_chicken', 3),
#  ('onions_cilantro', 3),
#  ('pay_attention', 3),
#  ('tacos_best', 3),
#  ('take_orders', 3),
#  ('pork_tamale', 3),
#  ('bar_well', 3),
#  ('rudys_great', 3),
#  ('food_went', 3),
#  ('burrito_food', 3),
#  ('definitely_going', 3),
#  ('said_ill', 3),
#  ('menu_said', 3),
#  ('said_could', 3),
#  ('time_food', 3),
#  ('great_great', 3),
#  ('ive_times', 3),
#  ('eaten_rudys', 3),
#  ('save_money', 3),
#  ('lunch_dinner', 3),
#  ('tacos_loaded', 3),
#  ('rudys_mexican', 3),
#  ('food_still', 3),
#  ('three_people', 3),
#  ('decent_amount', 3),
#  ('id_recommend', 3),
#  ('always_go', 3),
#  ('home_opened', 3),
#  ('still_open', 3),
#  ('past_months', 3),
#  ('staff_always', 3),
#  ('potato_taquitos', 3),
#  ('rice_burritos', 3),
#  ('full_cheese', 3),
#  ('ive_tried', 3),
#  ('got_ta', 3),
#  ('without_mask', 3),
#  ('able_place', 3),
#  ('even_close', 3),
#  ('worth_drive', 3),
#  ('good_shredded', 3),
#  ('taco_huge', 3),
#  ('way_go', 3),
#  ('place_santa', 3),
#  ('burritos_great', 3),
#  ('quite_often', 3),
#  ('one_eat', 3),
#  ('care_customers', 3),
#  ('food_awful', 3),
#  ('act_like', 3),
#  ('get_shredded', 3),
#  ('helpful_accommodating', 3),
#  ('also_love', 3),
#  ('place_really', 3),
#  ('food_amazing', 3),
#  ('rudys_came', 3),
#  ('tacos_rice', 3),
#  ('salsa_salsa', 3),
#  ('beans_delicious', 3),
#  ('hit_spot', 3),
#  ('food_expensive', 3),
#  ('portions_great', 3),
#  ('one_another', 3),
#  ('get_right', 3),
#  ('crispy_shell', 3),
#  ('much_cheese', 3),
#  ('hard_earned', 3),
#  ('even_melted', 3),
#  ('covered_food', 3),
#  ('shrimp_tacos', 3),
#  ('want_order', 3),
#  ('great_tacos', 3),
#  ('rudys_lot', 3),
#  ('one_favorite', 3),
#  ('past_year', 3),
#  ('food_get', 3),
#  ('try_place', 3),
#  ('order_get', 3),
#  ('cups_get', 3),
#  ('want_give', 3),
#  ('little_bit', 3),
#  ('like_made', 3),
#  ('nothing_else', 3),
#  ('past_years', 3),
#  ('variety_options', 3),
#  ('love_burritos', 3),
#  ('one_taco', 3),
#  ('stingy_salsa', 3),
#  ('give_much', 3),
#  ('read_reviews', 3),
#  ('tried_place', 3),
#  ('cashier_said', 3),
#  ('seem_care', 3),
#  ('get_something', 3),
#  ('something_wrong', 3),
#  ('two_stars', 3),
#  ('good_quick', 3),
#  ('decided_give', 3),
#  ('pretty_sad', 3),
#  ('good_bad', 3),
#  ('also_give', 3),
#  ('convenient_location', 3),
#  ('great_tasting', 3),
#  ('always_happy', 3),
#  ('meat_guac', 3),
#  ('chicken_burritos', 3),
#  ('decent_price', 3),
#  ('several_years', 3),
#  ('food_generally', 3),
#  ('bar_nice', 3),
#  ('eat_mexican', 3),
#  ('burrito_great', 3),
#  ('little_mexican', 3),
#  ('portions_big', 3),
#  ('combo_plate', 3),
#  ('crunchy_beef', 3),
#  ('people_work', 3),
#  ('service_awful', 3),
#  ('seating_outside', 3),
#  ('bite_eat', 3),
#  ('service_quick', 3),
#  ('quality_ingredients', 3),
#  ('time_got', 3),
#  ('used_go', 3),
#  ('liquor_store', 3),
#  ('walked_in', 3),
#  ('pleasantly_surprised', 3),
#  ('last_visit', 3),
#  ('got_two', 3),
#  ('looking_good', 3),
#  ('years_now', 3),
#  ('service_friendly', 3),
#  ('barely_tasted', 3),
#  ('place_ive', 3),
#  ('high_chair', 3),
#  ('go_there', 3),
#  ('taste_authentic', 3),
#  ('moneys_worth', 3),
#  ('called_order', 3),
#  ('food_customer', 3),
#  ('worst_mexican', 3),
#  ('better_options', 3),
#  ('food_options', 3),
#  ('food_keep', 3),
#  ('to_go', 3),
#  ('steak_burrito', 3),
#  ('bad_experience', 3),
#  ('place_definitely', 3),
#  ('large_portions', 3),
#  ('chip_salsa', 3),
#  ('place_good', 3),
#  ('in_ordered', 3),
#  ('get_back', 3),
#  ('grub_hub', 3),
#  ('im_going', 3),
#  ('ive_come', 3),
#  ('chicken_inside', 3),
#  ('try_food', 3),
#  ('burrito_mostly', 3),
#  ('attitude_told', 3),
#  ('decided_stop', 3),
#  ('expecting_much', 3),
#  ('up_food', 3),
#  ('back_next', 3),
#  ('full_bar', 3),
#  ('hey_airport', 3),
#  ('one_many', 3),
#  ('put_together', 3),
#  ('ordered_one', 3),
#  ('waiting_flight', 3),
#  ('shopping_center', 3),
#  ('another_time', 3),
#  ('time_ordered', 3),
#  ('always_friendly', 3),
#  ('airport_bar', 3),
#  ('try_it', 3),
#  ('like_going', 3),
#  ('guacamole_sour', 3),
#  ('friendly_attentive', 3),
#  ('front_customers', 3),
#  ('customers_never', 3),
#  ('pretty_decent', 3),
#  ('decent_airport', 3),
#  ('little_place', 3),
#  ('great_job', 3),
#  ('food_better', 3),
#  ('would_come', 3),
#  ('one_server', 3),
#  ('bloody_mary', 3),
#  ('prices_reasonable', 3),
#  ('always_seem', 3),
#  ('yum_yum', 3),
#  ('hot_sauce', 3),
#  ('pretty_hard', 3),
#  ('asked_refund', 3),
#  ('chicken_broth', 3),
#  ('wearing_gloves', 3),
#  ('recommend_coming', 3),
#  ('got_chicken', 3),
#  ('behind_me', 3),
#  ('told_would', 3),
#  ('food_one', 3),
#  ('general_manager', 3),
#  ('fan_chipotle', 3),
#  ('always_long', 3),
#  ('bowl_half', 3),
#  ('paid_extra', 3),
#  ('rest_night', 3),
#  ('eating_chipotle', 3),
#  ('say_hello', 3),
#  ('say_least', 3),
#  ('corn_salsa', 3),
#  ('like_chipotle', 3),
#  ('back_chipotle', 3),
#  ('double_wrapped', 3),
#  ('particular_location', 3),
#  ('eating_burrito', 3),
#  ('food_me', 3),
#  ('chipotle_chain', 3),
#  ('im_usually', 3),
#  ('serve_food', 3),
#  ...]

# %%
good_Mexican=Mexican[Mexican.stars>=3.5]
good_Mexican_review = Mexican_review[Mexican_review.business_id.isin(good_Mexican.business_id.values)]
good_Mexican_review_text = good_Mexican_review.text.str.cat(sep = " ")
good_Mexican_tokens = word_tokenize(good_Mexican_review_text)
# FreqDist(good_American_tokens).most_common()
bigrams_list_good_Mexican = ["_".join(item) for item in nltk.bigrams(good_Mexican_tokens)]
trigrams_list_good_Mexican = ["_".join(item) for item in nltk.trigrams(good_Mexican_tokens)]
# FreqDist(bigrams_list_good_Mexican).most_common()
FreqDist(trigrams_list_good_Mexican).most_common()
# Out:
# [('best_mexican_food', 675),
#  ('authentic_mexican_food', 490),
#  ('ive_ever_had', 477),
#  ('pico_de_gallo', 354),
#  ('good_mexican_food', 296),
#  ('cant_go_wrong', 275),
#  ('definitely_come_back', 250),
#  ('food_santa_barbara', 247),
#  ('mexican_food_santa', 224),
#  ('mexican_food_ive', 212),
#  ('la_super_rica', 186),
#  ('visiting_santa_barbara', 186),
#  ('great_mexican_food', 169),
#  ('wait_go_back', 168),
#  ('restaurant_santa_barbara', 161),
#  ('cant_wait_go', 160),
#  ('definitely_coming_back', 157),
#  ('visit_santa_barbara', 154),
#  ('trip_santa_barbara', 151),
#  ('food_great_service', 151),
#  ('best_ive_ever', 150),
#  ('great_salsa_bar', 147),
#  ('mexican_food_place', 145),
#  ('would_definitely_recommend', 143),
#  ('mexican_food_ever', 142),
#  ('next_time_im', 140),
#  ('great_food_great', 140),
#  ('highly_recommend_place', 139),
#  ('carne_asada_tacos', 132),
#  ('tacos_santa_barbara', 131),
#  ('would_definitely_come', 129),
#  ('de_la_vina', 126),
#  ('definitely_go_back', 125),
#  ('wait_come_back', 124),
#  ('favorite_mexican_restaurant', 122),
#  ('would_come_back', 120),
#  ('back_next_time', 120),
#  ('carne_asada_burrito', 119),
#  ('service_great_food', 118),
#  ('cant_wait_come', 118),
#  ('food_ive_ever', 118),
#  ('im_santa_barbara', 117),
#  ('food_really_good', 116),
#  ('al_pastor_tacos', 114),
#  ('time_santa_barbara', 109),
#  ('one_best_mexican', 109),
#  ('would_highly_recommend', 105),
#  ('tacos_ive_ever', 103),
#  ('great_customer_service', 103),
#  ('delicious_mexican_food', 102),
#  ('back_santa_barbara', 101),
#  ('place_santa_barbara', 100),
#  ('salsa_bar_great', 99),
#  ('santa_barbara_area', 99),
#  ('mexican_food_town', 97),
#  ('best_mexican_restaurant', 97),
#  ('mexican_restaurant_santa', 96),
#  ('santa_barbara_food', 95),
#  ('downtown_santa_barbara', 95),
#  ('food_good_service', 94),
#  ('best_tacos_ive', 92),
#  ('tacos_al_pastor', 89),
#  ('favorite_mexican_food', 88),
#  ('tacos_del_mar', 88),
#  ('east_beach_tacos', 88),
#  ('well_worth_it', 86),
#  ('one_favorite_places', 85),
#  ('ordered_carne_asada', 84),
#  ('would_go_back', 83),
#  ('come_back_try', 83),
#  ('definitely_recommend_place', 83),
#  ('spicy_crispy_shrimp', 83),
#  ('great_service_great', 81),
#  ('mexican_food_sb', 79),
#  ('homemade_corn_tortillas', 77),
#  ('go_santa_barbara', 77),
#  ('restaurants_santa_barbara', 76),
#  ('really_good_food', 76),
#  ('chips_salsa_bar', 75),
#  ('santa_barbara_great', 74),
#  ('free_chips_salsa', 74),
#  ('best_tacos_ever', 74),
#  ('would_definitely_go', 73),
#  ('good_food_good', 73),
#  ('salsa_salsa_bar', 72),
#  ('happy_hour_menu', 70),
#  ('love_mexican_food', 69),
#  ('food_ever_had', 68),
#  ('carne_asada_taco', 67),
#  ('super_rica_especial', 67),
#  ('go_wrong_anything', 67),
#  ('good_salsa_bar', 66),
#  ('every_time_go', 66),
#  ('sour_cream_guacamole', 66),
#  ('hand_made_tortillas', 66),
#  ('would_recommend_place', 66),
#  ('complimentary_chips_salsa', 66),
#  ('mexican_food_restaurant', 65),
#  ('best_tacos_santa', 65),
#  ('every_time_im', 65),
#  ('fresh_salsa_bar', 64),
#  ('staff_super_friendly', 64),
#  ('stop_santa_barbara', 63),
#  ('food_pretty_good', 63),
#  ('santa_barbara_place', 63),
#  ('best_tacos_town', 63),
#  ('chile_relleno_burrito', 62),
#  ('time_im_santa', 62),
#  ('every_time_come', 61),
#  ('salsa_bar_amazing', 61),
#  ('chile_verde_burrito', 60),
#  ('love_love_love', 60),
#  ('pan_con_tomate', 60),
#  ('al_pastor_taco', 59),
#  ('cheese_sour_cream', 59),
#  ('come_santa_barbara', 59),
#  ('amazing_mexican_food', 59),
#  ('los_agaves_burrito', 59),
#  ('staff_always_friendly', 58),
#  ('best_ever_had', 58),
#  ('cant_say_enough', 57),
#  ('come_back_again', 57),
#  ('really_really_good', 57),
#  ('eat_santa_barbara', 56),
#  ('great_happy_hour', 56),
#  ('love_los_agaves', 56),
#  ('give_place_try', 55),
#  ('got_carne_asada', 55),
#  ('good_food_great', 55),
#  ('great_place_eat', 55),
#  ('better_mexican_food', 55),
#  ('worth_every_penny', 55),
#  ('best_mexican_restaurants', 54),
#  ('little_hole_wall', 54),
#  ('real_mexican_food', 54),
#  ('come_back_next', 54),
#  ('one_favorite_restaurants', 53),
#  ('recommend_place_anyone', 52),
#  ('salsa_bar_good', 52),
#  ('santa_barbara_love', 52),
#  ('best_ive_had', 52),
#  ('go_back_try', 52),
#  ('craving_mexican_food', 52),
#  ('bean_cheese_burrito', 52),
#  ('quality_mexican_food', 52),
#  ('go_back_again', 51),
#  ('one_favorite_mexican', 51),
#  ('guacamole_sour_cream', 50),
#  ('great_food_service', 50),
#  ('keep_coming_back', 50),
#  ('definitely_going_back', 49),
#  ('also_really_good', 49),
#  ('like_mexican_food', 49),
#  ('service_good_food', 49),
#  ('hands_best_mexican', 48),
#  ('customer_service_great', 48),
#  ('mexican_food_places', 48),
#  ('places_santa_barbara', 48),
#  ('salsas_salsa_bar', 48),
#  ('flor_de_maiz', 48),
#  ('amazing_salsa_bar', 47),
#  ('well_worth_wait', 47),
#  ('la_vina_location', 46),
#  ('taken_care_of', 46),
#  ('los_agaves_salad', 46),
#  ('triple_play_tacos', 46),
#  ('salsa_bar_also', 45),
#  ('indoor_outdoor_seating', 45),
#  ('mexican_food_good', 45),
#  ('best_santa_barbara', 45),
#  ('chips_salsa_good', 45),
#  ('time_im_town', 45),
#  ('food_excellent_service', 45),
#  ('give_place_stars', 45),
#  ('eat_mexican_food', 45),
#  ('made_us_feel', 45),
#  ('ill_definitely_back', 44),
#  ('excellent_mexican_food', 44),
#  ('delicious_salsa_bar', 44),
#  ('santa_barbara_definitely', 44),
#  ('place_great_food', 44),
#  ('small_parking_lot', 44),
#  ('favorite_mexican_restaurants', 44),
#  ('really_good_too', 44),
#  ('home_made_tortillas', 44),
#  ('place_mexican_food', 44),
#  ('every_time_visit', 44),
#  ('love_salsa_bar', 44),
#  ('decided_give_try', 43),
#  ('great_authentic_mexican', 43),
#  ('mexican_food_great', 43),
#  ('nothing_write_home', 43),
#  ('santa_barbara_one', 43),
#  ('check_place_out', 43),
#  ('really_good_mexican', 43),
#  ('try_something_new', 43),
#  ('seated_right_away', 43),
#  ('mexican_food_go', 42),
#  ('santa_barbara_always', 42),
#  ('ive_ever_eaten', 42),
#  ('mexican_restaurant_town', 42),
#  ('totally_worth_it', 42),
#  ('found_place_yelp', 41),
#  ('cant_wait_try', 41),
#  ('tacos_really_good', 41),
#  ('first_time_here', 41),
#  ('delicious_highly_recommend', 41),
#  ('authentic_mexican_restaurant', 41),
#  ('ive_ever_tasted', 41),
#  ('la_superrica_taqueria', 41),
#  ('one_best_places', 41),
#  ('one_best_ive', 41),
#  ('food_los_agaves', 41),
#  ('ahi_poke_taco', 41),
#  ('lived_santa_barbara', 40),
#  ('santa_barbara_first', 40),
#  ('service_fast_friendly', 40),
#  ('never_go_back', 40),
#  ('line_order_food', 40),
#  ('next_time_santa', 40),
#  ('definitely_worth_it', 40),
#  ('next_time_were', 40),
#  ('ever_santa_barbara', 40),
#  ('food_came_quickly', 40),
#  ('rice_black_beans', 40),
#  ('im_glad_did', 39),
#  ('salsa_bar_awesome', 39),
#  ('ive_long_time', 39),
#  ('highly_recommend_it', 39),
#  ('write_home_about', 39),
#  ('mole_mole_mole', 39),
#  ('santa_barbara_weekend', 38),
#  ('great_place_go', 38),
#  ('julia_childs_favorite', 38),
#  ('wait_line_order', 38),
#  ('really_cant_go', 38),
#  ('would_recommend_anyone', 37),
#  ('chicken_tri_tip', 37),
#  ('passing_santa_barbara', 37),
#  ('service_delicious_food', 37),
#  ('outdoor_seating_area', 37),
#  ('fast_friendly_service', 37),
#  ('good_authentic_mexican', 37),
#  ('spot_santa_barbara', 37),
#  ('los_agaves_one', 37),
#  ('food_amazing_service', 37),
#  ('next_batting_cages', 37),
#  ('salsas_choose_from', 36),
#  ('santa_barbara_would', 36),
#  ('im_pretty_sure', 36),
#  ('mexican_restaurants_santa', 36),
#  ('best_authentic_mexican', 36),
#  ('tacos_salsa_bar', 36),
#  ('santa_barbara_best', 36),
#  ('rajas_con_queso', 36),
#  ('ive_ever_life', 36),
#  ('come_back_santa', 36),
#  ('mexican_food_best', 36),
#  ('make_sure_get', 36),
#  ('blood_orange_margarita', 36),
#  ('go_los_agaves', 36),
#  ('sal_de_mar', 36),
#  ('santa_barbara_looking', 35),
#  ('mexican_restaurants_ive', 35),
#  ('tacos_carne_asada', 35),
#  ('buy_one_get', 35),
#  ('ive_santa_barbara', 35),
#  ('id_go_back', 35),
#  ('santa_barbara_day', 35),
#  ('wrong_anything_menu', 35),
#  ('great_service_food', 35),
#  ('far_best_mexican', 35),
#  ('santa_barbara_public', 35),
#  ('go_somewhere_else', 34),
#  ('based_yelp_reviews', 34),
#  ('eat_every_day', 34),
#  ('made_corn_tortillas', 34),
#  ('every_single_time', 34),
#  ('came_santa_barbara', 34),
#  ('santa_barbara_really', 34),
#  ('good_happy_hour', 34),
#  ('santa_barbara_go', 34),
#  ('barbara_public_market', 34),
#  ('love_place_food', 33),
#  ('food_highly_recommend', 33),
#  ('food_great_atmosphere', 33),
#  ('great_food_good', 33),
#  ('time_im_sb', 33),
#  ('food_delicious_service', 33),
#  ('carne_asada_chicken', 33),
#  ('wait_worth_it', 33),
#  ('tacos_de_bistec', 33),
#  ('el_pollo_loco', 33),
#  ('definitely_worth_wait', 33),
#  ('santa_barbara_must', 33),
#  ('best_fish_tacos', 33),
#  ('drive_santa_barbara', 33),
#  ('ordered_triple_play', 33),
#  ('highly_recommend_restaurant', 32),
#  ('definitely_come_again', 32),
#  ('one_favorite_spots', 32),
#  ('favorite_mexican_place', 32),
#  ('im_giving_stars', 32),
#  ('burrito_carne_asada', 32),
#  ('stop_every_time', 32),
#  ('salsa_bar_best', 32),
#  ('carne_asada_fries', 32),
#  ('took_minutes_get', 32),
#  ('get_moneys_worth', 32),
#  ('pretty_good_too', 32),
#  ('overall_great_experience', 32),
#  ('food_absolutely_delicious', 32),
#  ('stand_line_order', 32),
#  ('mexican_food_restaurants', 32),
#  ('santa_barbara_hands', 32),
#  ('get_triple_play', 32),
#  ('salsa_bar_nice', 31),
#  ('tacos_rice_beans', 31),
#  ('say_enough_good', 31),
#  ('staff_friendly_food', 31),
#  ('can_not_wait', 31),
#  ('tortillas_hand_made', 31),
#  ('came_rice_beans', 31),
#  ('looking_good_mexican', 31),
#  ('awesome_salsa_bar', 31),
#  ('coming_back_again', 31),
#  ('one_get_one', 31),
#  ('good_mexican_restaurant', 31),
#  ('id_come_back', 31),
#  ('order_counter_bring', 31),
#  ('good_customer_service', 31),
#  ('food_always_good', 31),
#  ('santa_barbara_come', 31),
#  ('tacos_ever_had', 31),
#  ('cant_wait_return', 31),
#  ('service_amazing_food', 31),
#  ('carne_asada_nachos', 31),
#  ('favorite_taco_place', 30),
#  ('burrito_ive_ever', 30),
#  ('enough_good_things', 30),
#  ('super_friendly_staff', 30),
#  ('al_pastor_burrito', 30),
#  ('serve_salsa_bar', 30),
#  ('santa_barbara_make', 30),
#  ('around_santa_barbara', 30),
#  ('want_come_back', 30),
#  ('santa_barbara_decided', 30),
#  ('would_give_stars', 30),
#  ('fresh_mexican_food', 30),
#  ('side_rice_beans', 30),
#  ('service_excellent_food', 30),
#  ('authentic_mexican_cuisine', 30),
#  ('live_santa_barbara', 30),
#  ('line_moves_fast', 30),
#  ('mexican_food_like', 30),
#  ('style_mexican_food', 30),
#  ('los_agaves_enchiladas', 30),
#  ('last_time_went', 30),
#  ('within_walking_distance', 30),
#  ('next_time_ill', 30),
#  ('fish_shrimp_tacos', 30),
#  ('la_playa_azul', 30),
#  ('best_tacos_sb', 29),
#  ('mexican_food_food', 29),
#  ('food_fast_service', 29),
#  ('santa_barbara_get', 29),
#  ('self_serve_salsa', 29),
#  ('try_something_different', 29),
#  ('want_go_back', 29),
#  ('handmade_corn_tortillas', 29),
#  ('happy_hour_great', 29),
#  ('excellent_customer_service', 29),
#  ('hole_wall_place', 29),
#  ('food_friendly_staff', 29),
#  ('one_best_tacos', 29),
#  ('santa_barbara_eat', 29),
#  ('guac_sour_cream', 29),
#  ('ive_ever_to', 29),
#  ('gambas_al_ajillo', 29),
#  ('delicious_authentic_mexican', 28),
#  ('hands_down_best', 28),
#  ('santa_barbara_chicken', 28),
#  ('wish_lived_closer', 28),
#  ('asada_al_pastor', 28),
#  ('delicious_food_great', 28),
#  ('probably_one_best', 28),
#  ('camarones_la_diabla', 28),
#  ('stumbled_upon_place', 28),
#  ('food_service_great', 28),
#  ('come_back_here', 28),
#  ('santa_barbara_good', 28),
#  ('go_wrong_here', 28),
#  ('santa_barbara_went', 28),
#  ('mexican_food_definitely', 28),
#  ('nice_salsa_bar', 28),
#  ('can_not_go', 28),
#  ('really_good_service', 28),
#  ('service_top_notch', 28),
#  ('mole_con_pollo', 28),
#  ('quick_bite_eat', 27),
#  ('get_mexican_food', 27),
#  ('food_great_prices', 27),
#  ('mexican_food_im', 27),
#  ('also_salsa_bar', 27),
#  ('let_tell_you', 27),
#  ('got_ta_try', 27),
#  ('right_next_door', 27),
#  ('food_fresh_delicious', 27),
#  ('absolutely_love_place', 27),
#  ('bring_food_table', 27),
#  ('everything_tasted_fresh', 27),
#  ('hole_wall_mexican', 27),
#  ('best_salsa_bar', 27),
#  ('come_back_im', 27),
#  ('mexican_food_service', 27),
#  ('cinco_de_mayo', 27),
#  ('place_eat_santa', 27),
#  ('carne_asada_plate', 27),
#  ('amazing_food_great', 27),
#  ('staff_super_nice', 27),
#  ('never_come_back', 27),
#  ('driving_santa_barbara', 27),
#  ('get_pay_for', 27),
#  ('love_place_great', 27),
#  ('chicken_mole_enchiladas', 27),
#  ('los_agaves_food', 27),
#  ('tri_tip_burrito', 27),
#  ('went_santa_barbara', 27),
#  ('lunch_next_day', 27),
#  ('barbara_hands_down', 27),
#  ('fresh_corn_tortillas', 26),
#  ('first_time_santa', 26),
#  ('taco_al_pastor', 26),
#  ('santa_barbara_location', 26),
#  ('looking_authentic_mexican', 26),
#  ('high_quality_food', 26),
#  ('pretty_darn_good', 26),
#  ('get_carne_asada', 26),
#  ('spots_santa_barbara', 26),
#  ('ordered_al_pastor', 26),
#  ('make_sure_stop', 26),
#  ('decided_try_it', 26),
#  ('really_good_tacos', 26),
#  ('every_time_santa', 26),
#  ('santa_barbara_found', 26),
#  ('tortillas_made_fresh', 26),
#  ('pretty_damn_good', 26),
#  ('favorite_place_eat', 26),
#  ('go_back_next', 26),
#  ('ordered_fish_tacos', 26),
#  ('freshly_made_tortillas', 26),
#  ('service_always_great', 26),
#  ('staff_friendly_attentive', 26),
#  ('santa_barbara_ive', 26),
#  ('enchiladas_green_sauce', 26),
#  ('chips_salsa_great', 26),
#  ('try_santa_barbara', 26),
#  ('food_worth_it', 26),
#  ('santa_barbara_came', 26),
#  ('staff_friendly_helpful', 26),
#  ('not_go_wrong', 26),
#  ('good_service_great', 26),
#  ('authentic_mexican_tacos', 26),
#  ('one_best_meals', 26),
#  ('loved_salsa_bar', 26),
#  ('salsa_bar_delicious', 26),
#  ('traditional_mexican_food', 25),
#  ('cant_get_enough', 25),
#  ('prices_little_high', 25),
#  ('good_would_definitely', 25),
#  ('good_food_service', 25),
#  ('salsa_really_good', 25),
#  ('de_gallo_salsa', 25),
#  ('food_friendly_service', 25),
#  ('old_town_goleta', 25),
#  ('mexican_food_spot', 25),
#  ('find_santa_barbara', 25),
#  ('back_every_time', 25),
#  ('chicken_carne_asada', 25),
#  ('forward_coming_back', 25),
#  ('santa_barbara_cant', 25),
#  ('right_state_street', 25),
#  ('happy_hour_prices', 25),
#  ('beautiful_santa_barbara', 25),
#  ('mexican_food_around', 25),
#  ('mexican_restaurants_town', 25),
#  ('ordered_chicken_burrito', 25),
#  ('time_visit_sb', 25),
#  ('favorite_restaurant_santa', 25),
#  ('food_best_mexican', 25),
#  ('adobada_marinated_pork', 25),
#  ('ahi_tuna_ceviche', 25),
#  ('line_moves_quickly', 25),
#  ('different_types_salsa', 25),
#  ('right_next_batting', 25),
#  ('food_reasonably_priced', 24),
#  ('rice_sour_cream', 24),
#  ('santa_barbara_im', 24),
#  ('went_first_time', 24),
#  ('good_place_eat', 24),
#  ('place_good_food', 24),
#  ('would_definitely_return', 24),
#  ('food_good_great', 24),
#  ('first_time_went', 24),
#  ('good_service_good', 24),
#  ('next_time_town', 24),
#  ('happy_hour_specials', 24),
#  ('never_bad_experience', 24),
#  ('santa_barbara_visit', 24),
#  ('coming_back_soon', 24),
#  ('could_ask_for', 24),
#  ('were_santa_barbara', 24),
#  ('next_time_visit', 24),
#  ('bring_food_you', 24),
#  ('dulce_de_leche', 24),
#  ('make_sure_ask', 23),
#  ('customer_service_food', 23),
#  ('food_reasonable_prices', 23),
#  ('santa_barbara_got', 23),
#  ('place_first_time', 23),
#  ('rice_beans_cheese', 23),
#  ('sour_cream_guac', 23),
#  ('love_love_place', 23),
#  ('excited_try_place', 23),
#  ('food_good_prices', 23),
#  ('chili_verde_burrito', 23),
#  ('food_salsa_bar', 23),
#  ('salsa_bar_chips', 23),
#  ('really_like_place', 23),
#  ('great_food_delicious', 23),
#  ('mexican_food_would', 23),
#  ('comes_rice_beans', 23),
#  ('visited_santa_barbara', 23),
#  ('came_first_time', 23),
#  ('tacos_pretty_good', 23),
#  ('worth_wait_line', 23),
#  ('try_next_time', 23),
#  ('food_consistently_good', 23),
#  ('americanized_mexican_food', 23),
#  ('eat_los_agaves', 23),
#  ('back_next_day', 23),
#  ('best_carne_asada', 23),
#  ('definitely_back_next', 23),
#  ('time_visit_santa', 23),
#  ('comes_mexican_food', 23),
#  ('place_amazing_food', 23),
#  ('santa_barbara_again', 23),
#  ('santa_barbara_try', 23),
#  ('reason_im_giving', 23),
#  ('weve_ever_had', 23),
#  ('try_los_agaves', 23),
#  ('awesome_mexican_food', 23),
#  ('excellent_food_service', 23),
#  ('salsa_bar_one', 23),
#  ('rice_beans_good', 23),
#  ('im_big_fan', 23),
#  ('meal_santa_barbara', 23),
#  ('grilled_fish_tacos', 23),
#  ('order_counter_find', 23),
#  ('parking_lot_back', 23),
#  ('crispy_shrimp_taco', 23),
#  ('first_time_trying', 22),
#  ('salsa_bar_different', 22),
#  ('good_carne_asada', 22),
#  ('favorite_places_eat', 22),
#  ('food_good_price', 22),
#  ('staff_really_friendly', 22),
#  ('place_authentic_mexican', 22),
#  ('typical_mexican_food', 22),
#  ('carne_asada_carnitas', 22),
#  ('got_fish_tacos', 22),
#  ('maybe_next_time', 22),
#  ('place_really_good', 22),
#  ('new_favorite_mexican', 22),
#  ('service_bit_slow', 22),
#  ('delicious_carne_asada', 22),
#  ('food_great_price', 22),
#  ('two_corn_tortillas', 22),
#  ('best_food_ever', 22),
#  ('santa_barbara_everything', 22),
#  ('family_owned_operated', 22),
#  ('coming_back_next', 22),
#  ('next_time_come', 22),
#  ('fresh_pico_de', 22),
#  ('horrible_customer_service', 22),
#  ('place_best_mexican', 22),
#  ('night_santa_barbara', 22),
#  ('mexican_food_los', 22),
#  ('next_time_sb', 22),
#  ('took_great_care', 22),
#  ('good_chips_salsa', 22),
#  ('carne_asada_adobada', 22),
#  ('great_chips_salsa', 22),
#  ('everything_ive_tried', 22),
#  ('ordered_chile_relleno', 22),
#  ('good_things_place', 22),
#  ('definitely_one_best', 22),
#  ('mexican_santa_barbara', 22),
#  ('make_sure_try', 22),
#  ('chipotle_cream_sauce', 22),
#  ('sb_chicken_ranch', 22),
#  ('found_los_agaves', 22),
#  ('carnitas_carne_asada', 22),
#  ('santa_barbara_mexican', 22),
#  ('chicken_mole_taco', 22),
#  ('gangnam_style_taco', 22),
#  ('service_friendly_fast', 21),
#  ('day_trip_santa', 21),
#  ('worth_checking_out', 21),
#  ('many_mexican_restaurants', 21),
#  ('food_always_fresh', 21),
#  ('santa_barbara_county', 21),
#  ('tacos_best_ive', 21),
#  ('go_every_time', 21),
#  ('way_santa_barbara', 21),
#  ('santa_barbara_amazing', 21),
#  ('go_back_place', 21),
#  ('decided_try_place', 21),
#  ('moved_santa_barbara', 21),
#  ('salsa_bar_fresh', 21),
#  ('mexican_food_love', 21),
#  ('im_gon_na', 21),
#  ('probably_best_mexican', 21),
#  ('nice_outdoor_patio', 21),
#  ('food_customer_service', 21),
#  ('came_across_place', 21),
#  ('hard_shell_tacos', 21),
#  ('crispy_chicken_taco', 21),
#  ('santa_barbara_way', 21),
#  ('could_give_stars', 21),
#  ('mexican_food_area', 21),
#  ('try_something_else', 21),
#  ('got_order_wrong', 21),
#  ('happy_hour_drinks', 21),
#  ('come_every_time', 21),
#  ('overall_good_experience', 21),
#  ('stay_santa_barbara', 21),
#  ('let_start_saying', 21),
#  ('every_time_ive', 21),
#  ('santa_barbara_far', 21),
#  ('order_counter_get', 21),
#  ('stop_next_time', 21),
#  ('santa_barbara_want', 21),
#  ('mexican_food_ordered', 21),
#  ('first_come_first', 21),
#  ('come_first_serve', 21),
#  ('barbara_chicken_ranch', 21),
#  ('salsa_bar_well', 21),
#  ('mexican_restaurant_ever', 21),
#  ('mexican_restaurant_sb', 21),
#  ('im_huge_fan', 21),
#  ('food_ive_had', 21),
#  ('great_food_drinks', 21),
#  ('great_tacos_great', 21),
#  ('stopped_way_back', 21),
#  ('santa_barbara_well', 21),
#  ('great_service_friendly', 21),
#  ('town_hands_down', 21),
#  ('yes_yes_yes', 21),
#  ('monterey_jack_cheese', 21),
#  ('never_go_wrong', 21),
#  ('like_fast_food', 21),
#  ('mexican_food_always', 21),
#  ('sea_earth_molcajete', 21),
#  ('table_next_us', 21),
#  ('santa_barbara_highly', 21),
#  ('great_mexican_restaurant', 21),
#  ('ahi_poke_tacos', 21),
#  ('high_quality_ingredients', 21),
#  ('counter_bring_food', 21),
#  ('next_batting_cage', 21),
#  ('crispy_shrimp_tacos', 21),
#  ('got_triple_play', 21),
#  ('ordered_agaves_enchiladas', 21),
#  ('carne_asada_torta', 20),
#  ('recommend_anyone_looking', 20),
#  ('santa_barbara_tacos', 20),
#  ('tasting_mexican_food', 20),
#  ('burrito_santa_barbara', 20),
#  ('really_great_food', 20),
#  ('tasty_salsa_bar', 20),
#  ('pretty_good_food', 20),
#  ('service_pretty_good', 20),
#  ('quality_food_service', 20),
#  ('look_like_much', 20),
#  ('overall_great_place', 20),
#  ('tacos_die_for', 20),
#  ('decent_mexican_food', 20),
#  ('back_los_agaves', 20),
#  ('everything_menu_delicious', 20),
#  ('best_street_tacos', 20),
#  ('good_place_go', 20),
#  ('santa_barbara_service', 20),
#  ('im_coming_back', 20),
#  ('crispy_chicken_tacos', 20),
#  ('mexican_food_got', 20),
#  ('make_sure_everything', 20),
#  ('heard_good_things', 20),
#  ('looking_place_eat', 20),
#  ('service_really_good', 20),
#  ('best_taco_place', 20),
#  ('near_santa_barbara', 20),
#  ('marinated_pork_tacos', 20),
#  ('place_happy_hour', 20),
#  ('place_order_counter', 20),
#  ('food_authentic_mexican', 20),
#  ('friendly_staff_great', 20),
#  ('think_ive_ever', 20),
#  ('burrito_really_good', 20),
#  ('chips_salsa_delicious', 20),
#  ('bell_peppers_onions', 20),
#  ('rice_beans_tortillas', 20),
#  ('would_order_again', 20),
#  ('let_us_know', 20),
#  ('salad_mango_dressing', 20),
#  ('salsa_bar_really', 20),
#  ('los_agaves_best', 20),
#  ('went_happy_hour', 20),
#  ('one_best_restaurants', 20),
#  ('salsa_bar_many', 20),
#  ('im_looking_forward', 20),
#  ('like_los_agaves', 20),
#  ('next_time_go', 20),
#  ('lot_mexican_food', 20),
#  ('best_mexican_ive', 20),
#  ('worst_customer_service', 20),
#  ('coming_back_place', 20),
#  ('salsa_pico_de', 20),
#  ('taco_carne_asada', 20),
#  ('order_counter_take', 20),
#  ('service_salsa_bar', 20),
#  ('service_friendly_staff', 19),
#  ('salsa_bar_fantastic', 19),
#  ('beef_pork_chicken', 19),
#  ('way_back_home', 19),
#  ('great_place_grab', 19),
#  ('san_luis_obispo', 19),
#  ('best_burrito_ive', 19),
#  ('place_pretty_good', 19),
#  ('pastor_carne_asada', 19),
#  ('chorizo_breakfast_burrito', 19),
#  ('give_zero_stars', 19),
#  ('got_al_pastor', 19),
#  ('delicious_cant_wait', 19),
#  ('excellent_salsa_bar', 19),
#  ('burrito_pretty_good', 19),
#  ('salsa_bar_excellent', 19),
#  ('great_little_place', 19),
#  ('worst_mexican_food', 19),
#  ('carne_asada_pork', 19),
#  ('parking_lot_small', 19),
#  ('mexican_restaurants_sb', 19),
#  ('carne_asada_al', 19),
#  ('salsa_bar_always', 19),
#  ('fast_food_place', 19),
#  ('time_come_santa', 19),
#  ('love_come_back', 19),
#  ('tasty_mexican_food', 19),
#  ('service_highly_recommend', 19),
#  ('tri_tip_chicken', 19),
#  ('good_highly_recommend', 19),
#  ('dinner_last_night', 19),
#  ('ordered_chicken_enchiladas', 19),
#  ('came_happy_hour', 19),
#  ('mexican_food_really', 19),
#  ('back_try_dishes', 19),
#  ('food_great_drinks', 19),
#  ('ok_nothing_special', 19),
#  ('customer_service_good', 19),
#  ('ive_never_seen', 19),
#  ('definitely_worth_visit', 19),
#  ('place_real_deal', 19),
#  ('sure_taken_care', 19),
#  ('chips_salsa_salsa', 19),
#  ('visit_los_agaves', 19),
#  ('looking_forward_trying', 19),
#  ('food_came_quick', 19),
#  ('keep_good_work', 19),
#  ('great_service_good', 19),
#  ('santa_barbara_los', 19),
#  ('give_free_chips', 19),
#  ('recommend_los_agaves', 19),
#  ('must_try_santa', 19),
#  ('chicken_mole_tacos', 19),
#  ('crispy_shrimp_ahi', 19),
#  ('carpaccio_de_carne', 19),
#  ('tried_carne_asada', 18),
#  ('id_definitely_recommend', 18),
#  ('yum_yum_yum', 18),
#  ('wish_could_give', 18),
#  ('yummy_mexican_food', 18),
#  ('makes_feel_like', 18),
#  ('place_best_tacos', 18),
#  ('great_food_nice', 18),
#  ('great_service_delicious', 18),
#  ('enchiladas_rice_beans', 18),
#  ('id_highly_recommend', 18),
#  ('highly_recommend_trying', 18),
#  ('try_everything_menu', 18),
#  ('got_chicken_burrito', 18),
#  ('everything_made_fresh', 18),
#  ('made_fresh_order', 18),
#  ('never_coming_back', 18),
#  ('authentic_street_tacos', 18),
#  ('salsas_really_good', 18),
#  ('santa_barbara_goleta', 18),
#  ('family_owned_business', 18),
#  ('santa_barbara_stopped', 18),
#  ('time_im_area', 18),
#  ('little_salsa_bar', 18),
#  ('service_great_atmosphere', 18),
#  ('plate_rice_beans', 18),
#  ('place_definitely_worth', 18),
#  ('wait_long_line', 18),
#  ('fajitas_del_mar', 18),
#  ('great_food_excellent', 18),
#  ('food_came_fast', 18),
#  ('took_care_us', 18),
#  ('one_best_things', 18),
#  ('cant_remember_name', 18),
#  ('food_reasonable_price', 18),
#  ('worth_it_food', 18),
#  ('great_people_watching', 18),
#  ('one_best_taco', 18),
#  ('good_would_recommend', 18),
#  ('locations_santa_barbara', 18),
#  ('food_came_pretty', 18),
#  ('best_part_meal', 18),
#  ('fresh_tortilla_chips', 18),
#  ('need_say_more', 18),
#  ('santa_barbara_often', 18),
#  ('definitely_would_recommend', 18),
#  ('santa_barbara_weather', 18),
#  ('breakfast_lunch_dinner', 18),
#  ('first_time_eating', 18),
#  ('super_fast_service', 18),
#  ('great_outdoor_seating', 18),
#  ('love_food_here', 18),
#  ('got_agaves_burrito', 18),
#  ('taco_ive_ever', 18),
#  ('los_agaves_great', 18),
#  ('ever_had_great', 18),
#  ('place_food_good', 18),
#  ('took_long_time', 18),
#  ('theres_always_line', 18),
#  ('definitely_recommend_coming', 18),
#  ('place_gets_packed', 18),
#  ('keep_going_back', 18),
#  ('know_good_mexican', 18),
#  ('food_brought_table', 18),
#  ('ordered_tacos_del', 18),
#  ('creamy_chipotle_sauce', 18),
#  ('gem_santa_barbara', 18),
#  ('sb_public_market', 18),
#  ('shrimp_carne_asada', 18),
#  ('spicy_shrimp_tacos', 18),
#  ('went_los_agaves', 18),
#  ('know_mexican_food', 17),
#  ('carne_asada_burritos', 17),
#  ('salsa_bar_pretty', 17),
#  ('ever_had_also', 17),
#  ('burrito_al_pastor', 17),
#  ('good_quality_food', 17),
#  ('best_burrito_ever', 17),
#  ('best_mexican_place', 17),
#  ('al_pastor_carne', 17),
#  ('fresh_made_order', 17),
#  ('real_authentic_mexican', 17),
#  ('santa_barbara_tried', 17),
#  ('bean_rice_cheese', 17),
#  ('mexican_restaurant_ive', 17),
#  ('small_salsa_bar', 17),
#  ('mexican_food_found', 17),
#  ('great_food_friendly', 17),
#  ('pretty_much_everything', 17),
#  ('really_enjoyed_food', 17),
#  ('mexican_food_taste', 17),
#  ('food_taste_like', 17),
#  ('always_great_food', 17),
#  ('chili_relleno_burrito', 17),
#  ('burrito_rice_beans', 17),
#  ('mexican_food_delicious', 17),
#  ('santa_barbara_restaurant', 17),
#  ('burritos_ive_ever', 17),
#  ('barbara_make_sure', 17),
#  ('amazing_customer_service', 17),
#  ('come_back_place', 17),
#  ('nice_outdoor_seating', 17),
#  ('way_like_it', 17),
#  ('grab_quick_bite', 17),
#  ('ordered_chile_verde', 17),
#  ('back_try_items', 17),
#  ('santa_barbara_know', 17),
#  ('cheese_marinated_pork', 17),
#  ('pretty_good_service', 17),
#  ('santa_barbara_la', 17),
#  ('much_better_mexican', 17),
#  ('fish_tacos_delicious', 17),
#  ('rice_refried_beans', 17),
#  ('ordered_tacos_de', 17),
#  ('id_definitely_come', 17),
#  ('ive_coming_years', 17),
#  ('drinks_happy_hour', 17),
#  ('wait_long_food', 17),
#  ('hands_one_best', 17),
#  ('solid_mexican_food', 17),
#  ('happy_hour_deals', 17),
#  ('love_place_always', 17),
#  ('taqueria_santa_barbara', 17),
#  ('food_always_delicious', 17),
#  ('totally_worth_wait', 17),
#  ('look_forward_coming', 17),
#  ('great_quality_food', 17),
#  ('santa_barbara_local', 17),
#  ('mexican_food_well', 17),
#  ('great_care_us', 17),
#  ('one_de_la', 17),
#  ('food_tastes_like', 17),
#  ('best_nachos_ever', 17),
#  ('definitely_back_try', 17),
#  ('well_taken_care', 17),
#  ('used_love_place', 17),
#  ('never_came_back', 17),
#  ('best_breakfast_burritos', 17),
#  ('food_drinks_great', 17),
#  ('two_tacos_one', 17),
#  ('would_go_again', 17),
#  ('best_happy_hour', 17),
#  ('must_santa_barbara', 17),
#  ('salsa_bar_food', 17),
#  ('back_next_trip', 17),
#  ('us_feel_like', 17),
#  ('come_back_more', 17),
#  ('next_trip_santa', 17),
#  ('bar_santa_barbara', 17),
#  ('staff_extremely_friendly', 17),
#  ('santa_barbara_ordered', 17),
#  ('wanted_like_place', 17),
#  ('delicious_would_definitely', 17),
#  ('food_delivered_table', 17),
#  ('restaurant_great_food', 17),
#  ('fan_mexican_food', 17),
#  ('salsa_bar_variety', 17),
#  ('santa_barbara_every', 17),
#  ('mexican_restaurants_area', 17),
#  ('onions_cilantro_salsa', 17),
#  ('los_agaves_restaurant', 17),
#  ('food_high_quality', 17),
#  ('barbara_highly_recommend', 17),
#  ('fish_tacos_ive', 17),
#  ('got_food_poisoning', 17),
#  ('steak_burrito_mojado', 17),
#  ('sweet_potato_fries', 17),
#  ('best_breakfast_burrito', 16),
#  ('love_place_best', 16),
#  ('carne_asada_best', 16),
#  ('food_made_order', 16),
#  ('place_hidden_gem', 16),
#  ('come_back_visit', 16),
#  ('great_place_stop', 16),
#  ('street_style_tacos', 16),
#  ('mexican_place_santa', 16),
#  ('salsa_bar_too', 16),
#  ('authentic_delicious_mexican', 16),
#  ('mexican_food_highly', 16),
#  ('al_pastor_good', 16),
#  ('mexican_food_come', 16),
#  ('great_would_definitely', 16),
#  ('food_comes_quickly', 16),
#  ('get_santa_barbara', 16),
#  ('back_first_time', 16),
#  ('day_santa_barbara', 16),
#  ('ordered_tri_tip', 16),
#  ('try_place_out', 16),
#  ('lettuce_sour_cream', 16),
#  ('got_ta_say', 16),
#  ('little_taco_shop', 16),
#  ('food_decent_price', 16),
#  ('get_one_free', 16),
#  ('order_counter_sit', 16),
#  ('definitely_recommend_trying', 16),
#  ('definitely_worth_try', 16),
#  ('friendly_service_great', 16),
#  ('selfserve_salsa_bar', 16),
#  ('give_five_stars', 16),
#  ('definitely_check_place', 16),
#  ('sour_cream_cheese', 16),
#  ('service_great_prices', 16),
#  ('mexican_food_get', 16),
#  ('street_santa_barbara', 16),
#  ('try_items_menu', 16),
#  ('great_place_get', 16),
#  ('never_bad_meal', 16),
#  ('homemade_mexican_food', 16),
#  ('look_forward_going', 16),
#  ('like_santa_barbara', 16),
#  ('drinks_great_food', 16),
#  ('santa_barbara_craving', 16),
#  ('tamal_de_verduras', 16),
#  ('pork_chile_verde', 16),
#  ...]

# %% [markdown]
# ### Coffee

# %%
Coffee = business_df[business_df.Type=='Coffee']
Coffee_review = review1[review1.business_id.isin(Coffee.business_id.values)]
Coffee_review["text"] = Coffee_review["text"].str.lower()
Coffee_review['text'] = Coffee_review['text'].apply(lambda text: cleaning_stopwords(text))
Coffee_review['text']= Coffee_review['text'].apply(lambda x: cleaning_punctuations(x))
Coffee_review['text'] = Coffee_review['text'].apply(lambda x: cleaning_repeating_char(x))
Coffee_review['text'] = Coffee_review['text'].apply(lambda x: cleaning_URLs(x))
Coffee_review['text'] = Coffee_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Coffee=Coffee[Coffee.stars<3.5]
bad_Coffee_review = Coffee_review[Coffee_review.business_id.isin(bad_Coffee.business_id.values)]
bad_Coffee_review_text = bad_Coffee_review.text.str.cat(sep = " ")
bad_Coffee_tokens = word_tokenize(bad_Coffee_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_bad_Coffee = ["_".join(item) for item in nltk.bigrams(bad_Coffee_tokens)]
trigrams_list_bad_Coffee = ["_".join(item) for item in nltk.trigrams(bad_Coffee_tokens)]
FreqDist(bigrams_list_bad_Coffee).most_common()
# FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('customer_service', 41),
#  ('santa_barbara', 20),
#  ('every_time', 18),
#  ('worst_starbucks', 16),
#  ('mobile_order', 16),
#  ('starbucks_location', 15),
#  ('iced_coffee', 15),
#  ('isla_vista', 15),
#  ('ive_ever', 14),
#  ('love_starbucks', 14),
#  ('go_starbucks', 13),
#  ('friendly_staff', 13),
#  ('behind_counter', 12),
#  ('favorite_starbucks', 12),
#  ('staff_friendly', 12),
#  ('coffee_shop', 11),
#  ('super_friendly', 11),
#  ('great_service', 11),
#  ('great_location', 11),
#  ('even_though', 11),
#  ('ive_never', 10),
#  ('starbucks_ever', 10),
#  ('college_students', 10),
#  ('caramel_macchiato', 10),
#  ('light_ice', 10),
#  ('seems_like', 9),
#  ('green_tea', 9),
#  ('la_cumbre', 9),
#  ('making_drinks', 9),
#  ('starbucks_ive', 8),
#  ('cup_coffee', 8),
#  ('drink_order', 8),
#  ('first_time', 8),
#  ('really_like', 8),
#  ('outdoor_seating', 8),
#  ('make_drink', 8),
#  ('cake_pop', 8),
#  ('staff_always', 8),
#  ('always_great', 8),
#  ('waited_minutes', 8),
#  ('place_study', 8),
#  ('always_make', 8),
#  ('mobile_orders', 8),
#  ('order_right', 7),
#  ('like_starbucks', 7),
#  ('im_sure', 7),
#  ('starbucks_coffee', 7),
#  ('many_starbucks', 7),
#  ('parking_lot', 7),
#  ('particular_starbucks', 7),
#  ('get_drink', 7),
#  ('across_street', 7),
#  ('took_minutes', 7),
#  ('great_place', 7),
#  ('ever_to', 7),
#  ('super_nice', 7),
#  ('order_wrong', 7),
#  ('hot_chocolate', 7),
#  ('every_morning', 7),
#  ('cold_brew', 7),
#  ('poop_james', 7),
#  ('one_best', 6),
#  ('walk_away', 6),
#  ('best_starbucks', 6),
#  ('starbucks_go', 6),
#  ('online_order', 6),
#  ('starbucks_great', 6),
#  ('starbucks_town', 6),
#  ('long_time', 6),
#  ('service_get', 6),
#  ('drinks_always', 6),
#  ('breakfast_sandwiches', 6),
#  ('camino_real', 6),
#  ('half_half', 6),
#  ('last_time', 6),
#  ('gift_card', 6),
#  ('get_coffee', 6),
#  ('every_single', 6),
#  ('feel_like', 6),
#  ('starbucks_starbucks', 6),
#  ('coming_back', 6),
#  ('make_drinks', 6),
#  ('pumpkin_spice', 6),
#  ('whipped_cream', 6),
#  ('waiting_line', 6),
#  ('almost_every', 5),
#  ('get_order', 5),
#  ('great_coffee', 5),
#  ('coffee_shops', 5),
#  ('seating_inside', 5),
#  ('friendly_service', 5),
#  ('really_nice', 5),
#  ('service_quick', 5),
#  ('could_get', 5),
#  ('toilet_paper', 5),
#  ('baristas_friendly', 5),
#  ('starbucks_one', 5),
#  ('drink_right', 5),
#  ('slow_service', 5),
#  ('every_starbucks', 5),
#  ('drinks_made', 5),
#  ('pretty_good', 5),
#  ('fast_service', 5),
#  ('pick_up', 5),
#  ('store_clean', 5),
#  ('get_busy', 5),
#  ('minutes_make', 5),
#  ('line_people', 5),
#  ('time_im', 5),
#  ('next_time', 5),
#  ('clover_machine', 5),
#  ('would_like', 5),
#  ('coffee_great', 5),
#  ('next_door', 5),
#  ('outside_seating', 5),
#  ('ten_minutes', 5),
#  ('lot_people', 5),
#  ('starbucks_usually', 5),
#  ('service_great', 5),
#  ('busy_time', 5),
#  ('good_coffee', 5),
#  ('coconut_milk', 5),
#  ('around_pm', 5),
#  ('people_waiting', 5),
#  ('iced_caramel', 5),
#  ('starbucks_santa', 5),
#  ('location_always', 5),
#  ('friendly_helpful', 5),
#  ('starbucks_always', 5),
#  ('come_starbucks', 5),
#  ('minutes_get', 5),
#  ('asked_barista', 5),
#  ('good_service', 5),
#  ('people_working', 5),
#  ('food_items', 5),
#  ('morning_coffee', 5),
#  ('ordered_two', 5),
#  ('college_town', 5),
#  ('always_really', 5),
#  ('every_day', 5),
#  ('people_line', 5),
#  ('come_back', 5),
#  ('friendly_baristas', 4),
#  ('got_drink', 4),
#  ('many_times', 4),
#  ('go_to', 4),
#  ('make_sure', 4),
#  ('always_friendly', 4),
#  ('made_drinks', 4),
#  ('super_busy', 4),
#  ('remember_name', 4),
#  ('tea_latte', 4),
#  ('stop_starbucks', 4),
#  ('drink_coffee', 4),
#  ('bad_reviews', 4),
#  ('bad_service', 4),
#  ('like_it', 4),
#  ('almost_always', 4),
#  ('mobile_ordering', 4),
#  ('starbucks_even', 4),
#  ('free_wifi', 4),
#  ('went_starbucks', 4),
#  ('way_make', 4),
#  ('one_day', 4),
#  ('one_drink', 4),
#  ('second_time', 4),
#  ('young_man', 4),
#  ('let_know', 4),
#  ('times_staff', 4),
#  ('going_back', 4),
#  ('made_drink', 4),
#  ('drinks_ordered', 4),
#  ('good_starbucks', 4),
#  ('go_one', 4),
#  ('coffee_stop', 4),
#  ('taking_order', 4),
#  ('bad_day', 4),
#  ('look_like', 4),
#  ('work_done', 4),
#  ('single_time', 4),
#  ('time_ive', 4),
#  ('got_order', 4),
#  ('seating_area', 4),
#  ('made_order', 4),
#  ('much_better', 4),
#  ('starbucks_locations', 4),
#  ('two_stars', 4),
#  ('still_good', 4),
#  ('seemed_like', 4),
#  ('espresso_shot', 4),
#  ('never_problem', 4),
#  ('quick_coffee', 4),
#  ('love_coming', 4),
#  ('took_order', 4),
#  ('drink_came', 4),
#  ('always_go', 4),
#  ('friendly_nice', 4),
#  ('making_drink', 4),
#  ('starbucks_get', 4),
#  ('order_made', 4),
#  ('good_thing', 4),
#  ('spice_latte', 4),
#  ('less_minutes', 4),
#  ('really_appreciate', 4),
#  ('black_coffee', 4),
#  ('friendly_welcoming', 4),
#  ('horrible_service', 4),
#  ('great_customer', 4),
#  ('often_times', 4),
#  ('help_you', 4),
#  ('nice_people', 4),
#  ('drink_orders', 4),
#  ('today_ordered', 4),
#  ('even_bother', 4),
#  ('coffee_like', 4),
#  ('white_mocha', 4),
#  ('coffee_go', 4),
#  ('looked_like', 4),
#  ('line_order', 4),
#  ('nicest_people', 4),
#  ('service_fast', 4),
#  ('whip_cream', 4),
#  ('vanilla_syrup', 4),
#  ('far_worst', 4),
#  ('bad_experience', 4),
#  ('appreciate_it', 4),
#  ('got_drinks', 4),
#  ('employees_nice', 4),
#  ('place_nice', 4),
#  ('years_ago', 3),
#  ('probably_worst', 3),
#  ('ever_in', 3),
#  ('starbucks_fan', 3),
#  ('usually_go', 3),
#  ('employees_friendly', 3),
#  ('give_location', 3),
#  ('say_starbucks', 3),
#  ('high_turnover', 3),
#  ('good_drink', 3),
#  ('location_makes', 3),
#  ('never_go', 3),
#  ('time_make', 3),
#  ('service_slow', 3),
#  ('like_new', 3),
#  ('friendly_get', 3),
#  ('going_starbucks', 3),
#  ('drinks_like', 3),
#  ('you_ive', 3),
#  ('well_store', 3),
#  ('ordered_drinks', 3),
#  ('super_sweet', 3),
#  ('staff_super', 3),
#  ('staff_makes', 3),
#  ('coffee_even', 3),
#  ('sugar_free', 3),
#  ('caramel_drizzle', 3),
#  ('good_place', 3),
#  ('makes_sense', 3),
#  ('drive_thru', 3),
#  ('long_way', 3),
#  ('local_starbucks', 3),
#  ('need_it', 3),
#  ('get_orders', 3),
#  ('coffee_always', 3),
#  ('get_there', 3),
#  ('want_go', 3),
#  ('location_perfect', 3),
#  ('one_many', 3),
#  ('mom_pop', 3),
#  ('shopping_center', 3),
#  ('matcha_latte', 3),
#  ('ive_gotten', 3),
#  ('another_customer', 3),
#  ('try_avoid', 3),
#  ('avoid_starbucks', 3),
#  ('five_points', 3),
#  ('terribly_slow', 3),
#  ('starbucks_to', 3),
#  ('getting_coffee', 3),
#  ('poor_management', 3),
#  ('app_order', 3),
#  ('store_manager', 3),
#  ('closing_time', 3),
#  ('day_going', 3),
#  ('thank_you', 3),
#  ('good_location', 3),
#  ('get_pretty', 3),
#  ('pretty_busy', 3),
#  ('up_love', 3),
#  ('time_there', 3),
#  ('back_location', 3),
#  ('need_little', 3),
#  ('one_person', 3),
#  ('drink_time', 3),
#  ('real_marketplace', 3),
#  ('im_going', 3),
#  ('place_get', 3),
#  ('never_going', 3),
#  ('find_seat', 3),
#  ('pretty_much', 3),
#  ('long_drive', 3),
#  ('cup_said', 3),
#  ('ever_starbucks', 3),
#  ('custom_coffee', 3),
#  ('sunday_morning', 3),
#  ('coffee_came', 3),
#  ('service_location', 3),
#  ('coffee_good', 3),
#  ('long_line', 3),
#  ('location_great', 3),
#  ('shopping_plaza', 3),
#  ('foot_traffic', 3),
#  ('starbucks_got', 3),
#  ('starbucks_area', 3),
#  ('always_kind', 3),
#  ('get_two', 3),
#  ('close_ucsb', 3),
#  ('like_me', 3),
#  ('nice_helpful', 3),
#  ('order_starbucks', 3),
#  ('hard_find', 3),
#  ('im_glad', 3),
#  ('time_go', 3),
#  ('convenient_location', 3),
#  ('bring_jacket', 3),
#  ('need_work', 3),
#  ('one_like', 3),
#  ('packed_students', 3),
#  ('stars_instead', 3),
#  ('instead_one', 3),
#  ('one_usually', 3),
#  ('theres_always', 3),
#  ('busy_location', 3),
#  ('early_morning', 3),
#  ('staff_also', 3),
#  ('really_friendly', 3),
#  ('go_late', 3),
#  ('coming_here', 3),
#  ('ucsb_students', 3),
#  ('time_come', 3),
#  ('nice_store', 3),
#  ('steamed_milk', 3),
#  ('ordered_regular', 3),
#  ('decaf_coffee', 3),
#  ('usually_stop', 3),
#  ('make_cup', 3),
#  ('making_coffee', 3),
#  ('go_place', 3),
#  ('drinks_fine', 3),
#  ('day_super', 3),
#  ('long_table', 3),
#  ('make_best', 3),
#  ('location_one', 3),
#  ('starbucks_staff', 3),
#  ('wait_minutes', 3),
#  ('made_quickly', 3),
#  ('quality_drinks', 3),
#  ('give_place', 3),
#  ('gold_card', 3),
#  ('make_point', 3),
#  ('went_way', 3),
#  ('love_place', 3),
#  ('get_it', 3),
#  ('venti_iced', 3),
#  ('mobile_app', 3),
#  ('drink_asked', 3),
#  ('service_pretty', 3),
#  ('pretty_sure', 3),
#  ('still_waiting', 3),
#  ('coming_starbucks', 3),
#  ('terrible_service', 3),
#  ('wear_mask', 3),
#  ('twenty_minutes', 3),
#  ('order_line', 3),
#  ('think_starbucks', 3),
#  ('nice_friendly', 3),
#  ('nice_staff', 3),
#  ('baristas_usually', 3),
#  ('said_i', 3),
#  ('gotten_order', 3),
#  ('egg_bites', 3),
#  ('early_day', 3),
#  ('racial_profiling', 3),
#  ('gross_negligence', 3),
#  ('ordered_caramel', 3),
#  ('grab_coffee', 3),
#  ('avoid_location', 3),
#  ('stop_here', 3),
#  ('finally_got', 3),
#  ('could_make', 3),
#  ('write_review', 3),
#  ('time_time', 3),
#  ('one_ever', 3),
#  ('taste_like', 3),
#  ('finals_week', 3),
#  ('right_now', 3),
#  ('ever_experienced', 3),
#  ('minutes_one', 3),
#  ('ever_had', 3),
#  ('closest_starbucks', 3),
#  ('fan_starbucks', 3),
#  ('indoor_seating', 3),
#  ('small_crowded', 3),
#  ('made_feel', 3),
#  ('horrible_customer', 3),
#  ('place_go', 3),
#  ('id_say', 3),
#  ('wait_line', 3),
#  ('order_ive', 3),
#  ('people_ever', 3),
#  ('hot_coffee', 3),
#  ('remake_drink', 3),
#  ('days_later', 3),
#  ('would_remake', 3),
#  ('drinks_quickly', 3),
#  ('room_cream', 3),
#  ('place_always', 3),
#  ('cant_believe', 3),
#  ('time_waited', 3),
#  ('ask_light', 3),
#  ('starbucks_app', 3),
#  ('always_nice', 3),
#  ('two_drinks', 3),
#  ('drinks_two', 3),
#  ('said_would', 3),
#  ('always_busy', 3),
#  ('here_great', 3),
#  ('inside_store', 3),
#  ('got_coffee', 3),
#  ('little_bit', 3),
#  ('time_went', 3),
#  ('venti_caramel', 3),
#  ('ordered_grande', 3),
#  ('coffee_im', 3),
#  ('us_got', 3),
#  ('behind_us', 3),
#  ('vista_starbucks', 3),
#  ('high_five', 3),
#  ('also_got', 3),
#  ('pour_over', 3),
#  ('minutes_waiting', 3),
#  ('starbucks_worst', 3),
#  ('drinks_starbucks', 3),
#  ('one_making', 3),
#  ('location_used', 3),
#  ('service_excellent', 3),
#  ('location_starbucks', 3),
#  ('sweet_cream', 3),
#  ('ice_half', 3),
#  ('double_shot', 3),
#  ('get_work', 3),
#  ('mesa_location', 3),
#  ('almost_everyday', 2),
#  ('everyday_one', 2),
#  ('know_starbucks', 2),
#  ('coffee_come', 2),
#  ('come_one', 2),
#  ('one_starbucks', 2),
#  ('top_that', 2),
#  ('beverage_great', 2),
#  ('great_ordered', 2),
#  ('freezing_inside', 2),
#  ('working_register', 2),
#  ('couple_minutes', 2),
#  ('find_table', 2),
#  ('table_outside', 2),
#  ('starbucks_standard', 2),
#  ('store_one', 2),
#  ('stopped_way', 2),
#  ('want_give', 2),
#  ('location_good', 2),
#  ('good_review', 2),
#  ('every_location', 2),
#  ('drinks_consistently', 2),
#  ('go_again', 2),
#  ('one_one', 2),
#  ('friendly_despite', 2),
#  ('customers_ordered', 2),
#  ('find_store', 2),
#  ('store_small', 2),
#  ('great_employees', 2),
#  ('people_great', 2),
#  ('recommend_going', 2),
#  ('place_busy', 2),
#  ('staff_amazing', 2),
#  ('cranking_drinks', 2),
#  ('props_you', 2),
#  ('never_seen', 2),
#  ('seen_starbucks', 2),
#  ('barista_made', 2),
#  ('drinks_friends', 2),
#  ('think_thats', 2),
#  ('get_place', 2),
#  ('place_got', 2),
#  ('needed_stop', 2),
#  ('extra_minutes', 2),
#  ('minutes_wait', 2),
#  ('year_old', 2),
#  ('waiting_drinks', 2),
#  ('drinks_one', 2),
#  ('cake_pops', 2),
#  ('staff_starbucks', 2),
#  ('times_week', 2),
#  ('name_drink', 2),
#  ('sometimes_get', 2),
#  ('busy_staff', 2),
#  ('staff_great', 2),
#  ('better_friendly', 2),
#  ('friendly_people', 2),
#  ('chai_tea', 2),
#  ('guys_make', 2),
#  ('pretty_awesome', 2),
#  ('free_vanilla', 2),
#  ('caramel_sauce', 2),
#  ('would_definitely', 2),
#  ('local_coffee', 2),
#  ('reviews_place', 2),
#  ('say_something', 2),
#  ('time_say', 2),
#  ('even_small', 2),
#  ('five_star', 2),
#  ('quick_accurate', 2),
#  ('coffee_making', 2),
#  ('cumbre_plaza', 2),
#  ('much_seating', 2),
#  ('orders_right', 2),
#  ('recently_saw', 2),
#  ('clean_even', 2),
#  ('one_good', 2),
#  ('visit_starbucks', 2),
#  ('usually_order', 2),
#  ('ever_seen', 2),
#  ('far_one', 2),
#  ('cumbre_mall', 2),
#  ('like_work', 2),
#  ('regardless_busy', 2),
#  ('stopped_coffee', 2),
#  ('coffee_road', 2),
#  ('get_free', 2),
#  ('would_get', 2),
#  ('seat_covers', 2),
#  ('seating_well', 2),
#  ('made_fine', 2),
#  ('here_baristas', 2),
#  ('ask_for', 2),
#  ('stop_morning', 2),
#  ('could_give', 2),
#  ('took_little', 2),
#  ('easy_access', 2),
#  ('starbucks_recently', 2),
#  ('staff_quick', 2),
#  ('quick_service', 2),
#  ('definitely_favorite', 2),
#  ('drink_every', 2),
#  ('latte_ive', 2),
#  ('even_know', 2),
#  ('make_it', 2),
#  ('to_plus', 2),
#  ('im_shopping', 2),
#  ('made_wrong', 2),
#  ('time_wait', 2),
#  ('made_right', 2),
#  ('chocolate_loaf', 2),
#  ('yelp_said', 2),
#  ('bakery_goods', 2),
#  ('see_review', 2),
#  ('me_asked', 2),
#  ('know_it', 2),
#  ('still_go', 2),
#  ('customers_would', 2),
#  ('star_review', 2),
#  ('wanted_hot', 2),
#  ('thanks_guys', 2),
#  ('good_team', 2),
#  ('people_here', 2),
#  ('customer_experience', 2),
#  ('location_customer', 2),
#  ('though_place', 2),
#  ('place_small', 2),
#  ('rush_hour', 2),
#  ('hour_get', 2),
#  ('nice_outside', 2),
#  ('could_be', 2),
#  ('drinks_back', 2),
#  ('back_up', 2),
#  ('new_lids', 2),
#  ('entire_time', 2),
#  ('getting_drinks', 2),
#  ('someone_else', 2),
#  ('county_health', 2),
#  ('probably_best', 2),
#  ('best_place', 2),
#  ('went_pick', 2),
#  ('thats_always', 2),
#  ('cup_ice', 2),
#  ('ice_notice', 2),
#  ('super_clean', 2),
#  ('drink_cold', 2),
#  ('quick_stop', 2),
#  ('girl_register', 2),
#  ('started_drink', 2),
#  ('happy_hour', 2),
#  ('starbucks_never', 2),
#  ('never_issue', 2),
#  ('never_return', 2),
#  ('return_location', 2),
#  ('location_gets', 2),
#  ('star_since', 2),
#  ('however_made', 2),
#  ('drinks_location', 2),
#  ('usually_clean', 2),
#  ('your_drink', 2),
#  ('starbucks_camino', 2),
#  ('place_dirty', 2),
#  ('somewhere_else', 2),
#  ('would_great', 2),
#  ('study_spot', 2),
#  ('thought_would', 2),
#  ('usual_drink', 2),
#  ('would_recommend', 2),
#  ('coffee_time', 2),
#  ('study_hang', 2),
#  ('hang_out', 2),
#  ('so_get', 2),
#  ('get_crowded', 2),
#  ('bad_starbucks', 2),
#  ('home_depot', 2),
#  ('movie_theater', 2),
#  ('always_crowded', 2),
#  ('students_studying', 2),
#  ('couple_years', 2),
#  ('prime_location', 2),
#  ('cant_remember', 2),
#  ('way_asked', 2),
#  ('wrote_name', 2),
#  ('name_cup', 2),
#  ('rolled_eyes', 2),
#  ('walked_away', 2),
#  ('never_ever', 2),
#  ('rude_disrespectful', 2),
#  ('employees_tried', 2),
#  ('day_thats', 2),
#  ('working_customer', 2),
#  ('oh_also', 2),
#  ('coffee_clover', 2),
#  ('crowded_sunday', 2),
#  ('tall_size', 2),
#  ('complaint_service', 2),
#  ('regular_coffee', 2),
#  ('something_else', 2),
#  ('peak_times', 2),
#  ('since_last', 2),
#  ('get_outlets', 2),
#  ('outlets_fixed', 2),
#  ('starbucks_thats', 2),
#  ('ice_coffee', 2),
#  ('free_drinks', 2),
#  ('nice_her', 2),
#  ('baristas_ive', 2),
#  ('baristas_make', 2),
#  ('enough_seats', 2),
#  ('though_really', 2),
#  ('try_new', 2),
#  ('work_sometimes', 2),
#  ('many_customers', 2),
#  ('location_im', 2),
#  ('starbucks_second', 2),
#  ('starbucks_right', 2),
#  ('many_things', 2),
#  ('cold_here', 2),
#  ('colder_inside', 2),
#  ('inside_outside', 2),
#  ('never_come', 2),
#  ('monday_morning', 2),
#  ('want_late', 2),
#  ('late_work', 2),
#  ('chai_latte', 2),
#  ('employees_super', 2),
#  ('starbucks_study', 2),
#  ('order_quickly', 2),
#  ('lines_long', 2),
#  ('time_get', 2),
#  ('came_another', 2),
#  ('service_amenities', 2),
#  ('students_like', 2),
#  ('big_tables', 2),
#  ('work_staff', 2),
#  ('staff_nice', 2),
#  ('everyone_feel', 2),
#  ('drive_way', 2),
#  ('ever_encountered', 2),
#  ('cashiers_super', 2),
#  ('baristas_made', 2),
#  ('always_rude', 2),
#  ('coffee_cup', 2),
#  ('brewed_starbucks', 2),
#  ('piping_hot', 2),
#  ('plenty_outlets', 2),
#  ('plan_staying', 2),
#  ('bathroom_always', 2),
#  ('id_recommend', 2),
#  ('know_order', 2),
#  ('order_ahead', 2),
#  ('shop_great', 2),
#  ('great_spot', 2),
#  ('service_even', 2),
#  ('order_online', 2),
#  ('usually_pretty', 2),
#  ('pretty_nice', 2),
#  ('register_one', 2),
#  ('even_theres', 2),
#  ('free_coffee', 2),
#  ('barista_register', 2),
#  ('drink_another', 2),
#  ('helpful_even', 2),
#  ('coffee_amazing', 2),
#  ('location_needs', 2),
#  ('needs_hire', 2),
#  ('starbucks_employees', 2),
#  ('short_staffed', 2),
#  ('making_mistakes', 2),
#  ('service_still', 2),
#  ('give_stars', 2),
#  ('ever_too', 2),
#  ('like_years', 2),
#  ('coffee_leave', 2),
#  ('remake_them', 2),
#  ('could_use', 2),
#  ('bathroom_disgustingly', 2),
#  ('disgustingly_dirty', 2),
#  ('starbucks_best', 2),
#  ('store_long', 2),
#  ('tea_coffee', 2),
#  ('coffee_wish', 2),
#  ('nice_know', 2),
#  ('morning_afternoon', 2),
#  ('order_want', 2),
#  ('coffee_better', 2),
#  ('french_press', 2),
#  ('considering_busy', 2),
#  ('busy_store', 2),
#  ('used_love', 2),
#  ('get_line', 2),
#  ('wait_drink', 2),
#  ('came_around', 2),
#  ('free_drink', 2),
#  ('it_drink', 2),
#  ('orders_even', 2),
#  ('time_drink', 2),
#  ('drink_one', 2),
#  ('area_staff', 2),
#  ('barista_staff', 2),
#  ('student_body', 2),
#  ('go_spot', 2),
#  ('study_hours', 2),
#  ('baristas_always', 2),
#  ('drink_thats', 2),
#  ('shot_espresso', 2),
#  ('expect_starbucks', 2),
#  ('warm_inviting', 2),
#  ('lot_seating', 2),
#  ('large_area', 2),
#  ('lot_students', 2),
#  ('students_study', 2),
#  ('going_coffee', 2),
#  ('coffee_bean', 2),
#  ('never_actually', 2),
#  ('word_get', 2),
#  ('worth_it', 2),
#  ('put_much', 2),
#  ('run_like', 2),
#  ('like_disorganized', 2),
#  ('disorganized_mom', 2),
#  ('pop_shop', 2),
#  ('first_morning', 2),
#  ('coffee_ordered', 2),
#  ('would_prefer', 2),
#  ('asked_wanted', 2),
#  ('said_no', 2),
#  ('without_asking', 2),
#  ('gets_better', 2),
#  ('specific_location', 2),
#  ('get_cup', 2),
#  ('cup_decaf', 2),
#  ('make_decaf', 2),
#  ('decaf_afternoon', 2),
#  ('different_location', 2),
#  ('cup_charge', 2),
#  ('medium_cup', 2),
#  ('large_cup', 2),
#  ('say_location', 2),
#  ('tell_im', 2),
#  ('im_happy', 2),
#  ('train_employees', 2),
#  ('better_customer', 2),
#  ('plenty_seating', 2),
#  ('people_watching', 2),
#  ('come_study', 2),
#  ('slow_lazy', 2),
#  ('lazy_worker', 2),
#  ('even_told', 2),
#  ('drink_pickup', 2),
#  ('finally_made', 2),
#  ('drink_even', 2),
#  ('rude_workers', 2),
#  ('slowest_starbucks', 2),
#  ('point_often', 2),
#  ('times_day', 2),
#  ('day_ive', 2),
#  ('quick_friendly', 2),
#  ('courteous_friendly', 2),
#  ('drinks_fast', 2),
#  ('place_super', 2),
#  ('easy_pick', 2),
#  ('pick_order', 2),
#  ('location_got', 2),
#  ('ive_seen', 2),
#  ('breath_fresh', 2),
#  ('fresh_air', 2),
#  ('cookie_cutter', 2),
#  ('starbucks_stores', 2),
#  ('large_table', 2),
#  ('lots_parking', 2),
#  ('even_peak', 2),
#  ('peak_hours', 2),
#  ('crowded_cramped', 2),
#  ('definitely_best', 2),
#  ('drinks_also', 2),
#  ('past_years', 2),
#  ('years_never', 2),
#  ('never_get', 2),
#  ('coffee_ice', 2),
#  ('make_order', 2),
#  ('right_also', 2),
#  ('usually_long', 2),
#  ('usually_crowded', 2),
#  ('times_drink', 2),
#  ('one_always', 2),
#  ('drink_wrong', 2),
#  ('make_customer', 2),
#  ('received_drinks', 2),
#  ('another_thing', 2),
#  ('location_new', 2),
#  ('gold_member', 2),
#  ('sometimes_little', 2),
#  ('little_crowded', 2),
#  ('really_busy', 2),
#  ('disappointed_starbucks', 2),
#  ('time_starbucks', 2),
#  ('benefit_doubt', 2),
#  ('location_really', 2),
#  ('communal_table', 2),
#  ('place_come', 2),
#  ('coffee_study', 2),
#  ('get_usually', 2),
#  ('usually_get', 2),
#  ('soy_milk', 2),
#  ('gets_crowded', 2),
#  ('sitting_outside', 2),
#  ('today_around', 2),
#  ('im_writing', 2),
#  ('coffee_also', 2),
#  ('starbucks_prime', 2),
#  ('welcoming_always', 2),
#  ('thought_starbucks', 2),
#  ('starbucks_tried', 2),
#  ('right_across', 2),
#  ('bright_side', 2),
#  ('highly_recommend', 2),
#  ('employees_really', 2),
#  ('always_ask', 2),
#  ('ask_day', 2),
#  ('day_make', 2),
#  ('swamped_orders', 2),
#  ('order_thats', 2),
#  ('service_skills', 2),
#  ('location_opens', 2),
#  ('starbucks_montecito', 2),
#  ('sitting_areas', 2),
#  ('hire_staff', 2),
#  ('wait_times', 2),
#  ('hours_day', 2),
#  ('college_kids', 2),
#  ('still_takes', 2),
#  ('close_minutes', 2),
#  ('clean_well', 2),
#  ('bad_attitude', 2),
#  ('attitude_like', 2),
#  ('like_good', 2),
#  ('here_never', 2),
#  ('it_ask', 2),
#  ('still_get', 2),
#  ('busy_chatting', 2),
#  ('time_job', 2),
#  ('get_fix', 2),
#  ('service_waited', 2),
#  ('made_less', 2),
#  ('got_it', 2),
#  ('ordered_venti', 2),
#  ('asked_girl', 2),
#  ('times_locations', 2),
#  ('ordered_mobile', 2),
#  ('ordered_wrong', 2),
#  ('wrong_drink', 2),
#  ('sure_place', 2),
#  ('place_run', 2),
#  ('run_college', 2),
#  ('students_actually', 2),
#  ('actually_need', 2),
#  ('work_type', 2),
#  ('type_service', 2),
#  ('get_often', 2),
#  ('times_busy', 2),
#  ('busy_talking', 2),
#  ('talking_amongst', 2),
#  ('amongst_times', 2),
#  ('times_forget', 2),
#  ('forget_make', 2),
#  ('make_something', 2),
#  ('something_orderedno', 2),
#  ('orderedno_joke', 2),
#  ('joke_notice', 2),
#  ('notice_ask', 2),
#  ('ask_realize', 2),
#  ('realize_still', 2),
#  ('waiting_often', 2),
#  ('times_greeting', 2),
#  ('greeting_even', 2),
#  ('even_store', 2),
#  ('store_relatively', 2),
#  ('relatively_empty', 2),
#  ('empty_can', 2),
#  ('can_help', 2),
#  ('you_even', 2),
#  ('even_standing', 2),
#  ('standing_front', 2),
#  ('front_register', 2),
#  ('register_continue', 2),
#  ('continue_talk', 2),
#  ('talk_deign', 2),
#  ('deign_help', 2),
#  ('you_try', 2),
#  ('avoid_coming', 2),
#  ('new_drinks', 2),
#  ('barista_girl', 2),
#  ('wanted_drink', 2),
#  ('hot_cold', 2),
#  ('care_environment', 2),
#  ('really_care', 2),
#  ('cup_discount', 2),
#  ('wish_drive', 2),
#  ('finally_asked', 2),
#  ('cold_coffee', 2),
#  ('even_ask', 2),
#  ('amazing_service', 2),
#  ('starbucks_ordered', 2),
#  ('again_horrible', 2),
#  ('would_ready', 2),
#  ('theyre_busy', 2),
#  ('offer_refund', 2),
#  ('starbucks_every', 2),
#  ('order_ready', 2),
#  ('remembers_name', 2),
#  ('makes_feel', 2),
#  ('starbucks_messes', 2),
#  ('hot_drinks', 2),
#  ('app_arrived', 2),
#  ('minutes_late', 2),
#  ('line_ask', 2),
#  ('scoop_ice', 2),
#  ('drinks_much', 2),
#  ('make_sense', 2),
#  ('ice_scoop', 2),
#  ('drink_times', 2),
#  ('help_make', 2),
#  ('afternoon_brake', 2),
#  ('brake_time', 2),
#  ('time_pm', 2),
#  ('pm_need', 2),
#  ('little_caffeine', 2),
#  ('caffeine_make', 2),
#  ('make_thru', 2),
#  ('thru_day', 2),
#  ('friendly_cashiers', 2),
#  ('cashiers_barista', 2),
#  ('quick_order', 2),
#  ('college_student', 2),
#  ('closest_location', 2),
#  ('location_house', 2),
#  ('usually_mobile', 2),
#  ('must_say', 2),
#  ('working_friendly', 2),
#  ('wrong_asked', 2),
#  ('asked_it', 2),
#  ('wrong_said', 2),
#  ('several_minutes', 2),
#  ('drink_noticed', 2),
#  ('anything_like', 2),
#  ('passion_tea', 2),
#  ('always_pleasant', 2),
#  ...]

# %%
good_Coffee=Coffee[Coffee.stars>=4.5]
good_Coffee_review = Coffee_review[Coffee_review.business_id.isin(good_Coffee.business_id.values)]
good_Coffee_review_text = good_Coffee_review.text.str.cat(sep = " ")
good_Coffee_tokens = word_tokenize(good_Coffee_review_text)
# FreqDist(good_American_tokens).most_common()
bigrams_list_good_Coffee = ["_".join(item) for item in nltk.bigrams(good_Coffee_tokens)]
trigrams_list_good_Coffee = ["_".join(item) for item in nltk.trigrams(good_Coffee_tokens)]
# FreqDist(bigrams_list_good_Coffee).most_common()
FreqDist(trigrams_list_good_Coffee).most_common()
# Out:
# [('ive_ever_had', 46),
#  ('tugboat_eggs_benedict', 22),
#  ('wait_come_back', 20),
#  ('benedict_fried_chicken', 20),
#  ('cant_wait_come', 19),
#  ('definitely_come_back', 19),
#  ('tugboat_fried_chicken', 19),
#  ('wait_go_back', 18),
#  ('salmon_yo_face', 18),
#  ('next_time_im', 17),
#  ('come_back_try', 17),
#  ('fried_chicken_tugboat', 17),
#  ('cant_wait_go', 16),
#  ('indoor_outdoor_seating', 16),
#  ('fried_chicken_sandwich', 16),
#  ('back_next_time', 15),
#  ('staff_super_friendly', 14),
#  ('visiting_santa_barbara', 14),
#  ('cant_go_wrong', 14),
#  ('fried_chicken_benedict', 14),
#  ('go_back_try', 13),
#  ('great_customer_service', 13),
#  ('highly_recommend_place', 13),
#  ('visit_santa_barbara', 12),
#  ('gluten_free_bread', 12),
#  ('dean_coffee_shop', 12),
#  ('eggs_benedict_fried', 12),
#  ('chicken_eggs_benedict', 12),
#  ('fried_chicken_eggs', 12),
#  ('would_highly_recommend', 11),
#  ('outdoor_seating_area', 11),
#  ('best_damn_oatmeal', 11),
#  ('mac_n_cheese', 11),
#  ('spot_santa_barbara', 10),
#  ('worth_every_penny', 10),
#  ('definitely_coming_back', 10),
#  ('cant_wait_try', 10),
#  ('fried_chicken_biscuits', 10),
#  ('great_food_great', 10),
#  ('breakfast_santa_barbara', 10),
#  ('toast_fried_chicken', 10),
#  ('buttermilk_fried_chicken', 10),
#  ('come_back_again', 9),
#  ('also_really_good', 9),
#  ('best_ive_ever', 9),
#  ('latte_oat_milk', 9),
#  ('iced_oat_milk', 9),
#  ('super_friendly_staff', 9),
#  ('great_outdoor_seating', 9),
#  ('tri_tip_sandwich', 9),
#  ('chicken_french_toast', 9),
#  ('strawberry_bbq_sauce', 9),
#  ('bring_food_you', 9),
#  ('ordered_fried_chicken', 9),
#  ('would_definitely_go', 8),
#  ('fried_chicken_biscuit', 8),
#  ('eggs_yo_face', 8),
#  ('yolo_fried_chicken', 8),
#  ('french_toast_fried', 8),
#  ('one_favorite_places', 8),
#  ('chicken_biscuits_gravy', 8),
#  ('smoked_tomato_hollandaise', 8),
#  ('gluten_free_options', 8),
#  ('best_bread_ever', 8),
#  ('would_definitely_recommend', 7),
#  ('would_come_back', 7),
#  ('downtown_santa_barbara', 7),
#  ('customer_service_great', 7),
#  ('would_recommend_place', 7),
#  ('bella_rose_matcha', 7),
#  ('time_santa_barbara', 7),
#  ('staff_friendly_helpful', 7),
#  ('next_time_were', 7),
#  ('vietnamese_iced_coffee', 7),
#  ('oat_milk_matcha', 7),
#  ('oat_milk_chai', 7),
#  ('two_poached_eggs', 7),
#  ('best_breakfast_santa', 7),
#  ('gravy_fried_chicken', 7),
#  ('everything_ive_tried', 7),
#  ('ordered_eggs_benedict', 7),
#  ('place_order_window', 7),
#  ('order_window_bring', 7),
#  ('egg_white_omelette', 7),
#  ('come_back_next', 6),
#  ('time_im_sb', 6),
#  ('definitely_go_back', 6),
#  ('decided_check_out', 6),
#  ('recommend_place_anyone', 6),
#  ('back_next_day', 6),
#  ('place_santa_barbara', 6),
#  ('give_place_stars', 6),
#  ('outdoor_seating_great', 6),
#  ('inside_outside_seating', 6),
#  ('oat_milk_latte', 6),
#  ('trip_santa_barbara', 6),
#  ('santa_barbara_place', 6),
#  ('were_santa_barbara', 6),
#  ('favorite_breakfast_spot', 6),
#  ('ordered_tug_boat', 6),
#  ('fried_chicken_french', 6),
#  ('walk_window_order', 6),
#  ('house_cured_salmon', 6),
#  ('ordered_mac_crack', 6),
#  ('salmon_poached_eggs', 6),
#  ('order_window_find', 6),
#  ('beautiful_santa_barbara', 6),
#  ('bring_food_table', 6),
#  ('im_gon_na', 6),
#  ('serve_handlebar_coffee', 6),
#  ('almond_butter_toast', 6),
#  ('got_eggs_benedict', 6),
#  ('best_eggs_benedict', 6),
#  ('fried_chicken_perfectly', 6),
#  ('boba_milk_tea', 6),
#  ('bread_ive_ever', 6),
#  ('great_way_spend', 5),
#  ('check_place_out', 5),
#  ('ill_definitely_back', 5),
#  ('wish_could_give', 5),
#  ('great_place_go', 5),
#  ('found_place_yelp', 5),
#  ('back_santa_barbara', 5),
#  ('staff_extremely_friendly', 5),
#  ('im_big_fan', 5),
#  ('ive_ever_life', 5),
#  ('plenty_outdoor_seating', 5),
#  ('try_something_new', 5),
#  ('best_coffee_shop', 5),
#  ('id_come_back', 5),
#  ('unique_coffee_drinks', 5),
#  ('local_coffee_shops', 5),
#  ('coffee_ive_ever', 5),
#  ('definitely_must_try', 5),
#  ('latte_almond_milk', 5),
#  ('would_definitely_come', 5),
#  ('coffee_drinks_like', 5),
#  ('day_santa_barbara', 5),
#  ('im_glad_did', 5),
#  ('go_wrong_anything', 5),
#  ('wrong_anything_menu', 5),
#  ('friendly_staff_great', 5),
#  ('santa_barbara_stopped', 5),
#  ('come_santa_barbara', 5),
#  ('place_super_cute', 5),
#  ('lots_outdoor_seating', 5),
#  ('let_tell_you', 5),
#  ('iced_vanilla_latte', 5),
#  ('cant_say_enough', 5),
#  ('outdoor_indoor_seating', 5),
#  ('santa_barbara_area', 5),
#  ('chicken_biscuit_gravy', 5),
#  ('decided_give_try', 5),
#  ('fried_chicken_delicious', 5),
#  ('outdoor_seating_perfect', 5),
#  ('poached_eggs_toast', 5),
#  ('santa_barbara_food', 5),
#  ('good_day_sunshine', 5),
#  ('eggs_benedict_carnitas', 5),
#  ('salmon_eggs_benedict', 5),
#  ('breakfast_shop_cafe', 5),
#  ('poached_egg_top', 5),
#  ('best_thing_menu', 5),
#  ('ive_long_time', 5),
#  ('perfectly_poached_egg', 5),
#  ('version_eggs_benedict', 5),
#  ('avocado_hollandaise_sauce', 5),
#  ('window_bring_food', 5),
#  ('food_eggs_benedict', 5),
#  ('ordered_tugboat_fried', 5),
#  ('next_tire_shop', 5),
#  ('frenchie_fried_chicken', 5),
#  ('next_time_visit', 5),
#  ('nice_outdoor_patio', 5),
#  ('brunch_santa_barbara', 5),
#  ('egg_fried_chicken', 5),
#  ('eggs_benedict_salmon', 5),
#  ('best_pizza_ever', 5),
#  ('bread_oat_bakery', 5),
#  ('best_bread_ive', 5),
#  ('look_forward_going', 4),
#  ('take_one_home', 4),
#  ('first_cat_cafe', 4),
#  ('im_santa_barbara', 4),
#  ('santa_barbara_one', 4),
#  ('well_taken_care', 4),
#  ('definitely_recommend_place', 4),
#  ('passing_santa_barbara', 4),
#  ('place_good_food', 4),
#  ('rose_matcha_rose', 4),
#  ('back_try_drinks', 4),
#  ('delicious_staff_friendly', 4),
#  ('place_first_time', 4),
#  ('ill_back_try', 4),
#  ('bela_rose_matcha', 4),
#  ('definitely_come_again', 4),
#  ('stop_every_time', 4),
#  ('every_time_im', 4),
#  ('favorite_coffee_spot', 4),
#  ('go_back_every', 4),
#  ('street_parking_around', 4),
#  ('coffee_shop_ever', 4),
#  ('best_coffee_ive', 4),
#  ('places_santa_barbara', 4),
#  ('today_first_time', 4),
#  ('parking_street_parking', 4),
#  ('matcha_rose_latte', 4),
#  ('stop_santa_barbara', 4),
#  ('highly_recommend_it', 4),
#  ('coming_back_try', 4),
#  ('excellent_customer_service', 4),
#  ('love_love_love', 4),
#  ('cold_brew_coffee', 4),
#  ('delicious_cant_wait', 4),
#  ('write_home_about', 4),
#  ('good_avocado_toast', 4),
#  ('santa_barbara_day', 4),
#  ('get_work_done', 4),
#  ('got_ta_try', 4),
#  ('cute_coffee_shop', 4),
#  ('coffee_oat_milk', 4),
#  ('probably_coming_back', 4),
#  ('chocolate_chip_cookie', 4),
#  ('staff_always_friendly', 4),
#  ('keep_coming_back', 4),
#  ('outside_seating_area', 4),
#  ('santa_barbara_good', 4),
#  ('love_place_great', 4),
#  ('shop_cafe_great', 4),
#  ('carnitas_eggs_benedict', 4),
#  ('basically_eggs_benedict', 4),
#  ('chicken_dark_meat', 4),
#  ('smoked_tomato_spread', 4),
#  ('spot_breakfast_lunch', 4),
#  ('french_press_coffee', 4),
#  ('great_breakfast_place', 4),
#  ('order_food_window', 4),
#  ('time_im_area', 4),
#  ('santa_barbara_brunch', 4),
#  ('one_best_breakfast', 4),
#  ('santa_barbara_shop', 4),
#  ('fried_chicken_breast', 4),
#  ('food_really_good', 4),
#  ('jean_claude_van', 4),
#  ('home_made_biscuits', 4),
#  ('order_window_get', 4),
#  ('topped_fried_chicken', 4),
#  ('recommend_place_food', 4),
#  ('window_find_seat', 4),
#  ('housemade_almond_butter', 4),
#  ('good_food_great', 4),
#  ('like_fried_chicken', 4),
#  ('chicken_little_dry', 4),
#  ('spot_order_counter', 4),
#  ('egg_benedict_fried', 4),
#  ('indoor_seating_area', 4),
#  ('great_place_eat', 4),
#  ('tugboat_maple_bacon', 4),
#  ('tip_tritip_sandwich', 4),
#  ('fried_chicken_gravy', 4),
#  ('dill_creme_fraiche', 4),
#  ('fried_chicken_good', 4),
#  ('santa_barbara_come', 4),
#  ('bananas_yo_face', 4),
#  ('perfectly_poached_eggs', 4),
#  ('order_window_sit', 4),
#  ('got_french_toast', 4),
#  ('boat_fried_chicken', 4),
#  ('soft_poached_egg', 4),
#  ('try_everything_menu', 4),
#  ('egg_white_scramble', 4),
#  ('really_good_food', 4),
#  ('great_spot_brunch', 4),
#  ('food_great_service', 4),
#  ('eggs_benedict_tugboat', 4),
#  ('banana_almond_butter', 4),
#  ('eggs_benedict_chicken', 4),
#  ('chicken_perfectly_crisp', 4),
#  ('outdoor_patio_seating', 4),
#  ('french_toast_good', 4),
#  ('great_place_brunch', 4),
#  ('good_french_toast', 4),
#  ('ordered_salmon_toast', 4),
#  ('benedict_ive_ever', 4),
#  ('spots_santa_barbara', 4),
#  ('time_were_santa', 4),
#  ('give_place_try', 4),
#  ('would_go_back', 4),
#  ('delicious_eggs_benedict', 4),
#  ('mango_pomelo_sago', 4),
#  ('bread_santa_barbara', 4),
#  ('super_seed_bread', 4),
#  ('truffle_cream_cheese', 4),
#  ('truffle_cashew_cream', 4),
#  ('cashew_cream_cheese', 4),
#  ('love_cat_therapy', 3),
#  ('go_coffee_shop', 3),
#  ('cats_available_adoption', 3),
#  ('vacationing_santa_barbara', 3),
#  ('cat_therapy_wonderful', 3),
#  ('thanks_cat_therapy', 3),
#  ('next_time_town', 3),
#  ('can_not_wait', 3),
#  ('amazing_place_great', 3),
#  ('places_like_this', 3),
#  ('best_place_ever', 3),
#  ('could_give_stars', 3),
#  ('place_cant_wait', 3),
#  ('cant_wait_visit', 3),
#  ('taken_care_of', 3),
#  ('love_place_much', 3),
#  ('highly_recommend_checking', 3),
#  ('cat_cafe_visit', 3),
#  ('cats_different_ages', 3),
#  ('different_ages_breeds', 3),
#  ('enjoyed_place_much', 3),
#  ('amazing_cant_wait', 3),
#  ('looking_adopt_cat', 3),
#  ('absolutely_loved_visit', 3),
#  ('thanks_great_time', 3),
#  ('come_back_santa', 3),
#  ('good_cup_coffee', 3),
#  ('environment_super_cool', 3),
#  ('let_start_saying', 3),
#  ('want_go_back', 3),
#  ('really_wanted_like', 3),
#  ('wanted_like_place', 3),
#  ('good_food_good', 3),
#  ('super_friendly_helpful', 3),
#  ('favorite_coffee_shop', 3),
#  ('rose_matcha_latte', 3),
#  ('came_back_next', 3),
#  ('tried_place_first', 3),
#  ('house_made_almond', 3),
#  ('made_almond_milk', 3),
#  ('almond_milk_latte', 3),
#  ('local_coffee_shop', 3),
#  ('outdoor_seating_available', 3),
#  ('totally_worth_it', 3),
#  ('ordered_bela_rose', 3),
#  ('try_specialty_drinks', 3),
#  ('bagel_cream_cheese', 3),
#  ('activated_charcoal_ginger', 3),
#  ('definitely_worth_try', 3),
#  ('im_glad_tried', 3),
#  ('came_first_time', 3),
#  ('sugarwood_lavished_love', 3),
#  ('live_santa_barbara', 3),
#  ('ginger_salt_rim', 3),
#  ('made_us_feel', 3),
#  ('ordered_matcha_latte', 3),
#  ('could_give_place', 3),
#  ('santa_barbara_weekend', 3),
#  ('coffee_tea_drinks', 3),
#  ('drinks_pricier_side', 3),
#  ('great_place_stop', 3),
#  ('amazing_highly_recommend', 3),
#  ('vanilla_latte_oat', 3),
#  ('time_im_santa', 3),
#  ('santa_barbara_people', 3),
#  ('probably_come_back', 3),
#  ('first_time_today', 3),
#  ('barbara_one_best', 3),
#  ('maybe_next_time', 3),
#  ('lived_santa_barbara', 3),
#  ('santa_barbara_id', 3),
#  ('new_favorite_spot', 3),
#  ('best_coffee_ever', 3),
#  ('santa_barbara_great', 3),
#  ('gem_santa_barbara', 3),
#  ('santa_barbara_ive', 3),
#  ('really_good_also', 3),
#  ('coffee_shop_town', 3),
#  ('perfect_amount_sweetness', 3),
#  ('first_time_santa', 3),
#  ('never_anything_like', 3),
#  ('homemade_almond_milk', 3),
#  ('good_portion_size', 3),
#  ('portion_size_average', 3),
#  ('size_average_service', 3),
#  ('service_order_counter', 3),
#  ('must_try_place', 3),
#  ('time_visiting_santa', 3),
#  ('definitely_going_back', 3),
#  ('perfect_santa_barbara', 3),
#  ('santa_barbara_saw', 3),
#  ('moving_santa_barbara', 3),
#  ('also_top_notch', 3),
#  ('delicious_highly_recommend', 3),
#  ('ive_ever_seen', 3),
#  ('sweetened_condensed_milk', 3),
#  ('went_back_next', 3),
#  ('since_first_time', 3),
#  ('back_try_everything', 3),
#  ('nothing_write_home', 3),
#  ('delicious_service_quick', 3),
#  ('definitely_place_would', 3),
#  ('favorite_santa_barbara', 3),
#  ('great_place_grab', 3),
#  ('every_time_go', 3),
#  ('plenty_seating_inside', 3),
#  ('every_time_ive', 3),
#  ('try_rest_menu', 3),
#  ('great_service_great', 3),
#  ('find_santa_barbara', 3),
#  ('fancy_avocado_toast', 3),
#  ('recommend_checking_place', 3),
#  ('ordered_cold_brew', 3),
#  ('delicious_also_got', 3),
#  ('villa_wine_bar', 3),
#  ('vanilla_latte_delicious', 3),
#  ('it_definitely_come', 3),
#  ('delicious_avocado_toast', 3),
#  ('friendly_food_delicious', 3),
#  ('new_coffee_shop', 3),
#  ('cool_little_spot', 3),
#  ('seating_inside_outside', 3),
#  ('outdoor_seating_dog', 3),
#  ('seating_dog_friendly', 3),
#  ('food_items_menu', 3),
#  ('chocolate_chip_cookies', 3),
#  ('good_local_coffee', 3),
#  ('friendly_staff_amazing', 3),
#  ('coffee_shop_goleta', 3),
#  ('outdoor_seating_staff', 3),
#  ('seating_staff_always', 3),
#  ('indoor_seating_great', 3),
#  ('friendly_staff_nice', 3),
#  ('well_worth_it', 3),
#  ('give_another_chance', 3),
#  ('nice_outdoor_seating', 3),
#  ('would_definitely_return', 3),
#  ('ordered_tugboat_eggs', 3),
#  ('credit_card_receipt', 3),
#  ('super_friendly_food', 3),
#  ('back_try_rest', 3),
#  ('ever_santa_barbara', 3),
#  ('santa_barbara_again', 3),
#  ('food_love_place', 3),
#  ('place_great_food', 3),
#  ('food_great_coffee', 3),
#  ('breakfast_lunch_place', 3),
#  ('always_fresh_delicious', 3),
#  ('justin_yo_face', 3),
#  ('poached_eggs_salmon', 3),
#  ('options_santa_barbara', 3),
#  ('santa_barbara_decided', 3),
#  ('general_sanders_sandwich', 3),
#  ('yo_face_salmon', 3),
#  ('dog_friendly_too', 3),
#  ('biscuits_sausage_gravy', 3),
#  ('sausage_gravy_fried', 3),
#  ('self_serve_water', 3),
#  ('food_came_quickly', 3),
#  ('delicious_outdoor_seating', 3),
#  ('place_breakfast_brunch', 3),
#  ('fried_chicken_looked', 3),
#  ('next_time_santa', 3),
#  ('service_great_food', 3),
#  ('dog_friendly_patio', 3),
#  ('best_ever_had', 3),
#  ('scrambled_eggs_bacon', 3),
#  ('eggs_bacon_avocado', 3),
#  ('roasted_tomato_sauce', 3),
#  ('eggs_toast_avocado', 3),
#  ('homemade_almond_butter', 3),
#  ('almond_butter_bananas', 3),
#  ('breakfast_spot_sb', 3),
#  ('sweet_maria_sandwich', 3),
#  ('bacon_fried_chicken', 3),
#  ('would_order_again', 3),
#  ('ordered_salmon_yo', 3),
#  ('got_best_damn', 3),
#  ('almond_butter_banana', 3),
#  ('buttermilk_biscuit_topped', 3),
#  ('biscuit_topped_fried', 3),
#  ('fried_chicken_sausage', 3),
#  ('chicken_sausage_gravy', 3),
#  ('toast_housemade_almond', 3),
#  ('came_saturday_morning', 3),
#  ('split_fried_chicken', 3),
#  ('location_great_outdoor', 3),
#  ('eggs_benedict_w', 3),
#  ('try_something_else', 3),
#  ('best_breakfast_ive', 3),
#  ('veggie_eggs_benedict', 3),
#  ('want_sit_outside', 3),
#  ('next_time_go', 3),
#  ('eggs_benedict_also', 3),
#  ('eggs_cooked_perfectly', 3),
#  ('fried_chicken_little', 3),
#  ('fried_chicken_cooked', 3),
#  ('ordered_sweet_maria', 3),
#  ('went_first_time', 3),
#  ('got_salmon_yo', 3),
#  ('smoked_tomato_sauce', 3),
#  ('cute_little_spot', 3),
#  ('order_counter_bring', 3),
#  ('counter_bring_food', 3),
#  ('loved_it_definitely', 3),
#  ('try_things_menu', 3),
#  ('wasabi_creme_fraiche', 3),
#  ('open_breakfast_lunch', 3),
#  ('real_maple_syrup', 3),
#  ('salmon_poached_egg', 3),
#  ('heard_great_things', 3),
#  ('almond_butter_honey', 3),
#  ('come_back_every', 3),
#  ('back_every_time', 3),
#  ('great_little_spot', 3),
#  ('tip_tri_tip', 3),
#  ('sandwich_caramelized_onions', 3),
#  ('earth_would_ever', 3),
#  ('would_ever_want', 3),
#  ('ever_want_eat', 3),
#  ('want_eat_breakfast', 3),
#  ('eat_breakfast_girlfriend', 3),
#  ('breakfast_girlfriend_went', 3),
#  ('girlfriend_went_breakfast', 3),
#  ('went_breakfast_woman', 3),
#  ('breakfast_woman_took', 3),
#  ('woman_took_order', 3),
#  ('took_order_friendlier', 3),
#  ('order_friendlier_yes', 3),
#  ('friendlier_yes_im', 3),
#  ('yes_im_sarcastic', 3),
#  ('im_sarcastic_ordered', 3),
#  ('sarcastic_ordered_food', 3),
#  ('ordered_food_window', 3),
#  ('food_window_acting', 3),
#  ('window_acting_important', 3),
#  ('acting_important_things', 3),
#  ('important_things_serve', 3),
#  ('things_serve_us', 3),
#  ('serve_us_apparently', 3),
#  ('us_apparently_customers', 3),
#  ('apparently_customers_important', 3),
#  ('customers_important_here', 3),
#  ('important_here_ordered', 3),
#  ('here_ordered_chicken', 3),
#  ('ordered_chicken_gravy', 3),
#  ('chicken_gravy_biscuits', 3),
#  ('potatoes_bacon_side', 3),
#  ('bacon_side_dishes', 3),
#  ('side_dishes_came', 3),
#  ('dishes_came_first', 3),
#  ('thing_menu_bacon', 3),
#  ('menu_bacon_even', 3),
#  ('bacon_even_getting', 3),
#  ('even_getting_silverware', 3),
#  ('getting_silverware_hassle', 3),
#  ('silverware_hassle_person', 3),
#  ('hassle_person_decent', 3),
#  ('person_decent_us', 3),
#  ('decent_us_smiling', 3),
#  ('us_smiling_woman', 3),
#  ('smiling_woman_cleaning', 3),
#  ('promptly_provided_us', 3),
#  ('provided_us_box', 3),
#  ('us_box_honestly', 3),
#  ('box_honestly_ate', 3),
#  ('honestly_ate_hour', 3),
#  ('ate_hour_ago', 3),
#  ('hour_ago_feel', 3),
#  ('ago_feel_gross', 3),
#  ('feel_gross_sluggish', 3),
#  ('gross_sluggish_sb', 3),
#  ('sluggish_sb_restaurant', 3),
#  ('sb_restaurant_trying', 3),
#  ('restaurant_trying_hard', 3),
#  ('trying_hard_like', 3),
#  ('hard_like_la', 3),
#  ('like_la_nice', 3),
#  ('la_nice_try', 3),
#  ('nice_try_even', 3),
#  ('try_even_similar', 3),
#  ('even_similar_restaurants', 3),
#  ('similar_restaurants_la', 3),
#  ('restaurants_la_better', 3),
#  ('la_better_service', 3),
#  ('better_service_items', 3),
#  ('service_items_menu', 3),
#  ('items_menu_definitely', 3),
#  ('menu_definitely_worth', 3),
#  ('definitely_worth_it', 3),
#  ('seating_friendly_staff', 3),
#  ('biscuits_fried_chicken', 3),
#  ('worth_it_great', 3),
#  ('tug_boat_salmon', 3),
#  ('biscuit_instead_english', 3),
#  ('instead_english_muffin', 3),
#  ('food_highly_recommend', 3),
#  ('fried_chicken_absolutely', 3),
#  ('poached_eggs_perfect', 3),
#  ('eggs_benedict_ever', 3),
#  ('one_best_brunch', 3),
#  ('maria_grilled_chicken', 3),
#  ('santa_barbara_days', 3),
#  ('go_back_next', 3),
#  ('santa_barbara_looking', 3),
#  ('fast_friendly_service', 3),
#  ('right_next_tire', 3),
#  ('delicious_mac_crack', 3),
#  ('order_counter_take', 3),
#  ('breakfast_next_time', 3),
#  ('try_place_out', 3),
#  ('grilled_buttermilk_biscuit', 3),
#  ('food_outdoor_seating', 3),
#  ('place_amazing_food', 3),
#  ('eggs_benedict_got', 3),
#  ('got_fried_chicken', 3),
#  ('poached_eggs_smoked', 3),
#  ('eggs_smoked_tomato', 3),
#  ('really_good_too', 3),
#  ('back_try_menu', 3),
#  ('chicken_good_much', 3),
#  ('fried_chicken_avocado', 3),
#  ('favorite_places_town', 3),
#  ('santa_barbara_it', 3),
#  ('place_food_good', 3),
#  ('eggs_perfectly_cooked', 3),
#  ('santa_barbara_best', 3),
#  ('day_really_good', 3),
#  ('get_banana_toast', 3),
#  ('fun_creative_menu', 3),
#  ('general_sanders_chicken', 3),
#  ('food_delivered_table', 3),
#  ('smoked_salmon_good', 3),
#  ('eggs_fried_chicken', 3),
#  ('smoked_salmon_poached', 3),
#  ('time_im_town', 3),
#  ('coffee_really_good', 3),
#  ('eggs_benedict_homemade', 3),
#  ('eggs_benedict_looked', 3),
#  ('good_eggs_benedict', 3),
#  ('side_bacon_potatoes', 3),
#  ('outdoor_seating_cute', 3),
#  ('food_reasonable_price', 3),
#  ('fried_chicken_poached', 3),
#  ('dog_friendly_well', 3),
#  ('santa_barbara_never', 3),
#  ('smoked_salmon_toast', 3),
#  ('came_santa_barbara', 3),
#  ('chilaquiles_eggs_benedict', 3),
#  ('finely_chopped_almonds', 3),
#  ('looking_forward_coming', 3),
#  ('place_dog_friendly', 3),
#  ('breakfast_brunch_lunch', 3),
#  ('eggs_benedict_ive', 3),
#  ('coming_back_next', 3),
#  ('ordered_tugboat_chicken', 3),
#  ('breakfast_lunch_options', 3),
#  ('fried_chicken_fried', 3),
#  ('forward_coming_back', 3),
#  ('place_next_time', 3),
#  ('great_brunch_place', 3),
#  ('food_great_find', 3),
#  ('frenchie_grilled_french', 3),
#  ('grilled_french_toast', 3),
#  ('toast_added_bacon', 3),
#  ('santa_barbara_breakfast', 3),
#  ('place_eat_santa', 3),
#  ('eat_santa_barbara', 3),
#  ('small_indoor_area', 3),
#  ('house_made_bread', 3),
#  ('great_spot_breakfast', 3),
#  ('spot_beaten_path', 3),
#  ('one_absolute_favorite', 3),
#  ('everything_pretty_good', 3),
#  ('would_go_way', 3),
#  ('one_fried_chicken', 3),
#  ('santa_barbara_goleta', 3),
#  ('fried_chicken_tug', 3),
#  ('chicken_tug_boat', 3),
#  ('fried_egg_fried', 3),
#  ('oolong_milk_tea', 3),
#  ('salmon_tug_boat', 3),
#  ('milk_tea_boba', 3),
#  ('street_parking_available', 3),
#  ('tug_boat_fried', 3),
#  ('guava_fruit_tea', 3),
#  ('honor_bar_menu', 3),
#  ('honor_market_amazing', 3),
#  ('pizza_ever_had', 3),
#  ('bakery_santa_barbara', 3),
#  ('almond_date_bread', 3),
#  ('time_would_highly', 2),
#  ('forward_going_back', 2),
#  ('coffee_shop_could', 2),
#  ('cat_therapy_cafe', 2),
#  ('would_much_rather', 2),
#  ('time_cat_therapy', 2),
#  ('yelp_check_in', 2),
#  ('cats_come_local', 2),
#  ('come_local_shelters', 2),
#  ('comfortable_environment_cats', 2),
#  ('kitty_home_cat', 2),
#  ('anyone_looking_cat', 2),
#  ('different_types_cats', 2),
#  ('play_adorable_cats', 2),
#  ('cafe_next_door', 2),
#  ('not_wait_go', 2),
#  ('go_back_went', 2),
#  ('coming_back_again', 2),
#  ('back_again_absolutely', 2),
#  ('again_absolutely_amazing', 2),
#  ('im_huge_cat', 2),
#  ('great_even_though', 2),
#  ('coffee_something_really', 2),
#  ('go_inside_sit', 2),
#  ('fall_love_one', 2),
#  ('get_take_home', 2),
#  ('go_back_recommend', 2),
#  ('family_time_left', 2),
#  ('experience_highly_recommend', 2),
#  ('well_worth_wait', 2),
#  ('well_definitely_back', 2),
#  ('sweet_wish_could', 2),
#  ('way_spend_afternoon', 2),
#  ('love_place_many', 2),
#  ('atmosphere_cant_wait', 2),
#  ('tell_really_care', 2),
#  ('much_fun_cats', 2),
#  ('feel_like_need', 2),
#  ('cats_well_taken', 2),
#  ('visited_first_time', 2),
#  ('free_coffee_tea', 2),
#  ('great_time_cat', 2),
#  ('wish_could_adopt', 2),
#  ('fun_unique_experience', 2),
#  ('cats_enjoyed_place', 2),
#  ('love_rescue_animals', 2),
#  ('rescue_animals_desperate', 2),
#  ('animals_desperate_need', 2),
#  ('desperate_need_help', 2),
#  ('need_help_adopt', 2),
#  ('help_adopt_many', 2),
#  ('adopt_many_cats', 2),
#  ('many_cats_place', 2),
#  ('cafe_visit_highly', 2),
#  ('visit_highly_recommendedhour', 2),
#  ('highly_recommendedhour_free', 2),
#  ('recommendedhour_free_tea', 2),
#  ('free_tea_coffee', 2),
#  ('tea_coffee_dozen', 2),
#  ('coffee_dozen_cats', 2),
#  ('dozen_cats_different', 2),
#  ('ages_breeds_ask', 2),
#  ('breeds_ask_food', 2),
#  ('ask_food_give', 2),
#  ('food_give_cats', 2),
#  ('give_cats_nuts', 2),
#  ('cats_nuts_kittens', 2),
#  ('nuts_kittens_adorable', 2),
#  ('kittens_adorable_definitely', 2),
#  ('adorable_definitely_unique', 2),
#  ('definitely_unique_experience', 2),
#  ('unique_experience_take', 2),
#  ('experience_take_friends', 2),
#  ('take_friends_family', 2),
#  ('friends_family_to', 2),
#  ('family_to_would', 2),
#  ('to_would_return', 2),
#  ('would_return_sure', 2),
#  ('owner_super_sweet', 2),
#  ('cat_cafe_think', 2),
#  ('play_area_cats', 2),
#  ('found_place_accident', 2),
#  ('around_long_time', 2),
#  ('high_kill_shelters', 2),
#  ('staff_extremely_nice', 2),
#  ('adopt_cat_would', 2),
#  ('coffee_also_really', 2),
#  ('good_definitely_worth', 2),
#  ('coming_santa_barbara', 2),
#  ('santa_barbara_since', 2),
#  ('cat_person_visit', 2),
#  ('brasil_arts_cafe', 2),
#  ('loved_visit_here', 2),
#  ('cats_ages_sizes', 2),
#  ('place_adopt_sweet', 2),
#  ('visit_amazing_place', 2),
#  ('fun_place_chill', 2),
#  ('adopt_one_cat', 2),
#  ('definitely_go_again', 2),
#  ('staff_really_nice', 2),
#  ('would_also_recommend', 2),
#  ('amazing_place_coffee', 2),
#  ('coffee_delicious_matcha', 2),
#  ('friendly_helpful_great', 2),
#  ('great_menu_selection', 2),
#  ('offer_go_cups', 2),
#  ('delicious_coffee_drinks', 2),
#  ('best_matcha_ever', 2),
#  ('matcha_ever_had', 2),
#  ('amazing_avocado_toast', 2),
#  ('bread_really_nice', 2),
#  ('isla_vista_location', 2),
#  ('single_use_cups', 2),
#  ('reusable_ceramic_cup', 2),
#  ('boyfriend_got_yemen', 2),
#  ('staff_incredibly_kind', 2),
#  ('amazing_place_good', 2),
#  ('outside_seating_nice', 2),
#  ('friendly_helpful_well', 2),
#  ('santa_barbara_ambiance', 2),
#  ('make_sure_give', 2),
#  ('sit_enjoy_drink', 2),
#  ('going_back_try', 2),
#  ('try_drinks_menu', 2),
#  ('bela_rose_jupiters', 2),
#  ('rose_jupiters_forest', 2),
#  ('excited_get_taste', 2),
#  ('get_taste_amazing', 2),
#  ('taste_amazing_coffee', 2),
#  ('amazing_coffee_drinks', 2),
#  ('coffee_drinks_finally', 2),
#  ('drinks_finally_did', 2),
#  ('finally_did_ordered', 2),
#  ('did_ordered_burnout', 2),
#  ('ordered_burnout_loved', 2),
#  ('burnout_loved_much', 2),
#  ('loved_much_came', 2),
#  ('much_came_back', 2),
#  ('next_day_more', 2),
#  ('day_more_also', 2),
#  ('more_also_ordered', 2),
#  ('also_ordered_avocado', 2),
#  ('ordered_avocado_toast', 2),
#  ('avocado_toast_think', 2),
#  ('toast_think_best', 2),
#  ('think_best_ive', 2),
#  ('ever_life_officially', 2),
#  ('life_officially_new', 2),
#  ('officially_new_local', 2),
#  ('new_local_favorite', 2),
#  ('local_favorite_spot', 2),
#  ('favorite_spot_us', 2),
#  ('spot_us_every', 2),
#  ('us_every_person', 2),
#  ('every_person_brought', 2),
#  ('person_brought_feels', 2),
#  ('brought_feels_same', 2),
#  ('feels_same_cant', 2),
#  ('same_cant_wait', 2),
#  ('cant_wait_check', 2),
#  ('wait_check_speakeasy', 2),
#  ('check_speakeasy_nighttime', 2),
#  ('speakeasy_nighttime_bar', 2),
#  ('nighttime_bar_scene', 2),
#  ('place_really_good', 2),
#  ('really_good_coffee', 2),
#  ('im_huge_fan', 2),
#  ('fan_caje_iv', 2),
#  ('coffee_drinks_also', 2),
#  ('try_one_craft', 2),
#  ('rosemary_thai_tea', 2),
#  ('nice_crunchy_crust', 2),
#  ('delicious_house_made', 2),
#  ('toast_favorite_part', 2),
#  ('back_next_trip', 2),
#  ('bourbon_pecan_syrup', 2),
#  ('milk_oat_milk', 2),
#  ('it_highly_recommend', 2),
#  ('see_im_talking', 2),
#  ('im_talking_about', 2),
#  ('rose_matcha_infused', 2),
#  ('simple_coffee_drinker', 2),
#  ('place_like_this', 2),
#  ('one_signature_drinks', 2),
#  ('cheap_certainly_worth', 2),
#  ('got_avocado_toast', 2),
#  ('area_would_definitely', 2),
#  ('see_creative_menu', 2),
#  ('highly_recommend_come', 2),
#  ('drink_ive_ever', 2),
#  ('ive_ever_gotten', 2),
#  ('can_not_stop', 2),
#  ('moved_santa_barbara', 2),
#  ('santa_barbara_definitely', 2),
#  ('staff_nice_enough', 2),
#  ('super_cute_location', 2),
#  ('loved_it_im', 2),
#  ('almond_milk_good', 2),
#  ('santa_barbara_try', 2),
#  ('visited_santa_barbara', 2),
#  ('great_coffee_shop', 2),
#  ('coffee_shop_make', 2),
#  ('bustle_state_street', 2),
#  ('want_try_something', 2),
#  ('staff_friendly_coffee', 2),
#  ('cant_wait_back', 2),
#  ('good_simple_espresso', 2),
#  ('glad_tried_out', 2),
#  ('one_best_coffee', 2),
#  ('new_favorite_coffee', 2),
#  ('avocado_toast_must', 2),
#  ('toast_must_try', 2),
#  ('bela_rose_drink', 2),
#  ('drink_also_ordered', 2),
#  ('staff_super_sweet', 2),
#  ('little_bit_pricey', 2),
#  ('ever_had_definitely', 2),
#  ('find_good_coffee', 2),
#  ('great_friendly_service', 2),
#  ('well_back_try', 2),
#  ('really_unique_drinks', 2),
#  ('beautiful_unique_coffee', 2),
#  ('give_try_im', 2),
#  ('try_im_glad', 2),
#  ('wish_lived_closer', 2),
#  ('grab_bite_eat', 2),
#  ('shop_super_clean', 2),
#  ('ordered_sugarwood_lavished', 2),
#  ('coffee_spot_santa', 2),
#  ('coffee_shop_like', 2),
#  ('id_love_come', 2),
#  ('high_quality_ingredients', 2),
#  ('cocktail_bar_coffee', 2),
#  ('definitely_would_recommend', 2),
#  ('us_feel_comfortable', 2),
#  ('best_matcha_latte', 2),
#  ('perfect_amount_sweet', 2),
#  ('many_coffee_places', 2),
#  ('almond_milk_made', 2),
#  ('milk_made_house', 2),
#  ('never_coffee_drink', 2),
#  ('go_back_best', 2),
#  ('avocado_toast_amazing', 2),
#  ('totally_recommend_place', 2),
#  ('perfect_balance_sweetness', 2),
#  ('make_sure_eat', 2),
#  ('shop_next_door', 2),
#  ('tasty_coffee_nice', 2),
#  ('cafe_santa_barbara', 2),
#  ('coffee_great_customer', 2),
#  ('service_highly_recommend', 2),
#  ('highly_recommend_coffee', 2),
#  ('spot_go_to', 2),
#  ('grab_quick_coffee', 2),
#  ('speakeasy_bar_night', 2),
#  ('mill_haley_st', 2),
#  ('order_average_coffee', 2),
#  ('like_delicious_coffee', 2),
#  ('best_coffee_santa', 2),
#  ('coffee_santa_barbara', 2),
#  ('supporting_local_businesses', 2),
#  ('got_vanilla_latte', 2),
#  ('good_service_great', 2),
#  ('huge_fan_coffee', 2),
#  ('jupiters_forest_burnout', 2),
#  ('delicious_coffee_also', 2),
#  ('drink_coffee_sit', 2),
#  ('one_specialty_drinks', 2),
#  ('back_several_times', 2),
#  ('every_single_time', 2),
#  ('avocado_toast_delicious', 2),
#  ('id_definitely_recommend', 2),
#  ('ive_ever_to', 2),
#  ('food_looked_great', 2),
#  ('make_almond_milk', 2),
#  ('barista_super_nice', 2),
#  ('super_nice_too', 2),
#  ('cajé_coffee_roasters', 2),
#  ('love_coffee_shop', 2),
#  ('omg_best_coffee', 2),
#  ('coffee_ever_had', 2),
#  ('probably_best_ive', 2),
#  ('ever_had_burnout', 2),
#  ('tea_drinks_santa', 2),
#  ('drinks_santa_barbara', 2),
#  ('santa_barbara_also', 2),
#  ('well_staff_friendly', 2),
#  ('service_great_really', 2),
#  ('found_place_sooner', 2),
#  ('enjoy_cup_coffee', 2),
#  ('served_cocktail_glass', 2),
#  ('four_shots_espresso', 2),
#  ('great_coffee_great', 2),
#  ('coffee_great_food', 2),
#  ('toast_really_good', 2),
#  ('service_always_friendly', 2),
#  ('amount_outdoor_seating', 2),
#  ('went_today_first', 2),
#  ('get_studying_done', 2),
#  ('love_trying_new', 2),
#  ('ive_tried_different', 2),
#  ('located_right_next', 2),
#  ('avocado_toast_looks', 2),
#  ('back_try_another', 2),
#  ('coffee_cant_wait', 2),
#  ('try_avocado_toast', 2),
#  ('service_top_notch', 2),
#  ('service_even_better', 2),
#  ('average_service_order', 2),
#  ('make_signature_drinks', 2),
#  ('signature_drinks_told', 2),
#  ('best_santa_barbara', 2),
#  ('first_time_there', 2),
#  ('fries_really_good', 2),
#  ...]

# %% [markdown]
# ### Breakfast

# %%
Breakfast = business_df[business_df.Type=='Breakfast']
Breakfast_review = review1[review1.business_id.isin(Breakfast.business_id.values)]
Breakfast_review["text"] = Breakfast_review["text"].str.lower()
Breakfast_review['text'] = Breakfast_review['text'].apply(lambda text: cleaning_stopwords(text))
Breakfast_review['text']= Breakfast_review['text'].apply(lambda x: cleaning_punctuations(x))
Breakfast_review['text'] = Breakfast_review['text'].apply(lambda x: cleaning_repeating_char(x))
Breakfast_review['text'] = Breakfast_review['text'].apply(lambda x: cleaning_URLs(x))
Breakfast_review['text'] = Breakfast_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Breakfast=Breakfast[Breakfast.stars<3.5]
bad_Breakfast_review = Breakfast_review[Breakfast_review.business_id.isin(bad_Breakfast.business_id.values)]
bad_Breakfast_review_text = bad_Breakfast_review.text.str.cat(sep = " ")
bad_Breakfast_tokens = word_tokenize(bad_Breakfast_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_bad_Breakfast = ["_".join(item) for item in nltk.bigrams(bad_Breakfast_tokens)]
trigrams_list_bad_Breakfast = ["_".join(item) for item in nltk.trigrams(bad_Breakfast_tokens)]
FreqDist(bigrams_list_bad_Breakfast).most_common()
# FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('santa_barbara', 31),
#  ('hash_browns', 27),
#  ('customer_service', 16),
#  ('eggs_benedict', 16),
#  ('good_food', 15),
#  ('great_service', 14),
#  ('french_toast', 12),
#  ('food_good', 12),
#  ('food_service', 11),
#  ('one_star', 11),
#  ('came_back', 11),
#  ('even_though', 10),
#  ('across_street', 10),
#  ('service_great', 10),
#  ('orange_juice', 9),
#  ('good_service', 9),
#  ('tasted_like', 9),
#  ('come_back', 9),
#  ('coming_back', 9),
#  ('go_back', 9),
#  ('patio_cafe', 9),
#  ('friendly_service', 8),
#  ('thank_you', 8),
#  ('waited_minutes', 8),
#  ('got_food', 8),
#  ('ive_never', 8),
#  ('staff_friendly', 8),
#  ('horrible_service', 8),
#  ('right_away', 8),
#  ('chain_restaurant', 8),
#  ('first_time', 8),
#  ('every_time', 7),
#  ('always_good', 7),
#  ('poached_eggs', 7),
#  ('great_food', 7),
#  ('long_time', 7),
#  ('drink_order', 7),
#  ('food_delicious', 7),
#  ('ordered_chicken', 7),
#  ('im_sure', 7),
#  ('sunday_morning', 7),
#  ('food_mediocre', 7),
#  ('mom_pop', 7),
#  ('waiter_said', 6),
#  ('waiter_nice', 6),
#  ('breakfast_food', 6),
#  ('cup_coffee', 6),
#  ('check_us', 6),
#  ('go_ihop', 6),
#  ('love_ihop', 6),
#  ('service_food', 6),
#  ('food_came', 6),
#  ('right_next', 6),
#  ('feel_like', 6),
#  ('time_food', 6),
#  ('pumpkin_pancakes', 6),
#  ('pretty_good', 6),
#  ('place_eat', 6),
#  ('years_ago', 6),
#  ('free_pancakes', 6),
#  ('eggs_bacon', 5),
#  ('typical_ihop', 5),
#  ('took_minutes', 5),
#  ('decided_go', 5),
#  ('place_clean', 5),
#  ('fried_steak', 5),
#  ('eggs_hash', 5),
#  ('worst_service', 5),
#  ('ihop_great', 5),
#  ('ihop_food', 5),
#  ('like_ihop', 5),
#  ('next_time', 5),
#  ('said_would', 5),
#  ('minutes_later', 5),
#  ('would_like', 5),
#  ('took_long', 5),
#  ('never_came', 5),
#  ('food_took', 5),
#  ('pancakes_eggs', 5),
#  ('definitely_back', 5),
#  ('saturday_morning', 5),
#  ('excellent_service', 5),
#  ('stack_pancakes', 5),
#  ('happy_hour', 5),
#  ('chicken_sandwich', 5),
#  ('really_good', 5),
#  ('great_place', 5),
#  ('breakfast_lunch', 5),
#  ('asked_waiter', 5),
#  ('nothing_special', 5),
#  ('food_great', 5),
#  ('bloody_marys', 5),
#  ('hit_spot', 4),
#  ('placed_order', 4),
#  ('iced_coffee', 4),
#  ('much_better', 4),
#  ('clean_friendly', 4),
#  ('breakfast_place', 4),
#  ('minus_one', 4),
#  ('one_thing', 4),
#  ('worst_experience', 4),
#  ('several_times', 4),
#  ('harvest_grain', 4),
#  ('clam_chowder', 4),
#  ('sent_back', 4),
#  ('received_food', 4),
#  ('ever_came', 4),
#  ('ihop_again', 4),
#  ('breakfast_places', 4),
#  ('bad_reviews', 4),
#  ('take_order', 4),
#  ('love_pancakes', 4),
#  ('terrible_service', 4),
#  ('peanut_butter', 4),
#  ('grilled_cheese', 4),
#  ('well_food', 4),
#  ('visit_ihop', 4),
#  ('ordered_food', 4),
#  ('food_arrived', 4),
#  ('decided_leave', 4),
#  ('never_coming', 4),
#  ('back_again', 4),
#  ('would_give', 4),
#  ('give_place', 4),
#  ('food_even', 4),
#  ('turkey_sandwich', 4),
#  ('server_never', 4),
#  ('order_taken', 4),
#  ('speak_manager', 4),
#  ('food_really', 4),
#  ('late_night', 4),
#  ('service_decided', 4),
#  ('also_ordered', 4),
#  ('said_ok', 4),
#  ('onion_rings', 4),
#  ('wait_staff', 4),
#  ('super_friendly', 4),
#  ('good_place', 4),
#  ('friendly_attentive', 4),
#  ('delicious_food', 4),
#  ('decided_get', 4),
#  ('minutes_get', 4),
#  ('far_best', 4),
#  ('definitely_go', 4),
#  ('back_ihop', 4),
#  ('fast_service', 4),
#  ('manager_chris', 4),
#  ('food_ok', 4),
#  ('dining_experience', 4),
#  ('anything_else', 4),
#  ('ihop_restaurant', 4),
#  ('outdoor_seating', 4),
#  ('people_watching', 4),
#  ('asked_waitress', 4),
#  ('server_great', 4),
#  ('somewhere_else', 4),
#  ('would_come', 4),
#  ('made_sure', 4),
#  ('biscuits_gravy', 4),
#  ('biscuit_gravy', 4),
#  ('cafe_shell', 4),
#  ('ihop_carpinteria', 4),
#  ('chocolate_pancakes', 3),
#  ('pancakes_ihop', 3),
#  ('something_else', 3),
#  ('stars_would', 3),
#  ('worth_it', 3),
#  ('it_came', 3),
#  ('good_meal', 3),
#  ('restaurant_like', 3),
#  ('get_good', 3),
#  ('food_decent', 3),
#  ('quick_service', 3),
#  ('speak_english', 3),
#  ('ordered_pancakes', 3),
#  ('felt_like', 3),
#  ('service_slow', 3),
#  ('food_okay', 3),
#  ('consistently_good', 3),
#  ('los_angeles', 3),
#  ('apple_juice', 3),
#  ('ever_go', 3),
#  ('service_excellent', 3),
#  ('one_state', 3),
#  ('state_st', 3),
#  ('going_back', 3),
#  ('yummy_breakfast', 3),
#  ('service_horrible', 3),
#  ('really_needs', 3),
#  ('everyone_else', 3),
#  ('everything_great', 3),
#  ('service_ever', 3),
#  ('one_time', 3),
#  ('even_get', 3),
#  ('get_one', 3),
#  ('grain_pancakes', 3),
#  ('time_ihop', 3),
#  ('side_salad', 3),
#  ('home_cooked', 3),
#  ('calle_real', 3),
#  ('came_check', 3),
#  ('us_wanted', 3),
#  ('never_go', 3),
#  ('scrambled_eggs', 3),
#  ('everything_else', 3),
#  ('breakfast_dinner', 3),
#  ('better_breakfast', 3),
#  ('time_go', 3),
#  ('want_come', 3),
#  ('food_amazing', 3),
#  ('ever_to', 3),
#  ('ihop_one', 3),
#  ('eggs_sausage', 3),
#  ('good_too', 3),
#  ('told_waiter', 3),
#  ('eaten_ihop', 3),
#  ('nice_enough', 3),
#  ('asked_could', 3),
#  ('half_hour', 3),
#  ('ten_minutes', 3),
#  ('third_time', 3),
#  ('waitress_came', 3),
#  ('without_paying', 3),
#  ('stay_business', 3),
#  ('eat_here', 3),
#  ('staring_us', 3),
#  ('ihop_deserves', 3),
#  ('can_not', 3),
#  ('left_waiter', 3),
#  ('going_again', 3),
#  ('chicken_fried', 3),
#  ('still_waiting', 3),
#  ('service_ihop', 3),
#  ('great_meal', 3),
#  ('us_right', 3),
#  ('went_ihop', 3),
#  ('place_busy', 3),
#  ('service_good', 3),
#  ('sat_down', 3),
#  ('kids_meals', 3),
#  ('good_breakfast', 3),
#  ('cold_never', 3),
#  ('get_bill', 3),
#  ('extremely_rude', 3),
#  ('ihop_experience', 3),
#  ('service_always', 3),
#  ('front_desk', 3),
#  ('food_always', 3),
#  ('amount_people', 3),
#  ('ihop_santa', 3),
#  ('santa_maria', 3),
#  ('better_service', 3),
#  ('go_again', 3),
#  ('seated_right', 3),
#  ('friendly_food', 3),
#  ('numerous_times', 3),
#  ('light_fluffy', 3),
#  ('nice_service', 3),
#  ('place_breakfast', 3),
#  ('give_stars', 3),
#  ('bad_service', 3),
#  ('wanted_get', 3),
#  ('always_go', 3),
#  ('definitely_coming', 3),
#  ('like_dennys', 3),
#  ('lot_better', 3),
#  ('bacon_eggs', 3),
#  ('looks_like', 3),
#  ('back_thats', 3),
#  ('thats_sure', 3),
#  ('hollandaise_sauce', 3),
#  ('husband_ordered', 3),
#  ('patty_melt', 3),
#  ('food_quality', 3),
#  ('turkey_bacon', 3),
#  ('let_know', 3),
#  ('ive_eaten', 3),
#  ('came_breakfast', 3),
#  ('order_told', 3),
#  ('wave_waiter', 3),
#  ('get_leave', 3),
#  ('told_would', 3),
#  ('three_us', 3),
#  ('got_seated', 3),
#  ('ihop_chain', 3),
#  ('friendly_helpful', 3),
#  ('places_around', 3),
#  ('sit_us', 3),
#  ('best_part', 3),
#  ('make_sure', 3),
#  ('hair_food', 3),
#  ('sure_ihop', 3),
#  ('breakfast_today', 3),
#  ('took_min', 3),
#  ('good_price', 3),
#  ('juice_coffee', 3),
#  ('pancakes_side', 3),
#  ('look_like', 3),
#  ('ihop_would', 3),
#  ('quality_food', 3),
#  ('stopped_breakfast', 3),
#  ('many_years', 3),
#  ('pancakes_great', 3),
#  ('years_old', 3),
#  ('cant_wait', 3),
#  ('great_restaurant', 3),
#  ('service_ok', 3),
#  ('great_friendly', 3),
#  ('food_nothing', 3),
#  ('pancakes_french', 3),
#  ('enjoy_family', 3),
#  ('again_great', 3),
#  ('great_experience', 3),
#  ('worst_ihop', 3),
#  ('manager_came', 3),
#  ('overall_great', 3),
#  ('would_make', 3),
#  ('way_home', 3),
#  ('state_street', 3),
#  ('finish_meal', 3),
#  ('outside_seating', 3),
#  ('grilled_chicken', 3),
#  ('made_feel', 3),
#  ('pancakes_really', 3),
#  ('good_tried', 3),
#  ('little_slow', 3),
#  ('hard_find', 3),
#  ('delicious_breakfast', 3),
#  ('one_best', 3),
#  ('got_breakfast', 3),
#  ('breakfast_burrito', 3),
#  ('trader_joes', 3),
#  ('de_la', 3),
#  ('la_vina', 3),
#  ('service_prompt', 3),
#  ('full_happy', 3),
#  ('santa_barbra', 3),
#  ('food_nice', 3),
#  ('bacon_waffle', 3),
#  ('could_find', 3),
#  ('could_tell', 3),
#  ('huevos_rancheros', 3),
#  ('even_bother', 3),
#  ('breakfast_spot', 3),
#  ('nice_friendly', 3),
#  ('every_day', 3),
#  ('give_us', 3),
#  ('got_eggs', 3),
#  ('ok_service', 3),
#  ('us_back', 3),
#  ('fork_egg', 3),
#  ('egg_it', 3),
#  ('chocolate_milk', 3),
#  ('potato_chips', 3),
#  ('would_return', 3),
#  ('food_cold', 3),
#  ('new_years', 3),
#  ('window_seat', 3),
#  ('server_comes', 2),
#  ('asked_wanted', 2),
#  ('said_no', 2),
#  ('walked_away', 2),
#  ('could_give', 2),
#  ('give_negative', 2),
#  ('negative_stars', 2),
#  ('go_here', 2),
#  ('server_nice', 2),
#  ('nice_helpful', 2),
#  ('helpful_food', 2),
#  ('closing_time', 2),
#  ('ihop_went', 2),
#  ('something_like', 2),
#  ('needed_dinner', 2),
#  ('iced_mocha', 2),
#  ('white_chocolate', 2),
#  ('chocolate_waiter', 2),
#  ('asked_make', 2),
#  ('make_ordered', 2),
#  ('ordered_it', 2),
#  ('it_asked', 2),
#  ('better_said', 2),
#  ('thick_dark', 2),
#  ('brought_water', 2),
#  ('barely_warm', 2),
#  ('know_could', 2),
#  ('like_this', 2),
#  ('manager_get', 2),
#  ('location_again', 2),
#  ('hit_miss', 2),
#  ('sometimes_get', 2),
#  ('ihop_clean', 2),
#  ('ihop_really', 2),
#  ('big_chain', 2),
#  ('ihops_times', 2),
#  ('goto_breakfast', 2),
#  ('fixed_quickly', 2),
#  ('sour_cream', 2),
#  ('food_bland', 2),
#  ('nice_little', 2),
#  ('particular_ihop', 2),
#  ('course_pancakes', 2),
#  ('always_orders', 2),
#  ('ihop_offers', 2),
#  ('keep_good', 2),
#  ('good_work', 2),
#  ('literally_worst', 2),
#  ('experience_staff', 2),
#  ('took_two', 2),
#  ('order_go', 2),
#  ('cajun_kitchen', 2),
#  ('coffee_bad', 2),
#  ('leave_never', 2),
#  ('go_awful', 2),
#  ('chain_breakfast', 2),
#  ('sunday_night', 2),
#  ('put_order', 2),
#  ('getting_orders', 2),
#  ('go_ask', 2),
#  ('min_wait', 2),
#  ('order_like', 2),
#  ('never_going', 2),
#  ('want_pay', 2),
#  ('food_way', 2),
#  ('way_expensive', 2),
#  ('really_know', 2),
#  ('know_place', 2),
#  ('food_perfect', 2),
#  ('time_back', 2),
#  ('behind_counter', 2),
#  ('give_up', 2),
#  ('maybe_thats', 2),
#  ('meal_go', 2),
#  ('food_poisoning', 2),
#  ('us_one', 2),
#  ('time_even', 2),
#  ('pancakes_husband', 2),
#  ('service_ive', 2),
#  ('ordered_poached', 2),
#  ('medium_eggs', 2),
#  ('eggs_cooked', 2),
#  ('cooked_perfectly', 2),
#  ('mediocre_ordered', 2),
#  ('back_got', 2),
#  ('asked_side', 2),
#  ('nothing_write', 2),
#  ('write_home', 2),
#  ('home_about', 2),
#  ('myself_would', 2),
#  ('service_kinda', 2),
#  ('hard_time', 2),
#  ('busy_service', 2),
#  ('service_terrible', 2),
#  ('lipstick_cup', 2),
#  ('food_poorly', 2),
#  ('one_ever', 2),
#  ('waiter_get', 2),
#  ('get_check', 2),
#  ('recommend_going', 2),
#  ('far_worst', 2),
#  ('two_groups', 2),
#  ('groups_people', 2),
#  ('walked_seated', 2),
#  ('sat_minutes', 2),
#  ('ask_us', 2),
#  ('wanted_drink', 2),
#  ('barely_cooked', 2),
#  ('sunny_side', 2),
#  ('waiting_food', 2),
#  ('food_ive', 2),
#  ('ihop_today', 2),
#  ('food_ordered', 2),
#  ('time_ago', 2),
#  ('dinner_good', 2),
#  ('always_leave', 2),
#  ('place_bad', 2),
#  ('breakfast_amazing', 2),
#  ('top_everything', 2),
#  ('really_nice', 2),
#  ('lunch_break', 2),
#  ('one_person', 2),
#  ('right_one', 2),
#  ('one_server', 2),
#  ('second_time', 2),
#  ('time_bad', 2),
#  ('coffee_pot', 2),
#  ('inside_cup', 2),
#  ('whole_time', 2),
#  ('manager_said', 2),
#  ('egg_whites', 2),
#  ('experience_ever', 2),
#  ('told_wanted', 2),
#  ('refused_give', 2),
#  ('worst_place', 2),
#  ('place_worst', 2),
#  ('said_hi', 2),
#  ('asked_drink', 2),
#  ('brought_drinks', 2),
#  ('drinks_took', 2),
#  ('took_order', 2),
#  ('cheese_steak', 2),
#  ('made_good', 2),
#  ('eat_ihop', 2),
#  ('never_disappointed', 2),
#  ('hash_brown', 2),
#  ('older_gentlemen', 2),
#  ('wow_ihop', 2),
#  ('could_made', 2),
#  ('right_across', 2),
#  ('ihop_years', 2),
#  ('know_expect', 2),
#  ('ok_food', 2),
#  ('food_quick', 2),
#  ('good_quick', 2),
#  ('minutes_without', 2),
#  ('one_minute', 2),
#  ('another_minutes', 2),
#  ('restaurant_busy', 2),
#  ('busy_all', 2),
#  ('one_table', 2),
#  ('table_us', 2),
#  ('poor_service', 2),
#  ('bill_go', 2),
#  ('charged_us', 2),
#  ('us_like', 2),
#  ('first_drink', 2),
#  ('drink_orders', 2),
#  ('work_food', 2),
#  ('food_come', 2),
#  ('could_see', 2),
#  ('toast_one', 2),
#  ('really_feel', 2),
#  ('time_toast', 2),
#  ('us_asked', 2),
#  ('got_one', 2),
#  ('later_grabbed', 2),
#  ('two_people', 2),
#  ('one_them', 2),
#  ('away_without', 2),
#  ('refill_it', 2),
#  ('made_mistakes', 2),
#  ('satisfied_service', 2),
#  ('left_without', 2),
#  ('believe_name', 2),
#  ('super_sweet', 2),
#  ('wish_would', 2),
#  ('read_reviews', 2),
#  ('kept_staring', 2),
#  ('us_food', 2),
#  ('stars_could', 2),
#  ('ihop_state', 2),
#  ('place_stars', 2),
#  ('worse_food', 2),
#  ('server_said', 2),
#  ('time_want', 2),
#  ('want_give', 2),
#  ('give_another', 2),
#  ('another_chance', 2),
#  ('brought_out', 2),
#  ('again_good', 2),
#  ('definitely_better', 2),
#  ('better_dennys', 2),
#  ('slow_service', 2),
#  ('food_arrive', 2),
#  ('something_wrong', 2),
#  ('minutes_arrive', 2),
#  ('tell_us', 2),
#  ('order_waited', 2),
#  ('wanted_speak', 2),
#  ('franchise_manager', 2),
#  ('manager_would', 2),
#  ('back_soon', 2),
#  ('make_things', 2),
#  ('yum_yum', 2),
#  ('never_seen', 2),
#  ('long_wait', 2),
#  ('near_freeway', 2),
#  ('really_great', 2),
#  ('would_definitely', 2),
#  ('would_take', 2),
#  ('hour_later', 2),
#  ('later_asked', 2),
#  ('asked_would', 2),
#  ('said_oh', 2),
#  ('never_called', 2),
#  ('sat_us', 2),
#  ('screaming_kids', 2),
#  ('free_pancake', 2),
#  ('even_eat', 2),
#  ('eat_food', 2),
#  ('came_late', 2),
#  ('dinner_place', 2),
#  ('down_ordered', 2),
#  ('chicken_salad', 2),
#  ('breakfast_time', 2),
#  ('pancakes_ordered', 2),
#  ('bacon_pancakes', 2),
#  ('side_toast', 2),
#  ('im_small', 2),
#  ('id_say', 2),
#  ('clean_food', 2),
#  ('breakfast_get', 2),
#  ('whipped_cream', 2),
#  ('pretty_empty', 2),
#  ('comes_asks', 2),
#  ('water_im', 2),
#  ('food_comes', 2),
#  ('thought_would', 2),
#  ('coffee_it', 2),
#  ('never_got', 2),
#  ('water_even', 2),
#  ('separate_checks', 2),
#  ('ready_pay', 2),
#  ('pay_leave', 2),
#  ('average_ihop', 2),
#  ('food_done', 2),
#  ('location_really', 2),
#  ('stopped_ihop', 2),
#  ('conveniently_located', 2),
#  ('could_use', 2),
#  ('morning_husband', 2),
#  ('always_great', 2),
#  ('past_weekend', 2),
#  ('stopped_place', 2),
#  ('place_packed', 2),
#  ('hostess_said', 2),
#  ('hostess_seated', 2),
#  ('see_name', 2),
#  ('seated_us', 2),
#  ('n_hour', 2),
#  ('me_manager', 2),
#  ('let_start', 2),
#  ('start_saying', 2),
#  ('came_one', 2),
#  ('say_ihop', 2),
#  ('shyt_put', 2),
#  ('put_one', 2),
#  ('portions_santa', 2),
#  ('brown_sugar', 2),
#  ('asked_for', 2),
#  ('good_also', 2),
#  ('kids_menu', 2),
#  ('know_bad', 2),
#  ('ive_ever', 2),
#  ('never_even', 2),
#  ('needed_anything', 2),
#  ('terrible_terrible', 2),
#  ('stay_away', 2),
#  ('skipped_us', 2),
#  ('low_quality', 2),
#  ('food_short', 2),
#  ('amount_time', 2),
#  ('food_ihop', 2),
#  ('ihop_good', 2),
#  ('decided_try', 2),
#  ('got_chicken', 2),
#  ('flavor_good', 2),
#  ('go_one', 2),
#  ('roach_crawling', 2),
#  ('needless_say', 2),
#  ('ihop_location', 2),
#  ('again_went', 2),
#  ('went_sunday', 2),
#  ('clean_one', 2),
#  ('took_forever', 2),
#  ('get_coffee', 2),
#  ('seating_us', 2),
#  ('eat_again', 2),
#  ('staff_always', 2),
#  ('lunch_dinner', 2),
#  ('go_way', 2),
#  ('come_eat', 2),
#  ('waitress_patient', 2),
#  ('decent_service', 2),
#  ('id_give', 2),
#  ('turned_away', 2),
#  ('went_dennys', 2),
#  ('food_place', 2),
#  ('food_us', 2),
#  ('ask_refill', 2),
#  ('brought_us', 2),
#  ('wan_na', 2),
#  ('delicious_pancakes', 2),
#  ('best_ihop', 2),
#  ('best_place', 2),
#  ('black_coffee', 2),
#  ('coffee_already', 2),
#  ('husband_wanted', 2),
#  ('get_ihop', 2),
#  ('asked_new', 2),
#  ('back_check', 2),
#  ('coffee_even', 2),
#  ('check_place', 2),
#  ('place_out', 2),
#  ('out_definitely', 2),
#  ('nice_food', 2),
#  ('cooked_meal', 2),
#  ('service_asked', 2),
#  ('breakfast_morning', 2),
#  ('looked_like', 2),
#  ('like_regular', 2),
#  ('english_muffin', 2),
#  ('ask_waiter', 2),
#  ('sharper_knife', 2),
#  ('use_restroom', 2),
#  ('son_ended', 2),
#  ('heading_back', 2),
#  ('take_food', 2),
#  ('staff_first', 2),
#  ('birthday_stack', 2),
#  ('pictures_menu', 2),
#  ('pancakes_service', 2),
#  ('service_friendly', 2),
#  ('took_us', 2),
#  ('upon_entering', 2),
#  ('ordered_turkey', 2),
#  ('french_roll', 2),
#  ('house_pancakes', 2),
#  ('clean_good', 2),
#  ('pancakes_disappoint', 2),
#  ('negative_reviews', 2),
#  ('timely_manner', 2),
#  ('zero_stars', 2),
#  ('family_came', 2),
#  ('host_comes', 2),
#  ('person_restaurant', 2),
#  ('comes_back', 2),
#  ('food_order', 2),
#  ('wed_enough', 2),
#  ('waiter_walked', 2),
#  ('nodded_head', 2),
#  ('head_walked', 2),
#  ('room_temperature', 2),
#  ('waiter_took', 2),
#  ('ate_anyway', 2),
#  ('anyway_never', 2),
#  ('coffee_tasted', 2),
#  ('craving_ihop', 2),
#  ('ihop_pancakes', 2),
#  ('even_offer', 2),
#  ('ihop_ever', 2),
#  ('came_fast', 2),
#  ('never_ask', 2),
#  ('coffee_orange', 2),
#  ('steak_tips', 2),
#  ('experience_though', 2),
#  ('service_waiter', 2),
#  ('got_right', 2),
#  ('us_got', 2),
#  ('food_asked', 2),
#  ('minutes_never', 2),
#  ('get_food', 2),
#  ('location_far', 2),
#  ('minutes_already', 2),
#  ('nice_well', 2),
#  ('great_waiter', 2),
#  ('gave_us', 2),
#  ('went_downhill', 2),
#  ('sat_right', 2),
#  ('ignored_us', 2),
#  ('time_get', 2),
#  ('get_us', 2),
#  ('service_worth', 2),
#  ('morning_breakfast', 2),
#  ('staff_nice', 2),
#  ('coffee_fresh', 2),
#  ('never_ending', 2),
#  ('ordered_even', 2),
#  ('busy_waitress', 2),
#  ('stop_breakfast', 2),
#  ('theres_always', 2),
#  ('mom_waitress', 2),
#  ('waitress_brought', 2),
#  ('got_new', 2),
#  ('new_cup', 2),
#  ('next_us', 2),
#  ('another_customer', 2),
#  ('server_took', 2),
#  ('greet_us', 2),
#  ('us_said', 2),
#  ('seemed_like', 2),
#  ('food_wrong', 2),
#  ('disappointed_service', 2),
#  ('here_try', 2),
#  ('disgrace_ihop', 2),
#  ('family_dining', 2),
#  ('eating_great', 2),
#  ('morning_family', 2),
#  ('experience_food', 2),
#  ('time_came', 2),
#  ('came_us', 2),
#  ('barbara_staff', 2),
#  ('needs_new', 2),
#  ('found_hair', 2),
#  ('gave_one', 2),
#  ('took_care', 2),
#  ('great_buddy', 2),
#  ('best_ive', 2),
#  ('mushroom_onion', 2),
#  ('full_flavor', 2),
#  ('pancakes_good', 2),
#  ('good_great', 2),
#  ('place_great', 2),
#  ('sandwich_onion', 2),
#  ('mashed_potatoes', 2),
#  ('anything_order', 2),
#  ('could_accommodate', 2),
#  ('diced_tomatoes', 2),
#  ('min_order', 2),
#  ('attitude_never', 2),
#  ('around_pm', 2),
#  ('ihop_always', 2),
#  ('hot_breakfast', 2),
#  ('breakfast_good', 2),
#  ('sat_patio', 2),
#  ('cool_morning', 2),
#  ('looking_good', 2),
#  ('choice_breakfast', 2),
#  ('breakfast_two', 2),
#  ('came_ihop', 2),
#  ('crepes_pancakes', 2),
#  ('roasted_potatoes', 2),
#  ('dusts_there', 2),
#  ('there_asked', 2),
#  ('new_water', 2),
#  ('wife_ordered', 2),
#  ('browns_overcooked', 2),
#  ('served_time', 2),
#  ('visit_santa', 2),
#  ('place_even', 2),
#  ('today_get', 2),
#  ('side_ham', 2),
#  ('get_breakfast', 2),
#  ('way_start', 2),
#  ('start_day', 2),
#  ('would_never', 2),
#  ('hole_walls', 2),
#  ('good_coffee', 2),
#  ('even_think', 2),
#  ('would_put', 2),
#  ('said_yes', 2),
#  ('service_industry', 2),
#  ('sweet_creamcheese', 2),
#  ('creamcheese_filled', 2),
#  ('filled_crape', 2),
#  ('two_strips', 2),
#  ('strips_bacon', 2),
#  ('whip_cream', 2),
#  ('glass_orange', 2),
#  ('pretty_bad', 2),
#  ('really_hungry', 2),
#  ('eat_it', 2),
#  ('poor_quality', 2),
#  ('food_still', 2),
#  ('nice_day', 2),
#  ('long_long', 2),
#  ('would_rather', 2),
#  ('rather_waited', 2),
#  ('barbara_hands', 2),
#  ('best_breakfast', 2),
#  ('employees_like', 2),
#  ('year_old', 2),
#  ('last_week', 2),
#  ('week_vacation', 2),
#  ('around_santa', 2),
#  ('breakfast_ordered', 2),
#  ('crawling_around', 2),
#  ('bill_left', 2),
#  ('pancakes_said', 2),
#  ('pancakes_would', 2),
#  ('came_from', 2),
#  ('barbara_again', 2),
#  ('bbq_burger', 2),
#  ('average_food', 2),
#  ('took_five', 2),
#  ('five_minutes', 2),
#  ('always_consistent', 2),
#  ('eggs_california', 2),
#  ('service_fast', 2),
#  ('around_giant', 2),
#  ('tree_years', 2),
#  ('middle_restaurant', 2),
#  ('chain_restaurants', 2),
#  ('even_better', 2),
#  ('coffee_waters', 2),
#  ('service_definitely', 2),
#  ('cheese_sandwich', 2),
#  ('friendly_efficient', 2),
#  ('yr_old', 2),
#  ('something_inside', 2),
#  ('could_please', 2),
#  ('ihop_around', 2),
#  ('fig_tree', 2),
#  ('service_manager', 2),
#  ('wait_come', 2),
#  ('yelp_shows', 2),
#  ('turned_us', 2),
#  ('us_away', 2),
#  ('highly_disappointed', 2),
#  ('ihop_life', 2),
#  ('ok_nothing', 2),
#  ('ordered_breakfast', 2),
#  ('breakfast_sampler', 2),
#  ('pancakes_fluffy', 2),
#  ('chicken_florentine', 2),
#  ('came_swimming', 2),
#  ('swimming_oil', 2),
#  ('service_really', 2),
#  ('hungry_pancake', 2),
#  ('pancake_loving', 2),
#  ('loving_kids', 2),
#  ('kids_good', 2),
#  ('good_chain', 2),
#  ('restaurant_you', 2),
#  ('you_consistently', 2),
#  ('special_granddaughters', 2),
#  ('granddaughters_love', 2),
#  ('toast_nutella', 2),
#  ('nutella_bring', 2),
#  ('bring_side', 2),
#  ('side_fruit', 2),
#  ('fruit_request', 2),
#  ('request_staff', 2),
#  ('staff_attentive', 2),
#  ('attentive_request', 2),
#  ('request_great', 2),
#  ('great_house', 2),
#  ('house_salsa', 2),
#  ('salsa_add', 2),
#  ('add_eggs', 2),
#  ('hurry_enjoy', 2),
#  ('family_time', 2),
#  ('early_said', 2),
#  ('meal_would', 2),
#  ('say_thank', 2),
#  ('ihop_staff', 2),
#  ('well_great', 2),
#  ('fast_food', 2),
#  ('zum_mittagessen', 2),
#  ('us_want', 2),
#  ('back_thank', 2),
#  ('better_get', 2),
#  ('right_front', 2),
#  ('kitchen_area', 2),
#  ('area_where', 2),
#  ('little_bit', 2),
#  ('service_even', 2),
#  ('amazing_service', 2),
#  ('nice_even', 2),
#  ('im_glad', 2),
#  ('almost_immediately', 2),
#  ('recommend_eating', 2),
#  ('ice_vanilla', 2),
#  ('vanilla_coffee', 2),
#  ('even_tho', 2),
#  ('regular_ice', 2),
#  ('ice_coffee', 2),
#  ('one_favorite', 2),
#  ('table_ordered', 2),
#  ('light_ice', 2),
#  ('lunch_tomorrow', 2),
#  ('bleu_cheese', 2),
#  ('cheese_dressing', 2),
#  ('around_town', 2),
#  ('could_get', 2),
#  ('guess_thats', 2),
#  ('many_places', 2),
#  ('service_staff', 2),
#  ('recommend_place', 2),
#  ('nice_breakfast', 2),
#  ('eat_somewhere', 2),
#  ('went_today', 2),
#  ('unfortunately_food', 2),
#  ('say_anything', 2),
#  ('typical_chain', 2),
#  ('restaurant_quality', 2),
#  ('outdoor_patio', 2),
#  ('clean_up', 2),
#  ('ihop_id', 2),
#  ('definitely_recommend', 2),
#  ('one_goleta', 2),
#  ('ihop_many', 2),
#  ('one_free', 2),
#  ('today_day', 2),
#  ('free_food', 2),
#  ('since_changed', 2),
#  ('mens_room', 2),
#  ('us_sat', 2),
#  ('came_table', 2),
#  ('table_one', 2),
#  ('one_place', 2),
#  ('welcome_ihop', 2),
#  ('please_get', 2),
#  ('decent_place', 2),
#  ('place_overall', 2),
#  ('place_another', 2),
#  ('food_awesome', 2),
#  ('everyones_needs', 2),
#  ('tried_new', 2),
#  ('coupon_free', 2),
#  ('service_little', 2),
#  ...]

# %%
good_Breakfast=Breakfast[Breakfast.stars>=3.5]
good_Breakfast_review = Breakfast_review[Breakfast_review.business_id.isin(good_Breakfast.business_id.values)]
good_Breakfast_review_text = good_Breakfast_review.text.str.cat(sep = " ")
good_Breakfast_tokens = word_tokenize(good_Breakfast_review_text)
# FreqDist(good_American_tokens).most_common()
bigrams_list_good_Breakfast = ["_".join(item) for item in nltk.bigrams(good_Breakfast_tokens)]
trigrams_list_good_Breakfast = ["_".join(item) for item in nltk.trigrams(good_Breakfast_tokens)]
# FreqDist(bigrams_list_good_Breakfast).most_common()
FreqDist(trigrams_list_good_Breakfast).most_common()
# Out:
# [('corned_beef_hash', 202),
#  ('chicken_fried_steak', 112),
#  ('lemon_ricotta_pancakes', 85),
#  ('ive_ever_had', 75),
#  ('definitely_come_back', 74),
#  ('food_great_service', 65),
#  ('corn_beef_hash', 57),
#  ('worker_bee_cafe', 57),
#  ('great_food_great', 53),
#  ('service_great_food', 51),
#  ('chocolate_chip_muffins', 46),
#  ('would_definitely_come', 43),
#  ('would_come_back', 43),
#  ('food_really_good', 41),
#  ('cajun_kitchen_cafe', 40),
#  ('definitely_coming_back', 40),
#  ('cant_go_wrong', 40),
#  ('food_good_service', 40),
#  ('would_highly_recommend', 39),
#  ('next_time_im', 39),
#  ('visiting_santa_barbara', 38),
#  ('would_definitely_recommend', 36),
#  ('food_pretty_good', 36),
#  ('back_next_time', 36),
#  ('crab_cake_benedict', 35),
#  ('visit_santa_barbara', 34),
#  ('eggs_hash_browns', 34),
#  ('best_ive_ever', 34),
#  ('highly_recommend_place', 34),
#  ('california_eggs_benedict', 33),
#  ('maple_bacon_biscuit', 33),
#  ('great_service_great', 31),
#  ('service_good_food', 31),
#  ('wait_go_back', 31),
#  ('cant_wait_go', 30),
#  ('definitely_go_back', 30),
#  ('across_street_beach', 30),
#  ('great_place_breakfast', 28),
#  ('breakfast_santa_barbara', 28),
#  ('santa_barbara_omelette', 27),
#  ('fried_chicken_benedict', 26),
#  ('downtown_santa_barbara', 26),
#  ('good_food_good', 26),
#  ('potato_skin_hash', 26),
#  ('endless_summer_scramble', 26),
#  ('beef_hash_eggs', 25),
#  ('great_breakfast_spot', 25),
#  ('de_la_vina', 24),
#  ('seated_right_away', 24),
#  ('trip_santa_barbara', 24),
#  ('santa_barbara_area', 23),
#  ('would_go_back', 23),
#  ('santa_barbara_food', 23),
#  ('staff_super_friendly', 23),
#  ('really_good_food', 23),
#  ('come_back_try', 23),
#  ('santa_barbara_breakfast', 22),
#  ('ordered_shrimp_grits', 22),
#  ('spot_santa_barbara', 22),
#  ('gluten_free_options', 22),
#  ('right_across_beach', 22),
#  ('brioche_french_toast', 21),
#  ('back_santa_barbara', 21),
#  ('ordered_french_toast', 21),
#  ('great_customer_service', 21),
#  ('wait_come_back', 21),
#  ('place_santa_barbara', 21),
#  ('well_worth_it', 20),
#  ('im_santa_barbara', 20),
#  ('crab_cakes_benedict', 20),
#  ('great_food_service', 20),
#  ('favorite_breakfast_place', 19),
#  ('chocolate_chip_pancakes', 19),
#  ('place_great_food', 19),
#  ('ordered_eggs_benedict', 19),
#  ('cant_wait_come', 19),
#  ('santa_barbara_omelet', 19),
#  ('soft_scrambled_eggs', 19),
#  ('food_came_quickly', 18),
#  ('indoor_outdoor_seating', 18),
#  ('come_back_next', 18),
#  ('right_across_street', 18),
#  ('highly_recommend_it', 18),
#  ('made_us_feel', 18),
#  ('great_service_food', 17),
#  ('country_fried_steak', 17),
#  ('next_time_were', 17),
#  ('would_recommend_place', 17),
#  ('good_service_good', 17),
#  ('good_food_great', 17),
#  ('shrimp_po_boy', 16),
#  ('best_breakfast_place', 16),
#  ('great_service_good', 16),
#  ('recommend_place_anyone', 16),
#  ('definitely_recommend_place', 16),
#  ('gluten_free_pancakes', 16),
#  ('mini_chocolate_chip', 16),
#  ('blueberry_chocolate_chip', 16),
#  ('staff_friendly_attentive', 15),
#  ('one_favorite_places', 15),
#  ('homemade_corned_beef', 15),
#  ('red_beans_rice', 15),
#  ('great_breakfast_place', 15),
#  ('would_definitely_go', 15),
#  ('food_delicious_service', 15),
#  ('fried_steak_eggs', 15),
#  ('got_breakfast_burrito', 15),
#  ('omelette_hash_browns', 15),
#  ('go_back_try', 15),
#  ('time_im_town', 15),
#  ('found_place_yelp', 15),
#  ('write_home_about', 14),
#  ('best_breakfast_ever', 14),
#  ('service_amazing_food', 14),
#  ('love_cajun_kitchen', 14),
#  ('service_really_good', 14),
#  ('staff_always_friendly', 14),
#  ('time_santa_barbara', 14),
#  ('cant_say_enough', 14),
#  ('time_im_santa', 14),
#  ('beautiful_santa_barbara', 14),
#  ('service_bit_slow', 14),
#  ('never_came_back', 14),
#  ('nothing_write_home', 13),
#  ('good_service_great', 13),
#  ('service_quick_friendly', 13),
#  ('come_back_again', 13),
#  ('santa_barbara_weekend', 13),
#  ('ordered_fried_chicken', 13),
#  ('one_favorite_breakfast', 13),
#  ('favorite_breakfast_spot', 13),
#  ('every_time_go', 13),
#  ('service_little_slow', 13),
#  ('came_hash_browns', 13),
#  ('ordered_breakfast_burrito', 13),
#  ('french_toast_combo', 13),
#  ('brunch_santa_barbara', 13),
#  ('best_ever_had', 13),
#  ('ordered_corned_beef', 13),
#  ('food_friendly_service', 13),
#  ('ordered_fig_burger', 13),
#  ('complimentary_mini_muffins', 13),
#  ('basket_mini_muffins', 13),
#  ('way_start_day', 12),
#  ('hash_browns_good', 12),
#  ('service_friendly_attentive', 12),
#  ('one_best_breakfast', 12),
#  ('want_come_back', 12),
#  ('santa_barbara_place', 12),
#  ('overall_great_experience', 12),
#  ('beef_hash_good', 12),
#  ('side_hash_browns', 12),
#  ('ive_long_time', 12),
#  ('came_santa_barbara', 12),
#  ('great_food_good', 12),
#  ('next_time_visit', 12),
#  ('best_corned_beef', 12),
#  ('really_wanted_like', 12),
#  ('go_santa_barbara', 12),
#  ('dog_friendly_patio', 12),
#  ('great_food_friendly', 11),
#  ('great_way_start', 11),
#  ('ive_ever_seen', 11),
#  ('places_santa_barbara', 11),
#  ('special_scrambled_eggs', 11),
#  ('service_pretty_good', 11),
#  ('ordered_chicken_fried', 11),
#  ('crispy_hash_browns', 11),
#  ('food_great_staff', 11),
#  ('strawberries_whipped_cream', 11),
#  ('food_friendly_staff', 11),
#  ('food_excellent_service', 11),
#  ('way_santa_barbara', 11),
#  ('santa_barbara_location', 11),
#  ('squeezed_orange_juice', 11),
#  ('good_food_friendly', 11),
#  ('staff_great_food', 11),
#  ('first_time_here', 11),
#  ('beef_hash_benedict', 11),
#  ('table_next_us', 11),
#  ('old_school_diner', 11),
#  ('great_view_beach', 11),
#  ('im_glad_did', 11),
#  ('french_toast_amazing', 11),
#  ('service_top_notch', 11),
#  ('service_excellent_food', 11),
#  ('hash_browns_pancakes', 11),
#  ('took_long_time', 11),
#  ('short_rib_benedict', 11),
#  ('food_great_prices', 10),
#  ('ordered_huevos_rancheros', 10),
#  ('eggs_cooked_perfectly', 10),
#  ('crab_cake_eggs', 10),
#  ('cake_eggs_benedict', 10),
#  ('ordered_corn_beef', 10),
#  ('love_place_great', 10),
#  ('best_ive_had', 10),
#  ('come_santa_barbara', 10),
#  ('fried_chicken_waffles', 10),
#  ('food_came_fast', 10),
#  ('put_name_list', 10),
#  ('try_something_new', 10),
#  ('love_love_love', 10),
#  ('really_enjoyed_it', 10),
#  ('go_back_again', 10),
#  ('good_diner_food', 10),
#  ('food_absolutely_delicious', 10),
#  ('outside_soft_inside', 10),
#  ('best_breakfast_spot', 10),
#  ('definitely_worth_it', 10),
#  ('fast_friendly_service', 10),
#  ('definitely_going_back', 10),
#  ('great_place_eat', 10),
#  ('friendly_staff_great', 10),
#  ('let_start_saying', 10),
#  ('friendly_service_great', 10),
#  ('decided_give_try', 10),
#  ('good_corned_beef', 10),
#  ('cute_little_place', 10),
#  ('every_time_im', 10),
#  ('breakfast_worker_bee', 10),
#  ('ive_ever_tasted', 10),
#  ('place_great_service', 10),
#  ('taken_care_of', 10),
#  ('labor_day_weekend', 10),
#  ('stop_santa_barbara', 10),
#  ('well_definitely_back', 10),
#  ('santa_barbara_great', 10),
#  ('fresh_squeezed_oj', 10),
#  ('breakfast_place_santa', 10),
#  ('small_parking_lot', 10),
#  ('santa_barbara_came', 10),
#  ('good_highly_recommend', 10),
#  ('ordered_santa_barbara', 10),
#  ('fried_chicken_sandwich', 10),
#  ('fig_cream_cheese', 10),
#  ('mini_muffins_give', 10),
#  ('go_somewhere_else', 9),
#  ('breakfast_cajun_kitchen', 9),
#  ('food_always_good', 9),
#  ('first_come_first', 9),
#  ('got_chicken_fried', 9),
#  ('really_hit_spot', 9),
#  ('santa_claus_lane', 9),
#  ('outdoor_seating_area', 9),
#  ('food_fresh_tasty', 9),
#  ('two_poached_eggs', 9),
#  ('great_place_brunch', 9),
#  ('came_check_us', 9),
#  ('shrimp_n_grits', 9),
#  ('favorite_brunch_spot', 9),
#  ('hash_browns_toast', 9),
#  ('check_place_out', 9),
#  ('looking_forward_trying', 9),
#  ('service_fast_friendly', 9),
#  ('definitely_worth_wait', 9),
#  ('hash_browns_bacon', 9),
#  ('good_coffee_good', 9),
#  ('made_feel_like', 9),
#  ('customer_service_great', 9),
#  ('decided_try_place', 9),
#  ('hash_browns_delicious', 9),
#  ('took_drink_order', 9),
#  ('service_delicious_food', 9),
#  ('great_staff_friendly', 9),
#  ('wait_another_minutes', 9),
#  ('best_breakfast_burritos', 9),
#  ('wait_worth_it', 9),
#  ('id_come_back', 9),
#  ('within_walking_distance', 9),
#  ('coconut_french_toast', 9),
#  ('fresh_squeezed_orange', 9),
#  ('hash_browns_crispy', 9),
#  ('cute_little_restaurant', 9),
#  ('delicious_food_great', 9),
#  ('raisin_french_toast', 9),
#  ('really_really_good', 9),
#  ('super_friendly_staff', 9),
#  ('love_place_food', 9),
#  ('go_back_next', 9),
#  ('restaurant_santa_barbara', 9),
#  ('two_egg_breakfast', 9),
#  ('restaurants_santa_barbara', 9),
#  ('crunchy_french_toast', 9),
#  ('baja_fish_tacos', 9),
#  ('santa_barbara_day', 9),
#  ('yukon_gold_cinnamon', 9),
#  ('chocolate_chip_blueberry', 9),
#  ('shrimp_andouille_grits', 8),
#  ('french_toast_delicious', 8),
#  ('great_service_even', 8),
#  ('french_quarter_omelette', 8),
#  ('french_toast_pancakes', 8),
#  ('great_food_nice', 8),
#  ('gem_santa_barbara', 8),
#  ('overall_great_place', 8),
#  ('give_place_try', 8),
#  ('well_worth_wait', 8),
#  ('cheese_choice_toast', 8),
#  ('choice_toast_potatoes', 8),
#  ('shrimp_andouille_sausage', 8),
#  ('really_good_too', 8),
#  ('eggs_benedict_good', 8),
#  ('seated_within_minutes', 8),
#  ('good_service_excellent', 8),
#  ('service_great_everyone', 8),
#  ('let_us_know', 8),
#  ('also_really_good', 8),
#  ('go_cajun_kitchen', 8),
#  ('would_give_stars', 8),
#  ('time_were_town', 8),
#  ('great_place_get', 8),
#  ('good_french_toast', 8),
#  ('benedict_french_toast', 8),
#  ('best_eggs_benedict', 8),
#  ('way_like_it', 8),
#  ('friendly_food_delicious', 8),
#  ('looking_breakfast_place', 8),
#  ('came_saturday_morning', 8),
#  ('favorite_place_breakfast', 8),
#  ('great_place_go', 8),
#  ('come_back_here', 8),
#  ('pancakes_french_toast', 8),
#  ('highly_recommend_restaurant', 8),
#  ('cant_wait_return', 8),
#  ('benedict_hash_browns', 8),
#  ('back_next_day', 8),
#  ('super_friendly_food', 8),
#  ('fried_steak_good', 8),
#  ('family_run_business', 8),
#  ('order_eggs_benedict', 8),
#  ('service_great_too', 8),
#  ('go_wrong_here', 8),
#  ('good_hash_browns', 8),
#  ('return_next_time', 8),
#  ('weve_ever_had', 8),
#  ('come_back_soon', 8),
#  ('gluten_free_french', 8),
#  ('worker_bee_benedict', 8),
#  ('based_yelp_reviews', 8),
#  ('never_come_back', 8),
#  ('amazing_highly_recommend', 8),
#  ('good_breakfast_spot', 8),
#  ('busy_sunday_morning', 8),
#  ('would_definitely_return', 8),
#  ('great_place_great', 8),
#  ('even_though_busy', 8),
#  ('every_time_visit', 8),
#  ('good_customer_service', 8),
#  ('next_time_go', 8),
#  ('long_time_get', 8),
#  ('short_stack_pancakes', 8),
#  ('pico_de_gallo', 8),
#  ('got_eggs_benedict', 8),
#  ('food_quite_good', 8),
#  ('breakfast_spot_santa', 8),
#  ('sb_sunshine_cafe', 8),
#  ('french_toast_eggs', 8),
#  ('little_hard_find', 8),
#  ('sat_outside_patio', 8),
#  ('mac_n_cheese', 8),
#  ('ordered_something_different', 7),
#  ('breakfast_sunday_morning', 7),
#  ('best_breakfast_town', 7),
#  ('friendly_attentive_food', 7),
#  ('got_french_toast', 7),
#  ('make_sure_get', 7),
#  ('new_orleans_omelet', 7),
#  ('wait_minutes_get', 7),
#  ('one_best_ive', 7),
#  ('food_come_out', 7),
#  ('la_vina_location', 7),
#  ('place_breakfast_lunch', 7),
#  ('hash_browns_nice', 7),
#  ('good_would_definitely', 7),
#  ('came_sunday_morning', 7),
#  ('cajun_kitchen_breakfast', 7),
#  ('every_time_ive', 7),
#  ('sunday_morning_brunch', 7),
#  ('really_good_service', 7),
#  ('service_quick_food', 7),
#  ('santa_barbara_again', 7),
#  ('ill_come_back', 7),
#  ('try_something_else', 7),
#  ('next_time_santa', 7),
#  ('food_good_great', 7),
#  ('patio_dog_friendly', 7),
#  ('little_breakfast_spot', 7),
#  ('food_great_price', 7),
#  ('say_enough_good', 7),
#  ('enough_good_things', 7),
#  ('never_go_back', 7),
#  ('breakfast_burrito_bacon', 7),
#  ('cajun_kitchen_one', 7),
#  ('one_favorite_brunch', 7),
#  ('staff_friendly_food', 7),
#  ('super_friendly_service', 7),
#  ('good_cajun_food', 7),
#  ('best_breakfast_burrito', 7),
#  ('atmosphere_great_service', 7),
#  ('santa_barbara_last', 7),
#  ('first_time_eating', 7),
#  ('service_great_staff', 7),
#  ('staff_friendly_helpful', 7),
#  ('french_toast_bacon', 7),
#  ('breakfast_brunch_lunch', 7),
#  ('cajun_kitchen_café', 7),
#  ('first_time_trying', 7),
#  ('hash_browns_best', 7),
#  ('amazing_service_great', 7),
#  ('food_came_out', 7),
#  ('eggs_benedict_crab', 7),
#  ('food_even_better', 7),
#  ('gluten_free_items', 7),
#  ('free_french_toast', 7),
#  ('cute_little_diner', 7),
#  ('hash_poached_eggs', 7),
#  ('beef_hash_ever', 7),
#  ('service_really_great', 7),
#  ('got_cinnamon_roll', 7),
#  ('farm_fresh_eggs', 7),
#  ('crispy_outside_soft', 7),
#  ('far_best_breakfast', 7),
#  ('best_breakfast_ive', 7),
#  ('food_top_notch', 7),
#  ('service_great_friendly', 7),
#  ('food_always_fresh', 7),
#  ('cinnamon_raisin_french', 7),
#  ('customer_service_food', 7),
#  ('recommend_place_great', 7),
#  ('keep_coming_back', 7),
#  ('next_time_town', 7),
#  ('great_service_definitely', 7),
#  ('coming_back_again', 7),
#  ('worst_service_ever', 7),
#  ('took_care_us', 7),
#  ('food_great_location', 7),
#  ('took_minutes_get', 7),
#  ('highly_recommend_great', 7),
#  ('open_breakfast_lunch', 7),
#  ('pretty_good_though', 7),
#  ('vacation_santa_barbara', 7),
#  ('busy_saturday_morning', 7),
#  ('pancakes_shrimp_grits', 7),
#  ('went_santa_barbara', 7),
#  ('kale_caesar_salad', 7),
#  ('can_not_wait', 7),
#  ('pork_belly_hash', 7),
#  ('santa_barbara_definitely', 7),
#  ('banana_coconut_french', 7),
#  ('text_table_ready', 7),
#  ('south_border_omelette', 7),
#  ('drink_order_taken', 6),
#  ('food_great_portions', 6),
#  ('excellent_service_great', 6),
#  ('love_place_breakfast', 6),
#  ('ive_coming_years', 6),
#  ('service_even_better', 6),
#  ('santa_barbara_first', 6),
#  ('good_staff_friendly', 6),
#  ('really_wanted_try', 6),
#  ('here_great_food', 6),
#  ('good_breakfast_place', 6),
#  ('hidden_gem_santa', 6),
#  ('prices_great_service', 6),
#  ('cajun_kitchen_always', 6),
#  ('breakfast_lunch_place', 6),
#  ('love_santa_barbara', 6),
#  ('get_pay_for', 6),
#  ('sunny_side_eggs', 6),
#  ('pretty_darn_good', 6),
#  ('santa_barbara_would', 6),
#  ('minutes_get_table', 6),
#  ('scrambled_eggs_mushrooms', 6),
#  ('really_good_would', 6),
#  ('santa_barbara_stop', 6),
#  ('last_time_went', 6),
#  ('probably_go_back', 6),
#  ('nice_little_spot', 6),
#  ('looking_forward_eating', 6),
#  ('ive_never_seen', 6),
#  ('place_great_breakfast', 6),
#  ('barbara_food_delicious', 6),
#  ('come_back_would', 6),
#  ('staff_really_nice', 6),
#  ('food_huge_portions', 6),
#  ('huge_portions_great', 6),
#  ('got_jambalaya_eggs', 6),
#  ('quick_friendly_service', 6),
#  ('came_pretty_quickly', 6),
#  ('omelette_home_fries', 6),
#  ('best_breakfast_santa', 6),
#  ('many_years_ago', 6),
#  ('always_good_sign', 6),
#  ('new_favorite_breakfast', 6),
#  ('place_grab_breakfast', 6),
#  ('hash_browns_amazing', 6),
#  ('ordered_home_fries', 6),
#  ('hash_browns_tasted', 6),
#  ('browns_tasted_like', 6),
#  ('next_time_ill', 6),
#  ('come_back_place', 6),
#  ('good_things_place', 6),
#  ('good_service_friendly', 6),
#  ('people_waiting_outside', 6),
#  ('ill_definitely_back', 6),
#  ('wheat_germ_pancakes', 6),
#  ('food_santa_barbara', 6),
#  ('perfect_breakfast_spot', 6),
#  ('probably_come_back', 6),
#  ('come_check_us', 6),
#  ('really_good_breakfast', 6),
#  ('best_french_toast', 6),
#  ('horrible_customer_service', 6),
#  ('friendly_staff_highly', 6),
#  ('best_place_breakfast', 6),
#  ('sit_outside_enjoy', 6),
#  ('day_santa_barbara', 6),
#  ('santa_barbara_im', 6),
#  ('eggs_benedict_delicious', 6),
#  ('santa_barbara_brunch', 6),
#  ('good_service_food', 6),
#  ('good_nothing_special', 6),
#  ('santa_barbara_eat', 6),
#  ('service_friendly_fast', 6),
#  ('coffee_cup_never', 6),
#  ('typical_diner_food', 6),
#  ('id_go_back', 6),
#  ('inside_outside_seating', 6),
#  ('really_enjoyed_food', 6),
#  ('spots_santa_barbara', 6),
#  ('two_days_row', 6),
#  ('ive_never_bad', 6),
#  ('brunch_spot_santa', 6),
#  ('gluten_free_bread', 6),
#  ('santa_barbara_love', 6),
#  ('came_across_place', 6),
#  ('everything_else_menu', 6),
#  ('back_good_food', 6),
#  ('food_good_atmosphere', 6),
#  ('took_great_care', 6),
#  ('great_care_us', 6),
#  ('id_definitely_recommend', 6),
#  ('feel_right_home', 6),
#  ('ive_santa_barbara', 6),
#  ('thick_cut_bacon', 6),
#  ('made_eye_contact', 6),
#  ('definitely_stop_again', 6),
#  ('eggs_french_toast', 6),
#  ('breakfast_french_toast', 6),
#  ('service_great_coffee', 6),
#  ('great_service_delicious', 6),
#  ('place_good_food', 6),
#  ('coming_back_next', 6),
#  ('back_next_visit', 6),
#  ('santa_barbara_delicious', 6),
#  ('cant_wait_try', 6),
#  ('outdoor_seating_available', 6),
#  ('one_best_ever', 6),
#  ('great_food_awesome', 6),
#  ('beef_hash_best', 6),
#  ('ive_ever_eaten', 6),
#  ('beef_hash_poached', 6),
#  ('delicious_corned_beef', 6),
#  ('could_give_stars', 6),
#  ('coffee_good_too', 6),
#  ('hour_get_food', 6),
#  ('beef_hash_delicious', 6),
#  ('back_love_place', 6),
#  ('id_recommend_place', 6),
#  ('beef_hash_great', 6),
#  ('make_feel_welcome', 6),
#  ('super_friendly_attentive', 6),
#  ('fresh_baked_muffins', 6),
#  ('told_us_would', 6),
#  ('san_luis_obispo', 6),
#  ('place_food_good', 6),
#  ('great_little_place', 6),
#  ('ordered_steak_eggs', 6),
#  ('went_first_time', 6),
#  ('definitely_recommend_it', 6),
#  ('great_service_too', 6),
#  ('even_better_service', 6),
#  ('great_food_amazing', 6),
#  ('food_amazing_service', 6),
#  ('love_worker_bee', 6),
#  ('perfect_hash_browns', 6),
#  ('home_style_potatoes', 6),
#  ('place_great_location', 6),
#  ('one_favorite_restaurants', 6),
#  ('friendly_staff_good', 6),
#  ('ordered_biscuits_gravy', 6),
#  ('french_toast_also', 6),
#  ('staff_friendly_efficient', 6),
#  ('breakfast_great_service', 6),
#  ('waitress_took_order', 6),
#  ('yum_yum_yum', 6),
#  ('bacon_breakfast_burrito', 6),
#  ('early_morning_breakfast', 6),
#  ('well_taken_care', 6),
#  ('everyone_super_friendly', 6),
#  ('wish_could_give', 6),
#  ('want_go_back', 6),
#  ('wanted_like_place', 6),
#  ('got_santa_barbara', 6),
#  ('tasted_like_came', 6),
#  ('food_highly_recommend', 6),
#  ('time_visit_santa', 6),
#  ('best_part_meal', 6),
#  ('lived_santa_barbara', 6),
#  ('pretty_good_service', 6),
#  ('got_huevos_rancheros', 6),
#  ('definitely_would_come', 6),
#  ('santa_barbara_try', 6),
#  ('cinnamon_roll_good', 6),
#  ('eat_santa_barbara', 6),
#  ('night_santa_barbara', 6),
#  ('maple_bacon_biscuits', 6),
#  ('highly_recommend_anyone', 6),
#  ('burger_garlic_fries', 6),
#  ('pork_belly_sandwich', 6),
#  ('found_scarlett_begonia', 6),
#  ('outdoor_dining_area', 6),
#  ('breakfast_scarlett_begonia', 6),
#  ('bit_hard_find', 6),
#  ('totally_worth_it', 6),
#  ('ordered_lemon_ricotta', 6),
#  ('brunch_spot_sb', 6),
#  ('mothers_day_brunch', 6),
#  ('gold_cinnamon_roll', 6),
#  ('sambos_santa_barbara', 6),
#  ('little_black_sambo', 6),
#  ('free_mini_muffins', 6),
#  ('hash_eggs_benedict', 6),
#  ('give_chocolate_chip', 6),
#  ('chocolate_chip_mini', 6),
#  ('chip_mini_muffins', 6),
#  ('muffins_nice_touch', 6),
#  ('last_remaining_sambos', 6),
#  ('location_right_across', 6),
#  ('give_stars_could', 5),
#  ('atmosphere_great_food', 5),
#  ('side_home_fries', 5),
#  ('butter_apple_butter', 5),
#  ('every_time_come', 5),
#  ('staff_delicious_food', 5),
#  ('spot_breakfast_brunch', 5),
#  ('serve_breakfast_day', 5),
#  ('come_first_served', 5),
#  ('location_santa_barbara', 5),
#  ('service_yummy_food', 5),
#  ('goto_breakfast_spot', 5),
#  ('grits_andouille_sausage', 5),
#  ('make_sure_check', 5),
#  ('also_ordered_side', 5),
#  ('service_great_place', 5),
#  ('goleta_santa_barbara', 5),
#  ('took_forever_get', 5),
#  ('food_finally_came', 5),
#  ('cute_little_breakfast', 5),
#  ('great_service_friendly', 5),
#  ('would_come_again', 5),
#  ('place_eat_breakfast', 5),
#  ('johns_special_scrambled', 5),
#  ('cream_cheese_choice', 5),
#  ('far_one_best', 5),
#  ('ive_ever_to', 5),
#  ('real_maple_syrup', 5),
#  ('long_wait_time', 5),
#  ('next_time_come', 5),
#  ('staff_nice_food', 5),
#  ('best_hash_browns', 5),
#  ('great_food_came', 5),
#  ('food_came_quick', 5),
#  ('im_big_fan', 5),
#  ('breakfast_lunch_love', 5),
#  ('really_good_place', 5),
#  ('portions_great_service', 5),
#  ('pancakes_eggs_benedict', 5),
#  ('go_back_sure', 5),
#  ('eggs_perfectly_cooked', 5),
#  ('food_service_great', 5),
#  ('breakfast_place_sb', 5),
#  ('im_giving_stars', 5),
#  ('food_good_portions', 5),
#  ('ever_area_again', 5),
#  ('want_great_food', 5),
#  ('french_toast_good', 5),
#  ('days_santa_barbara', 5),
#  ('looking_place_eat', 5),
#  ('great_food_delicious', 5),
#  ('someone_take_order', 5),
#  ('people_came_us', 5),
#  ('breakfast_place_area', 5),
#  ('look_like_much', 5),
#  ('first_time_location', 5),
#  ('food_great_atmosphere', 5),
#  ('come_back_great', 5),
#  ('back_great_food', 5),
#  ('breakfast_food_great', 5),
#  ('breakfast_burrito_good', 5),
#  ('food_good_price', 5),
#  ('muffins_die_for', 5),
#  ('food_decent_price', 5),
#  ('service_could_better', 5),
#  ('beignets_die_for', 5),
#  ('actually_pretty_good', 5),
#  ('always_great_food', 5),
#  ('blueberry_wheat_germ', 5),
#  ('place_get_breakfast', 5),
#  ('wait_staff_attentive', 5),
#  ('come_back_sure', 5),
#  ('great_little_breakfast', 5),
#  ('first_time_ordered', 5),
#  ('one_best_brunch', 5),
#  ('good_food_service', 5),
#  ('choice_hash_browns', 5),
#  ('back_great_place', 5),
#  ('favorite_breakfast_spots', 5),
#  ('best_one_ive', 5),
#  ('food_cajun_kitchen', 5),
#  ('cajun_kitchen_years', 5),
#  ('meal_great_service', 5),
#  ('brunch_places_sb', 5),
#  ('im_gon_na', 5),
#  ('one_best_places', 5),
#  ('staff_highly_recommend', 5),
#  ('great_service_wonderful', 5),
#  ('food_delicious_ordered', 5),
#  ('eggs_benedict_also', 5),
#  ('needed_anything_else', 5),
#  ('poor_customer_service', 5),
#  ('try_place_breakfast', 5),
#  ('food_took_minutes', 5),
#  ('service_good_atmosphere', 5),
#  ('die_for_cant', 5),
#  ('happy_found_place', 5),
#  ('pretty_good_too', 5),
#  ('great_spot_breakfast', 5),
#  ('food_reasonably_priced', 5),
#  ('came_take_order', 5),
#  ('delicious_french_toast', 5),
#  ('service_always_great', 5),
#  ('great_food_love', 5),
#  ('overall_good_experience', 5),
#  ('worth_every_penny', 5),
#  ('make_feel_like', 5),
#  ('service_friendly_staff', 5),
#  ('live_santa_barbara', 5),
#  ('were_santa_barbara', 5),
#  ('vegan_breakfast_burrito', 5),
#  ('food_large_portions', 5),
#  ('eggs_home_fries', 5),
#  ('customer_service_best', 5),
#  ('best_brunch_spot', 5),
#  ('eggs_benedict_service', 5),
#  ('service_excellent_coffee', 5),
#  ('came_back_next', 5),
#  ('food_good_nothing', 5),
#  ('give_place_stars', 5),
#  ('able_get_seated', 5),
#  ('fried_steak_gravy', 5),
#  ('bagel_cream_cheese', 5),
#  ('ordered_jambalaya_eggs', 5),
#  ('wonderful_dining_experience', 5),
#  ('worth_it_food', 5),
#  ('couple_weeks_ago', 5),
#  ('would_definitely_stop', 5),
#  ('also_got_side', 5),
#  ('outdoor_indoor_seating', 5),
#  ('forward_going_back', 5),
#  ('portions_pretty_big', 5),
#  ('order_right_away', 5),
#  ('large_portions_great', 5),
#  ('delicious_service_friendly', 5),
#  ('service_food_excellent', 5),
#  ('side_biscuits_gravy', 5),
#  ('place_food_great', 5),
#  ('bee_cafe_breakfast', 5),
#  ('service_really_slow', 5),
#  ('cute_little_cafe', 5),
#  ('gluten_free_toast', 5),
#  ('free_range_eggs', 5),
#  ('give_place_another', 5),
#  ('great_highly_recommend', 5),
#  ('hash_ever_had', 5),
#  ('breakfast_ever_had', 5),
#  ('santa_barbara_know', 5),
#  ('service_super_friendly', 5),
#  ('maybe_next_time', 5),
#  ('real_corned_beef', 5),
#  ('delicious_service_great', 5),
#  ('hash_jalapeño_bacon', 5),
#  ('took_way_long', 5),
#  ('santa_barbara_must', 5),
#  ('food_delicious_well', 5),
#  ('perfectly_poached_eggs', 5),
#  ('got_corned_beef', 5),
#  ('got_biscuits_gravy', 5),
#  ('need_say_more', 5),
#  ('finally_got_food', 5),
#  ('great_little_spot', 5),
#  ('quickly_service_great', 5),
#  ('im_huge_fan', 5),
#  ('next_time_area', 5),
#  ('friendly_food_good', 5),
#  ('got_steak_eggs', 5),
#  ('stop_next_time', 5),
#  ('ever_had_great', 5),
#  ('great_start_day', 5),
#  ('service_great_definitely', 5),
#  ('definitely_return_next', 5),
#  ('fresh_good_quality', 5),
#  ('breakfast_place_ive', 5),
#  ('love_come_back', 5),
#  ('waited_minutes_food', 5),
#  ('food_definitely_worth', 5),
#  ('service_awesome_food', 5),
#  ('high_quality_ingredients', 5),
#  ('definitely_back_next', 5),
#  ('parking_lot_back', 5),
#  ('good_even_though', 5),
#  ('staff_good_food', 5),
#  ('orange_juice_good', 5),
#  ('place_super_cute', 5),
#  ('food_fantastic_service', 5),
#  ('food_service_excellent', 5),
#  ('good_food_get', 5),
#  ('wed_give_try', 5),
#  ('nothing_rave_about', 5),
#  ('santa_barbara_ive', 5),
#  ('delicious_home_fries', 5),
#  ('santa_barbara_right', 5),
#  ('sat_right_away', 5),
#  ('make_sure_stop', 5),
#  ('flat_iron_steak', 5),
#  ('got_food_us', 5),
#  ('worth_it_staff', 5),
#  ('amazing_food_great', 5),
#  ('delicious_highly_recommend', 5),
#  ('santa_barbara_make', 5),
#  ('favorite_breakfast_places', 5),
#  ('delicious_staff_friendly', 5),
#  ('nice_outdoor_seating', 5),
#  ('food_awesome_service', 5),
#  ('place_first_time', 5),
#  ('it_staff_friendly', 5),
#  ('highly_recommend_service', 5),
#  ('delicious_would_definitely', 5),
#  ('good_great_service', 5),
#  ('hash_browns_instead', 5),
#  ('huevos_rancheros_delicious', 5),
#  ('great_food_excellent', 5),
#  ('would_go_again', 5),
#  ('old_town_goleta', 5),
#  ('lunch_dinner_menu', 5),
#  ('service_food_good', 5),
#  ('get_act_together', 5),
#  ('looking_great_breakfast', 5),
#  ('think_ive_ever', 5),
#  ('service_tasty_food', 5),
#  ('come_every_time', 5),
#  ('let_tell_you', 5),
#  ('new_orleans_omelette', 5),
#  ('food_ok_nothing', 5),
#  ('salmon_eggs_benedict', 5),
#  ('really_cant_go', 5),
#  ('eggs_hollandaise_sauce', 5),
#  ('got_crab_cakes', 5),
#  ('first_time_santa', 5),
#  ('ever_santa_barbara', 5),
#  ('last_time_came', 5),
#  ('classic_eggs_benedict', 5),
#  ('good_eggs_benedict', 5),
#  ('definitely_back_came', 5),
#  ('santa_barbara_one', 5),
#  ('definitely_come_again', 5),
#  ('eggs_benedict_one', 5),
#  ('clam_chowder_good', 5),
#  ('breakfast_next_time', 5),
#  ('us_feel_like', 5),
#  ('service_great_well', 5),
#  ('first_time_coming', 5),
#  ('barbara_food_amazing', 5),
#  ('never_bad_meal', 5),
#  ('forward_coming_back', 5),
#  ('back_next_trip', 5),
#  ('right_next_door', 5),
#  ('little_hidden_gem', 5),
#  ('service_excellent_friendly', 5),
#  ('french_toast_fig', 5),
#  ('santa_barbara_weather', 5),
#  ('tucked_away_state', 5),
#  ('la_arcada_plaza', 5),
#  ('place_sit_outside', 5),
#  ('santa_barbara_vacation', 5),
#  ('cheese_caramelized_onions', 5),
#  ('came_back_check', 5),
#  ('order_biscuit_sampler', 5),
#  ('cute_outdoor_seating', 5),
#  ('ive_ever_life', 5),
#  ('tables_next_us', 5),
#  ('good_santa_barbara', 5),
#  ('menu_changes_seasonally', 5),
#  ('away_state_street', 5),
#  ('bloody_marys_mimosas', 5),
#  ('right_state_street', 5),
#  ('sausage_kale_soup', 5),
#  ('great_place_sit', 5),
#  ('definitely_back_try', 5),
#  ('toasted_coconut_latte', 5),
#  ('pancakes_die_for', 5),
#  ('wait_staff_friendly', 5),
#  ('cinnamon_roll_also', 5),
#  ('ordered_short_rib', 5),
#  ('great_place_take', 5),
#  ('banana_bread_french', 5),
#  ('bread_french_toast', 5),
#  ('scarlett_begonia_one', 5),
#  ('toast_eggs_benedict', 5),
#  ('soft_poached_eggs', 5),
#  ('get_cinnamon_roll', 5),
#  ('mimosa_flight_good', 5),
#  ('basket_mini_chocolate', 5),
#  ('chip_muffins_start', 5),
#  ('crab_avocado_omelet', 5),
#  ('cant_beat_view', 5),
#  ('huevos_rancheros_special', 5),
#  ('pancakes_pretty_good', 5),
#  ('place_right_beach', 5),
#  ('warm_mini_muffins', 5),
#  ('nice_view_ocean', 5),
#  ('eggs_benedict_best', 5),
#  ('chip_blueberry_muffins', 5),
#  ('great_location_across', 5),
#  ('benedict_corned_beef', 5),
#  ('little_chocolate_chip', 5),
#  ('cant_beat_location', 5),
#  ('hands_best_breakfast', 4),
#  ('highly_recommend_cajun', 4),
#  ('recommend_cajun_kitchen', 4),
#  ('way_back_home', 4),
#  ('come_take_order', 4),
#  ('took_minutes_bring', 4),
#  ('one_star_food', 4),
#  ('best_brunch_place', 4),
#  ('place_ive_ever', 4),
#  ('eggs_sourdough_toast', 4),
#  ('food_service_atmosphere', 4),
#  ('id_give_stars', 4),
#  ('two_eggs_easy', 4),
#  ('fruit_hash_browns', 4),
#  ('wait_well_worth', 4),
#  ('im_glad_found', 4),
#  ('im_ever_back', 4),
#  ('sunday_morning_am', 4),
#  ('every_single_time', 4),
#  ('love_going_breakfast', 4),
#  ('great_food_fast', 4),
#  ('food_new_orleans', 4),
#  ('keep_going_back', 4),
#  ('great_prices_great', 4),
#  ('great_service_love', 4),
#  ('service_love_place', 4),
#  ('whipped_cream_caramel', 4),
#  ('definitely_one_best', 4),
#  ('two_thumbs_up', 4),
#  ('really_good_well', 4),
#  ('mushrooms_spinach_feta', 4),
#  ('spinach_feta_cheese', 4),
#  ('prices_reasonable_portions', 4),
#  ('definitely_give_place', 4),
#  ('theres_always_wait', 4),
#  ('wait_get_table', 4),
#  ('cornbread_apple_butter', 4),
#  ('kmart_shopping_center', 4),
#  ('definitely_place_go', 4),
#  ('shrimp_grits_andouille', 4),
#  ('place_gets_pretty', 4),
#  ('gets_pretty_busy', 4),
#  ('outdoor_patio_area', 4),
#  ('breakfast_lunch_menu', 4),
#  ('avocado_sour_cream', 4),
#  ('place_would_recommend', 4),
#  ('wish_open_dinner', 4),
#  ('great_service_excellent', 4),
#  ('service_fast_food', 4),
#  ('ordered_crab_cake', 4),
#  ('santa_barbara_wait', 4),
#  ('try_next_time', 4),
#  ('wait_long_food', 4),
#  ('potatoes_bacon_ham', 4),
#  ('bacon_ham_hot', 4),
#  ('ham_hot_sausage', 4),
#  ('hot_sausage_scrambled', 4),
#  ('mushrooms_green_onions', 4),
#  ('potatoes_hash_browns', 4),
#  ('go_back_food', 4),
#  ('best_breakfast_spots', 4),
#  ('great_service_staff', 4),
#  ...]

# %% [markdown]
# ### Japanese

# %%
Japanese = business_df[business_df.Type=='Japanese']
Japanese_review = review1[review1.business_id.isin(Japanese.business_id.values)]
Japanese_review["text"] = Japanese_review["text"].str.lower()
Japanese_review['text'] = Japanese_review['text'].apply(lambda text: cleaning_stopwords(text))
Japanese_review['text']= Japanese_review['text'].apply(lambda x: cleaning_punctuations(x))
Japanese_review['text'] = Japanese_review['text'].apply(lambda x: cleaning_repeating_char(x))
Japanese_review['text'] = Japanese_review['text'].apply(lambda x: cleaning_URLs(x))
Japanese_review['text'] = Japanese_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Japanese=Japanese[Japanese.stars<3.5]
bad_Japanese_review = Japanese_review[Japanese_review.business_id.isin(bad_Japanese.business_id.values)]
bad_Japanese_review_text = bad_Japanese_review.text.str.cat(sep = " ")
bad_Japanese_tokens = word_tokenize(bad_Japanese_review_text)
# FreqDist(bad_American_tokens).most_common()
bigrams_list_bad_Japanese = ["_".join(item) for item in nltk.bigrams(bad_Japanese_tokens)]
trigrams_list_bad_Japanese = ["_".join(item) for item in nltk.trigrams(bad_Japanese_tokens)]
FreqDist(bigrams_list_bad_Japanese).most_common()
# FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('sushi_teri', 116),
#  ('shabu_shabu', 105),
#  ('santa_barbara', 72),
#  ('pretty_good', 55),
#  ('miso_soup', 54),
#  ('california_roll', 50),
#  ('good_sushi', 47),
#  ('spicy_tuna', 46),
#  ('sushi_place', 43),
#  ('come_back', 41),
#  ('first_time', 35),
#  ('sushi_rolls', 35),
#  ('teriyaki_chicken', 34),
#  ('food_good', 34),
#  ('sushi_restaurant', 34),
#  ('chicken_teriyaki', 33),
#  ('sushi_ai', 32),
#  ('really_good', 31),
#  ('customer_service', 31),
#  ('california_rolls', 29),
#  ('dragon_roll', 26),
#  ('salmon_skin', 25),
#  ('quality_food', 24),
#  ('coming_back', 23),
#  ('last_time', 23),
#  ('go_back', 22),
#  ('great_sushi', 22),
#  ('sushi_good', 22),
#  ('japanese_restaurant', 22),
#  ('hand_rolls', 22),
#  ('state_street', 22),
#  ('service_great', 21),
#  ('good_service', 21),
#  ('good_food', 21),
#  ('even_though', 21),
#  ('rainbow_roll', 21),
#  ('sushi_roll', 21),
#  ('feel_like', 20),
#  ('next_time', 20),
#  ('sushi_places', 20),
#  ('ice_cream', 19),
#  ('teriyaki_bowl', 19),
#  ('sushi_chef', 19),
#  ('shrimp_tempura', 19),
#  ('best_sushi', 19),
#  ('great_service', 19),
#  ('craving_sushi', 18),
#  ('sushi_fresh', 18),
#  ('lunch_special', 18),
#  ('recommend_place', 18),
#  ('sushi_bar', 18),
#  ('would_recommend', 18),
#  ('rolls_good', 18),
#  ('tempura_roll', 18),
#  ('come_here', 18),
#  ('japanese_food', 17),
#  ('great_place', 17),
#  ('every_time', 17),
#  ('service_friendly', 17),
#  ('raw_fish', 17),
#  ('fish_fresh', 16),
#  ('highly_recommend', 16),
#  ('ive_never', 16),
#  ('hand_roll', 16),
#  ('salad_dressing', 16),
#  ('bad_service', 16),
#  ('tuna_roll', 16),
#  ('beef_teriyaki', 16),
#  ('cabbage_salad', 15),
#  ('green_tea', 15),
#  ('ive_ever', 15),
#  ('service_good', 15),
#  ('cream_cheese', 15),
#  ('going_back', 15),
#  ('friendly_staff', 15),
#  ('im_sure', 15),
#  ('roll_good', 15),
#  ('spider_roll', 15),
#  ('better_sushi', 15),
#  ('worth_it', 15),
#  ('bento_box', 15),
#  ('looked_like', 15),
#  ('ever_had', 14),
#  ('soy_sauce', 14),
#  ('food_great', 14),
#  ('got_food', 14),
#  ('tasted_like', 14),
#  ('fresh_fish', 14),
#  ('staff_friendly', 14),
#  ('great_food', 14),
#  ('quality_sushi', 14),
#  ('wait_staff', 14),
#  ('next_door', 14),
#  ('chirashi_bowl', 14),
#  ('place_go', 13),
#  ('would_go', 13),
#  ('seaweed_salad', 13),
#  ('love_sushi', 13),
#  ('worst_sushi', 13),
#  ('quality_fish', 13),
#  ('love_place', 13),
#  ('favorite_sushi', 13),
#  ('nothing_special', 13),
#  ('food_service', 13),
#  ('terrible_service', 13),
#  ('spicy_mayo', 13),
#  ('crunch_roll', 13),
#  ('also_ordered', 13),
#  ('kai_sushi', 13),
#  ('taste_fresh', 13),
#  ('go_again', 12),
#  ('place_good', 12),
#  ('teriyaki_sauce', 12),
#  ('imitation_crab', 12),
#  ('service_slow', 12),
#  ('last_night', 12),
#  ('never_go', 12),
#  ('good_place', 12),
#  ('can_not', 12),
#  ('horrible_service', 12),
#  ('ordered_sushi', 11),
#  ('several_times', 11),
#  ('food_came', 11),
#  ('bad_bad', 11),
#  ('service_food', 11),
#  ('good_price', 11),
#  ('fast_food', 11),
#  ('sushi_fix', 11),
#  ('much_better', 11),
#  ('sushi_restaurants', 11),
#  ('sushi_chefs', 11),
#  ('one_star', 11),
#  ('service_always', 10),
#  ('sushi_great', 10),
#  ('food_decent', 10),
#  ('food_ok', 10),
#  ('also_got', 10),
#  ('take_order', 10),
#  ('took_minutes', 10),
#  ('minutes_later', 10),
#  ('crunchy_roll', 10),
#  ('great_experience', 10),
#  ('go_sushi', 10),
#  ('special_rolls', 10),
#  ('food_delicious', 10),
#  ('sushi_spot', 10),
#  ('ordered_rolls', 10),
#  ('felt_like', 10),
#  ('anything_else', 10),
#  ('soup_salad', 10),
#  ('food_pretty', 10),
#  ('like_place', 10),
#  ('skin_roll', 10),
#  ('tempura_shrimp', 10),
#  ('lunch_specials', 10),
#  ('japanese_restaurants', 10),
#  ('fast_service', 10),
#  ('food_sushi', 10),
#  ('goleta_sushi', 10),
#  ('many_times', 10),
#  ('tempura_udon', 10),
#  ('somewhere_else', 9),
#  ('orange_dragon', 9),
#  ('reasonably_priced', 9),
#  ('sushi_house', 9),
#  ('chicken_bowl', 9),
#  ('food_okay', 9),
#  ('eat_here', 9),
#  ('ordered_chicken', 9),
#  ('gave_us', 9),
#  ('fresh_tasty', 9),
#  ('service_terrible', 9),
#  ('sushi_terri', 9),
#  ('ive_eaten', 9),
#  ('good_enough', 9),
#  ('would_give', 9),
#  ('service_fast', 9),
#  ('waited_minutes', 9),
#  ('definitely_recommend', 9),
#  ('grocery_store', 9),
#  ('really_nice', 9),
#  ('sushi_ok', 9),
#  ('would_like', 9),
#  ('would_come', 9),
#  ('real_crab', 9),
#  ('years_ago', 9),
#  ('fell_apart', 9),
#  ('would_say', 9),
#  ('soup_base', 9),
#  ('roll_spicy', 9),
#  ('long_time', 9),
#  ('falling_apart', 9),
#  ('decent_sushi', 9),
#  ('place_great', 8),
#  ('decent_service', 8),
#  ('one_time', 8),
#  ('place_sushi', 8),
#  ('want_sushi', 8),
#  ('heart_attack', 8),
#  ('highly_recommended', 8),
#  ('really_bad', 8),
#  ('bad_experience', 8),
#  ('always_fresh', 8),
#  ('service_nice', 8),
#  ('poor_quality', 8),
#  ('yellow_tail', 8),
#  ('deep_fried', 8),
#  ('slow_service', 8),
#  ('roll_sushi', 8),
#  ('never_came', 8),
#  ('sushi_spots', 8),
#  ('always_good', 8),
#  ('little_bit', 8),
#  ('beef_bowl', 8),
#  ('us_food', 8),
#  ('generous_portions', 8),
#  ('gon_na', 8),
#  ('go_place', 8),
#  ('quick_sushi', 8),
#  ('one_best', 8),
#  ('really_enjoyed', 8),
#  ('back_here', 8),
#  ('never_bad', 8),
#  ('good_quality', 8),
#  ('scallop_roll', 8),
#  ('ive_tried', 8),
#  ('kobe_beef', 8),
#  ('downtown_santa', 8),
#  ('quality_service', 8),
#  ('get_sushi', 8),
#  ('teri_goleta', 8),
#  ('sushi_goleta', 8),
#  ('seemed_like', 8),
#  ('tea_ice', 7),
#  ('parking_lot', 7),
#  ('two_rolls', 7),
#  ('eat_it', 7),
#  ('bring_food', 7),
#  ('worst_service', 7),
#  ('bit_pricey', 7),
#  ('sushi_decent', 7),
#  ('godzilla_roll', 7),
#  ('rice_salad', 7),
#  ('back_again', 7),
#  ('time_came', 7),
#  ('came_out', 7),
#  ('never_tried', 7),
#  ('one_roll', 7),
#  ('roll_ordered', 7),
#  ('like_sushi', 7),
#  ('overall_good', 7),
#  ('ive_sushi', 7),
#  ('roll_also', 7),
#  ('good_thing', 7),
#  ('poke_bowl', 7),
#  ('dining_experience', 7),
#  ('came_table', 7),
#  ('service_ok', 7),
#  ('attack_roll', 7),
#  ('brought_us', 7),
#  ('good_experience', 7),
#  ('sushi_santa', 7),
#  ('good_value', 7),
#  ('stay_away', 7),
#  ('would_get', 7),
#  ('get_better', 7),
#  ('also_tried', 7),
#  ('tastes_like', 7),
#  ('many_years', 7),
#  ('good_too', 7),
#  ('every_week', 7),
#  ('super_friendly', 7),
#  ('quite_good', 7),
#  ('place_get', 7),
#  ('state_st', 7),
#  ('tried_shabu', 7),
#  ('cooked_food', 7),
#  ('food_poisoning', 7),
#  ('told_us', 7),
#  ('dipping_sauce', 7),
#  ('definitely_come', 7),
#  ('food_well', 7),
#  ('get_good', 7),
#  ('side_salad', 7),
#  ('got_sushi', 7),
#  ('spicy_salmon', 7),
#  ('one_favorite', 7),
#  ('across_street', 7),
#  ('pork_ramen', 7),
#  ('come_out', 7),
#  ('give_place', 7),
#  ('ordered_tempura', 7),
#  ('broken_heart', 7),
#  ('time_go', 6),
#  ('really_love', 6),
#  ('again_sushi', 6),
#  ('took_forever', 6),
#  ('three_stars', 6),
#  ('something_like', 6),
#  ('ordered_beef', 6),
#  ('really_really', 6),
#  ('many_people', 6),
#  ('took_hour', 6),
#  ('get_food', 6),
#  ('get_order', 6),
#  ('get_it', 6),
#  ('service_excellent', 6),
#  ('friendly_service', 6),
#  ('year_old', 6),
#  ('good_get', 6),
#  ('brown_rice', 6),
#  ('snake_roll', 6),
#  ('ponzu_sauce', 6),
#  ('two_people', 6),
#  ('definitely_coming', 6),
#  ('service_horrible', 6),
#  ('food_even', 6),
#  ('even_busy', 6),
#  ('definitely_worth', 6),
#  ('roll_tasty', 6),
#  ('time_sushi', 6),
#  ('even_get', 6),
#  ('good_fresh', 6),
#  ('fish_market', 6),
#  ('service_also', 6),
#  ('night_sushi', 6),
#  ('really_enjoy', 6),
#  ('place_come', 6),
#  ('could_eat', 6),
#  ('tell_us', 6),
#  ('came_back', 6),
#  ('food_really', 6),
#  ('sub_par', 6),
#  ('food_always', 6),
#  ('eat_sushi', 6),
#  ('said_yes', 6),
#  ('make_sure', 6),
#  ('come_every', 6),
#  ('sushi_would', 6),
#  ('come_again', 6),
#  ('time_ordered', 6),
#  ('goleta_location', 6),
#  ('anywhere_else', 6),
#  ('fresh_sushi', 6),
#  ('went_lunch', 6),
#  ('ca_roll', 6),
#  ('someone_else', 6),
#  ('ordered_teriyaki', 6),
#  ('tuna_spicy', 6),
#  ('salmon_sushi', 6),
#  ('got_there', 6),
#  ('food_quality', 6),
#  ('better_places', 6),
#  ('time_really', 6),
#  ('shredded_cabbage', 6),
#  ('roll_best', 6),
#  ('sushi_get', 6),
#  ('time_eating', 6),
#  ('take_out', 6),
#  ('rolls_pretty', 6),
#  ('back_sushi', 6),
#  ('hard_time', 6),
#  ('bad_sushi', 6),
#  ('food_tasted', 6),
#  ('place_pretty', 6),
#  ('spend_money', 6),
#  ('sushi_best', 6),
#  ('behind_counter', 6),
#  ('read_reviews', 6),
#  ('boiling_water', 6),
#  ('udon_soup', 6),
#  ('better_quality', 6),
#  ('sushi_one', 6),
#  ('usually_get', 6),
#  ('cali_roll', 6),
#  ('even_finish', 6),
#  ('took_order', 6),
#  ('different_rolls', 6),
#  ('hot_pot', 6),
#  ('food_get', 6),
#  ('lot_food', 6),
#  ('order_counter', 6),
#  ('decided_try', 6),
#  ('rolls_ordered', 6),
#  ('authentic_sushi', 6),
#  ('salad_rice', 6),
#  ('bad_reviews', 6),
#  ('times_ive', 6),
#  ('college_student', 6),
#  ('wait_time', 6),
#  ('yellowtail_roll', 6),
#  ('never_got', 6),
#  ('chicken_katsu', 6),
#  ('friendly_helpful', 6),
#  ('bill_came', 6),
#  ('rolls_sushi', 6),
#  ('order_sushi', 6),
#  ('poke_salad', 6),
#  ('place_town', 5),
#  ('go_somewhere', 5),
#  ('probably_best', 5),
#  ('spicy_edamame', 5),
#  ('want_go', 5),
#  ('also_really', 5),
#  ('great_prices', 5),
#  ('priced_good', 5),
#  ('great_price', 5),
#  ('service_absolutely', 5),
#  ('best_ive', 5),
#  ('good_also', 5),
#  ('cant_beat', 5),
#  ('hard_find', 5),
#  ('la_carte', 5),
#  ('panda_express', 5),
#  ('good_one', 5),
#  ('fish_taste', 5),
#  ('atmosphere_nice', 5),
#  ('good_would', 5),
#  ('would_definitely', 5),
#  ('definitely_go', 5),
#  ('back_area', 5),
#  ('end_meal', 5),
#  ('could_get', 5),
#  ('good_rolls', 5),
#  ('teri_great', 5),
#  ('salmon_tuna', 5),
#  ('place_service', 5),
#  ('stomach_ache', 5),
#  ('side_note', 5),
#  ('always_great', 5),
#  ('dinner_sushi', 5),
#  ('go_there', 5),
#  ('ahi_tuna', 5),
#  ('nice_food', 5),
#  ('price_reasonable', 5),
#  ('good_good', 5),
#  ('im_sad', 5),
#  ('say_sushi', 5),
#  ('ive_always', 5),
#  ('roll_tempura', 5),
#  ('everything_good', 5),
#  ('came_ask', 5),
#  ('check_us', 5),
#  ('really_fresh', 5),
#  ('it_overall', 5),
#  ('lunch_today', 5),
#  ('nigiri_sushi', 5),
#  ('times_always', 5),
#  ('asked_us', 5),
#  ('tempura_crunch', 5),
#  ('large_group', 5),
#  ('people_work', 5),
#  ('salmon_sashimi', 5),
#  ('sushi_delicious', 5),
#  ('food_ordered', 5),
#  ('way_much', 5),
#  ('really_weird', 5),
#  ('sauce_tempura', 5),
#  ('skip_place', 5),
#  ('never_come', 5),
#  ('wait_food', 5),
#  ('mixed_tempura', 5),
#  ('im_giving', 5),
#  ('nice_enough', 5),
#  ('happy_hour', 5),
#  ('cant_wait', 5),
#  ('roll_came', 5),
#  ('told_waitress', 5),
#  ('delicious_sushi', 5),
#  ('place_really', 5),
#  ('came_quickly', 5),
#  ('really_liked', 5),
#  ('one_bite', 5),
#  ('seems_like', 5),
#  ('service_really', 5),
#  ('tempura_veggies', 5),
#  ('lunch_dinner', 5),
#  ('sushi_ive', 5),
#  ('sushi_here', 5),
#  ('here_service', 5),
#  ('always_nice', 5),
#  ('really_like', 5),
#  ('rolls_also', 5),
#  ('new_sushi', 5),
#  ('give_try', 5),
#  ('picked_up', 5),
#  ('kitchen_staff', 5),
#  ('sushi_instead', 5),
#  ('ive_coming', 5),
#  ('salad_comes', 5),
#  ('vegetable_tempura', 5),
#  ('sat_bar', 5),
#  ('time_went', 5),
#  ('whole_time', 5),
#  ('cook_food', 5),
#  ('asked_speak', 5),
#  ('never_experienced', 5),
#  ('priced_sushi', 5),
#  ('fresh_service', 5),
#  ('good_well', 5),
#  ('high_quality', 5),
#  ('taste_like', 5),
#  ('good_deal', 5),
#  ('place_definitely', 5),
#  ('wanted_sushi', 5),
#  ('ordered_two', 5),
#  ('sushi_bad', 5),
#  ('price_sushi', 5),
#  ('comes_sushi', 5),
#  ('always_excellent', 5),
#  ('sushi_quality', 5),
#  ('great_spot', 5),
#  ('asked_could', 5),
#  ('could_make', 5),
#  ('pay_for', 5),
#  ('always_get', 5),
#  ('hot_water', 5),
#  ('los_agaves', 5),
#  ('sushi_plate', 5),
#  ('bowl_california', 5),
#  ('received_food', 5),
#  ('waste_time', 5),
#  ('expect_much', 5),
#  ('two_us', 5),
#  ('times_got', 5),
#  ('fish_tempura', 5),
#  ('sushi_rice', 5),
#  ('sushi_shabu', 5),
#  ('outdoor_seating', 5),
#  ('another_minutes', 5),
#  ('per_roll', 5),
#  ('back_patio', 5),
#  ('place_order', 5),
#  ('food_bad', 5),
#  ('really_great', 5),
#  ('spicy_scallop', 5),
#  ('benefit_doubt', 5),
#  ('could_use', 5),
#  ('somethings_fishy', 5),
#  ('roll_rolls', 5),
#  ('negative_reviews', 5),
#  ('place_like', 5),
#  ('teriyaki_beef', 5),
#  ('give_one', 5),
#  ('de_la', 5),
#  ('time_got', 5),
#  ('mediocre_food', 5),
#  ('rolls_really', 5),
#  ('got_it', 5),
#  ('fresh_rolls', 5),
#  ('togo_order', 5),
#  ('mediocre_sushi', 5),
#  ('okay_nothing', 5),
#  ('quite_bit', 5),
#  ('service_pretty', 5),
#  ('one_better', 5),
#  ('go_here', 5),
#  ('roll_combo', 5),
#  ('japanese_sushi', 5),
#  ('family_boat', 5),
#  ('order_ordered', 5),
#  ('even_know', 5),
#  ('rolls_come', 5),
#  ('good_size', 5),
#  ('let_know', 5),
#  ('came_lunch', 5),
#  ('first_last', 5),
#  ('place_goleta', 5),
#  ('zero_stars', 5),
#  ('fall_apart', 5),
#  ('waiting_minutes', 5),
#  ('fried_rice', 5),
#  ('would_rather', 5),
#  ('pizza_roll', 5),
#  ('surfs_roll', 5),
#  ('waste_money', 5),
#  ('downtown_location', 5),
#  ('calle_real', 5),
#  ('bean_sprouts', 5),
#  ('roll_broken', 5),
#  ('always_order', 4),
#  ('always_friendly', 4),
#  ('friendly_quick', 4),
#  ('couple_years', 4),
#  ('nice_sushi', 4),
#  ('fresh_delicious', 4),
#  ('bay_area', 4),
#  ('tempura_teriyaki', 4),
#  ('forever_get', 4),
#  ('tempura_good', 4),
#  ('best_teriyaki', 4),
#  ('okay_service', 4),
#  ('place_even', 4),
#  ('white_rice', 4),
#  ('never_again', 4),
#  ('nice_service', 4),
#  ('garlic_edamame', 4),
#  ('sushi_snob', 4),
#  ('room_temperature', 4),
#  ('soy_paper', 4),
#  ('never_eat', 4),
#  ('never_ever', 4),
#  ('sushi_area', 4),
#  ('place_clean', 4),
#  ('good_ordered', 4),
#  ('eat_one', 4),
#  ('going_there', 4),
#  ('beef_chicken', 4),
#  ('drive_santa', 4),
#  ('bad_review', 4),
#  ('would_eat', 4),
#  ('eat_again', 4),
#  ('got_order', 4),
#  ('charge_us', 4),
#  ('service_ever', 4),
#  ('well_worth', 4),
#  ('teriyaki_combo', 4),
#  ('wish_could', 4),
#  ('pieces_nigiri', 4),
#  ('tuna_salmon', 4),
#  ('roll_salmon', 4),
#  ('rolls_looked', 4),
#  ('never_going', 4),
#  ('never_disappointed', 4),
#  ('different_servers', 4),
#  ('ever_go', 4),
#  ('roll_fish', 4),
#  ('even_eat', 4),
#  ('always_come', 4),
#  ('sushi_around', 4),
#  ('special_good', 4),
#  ('chicken_beef', 4),
#  ('food_average', 4),
#  ('lot_people', 4),
#  ('rolls_decent', 4),
#  ('one_favorites', 4),
#  ('star_rating', 4),
#  ('place_terrible', 4),
#  ('place_bad', 4),
#  ('poor_service', 4),
#  ('care_us', 4),
#  ('food_alright', 4),
#  ('minutes_get', 4),
#  ('roll_specialty', 4),
#  ('friendly_place', 4),
#  ('high_end', 4),
#  ('give_stars', 4),
#  ('roll_falling', 4),
#  ('stars_instead', 4),
#  ('chicken_salad', 4),
#  ('times_week', 4),
#  ('here_ive', 4),
#  ('tried_sushi', 4),
#  ('good_got', 4),
#  ('sushi_teriyaki', 4),
#  ('way_back', 4),
#  ('sushi_ever', 4),
#  ('look_fresh', 4),
#  ('best_part', 4),
#  ('here_food', 4),
#  ('multiple_times', 4),
#  ('reading_reviews', 4),
#  ('fish_got', 4),
#  ('half_hour', 4),
#  ('everything_tasted', 4),
#  ('time_around', 4),
#  ('size_rolls', 4),
#  ('recommend_getting', 4),
#  ('service_usually', 4),
#  ('sushi_go', 4),
#  ('tasted_really', 4),
#  ('food_table', 4),
#  ('asked_would', 4),
#  ('everything_fresh', 4),
#  ('sushi_combination', 4),
#  ('us_like', 4),
#  ('place_food', 4),
#  ('sushi_sb', 4),
#  ('different_sushi', 4),
#  ('impressed_sushi', 4),
#  ('going_sushi', 4),
#  ('get_us', 4),
#  ('us_one', 4),
#  ('selection_sushi', 4),
#  ('sushi_ordered', 4),
#  ('curry_rice', 4),
#  ('also_good', 4),
#  ('go_order', 4),
#  ('prices_reasonable', 4),
#  ('fast_friendly', 4),
#  ('food_place', 4),
#  ('experiences_sushi', 4),
#  ('tempura_combo', 4),
#  ('good_things', 4),
#  ('try_out', 4),
#  ('quick_service', 4),
#  ('time_asked', 4),
#  ('got_home', 4),
#  ('took_one', 4),
#  ('lot_sushi', 4),
#  ('next_day', 4),
#  ('needless_say', 4),
#  ('love_it', 4),
#  ('roll_special', 4),
#  ('ingredients_fresh', 4),
#  ('awesome_sushi', 4),
#  ('pretty_much', 4),
#  ('oh_well', 4),
#  ('hamachi_kama', 4),
#  ('tastes_fresh', 4),
#  ('people_came', 4),
#  ('years_never', 4),
#  ('order_taken', 4),
#  ('wrong_order', 4),
#  ('place_stars', 4),
#  ('fish_always', 4),
#  ('fresh_ive', 4),
#  ('good_used', 4),
#  ('soft_shell', 4),
#  ('shell_crab', 4),
#  ('drink_order', 4),
#  ('rolls_great', 4),
#  ('goleta_santa', 4),
#  ('fish_rolls', 4),
#  ('pretty_bad', 4),
#  ('nice_atmosphere', 4),
#  ('dinner_prices', 4),
#  ('im_still', 4),
#  ('daily_special', 4),
#  ('roll_two', 4),
#  ('waitress_kept', 4),
#  ('top_that', 4),
#  ('times_before', 4),
#  ('excuse_me', 4),
#  ('order_go', 4),
#  ('comes_salad', 4),
#  ('udon_noodles', 4),
#  ('avoid_place', 4),
#  ('shabu_bar', 4),
#  ('dipping_sauces', 4),
#  ('miso_base', 4),
#  ('large_beef', 4),
#  ('roll_okay', 4),
#  ('cut_rolls', 4),
#  ('quality_meat', 4),
#  ('sushi_night', 4),
#  ('beef_pork', 4),
#  ('giving_place', 4),
#  ('place_chance', 4),
#  ('get_shabu', 4),
#  ('shabu_places', 4),
#  ('skin_hand', 4),
#  ('restaurant_goleta', 4),
#  ('couple_times', 4),
#  ('cant_get', 4),
#  ('friend_ordered', 4),
#  ('got_california', 4),
#  ('sunday_night', 4),
#  ('real_sushi', 4),
#  ('good_lunch', 4),
#  ('im_picky', 4),
#  ('bento_boxes', 4),
#  ('ordered_spicy', 4),
#  ('tuna_rolls', 4),
#  ('way_overpriced', 4),
#  ('beef_shabu', 4),
#  ('noodle_soup', 4),
#  ('much_sushi', 4),
#  ('cant_say', 4),
#  ('pretty_decent', 4),
#  ('every_piece', 4),
#  ('next_us', 4),
#  ('ordered_salmon', 4),
#  ('served_rice', 4),
#  ('horrible_food', 4),
#  ('shabu_sushi', 4),
#  ('sushi_okay', 4),
#  ('comes_miso', 4),
#  ('could_better', 4),
#  ('go_restaurant', 4),
#  ('many_sushi', 4),
#  ('time_ive', 4),
#  ('walking_distance', 4),
#  ('try_sushi', 4),
#  ('salmon_rolls', 4),
#  ('place_one', 4),
#  ('red_dragon', 4),
#  ('best_place', 4),
#  ('box_lunch', 4),
#  ('quality_good', 4),
#  ('price_quality', 4),
#  ('eating_sushi', 4),
#  ('could_order', 4),
#  ('stopped_lunch', 4),
#  ('another_thing', 4),
#  ('shabu_santa', 4),
#  ('probably_come', 4),
#  ('craving_shabu', 4),
#  ('thin_slices', 4),
#  ('back_try', 4),
#  ('everything_else', 4),
#  ('ever_come', 4),
#  ('rolls_monday', 4),
#  ('quick_lunch', 4),
#  ('terrible_food', 4),
#  ('sushi_came', 4),
#  ('put_together', 4),
#  ('thought_would', 4),
#  ('ever_seen', 4),
#  ('excellent_service', 4),
#  ('serve_us', 4),
#  ('food_disgusting', 4),
#  ('looks_like', 4),
#  ('made_mistake', 4),
#  ('here_sushi', 4),
#  ('really_wanted', 4),
#  ('wait_minutes', 4),
#  ('sashimi_salad', 4),
#  ('used_go', 4),
#  ('got_rainbow', 4),
#  ('im_used', 4),
#  ('order_take', 4),
#  ('made_sushi', 4),
#  ('good_variety', 4),
#  ('save_money', 4),
#  ('shabu_place', 4),
#  ('nothing_really', 4),
#  ('overall_would', 4),
#  ('take_food', 4),
#  ('good_hot', 4),
#  ('friday_night', 4),
#  ('also_like', 4),
#  ('bowl_good', 4),
#  ('enough_food', 4),
#  ('la_guerra', 4),
#  ('think_place', 4),
#  ('roll_yellowtail', 4),
#  ('food_was', 4),
#  ('sushi_went', 4),
#  ('id_give', 4),
#  ('service_mediocre', 4),
#  ('sushi_pretty', 4),
#  ('amazing_service', 4),
#  ('got_teriyaki', 4),
#  ('volcano_roll', 4),
#  ('quick_bite', 4),
#  ('rolls_one', 4),
#  ('small_portions', 4),
#  ('recent_visit', 4),
#  ('could_give', 4),
#  ('cant_even', 4),
#  ('told_would', 4),
#  ('place_next', 4),
#  ('good_prices', 4),
#  ('eaten_sushi', 4),
#  ('waiting_food', 4),
#  ('food_come', 4),
#  ('rolls_ok', 4),
#  ('salmon_roll', 4),
#  ('tempura_soggy', 4),
#  ('orange_county', 4),
#  ('second_time', 4),
#  ('decent_price', 4),
#  ('got_one', 4),
#  ('fresh_also', 4),
#  ('bulgogi_bowl', 4),
#  ('time_time', 4),
#  ('super_disappointed', 4),
#  ('strip_mall', 4),
#  ('always_really', 4),
#  ('amazing_food', 4),
#  ('id_definitely', 4),
#  ('ordered_food', 4),
#  ('food_go', 4),
#  ('lunch_menu', 4),
#  ('daily_specials', 4),
#  ('minute_wait', 4),
#  ('great_time', 4),
#  ('big_fan', 4),
#  ('definitely_favorite', 4),
#  ('two_sushi', 4),
#  ('tasted_old', 4),
#  ('right_now', 4),
#  ('sushi_really', 4),
#  ('never_received', 4),
#  ('super_fresh', 4),
#  ('sushi_always', 4),
#  ('good_ive', 4),
#  ('like_food', 4),
#  ('top_roll', 4),
#  ('hit_miss', 4),
#  ('service_ive', 4),
#  ('think_sushi', 4),
#  ('id_say', 4),
#  ('usually_order', 4),
#  ('main_course', 4),
#  ('goto_sushi', 4),
#  ('curry_udon', 4),
#  ('crab_roll', 4),
#  ('order_salmon', 3),
#  ('also_love', 3),
#  ('love_spicy', 3),
#  ('portions_big', 3),
#  ('read_yelp', 3),
#  ('yelp_reviews', 3),
#  ('make_mine', 3),
#  ('sushi_dinner', 3),
#  ('good_staff', 3),
#  ('ok_nothing', 3),
#  ('nothing_great', 3),
#  ('called_seafood', 3),
#  ('well_tried', 3),
#  ('three_times', 3),
#  ('people_know', 3),
#  ('know_place', 3),
#  ('decent_place', 3),
#  ('time_waitress', 3),
#  ('im_sushi', 3),
#  ('hot_saki', 3),
#  ('dinner_place', 3),
#  ('here_place', 3),
#  ('server_nice', 3),
#  ('friendly_great', 3),
#  ('salmon_salmon', 3),
#  ('never_return', 3),
#  ('ask_take', 3),
#  ('ordered_one', 3),
#  ('like_frozen', 3),
#  ('store_bought', 3),
#  ('sushi_super', 3),
#  ('sushi_even', 3),
#  ('forgot_order', 3),
#  ('order_least', 3),
#  ('place_ever', 3),
#  ('food_items', 3),
#  ('first_waiter', 3),
#  ('order_came', 3),
#  ('came_minutes', 3),
#  ('overall_experience', 3),
#  ('worst_ever', 3),
#  ('even_bother', 3),
#  ('needed_anything', 3),
#  ('around_us', 3),
#  ('left_us', 3),
#  ('worth_money', 3),
#  ('food_fresh', 3),
#  ('tasty_sushi', 3),
#  ('charged_us', 3),
#  ('rolls_asked', 3),
#  ('came_sushi', 3),
#  ('entire_meal', 3),
#  ('recommend_sushi', 3),
#  ('old_sushi', 3),
#  ('sushi_sloppy', 3),
#  ('mood_sushi', 3),
#  ('eye_contact', 3),
#  ('worst_experience', 3),
#  ('thought_id', 3),
#  ('messed_order', 3),
#  ('got_bad', 3),
#  ('food_terrible', 3),
#  ('tuna_sushi', 3),
#  ('waited_hour', 3),
#  ('one_person', 3),
#  ('sashimi_always', 3),
#  ('restaurant_worst', 3),
#  ('warm_sushi', 3),
#  ('quality_best', 3),
#  ('omega_roll', 3),
#  ('generous_portion', 3),
#  ('bit_weird', 3),
#  ('absolutely_delicious', 3),
#  ('experience_im', 3),
#  ('rice_also', 3),
#  ('area_good', 3),
#  ('little_expensive', 3),
#  ('japanese_place', 3),
#  ('go_to', 3),
#  ('went_restaurant', 3),
#  ('ordered_large', 3),
#  ('again_place', 3),
#  ('however_time', 3),
#  ('take_care', 3),
#  ('experience_sushi', 3),
#  ('fried_tofu', 3),
#  ('tax_tip', 3),
#  ('roll_really', 3),
#  ('pieces_sushi', 3),
#  ('still_hungry', 3),
#  ('overall_service', 3),
#  ('good_definitely', 3),
#  ('high_prices', 3),
#  ('busy_food', 3),
#  ('worth_wait', 3),
#  ('it_sushi', 3),
#  ('like_grocery', 3),
#  ('tempura_rolls', 3),
#  ('get_takeout', 3),
#  ('meal_place', 3),
#  ('never_disappoints', 3),
#  ...]

# %%
good_Japanese=Japanese[Japanese.stars>=4.5]
good_Japanese_review = Japanese_review[Japanese_review.business_id.isin(good_Japanese.business_id.values)]
good_Japanese_review_text = good_Japanese_review.text.str.cat(sep = " ")
good_Japanese_tokens = word_tokenize(good_Japanese_review_text)
# FreqDist(good_American_tokens).most_common()
bigrams_list_good_Japanese = ["_".join(item) for item in nltk.bigrams(good_Japanese_tokens)]
trigrams_list_good_Japanese = ["_".join(item) for item in nltk.trigrams(good_Japanese_tokens)]
FreqDist(bigrams_list_good_Japanese).most_common()
FreqDist(trigrams_list_good_Japanese).most_common()
# Out:
# [('bone_marrow_bruschetta', 80),
#  ('ive_ever_had', 48),
#  ('definitely_come_back', 41),
#  ('ramen_pork_belly', 37),
#  ('wait_go_back', 33),
#  ('restaurant_santa_barbara', 32),
#  ('soft_boiled_egg', 32),
#  ('cant_wait_go', 31),
#  ('ramen_pork_shoulder', 27),
#  ('back_next_time', 26),
#  ('would_come_back', 24),
#  ('place_santa_barbara', 24),
#  ('santa_barbara_area', 22),
#  ('sushi_santa_barbara', 22),
#  ('black_kuro_ramen', 22),
#  ('food_great_service', 21),
#  ('highly_recommend_place', 21),
#  ('next_time_im', 20),
#  ('would_definitely_recommend', 19),
#  ('best_ramen_ive', 19),
#  ('wait_come_back', 18),
#  ('pork_belly_ramen', 18),
#  ('boar_spare_ribs', 18),
#  ('great_service_great', 17),
#  ('definitely_go_back', 17),
#  ('definitely_coming_back', 17),
#  ('cant_wait_come', 17),
#  ('noodles_pork_belly', 17),
#  ('beef_bone_marrow', 16),
#  ('spicy_aka_ramen', 16),
#  ('spicy_ramen_pork', 16),
#  ('would_definitely_come', 15),
#  ('blue_fin_tuna', 15),
#  ('kuro_ramen_pork', 15),
#  ('definitely_going_back', 14),
#  ('keep_coming_back', 14),
#  ('tuna_crispy_rice', 14),
#  ('one_best_dining', 13),
#  ('best_dining_experiences', 13),
#  ('would_highly_recommend', 13),
#  ('visiting_santa_barbara', 13),
#  ('one_best_meals', 13),
#  ('visit_santa_barbara', 13),
#  ('would_go_back', 13),
#  ('cant_go_wrong', 13),
#  ('gem_santa_barbara', 12),
#  ('worth_every_penny', 12),
#  ('can_not_wait', 12),
#  ('best_ive_ever', 12),
#  ('best_sushi_ive', 12),
#  ('service_great_food', 12),
#  ('great_food_great', 12),
#  ('spicy_tuna_roll', 12),
#  ('spicy_tuna_crispy', 12),
#  ('best_sushi_town', 12),
#  ('ive_santa_barbara', 12),
#  ('wild_boar_spare', 12),
#  ('chefs_tasting_menu', 12),
#  ('baby_back_ribs', 12),
#  ('ramen_santa_barbara', 12),
#  ('favorite_restaurant_santa', 11),
#  ('restaurants_santa_barbara', 11),
#  ('highly_recommend_it', 11),
#  ('sushi_bar_montecito', 11),
#  ('come_back_try', 11),
#  ('come_back_next', 11),
#  ('come_back_again', 11),
#  ('best_sushi_santa', 11),
#  ('places_santa_barbara', 11),
#  ('favorite_sushi_place', 11),
#  ('roasted_beet_salad', 11),
#  ('food_good_service', 11),
#  ('best_ramen_place', 11),
#  ('pork_belly_pork', 11),
#  ('downtown_santa_barbara', 10),
#  ('highly_recommend_restaurant', 10),
#  ('well_worth_it', 10),
#  ('santa_barbara_uni', 10),
#  ('would_definitely_go', 10),
#  ('great_customer_service', 10),
#  ('first_time_trying', 10),
#  ('food_really_good', 10),
#  ('one_best_sushi', 10),
#  ('spot_santa_barbara', 10),
#  ('go_back_try', 10),
#  ('sushi_place_santa', 10),
#  ('roasted_bone_marrow', 10),
#  ('dinner_black_sheep', 10),
#  ('duck_leg_confit', 10),
#  ('wagyu_beef_carpaccio', 10),
#  ('tonkotsu_black_kuro', 10),
#  ('santa_barbara_food', 9),
#  ('back_santa_barbara', 9),
#  ('beef_pepper_rice', 9),
#  ('recommend_place_anyone', 9),
#  ('seated_right_away', 9),
#  ('experience_black_sheep', 9),
#  ('really_good_ramen', 9),
#  ('staff_super_friendly', 9),
#  ('give_place_try', 9),
#  ('best_ramen_ever', 9),
#  ('original_shiro_ramen', 9),
#  ('spicy_tonkotsu_ramen', 9),
#  ('belly_pork_shoulder', 9),
#  ('ramen_ive_ever', 9),
#  ('santa_barbara_definitely', 8),
#  ('go_back_again', 8),
#  ('cant_wait_return', 8),
#  ('trip_santa_barbara', 8),
#  ('green_tea_ice', 8),
#  ('tea_ice_cream', 8),
#  ('next_time_were', 8),
#  ('great_food_service', 8),
#  ('menu_per_person', 8),
#  ('would_give_stars', 8),
#  ('one_best_restaurants', 8),
#  ('six_step_salmon', 8),
#  ('state_street_roll', 8),
#  ('best_sushi_sb', 8),
#  ('red_dragon_roll', 8),
#  ('new_years_eve', 8),
#  ('made_us_feel', 8),
#  ('thick_noodles_pork', 8),
#  ('food_excellent_service', 7),
#  ('santa_barbara_weekend', 7),
#  ('time_santa_barbara', 7),
#  ('high_quality_ingredients', 7),
#  ('santa_barbara_place', 7),
#  ('best_dining_experience', 7),
#  ('garlic_beef_pepper', 7),
#  ('one_favorite_places', 7),
#  ('food_came_quickly', 7),
#  ('overall_great_experience', 7),
#  ('next_time_visit', 7),
#  ('braised_pork_belly', 7),
#  ('sushi_place_town', 7),
#  ('lived_santa_barbara', 7),
#  ('staff_friendly_attentive', 7),
#  ('new_sushi_place', 7),
#  ('heard_good_things', 7),
#  ('coming_back_again', 7),
#  ('go_santa_barbara', 7),
#  ('food_even_better', 7),
#  ('restaurant_next_door', 7),
#  ('black_sheep_one', 7),
#  ('try_tasting_menu', 7),
#  ('sugar_snap_peas', 7),
#  ('cant_say_enough', 7),
#  ('tasting_menu_per', 7),
#  ('best_ramen_santa', 7),
#  ('delicious_pork_belly', 7),
#  ('gambas_al_ajillo', 7),
#  ('went_black_sheep', 7),
#  ('ordered_shoyu_ramen', 7),
#  ('tonkotsu_original_shiro', 7),
#  ('tonkotsu_spicy_aka', 7),
#  ('spicy_tonkatsu_ramen', 7),
#  ('favorite_ramen_place', 7),
#  ('ordered_kuro_ramen', 7),
#  ('added_soft_boiled', 7),
#  ('ramen_thick_noodles', 7),
#  ('get_spicy_ramen', 7),
#  ('mikes_dancing_pants', 7),
#  ('santa_barbara_im', 6),
#  ('food_santa_barbara', 6),
#  ('best_japanese_restaurant', 6),
#  ('love_japanese_food', 6),
#  ('seven_course_meal', 6),
#  ('high_quality_fish', 6),
#  ('find_santa_barbara', 6),
#  ('hidden_gem_santa', 6),
#  ('course_tasting_menu', 6),
#  ('get_anywhere_else', 6),
#  ('garlic_beef_rice', 6),
#  ('santa_barbara_fish', 6),
#  ('good_asian_food', 6),
#  ('santa_barbara_hands', 6),
#  ('barbara_hands_down', 6),
#  ('honestly_one_best', 6),
#  ('dinner_last_night', 6),
#  ('next_time_ill', 6),
#  ('best_restaurant_santa', 6),
#  ('good_highly_recommend', 6),
#  ('can_not_say', 6),
#  ('definitely_recommend_place', 6),
#  ('staff_super_nice', 6),
#  ('sushi_long_time', 6),
#  ('favorite_restaurant_sb', 6),
#  ('soft_shell_crab', 6),
#  ('sushi_spot_santa', 6),
#  ('definitely_back_next', 6),
#  ('salmon_six_step', 6),
#  ('time_im_town', 6),
#  ('toro_blue_fin', 6),
#  ('salmon_delight_roll', 6),
#  ('santa_barbara_sushi', 6),
#  ('found_place_yelp', 6),
#  ('sushi_restaurant_santa', 6),
#  ('service_top_notch', 6),
#  ('best_sushi_restaurant', 6),
#  ('staff_extremely_friendly', 6),
#  ('amazing_food_service', 6),
#  ('thank_black_sheep', 6),
#  ('check_place_out', 6),
#  ('im_big_fan', 6),
#  ('carrots_duck_fat', 6),
#  ('really_wanted_like', 6),
#  ('dining_experiences_ive', 6),
#  ('im_glad_found', 6),
#  ('around_santa_barbara', 6),
#  ('broth_rich_flavorful', 6),
#  ('place_great_food', 6),
#  ('probably_best_ramen', 6),
#  ('happy_hour_menu', 6),
#  ('place_really_good', 6),
#  ('pork_belly_sliders', 6),
#  ('best_meal_ive', 6),
#  ('ordered_spicy_ramen', 6),
#  ('one_best_ramen', 6),
#  ('tonkotsu_spicy_ramen', 6),
#  ('shoyu_ramen_chicken', 6),
#  ('ramen_place_goleta', 6),
#  ('rice_spicy_tuna', 6),
#  ('pork_belly_chashu', 6),
#  ('santa_barbara_public', 6),
#  ('barbara_public_market', 6),
#  ('addition_santa_barbara', 5),
#  ('japanese_restaurant_santa', 5),
#  ('course_kaiseki_dinner', 5),
#  ('next_time_santa', 5),
#  ('service_amazing_food', 5),
#  ('wait_staff_attentive', 5),
#  ('weve_ever_had', 5),
#  ('im_looking_forward', 5),
#  ('looking_forward_next', 5),
#  ('meals_ive_ever', 5),
#  ('best_meals_ive', 5),
#  ('perfect_date_night', 5),
#  ('curry_beef_udon', 5),
#  ('santa_barbara_last', 5),
#  ('grilled_duck_breast', 5),
#  ('reason_im_giving', 5),
#  ('garlic_pepper_beef', 5),
#  ('sweet_soy_sauce', 5),
#  ('best_poke_place', 5),
#  ('staff_friendly_accommodating', 5),
#  ('experience_santa_barbara', 5),
#  ('day_santa_barbara', 5),
#  ('really_really_good', 5),
#  ('customer_service_great', 5),
#  ('makes_feel_like', 5),
#  ('pepper_beef_plate', 5),
#  ('food_pretty_good', 5),
#  ('santa_barbara_fresh', 5),
#  ('new_favorite_restaurant', 5),
#  ('love_love_love', 5),
#  ('ill_definitely_back', 5),
#  ('got_food_poisoning', 5),
#  ('eat_santa_barbara', 5),
#  ('would_go_again', 5),
#  ('local_santa_barbara', 5),
#  ('good_must_try', 5),
#  ('time_sun_sushi', 5),
#  ('sushi_places_sb', 5),
#  ('best_sushi_restaurants', 5),
#  ('santa_barbara_service', 5),
#  ('fish_high_quality', 5),
#  ('decided_give_try', 5),
#  ('salmon_skin_roll', 5),
#  ('great_service_good', 5),
#  ('salmon_skin_salad', 5),
#  ('hands_best_sushi', 5),
#  ('sushi_restaurants_town', 5),
#  ('santa_barbara_ive', 5),
#  ('beef_short_rib', 5),
#  ('amazing_dining_experience', 5),
#  ('fish_super_fresh', 5),
#  ('yellow_tail_delight', 5),
#  ('come_back_here', 5),
#  ('santa_barbara_county', 5),
#  ('japanese_fried_chicken', 5),
#  ('service_good_food', 5),
#  ('came_miso_soup', 5),
#  ('not_say_enough', 5),
#  ('im_santa_barbara', 5),
#  ('good_wine_list', 5),
#  ('salad_bone_marrow', 5),
#  ('im_glad_did', 5),
#  ('back_black_sheep', 5),
#  ('wanted_like_place', 5),
#  ('glad_found_place', 5),
#  ('back_try_more', 5),
#  ('braised_short_rib', 5),
#  ('would_recommend_place', 5),
#  ('good_service_good', 5),
#  ('would_definitely_return', 5),
#  ('table_behind_us', 5),
#  ('one_favorite_restaurants', 5),
#  ('bone_marrow_toast', 5),
#  ('black_sheep_food', 5),
#  ('black_sheep_family', 5),
#  ('give_place_stars', 5),
#  ('give_stars_could', 5),
#  ('braised_beef_cheeks', 5),
#  ('got_pork_belly', 5),
#  ('highly_highly_recommend', 5),
#  ('im_pretty_sure', 5),
#  ('looking_forward_returning', 5),
#  ('boy_glad_did', 5),
#  ('get_pork_belly', 5),
#  ('good_food_great', 5),
#  ('flourless_chocolate_cake', 5),
#  ('want_come_back', 5),
#  ('broth_ive_ever', 5),
#  ('ramen_ever_had', 5),
#  ('good_ramen_place', 5),
#  ('ordered_tonkotsu_original', 5),
#  ('noodles_pork_shoulder', 5),
#  ('pork_belly_delicious', 5),
#  ('aka_ramen_pork', 5),
#  ('ramen_place_ive', 5),
#  ('black_garlic_ramen', 5),
#  ('ordered_tonkotsu_spicy', 5),
#  ('ramen_chicken_chashu', 5),
#  ('seared_salmon_belly', 5),
#  ('ramen_places_santa', 5),
#  ('best_ramen_town', 5),
#  ('addition_public_market', 5),
#  ('inside_santa_barbara', 5),
#  ('dancing_pants_roll', 5),
#  ('yoichis_last_night', 4),
#  ('wonderful_dining_experience', 4),
#  ('live_santa_barbara', 4),
#  ('back_amazing_food', 4),
#  ('super_fresh_fish', 4),
#  ('best_japanese_food', 4),
#  ('ever_santa_barbara', 4),
#  ('definitely_recommend_restaurant', 4),
#  ('back_one_best', 4),
#  ('loved_every_bite', 4),
#  ('santa_barbara_wanted', 4),
#  ('authentic_japanese_food', 4),
#  ('prix_fixe_menu', 4),
#  ('santa_barbara_restaurant', 4),
#  ('cuisine_santa_barbara', 4),
#  ('service_great_well', 4),
#  ('near_santa_barbara', 4),
#  ('really_good_went', 4),
#  ('service_excellent_well', 4),
#  ('dining_experience_service', 4),
#  ('food_ive_ever', 4),
#  ('beef_rice_cheese', 4),
#  ('service_highly_recommend', 4),
#  ('garlic_shoyu_sauce', 4),
#  ('beef_rice_plate', 4),
#  ('never_anything_like', 4),
#  ('make_sure_everything', 4),
#  ('ordered_garlic_beef', 4),
#  ('first_time_came', 4),
#  ('make_sure_get', 4),
#  ('came_first_time', 4),
#  ('place_hidden_gem', 4),
#  ('service_super_fast', 4),
#  ('lychee_rose_drink', 4),
#  ('favorite_place_eat', 4),
#  ('fantastic_food_great', 4),
#  ('good_things_place', 4),
#  ('maybe_next_time', 4),
#  ('santa_barbara_would', 4),
#  ('fish_tasted_fresh', 4),
#  ('food_came_quick', 4),
#  ('great_date_night', 4),
#  ('definitely_worth_it', 4),
#  ('experiences_ive_ever', 4),
#  ('sweet_potato_fries', 4),
#  ('service_quality_food', 4),
#  ('experience_sun_sushi', 4),
#  ('would_order_again', 4),
#  ('avocado_eel_roll', 4),
#  ('love_sun_sushi', 4),
#  ('every_single_dish', 4),
#  ('every_single_one', 4),
#  ('thing_would_change', 4),
#  ('fresh_melted_mouth', 4),
#  ('favorite_sushi_restaurant', 4),
#  ('new_sushi_spot', 4),
#  ('went_friday_night', 4),
#  ('sb_highly_recommend', 4),
#  ('service_good_too', 4),
#  ('best_sushi_ever', 4),
#  ('salmon_six_steps', 4),
#  ('sun_sushi_friends', 4),
#  ('roll_rainbow_roll', 4),
#  ('excited_try_place', 4),
#  ('get_pay_for', 4),
#  ('place_best_sushi', 4),
#  ('overall_really_good', 4),
#  ('came_friday_night', 4),
#  ('quality_food_service', 4),
#  ('sushi_absolutely_amazing', 4),
#  ('fast_friendly_service', 4),
#  ('friendly_service_great', 4),
#  ('service_great_atmosphere', 4),
#  ('high_end_sushi', 4),
#  ('favorite_sushi_spot', 4),
#  ('far_best_sushi', 4),
#  ('roll_spicy_tuna', 4),
#  ('santa_barbara_really', 4),
#  ('ive_long_time', 4),
#  ('cant_wait_try', 4),
#  ('wait_try_items', 4),
#  ('ever_had_highly', 4),
#  ('had_highly_recommend', 4),
#  ('service_also_great', 4),
#  ('everything_ive_ever', 4),
#  ('ive_fair_share', 4),
#  ('fish_always_fresh', 4),
#  ('went_first_time', 4),
#  ('place_go_to', 4),
#  ('weekend_santa_barbara', 4),
#  ('new_goto_sushi', 4),
#  ('one_best_places', 4),
#  ('amazing_food_great', 4),
#  ('time_visit_santa', 4),
#  ('santa_barbara_first', 4),
#  ('dinner_friday_night', 4),
#  ('tempura_ice_cream', 4),
#  ('really_good_food', 4),
#  ('menu_highly_recommend', 4),
#  ('ordered_pork_belly', 4),
#  ('beef_cheeks_pork', 4),
#  ('cheeks_pork_belly', 4),
#  ('the_black_sheep', 4),
#  ('pork_belly_good', 4),
#  ('ramen_im_sure', 4),
#  ('cooked_duck_fat', 4),
#  ('ramen_places_ive', 4),
#  ('bone_marrow_amazing', 4),
#  ('marrow_bruschetta_duck', 4),
#  ('bruschetta_duck_confit', 4),
#  ('try_black_sheep', 4),
#  ('wild_boar_short', 4),
#  ('ramen_one_best', 4),
#  ('not_wait_go', 4),
#  ('whole_grain_mustard', 4),
#  ('pork_belly_egg', 4),
#  ('looking_forward_trying', 4),
#  ('happy_hour_pm', 4),
#  ('bone_marrow_crostini', 4),
#  ('wild_boar_ribs', 4),
#  ('table_next_us', 4),
#  ('pork_belly_tender', 4),
#  ('recommend_black_sheep', 4),
#  ('santa_barbara_finally', 4),
#  ('finally_good_ramen', 4),
#  ('broth_pork_belly', 4),
#  ('pork_belly_added', 4),
#  ('time_im_santa', 4),
#  ('love_place_food', 4),
#  ('blue_cheese_salad', 4),
#  ('outside_tender_inside', 4),
#  ('visited_black_sheep', 4),
#  ('santa_barbara_good', 4),
#  ('ramen_great_service', 4),
#  ('recommend_bone_marrow', 4),
#  ('family_style_tasting', 4),
#  ('style_tasting_menu', 4),
#  ('ramen_bone_marrow', 4),
#  ('go_back_next', 4),
#  ('delicious_bone_marrow', 4),
#  ('meat_fell_bone', 4),
#  ('came_greet_us', 4),
#  ('hands_one_best', 4),
#  ('decided_tasting_menu', 4),
#  ('food_attentive_service', 4),
#  ('time_visit_sb', 4),
#  ('marrow_bruschetta_risotto', 4),
#  ('came_check_us', 4),
#  ('good_bone_marrow', 4),
#  ('ordered_duck_confit', 4),
#  ('duck_confit_pork', 4),
#  ('confit_pork_belly', 4),
#  ('amazing_food_even', 4),
#  ('place_amazing_food', 4),
#  ('best_part_meal', 4),
#  ('even_better_service', 4),
#  ('small_plates_got', 4),
#  ('black_sheep_dinner', 4),
#  ('meal_santa_barbara', 4),
#  ('found_black_sheep', 4),
#  ('crispy_outside_tender', 4),
#  ('best_food_ever', 4),
#  ('even_chef_came', 4),
#  ('one_best_ive', 4),
#  ('definitely_recommend_anyone', 4),
#  ('first_time_visiting', 4),
#  ('going_back_again', 4),
#  ('ordered_pork_shoulder', 4),
#  ('thank_nikka_ramen', 4),
#  ('ramen_place_town', 4),
#  ('places_ive_tried', 4),
#  ('thin_noodles_pork', 4),
#  ('pork_belly_broth', 4),
#  ('shiro_ramen_pork', 4),
#  ('got_spicy_ramen', 4),
#  ('definitely_best_ramen', 4),
#  ('authentic_ramen_place', 4),
#  ('place_nikka_ramen', 4),
#  ('pork_shoulder_delicious', 4),
#  ('tonkotsu_broth_rich', 4),
#  ('looking_good_ramen', 4),
#  ('ordered_spicy_tonkotsu', 4),
#  ('ramen_place_go', 4),
#  ('pork_belly_really', 4),
#  ('broth_rich_creamy', 4),
#  ('right_amount_spice', 4),
#  ('great_ramen_place', 4),
#  ('ramen_place_santa', 4),
#  ('pork_belly_meat', 4),
#  ('tonkatsu_ramen_pork', 4),
#  ('spicy_ramen_chicken', 4),
#  ('pork_shoulder_tender', 4),
#  ('pork_shoulder_thick', 4),
#  ('shoulder_thick_noodles', 4),
#  ('back_many_times', 4),
#  ('best_ramen_sb', 4),
#  ('thick_thin_noodles', 4),
#  ('always_get_spicy', 4),
#  ('public_market_food', 4),
#  ('lion_king_roll', 4),
#  ('sb_craft_noodles', 4),
#  ('sb_craft_ramen', 4),
#  ('barbara_food_scene', 3),
#  ('authentic_japanese_restaurant', 3),
#  ('service_perfect_food', 3),
#  ('experiences_santa_barbara', 3),
#  ('best_restaurant_sb', 3),
#  ('little_gem_santa', 3),
#  ('loved_it_service', 3),
#  ('it_service_great', 3),
#  ('not_wait_come', 3),
#  ('sushi_great_service', 3),
#  ('real_japanese_food', 3),
#  ('im_giving_stars', 3),
#  ('never_go_back', 3),
#  ('great_course_meal', 3),
#  ('service_really_good', 3),
#  ('santa_barbara_went', 3),
#  ('santa_barbara_best', 3),
#  ('great_service_nice', 3),
#  ('good_kaiseki_meal', 3),
#  ('santa_barbara_many', 3),
#  ('one_favorite_dishes', 3),
#  ('fish_incredibly_fresh', 3),
#  ('place_must_try', 3),
#  ('anywhere_else_sb', 3),
#  ('delicious_prices_reasonable', 3),
#  ('best_authentic_japanese', 3),
#  ('japanese_food_ive', 3),
#  ('one_favorite_meals', 3),
#  ('authentic_japanese_cuisine', 3),
#  ('best_santa_barbara', 3),
#  ('expect_high_quality', 3),
#  ('area_make_point', 3),
#  ('santa_barbara_unique', 3),
#  ('come_back_heartbeat', 3),
#  ('delicious_perfectly_proportioned', 3),
#  ('experience_per_person', 3),
#  ('menu_every_dish', 3),
#  ('cant_get_anywhere', 3),
#  ('la_carte_menu', 3),
#  ('got_kimchi_beef', 3),
#  ('beef_udon_added', 3),
#  ('decided_give_place', 3),
#  ('give_another_shot', 3),
#  ('id_definitely_come', 3),
#  ('eat_every_day', 3),
#  ('practically_melted_mouth', 3),
#  ('quality_sushi_sashimi', 3),
#  ('boyfriend_wanted_try', 3),
#  ('try_kaiseki_meal', 3),
#  ('encouraged_us_try', 3),
#  ('curry_beef_rice', 3),
#  ('great_service_highly', 3),
#  ('santa_barbara_big', 3),
#  ('fresh_sashimi_sushi', 3),
#  ('place_good_food', 3),
#  ('expensive_small_portions', 3),
#  ('find_good_sushi', 3),
#  ('definitely_recommend_coming', 3),
#  ('great_place_eat', 3),
#  ('actually_really_good', 3),
#  ('really_good_would', 3),
#  ('well_thought_out', 3),
#  ('sushi_ive_ever', 3),
#  ('better_pepper_lunch', 3),
#  ('super_nice_friendly', 3),
#  ('definitely_recommend_trying', 3),
#  ('like_raw_fish', 3),
#  ('sure_like_it', 3),
#  ('im_excited_try', 3),
#  ('last_time_went', 3),
#  ('santa_barbara_always', 3),
#  ('also_pretty_good', 3),
#  ('service_definitely_coming', 3),
#  ('back_first_time', 3),
#  ('flavorful_pork_belly', 3),
#  ('nothing_write_home', 3),
#  ('write_home_about', 3),
#  ('sweet_fish_roe', 3),
#  ('enjoyed_every_bite', 3),
#  ('time_last_night', 3),
#  ('experience_highly_recommend', 3),
#  ('poke_place_iv', 3),
#  ('first_time_here', 3),
#  ('pretty_good_best', 3),
#  ('ive_ever_tried', 3),
#  ('better_santa_barbara', 3),
#  ('dining_experience_santa', 3),
#  ('better_poke_ceviche', 3),
#  ('told_would_ready', 3),
#  ('would_ready_minutes', 3),
#  ('great_service_food', 3),
#  ('out_first_time', 3),
#  ('food_definitely_come', 3),
#  ('awesome_customer_service', 3),
#  ('grilled_steamed_dishes', 3),
#  ('really_good_portions', 3),
#  ('staff_really_nice', 3),
#  ('go_anywhere_else', 3),
#  ('service_great_every', 3),
#  ('best_service_ever', 3),
#  ('every_time_ive', 3),
#  ('would_love_go', 3),
#  ('santa_barbara_small', 3),
#  ('back_next_trip', 3),
#  ('soy_sauce_marinated', 3),
#  ('santa_barbara_looking', 3),
#  ('definitely_must_try', 3),
#  ('decided_try_new', 3),
#  ('good_place_eat', 3),
#  ('highest_quality_fish', 3),
#  ('good_poke_bowl', 3),
#  ('glad_place_opened', 3),
#  ('best_decision_ever', 3),
#  ('food_five_stars', 3),
#  ('high_end_restaurant', 3),
#  ('im_giving_place', 3),
#  ('die_for_service', 3),
#  ('try_place_out', 3),
#  ('save_money_go', 3),
#  ('go_somewhere_else', 3),
#  ('friendly_service_food', 3),
#  ('albacore_delight_roll', 3),
#  ('town_hands_down', 3),
#  ('let_us_know', 3),
#  ('experiences_ive_had', 3),
#  ('roll_eel_avocado', 3),
#  ('super_excited_try', 3),
#  ('ill_definitely_going', 3),
#  ('goto_sushi_place', 3),
#  ('definitely_back_soon', 3),
#  ('date_night_spot', 3),
#  ('yellowtail_delight_roll', 3),
#  ('pretty_good_nice', 3),
#  ('great_place_great', 3),
#  ('wait_get_seated', 3),
#  ('shrimp_tempura_roll', 3),
#  ('highly_recommend_everyone', 3),
#  ('high_quality_fresh', 3),
#  ('made_dining_experience', 3),
#  ('try_new_sushi', 3),
#  ('goto_sushi_spot', 3),
#  ('service_great_staff', 3),
#  ('would_definitely_back', 3),
#  ('ill_back_next', 3),
#  ('roll_state_street', 3),
#  ('went_sun_sushi', 3),
#  ('sun_sushi_great', 3),
#  ('sit_sushi_bar', 3),
#  ('fresh_melt_mouth', 3),
#  ('salad_miso_soup', 3),
#  ('roll_tempura_batter', 3),
#  ('tempura_batter_light', 3),
#  ('anywhere_else_town', 3),
#  ('recommend_sun_sushi', 3),
#  ('walk_state_street', 3),
#  ('roll_volcano_roll', 3),
#  ('everyone_super_nice', 3),
#  ('got_ta_try', 3),
#  ('new_favorite_sushi', 3),
#  ('best_sushi_bar', 3),
#  ('night_without_reservation', 3),
#  ('impressed_quality_food', 3),
#  ('good_second_time', 3),
#  ('fin_tuna_special', 3),
#  ('definitely_back_thank', 3),
#  ('sun_sushi_always', 3),
#  ('sweet_shrimp_sushi', 3),
#  ('ordered_seaweed_salad', 3),
#  ('great_way_end', 3),
#  ('great_would_definitely', 3),
#  ('sushi_pretty_good', 3),
#  ('reasonably_priced_sushi', 3),
#  ('use_soy_sauce', 3),
#  ('people_would_like', 3),
#  ('best_sushi_long', 3),
#  ('sushi_spot_sb', 3),
#  ('would_like_try', 3),
#  ('try_next_time', 3),
#  ('taking_good_care', 3),
#  ('tempura_lobster_roll', 3),
#  ('definitely_best_sushi', 3),
#  ('highly_recommend_salmon', 3),
#  ('sushi_always_fresh', 3),
#  ('love_place_much', 3),
#  ('roll_mexican_roll', 3),
#  ('roll_spider_roll', 3),
#  ('little_hole_wall', 3),
#  ('year_old_daughter', 3),
#  ('best_sushi_place', 3),
#  ('fish_really_fresh', 3),
#  ('highly_recommend_sushi', 3),
#  ('santa_barbara_years', 3),
#  ('service_food_great', 3),
#  ('really_loved_place', 3),
#  ('really_disappointed_service', 3),
#  ('sushi_place_ever', 3),
#  ('never_go_wrong', 3),
#  ('long_time_customer', 3),
#  ('come_again_great', 3),
#  ('high_quality_sushi', 3),
#  ('melt_mouth_delicious', 3),
#  ('crispy_spicy_tuna', 3),
#  ('definitely_come_again', 3),
#  ('santa_barbara_long', 3),
#  ('miso_soup_salad', 3),
#  ('tuna_six_step', 3),
#  ('heard_great_things', 3),
#  ('also_got_two', 3),
#  ('try_something_new', 3),
#  ('good_also_got', 3),
#  ('sushi_also_delicious', 3),
#  ('spicy_tuna_spicy', 3),
#  ('honestly_best_sushi', 3),
#  ('recommend_everyone_try', 3),
#  ('im_bay_area', 3),
#  ('to_die_for', 3),
#  ('sunny_press_box', 3),
#  ('delicious_great_service', 3),
#  ('sushi_places_santa', 3),
#  ('santa_barbara_love', 3),
#  ('barbara_area_best', 3),
#  ('crispy_rice_amazing', 3),
#  ('try_items_menu', 3),
#  ('going_back_soon', 3),
#  ('atmosphere_nice_food', 3),
#  ('great_food_even', 3),
#  ('experience_best_sushi', 3),
#  ('santa_barbara_came', 3),
#  ('good_quality_sushi', 3),
#  ('recommend_place_food', 3),
#  ('every_time_go', 3),
#  ('great_dining_experience', 3),
#  ('fresh_service_great', 3),
#  ('great_highly_recommend', 3),
#  ('really_good_well', 3),
#  ('family_tasting_menu', 3),
#  ('tasting_menu_option', 3),
#  ('black_sheep_nachos', 3),
#  ('food_ambiance_service', 3),
#  ('asian_fusion_food', 3),
#  ('got_tasting_menu', 3),
#  ('blistered_snap_peas', 3),
#  ('marrow_bruschetta_die', 3),
#  ('bruschetta_die_for', 3),
#  ('service_excellent_friendly', 3),
#  ('wagyu_skirt_steak', 3),
#  ('food_black_sheep', 3),
#  ('amazing_bone_marrow', 3),
#  ('food_delicious_got', 3),
#  ('eat_black_sheep', 3),
#  ('scallop_crudo_delicious', 3),
#  ('go_back_great', 3),
#  ('next_time_town', 3),
#  ('ramen_best_ive', 3),
#  ('best_ive_santa', 3),
#  ('sweetbreads_duck_confit', 3),
#  ('lamb_shank_everything', 3),
#  ('recommend_santa_barbara', 3),
#  ('staff_friendly_helpful', 3),
#  ('good_bowl_ramen', 3),
#  ('ever_had_definitely', 3),
#  ('appetizer_main_course', 3),
#  ('black_sheep_great', 3),
#  ('duck_confit_sea', 3),
#  ('confit_sea_bass', 3),
#  ('working_really_hard', 3),
#  ('one_santa_barbaras', 3),
#  ('santa_barbara_great', 3),
#  ('ordered_tasting_menu', 3),
#  ('black_sheep_really', 3),
#  ('food_bone_marrow', 3),
#  ('black_sheep_would', 3),
#  ('tried_black_sheep', 3),
#  ('forward_next_visit', 3),
#  ('dining_experience_ive', 3),
#  ('new_favorite_spot', 3),
#  ('small_plates_share', 3),
#  ('good_every_time', 3),
#  ('fine_dining_experience', 3),
#  ('excellent_dining_experience', 3),
#  ('boar_short_ribs', 3),
#  ('time_eating_here', 3),
#  ('ordered_scallop_crudo', 3),
#  ('hands_best_service', 3),
#  ('try_bone_marrow', 3),
#  ('food_well_prepared', 3),
#  ('waygu_beef_carpaccio', 3),
#  ('carpaccio_la_pho', 3),
#  ('crudo_beet_salad', 3),
#  ('know_good_ramen', 3),
#  ('pieces_pork_belly', 3),
#  ('service_excellent_staff', 3),
#  ('santa_barbara_wow', 3),
#  ('evening_black_sheep', 3),
#  ('really_good_service', 3),
#  ('go_back_black', 3),
#  ('find_better_ramen', 3),
#  ('amazing_food_amazing', 3),
#  ('service_really_nice', 3),
#  ('well_taken_care', 3),
#  ('food_amazing_service', 3),
#  ('experience_first_time', 3),
#  ('pork_belly_cooked', 3),
#  ('food_took_long', 3),
#  ('took_long_time', 3),
#  ('food_friendly_staff', 3),
#  ('highly_recommend_black', 3),
#  ('back_again_great', 3),
#  ('everyone_super_friendly', 3),
#  ('flat_iron_steak', 3),
#  ('beef_marrow_bruschetta', 3),
#  ('marrow_bruschetta_ahi', 3),
#  ('next_time_come', 3),
#  ('great_wine_beer', 3),
#  ('it_pork_belly', 3),
#  ('food_good_nothing', 3),
#  ('place_feels_like', 3),
#  ('ramen_every_time', 3),
#  ('every_time_im', 3),
#  ('pork_belly_shiitake', 3),
#  ('well_definitely_back', 3),
#  ('niman_ranch_beef', 3),
#  ('ranch_beef_shortribs', 3),
#  ('wasabi_mashed_potatoes', 3),
#  ('blown_away_food', 3),
#  ('hope_come_back', 3),
#  ('santa_barbara_every', 3),
#  ('definitely_would_recommend', 3),
#  ('short_rib_special', 3),
#  ('experience_cant_wait', 3),
#  ('chef_even_came', 3),
#  ('atmosphere_highly_recommend', 3),
#  ('braised_short_ribs', 3),
#  ('every_time_come', 3),
#  ('feel_like_family', 3),
#  ('delicious_highly_recommend', 3),
#  ('feel_like_im', 3),
#  ('every_single_thing', 3),
#  ('really_looking_forward', 3),
#  ('little_bit_everything', 3),
#  ('bone_marrow_appetizer', 3),
#  ('chose_tasting_menu', 3),
#  ('chef_came_greet', 3),
#  ('wait_staff_great', 3),
#  ('great_atmosphere_nice', 3),
#  ('every_time_visit', 3),
#  ('black_sheep_awesome', 3),
#  ('called_black_sheep', 3),
#  ('best_food_ive', 3),
#  ('tasting_menu_person', 3),
#  ('white_marinated_anchovies', 3),
#  ('cream_puff_dessert', 3),
#  ('everything_ordered_delicious', 3),
#  ('salad_duck_confit', 3),
#  ('duck_confit_special', 3),
#  ('restaurant_excellent_place', 3),
#  ('staff_friendly_highly', 3),
#  ('recommend_anyone_looking', 3),
#  ('bone_marrow_dish', 3),
#  ('black_sheep_last', 3),
#  ('remember_last_time', 3),
#  ('ordered_risotto_special', 3),
#  ('tasting_menu_best', 3),
#  ('stop_santa_barbara', 3),
#  ('restaurant_downtown_santa', 3),
#  ('good_food_good', 3),
#  ('tasting_menu_worth', 3),
#  ('totally_worth_it', 3),
#  ('wagu_beef_carpaccio', 3),
#  ('wish_lived_closer', 3),
#  ('like_bone_marrow', 3),
#  ('first_time_went', 3),
#  ('ive_ever_tasted', 3),
#  ('goat_cheese_panna', 3),
#  ('cheese_panna_cotta', 3),
#  ('friday_night_reservations', 3),
#  ('wine_list_also', 3),
#  ('snap_peas_potato', 3),
#  ('ribs_duck_confit', 3),
#  ('come_back_town', 3),
#  ('ive_never_anything', 3),
#  ('much_better_places', 3),
#  ('restaurant_great_food', 3),
#  ('make_things_right', 3),
#  ('delicious_staff_friendly', 3),
#  ('place_fine_dining', 3),
#  ('ordered_duck_leg', 3),
#  ('blood_orange_zest', 3),
#  ('marrow_bruschetta_pear', 3),
#  ('time_tasting_menu', 3),
#  ('ive_ever_life', 3),
#  ('done_tasting_menu', 3),
#  ('opted_tasting_menu', 3),
#  ('gnocchi_duck_confit', 3),
#  ('almond_financier_dessert', 3),
#  ('made_feel_like', 3),
#  ('first_time_ive', 3),
#  ('wine_selection_great', 3),
#  ('marrow_bruschetta_sweetbreads', 3),
#  ('visited_santa_barbara', 3),
#  ('amazing_place_great', 3),
#  ('beet_salad_excellent', 3),
#  ('la_carte_items', 3),
#  ('little_gem_salad', 3),
#  ('hands_down_one', 3),
#  ('staff_friendly_nice', 3),
#  ('food_absolutely_delicious', 3),
#  ('service_excellent_food', 3),
#  ('experience_ever_had', 3),
#  ('one_star_service', 3),
#  ('got_bone_marrow', 3),
#  ('amazing_service_food', 3),
#  ('feuille_de_brick', 3),
#  ('amazing_would_recommend', 3),
#  ('tasting_menu_wine', 3),
#  ('minutes_get_food', 3),
#  ('start_review_saying', 3),
#  ('got_beet_salad', 3),
#  ('next_time_well', 3),
#  ('flourless_chocolate_torte', 3),
#  ('chefs_choice_tasting', 3),
#  ('choice_tasting_menu', 3),
#  ('meal_ive_santa', 3),
#  ('santa_barbara_also', 3),
#  ('also_really_good', 3),
#  ('best_sushi_experiences', 3),
#  ('ive_ever_eaten', 3),
#  ('great_staff_friendly', 3),
#  ('typical_tonkotsu_ramen', 3),
#  ('got_shoyu_ramen', 3),
#  ('black_sheep_menu', 3),
#  ('really_enjoyed_food', 3),
#  ('service_spot_on', 3),
#  ('return_next_time', 3),
#  ('stayed_santa_barbara', 3),
#  ('first_time_ever', 3),
#  ('good_food_nice', 3),
#  ('food_delicious_staff', 3),
#  ('pork_belly_black', 3),
#  ('service_also_really', 3),
#  ('garlic_oil_ramen', 3),
#  ('favorite_ramen_spot', 3),
#  ('hands_best_ramen', 3),
#  ('nikka_japanese_market', 3),
#  ('ramen_place_open', 3),
#  ('ramen_spot_sb', 3),
#  ('pork_belly_amazing', 3),
#  ('deep_fried_egg', 3),
#  ('tonkotsu_original_ramen', 3),
#  ('original_ramen_pork', 3),
#  ('ramen_place_sb', 3),
#  ('far_best_ramen', 3),
#  ('good_best_ramen', 3),
#  ('tonkotsu_ramen_pork', 3),
#  ('love_ramen_place', 3),
#  ('back_again_ramen', 3),
#  ('coming_back_place', 3),
#  ('ramen_place_area', 3),
#  ('seated_within_minutes', 3),
#  ('ramen_shoyu_ramen', 3),
#  ('pork_shoulder_belly', 3),
#  ('rich_flavorful_creamy', 3),
#  ('great_quality_ramen', 3),
#  ('since_theyve_opened', 3),
#  ('recommend_black_garlic', 3),
#  ('tried_chicken_chashu', 3),
#  ('prefer_pork_shoulder', 3),
#  ('love_nikka_ramen', 3),
#  ...]

# %% [markdown]
# ### Healthy

# %%
Healthy = business_df[business_df.Type=='Healthy']
Healthy_review = review1[review1.business_id.isin(Healthy.business_id.values)]
Healthy_review["text"] = Healthy_review["text"].str.lower()
Healthy_review['text'] = Healthy_review['text'].apply(lambda text: cleaning_stopwords(text))
Healthy_review['text']= Healthy_review['text'].apply(lambda x: cleaning_punctuations(x))
Healthy_review['text'] = Healthy_review['text'].apply(lambda x: cleaning_repeating_char(x))
Healthy_review['text'] = Healthy_review['text'].apply(lambda x: cleaning_URLs(x))
Healthy_review['text'] = Healthy_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Healthy=Healthy[Healthy.stars<3.5]
bad_Healthy_review = Healthy_review[Healthy_review.business_id.isin(bad_Healthy.business_id.values)]
bad_Healthy_review_text = bad_Healthy_review.text.str.cat(sep = " ")
bad_Healthy_tokens = word_tokenize(bad_Healthy_review_text)

bigrams_list_bad_Healthy = ["_".join(item) for item in nltk.bigrams(bad_Healthy_tokens)]
trigrams_list_bad_Healthy = ["_".join(item) for item in nltk.trigrams(bad_Healthy_tokens)]
# FreqDist(bad_Healthy_tokens).most_common()
# FreqDist(bigrams_list_bad_Healthy).most_common()
FreqDist(trigrams_list_bad_American).most_common()
# Out:
# [('fried_chicken_sandwich', 7),
#  ('mac_n_cheese', 6),
#  ('coral_tree_cafe', 5),
#  ('food_good_service', 5),
#  ('definitely_recommend_place', 5),
#  ('also_pretty_good', 4),
#  ('im_big_fan', 4),
#  ('table_next_us', 4),
#  ('would_definitely_recommend', 4),
#  ('great_beer_selection', 4),
#  ('beer_selection_excellent', 4),
#  ('too_seems_like', 4),
#  ('public_market_garden', 4),
#  ('santa_barbara_public', 4),
#  ('barbara_public_market', 4),
#  ('going_somewhere_else', 3),
#  ('lemon_poppy_seed', 3),
#  ('definitely_come_back', 3),
#  ('took_long_time', 3),
#  ('molten_chocolate_cake', 3),
#  ('main_dining_area', 3),
#  ('chicken_enchilada_soup', 3),
#  ('never_going_back', 3),
#  ('service_really_good', 3),
#  ('good_service_food', 3),
#  ('food_pretty_good', 3),
#  ('cant_go_wrong', 3),
#  ('every_time_go', 3),
#  ('worst_service_ever', 3),
#  ('never_go_back', 3),
#  ('great_service_food', 3),
#  ('loaded_mashed_potatoes', 3),
#  ('got_seated_right', 3),
#  ('cajun_chicken_pasta', 3),
#  ('never_bad_experience', 3),
#  ('got_food_first', 3),
#  ('never_checked_us', 3),
#  ('food_would_come', 3),
#  ('minutes_come_out', 3),
#  ('place_go_service', 3),
#  ('ordered_chicken_sandwich', 3),
#  ('good_customer_service', 3),
#  ('beer_selection_good', 3),
#  ('staff_super_friendly', 3),
#  ('corned_beef_hash', 3),
#  ('cheese_mac_n', 3),
#  ('well_half_stars', 3),
#  ('half_stars_really', 3),
#  ('stars_really_yelp', 3),
#  ('really_yelp_round', 3),
#  ('yelp_round_hey', 3),
#  ('round_hey_atmosphere', 3),
#  ('hey_atmosphere_garden', 3),
#  ('atmosphere_garden_good', 3),
#  ('garden_good_fine', 3),
#  ('good_fine_anchor', 3),
#  ('fine_anchor_sb', 3),
#  ('anchor_sb_public', 3),
#  ('sb_public_market', 3),
#  ('public_market_sure', 3),
#  ('market_sure_beer', 3),
#  ('sure_beer_selection', 3),
#  ('selection_excellent_taps', 3),
#  ('excellent_taps_great', 3),
#  ('taps_great_local', 3),
#  ('great_local_offering', 3),
#  ('local_offering_well', 3),
#  ('offering_well_excellent', 3),
#  ('well_excellent_regional', 3),
#  ('excellent_regional_choices', 3),
#  ('regional_choices_even', 3),
#  ('choices_even_fair', 3),
#  ('even_fair_selection', 3),
#  ('fair_selection_actual', 3),
#  ('selection_actual_quality', 3),
#  ('actual_quality_imports', 3),
#  ('quality_imports_means', 3),
#  ('imports_means_affligem', 3),
#  ('means_affligem_st', 3),
#  ('affligem_st_bernardus', 3),
#  ('st_bernardus_heineken', 3),
#  ('bernardus_heineken_stella', 3),
#  ('heineken_stella_food', 3),
#  ('stella_food_wise', 3),
#  ('food_wise_things', 3),
#  ('wise_things_cool', 3),
#  ('things_cool_amazing', 3),
#  ('cool_amazing_fried', 3),
#  ('amazing_fried_chicken', 3),
#  ('chicken_sandwich_thought', 3),
#  ('sandwich_thought_great', 3),
#  ('thought_great_fries', 3),
#  ('great_fries_came', 3),
#  ('fries_came_quite', 3),
#  ('came_quite_ordinary', 3),
#  ('quite_ordinary_ok', 3),
#  ('ordinary_ok_biggie', 3),
#  ('ok_biggie_chicken', 3),
#  ('biggie_chicken_good', 3),
#  ('chicken_good_awesome', 3),
#  ('good_awesome_fries', 3),
#  ('awesome_fries_too', 3),
#  ('fries_too_seems', 3),
#  ('seems_like_missed', 3),
#  ('like_missed_opportunity', 3),
#  ('missed_opportunity_wife', 3),
#  ('opportunity_wife_stone', 3),
#  ('wife_stone_fruit', 3),
#  ('stone_fruit_heirloom', 3),
#  ('fruit_heirloom_burrata', 3),
#  ('heirloom_burrata_caprese', 3),
#  ('burrata_caprese_salad', 3),
#  ('caprese_salad_cheese', 3),
#  ('salad_cheese_tomatoes', 3),
#  ('cheese_tomatoes_awesome', 3),
#  ('tomatoes_awesome_fruits', 3),
#  ('awesome_fruits_bit', 3),
#  ('fruits_bit_underripe', 3),
#  ('bit_underripe_top', 3),
#  ('underripe_top_everything', 3),
#  ('top_everything_though', 3),
#  ('everything_though_know', 3),
#  ('though_know_pseudo', 3),
#  ('know_pseudo_reasons', 3),
#  ('pseudo_reasons_policies', 3),
#  ('reasons_policies_would', 3),
#  ('policies_would_great', 3),
#  ('would_great_able', 3),
#  ('great_able_bring', 3),
#  ('able_bring_awesome', 3),
#  ('bring_awesome_foods', 3),
#  ('awesome_foods_purveyors', 3),
#  ('foods_purveyors_public', 3),
#  ('purveyors_public_market', 3),
#  ('market_garden_pair', 3),
#  ('garden_pair_amazing', 3),
#  ('pair_amazing_beers', 3),
#  ('amazing_beers_sigh', 3),
#  ('beers_sigh_come', 3),
#  ('sigh_come_back', 3),
#  ('come_back_beer', 3),
#  ('back_beer_mostly', 3),
#  ('things_menu_looked', 3),
#  ('menu_looked_good', 3),
#  ('beer_selection_great', 3),
#  ('place_watch_sports', 3),
#  ('burrito_pretty_good', 2),
#  ('definitely_worth_money', 2),
#  ('without_changing_gloves', 2),
#  ('going_back_again', 2),
#  ('whole_wheat_bun', 2),
#  ('suggest_going_somewhere', 2),
#  ('poppy_seed_muffins', 2),
#  ('service_super_friendly', 2),
#  ('go_sit_outside', 2),
#  ('ive_ever_had', 2),
#  ('pretty_good_place', 2),
#  ('etc_best_place', 2),
#  ('buy_one_get', 2),
#  ('one_get_one', 2),
#  ('every_single_one', 2),
#  ('chicken_sandwich_fries', 2),
#  ('love_ancho_salmon', 2),
#  ('ancho_salmon_two', 2),
#  ('salmon_two_times', 2),
#  ('two_times_gone', 2),
#  ('times_gone_told', 2),
#  ('gone_told_order', 2),
#  ('told_order_enough', 2),
#  ('order_enough_out', 2),
#  ('enough_out_good', 2),
#  ('out_good_business', 2),
#  ('beer_selection_beer', 2),
#  ('find_something_like', 2),
#  ('oh_look_receipt', 2),
#  ('fries_well_done', 2),
#  ('wanted_money_back', 2),
#  ('food_decent_service', 2),
#  ('one_came_table', 2),
#  ('taken_care_of', 2),
#  ('service_always_good', 2),
#  ('texas_cheese_fries', 2),
#  ('reason_im_giving', 2),
#  ('friend_manager_chilis', 2),
#  ('manager_chilis_feel', 2),
#  ('chilis_feel_really', 2),
#  ('service_hit_miss', 2),
#  ('paid_bill_left', 2),
#  ('ok_waiting_minutes', 2),
#  ('crispy_chicken_crispers', 2),
#  ('plan_coming_back', 2),
#  ('service_decent_experienced', 2),
#  ('decent_experienced_much', 2),
#  ('experienced_much_mostly', 2),
#  ('much_mostly_order', 2),
#  ('mostly_order_takeout', 2),
#  ('order_takeout_kitchen', 2),
#  ('takeout_kitchen_must', 2),
#  ('kitchen_must_certainly', 2),
#  ('must_certainly_laziest', 2),
#  ('certainly_laziest_ever', 2),
#  ('laziest_ever_encountered', 2),
#  ('ever_encountered_joking', 2),
#  ('encountered_joking_i', 2),
#  ('joking_i_restaurant', 2),
#  ('i_restaurant_experience', 2),
#  ('restaurant_experience_could', 2),
#  ('experience_could_run', 2),
#  ('could_run_better', 2),
#  ('run_better_kitchen', 2),
#  ('better_kitchen_reasons', 2),
#  ('kitchen_reasons_why', 2),
#  ('reasons_why_occasionally', 2),
#  ('why_occasionally_food', 2),
#  ('occasionally_food_arrive', 2),
#  ('food_arrive_without', 2),
#  ('arrive_without_sides', 2),
#  ('without_sides_forgot', 2),
#  ('sides_forgot_sides', 2),
#  ('forgot_sides_like', 2),
#  ('sides_like_job', 2),
#  ('like_job_theyre', 2),
#  ('job_theyre_helping', 2),
#  ('theyre_helping_buddy', 2),
#  ('helping_buddy_move', 2),
#  ('buddy_move_exchange', 2),
#  ('move_exchange_money', 2),
#  ('exchange_money_maybe', 2),
#  ('money_maybe_cheap', 2),
#  ('maybe_cheap_beer', 2),
#  ('cheap_beer_portion', 2),
#  ('beer_portion_sizing', 2),
#  ('portion_sizing_entirely', 2),
#  ('sizing_entirely_arbitrary', 2),
#  ('entirely_arbitrary_could', 2),
#  ('arbitrary_could_dozen', 2),
#  ('could_dozen_onion', 2),
#  ('dozen_onion_rings', 2),
#  ('onion_rings_could', 2),
#  ('rings_could_four', 2),
#  ('could_four_onion', 2),
#  ('four_onion_rings', 2),
#  ('onion_rings_knows', 2),
#  ('rings_knows_flip', 2),
#  ('knows_flip_coin', 2),
#  ('flip_coin_costs', 2),
#  ('coin_costs_six', 2),
#  ('costs_six_dollars', 2),
#  ('six_dollars_either', 2),
#  ('dollars_either_way', 2),
#  ('either_way_oh', 2),
#  ('way_oh_yeah', 2),
#  ('oh_yeah_order', 2),
#  ('yeah_order_bowl', 2),
#  ('order_bowl_instead', 2),
#  ('bowl_instead_cup', 2),
#  ('give_bowl_effectively', 2),
#  ('bowl_effectively_took', 2),
#  ('effectively_took_advantage', 2),
#  ('took_advantage_ordering', 2),
#  ('advantage_ordering_takeout', 2),
#  ('ordering_takeout_steal', 2),
#  ('takeout_steal_two', 2),
#  ('steal_two_dollars', 2),
#  ('two_dollars_me', 2),
#  ('dollars_me_even', 2),
#  ('me_even_like', 2),
#  ('even_like_place', 2),
#  ('like_place_cheap', 2),
#  ('place_cheap_horrid', 2),
#  ('cheap_horrid_waste', 2),
#  ('horrid_waste_commercial', 2),
#  ('waste_commercial_space', 2),
#  ('ate_lunch_boyfriend', 2),
#  ('lunch_boyfriend_week', 2),
#  ('boyfriend_week_ordered', 2),
#  ('week_ordered_food', 2),
#  ('ordered_food_lunch', 2),
#  ('food_lunch_combos', 2),
#  ('lunch_combos_pork', 2),
#  ('combos_pork_tacos', 2),
#  ('pork_tacos_house', 2),
#  ('tacos_house_salad', 2),
#  ('house_salad_bf', 2),
#  ('salad_bf_got', 2),
#  ('bf_got_quesadillas', 2),
#  ('got_quesadillas_chicken', 2),
#  ('quesadillas_chicken_enchilada', 2),
#  ('enchilada_soup_felt', 2),
#  ('soup_felt_portions', 2),
#  ('felt_portions_perfect', 2),
#  ('portions_perfect_size', 2),
#  ('perfect_size_since', 2),
#  ('size_since_want', 2),
#  ('since_want_eat', 2),
#  ('want_eat_much', 2),
#  ('eat_much_work', 2),
#  ('much_work_ordered', 2),
#  ('work_ordered_avocado', 2),
#  ('ordered_avocado_ranch', 2),
#  ('avocado_ranch_salad', 2),
#  ('ranch_salad_im', 2),
#  ('salad_im_big', 2),
#  ('big_fan_ranch', 2),
#  ('fan_ranch_salad', 2),
#  ('ranch_salad_one', 2),
#  ('salad_one_actually', 2),
#  ('one_actually_really', 2),
#  ('actually_really_enjoyed', 2),
#  ('really_enjoyed_tacos', 2),
#  ('enjoyed_tacos_pretty', 2),
#  ('tacos_pretty_good', 2),
#  ('pretty_good_nothing', 2),
#  ('good_nothing_special', 2),
#  ('nothing_special_would', 2),
#  ('special_would_rated', 2),
#  ('would_rated_one', 2),
#  ('rated_one_star', 2),
#  ('one_star_higher', 2),
#  ('star_higher_let', 2),
#  ('higher_let_get', 2),
#  ('let_get_one', 2),
#  ('get_one_chicken', 2),
#  ('one_chicken_one', 2),
#  ('chicken_one_pork', 2),
#  ('one_pork_taco', 2),
#  ('pork_taco_bummed', 2),
#  ('taco_bummed_out', 2),
#  ('bummed_out_tried', 2),
#  ('out_tried_bfs', 2),
#  ('tried_bfs_soup', 2),
#  ('bfs_soup_thought', 2),
#  ('soup_thought_flavorful', 2),
#  ('thought_flavorful_service', 2),
#  ('flavorful_service_really', 2),
#  ('really_good_especially', 2),
#  ('good_especially_since', 2),
#  ('especially_since_busy', 2),
#  ('since_busy_lunch', 2),
#  ('always_great_service', 2),
#  ('worst_customer_service', 2),
#  ('customer_service_ever', 2),
#  ('service_ever_experienced', 2),
#  ('get_drink_order', 2),
#  ('minutes_later_get', 2),
#  ('big_fan_chilis', 2),
#  ('restaurants_santa_barbara', 2),
#  ('come_back_food', 2),
#  ('someone_take_order', 2),
#  ('supposed_use_pay', 2),
#  ('feel_like_im', 2),
#  ('long_wait_times', 2),
#  ('man_whose_order', 2),
#  ('whose_order_consisted', 2),
#  ('good_experiences_chilis', 2),
#  ('little_bit_slow', 2),
#  ('margaritas_strong_like', 2),
#  ('im_pretty_sure', 2),
#  ('first_time_here', 2),
#  ('try_last_night', 2),
#  ('friendly_staff_quick', 2),
#  ('staff_quick_service', 2),
#  ('family_got_seated', 2),
#  ('seated_right_us', 2),
#  ('right_us_got', 2),
#  ('drink_order_taken', 2),
#  ('hit_miss_think', 2),
#  ('fajitas_without_bell', 2),
#  ('without_bell_peppers', 2),
#  ('well_never_back', 2),
#  ('chips_n_salsa', 2),
#  ('ordered_cajun_chicken', 2),
#  ('good_happy_hour', 2),
#  ('fine_dining_experience', 2),
#  ('appetizer_two_entrees', 2),
#  ('ask_three_different', 2),
#  ('hi_welcome_chilis', 2),
#  ('came_us_got', 2),
#  ('send_food_back', 2),
#  ('molten_cake_awesome', 2),
#  ('one_party_members', 2),
#  ('somewhere_else_want', 2),
#  ('next_visit_bad', 2),
#  ('stars_minus_one', 2),
#  ('time_got_home', 2),
#  ('one_last_week', 2),
#  ('give_us_bill', 2),
#  ('every_time_come', 2),
#  ('great_place_dinner', 2),
#  ('great_service_reasonable', 2),
#  ('great_place_go', 2),
#  ('go_service_great', 2),
#  ('service_great_love', 2),
#  ('great_love_hamburgers', 2),
#  ('love_hamburgers_chicken', 2),
#  ('hamburgers_chicken_would', 2),
#  ('chicken_would_definitely', 2),
#  ('recommend_place_nice', 2),
#  ('place_nice_quality', 2),
#  ('nice_quality_food', 2),
#  ('quality_food_way', 2),
#  ('food_way_better', 2),
#  ('way_better_general', 2),
#  ('better_general_fast', 2),
#  ('general_fast_food', 2),
#  ('fast_food_place', 2),
#  ('food_place_people', 2),
#  ('place_people_nice', 2),
#  ('people_nice_would', 2),
#  ('nice_would_definitely', 2),
#  ('one_favorite_places', 2),
#  ('roasted_street_corn', 2),
#  ('restaurant_im_sure', 2),
#  ('comes_bag_heat', 2),
#  ('bag_heat_up', 2),
#  ('chilis_one_places', 2),
#  ('ive_never_bad', 2),
#  ('food_good_complaints', 2),
#  ('us_got_food', 2),
#  ('bacon_looked_like', 2),
#  ('everything_made_fresh', 2),
#  ('would_come_back', 2),
#  ('credit_card_machine', 2),
#  ('food_great_beer', 2),
#  ('loaded_potatoes_broccoli', 2),
#  ('awesome_blossom_petals', 2),
#  ('food_large_portions', 2),
#  ('food_good_beer', 2),
#  ('ordered_cobb_salad', 2),
#  ('best_western_plus', 2),
#  ('try_menu_items', 2),
#  ('restaurant_rd_floor', 2),
#  ('super_friendly_staff', 2),
#  ('mango_habanero_good', 2),
#  ('best_wings_ive', 2),
#  ('great_customer_service', 2),
#  ('la_cumbre_plaza', 2),
#  ('online_ordering_easy', 2),
#  ('definitely_coming_back', 2),
#  ('online_ordering_system', 2),
#  ('home_cooked_style', 2),
#  ('cooked_style_food', 2),
#  ('staying_best_western', 2),
#  ('scrambled_eggs_bacon', 2),
#  ('waste_time_money', 2),
#  ('would_go_back', 2),
#  ('next_best_western', 2),
#  ('interior_looks_like', 2),
#  ('ive_never_seen', 2),
#  ('looked_like_cooked', 2),
#  ('excellent_selection_beer', 2),
#  ('located_public_market', 2),
#  ('stop_public_market', 2),
#  ('amazing_beer_selection', 2),
#  ('bring_food_vendors', 2),
#  ('rest_public_market', 2),
#  ('stout_ice_cream', 2),
#  ('beer_mostly_things', 2),
#  ('mostly_things_menu', 2),
#  ('looked_good_update', 2),
#  ('food_vendors_public', 2),
#  ('vendors_public_market', 2),
#  ('list_craft_beers', 2),
#  ('craft_beers_decent', 2),
#  ('bring_food_places', 2),
#  ('long_buy_drink', 2),
#  ('great_place_watch', 2),
#  ('goes_concept_public', 2),
#  ('concept_public_market', 2),
#  ('corazon_empty_bowl', 2),
#  ('worst_service_ive', 2),
#  ('service_ive_ever', 2),
#  ('husband_ordered_beer', 2),
#  ('charge_bring_food', 2),
#  ('made_wait_extra', 2),
#  ('wait_extra_minutes', 2),
#  ('bring_food_public', 2),
#  ('food_public_market', 2),
#  ('public_market_growing', 2),
#  ('big_fan_multiple', 2),
#  ('fan_multiple_businesses', 2),
#  ('multiple_businesses_one', 2),
#  ('businesses_one_roof', 2),
#  ('big_plus_bring', 2),
#  ('plus_bring_food', 2),
#  ('bring_food_anywhere', 2),
#  ('food_anywhere_market', 2),
#  ('anywhere_market_sit', 2),
#  ('ordered_hot_chocolate', 1),
#  ('hot_chocolate_tasted', 1),
#  ('chocolate_tasted_like', 1),
#  ('tasted_like_hot', 1),
#  ('like_hot_water', 1),
#  ('hot_water_sprinkled', 1),
#  ('water_sprinkled_coco', 1),
#  ('sprinkled_coco_powder', 1),
#  ('coco_powder_know', 1),
#  ('powder_know_mess', 1),
#  ('know_mess_powder', 1),
#  ('mess_powder_hot', 1),
#  ('powder_hot_chocolate', 1),
#  ('hot_chocolate_sip', 1),
#  ('chocolate_sip_threw', 1),
#  ('sip_threw_away', 1),
#  ('threw_away_come', 1),
#  ('away_come_want', 1),
#  ('come_want_breakfast', 1),
#  ('want_breakfast_burrito', 1),
#  ('breakfast_burrito_pretty', 1),
#  ('pretty_good_bad', 1),
#  ('good_bad_stop', 1),
#  ('bad_stop_serving', 1),
#  ('stop_serving_am', 1),
#  ('serving_am_recommend', 1),
#  ('am_recommend_eating', 1),
#  ('recommend_eating_food', 1),
#  ('eating_food_make', 1),
#  ('food_make_ranges', 1),
#  ('make_ranges_gross', 1),
#  ('ranges_gross_disgusting', 1),
#  ('gross_disgusting_definitely', 1),
#  ('disgusting_definitely_worth', 1),
#  ('worth_money_work', 1),
#  ('money_work_ucsb', 1),
#  ('work_ucsb_stop', 1),
#  ('ucsb_stop_frequently', 1),
#  ('stop_frequently_coffee', 1),
#  ('frequently_coffee_small', 1),
#  ('coffee_small_snacks', 1),
#  ('small_snacks_sometimes', 1),
#  ('snacks_sometimes_full', 1),
#  ('sometimes_full_lunch', 1),
#  ('full_lunch_great', 1),
#  ('lunch_great_part', 1),
#  ('great_part_coral', 1),
#  ('part_coral_tree', 1),
#  ('coral_tree_bit', 1),
#  ('tree_bit_everything', 1),
#  ('bit_everything_coffee', 1),
#  ('everything_coffee_shopconvenience', 1),
#  ('coffee_shopconvenience_storebreakfast', 1),
#  ('shopconvenience_storebreakfast_placelunch', 1),
#  ('storebreakfast_placelunch_placestudy', 1),
#  ('placelunch_placestudy_spot', 1),
#  ('placestudy_spot_rolled', 1),
#  ('spot_rolled_one', 1),
#  ('rolled_one_get', 1),
#  ('one_get_packaged', 1),
#  ('get_packaged_snacks', 1),
#  ('packaged_snacks_meals', 1),
#  ('snacks_meals_chips', 1),
#  ('meals_chips_granola', 1),
#  ('chips_granola_bars', 1),
#  ('granola_bars_yogurts', 1),
#  ('bars_yogurts_cold', 1),
#  ('yogurts_cold_bottled', 1),
#  ('cold_bottled_drinks', 1),
#  ('bottled_drinks_salads', 1),
#  ('drinks_salads_wrapped', 1),
#  ('salads_wrapped_cold', 1),
#  ('wrapped_cold_sandwiches', 1),
#  ('cold_sandwiches_etc', 1),
#  ('sandwiches_etc_one', 1),
#  ('etc_one_end', 1),
#  ('one_end_prepared', 1),
#  ('end_prepared_food', 1),
#  ('prepared_food_end', 1),
#  ('food_end_get', 1),
#  ('end_get_line', 1),
#  ('get_line_order', 1),
#  ('line_order_want', 1),
#  ('order_want_move', 1),
#  ('want_move_next', 1),
#  ('move_next_register', 1),
#  ('next_register_pay', 1),
#  ('register_pay_get', 1),
#  ('pay_get_number', 1),
#  ('get_number_bring', 1),
#  ('number_bring_right', 1),
#  ('bring_right_whether', 1),
#  ('right_whether_inside', 1),
#  ('whether_inside_outside', 1),
#  ('inside_outside_lunch', 1),
#  ('outside_lunch_menu', 1),
#  ('lunch_menu_staples', 1),
#  ('menu_staples_salads', 1),
#  ('staples_salads_sandwiches', 1),
#  ('salads_sandwiches_soups', 1),
#  ('sandwiches_soups_pitas', 1),
#  ('soups_pitas_burritos', 1),
#  ('pitas_burritos_stir', 1),
#  ('burritos_stir_fry', 1),
#  ('stir_fry_choices', 1),
#  ('fry_choices_etc', 1),
#  ('choices_etc_lunch', 1),
#  ('etc_lunch_rush', 1),
#  ('lunch_rush_prepared', 1),
#  ('rush_prepared_wait', 1),
#  ('prepared_wait_bit', 1),
#  ('wait_bit_place', 1),
#  ('bit_place_reasonably', 1),
#  ('place_reasonably_priced', 1),
#  ('reasonably_priced_large', 1),
#  ('priced_large_enough', 1),
#  ('large_enough_menu', 1),
#  ('enough_menu_satisfy', 1),
#  ('menu_satisfy_pretty', 1),
#  ('satisfy_pretty_much', 1),
#  ('pretty_much_everyone', 1),
#  ('much_everyone_suits', 1),
#  ('everyone_suits_many', 1),
#  ('suits_many_needs', 1),
#  ('many_needs_tips', 1),
#  ('needs_tips_ask', 1),
#  ('tips_ask_ucsb', 1),
#  ('ask_ucsb_student', 1),
#  ('ucsb_student_think', 1),
#  ('student_think_might', 1),
#  ('think_might_small', 1),
#  ('might_small_discount', 1),
#  ('small_discount_ie', 1),
#  ('discount_ie_pay', 1),
#  ('ie_pay_tax', 1),
#  ('pay_tax_bring', 1),
#  ('tax_bring_lunch', 1),
#  ('bring_lunch_totally', 1),
#  ('lunch_totally_cool', 1),
#  ('totally_cool_sitting', 1),
#  ('cool_sitting_outdoor', 1),
#  ('sitting_outdoor_tables', 1),
#  ('outdoor_tables_drink', 1),
#  ('tables_drink_coffee', 1),
#  ('drink_coffee_lot', 1),
#  ('coffee_lot_get', 1),
#  ('lot_get_frequent', 1),
#  ('get_frequent_flyer', 1),
#  ('frequent_flyer_card', 1),
#  ('flyer_card_stamp', 1),
#  ('card_stamp_every', 1),
#  ('stamp_every_time', 1),
#  ('every_time_get', 1),
#  ('time_get_coffee', 1),
#  ('get_coffee_it', 1),
#  ('coffee_it_works', 1),
#  ('it_works_coffee', 1),
#  ('works_coffee_unfortunately', 1),
#  ('coffee_unfortunately_ten', 1),
#  ('unfortunately_ten_stamps', 1),
#  ('ten_stamps_equals', 1),
#  ('stamps_equals_free', 1),
#  ('equals_free_coffee', 1),
#  ('free_coffee_breakfast', 1),
#  ('coffee_breakfast_served', 1),
#  ('breakfast_served_am', 1),
#  ('served_am_eat', 1),
#  ('am_eat_coral', 1),
#  ('eat_coral_tree', 1),
#  ('coral_tree_nearly', 1),
#  ('tree_nearly_every', 1),
#  ('nearly_every_day', 1),
#  ('every_day_another', 1),
#  ('day_another_reviewer', 1),
#  ('another_reviewer_suggested', 1),
#  ('reviewer_suggested_much', 1),
#  ('suggested_much_regulars', 1),
#  ('much_regulars_place', 1),
#  ('regulars_place_one', 1),
#  ('place_one_know', 1),
#  ('one_know_system', 1),
#  ('know_system_frustrating', 1),
#  ('system_frustrating_newbie', 1),
#  ('frustrating_newbie_regulars', 1),
#  ('newbie_regulars_anyway', 1),
#  ('regulars_anyway_considering', 1),
#  ('anyway_considering_challenge', 1),
#  ('considering_challenge_fresh', 1),
#  ('challenge_fresh_food', 1),
#  ('fresh_food_campus', 1),
#  ('food_campus_coral', 1),
#  ('campus_coral_tree', 1),
#  ('coral_tree_nice', 1),
#  ('tree_nice_job', 1),
#  ('nice_job_basically', 1),
#  ('job_basically_one', 1),
#  ('basically_one_go', 1),
#  ('one_go_ucen', 1),
#  ('go_ucen_different', 1),
#  ('ucen_different_fast', 1),
#  ('different_fast_food', 1),
#  ('fast_food_joints', 1),
#  ('food_joints_deli', 1),
#  ('joints_deli_salad', 1),
#  ('deli_salad_bar', 1),
#  ('salad_bar_engineering', 1),
#  ('bar_engineering_cafeteria', 1),
#  ('engineering_cafeteria_style', 1),
#  ('cafeteria_style_one', 1),
#  ('style_one_go', 1),
#  ('one_go_arbor', 1),
#  ('go_arbor_lot', 1),
#  ('arbor_lot_takeaway', 1),
#  ('lot_takeaway_sandwiches', 1),
#  ('takeaway_sandwiches_or', 1),
#  ('sandwiches_or_stands', 1),
#  ('or_stands_outside', 1),
#  ('stands_outside_arbor', 1),
#  ('outside_arbor_pretzels', 1),
#  ('arbor_pretzels_hotdogs', 1),
#  ('pretzels_hotdogs_burritos', 1),
#  ('hotdogs_burritos_pizza', 1),
#  ('burritos_pizza_one', 1),
#  ('pizza_one_go', 1),
#  ('one_go_coral', 1),
#  ('go_coral_tree', 1),
#  ('coral_tree_coral', 1),
#  ('tree_coral_tree', 1),
#  ('coral_tree_premade', 1),
#  ('tree_premade_sandwiches', 1),
#  ('premade_sandwiches_salads', 1),
#  ('sandwiches_salads_bad', 1),
#  ('salads_bad_affordable', 1),
#  ('bad_affordable_like', 1),
#  ('affordable_like_california', 1),
#  ('like_california_veggie', 1),
#  ('california_veggie_also', 1),
#  ('veggie_also_snacks', 1),
#  ('also_snacks_like', 1),
#  ('snacks_like_veggies', 1),
#  ('like_veggies_fruit', 1),
#  ('veggies_fruit_coral', 1),
#  ('fruit_coral_tree', 1),
#  ('coral_tree_also', 1),
#  ('tree_also_pretty', 1),
#  ('pretty_good_grill', 1),
#  ('good_grill_burritos', 1),
#  ('grill_burritos_burgers', 1),
#  ('burritos_burgers_etc', 1),
#  ('burgers_etc_well', 1),
#  ('etc_well_pitas', 1),
#  ('well_pitas_soups', 1),
#  ('pitas_soups_also', 1),
#  ('soups_also_pastries', 1),
#  ('also_pastries_bagels', 1),
#  ('pastries_bagels_fresh', 1),
#  ('bagels_fresh_fruit', 1),
#  ('fresh_fruit_also', 1),
#  ('fruit_also_coffee', 1),
#  ('also_coffee_espresso', 1),
#  ('coffee_espresso_drinks', 1),
#  ('espresso_drinks_service', 1),
#  ('drinks_service_slow', 1),
#  ('service_slow_fast', 1),
#  ('slow_fast_either', 1),
#  ('fast_either_especially', 1),
#  ('either_especially_lunch', 1),
#  ('especially_lunch_time', 1),
#  ('lunch_time_coming', 1),
#  ('time_coming_right', 1),
#  ('coming_right_right', 1),
#  ('right_right_noon', 1),
#  ('right_noon_hour', 1),
#  ('noon_hour_good', 1),
#  ('hour_good_idea', 1),
#  ('good_idea_although', 1),
#  ('idea_although_another', 1),
#  ('although_another_reviewer', 1),
#  ('another_reviewer_mentioned', 1),
#  ('reviewer_mentioned_frequently', 1),
#  ('mentioned_frequently_run', 1),
#  ('frequently_run_primary', 1),
#  ('run_primary_ingredients', 1),
#  ('primary_ingredients_but', 1),
#  ('ingredients_but_good', 1),
#  ('but_good_location', 1),
#  ('good_location_affordable', 1),
#  ('location_affordable_reasonably', 1),
#  ('affordable_reasonably_fresh', 1),
#  ('reasonably_fresh_is', 1),
#  ('fresh_is_so', 1),
#  ('is_so_im', 1),
#  ('so_im_really', 1),
#  ('im_really_badly', 1),
#  ('really_badly_allergic', 1),
#  ('badly_allergic_dairy', 1),
#  ('allergic_dairy_lactose', 1),
#  ('dairy_lactose_intolerant', 1),
#  ('lactose_intolerant_specified', 1),
#  ('intolerant_specified_ordered', 1),
#  ('specified_ordered_burger', 1),
#  ('ordered_burger_there', 1),
#  ('burger_there_asked', 1),
#  ('there_asked_cheese', 1),
#  ('asked_cheese_last', 1),
#  ('cheese_last_burger', 1),
#  ('last_burger_stock', 1),
#  ('burger_stock_day', 1),
#  ('stock_day_put', 1),
#  ('day_put_cheese', 1),
#  ('put_cheese_justified', 1),
#  ('cheese_justified_saying', 1),
#  ('justified_saying_this', 1),
#  ('saying_this_order', 1),
#  ('this_order_complicated', 1),
#  ('order_complicated_partner', 1),
#  ('complicated_partner_ordered', 1),
#  ('partner_ordered_burgers', 1),
#  ('ordered_burgers_supposed', 1),
#  ('burgers_supposed_bacon', 1),
#  ('supposed_bacon_them', 1),
#  ('bacon_them_price', 1),
#  ('them_price_tag', 1),
#  ('price_tag_match', 1),
#  ('tag_match_added', 1),
#  ('match_added_ingredient', 1),
#  ('added_ingredient_bacon', 1),
#  ('ingredient_bacon_offer', 1),
#  ('bacon_offer_anything', 1),
#  ('offer_anything_experience', 1),
#  ('anything_experience_except', 1),
#  ('experience_except_burger', 1),
#  ('except_burger_fixed', 1),
#  ('burger_fixed_cover', 1),
#  ('fixed_cover_cost', 1),
#  ('cover_cost_meal', 1),
#  ('cost_meal_peanut', 1),
#  ('meal_peanut_case', 1),
#  ('peanut_case_someone', 1),
#  ('case_someone_couldve', 1),
#  ('someone_couldve_died', 1),
#  ('couldve_died_ordered', 1),
#  ('died_ordered_vegetable', 1),
#  ('ordered_vegetable_stir', 1),
#  ('vegetable_stir_fry', 1),
#  ('stir_fry_contained', 1),
#  ('fry_contained_onions', 1),
#  ('contained_onions_carrots', 1),
#  ('onions_carrots_onions', 1),
#  ('carrots_onions_broccoli', 1),
#  ('onions_broccoli_onions', 1),
#  ('broccoli_onions_rice', 1),
#  ('onions_rice_onions', 1),
#  ('rice_onions_seriously', 1),
#  ('onions_seriously_got', 1),
#  ('seriously_got_least', 1),
#  ('got_least_entire', 1),
#  ('least_entire_onion', 1),
#  ('entire_onion_think', 1),
#  ('onion_think_veggies', 1),
#  ('think_veggies_worked', 1),
#  ('veggies_worked_alone', 1),
#  ('worked_alone_rest', 1),
#  ('alone_rest_day', 1),
#  ('rest_day_need', 1),
#  ('day_need_reminder', 1),
#  ('need_reminder_health', 1),
#  ('reminder_health_code', 1),
#  ('health_code_information', 1),
#  ('code_information_saw', 1),
#  ('information_saw_worker', 1),
#  ('saw_worker_take', 1),
#  ('worker_take_trash', 1),
#  ('take_trash_go', 1),
#  ('trash_go_help', 1),
#  ('go_help_run', 1),
#  ('help_run_food', 1),
#  ('run_food_take', 1),
#  ('food_take_orders', 1),
#  ('take_orders_without', 1),
#  ('orders_without_changing', 1),
#  ('changing_gloves_washing', 1),
#  ('gloves_washing_hands', 1),
#  ('washing_hands_beautiful', 1),
#  ('hands_beautiful_uc', 1),
#  ('beautiful_uc_santa', 1),
#  ('uc_santa_barbara', 1),
#  ('santa_barbara_campus', 1),
#  ('barbara_campus_mood', 1),
#  ('campus_mood_head', 1),
#  ('mood_head_food', 1),
#  ('head_food_court', 1),
#  ('food_court_get', 1),
#  ('court_get_lost', 1),
#  ('get_lost_crowdescape', 1),
#  ('lost_crowdescape_quiet', 1),
#  ('crowdescape_quiet_cozy', 1),
#  ('quiet_cozy_coral', 1),
#  ('cozy_coral_tree', 1),
#  ('tree_cafe_little', 1),
#  ('cafe_little_towards', 1),
#  ('little_towards_students', 1),
#  ('towards_students_affair', 1),
#  ('students_affair_building', 1),
#  ('affair_building_enormous', 1),
#  ('building_enormous_campbell', 1),
#  ('enormous_campbell_hall', 1),
#  ('campbell_hall_nestled', 1),
#  ('hall_nestled_lovely', 1),
#  ('nestled_lovely_red', 1),
#  ('lovely_red_coral', 1),
#  ('red_coral_trees', 1),
#  ('coral_trees_sell', 1),
#  ('trees_sell_typical', 1),
#  ('sell_typical_coffees', 1),
#  ('typical_coffees_iced', 1),
#  ('coffees_iced_drinks', 1),
#  ('iced_drinks_well', 1),
#  ('drinks_well_hot', 1),
#  ('well_hot_breakfastbaked', 1),
#  ('hot_breakfastbaked_goods', 1),
#  ('breakfastbaked_goods_hot', 1),
#  ('goods_hot_lunch', 1),
#  ('hot_lunch_soups', 1),
#  ('lunch_soups_sandwichs', 1),
#  ('soups_sandwichs_salads', 1),
#  ('sandwichs_salads_nice', 1),
#  ('salads_nice_getaway', 1),
#  ('nice_getaway_within', 1),
#  ('getaway_within_busy', 1),
#  ('within_busy_school', 1),
#  ('busy_school_ate', 1),
#  ('school_ate_coral', 1),
#  ('ate_coral_tree', 1),
#  ('tree_cafe_today', 1),
#  ('cafe_today_really', 1),
#  ('today_really_good', 1),
#  ('really_good_got', 1),
#  ('good_got_western', 1),
#  ('got_western_burger', 1),
#  ('western_burger_bacon', 1),
#  ('burger_bacon_sub', 1),
#  ('bacon_sub_veggie', 1),
#  ('sub_veggie_patty', 1),
#  ('veggie_patty_made', 1),
#  ('patty_made_combo', 1),
#  ('made_combo_cheaper', 1),
#  ('combo_cheaper_say', 1),
#  ('cheaper_say_ordering', 1),
#  ('say_ordering_habit', 1),
#  ('ordering_habit_really', 1),
#  ('habit_really_good', 1),
#  ('really_good_boyfriend', 1),
#  ('good_boyfriend_got', 1),
#  ('boyfriend_got_chicken', 1),
#  ('got_chicken_burrito', 1),
#  ('chicken_burrito_chicken', 1),
#  ('burrito_chicken_kind', 1),
#  ('chicken_kind_pink', 1),
#  ('kind_pink_really', 1),
#  ('pink_really_friendly', 1),
#  ('really_friendly_made', 1),
#  ('friendly_made_expensive', 1),
#  ('made_expensive_steak', 1),
#  ('expensive_steak_burrito', 1),
#  ('steak_burrito_extra', 1),
#  ('burrito_extra_charge', 1),
#  ('extra_charge_going', 1),
#  ('charge_going_back', 1),
#  ('back_again_perfect', 1),
#  ('again_perfect_spot', 1),
#  ('perfect_spot_lunch', 1),
#  ('spot_lunch_coffee', 1),
#  ('lunch_coffee_break', 1),
#  ('coffee_break_campus', 1),
#  ('break_campus_sandwiches', 1),
#  ('campus_sandwiches_fries', 1),
#  ('sandwiches_fries_delicious', 1),
#  ('fries_delicious_also', 1),
#  ('delicious_also_usual', 1),
#  ('also_usual_snacks', 1),
#  ('usual_snacks_coffee', 1),
#  ('snacks_coffee_menu', 1),
#  ('coffee_menu_sell', 1),
#  ('menu_sell_arbor', 1),
#  ('sell_arbor_even', 1),
#  ('arbor_even_bring', 1),
#  ('even_bring_lunch', 1),
#  ('bring_lunch_take', 1),
#  ('lunch_take_seat', 1),
#  ('take_seat_wherever', 1),
#  ('seat_wherever_plenty', 1),
#  ('wherever_plenty_outdoor', 1),
#  ('plenty_outdoor_seating', 1),
#  ('outdoor_seating_yeah', 1),
#  ('seating_yeah_nope', 1),
#  ('yeah_nope_really', 1),
#  ('nope_really_like', 1),
#  ('really_like_fact', 1),
#  ('like_fact_one', 1),
#  ('fact_one_knows', 1),
#  ('one_knows_make', 1),
#  ('knows_make_decent', 1),
#  ('make_decent_cup', 1),
#  ('decent_cup_coffee', 1),
#  ('cup_coffee_even', 1),
#  ('coffee_even_ended', 1),
#  ('even_ended_switching', 1),
#  ('ended_switching_vanilla', 1),
#  ('switching_vanilla_chai', 1),
#  ('vanilla_chai_powder', 1),
#  ('chai_powder_used', 1),
#  ...]

# %%
good_Healthy=Healthy[Healthy.stars>=3.5]
good_Healthy_review = Healthy_review[Healthy_review.business_id.isin(good_Healthy.business_id.values)]
good_Healthy_review_text = good_Healthy_review.text.str.cat(sep = " ")
good_Healthy_tokens = word_tokenize(good_Healthy_review_text)
# FreqDist(good_American_tokens).most_common()
bigrams_list_good_Healthy = ["_".join(item) for item in nltk.bigrams(good_Healthy_tokens)]
trigrams_list_good_Healthy = ["_".join(item) for item in nltk.trigrams(good_Healthy_tokens)]
Ngrams_list_good_Healthy = ["_".join(item) for item in nltk.ngrams(good_Healthy_tokens,3)]
# FreqDist(bigrams_list_good_Healthy).most_common()
# FreqDist(trigrams_list_good_Healthy).most_common()
FreqDist(Ngrams_list_good_Healthy).most_common()
# Out:
# [('ive_ever_had', 113),
#  ('definitely_come_back', 67),
#  ('definitely_coming_back', 60),
#  ('next_time_im', 58),
#  ('back_next_time', 58),
#  ('cant_go_wrong', 57),
#  ('visiting_santa_barbara', 56),
#  ('visit_santa_barbara', 56),
#  ('wait_come_back', 50),
#  ('wait_go_back', 49),
#  ('highly_recommend_place', 48),
#  ('cant_wait_go', 45),
#  ('old_town_salad', 45),
#  ('im_santa_barbara', 44),
#  ('trip_santa_barbara', 43),
#  ('restaurant_santa_barbara', 43),
#  ('cant_wait_come', 42),
#  ('would_definitely_recommend', 41),
#  ('vegan_gluten_free', 40),
#  ('would_highly_recommend', 37),
#  ('love_love_love', 37),
#  ('artichoke_crab_cakes', 37),
#  ('vanilla_ice_cream', 37),
#  ('would_definitely_come', 35),
#  ('best_vegan_food', 35),
#  ('egg_white_frittata', 33),
#  ('santa_barbara_area', 33),
#  ('place_santa_barbara', 32),
#  ('food_great_service', 32),
#  ('would_come_back', 31),
#  ('baklava_ice_cream', 31),
#  ('soy_ice_cream', 30),
#  ('every_time_come', 29),
#  ('staff_super_friendly', 28),
#  ('definitely_go_back', 28),
#  ('best_ive_ever', 28),
#  ('come_back_try', 28),
#  ('great_customer_service', 28),
#  ('back_santa_barbara', 28),
#  ('gluten_free_options', 27),
#  ('time_im_santa', 27),
#  ('bowl_island_bowl', 27),
#  ('better_jamba_juice', 27),
#  ('best_acai_bowls', 26),
#  ('cant_wait_try', 26),
#  ('gluten_free_pancakes', 25),
#  ('downtown_santa_barbara', 25),
#  ('would_go_back', 25),
#  ('love_backyard_bowls', 25),
#  ('vegan_ice_cream', 25),
#  ('every_time_go', 25),
#  ('pulled_mushroom_sandwich', 25),
#  ('one_favorite_places', 24),
#  ('mac_n_cheese', 23),
#  ('great_food_great', 22),
#  ('santa_barbara_food', 22),
#  ('santa_barbara_place', 22),
#  ('spot_santa_barbara', 22),
#  ('pacific_health_foods', 21),
#  ('come_back_again', 21),
#  ('best_vegan_restaurant', 21),
#  ('got_island_bowl', 21),
#  ('lived_santa_barbara', 21),
#  ('staff_friendly_helpful', 21),
#  ('kung_pao_cauliflower', 21),
#  ('time_santa_barbara', 21),
#  ('one_best_vegan', 21),
#  ('service_great_food', 20),
#  ('can_not_wait', 20),
#  ('found_place_yelp', 20),
#  ('yoga_pants_salad', 20),
#  ('gave_us_free', 20),
#  ('vanilla_bean_latte', 19),
#  ('squeezed_orange_juice', 19),
#  ('go_back_try', 19),
#  ('cocoa_almond_bowl', 19),
#  ('check_place_out', 19),
#  ('absolutely_love_place', 19),
#  ('thank_mesa_verde', 19),
#  ('definitely_recommend_place', 18),
#  ('recommend_place_anyone', 18),
#  ('food_santa_barbara', 18),
#  ('peanut_butter_smoothie', 18),
#  ('berry_bowl_island', 17),
#  ('outdoor_seating_area', 17),
#  ('best_acai_bowl', 17),
#  ('every_time_im', 17),
#  ('next_time_were', 17),
#  ('come_back_next', 17),
#  ('gluten_free_vegan', 17),
#  ('raw_veggie_wrap', 17),
#  ('mushroom_umami_burger', 17),
#  ('pulled_smoked_mushroom', 17),
#  ('luau_french_toast', 16),
#  ('would_definitely_go', 16),
#  ('food_really_good', 16),
#  ('keep_coming_back', 16),
#  ('restaurants_santa_barbara', 16),
#  ('favorite_restaurant_santa', 16),
#  ('green_table_burger', 16),
#  ('baklava_soy_ice', 16),
#  ('one_best_restaurants', 15),
#  ('fresh_squeezed_orange', 15),
#  ('indoor_outdoor_seating', 15),
#  ('got_build_hash', 15),
#  ('try_something_new', 15),
#  ('well_worth_it', 15),
#  ('passing_santa_barbara', 15),
#  ('give_place_try', 15),
#  ('go_santa_barbara', 15),
#  ('great_service_great', 15),
#  ('like_jamba_juice', 15),
#  ('salad_grilled_chicken', 15),
#  ('every_time_visit', 15),
#  ('love_natural_cafe', 14),
#  ('stop_santa_barbara', 14),
#  ('love_acai_bowls', 14),
#  ('highly_recommend_restaurant', 14),
#  ('pepper_jack_cheese', 14),
#  ('acai_bowls_ive', 14),
#  ('totally_worth_it', 14),
#  ('hash_sweet_potatoes', 14),
#  ('first_time_here', 14),
#  ('santa_barbara_one', 14),
#  ('took_minutes_get', 14),
#  ('diegos_power_bowl', 14),
#  ('santa_barbara_would', 14),
#  ('santa_barbara_day', 14),
#  ('good_customer_service', 14),
#  ('definitely_going_back', 14),
#  ('wish_lived_closer', 14),
#  ('recommend_mesa_verde', 14),
#  ('baklava_vanilla_ice', 14),
#  ('umami_mushroom_burger', 14),
#  ('try_mesa_verde', 14),
#  ('give_place_stars', 13),
#  ('everything_ive_tried', 13),
#  ('love_love_place', 13),
#  ('bowl_berry_bowl', 13),
#  ('cant_wait_return', 13),
#  ('want_go_back', 13),
#  ('ill_definitely_back', 13),
#  ('bowl_peanut_butter', 13),
#  ('ive_ever_to', 13),
#  ('time_im_town', 13),
#  ('food_excellent_service', 13),
#  ('juice_coconut_milk', 13),
#  ('natural_cafe_great', 13),
#  ('come_santa_barbara', 13),
#  ('high_quality_food', 13),
#  ('staff_super_nice', 13),
#  ('go_back_next', 13),
#  ('lemon_herb_dressing', 13),
#  ('highly_recommend_it', 13),
#  ('grilled_cheese_sandwich', 13),
#  ('blue_corn_chips', 13),
#  ('nonfat_frozen_yogurt', 13),
#  ('mesa_verde_amazing', 13),
#  ('ordered_street_tacos', 13),
#  ('ice_cream_baklava', 13),
#  ('ordered_berry_bowl', 12),
#  ('good_food_great', 12),
#  ('im_huge_fan', 12),
#  ('got_berry_bowl', 12),
#  ('one_best_meals', 12),
#  ('definitely_come_again', 12),
#  ('health_food_store', 12),
#  ('food_pretty_good', 12),
#  ('food_good_service', 12),
#  ('went_first_time', 12),
#  ('day_trip_santa', 12),
#  ('veggie_stir_fry', 12),
#  ('decided_give_try', 12),
#  ('customer_service_great', 12),
#  ('would_recommend_place', 12),
#  ('coming_back_next', 12),
#  ('peanut_butter_chocolate', 12),
#  ('love_mesa_verde', 12),
#  ('patatas_bravas_tacos', 12),
#  ('experience_mesa_verde', 12),
#  ('squash_blossom_quesadilla', 12),
#  ('food_always_fresh', 11),
#  ('vegan_vegetarian_options', 11),
#  ('every_single_time', 11),
#  ('great_place_breakfast', 11),
#  ('santa_barbara_im', 11),
#  ('fresh_orange_juice', 11),
#  ('chorizo_hash_special', 11),
#  ('santa_barbara_must', 11),
#  ('ive_ever_eaten', 11),
#  ('good_food_good', 11),
#  ('good_karma_burger', 11),
#  ('definitely_back_next', 11),
#  ('acai_bowl_place', 11),
#  ('madagascar_vanilla_bean', 11),
#  ('santa_barbara_go', 11),
#  ('dog_friendly_patio', 11),
#  ('cant_get_enough', 11),
#  ('eat_every_day', 11),
#  ('new_favorite_restaurant', 11),
#  ('delicious_acai_bowls', 11),
#  ('banana_strawberry_blueberry', 11),
#  ('bananas_strawberries_blueberries', 11),
#  ('pineapple_juice_coconut', 11),
#  ('ordered_island_bowl', 11),
#  ('bowl_ive_ever', 11),
#  ('wild_mushroom_tostada', 11),
#  ('super_friendly_staff', 11),
#  ('ive_ever_tasted', 11),
#  ('food_ive_ever', 11),
#  ('looking_forward_trying', 11),
#  ('back_next_day', 11),
#  ('one_favorite_restaurants', 11),
#  ('healthy_delicious_food', 11),
#  ('plant_based_food', 11),
#  ('mesa_verde_one', 11),
#  ('tacos_polenta_fries', 11),
#  ('visit_mesa_verde', 11),
#  ('black_bean_burger', 11),
#  ('green_plant_bowl', 11),
#  ('place_acai_bowls', 10),
#  ('places_santa_barbara', 10),
#  ('bowls_ive_ever', 10),
#  ('santa_barbara_definitely', 10),
#  ('fresh_squeezed_oj', 10),
#  ('would_definitely_return', 10),
#  ('go_back_again', 10),
#  ('nothing_write_home', 10),
#  ('love_place_food', 10),
#  ('build_hash_sweet', 10),
#  ('nice_outdoor_seating', 10),
#  ('came_santa_barbara', 10),
#  ('really_really_good', 10),
#  ('santa_barbara_first', 10),
#  ('amazing_food_great', 10),
#  ('great_place_stop', 10),
#  ('delicious_highly_recommend', 10),
#  ('bowl_backyard_bowl', 10),
#  ('definitely_worth_it', 10),
#  ('santa_barbara_weekend', 10),
#  ('santa_barbara_great', 10),
#  ('really_cant_go', 10),
#  ('time_im_area', 10),
#  ('santa_barbara_everything', 10),
#  ('definitely_would_recommend', 10),
#  ('next_time_town', 10),
#  ('vegan_food_ive', 10),
#  ('vegan_food_ever', 10),
#  ('next_time_santa', 10),
#  ('amazing_food_service', 10),
#  ('worth_checking_out', 10),
#  ('santa_barbara_love', 10),
#  ('time_visit_santa', 10),
#  ('love_pressed_juicery', 10),
#  ('polenta_fries_empanadas', 10),
#  ('mesa_verde_first', 10),
#  ('polenta_fries_street', 10),
#  ('fries_street_tacos', 10),
#  ('went_mesa_verde', 10),
#  ('found_mesa_verde', 10),
#  ('ice_cream_dessert', 10),
#  ('got_street_tacos', 10),
#  ('order_counter_bring', 9),
#  ('sweet_potato_hash', 9),
#  ('blueberries_goji_berries', 9),
#  ('butternut_squash_soup', 9),
#  ('made_us_feel', 9),
#  ('worth_every_penny', 9),
#  ('get_island_bowl', 9),
#  ('one_best_acai', 9),
#  ('wanted_like_place', 9),
#  ('staff_always_friendly', 9),
#  ('ordered_build_hash', 9),
#  ('right_state_street', 9),
#  ('come_back_im', 9),
#  ('ive_ever_seen', 9),
#  ('highly_recommend_spot', 9),
#  ('overall_great_experience', 9),
#  ('make_sure_get', 9),
#  ('santa_barbara_looking', 9),
#  ('time_im_sb', 9),
#  ('vegetarian_vegan_options', 9),
#  ('way_start_day', 9),
#  ('backyard_bowls_best', 9),
#  ('prisoner_egg_muffin', 9),
#  ('apple_juice_topped', 9),
#  ('also_really_good', 9),
#  ('definitely_back_soon', 9),
#  ('staff_friendly_food', 9),
#  ('super_friendly_helpful', 9),
#  ('cant_say_enough', 9),
#  ('great_outdoor_seating', 9),
#  ('amazing_customer_service', 9),
#  ('really_hit_spot', 9),
#  ('really_enjoyed_it', 9),
#  ('go_wrong_anything', 9),
#  ('backyard_bowls_amazing', 9),
#  ('coconut_shavings_granola', 9),
#  ('state_street_great', 9),
#  ('time_were_town', 9),
#  ('santa_barbara_get', 9),
#  ('best_smoothies_ever', 9),
#  ('first_time_trying', 9),
#  ('ive_long_time', 9),
#  ('food_amazing_service', 9),
#  ('amazing_vegan_food', 9),
#  ('staying_santa_barbara', 9),
#  ('great_food_service', 9),
#  ('even_gave_us', 9),
#  ('santa_barbara_really', 9),
#  ('restaurant_ive_ever', 9),
#  ('one_best_vegetarian', 9),
#  ('would_give_stars', 9),
#  ('high_quality_ingredients', 9),
#  ('tropical_guava_smoothie', 9),
#  ('highly_highly_recommend', 9),
#  ('stuffed_bell_pepper', 9),
#  ('raw_apple_pie', 9),
#  ('us_free_dessert', 9),
#  ('baklava_ive_ever', 9),
#  ('food_mesa_verde', 9),
#  ('mesa_verde_best', 9),
#  ('mesa_verde_great', 9),
#  ('ordered_polenta_fries', 9),
#  ('empanadas_polenta_fries', 9),
#  ('back_try_menu', 8),
#  ('wonderful_customer_service', 8),
#  ('try_something_else', 8),
#  ('not_wait_come', 8),
#  ('eggs_herb_aioli', 8),
#  ('bring_food_table', 8),
#  ('corned_beef_hash', 8),
#  ('first_time_today', 8),
#  ('good_service_good', 8),
#  ('come_back_here', 8),
#  ('strawberries_apple_juice', 8),
#  ('santa_barbara_county', 8),
#  ('love_place_great', 8),
#  ('pear_gorgonzola_flatbread', 8),
#  ('wait_line_order', 8),
#  ('eggs_hollandaise_sauce', 8),
#  ('keep_good_work', 8),
#  ('portobello_mushroom_sandwich', 8),
#  ('santa_barbara_always', 8),
#  ('excellent_customer_service', 8),
#  ('vegan_vegetarian_food', 8),
#  ('drive_santa_barbara', 8),
#  ('counter_bring_food', 8),
#  ('make_feel_like', 8),
#  ('wish_place_like', 8),
#  ('breakfast_dawn_patrol', 8),
#  ('come_back_place', 8),
#  ('super_fresh_tasty', 8),
#  ('bowls_santa_barbara', 8),
#  ('acai_bowl_ive', 8),
#  ('great_place_go', 8),
#  ('service_excellent_food', 8),
#  ('tried_island_bowl', 8),
#  ('service_little_slow', 8),
#  ('like_peanut_butter', 8),
#  ('find_santa_barbara', 8),
#  ('definitely_back_try', 8),
#  ('got_green_bowl', 8),
#  ('santa_barbara_eat', 8),
#  ('time_come_back', 8),
#  ('would_recommend_anyone', 8),
#  ('banana_mango_pineapple', 8),
#  ('mango_pineapple_juice', 8),
#  ('healthy_food_options', 8),
#  ('decided_try_place', 8),
#  ('spot_state_street', 8),
#  ('wow_wow_wow', 8),
#  ('love_come_back', 8),
#  ('chicken_crack_bowl', 8),
#  ('santa_barbara_best', 8),
#  ('santa_barbara_hands', 8),
#  ('eat_santa_barbara', 8),
#  ('write_home_about', 8),
#  ('cant_wait_visit', 8),
#  ('probably_one_best', 8),
#  ('really_liked_place', 8),
#  ('yum_yum_yum', 8),
#  ('plant_based_restaurant', 8),
#  ('gluten_free_bread', 8),
#  ('key_lime_pie', 8),
#  ('poor_customer_service', 8),
#  ('blue_corn_tortilla', 8),
#  ('spinach_artichoke_flatbread', 8),
#  ('place_amazing_food', 8),
#  ('great_food_good', 8),
#  ('santa_barbara_vegan', 8),
#  ('vegan_vanilla_ice', 8),
#  ('favorite_restaurant_sb', 8),
#  ('roasted_turkey_sandwich', 8),
#  ('since_first_time', 8),
#  ('try_everything_menu', 8),
#  ('definitely_check_place', 8),
#  ('best_smoothie_ever', 8),
#  ('go_jamba_juice', 8),
#  ('best_smoothies_ive', 8),
#  ('banana_nonfat_frozen', 8),
#  ('got_tropical_guava', 8),
#  ('smoked_pulled_mushroom', 8),
#  ('ice_cream_pomegranate', 8),
#  ('grilled_peach_salad', 8),
#  ('street_tacos_empanadas', 8),
#  ('us_complimentary_dessert', 8),
#  ('best_vegetarian_restaurant', 8),
#  ('let_tell_you', 7),
#  ('food_came_fast', 7),
#  ('place_good_food', 7),
#  ('strawberries_blueberries_bananas', 7),
#  ('good_healthy_food', 7),
#  ('great_highly_recommend', 7),
#  ('santa_barbara_came', 7),
#  ('healthy_fresh_food', 7),
#  ('favorite_vegan_restaurant', 7),
#  ('delicious_food_great', 7),
#  ('could_eat_everyday', 7),
#  ('ordered_green_bowl', 7),
#  ('best_meals_ive', 7),
#  ('try_santa_barbara', 7),
#  ('acai_berry_bowl', 7),
#  ('service_super_friendly', 7),
#  ('breakfast_santa_barbara', 7),
#  ('coast_village_road', 7),
#  ('would_eat_every', 7),
#  ('santa_barbara_again', 7),
#  ('perfect_way_start', 7),
#  ('last_time_went', 7),
#  ('barbara_first_time', 7),
#  ('excited_try_place', 7),
#  ('way_santa_barbara', 7),
#  ('best_ever_had', 7),
#  ('give_another_try', 7),
#  ('good_nothing_special', 7),
#  ('one_best_breakfast', 7),
#  ('one_best_breakfasts', 7),
#  ('fuji_stir_fry', 7),
#  ('quality_food_service', 7),
#  ('prices_bit_high', 7),
#  ('service_always_friendly', 7),
#  ('super_friendly_service', 7),
#  ('santa_barbara_location', 7),
#  ('fresh_fruit_granola', 7),
#  ('service_great_atmosphere', 7),
#  ('fresh_pressed_juice', 7),
#  ('service_great_friendly', 7),
#  ('im_glad_did', 7),
#  ('beautiful_santa_barbara', 7),
#  ('stop_every_time', 7),
#  ('fresh_local_produce', 7),
#  ('santa_barbara_tried', 7),
#  ('good_highly_recommend', 7),
#  ('jamba_juice_blenders', 7),
#  ('santa_barbara_husband', 7),
#  ('topped_bananas_strawberries', 7),
#  ('great_acai_bowls', 7),
#  ('staff_really_nice', 7),
#  ('food_reasonable_prices', 7),
#  ('santa_barbara_far', 7),
#  ('backyard_bowls_great', 7),
#  ('santa_barbara_roasting', 7),
#  ('coconut_ice_cream', 7),
#  ('give_five_stars', 7),
#  ('gem_santa_barbara', 7),
#  ('im_looking_forward', 7),
#  ('santa_barbara_years', 7),
#  ('place_absolutely_amazing', 7),
#  ('staff_friendly_knowledgeable', 7),
#  ('super_nice_helpful', 7),
#  ('spiritual_spinach_salad', 7),
#  ('id_give_stars', 7),
#  ('hands_down_best', 7),
#  ('bring_food_you', 7),
#  ('visited_santa_barbara', 7),
#  ('ordered_caesar_salad', 7),
#  ('food_absolutely_delicious', 7),
#  ('one_favorite_things', 7),
#  ('living_santa_barbara', 7),
#  ('really_wanted_love', 7),
#  ('pricey_worth_it', 7),
#  ('vegan_restaurant_town', 7),
#  ('were_santa_barbara', 7),
#  ('good_vegan_food', 7),
#  ('ive_never_seen', 7),
#  ('great_place_grab', 7),
#  ('absolutely_loved_it', 7),
#  ('best_açaí_bowls', 7),
#  ('place_first_time', 7),
#  ('wish_could_give', 7),
#  ('im_pretty_sure', 7),
#  ('corn_tortilla_chips', 7),
#  ('try_menu_items', 7),
#  ('love_place_much', 7),
#  ('plant_based_restaurants', 7),
#  ('want_come_back', 7),
#  ('food_friendly_service', 7),
#  ('bowl_green_bowl', 7),
#  ('delicious_would_definitely', 7),
#  ('best_restaurant_santa', 7),
#  ('vegan_food_town', 7),
#  ('also_gave_us', 7),
#  ('vegan_restaurant_santa', 7),
#  ('coming_back_more', 7),
#  ('best_ive_had', 7),
#  ('got_veggie_burger', 7),
#  ('delicious_healthy_food', 7),
#  ('town_salad_grilled', 7),
#  ('juice_strawberries_banana', 7),
#  ('matcha_green_tea', 7),
#  ('favorite_smoothie_place', 7),
#  ('first_time_ive', 7),
#  ('santa_barbara_highly', 7),
#  ('never_go_back', 7),
#  ('vegan_food_santa', 7),
#  ('santa_barbara_try', 7),
#  ('cant_wait_back', 7),
#  ('coming_back_try', 7),
#  ('like_mesa_verde', 7),
#  ('one_best_places', 7),
#  ('food_delicious_healthy', 7),
#  ('homemade_almond_milk', 7),
#  ('highly_recommend_mesa', 7),
#  ('delicious_beautifully_presented', 7),
#  ('amazing_food_amazing', 7),
#  ('healthy_vegan_food', 7),
#  ('meal_mesa_verde', 7),
#  ('fava_bean_puree', 7),
#  ('best_baklava_ive', 7),
#  ('street_tacos_delicious', 7),
#  ('sprouts_street_tacos', 7),
#  ('cacao_black_beans', 7),
#  ('gluten_free_pizza', 7),
#  ('best_vegan_restaurants', 7),
#  ('great_place_eat', 6),
#  ('try_island_bowl', 6),
#  ('minus_one_star', 6),
#  ('lower_state_street', 6),
#  ('sat_outside_patio', 6),
#  ('could_give_stars', 6),
#  ('definitely_one_best', 6),
#  ('fruit_always_fresh', 6),
#  ('reason_give_stars', 6),
#  ('food_great_price', 6),
#  ('definitely_worth_wait', 6),
#  ('strawberries_blueberries_goji', 6),
#  ('great_breakfast_spot', 6),
#  ('lot_across_street', 6),
#  ('build_hash_delicious', 6),
#  ('wish_one_la', 6),
#  ('really_go_wrong', 6),
#  ('live_far_away', 6),
#  ('stop_backyard_bowls', 6),
#  ('best_part_meal', 6),
#  ('friendly_helpful_staff', 6),
#  ('must_try_place', 6),
#  ('friendly_customer_service', 6),
#  ('friendly_staff_great', 6),
#  ('food_highly_recommend', 6),
#  ('burger_ive_ever', 6),
#  ('next_time_ill', 6),
#  ('santa_barbara_staple', 6),
#  ('smoothie_acai_bowl', 6),
#  ('acai_bowl_ever', 6),
#  ('way_start_morning', 6),
#  ('goji_berries_granola', 6),
#  ('berries_granola_honey', 6),
#  ('backyard_bowls_definitely', 6),
#  ('first_time_there', 6),
#  ('would_eat_everyday', 6),
#  ('staff_friendly_attentive', 6),
#  ('give_another_chance', 6),
#  ('friendly_staff_delicious', 6),
#  ('right_next_door', 6),
#  ('great_spot_breakfast', 6),
#  ('got_backyard_bowl', 6),
#  ('place_stop_get', 6),
#  ('stars_service_stars', 6),
#  ('great_place_great', 6),
#  ('mt_fuji_stir', 6),
#  ('place_gluten_free', 6),
#  ('hawaiian_french_toast', 6),
#  ('minutes_get_food', 6),
#  ('place_far_best', 6),
#  ('breakfast_spot_santa', 6),
#  ('backyard_bowls_always', 6),
#  ('looking_forward_next', 6),
#  ('forward_next_visit', 6),
#  ('gluten_free_granola', 6),
#  ('little_pricey_worth', 6),
#  ('good_vegan_options', 6),
#  ('order_counter_get', 6),
#  ('potatoes_corned_beef', 6),
#  ('meals_ive_ever', 6),
#  ('come_back_dinner', 6),
#  ('place_really_good', 6),
#  ('pretty_much_everything', 6),
#  ('acai_bowls_here', 6),
#  ('place_one_best', 6),
#  ('fire_roasted_salsa', 6),
#  ('food_fresh_delicious', 6),
#  ('could_eat_every', 6),
#  ('small_berry_bowl', 6),
#  ('table_next_us', 6),
#  ('acai_banana_mango', 6),
#  ('shavings_granola_honey', 6),
#  ('cafe_great_place', 6),
#  ('santa_barbara_stopped', 6),
#  ('service_top_notch', 6),
#  ('feel_good_eating', 6),
#  ('come_back_would', 6),
#  ('really_like_place', 6),
#  ('whenever_im_santa', 6),
#  ('service_great_too', 6),
#  ('smoothie_ive_ever', 6),
#  ('tofu_brown_rice', 6),
#  ('chips_salsa_also', 6),
#  ('favorite_places_eat', 6),
#  ('feel_right_home', 6),
#  ('go_back_place', 6),
#  ('laid_back_atmosphere', 6),
#  ('also_gluten_free', 6),
#  ('perfect_amount_sweetness', 6),
#  ('never_acai_bowl', 6),
#  ('would_definitely_eat', 6),
#  ('food_service_great', 6),
#  ('customer_service_also', 6),
#  ('teriyaki_chicken_sandwich', 6),
#  ('whenever_santa_barbara', 6),
#  ('customer_service_good', 6),
#  ('definitely_worth_price', 6),
#  ('staff_always_nice', 6),
#  ('always_wanted_try', 6),
#  ('get_one_free', 6),
#  ('im_sure_ill', 6),
#  ('sure_ill_back', 6),
#  ('food_came_quickly', 6),
#  ('looking_something_healthy', 6),
#  ('food_delicious_service', 6),
#  ('blown_away_place', 6),
#  ('would_definitely_get', 6),
#  ('location_state_street', 6),
#  ('great_tasting_healthy', 6),
#  ('come_back_santa', 6),
#  ('smoothie_place_ive', 6),
#  ('split_pea_soup', 6),
#  ('locations_santa_barbara', 6),
#  ('return_next_time', 6),
#  ('actually_really_good', 6),
#  ('would_love_come', 6),
#  ('customer_service_ive', 6),
#  ('frozen_yogurt_ice', 6),
#  ('yogurt_ice_cream', 6),
#  ('blended_bananas_strawberries', 6),
#  ('great_place_get', 6),
#  ('food_ever_had', 6),
#  ('vegetarian_vegan_dishes', 6),
#  ('hard_find_good', 6),
#  ('really_good_food', 6),
#  ('island_bowl_acai', 6),
#  ('forward_coming_back', 6),
#  ('food_came_pretty', 6),
#  ('one_best_ive', 6),
#  ('chocolate_cake_dessert', 6),
#  ('favorite_place_go', 6),
#  ('good_service_great', 6),
#  ('blown_away_food', 6),
#  ('go_wrong_here', 6),
#  ('keeps_coming_back', 6),
#  ('back_try_more', 6),
#  ('bowl_acai_banana', 6),
#  ('vegan_restaurant_ive', 6),
#  ('taken_care_of', 6),
#  ('best_food_ever', 6),
#  ('took_care_us', 6),
#  ('everything_really_good', 6),
#  ('get_bang_buck', 6),
#  ('one_favorite_spots', 6),
#  ('lived_closer_could', 6),
#  ('santa_barbara_staff', 6),
#  ('parking_lot_right', 6),
#  ('cold_pressed_juice', 6),
#  ('always_super_friendly', 6),
#  ('small_parking_lot', 6),
#  ('quick_bite_eat', 6),
#  ('great_people_watching', 6),
#  ('plant_based_foods', 6),
#  ('santa_barbara_amazing', 6),
#  ('best_thing_ever', 6),
#  ('makes_feel_like', 6),
#  ('chicken_caesar_salad', 6),
#  ('santa_barbara_ordered', 6),
#  ('one_free_supplement', 6),
#  ('santa_barbara_needed', 6),
#  ('based_yelp_reviews', 6),
#  ('food_good_price', 6),
#  ('ive_santa_barbara', 6),
#  ('tortilla_chips_salsa', 6),
#  ('santa_barbara_found', 6),
#  ('everything_else_menu', 6),
#  ('ill_definitely_coming', 6),
#  ('get_peanut_butter', 6),
#  ('green_tea_smoothie', 6),
#  ('santa_barbara_make', 6),
#  ('come_back_soon', 6),
#  ('came_first_time', 6),
#  ('every_time_order', 6),
#  ('im_giving_stars', 6),
#  ('banana_ice_milk', 6),
#  ('meat_eating_friends', 6),
#  ('smoothies_ive_ever', 6),
#  ('way_better_jamba', 6),
#  ('best_smoothie_place', 6),
#  ('hands_best_vegan', 6),
#  ('next_visit_santa', 6),
#  ('best_vegan_meals', 6),
#  ('first_time_went', 6),
#  ('service_every_time', 6),
#  ('love_coming_here', 6),
#  ('could_give_place', 6),
#  ('get_unlimited_toppings', 6),
#  ('im_even_vegetarian', 6),
#  ('mesa_verde_food', 6),
#  ('found_green_table', 6),
#  ('can_not_recommend', 6),
#  ('walnut_grilled_kale', 6),
#  ('grilled_kale_burger', 6),
#  ('cashew_cheese_board', 6),
#  ('polenta_fries_favorite', 6),
#  ('started_polenta_fries', 6),
#  ('eat_mesa_verde', 6),
#  ('ordered_macro_bowl', 6),
#  ('back_mesa_verde', 6),
#  ('ordered_picadillo_empanadas', 6),
#  ('decided_try_mesa', 6),
#  ('im_vegan_vegetarian', 6),
#  ('baklava_vegan_ice', 6),
#  ('delicious_vegan_food', 6),
#  ('smoked_mushroom_sandwich', 6),
#  ('restaurants_ive_ever', 6),
#  ('street_tacos_baklava', 6),
#  ('tacos_street_tacos', 6),
#  ('verde_first_time', 6),
#  ('save_room_dessert', 6),
#  ('santa_barbara_mesa', 6),
#  ('grilled_flatbread_hummus', 6),
#  ('stopped_mesa_verde', 6),
#  ('better_every_time', 6),
#  ('grilled_cashew_cheese', 6),
#  ('get_kids_size', 5),
#  ('great_breakfast_place', 5),
#  ('go_island_bowl', 5),
#  ('highly_recommend_going', 5),
#  ('highly_recommend_them', 5),
#  ('next_time_sb', 5),
#  ('natural_cafe_one', 5),
#  ('pretty_good_too', 5),
#  ('health_food_stores', 5),
#  ('getaway_santa_barbara', 5),
#  ('friendly_attentive_staff', 5),
#  ('added_peanut_butter', 5),
#  ('friendly_staff_food', 5),
#  ('definitely_eat_again', 5),
#  ('good_sized_portions', 5),
#  ('santa_barbara_super', 5),
#  ('trips_santa_barbara', 5),
#  ('food_really_fresh', 5),
#  ('poached_eggs_herb', 5),
#  ('acai_banana_strawberry', 5),
#  ('back_try_items', 5),
#  ('cant_really_go', 5),
#  ('amazing_vegan_restaurant', 5),
#  ('potatoes_sage_sausage', 5),
#  ('place_highly_recommend', 5),
#  ('acai_bowls_backyard', 5),
#  ('try_dawn_patrol', 5),
#  ('dawn_patrol_great', 5),
#  ('got_breakfast_burrito', 5),
#  ('really_wanted_like', 5),
#  ('favorite_place_eat', 5),
#  ('ive_tried_many', 5),
#  ('love_place_love', 5),
#  ('island_bowl_berry', 5),
#  ('build_hash_great', 5),
#  ('cant_stop_thinking', 5),
#  ('friendly_staff_clean', 5),
#  ('pretty_good_service', 5),
#  ('best_breakfast_ever', 5),
#  ('try_new_things', 5),
#  ('build_hash_amazing', 5),
#  ('here_food_good', 5),
#  ('great_acai_bowl', 5),
#  ('go_next_time', 5),
#  ('got_sweet_potatoes', 5),
#  ('favorite_breakfast_spot', 5),
#  ('service_good_food', 5),
#  ('everything_tasted_fresh', 5),
#  ('great_tasting_food', 5),
#  ('banana_strawberries_apple', 5),
#  ('toppings_banana_fresh', 5),
#  ('banana_fresh_berries', 5),
#  ('berries_goji_berries', 5),
#  ('black_bean_enchiladas', 5),
#  ('place_state_street', 5),
#  ('check_santa_barbara', 5),
#  ('order_pay_counter', 5),
#  ('outdoor_seating_available', 5),
#  ('ingredients_super_fresh', 5),
#  ('make_sure_everything', 5),
#  ('im_going_back', 5),
#  ('ended_waiting_minutes', 5),
#  ('next_trip_santa', 5),
#  ('sage_sausage_spinach', 5),
#  ('let_start_saying', 5),
#  ('reasonable_amount_time', 5),
#  ('go_backyard_bowls', 5),
#  ('santa_barbara_come', 5),
#  ('guy_behind_counter', 5),
#  ('wait_staff_friendly', 5),
#  ('great_staff_great', 5),
#  ('stir_fry_tofu', 5),
#  ('place_like_this', 5),
#  ('fresh_well_prepared', 5),
#  ('definitely_recommend_it', 5),
#  ('butternut_squash_ravioli', 5),
#  ('places_ive_ever', 5),
#  ('food_service_atmosphere', 5),
#  ('apple_crumble_dessert', 5),
#  ('acai_bowls_smoothies', 5),
#  ('guy_took_order', 5),
#  ('makes_feel_good', 5),
#  ('shop_next_door', 5),
#  ('gluten_free_menu', 5),
#  ('another_minutes_get', 5),
#  ('decided_give_place', 5),
#  ('breakfast_build_hash', 5),
#  ('state_street_place', 5),
#  ('get_acai_bowls', 5),
#  ('acai_bowls_place', 5),
#  ('berry_bowl_added', 5),
#  ('acai_bowl_places', 5),
#  ('ever_had_also', 5),
#  ('coming_back_place', 5),
#  ('bowl_backyard_bowls', 5),
#  ('diego_bowl_peanut', 5),
#  ('service_amazing_food', 5),
#  ('used_love_place', 5),
#  ('fruit_granola_honey', 5),
#  ('ingredients_fresh_delicious', 5),
#  ('fast_friendly_service', 5),
#  ('would_minute_wait', 5),
#  ('like_santa_barbara', 5),
#  ('wait_long_time', 5),
#  ('bowl_diegos_power', 5),
#  ('many_vegetarian_options', 5),
#  ('french_toast_good', 5),
#  ('one_best_things', 5),
#  ('try_acai_bowls', 5),
#  ('waited_another_minutes', 5),
#  ('get_pay_for', 5),
#  ('place_go_to', 5),
#  ('tried_berry_bowl', 5),
#  ('topped_banana_strawberry', 5),
#  ('wish_would_open', 5),
#  ('back_next_visit', 5),
#  ('delicious_fresh_ingredients', 5),
#  ('food_customer_service', 5),
#  ('ordered_breakfast_burrito', 5),
#  ('would_give_place', 5),
#  ('get_acai_bowl', 5),
#  ('really_nice_staff', 5),
#  ('ordered_huevos_rancheros', 5),
#  ('staff_extremely_friendly', 5),
#  ('came_pretty_quickly', 5),
#  ('island_bowl_favorite', 5),
#  ('place_great_food', 5),
#  ('bowl_blended_acai', 5),
#  ('blended_acai_banana', 5),
#  ('ive_vegetarian_years', 5),
#  ('bowl_small_size', 5),
#  ('food_tastes_good', 5),
#  ('outdoor_seating_nice', 5),
#  ('great_service_food', 5),
#  ('wide_variety_choices', 5),
#  ('definitely_go_again', 5),
#  ('santa_barbara_want', 5),
#  ('back_again_place', 5),
#  ('it_one_best', 5),
#  ('santa_barbara_fresh', 5),
#  ('favorite_santa_barbara', 5),
#  ('best_smoothie_ive', 5),
#  ('found_dawn_patrol', 5),
#  ('im_area_again', 5),
#  ('smoothie_die_for', 5),
#  ('santa_barbara_absolutely', 5),
#  ('would_come_again', 5),
#  ('definitely_recommend_anyone', 5),
#  ('worth_it_get', 5),
#  ('here_cant_wait', 5),
#  ('freshly_squeezed_orange', 5),
#  ('def_go_back', 5),
#  ('backyard_bowls_delicious', 5),
#  ('first_time_visiting', 5),
#  ('around_santa_barbara', 5),
#  ('coming_back_here', 5),
#  ('fresh_healthy_food', 5),
#  ('came_fairly_quickly', 5),
#  ('could_barely_finish', 5),
#  ('get_açaí_bowl', 5),
#  ('first_time_coming', 5),
#  ('service_fast_friendly', 5),
#  ('barbara_roasting_company', 5),
#  ('place_super_cute', 5),
#  ('santa_barbara_excellent', 5),
#  ('first_time_going', 5),
#  ('barbara_hands_down', 5),
#  ('not_wait_go', 5),
#  ('back_im_area', 5),
#  ('service_staff_friendly', 5),
#  ('customer_service_awesome', 5),
#  ('everything_fresh_delicious', 5),
#  ('little_pricey_side', 5),
#  ('first_time_came', 5),
#  ('food_great_staff', 5),
#  ('natural_cafe_locations', 5),
#  ('would_like_see', 5),
#  ('worth_it_im', 5),
#  ('chocolate_peanut_butter', 5),
#  ('salad_tahini_dressing', 5),
#  ('delicious_service_great', 5),
#  ('fresh_food_great', 5),
#  ('bowl_pitaya_bowl', 5),
#  ('service_friendly_helpful', 5),
#  ('dinner_last_night', 5),
#  ('visit_next_time', 5),
#  ('time_were_santa', 5),
#  ('couple_weeks_ago', 5),
#  ('great_vegan_food', 5),
#  ('ive_coming_years', 5),
#  ('made_hemp_milk', 5),
#  ('place_order_phone', 5),
#  ('food_super_yummy', 5),
#  ('say_enough_good', 5),
#  ('enough_good_things', 5),
#  ('great_experience_highly', 5),
#  ('really_feel_like', 5),
#  ('food_absolutely_amazing', 5),
#  ('plant_based_menu', 5),
#  ('jamba_juice_robeks', 5),
#  ('really_good_place', 5),
#  ('good_quality_food', 5),
#  ('small_island_bowl', 5),
#  ('staff_helpful_friendly', 5),
#  ('best_customer_service', 5),
#  ('even_finish_it', 5),
#  ('plant_based_vegan', 5),
#  ('santa_barbara_quick', 5),
#  ('food_always_good', 5),
#  ('go_back_amazing', 5),
#  ('tasted_like_real', 5),
#  ('definitely_worth_visit', 5),
#  ('clean_staff_friendly', 5),
#  ('love_plant_based', 5),
#  ('amazing_mesa_verde', 5),
#  ('highly_recommend_coming', 5),
#  ('food_always_great', 5),
#  ('one_new_favorite', 5),
#  ('food_brought_table', 5),
#  ('aesthetics_food_service', 5),
#  ('day_santa_barbara', 5),
#  ('excellent_food_service', 5),
#  ('amazing_every_time', 5),
#  ('staff_really_friendly', 5),
#  ('im_vegetarian_vegan', 5),
#  ('flatbread_pad_thai', 5),
#  ('santa_barbara_also', 5),
#  ('best_place_ever', 5),
#  ('side_salad_also', 5),
#  ('us_feel_welcome', 5),
#  ('go_mesa_verde', 5),
#  ('always_fresh_delicious', 5),
#  ('amazing_acai_bowls', 5),
#  ('eat_plant_based', 5),
#  ('quality_food_excellent', 5),
#  ('highly_recommend_anyone', 5),
#  ('always_friendly_helpful', 5),
#  ('santa_barbara_way', 5),
#  ('back_bay_area', 5),
#  ('excellent_vegan_food', 5),
#  ('us_dessert_house', 5),
#  ('plan_go_back', 5),
#  ('go_back_im', 5),
#  ('santa_barbara_bowl', 5),
#  ('really_excited_try', 5),
#  ('service_awesome_food', 5),
#  ('ive_ever_life', 5),
#  ('can_not_imagine', 5),
#  ('walk_state_street', 5),
#  ('service_really_good', 5),
#  ...]

# %% [markdown]
# ### Pizza

# %%
Pizza = business_df[business_df.Type=='Pizza']
Pizza_review = review1[review1.business_id.isin(Pizza.business_id.values)]
Pizza_review["text"] = Pizza_review["text"].str.lower()
Pizza_review['text'] = Pizza_review['text'].apply(lambda text: cleaning_stopwords(text))
Pizza_review['text']= Pizza_review['text'].apply(lambda x: cleaning_punctuations(x))
Pizza_review['text'] = Pizza_review['text'].apply(lambda x: cleaning_repeating_char(x))
Pizza_review['text'] = Pizza_review['text'].apply(lambda x: cleaning_URLs(x))
Pizza_review['text'] = Pizza_review['text'].apply(lambda x: cleaning_numbers(x))
# Out:
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/eason/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_Pizza=Pizza[Pizza.stars<3.5]
bad_Pizza_review = Pizza_review[Pizza_review.business_id.isin(bad_Pizza.business_id.values)]
bad_Pizza_review_text = bad_Pizza_review.text.str.cat(sep = " ")
bad_Pizza_tokens = word_tokenize(bad_Pizza_review_text)

bigrams_list_bad_Pizza = ["_".join(item) for item in nltk.bigrams(bad_Pizza_tokens)]
trigrams_list_bad_Pizza = ["_".join(item) for item in nltk.trigrams(bad_Pizza_tokens)]
# FreqDist(bad_Pizza_tokens).most_common()
# FreqDist(bigrams_list_bad_Pizza).most_common()
FreqDist(trigrams_list_bad_Pizza).most_common()
# Out:
# [('new_york_pizza', 22),
#  ('thin_crust_pizza', 20),
#  ('worst_customer_service', 20),
#  ('bbq_chicken_pizza', 19),
#  ('best_pizza_town', 16),
#  ('horrible_customer_service', 15),
#  ('pizza_santa_barbara', 15),
#  ('california_pizza_kitchen', 15),
#  ('pizza_thin_crust', 14),
#  ('really_good_pizza', 13),
#  ('ny_style_pizza', 13),
#  ('ive_ever_had', 13),
#  ('new_york_style', 13),
#  ('garlic_cheese_bread', 12),
#  ('pizza_ive_ever', 12),
#  ('never_go_back', 11),
#  ('pizza_pretty_good', 11),
#  ('trip_salad_bar', 10),
#  ('best_pizza_ive', 10),
#  ('terrible_customer_service', 10),
#  ('customer_service_ever', 10),
#  ('good_customer_service', 9),
#  ('cant_go_wrong', 9),
#  ('best_pizza_ever', 9),
#  ('york_style_pizza', 9),
#  ('never_order_again', 8),
#  ('poor_customer_service', 8),
#  ('visit_santa_barbara', 8),
#  ('great_customer_service', 8),
#  ('good_pizza_good', 8),
#  ('pizza_really_good', 8),
#  ('pizza_salad_bar', 8),
#  ('slice_cheese_pizza', 8),
#  ('one_trip_salad', 7),
#  ('love_rustys_pizza', 7),
#  ('visiting_santa_barbara', 7),
#  ('ordered_large_pepperoni', 7),
#  ('bad_customer_service', 7),
#  ('best_pizza_santa', 7),
#  ('wait_another_minutes', 6),
#  ('salad_bar_fresh', 6),
#  ('place_get_pizza', 6),
#  ('thin_crust_pepperoni', 6),
#  ('rustys_pizza_parlor', 6),
#  ('customer_service_skills', 6),
#  ('large_pepperoni_pizza', 6),
#  ('good_pizza_place', 6),
#  ('go_somewhere_else', 6),
#  ('tasted_like_cardboard', 6),
#  ('ordered_pepperoni_pizza', 6),
#  ('uncle_roccos_pizza', 6),
#  ('pizza_best_pizza', 5),
#  ('got_order_wrong', 5),
#  ('pizza_good_pizza', 5),
#  ('pan_crust_pizza', 5),
#  ('made_feel_like', 5),
#  ('asked_speak_manager', 5),
#  ('good_thin_crust', 5),
#  ('would_definitely_recommend', 5),
#  ('could_care_less', 5),
#  ('good_salad_bar', 5),
#  ('pretty_good_pizza', 5),
#  ('every_time_go', 5),
#  ('far_best_pizza', 5),
#  ('late_night_pizza', 5),
#  ('great_pizza_great', 5),
#  ('thai_crunch_salad', 5),
#  ('definitely_come_back', 5),
#  ('one_best_pizzas', 5),
#  ('never_come_back', 5),
#  ('customer_service_ive', 5),
#  ('get_money_back', 5),
#  ('food_great_service', 5),
#  ('love_pizza_chance', 5),
#  ('pizza_chance_guys', 5),
#  ('chance_guys_ever', 5),
#  ('guys_ever_available', 5),
#  ('ever_available_doordash', 5),
#  ('pizza_customer_service', 5),
#  ('gluten_free_pizza', 5),
#  ('quick_bite_eat', 5),
#  ('many_pizza_places', 5),
#  ('real_ny_pizza', 5),
#  ('pizza_uncle_roccos', 5),
#  ('small_salad_bar', 4),
#  ('order_thin_crust', 4),
#  ('half_rustys_special', 4),
#  ('it_thin_crust', 4),
#  ('customer_service_also', 4),
#  ('rustys_good_pizza', 4),
#  ('first_time_coming', 4),
#  ('food_good_service', 4),
#  ('get_thin_crust', 4),
#  ('two_large_pizzas', 4),
#  ('salad_bar_looked', 4),
#  ('pizza_cheesy_bread', 4),
#  ('back_one_time', 4),
#  ('great_pizza_place', 4),
#  ('round_table_pizza', 4),
#  ('pizza_good_thin', 4),
#  ('ordered_large_pizza', 4),
#  ('large_cheese_pizza', 4),
#  ('great_food_great', 4),
#  ('customer_service_would', 4),
#  ('salad_bar_drink', 4),
#  ('phone_number_address', 4),
#  ('place_santa_barbara', 4),
#  ('mac_n_cheese', 4),
#  ('go_santa_barbara', 4),
#  ('got_food_poisoning', 4),
#  ('never_ordering_again', 4),
#  ('would_definitely_go', 4),
#  ('definitely_go_back', 4),
#  ('santa_barbara_always', 4),
#  ('could_give_place', 4),
#  ('order_extra_sauce', 4),
#  ('ordered_thin_crust', 4),
#  ('barbecue_chicken_pizza', 4),
#  ('chicken_tequila_fettuccine', 4),
#  ('give_zero_stars', 4),
#  ('service_always_good', 4),
#  ('garlic_cream_fettuccine', 4),
#  ('service_good_food', 4),
#  ('worst_pizza_ever', 4),
#  ('good_pizza_nice', 4),
#  ('pizza_man_dans', 4),
#  ('would_give_stars', 4),
#  ('downtown_santa_barbara', 4),
#  ('thin_crust_rustys', 4),
#  ('never_received_order', 4),
#  ('every_single_time', 4),
#  ('one_topping_pizza', 4),
#  ('staff_friendly_helpful', 4),
#  ('next_time_ill', 4),
#  ('two_medium_pizzas', 4),
#  ('great_place_get', 4),
#  ('customer_service_worst', 4),
#  ('another_pizza_place', 4),
#  ('salad_bar_pizza', 4),
#  ('ordering_dominos_again', 4),
#  ('pizza_great_service', 4),
#  ('ordered_medium_pizza', 4),
#  ('ordered_cheese_pizza', 4),
#  ('give_place_zero', 4),
#  ('let_us_know', 4),
#  ('let_start_saying', 4),
#  ('right_state_street', 4),
#  ('awesome_customer_service', 4),
#  ('come_back_pizza', 4),
#  ('service_great_pizza', 4),
#  ('nyc_style_pizza', 4),
#  ('pizza_new_york', 4),
#  ('two_slices_pizza', 3),
#  ('pizza_small_salad', 3),
#  ('half_pepperoni_half', 3),
#  ('chuck_e_cheese', 3),
#  ('chicken_garlic_mushroom', 3),
#  ('order_call_back', 3),
#  ('rustys_pizza_parlors', 3),
#  ('pizza_garlic_cheese', 3),
#  ('hung_me_called', 3),
#  ('first_time_pizza', 3),
#  ('going_rustys_since', 3),
#  ('place_thin_crust', 3),
#  ('visit_salad_bar', 3),
#  ('chile_verde_pizza', 3),
#  ('topping_personal_pizza', 3),
#  ('make_sure_order', 3),
#  ('santa_barbara_love', 3),
#  ('quick_lunch_special', 3),
#  ('lunch_special_personal', 3),
#  ('pizza_hut_dominos', 3),
#  ('would_go_back', 3),
#  ('ordered_two_large', 3),
#  ('salad_bar_really', 3),
#  ('salad_salad_bar', 3),
#  ('first_last_time', 3),
#  ('good_quality_pizza', 3),
#  ('decided_eat_pizza', 3),
#  ('ordered_pizza_location', 3),
#  ('rustys_best_pizza', 3),
#  ('pizza_dad_ordered', 3),
#  ('new_years_eve', 3),
#  ('experience_best_pizza', 3),
#  ('best_pizza_around', 3),
#  ('time_customer_service', 3),
#  ('made_eye_contact', 3),
#  ('el_diablo_fuego', 3),
#  ('tastes_like_pizza', 3),
#  ('like_pizza_hut', 3),
#  ('tip_top_that', 3),
#  ('santa_barbara_ca', 3),
#  ('long_time_customer', 3),
#  ('customer_service_reflects', 3),
#  ('definitely_coming_back', 3),
#  ('using_debit_card', 3),
#  ('pizza_nothing_special', 3),
#  ('pizza_good_service', 3),
#  ('time_santa_barbara', 3),
#  ('time_make_sure', 3),
#  ('ordered_bbq_chicken', 3),
#  ('pizza_next_time', 3),
#  ('crust_rustys_special', 3),
#  ('worst_service_ever', 3),
#  ('seated_right_away', 3),
#  ('pizza_ok_better', 3),
#  ('nice_salad_bar', 3),
#  ('reason_im_giving', 3),
#  ('came_around_pm', 3),
#  ('pizza_good_great', 3),
#  ('ive_santa_barbara', 3),
#  ('save_money_go', 3),
#  ('order_here_ordered', 3),
#  ('place_best_pizza', 3),
#  ('hour_half_later', 3),
#  ('told_another_minutes', 3),
#  ('garlic_chicken_pizza', 3),
#  ('good_pizza_great', 3),
#  ('small_thin_crust', 3),
#  ('love_thin_crust', 3),
#  ('pizza_great_customer', 3),
#  ('large_pizza_half', 3),
#  ('gotten_order_wrong', 3),
#  ('open_late_night', 3),
#  ('original_bbq_chicken', 3),
#  ('spinach_artichoke_dip', 3),
#  ('order_rustys_again', 3),
#  ('pizza_last_night', 3),
#  ('pizza_real_deal', 3),
#  ('chinese_chicken_salad', 3),
#  ('personal_sized_pizza', 3),
#  ('every_time_visit', 3),
#  ('next_time_im', 3),
#  ('pizza_parlor_first', 3),
#  ('time_come_back', 3),
#  ('location_santa_barbara', 3),
#  ('cheesy_garlic_bread', 3),
#  ('avocado_egg_rolls', 3),
#  ('crispy_thin_crust', 3),
#  ('ordered_pizza_dominos', 3),
#  ('pizza_since_kid', 3),
#  ('wait_minutes_get', 3),
#  ('pizza_would_highly', 3),
#  ('would_highly_recommend', 3),
#  ('ordered_lunch_special', 3),
#  ('place_pizza_good', 3),
#  ('food_pretty_good', 3),
#  ('id_give_place', 3),
#  ('ive_ever_encountered', 3),
#  ('good_service_good', 3),
#  ('time_worst_customer', 3),
#  ('location_several_times', 3),
#  ('like_dominos_pizza', 3),
#  ('manager_said_no', 3),
#  ('side_santa_barbara', 3),
#  ('ordered_large_cheese', 3),
#  ('california_club_pizza', 3),
#  ('santa_barbara_people', 3),
#  ('even_say_sorry', 3),
#  ('work_customer_service', 3),
#  ('took_hour_half', 3),
#  ('medium_topping_pizza', 3),
#  ('took_minutes_get', 3),
#  ('calle_real_location', 3),
#  ('im_giving_stars', 3),
#  ('ordered_quick_lunch', 3),
#  ('eating_rustys_since', 3),
#  ('took_forever_get', 3),
#  ('get_right_food', 3),
#  ('try_something_new', 3),
#  ('ordered_pizza_salad', 3),
#  ('worst_pizza_ive', 3),
#  ('place_still_business', 3),
#  ('really_wanted_pizza', 3),
#  ('give_negative_stars', 3),
#  ('keep_coming_back', 3),
#  ('pizza_place_good', 3),
#  ('pizza_stopped_quick', 3),
#  ('stopped_quick_bite', 3),
#  ('better_customer_service', 3),
#  ('santa_barbara_pizza', 3),
#  ('make_sure_get', 3),
#  ('great_tasting_pizza', 3),
#  ('santa_barbara_really', 3),
#  ('long_story_short', 3),
#  ('called_next_day', 3),
#  ('large_pizza_large', 3),
#  ('pizza_definitely_worth', 3),
#  ('definitely_worth_it', 3),
#  ('cant_wait_come', 3),
#  ('place_zero_stars', 3),
#  ('customer_service_bad', 3),
#  ('credit_card_charge', 3),
#  ('pizza_hit_spot', 3),
#  ('decided_get_pizza', 3),
#  ('service_ever_ordered', 3),
#  ('large_salad_bowl', 3),
#  ('would_order_again', 3),
#  ('pizza_tastes_like', 3),
#  ('best_pizza_place', 3),
#  ('guy_took_order', 3),
#  ('never_eat_again', 3),
#  ('delivered_hotel_room', 3),
#  ('never_coming_back', 3),
#  ('good_place_stop', 3),
#  ('ordered_pizza_delivery', 3),
#  ('wings_pizza_good', 3),
#  ('red_pepper_flakes', 3),
#  ('outdoor_seating_area', 3),
#  ('high_quality_ingredients', 3),
#  ('next_time_visit', 3),
#  ('time_visit_santa', 3),
#  ('carpinteria_state_beach', 3),
#  ('crust_thin_crispy', 3),
#  ('decided_give_try', 3),
#  ('pizza_ever_tasted', 3),
#  ('small_cheese_pizza', 3),
#  ('order_whole_pizza', 3),
#  ('wish_could_give', 3),
#  ('service_ive_ever', 3),
#  ('ive_ever_experienced', 3),
#  ('bring_food_table', 3),
#  ('late_night_fee', 3),
#  ('pizza_pepperoni_sausage', 3),
#  ('place_really_good', 3),
#  ('pizza_new_yorker', 3),
#  ('great_place_sit', 3),
#  ('uncle_roccos_new', 3),
#  ('roccos_new_york', 3),
#  ('really_good_service', 3),
#  ('authentic_new_york', 3),
#  ('love_ny_pizza', 3),
#  ('pizza_place_would', 3),
#  ('pepperoni_pizza_slice', 3),
#  ('uncle_roccos_best', 3),
#  ('pizza_okay_best', 3),
#  ('inside_public_market', 3),
#  ('get_personal_pizza', 2),
#  ('im_sorry_say', 2),
#  ('place_looked_like', 2),
#  ('pizza_joint_town', 2),
#  ('came_first_time', 2),
#  ('time_years_last', 2),
#  ('american_style_pizza', 2),
#  ('well_pizza_good', 2),
#  ('next_time_ordered', 2),
#  ('time_ordered_delivery', 2),
#  ('good_luck_getting', 2),
#  ('it_pizza_okay', 2),
#  ('rustys_special_half', 2),
#  ('half_chicken_garlic', 2),
#  ('ranch_pizza_sauce', 2),
#  ('keep_up_guys', 2),
#  ('call_place_order', 2),
#  ('right_next_door', 2),
#  ('little_caesars_rustys', 2),
#  ('pizza_got_half', 2),
#  ('got_half_bbq', 2),
#  ('go_back_rustys', 2),
#  ('get_one_star', 2),
#  ('option_zero_stars', 2),
#  ('fast_pizza_good', 2),
#  ('good_pizza_bad', 2),
#  ('pizza_one_trip', 2),
#  ('personal_pan_pizza', 2),
#  ('place_pick_order', 2),
#  ('go_place_order', 2),
#  ('zero_stars_would', 2),
#  ('lady_behind_counter', 2),
#  ('free_pizza_garlic', 2),
#  ('called_corporate_office', 2),
#  ('take_advantage_free', 2),
#  ('replacement_cheese_pizza', 2),
#  ('system_call_center', 2),
#  ('placed_order_online', 2),
#  ('get_bbq_chicken', 2),
#  ('chicken_pizza_chicken', 2),
#  ('last_time_went', 2),
#  ('video_games_salad', 2),
#  ('pizza_ordered_pepperoni', 2),
#  ('old_bank_vault', 2),
#  ('lunch_special_get', 2),
#  ('topping_pizza_small', 2),
#  ('pizza_almost_every', 2),
#  ('pizzas_slices_left', 2),
#  ('called_speak_manager', 2),
#  ('speak_manager_said', 2),
#  ('manager_said_would', 2),
#  ('trying_get_something', 2),
#  ('get_something_free', 2),
#  ('rustys_since_s', 2),
#  ('good_neighborhood_pizza', 2),
#  ('neighborhood_pizza_place', 2),
#  ('ordered_delivery_order', 2),
#  ('thin_layer_cheese', 2),
#  ('asked_would_like', 2),
#  ('going_order_pizza', 2),
#  ('deep_dish_pizza', 2),
#  ('pizza_pizza_decent', 2),
#  ('pizza_feel_like', 2),
#  ('feel_like_driving', 2),
#  ('dominos_pizza_hut', 2),
#  ('pepperoni_pineapple_pizza', 2),
#  ('fresh_salad_bar', 2),
#  ('waiting_minutes_pizza', 2),
#  ('best_ive_ever', 2),
#  ('pretty_cool_inside', 2),
#  ('name_much_said', 2),
#  ('service_best_pizza', 2),
#  ('pizza_cooked_well', 2),
#  ('green_chiles_chorizo', 2),
#  ('chiles_chorizo_canadian', 2),
#  ('chorizo_canadian_style', 2),
#  ('canadian_style_bacon', 2),
#  ('style_bacon_pepperoni', 2),
#  ('bacon_pepperoni_fresh', 2),
#  ('pepperoni_fresh_onion', 2),
#  ('fresh_onion_fresh', 2),
#  ('onion_fresh_tomato', 2),
#  ('fresh_tomato_black', 2),
#  ('tomato_black_olives', 2),
#  ('tangy_bbq_sauce', 2),
#  ('pizzas_well_done', 2),
#  ('well_done_crispy', 2),
#  ('could_use_clean', 2),
#  ('stopped_quick_lunch', 2),
#  ('quick_lunch_since', 2),
#  ('look_menu_order', 2),
#  ('special_personal_topping', 2),
#  ('personal_topping_pizza', 2),
#  ('salad_bar_small', 2),
#  ('bar_small_drink', 2),
#  ('bad_salad_bar', 2),
#  ('thin_crust_crunchy', 2),
#  ('better_pizza_hut', 2),
#  ('go_back_im', 2),
#  ('crust_pepperoni_jalapenos', 2),
#  ('great_salad_bar', 2),
#  ('bar_really_good', 2),
#  ('definitely_worth_extra', 2),
#  ('living_santa_barbara', 2),
#  ('santa_barbara_three', 2),
#  ('every_time_went', 2),
#  ('lunch_lunch_special', 2),
#  ('ordered_med_rustys', 2),
#  ('med_rustys_special', 2),
#  ('called_rustys_hotline', 2),
#  ('rustys_hotline_told', 2),
#  ('ordered_online_pizza', 2),
#  ('customer_service_interaction', 2),
#  ('service_interaction_ive', 2),
#  ('interaction_ive_ever', 2),
#  ('waited_hour_pizza', 2),
#  ('pizza_never_came', 2),
#  ('santa_barbara_location', 2),
#  ('food_ready_time', 2),
#  ('classic_pizza_place', 2),
#  ('tried_ordering_order', 2),
#  ('ordering_order_business', 2),
#  ('order_business_partners', 2),
#  ('business_partners_family', 2),
#  ('partners_family_friends', 2),
#  ('family_friends_daily', 2),
#  ('friends_daily_basis', 2),
#  ('daily_basis_probably', 2),
#  ('basis_probably_aroundmo', 2),
#  ('probably_aroundmo_tonight', 2),
#  ('aroundmo_tonight_declined', 2),
#  ('tonight_declined_allow', 2),
#  ('declined_allow_order', 2),
#  ('allow_order_feel', 2),
#  ('order_feel_like', 2),
#  ('feel_like_delivering', 2),
#  ('one_time_disgusting', 2),
#  ('got_half_cheese', 2),
#  ('next_day_lunch', 2),
#  ('santa_barbara_days', 2),
#  ('pizza_place_huge', 2),
#  ('pizza_last_time', 2),
#  ('last_time_order', 2),
#  ('pizza_pan_crust', 2),
#  ('pizza_amazing_got', 2),
#  ('customer_service_guys', 2),
#  ('guys_taking_order', 2),
#  ('taking_order_rude', 2),
#  ('people_behind_counter', 2),
#  ('love_rustys_best', 2),
#  ('wrong_second_time', 2),
#  ('chicago_style_pan', 2),
#  ('style_pan_pizza', 2),
#  ('plain_cheese_pizza', 2),
#  ('sausage_mushroom_pizza', 2),
#  ('crust_really_cooked', 2),
#  ('enough_one_person', 2),
#  ('rustys_better_pizza', 2),
#  ('going_back_rustys', 2),
#  ('thin_thick_crust', 2),
#  ('big_pizza_person', 2),
#  ('pizza_place_ordered', 2),
#  ('ordered_large_rustys', 2),
#  ('large_rustys_special', 2),
#  ('called_back_let', 2),
#  ('asked_name_said', 2),
#  ('worked_hospitality_industry', 2),
#  ('hospitality_industry_years', 2),
#  ('say_least_disappointed', 2),
#  ('pizza_sauce_marinara', 2),
#  ('large_pizza_pineapple', 2),
#  ('guess_what_onions', 2),
#  ('what_onions_burnt', 2),
#  ('pizza_one_two', 2),
#  ('would_given_stars', 2),
#  ('online_ordering_hope', 2),
#  ('online_ordering_system', 2),
#  ('girl_behind_counter', 2),
#  ('would_like_order', 2),
#  ('pizza_ordered_large', 2),
#  ('im_pretty_sure', 2),
#  ('pretty_damn_good', 2),
#  ('cheese_pizza_ordered', 2),
#  ('waited_hour_delivery', 2),
#  ('okay_pizza_okay', 2),
#  ('crust_pizza_slice', 2),
#  ('can_not_eat', 2),
#  ('santa_barbara_without', 2),
#  ('charge_delivery_fee', 2),
#  ('top_that_pizza', 2),
#  ('that_pizza_great', 2),
#  ('santa_barbara_even', 2),
#  ('driving_santa_barbara', 2),
#  ('chicken_pizza_good', 2),
#  ('pizza_slice_good', 2),
#  ('manager_diego_customer', 2),
#  ('diego_customer_service', 2),
#  ('customer_service_server', 2),
#  ('service_server_yesenia', 2),
#  ('server_yesenia_exceptionally', 2),
#  ('yesenia_exceptionally_rude', 2),
#  ('exceptionally_rude_imconsiderate', 2),
#  ('rude_imconsiderate_unhelpful', 2),
#  ('imconsiderate_unhelpful_inquired', 2),
#  ('unhelpful_inquired_menu', 2),
#  ('inquired_menu_pizza', 2),
#  ('menu_pizza_special', 2),
#  ('pizza_special_long', 2),
#  ('special_long_time', 2),
#  ('time_customer_native', 2),
#  ('customer_native_santa', 2),
#  ('native_santa_barbaran', 2),
#  ('santa_barbaran_horrible', 2),
#  ('barbaran_horrible_service', 2),
#  ('horrible_service_acceptable', 2),
#  ('service_acceptable_town', 2),
#  ('acceptable_town_many', 2),
#  ('town_many_lunch', 2),
#  ('many_lunch_restaurant', 2),
#  ('lunch_restaurant_options', 2),
#  ('restaurant_options_location', 2),
#  ('options_location_seriously', 2),
#  ('location_seriously_lacking', 2),
#  ('seriously_lacking_customer', 2),
#  ('lacking_customer_service', 2),
#  ('service_reflects_poorly', 2),
#  ('reflects_poorly_overall', 2),
#  ('poorly_overall_rustys', 2),
#  ('overall_rustys_brand', 2),
#  ('rustys_brand_reputation', 2),
#  ('brand_reputation_customer', 2),
#  ('reputation_customer_expectation', 2),
#  ('customer_expectation_epic', 2),
#  ('expectation_epic_fail', 2),
#  ('diablo_bbq_chicken', 2),
#  ('chili_verde_pizza', 2),
#  ('old_arcade_games', 2),
#  ('year_old_son', 2),
#  ('went_across_street', 2),
#  ('games_keep_kids', 2),
#  ('customer_service_never', 2),
#  ('never_written_bad', 2),
#  ('written_bad_review', 2),
#  ('while_delivery_guy', 2),
#  ('voted_number_one', 2),
#  ('one_santa_barbara', 2),
#  ('here_pizza_delicious', 2),
#  ('pizza_delicious_thin', 2),
#  ('delicious_thin_crust', 2),
#  ('crust_amazing_salad', 2),
#  ('rustys_santa_barbara', 2),
#  ('santa_barbara_also', 2),
#  ('salad_bar_always', 2),
#  ('however_delivery_service', 2),
#  ('santa_barbara_probably', 2),
#  ('food_never_disappoints', 2),
#  ('rustys_really_good', 2),
#  ('less_customer_service', 2),
#  ('pizza_town_nice', 2),
#  ('ive_ever_to', 2),
#  ('going_back_soon', 2),
#  ('good_service_great', 2),
#  ('first_time_santa', 2),
#  ('surprised_high_quality', 2),
#  ('manager_told_us', 2),
#  ('make_great_pizza', 2),
#  ('chocolate_soufflé_cake', 2),
#  ('michelle_always_sweet', 2),
#  ('first_time_here', 2),
#  ('good_pizza_would', 2),
#  ('would_recommend_place', 2),
#  ('recommend_place_anybody', 2),
#  ('keep_great_work', 2),
#  ('mainstream_chain_food', 2),
#  ('thing_ill_probably', 2),
#  ('lived_sb_years', 2),
#  ('part_santa_barbara', 2),
#  ('ive_never_problem', 2),
#  ('pizza_place_santa', 2),
#  ('pizza_personal_pizza', 2),
#  ('lunch_special_includes', 2),
#  ('minutes_later_asked', 2),
#  ('ended_giving_us', 2),
#  ('pizza_rude_ass', 2),
#  ('late_night_management', 2),
#  ('delivery_came_without', 2),
#  ('salad_bar_simple', 2),
#  ('sb_pizza_good', 2),
#  ('pizza_good_definitely', 2),
#  ('im_giving_place', 2),
#  ('giving_place_stars', 2),
#  ('got_back_hotel', 2),
#  ('id_rather_eat', 2),
#  ('thick_crust_thin', 2),
#  ('crust_thin_crust', 2),
#  ('crust_extra_cheese', 2),
#  ('pizza_place_love', 2),
#  ('excellent_service_great', 2),
#  ('service_quick_staff', 2),
#  ('santa_barbara_definitely', 2),
#  ('im_glad_did', 2),
#  ('literally_two_slices', 2),
#  ('ive_read_reviews', 2),
#  ('place_weve_ordered', 2),
#  ('pizza_always_good', 2),
#  ('ordering_pizza_rustys', 2),
#  ('rustys_since_kid', 2),
#  ('two_days_later', 2),
#  ('highly_recommend_it', 2),
#  ('im_santa_barbara', 2),
#  ('way_situation_handled', 2),
#  ('im_sure_want', 2),
#  ('here_ordered_online', 2),
#  ('fast_hot_delicious', 2),
#  ('ive_eaten_rustys', 2),
#  ('rustys_whole_life', 2),
#  ('theres_nothing_like', 2),
#  ('cant_beat_lunch', 2),
#  ('beat_lunch_special', 2),
#  ('either_salad_bar', 2),
#  ('best_ranch_dressing', 2),
#  ('ranch_dressing_ever', 2),
#  ('good_fast_food', 2),
#  ('wait_time_minutes', 2),
#  ('fast_delivery_pizza', 2),
#  ('small_pepperoni_pizza', 2),
#  ('ordered_jamaican_jerk', 2),
#  ('jamaican_jerk_chicken', 2),
#  ('jerk_chicken_pizza', 2),
#  ('pizza_regular_crust', 2),
#  ('already_finished_pizza', 2),
#  ('ended_trying_it', 2),
#  ('paid_for_id', 2),
#  ('usually_order_online', 2),
#  ('otherwise_place_would', 2),
#  ('it_good_pizza', 2),
#  ('pizza_great_quality', 2),
#  ('asked_name_told', 2),
#  ('small_business_owner', 2),
#  ('service_little_slow', 2),
#  ('gluten_free_pizzas', 2),
#  ('location_always_good', 2),
#  ('across_street_beach', 2),
#  ('quality_gone_down', 2),
#  ('great_pizza_options', 2),
#  ('bbq_chicken_salad', 2),
#  ('years_since_last', 2),
#  ('id_order_again', 2),
#  ('order_wrong_times', 2),
#  ('ridiculous_customer_service', 2),
#  ('paying_full_price', 2),
#  ('back_canceled_order', 2),
#  ('customer_way_kid', 2),
#  ('way_kid_me', 2),
#  ('last_name_was', 2),
#  ('seemed_bit_priced', 2),
#  ('used_love_cpk', 2),
#  ('love_cpk_im', 2),
#  ('back_santa_barbara', 2),
#  ('never_got_delivered', 2),
#  ('bbq_chicken_chopped', 2),
#  ('pizza_money_back', 2),
#  ('horrible_horrible_experience', 2),
#  ('santa_barbara_went', 2),
#  ('best_pizza_sb', 2),
#  ('good_pizza_im', 2),
#  ('pizza_id_rather', 2),
#  ('give_place_stars', 2),
#  ('went_back_said', 2),
#  ('got_thin_crust', 2),
#  ('ive_always_loved', 2),
#  ('pizza_definitely_order', 2),
#  ('ordered_pizza_last', 2),
#  ('ive_always_found', 2),
#  ('call_ahead_time', 2),
#  ('instead_pan_crust', 2),
#  ('pizza_tasted_like', 2),
#  ('know_good_pizza', 2),
#  ('service_rather_slow', 2),
#  ('salad_die_for', 2),
#  ('waitress_made_experience', 2),
#  ('would_definitely_come', 2),
#  ('pizza_one_favorites', 2),
#  ('sb_make_stop', 2),
#  ('large_pepperoni_sausage', 2),
#  ('pepperoni_sausage_pizza', 2),
#  ('chain_restaurant_food', 2),
#  ('food_ready_quickly', 2),
#  ('old_school_arcade', 2),
#  ('school_arcade_games', 2),
#  ('best_pizzas_ive', 2),
#  ('corn_guacamole_chips', 2),
#  ('prices_little_high', 2),
#  ('customer_service_trying', 2),
#  ('come_back_family', 2),
#  ('customer_service_rude', 2),
#  ('rude_rude_rude', 2),
#  ('santa_barbara_ordered', 2),
#  ('pizza_go_salad', 2),
#  ('minutes_order_ready', 2),
#  ('one_trip_only', 2),
#  ('around_minutes_later', 2),
#  ('place_pretty_good', 2),
#  ('best_santa_barbara', 2),
#  ('poor_quality_pizza', 2),
#  ('would_rather_go', 2),
#  ('local_pizza_place', 2),
#  ('small_pizza_side', 2),
#  ('pizza_side_ranch', 2),
#  ('ranch_even_though', 2),
#  ('us_ranch_dressing', 2),
#  ('pizza_average_best', 2),
#  ('pizza_always_go', 2),
#  ('half_hour_later', 2),
#  ('later_got_call', 2),
#  ('employee_took_order', 2),
#  ('end_pizza_good', 2),
#  ('minutes_get_pizza', 2),
#  ('new_options_menu', 2),
#  ('overall_good_experience', 2),
#  ('ate_whole_thing', 2),
#  ('places_like_pizza', 2),
#  ('able_watch_pizza', 2),
#  ('worth_every_penny', 2),
#  ('salad_bar_soda', 2),
#  ('would_give_zero', 2),
#  ('zero_stars_could', 2),
#  ('terrible_service_terrible', 2),
#  ('food_ordered_pizza', 2),
#  ('give_name_cut', 2),
#  ('always_good_food', 2),
#  ('santa_barbara_lot', 2),
#  ('also_really_good', 2),
#  ('times_mess_order', 2),
#  ('checked_bank_account', 2),
#  ('place_you_looking', 2),
#  ('back_next_day', 2),
#  ('never_get_back', 2),
#  ('friendly_working_hard', 2),
#  ('love_food_here', 2),
#  ('salad_bbq_chicken', 2),
#  ('cream_fettuccine_chicken', 2),
#  ('got_great_location', 2),
#  ('pepperoni_pizza_garlic', 2),
#  ('little_pricey_worth', 2),
#  ('im_big_pizza', 2),
#  ('simply_best_pizza', 2),
#  ('can_not_remember', 2),
#  ('remember_last_time', 2),
#  ('ever_negative_rude', 2),
#  ('sit_ever_like', 2),
#  ('pizza_good_salad', 2),
#  ('good_salad_simple', 2),
#  ('pizza_absolutely_delicious', 2),
#  ('right_amount_spice', 2),
#  ('one_goto_places', 2),
#  ('great_lunch_special', 2),
#  ('got_lunch_special', 2),
#  ('pizza_good_also', 2),
#  ('give_place_try', 2),
#  ('customer_service_raul', 2),
#  ('way_make_sure', 2),
#  ('take_business_elsewhere', 2),
#  ('get_pay_for', 2),
#  ('want_get_here', 2),
#  ('really_like_thai', 2),
#  ('santa_barbara_whole', 2),
#  ('pizza_might_well', 2),
#  ('got_pizza_asked', 2),
#  ('went_cpk_lunch', 2),
#  ('sedona_tortilla_soup', 2),
#  ('food_decent_service', 2),
#  ('rustys_favorite_pizza', 2),
#  ('loved_it_thin', 2),
#  ('time_tried_ordering', 2),
#  ('tried_ordering_online', 2),
#  ('medium_pizza_hot', 2),
#  ('pizza_hot_wings', 2),
#  ('hot_wings_liter', 2),
#  ('wings_liter_soda', 2),
#  ('called_store_let', 2),
#  ('store_let_know', 2),
#  ('recommended_rustys_pizza', 2),
#  ('santa_barbara_local', 2),
#  ('italian_meatball_sandwich', 2),
#  ('santa_barbara_ive', 2),
#  ('paseo_nuevo_mall', 2),
#  ('california_pizza_kitchens', 2),
#  ('next_time_were', 2),
#  ('time_were_santa', 2),
#  ('were_santa_barbara', 2),
#  ('cheese_pizza_instead', 2),
#  ('pizza_okay_nothing', 2),
#  ('nothing_write_home', 2),
#  ('write_home_about', 2),
#  ('ordered_hawaiian_pizza', 2),
#  ('ordered_original_bbq', 2),
#  ('ordered_pizza_delivered', 2),
#  ('first_time_cpk', 2),
#  ('pizza_mins_later', 2),
#  ('later_call_back', 2),
#  ('rude_hung_me', 2),
#  ('rude_staff_im', 2),
#  ('staff_im_likely', 2),
#  ('im_likely_going', 2),
#  ('likely_going_ordering', 2),
#  ('going_ordering_due', 2),
#  ('ordering_due_experience', 2),
#  ('due_experience_thats', 2),
#  ('experience_thats_unfortunate', 2),
#  ('thats_unfortunate_like', 2),
#  ('unfortunate_like_dominos', 2),
#  ('dominos_pizza_time', 2),
#  ('pizza_time_time', 2),
#  ('time_time_customer', 2),
#  ('customer_service_horrible', 2),
#  ('counter_every_time', 2),
#  ('always_really_enjoyed', 2),
#  ('really_enjoyed_going', 2),
#  ('kept_coming_back', 2),
#  ('looked_tasted_like', 2),
#  ('place_food_good', 2),
#  ('service_wait_time', 2),
#  ('again_love_rustys', 2),
#  ('salad_bar_wish', 2),
#  ('pizza_salad_drink', 2),
#  ('asked_ranch_dressing', 2),
#  ('says_ok_get', 2),
#  ('asked_manager_said', 2),
#  ('always_hot_delicious', 2),
#  ('pizza_asked_delivery', 2),
#  ('got_hung_on', 2),
#  ('pizza_took_another', 2),
#  ('another_minutes_goes', 2),
#  ('delivery_man_nice', 2),
#  ('get_pizza_definitely', 2),
#  ('back_hour_later', 2),
#  ('good_pizza_customer', 2),
#  ('banh_mi_bowl', 2),
#  ('people_can_not', 2),
#  ('place_always_clean', 2),
#  ('pizza_good_make', 2),
#  ('answered_phone_rude', 2),
#  ('made_seem_like', 2),
#  ('worst_pizza_place', 2),
#  ('theres_many_places', 2),
#  ('look_forward_pizza', 2),
#  ('hard_long_hours', 2),
#  ('many_times_ignored', 2),
#  ('times_ignored_us', 2),
#  ('really_bad_attitude', 2),
#  ('would_never_go', 2),
#  ('second_time_pizza', 2),
#  ('made_effort_find', 2),
#  ('customer_service_keep', 2),
#  ('food_good_ordered', 2),
#  ('locations_santa_barbara', 2),
#  ('im_craving_pizza', 2),
#  ('took_one_bite', 2),
#  ('ever_entire_life', 2),
#  ('got_regular_hot', 2),
#  ('long_time_rustys', 2),
#  ('time_rustys_pizza', 2),
#  ('place_order_waiting', 2),
#  ('waited_long_line', 2),
#  ('like_this_good', 2),
#  ('good_food_good', 2),
#  ('pizza_thought_would', 2),
#  ('town_santa_barbara', 2),
#  ('sure_never_order', 2),
#  ('try_another_pizza', 2),
#  ('anyone_would_eat', 2),
#  ('let_down_ordered', 2),
#  ('could_find_order', 2),
#  ('overall_good_food', 2),
#  ('love_salad_bar', 2),
#  ('could_see_order', 2),
#  ('giovannis_called_order', 2),
#  ('delivery_girl_spoke', 2),
#  ('cheese_bread_never', 2),
#  ('really_good_love', 2),
#  ('get_order_wrong', 2),
#  ('minutes_later_got', 2),
#  ('wait_another_min', 2),
#  ('option_add_ranch', 2),
#  ('without_saying_anything', 2),
#  ('lure_fish_house', 2),
#  ('disappointed_customer_service', 2),
#  ('go_california_pizza', 2),
#  ('really_cant_go', 2),
#  ('pizza_chile_verde', 2),
#  ('thought_wed_try', 2),
#  ('great_option_santa', 2),
#  ('option_santa_barbara', 2),
#  ('pizza_places_santa', 2),
#  ('places_santa_barbara', 2),
#  ('placed_order_pick', 2),
#  ('going_back_forth', 2),
#  ('customer_service_phone', 2),
#  ('good_food_love', 2),
#  ('food_love_bbq', 2),
#  ('next_time_come', 2),
#  ('called_spoke_supervisor', 2),
#  ('pepperoni_pizza_cpk', 2),
#  ('im_going_go', 2),
#  ('cheese_tomato_sauce', 2),
#  ('pizza_good_favorite', 2),
#  ('pizza_cold_pizza', 2),
#  ('mediocre_pizza_especially', 2),
#  ('person_taking_order', 2),
#  ('salads_good_too', 2),
#  ('two_us_ordered', 2),
#  ('another_half_hour', 2),
#  ('ill_never_go', 2),
#  ('always_good_experience', 2),
#  ('pizza_hut_papa', 2),
#  ('hut_papa_johns', 2),
#  ('dominos_placed_order', 2),
#  ('god_santa_barbara', 2),
#  ('never_order_dominos', 2),
#  ('order_dominos_again', 2),
#  ('santa_barbara_every', 2),
#  ('barbara_every_year', 2),
#  ('santa_barbara_hotel', 2),
#  ('friendly_fast_service', 2),
#  ('best_pizza_pizza', 2),
#  ('thin_crust_right', 2),
#  ('car_get_pizza', 2),
#  ('make_big_deal', 2),
#  ('toll_you_toll', 2),
#  ('pizza_go_back', 2),
#  ('wings_last_night', 2),
#  ('video_games_kids', 2),
#  ('womens_restroom_two', 2),
#  ('salad_bar_though', 2),
#  ('good_nothing_special', 2),
#  ('large_veggie_pizza', 2),
#  ('extra_sauce_light', 2),
#  ('sauce_light_cheese', 2),
#  ('great_pizza_ordered', 2),
#  ('pizza_parm_bites', 2),
#  ('barely_warm_pizza', 2),
#  ('order_rustys_pizza', 2),
#  ('made_mistake_ordering', 2),
#  ('always_get_right', 2),
#  ('love_pizza_love', 2),
#  ('pizza_love_pizza', 2),
#  ('love_pizza_like', 2),
#  ('talk_make_sure', 2),
#  ('customer_service_dominos', 2),
#  ('pizza_soak_beer', 2),
#  ('santa_barbara_nice', 2),
#  ('offer_self_serve', 2),
#  ('self_serve_soda', 2),
#  ('serve_soda_fountain', 2),
#  ('personal_size_pizza', 2),
#  ('put_hold_minutes', 2),
#  ('person_answered_phone', 2),
#  ('lived_santa_barbara', 2),
#  ('hard_mess_up', 2),
#  ('santa_barbara_go', 2),
#  ('pizza_without_salad', 2),
#  ('without_salad_load', 2),
#  ...]

# %%
good_Pizza=Pizza[Pizza.stars>=3.5]
good_Pizza_review = Pizza_review[Pizza_review.business_id.isin(good_Pizza.business_id.values)]
good_Pizza_review_text = good_Pizza_review.text.str.cat(sep = " ")
good_Pizza_tokens = word_tokenize(good_Pizza_review_text)

bigrams_list_good_Pizza = ["_".join(item) for item in nltk.bigrams(good_Pizza_tokens)]
trigrams_list_good_Pizza = ["_".join(item) for item in nltk.trigrams(good_Pizza_tokens)]
# FreqDist(good_Pizza_tokens).most_common()
# FreqDist(bigrams_list_good_Pizza).most_common()
FreqDist(trigrams_list_good_Pizza).most_common()
# Out:
# [('deep_dish_pizza', 172),
#  ('ive_ever_had', 95),
#  ('pizza_santa_barbara', 92),
#  ('thin_crust_pizza', 80),
#  ('best_pizza_ive', 69),
#  ('gluten_free_pizza', 68),
#  ('definitely_come_back', 61),
#  ('best_pizza_santa', 61),
#  ('pizza_ive_ever', 55),
#  ('best_pizza_ever', 53),
#  ('best_pizza_town', 49),
#  ('cant_go_wrong', 48),
#  ('definitely_coming_back', 45),
#  ('really_good_pizza', 43),
#  ('great_customer_service', 43),
#  ('cant_wait_go', 42),
#  ('place_santa_barbara', 41),
#  ('wait_go_back', 38),
#  ('would_highly_recommend', 38),
#  ('pizza_ever_had', 37),
#  ('would_definitely_recommend', 36),
#  ('gluten_free_crust', 36),
#  ('wait_come_back', 36),
#  ('pizza_really_good', 34),
#  ('next_time_im', 34),
#  ('cant_wait_come', 33),
#  ('trip_santa_barbara', 33),
#  ('would_definitely_come', 32),
#  ('highly_recommend_place', 32),
#  ('food_great_service', 32),
#  ('back_next_time', 32),
#  ('best_ive_ever', 30),
#  ('best_pizza_sb', 29),
#  ('bbq_chicken_pizza', 29),
#  ('definitely_go_back', 29),
#  ('deep_dish_pizzas', 29),
#  ('ode_dan_russo', 29),
#  ('would_go_back', 28),
#  ('favorite_pizza_place', 28),
#  ('staff_super_friendly', 28),
#  ('wood_fired_pizza', 28),
#  ('squid_ink_calamari', 28),
#  ('one_best_pizzas', 27),
#  ('pizza_place_santa', 26),
#  ('great_food_great', 26),
#  ('service_great_food', 26),
#  ('santa_barbara_area', 25),
#  ('whole_wheat_crust', 24),
#  ('far_best_pizza', 24),
#  ('chipotle_chicken_pizza', 24),
#  ('chicago_style_pizza', 24),
#  ('pizza_thin_crust', 23),
#  ('come_back_try', 23),
#  ('visiting_santa_barbara', 23),
#  ('visit_santa_barbara', 22),
#  ('pulled_pork_sandwich', 22),
#  ('best_pizza_place', 21),
#  ('recommend_place_anyone', 21),
#  ('next_time_were', 21),
#  ('great_service_great', 21),
#  ('great_pizza_great', 21),
#  ('pizza_best_pizza', 20),
#  ('love_love_love', 20),
#  ('food_good_service', 19),
#  ('pretty_good_pizza', 19),
#  ('pizza_pretty_good', 19),
#  ('go_back_try', 19),
#  ('seated_right_away', 19),
#  ('food_pretty_good', 18),
#  ('meat_lovers_pizza', 18),
#  ('definitely_recommend_place', 18),
#  ('right_front_you', 18),
#  ('olio_e_limone', 18),
#  ('chicago_deep_dish', 18),
#  ('pizza_man_dans', 17),
#  ('hands_best_pizza', 17),
#  ('never_go_back', 17),
#  ('pizza_die_for', 17),
#  ('would_come_back', 17),
#  ('downtown_santa_barbara', 17),
#  ('good_pizza_great', 16),
#  ('time_santa_barbara', 16),
#  ('write_home_about', 16),
#  ('good_food_good', 16),
#  ('butternut_squash_ravioli', 16),
#  ('time_im_town', 16),
#  ('great_beer_selection', 16),
#  ('cant_say_enough', 16),
#  ('best_gluten_free', 16),
#  ('restaurant_next_door', 16),
#  ('good_pizza_good', 15),
#  ('customer_service_great', 15),
#  ('service_great_pizza', 15),
#  ('santa_barbara_pizza', 15),
#  ('highly_recommend_it', 15),
#  ('one_favorite_places', 15),
#  ('new_york_style', 15),
#  ('walking_state_street', 15),
#  ('one_best_ive', 15),
#  ('overall_great_experience', 15),
#  ('ordered_thin_crust', 14),
#  ('places_santa_barbara', 14),
#  ('great_pizza_place', 14),
#  ('pizzas_ive_ever', 14),
#  ('santa_barbara_love', 14),
#  ('pizza_one_best', 14),
#  ('nothing_write_home', 14),
#  ('go_back_again', 14),
#  ('ordered_two_pizzas', 14),
#  ('would_definitely_go', 14),
#  ('pizza_place_town', 14),
#  ('ordered_deep_dish', 14),
#  ('try_deep_dish', 14),
#  ('vegan_deep_dish', 14),
#  ('delicious_service_great', 13),
#  ('wood_fire_pizza', 13),
#  ('can_not_wait', 13),
#  ('food_really_good', 13),
#  ('next_time_ill', 13),
#  ('back_santa_barbara', 13),
#  ('took_long_time', 13),
#  ('wood_fired_oven', 13),
#  ('chicken_salad_sandwich', 13),
#  ('olio_crudo_bar', 13),
#  ('pizza_places_town', 12),
#  ('place_great_pizza', 12),
#  ('santa_barbara_place', 12),
#  ('one_favorite_pizza', 12),
#  ('love_place_pizza', 12),
#  ('come_back_again', 12),
#  ('im_big_fan', 12),
#  ('worst_service_ever', 12),
#  ('high_quality_ingredients', 12),
#  ('probably_best_pizza', 12),
#  ('definitely_going_back', 12),
#  ('right_amount_cheese', 12),
#  ('santa_barbara_great', 12),
#  ('im_pretty_sure', 12),
#  ('made_us_feel', 12),
#  ('let_us_know', 12),
#  ('ordered_margherita_pizza', 12),
#  ('wait_another_minutes', 12),
#  ('pizza_great_service', 12),
#  ('pizza_next_time', 12),
#  ('ever_had_crust', 12),
#  ('santa_barbara_went', 12),
#  ('staff_friendly_helpful', 12),
#  ('go_back_next', 12),
#  ('best_deep_dish', 12),
#  ('get_deep_dish', 12),
#  ('good_customer_service', 11),
#  ('service_good_pizza', 11),
#  ('new_favorite_pizza', 11),
#  ('good_pizza_place', 11),
#  ('delicious_highly_recommend', 11),
#  ('pizza_absolutely_delicious', 11),
#  ('one_best_pizza', 11),
#  ('ill_definitely_back', 11),
#  ('absolutely_love_place', 11),
#  ('best_pizzas_ive', 11),
#  ('excellent_customer_service', 11),
#  ('santa_barbara_would', 11),
#  ('time_were_town', 11),
#  ('looking_forward_trying', 11),
#  ('best_pizzas_ever', 11),
#  ('chicken_pesto_panini', 11),
#  ('really_good_food', 11),
#  ('come_back_next', 11),
#  ('would_take_minutes', 11),
#  ('would_recommend_place', 11),
#  ('pizza_tomato_sauce', 11),
#  ('mesa_pizza_co', 11),
#  ('dan_russo_pizza', 11),
#  ('well_worth_it', 10),
#  ('ive_santa_barbara', 10),
#  ('ny_style_pizza', 10),
#  ('ordered_pepperoni_pizza', 10),
#  ('good_food_great', 10),
#  ('great_place_watch', 10),
#  ('well_worth_wait', 10),
#  ('go_somewhere_else', 10),
#  ('im_giving_stars', 10),
#  ('first_time_ordering', 10),
#  ('great_food_service', 10),
#  ('place_great_food', 10),
#  ('great_place_go', 10),
#  ('santa_barbara_hands', 10),
#  ('barbara_hands_down', 10),
#  ('mushroom_truffle_pizza', 10),
#  ('every_time_come', 10),
#  ('outdoor_seating_area', 10),
#  ('favorite_pizza_places', 10),
#  ('right_state_street', 10),
#  ('santa_barbara_best', 10),
#  ('taken_care_of', 10),
#  ('ordered_margarita_pizza', 10),
#  ('santa_claus_lane', 10),
#  ('super_friendly_staff', 10),
#  ('calamari_al_nero', 10),
#  ('pizza_amazing_crust', 9),
#  ('poor_customer_service', 9),
#  ('great_thin_crust', 9),
#  ('pizza_places_santa', 9),
#  ('thin_crust_pepperoni', 9),
#  ('new_pizza_place', 9),
#  ('got_bbq_chicken', 9),
#  ('definitely_back_next', 9),
#  ('first_time_here', 9),
#  ('thin_crust_pizzas', 9),
#  ('first_time_went', 9),
#  ('every_single_time', 9),
#  ('nice_outdoor_seating', 9),
#  ('customer_service_food', 9),
#  ('really_good_too', 9),
#  ('back_best_pizza', 9),
#  ('white_chicken_pizza', 9),
#  ('could_ask_for', 9),
#  ('next_time_santa', 9),
#  ('east_coast_pizza', 9),
#  ('service_friendly_staff', 9),
#  ('want_come_back', 9),
#  ('best_pizza_iv', 9),
#  ('restaurant_santa_barbara', 9),
#  ('definitely_worth_it', 9),
#  ('eat_santa_barbara', 9),
#  ('santa_barbara_first', 9),
#  ('good_beer_selection', 9),
#  ('try_next_time', 9),
#  ('come_santa_barbara', 9),
#  ('gluten_free_dough', 9),
#  ('pizzas_ever_had', 9),
#  ('bad_customer_service', 9),
#  ('would_give_stars', 9),
#  ('great_people_watching', 9),
#  ('great_service_food', 9),
#  ('ever_santa_barbara', 9),
#  ('gluten_free_options', 9),
#  ('table_next_us', 9),
#  ('pizza_margarita_pizza', 9),
#  ('pizza_vegan_cheese', 9),
#  ('make_sure_order', 9),
#  ('told_would_take', 9),
#  ('great_place_stop', 9),
#  ('one_favorite_restaurants', 9),
#  ('im_glad_did', 9),
#  ('weve_ever_had', 9),
#  ('first_time_last', 9),
#  ('cant_wait_try', 9),
#  ('next_time_town', 9),
#  ('im_santa_barbara', 9),
#  ('pizza_great_price', 9),
#  ('never_coming_back', 9),
#  ('two_different_pizzas', 9),
#  ('say_enough_good', 9),
#  ('enough_good_things', 9),
#  ('made_right_front', 9),
#  ('every_time_im', 9),
#  ('wood_fired_pizzas', 9),
#  ('time_im_sb', 9),
#  ('stumbled_upon_place', 9),
#  ('butter_lettuce_salad', 9),
#  ('italian_style_pizza', 9),
#  ('pizza_online_company', 9),
#  ('olive_oil_cake', 9),
#  ('ive_long_time', 8),
#  ('beer_wine_selection', 8),
#  ('many_pizza_places', 8),
#  ('really_looking_forward', 8),
#  ('great_place_hang', 8),
#  ('thin_crispy_crust', 8),
#  ('one_favorite_spots', 8),
#  ('really_really_good', 8),
#  ('without_doubt_best', 8),
#  ('doubt_best_pizza', 8),
#  ('keep_good_work', 8),
#  ('food_excellent_service', 8),
#  ('labor_day_weekend', 8),
#  ('gave_us_free', 8),
#  ('crust_really_good', 8),
#  ('asked_speak_manager', 8),
#  ('ive_ever_tasted', 8),
#  ('friendly_staff_good', 8),
#  ('got_ta_try', 8),
#  ('pizza_ive_had', 8),
#  ('worst_pizza_ever', 8),
#  ('garlic_cheese_bread', 8),
#  ('ive_ever_eaten', 8),
#  ('pretty_darn_good', 8),
#  ('santa_barbara_eat', 8),
#  ('come_back_here', 8),
#  ('staff_friendly_food', 8),
#  ('really_like_pizza', 8),
#  ('best_italian_food', 8),
#  ('indoor_outdoor_seating', 8),
#  ('best_ive_had', 8),
#  ('sun_dried_tomatoes', 8),
#  ('pizza_good_too', 8),
#  ('pizza_great_place', 8),
#  ('caramelized_onion_pizza', 8),
#  ('food_great_atmosphere', 8),
#  ('forward_coming_back', 8),
#  ('service_friendly_fast', 8),
#  ('staff_friendly_attentive', 8),
#  ('let_tell_you', 8),
#  ('overall_great_place', 8),
#  ('stop_santa_barbara', 8),
#  ('pizza_gluten_free', 8),
#  ('love_come_back', 8),
#  ('gluten_free_pizzas', 8),
#  ('found_place_yelp', 8),
#  ('first_time_trying', 8),
#  ('good_thin_crust', 8),
#  ('new_york_pizza', 8),
#  ('santa_barbara_wanted', 8),
#  ('worth_every_penny', 8),
#  ('went_first_time', 8),
#  ('barbara_best_pizza', 8),
#  ('local_santa_barbara', 8),
#  ('decided_give_try', 8),
#  ('santa_barbara_looking', 8),
#  ('well_definitely_back', 8),
#  ('came_first_time', 8),
#  ('delicious_pizza_great', 8),
#  ('would_given_stars', 8),
#  ('best_thin_crust', 8),
#  ('crust_thin_crispy', 8),
#  ('ive_never_seen', 8),
#  ('spot_santa_barbara', 8),
#  ('service_good_food', 8),
#  ('lived_santa_barbara', 8),
#  ('wood_burning_oven', 8),
#  ('authentic_italian_pizza', 8),
#  ('black_parma_pizza', 8),
#  ('montecito_country_mart', 8),
#  ('deep_dish_takes', 8),
#  ('calabrian_chile_smoked', 8),
#  ('recommend_deep_dish', 8),
#  ('great_deep_dish', 8),
#  ('pizza_deep_dish', 8),
#  ('black_truffle_pizza', 8),
#  ('meat_cheese_plate', 8),
#  ('good_service_good', 7),
#  ('ive_ever_seen', 7),
#  ('pizza_delicious_staff', 7),
#  ('service_hit_miss', 7),
#  ('buffalo_chicken_pizza', 7),
#  ('place_really_good', 7),
#  ('cheese_pizza_really', 7),
#  ('would_definitely_return', 7),
#  ('fast_food_pizza', 7),
#  ('pizza_delicious_service', 7),
#  ('make_sure_get', 7),
#  ('ordered_large_pizza', 7),
#  ('red_pepper_flakes', 7),
#  ('buy_one_get', 7),
#  ('one_get_one', 7),
#  ('also_really_good', 7),
#  ('customer_service_pizza', 7),
#  ('never_going_back', 7),
#  ('pizza_good_great', 7),
#  ('definitely_return_next', 7),
#  ('santa_barbara_amazing', 7),
#  ('pizza_place_pizza', 7),
#  ('would_ready_minutes', 7),
#  ('every_time_go', 7),
#  ('worst_customer_service', 7),
#  ('customer_service_ever', 7),
#  ('great_tasting_pizza', 7),
#  ('favorite_pizza_sb', 7),
#  ('location_state_street', 7),
#  ('college_town_pizza', 7),
#  ('woodstocks_best_pizza', 7),
#  ('every_time_visit', 7),
#  ('extra_large_pizza', 7),
#  ('good_wine_selection', 7),
#  ('find_santa_barbara', 7),
#  ('let_start_saying', 7),
#  ('way_better_pizza', 7),
#  ('authentic_italian_food', 7),
#  ('drove_santa_barbara', 7),
#  ('probably_one_best', 7),
#  ('pizza_place_ive', 7),
#  ('pizza_isla_vista', 7),
#  ('maybe_next_time', 7),
#  ('people_watching_state', 7),
#  ('super_friendly_helpful', 7),
#  ('place_get_pizza', 7),
#  ('restaurants_santa_barbara', 7),
#  ('great_service_delicious', 7),
#  ('one_best_places', 7),
#  ('great_place_grab', 7),
#  ('next_time_go', 7),
#  ('located_state_street', 7),
#  ('offer_gluten_free', 7),
#  ('service_great_well', 7),
#  ('keep_coming_back', 7),
#  ('best_ever_had', 7),
#  ('right_next_door', 7),
#  ('food_came_quickly', 7),
#  ('really_great_pizza', 7),
#  ('said_best_pizza', 7),
#  ('lucky_penny_great', 7),
#  ('tomato_sauce_fresh', 7),
#  ('order_two_pizzas', 7),
#  ('next_time_come', 7),
#  ('amazing_pizza_great', 7),
#  ('call_ahead_time', 7),
#  ('santa_barbara_ordered', 7),
#  ('every_time_ive', 7),
#  ('decent_pizza_place', 7),
#  ('pizza_place_great', 7),
#  ('definitely_come_again', 7),
#  ('favorite_pizza_spot', 7),
#  ('give_another_shot', 7),
#  ('salad_really_good', 7),
#  ('want_go_back', 7),
#  ('id_come_back', 7),
#  ('fresh_ingredients_great', 7),
#  ('tomato_sauce_pizza', 7),
#  ('pizza_best_ive', 7),
#  ('worth_checking_out', 7),
#  ('black_dough_pizza', 7),
#  ('love_outdoor_seating', 7),
#  ('amazing_deep_dish', 7),
#  ('dish_pizza_ive', 7),
#  ('sausage_calabrian_chile', 7),
#  ('chile_smoked_mozzarella', 7),
#  ('since_deep_dish', 7),
#  ('market_greens_salad', 7),
#  ('special_deep_dish', 7),
#  ('fried_artichoke_hearts', 7),
#  ('umbrian_black_truffles', 7),
#  ('hazelnut_panna_cotta', 7),
#  ('delicious_staff_friendly', 6),
#  ('pizza_customer_service', 6),
#  ('good_pizza_service', 6),
#  ('pizza_man_dan', 6),
#  ('coming_back_again', 6),
#  ('love_thin_crust', 6),
#  ('pizza_place_go', 6),
#  ('pizza_much_better', 6),
#  ('better_customer_service', 6),
#  ('place_first_time', 6),
#  ('pretty_good_too', 6),
#  ('staff_friendly_accommodating', 6),
#  ('santa_barbara_im', 6),
#  ('pizza_good_price', 6),
#  ('us_told_us', 6),
#  ('santa_barbara_try', 6),
#  ('place_next_time', 6),
#  ('super_thin_crust', 6),
#  ('pizza_tastes_like', 6),
#  ('great_gluten_free', 6),
#  ('never_bad_experience', 6),
#  ('go_pizza_place', 6),
#  ('time_im_area', 6),
#  ('thin_crust_fresh', 6),
#  ('half_pepperoni_half', 6),
#  ('staff_always_friendly', 6),
#  ('pizza_state_street', 6),
#  ('santa_barbara_lunch', 6),
#  ('santa_barbara_good', 6),
#  ('made_feel_like', 6),
#  ('definitely_best_pizza', 6),
#  ('caesar_salad_good', 6),
#  ('santa_barbara_goleta', 6),
#  ('rustys_pizza_parlor', 6),
#  ('right_amount_sauce', 6),
#  ('love_place_great', 6),
#  ('actually_pretty_good', 6),
#  ('person_took_order', 6),
#  ('pizza_good_quality', 6),
#  ('return_next_time', 6),
#  ('good_pizza_santa', 6),
#  ('it_cant_wait', 6),
#  ('love_love_place', 6),
#  ('think_best_pizza', 6),
#  ('really_like_place', 6),
#  ('always_super_friendly', 6),
#  ('really_enjoyed_pizza', 6),
#  ('fast_friendly_service', 6),
#  ('santa_barbara_food', 6),
#  ('happy_hour_prices', 6),
#  ('great_selection_beers', 6),
#  ('absolutely_loved_it', 6),
#  ('service_little_slow', 6),
#  ('pizza_top_notch', 6),
#  ('food_absolutely_amazing', 6),
#  ('thick_crust_pizza', 6),
#  ('makes_feel_like', 6),
#  ('im_huge_fan', 6),
#  ('santa_barbara_service', 6),
#  ('it_best_pizza', 6),
#  ('dog_friendly_patio', 6),
#  ('pizza_place_good', 6),
#  ('place_good_pizza', 6),
#  ('also_pretty_good', 6),
#  ('great_selection_beer', 6),
#  ('giving_place_stars', 6),
#  ('customer_service_always', 6),
#  ('santa_barbara_well', 6),
#  ('pizza_good_beer', 6),
#  ('great_happy_hour', 6),
#  ('great_place_get', 6),
#  ('really_wanted_try', 6),
#  ('beer_selection_great', 6),
#  ('prefer_thin_crust', 6),
#  ('told_us_would', 6),
#  ('great_pizza_even', 6),
#  ('pizza_even_better', 6),
#  ('personal_sized_pizza', 6),
#  ('really_good_service', 6),
#  ('santa_barbara_definitely', 6),
#  ('food_customer_service', 6),
#  ('gem_santa_barbara', 6),
#  ('service_delicious_food', 6),
#  ('give_zero_stars', 6),
#  ('bread_olive_oil', 6),
#  ('food_great_staff', 6),
#  ('try_something_else', 6),
#  ('come_back_pizza', 6),
#  ('times_every_time', 6),
#  ('us_feel_like', 6),
#  ('took_another_minutes', 6),
#  ('highly_recommend_pizza', 6),
#  ('pepperoni_white_pizza', 6),
#  ('got_order_wrong', 6),
#  ('looking_quick_bite', 6),
#  ('coming_back_soon', 6),
#  ('crust_right_amount', 6),
#  ('good_things_place', 6),
#  ('pizza_west_coast', 6),
#  ('time_last_night', 6),
#  ('ill_come_back', 6),
#  ('make_feel_like', 6),
#  ('time_come_santa', 6),
#  ('highly_recommend_restaurant', 6),
#  ('pizza_delicious_definitely', 6),
#  ('service_food_amazing', 6),
#  ('time_im_santa', 6),
#  ('best_santa_barbara', 6),
#  ('york_style_pizza', 6),
#  ('got_margarita_pizza', 6),
#  ('back_next_day', 6),
#  ('it_definitely_back', 6),
#  ('good_great_pizza', 6),
#  ('definitely_worth_going', 6),
#  ('next_time_well', 6),
#  ('pizza_fresh_ingredients', 6),
#  ('fresh_ingredients_pizza', 6),
#  ('place_good_food', 6),
#  ('deep_dish_good', 6),
#  ('sauce_cheese_toppings', 6),
#  ('spots_santa_barbara', 6),
#  ('pizza_friendly_staff', 6),
#  ('really_hit_spot', 6),
#  ('last_time_went', 6),
#  ('ate_first_time', 6),
#  ('food_service_always', 6),
#  ('good_pizza_price', 6),
#  ('great_atmosphere_great', 6),
#  ('cant_beat_that', 6),
#  ('pizzas_ive_had', 6),
#  ('pizza_anywhere_else', 6),
#  ('time_best_pizza', 6),
#  ('pizza_really_liked', 6),
#  ('santa_barbara_since', 6),
#  ('check_place_out', 6),
#  ('patxis_deep_dish', 6),
#  ('come_back_more', 6),
#  ('service_fast_friendly', 6),
#  ('plenty_outdoor_seating', 6),
#  ('food_service_atmosphere', 6),
#  ('wood_fire_oven', 6),
#  ('actually_really_good', 6),
#  ('tasted_really_fresh', 6),
#  ('santa_barbara_came', 6),
#  ('atmosphere_great_service', 6),
#  ('delicious_thin_crust', 6),
#  ('wine_list_great', 6),
#  ('coming_back_great', 6),
#  ('reservation_open_table', 6),
#  ('back_try_pizza', 6),
#  ('really_enjoyed_it', 6),
#  ('local_beer_wine', 6),
#  ('great_little_place', 6),
#  ('great_wine_list', 6),
#  ('place_make_sure', 6),
#  ('dish_pizzas_take', 6),
#  ('dish_pizza_pizza', 6),
#  ('deep_dish_take', 6),
#  ('chicken_deep_dish', 6),
#  ('tried_deep_dish', 6),
#  ('place_grab_bite', 6),
#  ('order_deep_dish', 6),
#  ('quinoa_arugula_salad', 6),
#  ('pork_fennel_sausage', 6),
#  ('fennel_sausage_calabrian', 6),
#  ('lamb_meatball_sandwich', 6),
#  ('tasting_funk_zone', 6),
#  ('chicken_tikka_masala', 6),
#  ('robiola_cheese_crimini', 6),
#  ('sauce_fresh_mozzarella', 6),
#  ('restaurant_olio_e', 6),
#  ('little_pricey_side', 5),
#  ('chicken_pizza_delicious', 5),
#  ('pizza_good_salad', 5),
#  ('great_would_definitely', 5),
#  ('pizza_highly_recommend', 5),
#  ('great_salad_bar', 5),
#  ('definitely_order_again', 5),
#  ('good_would_definitely', 5),
#  ('good_pizza_came', 5),
#  ('next_time_great', 5),
#  ('pizza_last_night', 5),
#  ('ingredients_always_fresh', 5),
#  ('experience_would_recommend', 5),
#  ('personal_pan_pizza', 5),
#  ('looking_forward_eating', 5),
#  ('go_back_pizza', 5),
#  ('want_good_pizza', 5),
#  ('customer_service_one', 5),
#  ('give_one_star', 5),
#  ('sauce_tasted_like', 5),
#  ('another_pizza_place', 5),
#  ('back_multiple_times', 5),
#  ('take_business_elsewhere', 5),
#  ('terrible_customer_service', 5),
#  ('seriously_best_pizza', 5),
#  ('get_one_free', 5),
#  ('flourless_chocolate_cake', 5),
#  ('absolutely_best_pizza', 5),
#  ('mom_pop_shop', 5),
#  ('sb_first_time', 5),
#  ('crust_thin_crust', 5),
#  ('pizza_great_prices', 5),
#  ('goto_pizza_place', 5),
#  ('feels_like_home', 5),
#  ('pizza_cooked_perfectly', 5),
#  ('way_like_it', 5),
#  ('pizza_first_time', 5),
#  ('take_bake_pizza', 5),
#  ('reasonable_amount_time', 5),
#  ('lunch_special_pizza', 5),
#  ('great_lunch_special', 5),
#  ('fresh_mozzarella_cheese', 5),
#  ('waited_long_time', 5),
#  ('service_could_better', 5),
#  ('place_order_pick', 5),
#  ('order_pick_up', 5),
#  ('it_pizza_good', 5),
#  ('keep_great_work', 5),
#  ('busy_saturday_night', 5),
#  ('place_great_service', 5),
#  ('service_really_good', 5),
#  ('never_come_back', 5),
#  ('probably_go_back', 5),
#  ('family_owned_restaurant', 5),
#  ('pizza_way_better', 5),
#  ('totally_worth_it', 5),
#  ('woodstocks_isla_vista', 5),
#  ('definitely_worth_price', 5),
#  ('pizza_spot_sb', 5),
#  ('another_minutes_pizza', 5),
#  ('santa_barbara_far', 5),
#  ('chicken_pizza_good', 5),
#  ('everything_ive_tried', 5),
#  ('hole_wall_pizza', 5),
#  ('wall_pizza_place', 5),
#  ('can_not_go', 5),
#  ('not_go_wrong', 5),
#  ('forward_next_visit', 5),
#  ('best_pizza_world', 5),
#  ('staff_always_super', 5),
#  ('great_local_spot', 5),
#  ('place_pretty_good', 5),
#  ('pizza_places_try', 5),
#  ('cant_go_back', 5),
#  ('wild_things_are', 5),
#  ('great_place_eat', 5),
#  ('pizza_place_iv', 5),
#  ('minutes_get_food', 5),
#  ('pizza_every_time', 5),
#  ('pizza_ingredients_fresh', 5),
#  ('great_food_good', 5),
#  ('good_even_though', 5),
#  ('pizza_little_pricey', 5),
#  ('good_pizza_like', 5),
#  ('even_though_busy', 5),
#  ('delicious_full_flavor', 5),
#  ('wanted_like_place', 5),
#  ('salad_good_too', 5),
#  ('service_excellent_food', 5),
#  ('pizzas_pretty_good', 5),
#  ('love_woodstocks_pizza', 5),
#  ('awesome_pizza_great', 5),
#  ('food_absolutely_delicious', 5),
#  ('better_pizza_places', 5),
#  ('grilled_peaches_prosciutto', 5),
#  ('good_beer_good', 5),
#  ('slice_cheese_pizza', 5),
#  ('give_another_try', 5),
#  ('selection_beer_tap', 5),
#  ('day_santa_barbara', 5),
#  ('great_service_even', 5),
#  ('looking_forward_coming', 5),
#  ('try_new_place', 5),
#  ('prosciutto_grilled_peaches', 5),
#  ('san_luis_obispo', 5),
#  ('ordered_pizza_online', 5),
#  ('plain_cheese_pizza', 5),
#  ('cheese_pizza_also', 5),
#  ('santa_barbara_wine', 5),
#  ('dish_pizza_delicious', 5),
#  ('place_state_street', 5),
#  ('vegan_cheese_option', 5),
#  ('back_first_time', 5),
#  ('would_recommend_restaurant', 5),
#  ('shrimp_pink_vodka', 5),
#  ('yum_yum_yum', 5),
#  ('ive_ever_life', 5),
#  ('place_hang_friends', 5),
#  ('made_great_recommendations', 5),
#  ('good_quality_pizza', 5),
#  ('watching_state_street', 5),
#  ('late_night_pizza', 5),
#  ('took_forever_get', 5),
#  ('burrata_heirloom_tomatoes', 5),
#  ('place_amazing_food', 5),
#  ('pepperoni_pizza_delicious', 5),
#  ('time_definitely_back', 5),
#  ('food_service_great', 5),
#  ('one_pizza_place', 5),
#  ('wine_selection_good', 5),
#  ('decided_try_place', 5),
#  ('salad_pepperoni_pizza', 5),
#  ('brick_oven_pizza', 5),
#  ('friendly_food_amazing', 5),
#  ('selection_beers_tap', 5),
#  ('would_give_place', 5),
#  ('place_five_stars', 5),
#  ('next_time_id', 5),
#  ('free_pizza_crust', 5),
#  ('long_would_take', 5),
#  ('ordered_gluten_free', 5),
#  ('definitely_go_again', 5),
#  ('red_sauce_pizza', 5),
#  ('come_back_soon', 5),
#  ('definitely_recommend_coming', 5),
#  ('two_glasses_wine', 5),
#  ('again_great_pizza', 5),
#  ('spot_state_street', 5),
#  ('pizza_also_really', 5),
#  ('food_even_better', 5),
#  ('gave_us_great', 5),
#  ('pizza_great_beer', 5),
#  ('mixed_green_salad', 5),
#  ('pizza_would_take', 5),
#  ('one_best_weve', 5),
#  ('pizza_way_much', 5),
#  ('dinner_santa_barbara', 5),
#  ('wonderful_dining_experience', 5),
#  ('first_time_today', 5),
#  ('came_back_minutes', 5),
#  ('go_santa_barbara', 5),
#  ('say_best_pizza', 5),
#  ('staff_helpful_friendly', 5),
#  ('outdoor_dining_area', 5),
#  ('coming_back_here', 5),
#  ('great_dining_experience', 5),
#  ('got_seated_right', 5),
#  ('well_definitely_come', 5),
#  ('back_next_trip', 5),
#  ('next_trip_santa', 5),
#  ('definitely_back_im', 5),
#  ('perfect_amount_cheese', 5),
#  ('pizza_good_pizza', 5),
#  ('good_service_great', 5),
#  ('customer_service_excellent', 5),
#  ('amazing_customer_service', 5),
#  ('guy_behind_counter', 5),
#  ('chicken_chipotle_pizza', 5),
#  ('im_going_give', 5),
#  ('pizza_heart_best', 5),
#  ('give_place_shot', 5),
#  ('amazing_best_pizza', 5),
#  ('favorite_place_eat', 5),
#  ('amazing_crust_perfect', 5),
#  ('pizza_loved_it', 5),
#  ('great_place_pizza', 5),
#  ('friendly_staff_clean', 5),
#  ('recommend_place_everyone', 5),
#  ('garlic_olive_oil', 5),
#  ('id_go_back', 5),
#  ('gluten_free_option', 5),
#  ('vegan_gluten_free', 5),
#  ('food_delicious_service', 5),
#  ('santa_barbara_must', 5),
#  ('tried_place_first', 5),
#  ('crust_sauce_cheese', 5),
#  ('right_around_corner', 5),
#  ('definitely_worth_wait', 5),
#  ('pizza_new_york', 5),
#  ('long_time_get', 5),
#  ('definitely_back_soon', 5),
#  ('stars_customer_service', 5),
#  ('ginos_best_pizza', 5),
#  ('little_hole_wall', 5),
#  ('santa_barbara_really', 5),
#  ('style_pizza_place', 5),
#  ('since_first_time', 5),
#  ('santa_barbara_ill', 5),
#  ('give_another_chance', 5),
#  ('great_wine_selection', 5),
#  ('little_pizza_place', 5),
#  ('everything_tasted_fresh', 5),
#  ('pizza_sooo_good', 5),
#  ('try_place_out', 5),
#  ('high_quality_food', 5),
#  ('town_highly_recommend', 5),
#  ('definitely_back_pizza', 5),
#  ('nice_thin_crust', 5),
#  ('thin_crust_great', 5),
#  ('would_come_again', 5),
#  ('pizza_caesar_salad', 5),
#  ('great_experience_definitely', 5),
#  ('real_italian_pizza', 5),
#  ('pizza_ok_nothing', 5),
#  ('day_trip_santa', 5),
#  ('would_love_come', 5),
#  ('place_another_try', 5),
#  ('ever_had_pizza', 5),
#  ('looking_good_pizza', 5),
#  ('must_try_pizza', 5),
#  ('quality_food_service', 5),
#  ('really_good_well', 5),
#  ('going_via_vai', 5),
#  ('loved_it_great', 5),
#  ('neapolitan_style_pizza', 5),
#  ('time_come_back', 5),
#  ('flat_bread_pizza', 5),
#  ('it_first_time', 5),
#  ('crust_fresh_ingredients', 5),
#  ('santa_barbara_weekend', 5),
#  ('ive_ever_tried', 5),
#  ('santa_barbara_olio', 5),
#  ('got_margherita_pizza', 5),
#  ('trying_get_us', 5),
#  ('without_telling_us', 5),
#  ('carne_asada_pizza', 5),
#  ('institution_ale_co', 5),
#  ('great_beer_great', 5),
#  ('good_wine_list', 5),
#  ('table_right_away', 5),
#  ('free_garlic_bread', 5),
#  ('location_many_times', 5),
#  ('were_santa_barbara', 5),
#  ('deep_dish_chicago', 5),
#  ('santa_barbara_location', 5),
#  ('chocolate_chip_cookie', 5),
#  ('service_amazing_food', 5),
#  ('first_time_ive', 5),
#  ('farmers_market_pizza', 5),
#  ('it_great_pizza', 5),
#  ('warm_spinach_salad', 5),
#  ('santa_barbara_visit', 5),
#  ('bettina_best_pizza', 5),
#  ('maitake_mushroom_pizza', 5),
#  ('happy_hour_menu', 5),
#  ('pizzas_take_minutes', 5),
#  ('favorite_deep_dish', 5),
#  ('dish_pizza_takes', 5),
#  ('trying_deep_dish', 5),
#  ('dish_takes_minutes', 5),
#  ('small_deep_dish', 5),
#  ('good_deep_dish', 5),
#  ('wait_deep_dish', 5),
#  ('deep_dish_one', 5),
#  ('better_deep_dish', 5),
#  ('fan_deep_dish', 5),
#  ('classic_meat_deep', 5),
#  ('meat_deep_dish', 5),
#  ('chicagostyle_deep_dish', 5),
#  ('pesto_deep_dish', 5),
#  ('go_deep_dish', 5),
#  ('wine_tasting_funk', 5),
#  ('deep_dish_great', 5),
#  ('lucky_penny_really', 5),
#  ('great_service_good', 5),
#  ('lucky_penny_margherita', 5),
#  ('place_deep_dish', 5),
#  ('old_chicago_special', 5),
#  ('time_lucky_penny', 5),
#  ('mac_n_cheese', 5),
#  ('cheese_crimini_mushrooms', 5),
#  ('fried_squid_ink', 5),
#  ('mozzarella_spicy_salami', 5),
#  ('e_limone_restaurant', 5),
#  ('place_watch_football', 4),
#  ('service_delicious_pizza', 4),
#  ('pizza_overall_good', 4),
#  ('got_ta_give', 4),
#  ('great_place_come', 4),
#  ('pizza_probably_best', 4),
#  ('always_good_pizza', 4),
#  ('favorite_pizza_joint', 4),
#  ('best_pizza_planet', 4),
#  ('pizza_town_hands', 4),
#  ('town_hands_down', 4),
#  ('chicken_pizza_amazing', 4),
#  ('give_place_chance', 4),
#  ('ingredients_perfect_crust', 4),
#  ('go_back_get', 4),
#  ('definitely_recommend_anyone', 4),
#  ('staff_great_pizza', 4),
#  ('place_stars_pizza', 4),
#  ('fast_service_great', 4),
#  ('pizza_last_time', 4),
#  ('definitely_worth_drive', 4),
#  ('pretty_good_place', 4),
#  ('favorite_pizza_town', 4),
#  ('recommend_gluten_free', 4),
#  ('ever_go_back', 4),
#  ('first_time_ever', 4),
#  ('wait_long_pizza', 4),
#  ('customer_service_place', 4),
#  ('awesome_best_pizza', 4),
#  ('love_good_pizza', 4),
#  ('took_order_got', 4),
#  ('pizza_place_sure', 4),
#  ('pizza_place_best', 4),
#  ('great_pizza_salad', 4),
#  ('first_time_customer', 4),
#  ('decided_get_pizza', 4),
#  ('pizza_pepperoni_sausage', 4),
#  ('chicken_caesar_salad', 4),
#  ('good_place_go', 4),
#  ('use_fresh_ingredients', 4),
#  ('pizza_friendly_service', 4),
#  ('always_really_good', 4),
#  ('excellent_food_excellent', 4),
#  ('minutes_later_pizza', 4),
#  ('happened_upon_place', 4),
#  ('highly_recommend_getting', 4),
#  ('politely_asked_could', 4),
#  ('bad_experience_staff', 4),
#  ('large_deep_dish', 4),
#  ('crust_perfect_amount', 4),
#  ('food_came_fast', 4),
#  ('pizza_hut_dominos', 4),
#  ('it_highly_recommend', 4),
#  ('really_good_got', 4),
#  ('thin_crust_pan', 4),
#  ('outdoor_seating_available', 4),
#  ('crust_good_toppings', 4),
#  ('pizza_sb_hands', 4),
#  ('friendly_staff_generous', 4),
#  ('state_street_location', 4),
#  ('living_santa_barbara', 4),
#  ('santa_barbara_order', 4),
#  ('super_friendly_pizza', 4),
#  ('horrible_customer_service', 4),
#  ('really_good_though', 4),
#  ('take_n_bake', 4),
#  ('cant_recommend_enough', 4),
#  ('im_writing_review', 4),
#  ('moved_santa_barbara', 4),
#  ('minus_one_star', 4),
#  ('wanted_try_place', 4),
#  ('great_pizza_love', 4),
#  ('order_garlic_bread', 4),
#  ('love_it_pizza', 4),
#  ('great_service_too', 4),
#  ('best_customer_service', 4),
#  ('good_pasta_pizza', 4),
#  ('asked_money_back', 4),
#  ('lunch_special_personal', 4),
#  ('one_trip_salad', 4),
#  ('trip_salad_bar', 4),
#  ('ive_never_bad', 4),
#  ('can_not_say', 4),
#  ('good_pizza_was', 4),
#  ('pizza_good_also', 4),
#  ('night_place_packed', 4),
#  ('crust_crispy_outside', 4),
#  ('place_food_good', 4),
#  ('good_lunch_special', 4),
#  ('ingredients_super_fresh', 4),
#  ('get_slice_pizza', 4),
#  ('great_pizza_good', 4),
#  ('crispy_thin_crust', 4),
#  ('best_tasting_pizza', 4),
#  ('ive_going_years', 4),
#  ('fresh_staff_friendly', 4),
#  ('honestly_one_best', 4),
#  ('went_back_next', 4),
#  ('quick_friendly_service', 4),
#  ('pizza_good_sauce', 4),
#  ('large_slice_pizza', 4),
#  ('service_good_friendly', 4),
#  ...]
