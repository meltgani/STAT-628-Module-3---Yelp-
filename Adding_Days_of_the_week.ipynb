# %%
import pandas as pd ###
import numpy as np
from pathlib import Path

# %%
data = pd.read_csv("restaurant4.csv") ###
data.head()
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  index  Unnamed: 0  \
# 0             0             0             0      0          85
# 1             2             2             2      3         431
# 2             3             3             3      4         470
# 3             5             5             5      6         601
# 4             7             7             7     10        1320
#
#               business_id                  name                    address  \
# 0  IDtLPgUrqorrpqSLdfMhZQ  Helena Avenue Bakery      131 Anacapa St, Ste C
# 1  ifjluUv4VASwmFqEp8cWlQ         Marty's Pizza         2733 De La Vina St
# 2  VeFfrEZ4iWaecrQg6Eq4cg              Cal Taco  7320 Hollister Ave, Ste 1
# 3  xwSWtJcQkzTF6HNm_IMgcg  Rusty's Pizza Parlor              270 Storke Rd
# 4  UFpCraqzFBAhtZqmxmiWsA           Cat Therapy       1213 State St, Ste L
#
#             city state  postal_code   latitude   longitude  stars  \
# 0  Santa Barbara    CA        93101  34.414445 -119.690672    4.0
# 1  Santa Barbara    CA        93105  34.436236 -119.726147    4.0
# 2         Goleta    CA        93117  34.430542 -119.882367    4.0
# 3         Goleta    CA        93117  34.429043 -119.869362    2.5
# 4  Santa Barbara    CA        93101  34.423302 -119.705471    4.5
#
#    review_count  is_open                                         attributes  \
# 0           389        1  {'RestaurantsTakeOut': 'True', 'NoiseLevel': "...
# 1            64        1  {'Alcohol': "u'none'", 'BusinessAcceptsCreditC...
# 2           189        1  {'RestaurantsGoodForGroups': 'True', 'Business...
# 3            94        1  {'RestaurantsPriceRange2': '2', 'Alcohol': "u'...
# 4           116        1  {'WheelchairAccessible': 'True', 'WiFi': "u'fr...
#
#                                           categories  \
# 0  Food, Restaurants, Salad, Coffee & Tea, Breakf...
# 1                                 Pizza, Restaurants
# 2  Burgers, Cafes, Restaurants, Mexican, American...
# 3  Chicken Wings, Salad, Restaurants, Pizza, Ital...
# 4  Themed Cafes, Cafes, Pets, Arts & Entertainmen...
#
#                                                hours     Type
# 0  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...   Bakery
# 1  {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...    Pizza
# 2  {'Monday': '0:0-0:0', 'Tuesday': '8:0-20:30', ...  Mexican
# 3  {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:0', ...    Pizza
# 4  {'Monday': '10:0-17:15', 'Wednesday': '10:0-19...   Coffee

# %%
data.isnull().sum() ###
data.dropna()
len(data)
data.columns
data = data.drop(['Unnamed: 0.2','Unnamed: 0.1','index','Unnamed: 0','name','address','state','latitude','longitude','categories'],axis=1)
data.head(8)
#len(np.unique(data.business_id))
# Out:
#    Unnamed: 0.3             business_id           city  postal_code  stars  \
# 0             0  IDtLPgUrqorrpqSLdfMhZQ  Santa Barbara        93101    4.0
# 1             2  ifjluUv4VASwmFqEp8cWlQ  Santa Barbara        93105    4.0
# 2             3  VeFfrEZ4iWaecrQg6Eq4cg         Goleta        93117    4.0
# 3             5  xwSWtJcQkzTF6HNm_IMgcg         Goleta        93117    2.5
# 4             7  UFpCraqzFBAhtZqmxmiWsA  Santa Barbara        93101    4.5
# 5             8  JWFpjvCc_nkNDVtMPx1ZGg  Santa Barbara        93101    4.5
# 6            11  qdpdUjdkEUpzYDdce2yZng  Santa Barbara        93105    4.0
# 7            12  _v3DcLatG70adfYzWTd-CQ    Carpinteria        93013    4.5
#
#    review_count  is_open                                         attributes  \
# 0           389        1  {'RestaurantsTakeOut': 'True', 'NoiseLevel': "...
# 1            64        1  {'Alcohol': "u'none'", 'BusinessAcceptsCreditC...
# 2           189        1  {'RestaurantsGoodForGroups': 'True', 'Business...
# 3            94        1  {'RestaurantsPriceRange2': '2', 'Alcohol': "u'...
# 4           116        1  {'WheelchairAccessible': 'True', 'WiFi': "u'fr...
# 5            12        1  {'Caters': 'True', 'BusinessAcceptsBitcoin': '...
# 6           188        1  {'RestaurantsGoodForGroups': 'True', 'OutdoorS...
# 7            97        1  {'BikeParking': 'True', 'BusinessParking': "{'...
#
#                                                hours     Type
# 0  {'Monday': '0:0-0:0', 'Tuesday': '8:0-14:0', '...   Bakery
# 1  {'Tuesday': '11:0-21:30', 'Wednesday': '11:0-2...    Pizza
# 2  {'Monday': '0:0-0:0', 'Tuesday': '8:0-20:30', ...  Mexican
# 3  {'Monday': '0:0-0:0', 'Tuesday': '11:0-20:0', ...    Pizza
# 4  {'Monday': '10:0-17:15', 'Wednesday': '10:0-19...   Coffee
# 5  {'Monday': '0:0-0:0', 'Tuesday': '16:0-21:0', ...    Pizza
# 6  {'Monday': '10:0-17:30', 'Tuesday': '10:0-17:3...     Deli
# 7  {'Monday': '9:0-18:30', 'Tuesday': '9:0-18:30'...  Healthy

# %%
new_df = pd.DataFrame(data.hours.str.split(',').tolist(), index=data.business_id).stack() ###
new_df = new_df.reset_index([0, 'business_id'])
#new_df = ['business_id', 'hours']
new_df.columns = ['business_id', 'hours']
new_df.head()
# Out:
#               business_id                     hours
# 0  IDtLPgUrqorrpqSLdfMhZQ      {'Monday': '0:0-0:0'
# 1  IDtLPgUrqorrpqSLdfMhZQ     'Tuesday': '8:0-14:0'
# 2  IDtLPgUrqorrpqSLdfMhZQ   'Wednesday': '8:0-14:0'
# 3  IDtLPgUrqorrpqSLdfMhZQ    'Thursday': '8:0-14:0'
# 4  IDtLPgUrqorrpqSLdfMhZQ      'Friday': '8:0-14:0'

# %%
new_df[['day_of_the_week','hours']] = new_df['hours'].str.split(': ',expand=True) ###
new_df['day_of_the_week'] = new_df['day_of_the_week'].str.replace("'"," ")
new_df['day_of_the_week'] = new_df['day_of_the_week'].str.replace("{"," ")
new_df['day_of_the_week'] = new_df['day_of_the_week'].str.replace("}"," ")
new_df['day_of_the_week'] = new_df['day_of_the_week'].str.replace(" ","")
#new_df['day_of_the_week'] = new_df['day_of_the_week'].replace("Monday","m",regex=True)
new_df['hours'] = new_df['hours'].str.replace("'"," ")
new_df['hours'] = new_df['hours'].str.replace("{"," ")
new_df['hours'] = new_df['hours'].str.replace("}"," ")
new_df['hours'] = new_df['hours'].str.replace(" ","")
new_df.head(8)
# Out:
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\3133159498.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new_df['day_of_the_week'] = new_df['day_of_the_week'].str.replace("{"," ")
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\3133159498.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new_df['day_of_the_week'] = new_df['day_of_the_week'].str.replace("}"," ")
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\3133159498.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new_df['hours'] = new_df['hours'].str.replace("{"," ")
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\3133159498.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new_df['hours'] = new_df['hours'].str.replace("}"," ")
#               business_id       hours day_of_the_week
# 0  IDtLPgUrqorrpqSLdfMhZQ     0:0-0:0          Monday
# 1  IDtLPgUrqorrpqSLdfMhZQ    8:0-14:0         Tuesday
# 2  IDtLPgUrqorrpqSLdfMhZQ    8:0-14:0       Wednesday
# 3  IDtLPgUrqorrpqSLdfMhZQ    8:0-14:0        Thursday
# 4  IDtLPgUrqorrpqSLdfMhZQ    8:0-14:0          Friday
# 5  IDtLPgUrqorrpqSLdfMhZQ    8:0-14:0        Saturday
# 6  IDtLPgUrqorrpqSLdfMhZQ    8:0-14:0          Sunday
# 7  ifjluUv4VASwmFqEp8cWlQ  11:0-21:30         Tuesday

# %%
data = data.drop(['hours'],axis=1) ###
#data2 = pd.DataFrame(np.repeat(data.values, 7, axis=0))
#data2.columns = data.columns
data.head(8)

# %%
df = pd.merge(data,new_df,on = "business_id") ###
df.head(50)
#filepath = Path('C:/Users/aahuj/Desktop/628/df.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
#df.to_csv(filepath)

# %%
# days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
# new_df['day_of_the_week'] = new_df['day_of_the_week'].astype('string')
# for i in np.unique(new_df['business_id']):
#     print(i)
#     temp_days = days
#     for j in range(1, len(new_df['day_of_the_week'])) :
# #         print(new_df['day_of_the_week'][j].strip())
#         if new_df['day_of_the_week'][j].strip() in days :
#             temp_days.remove(new_df['day_of_the_week'][j].strip())
# #             s= new_df['day_of_the_week'][j]   
#             if len(temp_days) == 1:
#                 print(temp_days)
                
# new_df['day_of_the_week'] = new_df['day_of_the_week'].append(s)

# %%
days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
new_df['day_of_the_week'] = new_df['day_of_the_week'].astype('string')
count = 0
new_df2 = new_df
for i in new_df['business_id'].unique():
#     temp_days = days
    newdf1 = new_df[new_df["business_id"]==i]
    if len(newdf1)!= 7:
        count += 1
        print(i)
        temp = newdf1.day_of_the_week.str.strip().values
        diff = set(days)-set(temp)
        print(diff)
        for d in diff:
            newrows = {'business_id': i, 'hours': "0:0-0:0", 'day_of_the_week': d}
            new_df2=new_df2.append(newrows,ignore_index=True)
            print(newrows)
# Out:
# ifjluUv4VASwmFqEp8cWlQ
# {'Monday'}
# {'business_id': 'ifjluUv4VASwmFqEp8cWlQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# UFpCraqzFBAhtZqmxmiWsA
# {'Tuesday'}
# {'business_id': 'UFpCraqzFBAhtZqmxmiWsA', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# _v3DcLatG70adfYzWTd-CQ
# {'Sunday'}
# {'business_id': '_v3DcLatG70adfYzWTd-CQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# SHk_eYKzIOPvgwvTThtXiQ
# {'Sunday', 'Saturday'}
# {'business_id': 'SHk_eYKzIOPvgwvTThtXiQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'SHk_eYKzIOPvgwvTThtXiQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# GEGTsaKaO1R9fFB4sGS5qw
# {'Sunday', 'Monday', 'Saturday'}
# {'business_id': 'GEGTsaKaO1R9fFB4sGS5qw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'GEGTsaKaO1R9fFB4sGS5qw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'GEGTsaKaO1R9fFB4sGS5qw', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# DzpaiMQnB_sNhZPrgdvKHg
# {'Wednesday'}
# {'business_id': 'DzpaiMQnB_sNhZPrgdvKHg', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# iHdrLu8deF5GceB0V1rPhA
# {'Monday'}
# {'business_id': 'iHdrLu8deF5GceB0V1rPhA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# 0qu0fNTOsSmuREYVIMPuIQ
# {'Wednesday', 'Tuesday'}
# {'business_id': '0qu0fNTOsSmuREYVIMPuIQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': '0qu0fNTOsSmuREYVIMPuIQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# uO39--k_hrCFgZh-Bl8m8A
# {'Tuesday'}
# {'business_id': 'uO39--k_hrCFgZh-Bl8m8A', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# cVW9b_1bqsvTU1jhGNWUsw
# {'Sunday', 'Saturday'}
# {'business_id': 'cVW9b_1bqsvTU1jhGNWUsw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'cVW9b_1bqsvTU1jhGNWUsw', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# wFES5bGDiPANW13hNHnXOQ
# {'Sunday', 'Monday'}
# {'business_id': 'wFES5bGDiPANW13hNHnXOQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'wFES5bGDiPANW13hNHnXOQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# MbzgGsMQpGyVrUJXi_Jw0Q
# {'Tuesday'}
# {'business_id': 'MbzgGsMQpGyVrUJXi_Jw0Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# qNXAR7i6Tb3m0J0UBurj6g
# {'Sunday', 'Saturday'}
# {'business_id': 'qNXAR7i6Tb3m0J0UBurj6g', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'qNXAR7i6Tb3m0J0UBurj6g', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# syuKX2pH3JJhOOppzNI6SA
# {'Monday', 'Wednesday', 'Tuesday'}
# {'business_id': 'syuKX2pH3JJhOOppzNI6SA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'syuKX2pH3JJhOOppzNI6SA', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': 'syuKX2pH3JJhOOppzNI6SA', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# gebiRewfieSdtt17PTW6Zg
# {'Friday', 'Thursday', 'Sunday', 'Wednesday', 'Saturday', 'Tuesday'}
# {'business_id': 'gebiRewfieSdtt17PTW6Zg', 'hours': '0:0-0:0', 'day_of_the_week': 'Friday'}
# {'business_id': 'gebiRewfieSdtt17PTW6Zg', 'hours': '0:0-0:0', 'day_of_the_week': 'Thursday'}
# {'business_id': 'gebiRewfieSdtt17PTW6Zg', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'gebiRewfieSdtt17PTW6Zg', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': 'gebiRewfieSdtt17PTW6Zg', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# {'business_id': 'gebiRewfieSdtt17PTW6Zg', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# BEzvmorW8ILha6tcSxBBwA
# {'Sunday'}
# {'business_id': 'BEzvmorW8ILha6tcSxBBwA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# g5J9OJ5e8SgLYd2DL8_K9w
# {'Monday'}
# {'business_id': 'g5J9OJ5e8SgLYd2DL8_K9w', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# ejqpFQ0dwO7AZhxTO9fySg
# {'Tuesday'}
# {'business_id': 'ejqpFQ0dwO7AZhxTO9fySg', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 23OxrUaCvvVrwSa1z3xG-w
# {'Sunday', 'Monday'}
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# {'business_id': '23OxrUaCvvVrwSa1z3xG-w', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': '23OxrUaCvvVrwSa1z3xG-w', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# VC4jqq8Hu1_RjBFt8nHD2Q
# {'Friday', 'Thursday', 'Monday', 'Wednesday', 'Saturday', 'Tuesday'}
# {'business_id': 'VC4jqq8Hu1_RjBFt8nHD2Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Friday'}
# {'business_id': 'VC4jqq8Hu1_RjBFt8nHD2Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Thursday'}
# {'business_id': 'VC4jqq8Hu1_RjBFt8nHD2Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'VC4jqq8Hu1_RjBFt8nHD2Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': 'VC4jqq8Hu1_RjBFt8nHD2Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# {'business_id': 'VC4jqq8Hu1_RjBFt8nHD2Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 6HTGlttrzCMsuGBHO1ZGiw
# {'Tuesday'}
# {'business_id': '6HTGlttrzCMsuGBHO1ZGiw', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 12Gc4OFQ-WAW0fAk2hRZuQ
# {'Friday', 'Thursday', 'Sunday', 'Wednesday', 'Tuesday'}
# {'business_id': '12Gc4OFQ-WAW0fAk2hRZuQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Friday'}
# {'business_id': '12Gc4OFQ-WAW0fAk2hRZuQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Thursday'}
# {'business_id': '12Gc4OFQ-WAW0fAk2hRZuQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': '12Gc4OFQ-WAW0fAk2hRZuQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': '12Gc4OFQ-WAW0fAk2hRZuQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# pqF3WkYktbR28uk2PSR7Rg
# {'Wednesday', 'Tuesday'}
# {'business_id': 'pqF3WkYktbR28uk2PSR7Rg', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': 'pqF3WkYktbR28uk2PSR7Rg', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# rlfWeYI1SLvC8ZKM_OvXWA
# {'Sunday', 'Saturday'}
# {'business_id': 'rlfWeYI1SLvC8ZKM_OvXWA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'rlfWeYI1SLvC8ZKM_OvXWA', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# 1U8Kt44FIkC7RnJsNjaMTA
# {'Sunday'}
# {'business_id': '1U8Kt44FIkC7RnJsNjaMTA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# tjIIpbimdbi9Lrb-DoIzKg
# {'Monday'}
# {'business_id': 'tjIIpbimdbi9Lrb-DoIzKg', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# L8rhRyXtpq2nCE0il1KN_g
# {'Sunday', 'Saturday'}
# {'business_id': 'L8rhRyXtpq2nCE0il1KN_g', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'L8rhRyXtpq2nCE0il1KN_g', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# M3LZKA-tVFRJyPeKA3_2OA
# {'Sunday', 'Monday'}
# {'business_id': 'M3LZKA-tVFRJyPeKA3_2OA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'M3LZKA-tVFRJyPeKA3_2OA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# z6I4QVP1M1HXETgwD92XHg
# {'Monday'}
# {'business_id': 'z6I4QVP1M1HXETgwD92XHg', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# ZYqNIWch6Ik9wLZCa1hxkw
# {'Monday'}
# {'business_id': 'ZYqNIWch6Ik9wLZCa1hxkw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# p6yHZaiijFq4b4P3sYSRjA
# {'Sunday'}
# {'business_id': 'p6yHZaiijFq4b4P3sYSRjA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# tGQytMbOXDdZS_OSK9hkBw
# {'Monday'}
# {'business_id': 'tGQytMbOXDdZS_OSK9hkBw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# zJpZ-uQ_F0XVgK1u98uWSg
# {'Sunday'}
# {'business_id': 'zJpZ-uQ_F0XVgK1u98uWSg', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# yw3vRR7XLIjEnlhMnVzR7w
# {'Monday'}
# {'business_id': 'yw3vRR7XLIjEnlhMnVzR7w', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# JZrspVMm79n_iHTYftkI0g
# {'Monday'}
# {'business_id': 'JZrspVMm79n_iHTYftkI0g', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# vhWlxyLEWAbNOMtQ42yzFg
# {'Sunday'}
# {'business_id': 'vhWlxyLEWAbNOMtQ42yzFg', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# 2nF2syYoD5VBFk01le6NkA
# {'Sunday', 'Saturday'}
# {'business_id': '2nF2syYoD5VBFk01le6NkA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': '2nF2syYoD5VBFk01le6NkA', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# oJwMmSZKJOnMboZ_z67MZw
# {'Monday', 'Tuesday'}
# {'business_id': 'oJwMmSZKJOnMboZ_z67MZw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'oJwMmSZKJOnMboZ_z67MZw', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 9ugpNKKhnYRa51qXoxUw_A
# {'Tuesday'}
# {'business_id': '9ugpNKKhnYRa51qXoxUw_A', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# 3xJ_6qxRA0sdUm3ThCPiCw
# {'Tuesday'}
# {'business_id': '3xJ_6qxRA0sdUm3ThCPiCw', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# u3uB0GD7cVf5NC-AFHdwnQ
# {'Thursday', 'Monday', 'Wednesday', 'Tuesday'}
# {'business_id': 'u3uB0GD7cVf5NC-AFHdwnQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Thursday'}
# {'business_id': 'u3uB0GD7cVf5NC-AFHdwnQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'u3uB0GD7cVf5NC-AFHdwnQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': 'u3uB0GD7cVf5NC-AFHdwnQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# -r6nmLB5Vi2TLQCxh0_dtw
# {'Sunday'}
# {'business_id': '-r6nmLB5Vi2TLQCxh0_dtw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# omnCKxL0f_akh0eYeJxjDg
# {'Tuesday'}
# {'business_id': 'omnCKxL0f_akh0eYeJxjDg', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 0iLgVQpBeIYYwQZIblTTVw
# {'Sunday', 'Saturday'}
# {'business_id': '0iLgVQpBeIYYwQZIblTTVw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': '0iLgVQpBeIYYwQZIblTTVw', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# j3Ml_qEFnDOaH5miNzG6xw
# {'Monday'}
# {'business_id': 'j3Ml_qEFnDOaH5miNzG6xw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# E_ac8Q20OJD9L8cafCBKaQ
# {'Sunday'}
# {'business_id': 'E_ac8Q20OJD9L8cafCBKaQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# 2l-spLLGUzRiZg8dF623Nw
# {'Tuesday'}
# {'business_id': '2l-spLLGUzRiZg8dF623Nw', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# Hl_vXTiYLozWo7T9Cq17vw
# {'Sunday', 'Tuesday'}
# {'business_id': 'Hl_vXTiYLozWo7T9Cq17vw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'Hl_vXTiYLozWo7T9Cq17vw', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 0c28ysQJ_M1fVToTFV-FWQ
# {'Monday', 'Wednesday', 'Tuesday'}
# {'business_id': '0c28ysQJ_M1fVToTFV-FWQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': '0c28ysQJ_M1fVToTFV-FWQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': '0c28ysQJ_M1fVToTFV-FWQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# wvD7TOuE-qUhkyXoi8K8hA
# {'Monday'}
# {'business_id': 'wvD7TOuE-qUhkyXoi8K8hA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# NTLvzcGNm4IUF_yXIwIhvA
# {'Monday', 'Tuesday'}
# {'business_id': 'NTLvzcGNm4IUF_yXIwIhvA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'NTLvzcGNm4IUF_yXIwIhvA', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# FH0MVF7kK0D76Hh4e7hXfQ
# {'Tuesday'}
# {'business_id': 'FH0MVF7kK0D76Hh4e7hXfQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# Pf_7rI6TnV8M_btOBBLg5w
# {'Sunday'}
# {'business_id': 'Pf_7rI6TnV8M_btOBBLg5w', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# O8rIa0Wvapju2iC9T1Hp8Q
# {'Monday', 'Tuesday'}
# {'business_id': 'O8rIa0Wvapju2iC9T1Hp8Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'O8rIa0Wvapju2iC9T1Hp8Q', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 2MWEEuY3dtD2DNP99sNe_A
# {'Sunday', 'Monday', 'Tuesday'}
# {'business_id': '2MWEEuY3dtD2DNP99sNe_A', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': '2MWEEuY3dtD2DNP99sNe_A', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': '2MWEEuY3dtD2DNP99sNe_A', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# iBBV8vesQ8fo2IQA7an1JA
# {'Sunday'}
# {'business_id': 'iBBV8vesQ8fo2IQA7an1JA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# 1l4-uhraQzNiRjppKyMUUQ
# {'Tuesday'}
# {'business_id': '1l4-uhraQzNiRjppKyMUUQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# fKrmWy4GFsrgdOYhN9pyZA
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# {'Monday'}
# {'business_id': 'fKrmWy4GFsrgdOYhN9pyZA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# CuRjZOmfnXjefwEpyzmTTw
# {'Tuesday'}
# {'business_id': 'CuRjZOmfnXjefwEpyzmTTw', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# LlGIlNJE2Nv_PXkH7l4Wmg
# {'Tuesday'}
# {'business_id': 'LlGIlNJE2Nv_PXkH7l4Wmg', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# DqVpNtgFCP47n6frh-LREA
# {'Monday'}
# {'business_id': 'DqVpNtgFCP47n6frh-LREA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# T9I4G6Or3sAbyYmB7c23hw
# {'Sunday'}
# {'business_id': 'T9I4G6Or3sAbyYmB7c23hw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# GwtVBqKzW9j0zNQ7nYnT5g
# {'Sunday'}
# {'business_id': 'GwtVBqKzW9j0zNQ7nYnT5g', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# n_RyzuCAiR4yW2JLkl0Jng
# {'Tuesday'}
# {'business_id': 'n_RyzuCAiR4yW2JLkl0Jng', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# bXrQejeR66IwebuhxPS7GA
# {'Sunday'}
# {'business_id': 'bXrQejeR66IwebuhxPS7GA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# 8JzURExziDYuCrd7Ve9nDQ
# {'Sunday'}
# {'business_id': '8JzURExziDYuCrd7Ve9nDQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# GtrY5U_M1ac3bYCk0DUeIg
# {'Sunday'}
# {'business_id': 'GtrY5U_M1ac3bYCk0DUeIg', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# eCnHSfwrco1Vs3m-iRcavw
# {'Monday'}
# {'business_id': 'eCnHSfwrco1Vs3m-iRcavw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# EEwmN2uP1PmOyxpTstSIxA
# {'Saturday', 'Monday'}
# {'business_id': 'EEwmN2uP1PmOyxpTstSIxA', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# {'business_id': 'EEwmN2uP1PmOyxpTstSIxA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# 9kfN12wVGnKo54AaRjz0vQ
# {'Monday'}
# {'business_id': '9kfN12wVGnKo54AaRjz0vQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# LMm555z8BReDxgkpF_TEug
# {'Sunday', 'Saturday'}
# {'business_id': 'LMm555z8BReDxgkpF_TEug', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'LMm555z8BReDxgkpF_TEug', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# EPkF-beh6gg_s3HtlAdfiw
# {'Sunday'}
# {'business_id': 'EPkF-beh6gg_s3HtlAdfiw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# NuMR1xJu6Ewxaicc4yLOFw
# {'Sunday'}
# {'business_id': 'NuMR1xJu6Ewxaicc4yLOFw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# WVNkMz4sEl35swjVtKHOFw
# {'Monday'}
# {'business_id': 'WVNkMz4sEl35swjVtKHOFw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# kwqXOtLCbNjgvwuMj4H1AQ
# {'Sunday'}
# {'business_id': 'kwqXOtLCbNjgvwuMj4H1AQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# AFZTm786brtTbEc5yYBgfA
# {'Sunday'}
# {'business_id': 'AFZTm786brtTbEc5yYBgfA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# GUuLWkqfieTDwORs8z8mDg
# {'Sunday', 'Saturday'}
# {'business_id': 'GUuLWkqfieTDwORs8z8mDg', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'GUuLWkqfieTDwORs8z8mDg', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# r926yelr_EJAKQCjdD6AWA
# {'Tuesday'}
# {'business_id': 'r926yelr_EJAKQCjdD6AWA', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 8Vo6LN9gqULhXzoxj5k6kQ
# {'Monday', 'Tuesday'}
# {'business_id': '8Vo6LN9gqULhXzoxj5k6kQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': '8Vo6LN9gqULhXzoxj5k6kQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# VZhRxX3BzU09qK4UlXrN4g
# {'Monday'}
# {'business_id': 'VZhRxX3BzU09qK4UlXrN4g', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# Sp4HOjXy-LYV_4yy10L3jg
# {'Tuesday'}
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# {'business_id': 'g9MWxLxQdADqja0qN1HKkQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# bp482wqF6v80AltDNlPDfw
# {'Monday'}
# {'business_id': 'bp482wqF6v80AltDNlPDfw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# BVzFvRrgMpL62oPIqGvLMg
# {'Sunday'}
# {'business_id': 'BVzFvRrgMpL62oPIqGvLMg', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# 8_r9EZL6vX5fPBoVh3gUrA
# {'Monday'}
# {'business_id': '8_r9EZL6vX5fPBoVh3gUrA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# WzgtV5eNV7rwtJYJUiPJ2w
# {'Friday', 'Thursday', 'Monday', 'Wednesday', 'Saturday', 'Tuesday'}
# {'business_id': 'WzgtV5eNV7rwtJYJUiPJ2w', 'hours': '0:0-0:0', 'day_of_the_week': 'Friday'}
# {'business_id': 'WzgtV5eNV7rwtJYJUiPJ2w', 'hours': '0:0-0:0', 'day_of_the_week': 'Thursday'}
# {'business_id': 'WzgtV5eNV7rwtJYJUiPJ2w', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'WzgtV5eNV7rwtJYJUiPJ2w', 'hours': '0:0-0:0', 'day_of_the_week': 'Wednesday'}
# {'business_id': 'WzgtV5eNV7rwtJYJUiPJ2w', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# {'business_id': 'WzgtV5eNV7rwtJYJUiPJ2w', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 5Z3uvoIoOFUzTmrBmIJv2g
# {'Sunday', 'Saturday'}
# {'business_id': '5Z3uvoIoOFUzTmrBmIJv2g', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': '5Z3uvoIoOFUzTmrBmIJv2g', 'hours': '0:0-0:0', 'day_of_the_week': 'Saturday'}
# WUGRmrfSzQCyeG6mYAM-vw
# {'Monday'}
# {'business_id': 'WUGRmrfSzQCyeG6mYAM-vw', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# u9oG6CVhS9dJR5ZHS5q23A
# {'Sunday', 'Monday'}
# {'business_id': 'u9oG6CVhS9dJR5ZHS5q23A', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'u9oG6CVhS9dJR5ZHS5q23A', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# UQZe-qWOpGiyEPsTUko5Rg
# {'Monday', 'Tuesday'}
# {'business_id': 'UQZe-qWOpGiyEPsTUko5Rg', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'UQZe-qWOpGiyEPsTUko5Rg', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# Ss6f5v_t5Vddiaz4ZOxL0g
# {'Tuesday'}
# {'business_id': 'Ss6f5v_t5Vddiaz4ZOxL0g', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# 4D7QDfPOsSPfKxBi3gs_qQ
# {'Monday'}
# {'business_id': '4D7QDfPOsSPfKxBi3gs_qQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# krTxH1a9kzWgwvt3PVH8pQ
# {'Sunday'}
# {'business_id': 'krTxH1a9kzWgwvt3PVH8pQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# gjCxTVItFxk46rCZ-YaiFA
# {'Sunday'}
# {'business_id': 'gjCxTVItFxk46rCZ-YaiFA', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# fiQxkb1pfPpvrr0oYYYBcA
# {'Tuesday'}
# {'business_id': 'fiQxkb1pfPpvrr0oYYYBcA', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# BErYojCJSO959vzaz9JclQ
# {'Sunday'}
# {'business_id': 'BErYojCJSO959vzaz9JclQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# xRapA2lG7mjJ6eOqHmxe-A
# {'Sunday', 'Monday', 'Tuesday'}
# {'business_id': 'xRapA2lG7mjJ6eOqHmxe-A', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# {'business_id': 'xRapA2lG7mjJ6eOqHmxe-A', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# {'business_id': 'xRapA2lG7mjJ6eOqHmxe-A', 'hours': '0:0-0:0', 'day_of_the_week': 'Tuesday'}
# AgVekFXqwt4Y1HxfQcpyiw
# {'Sunday'}
# {'business_id': 'AgVekFXqwt4Y1HxfQcpyiw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# GuzbBFraIq-fbkjfvaTRvg
# {'Monday'}
# {'business_id': 'GuzbBFraIq-fbkjfvaTRvg', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# q-1ICFSqs2MwDGfe5tX-SQ
# {'Sunday'}
# {'business_id': 'q-1ICFSqs2MwDGfe5tX-SQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# 0it-2gWk_gyuZyEMQzBBuQ
# {'Monday'}
# {'business_id': '0it-2gWk_gyuZyEMQzBBuQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# bVaRZDHkWdsHuARGxxpREw
# {'Sunday'}
# {'business_id': 'bVaRZDHkWdsHuARGxxpREw', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# izSgTrqebu8bN8ONOCs6cQ
# {'Sunday'}
# {'business_id': 'izSgTrqebu8bN8ONOCs6cQ', 'hours': '0:0-0:0', 'day_of_the_week': 'Sunday'}
# 2xxkaRy7rP5EUyjFt2J5kA
# {'Monday'}
# {'business_id': '2xxkaRy7rP5EUyjFt2J5kA', 'hours': '0:0-0:0', 'day_of_the_week': 'Monday'}
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)
# C:\Users\aahuj\AppData\Local\Temp\ipykernel_1836\4159134345.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df2=new_df2.append(newrows,ignore_index=True)

# %%
new_df2 = new_df2.sort_values(by="business_id",ignore_index=True)

# %%
new_df2[new_df2["business_id"] == "-3AooxIkg38UyUdlz5oXdw"]
# Out:
#               business_id       hours day_of_the_week
# 0  -3AooxIkg38UyUdlz5oXdw  11:30-22:0          Friday
# 1  -3AooxIkg38UyUdlz5oXdw  11:30-21:0        Thursday
# 2  -3AooxIkg38UyUdlz5oXdw  11:30-21:0       Wednesday
# 3  -3AooxIkg38UyUdlz5oXdw  11:30-21:0         Tuesday
# 4  -3AooxIkg38UyUdlz5oXdw  11:30-22:0        Saturday
# 5  -3AooxIkg38UyUdlz5oXdw  11:30-21:0          Sunday
# 6  -3AooxIkg38UyUdlz5oXdw  11:30-21:0          Monday

# %%
new_df2[new_df2["business_id"] == "MiMRlsXOpHJMSTDAuw8s1w"]
# Out:
# Empty DataFrame
# Columns: [business_id, hours, day_of_the_week]
# Index: []

# %%
new_df["day_of_the_week"][0].strip() in days
# Out:
# True

# %%
new_df

# %%
new_df[new_df['business_id']== 'ifjluUv4VASwmFqEp8cWlQ']
# Out:
#                business_id       hours day_of_the_week
# 7   ifjluUv4VASwmFqEp8cWlQ  11:0-21:30         Tuesday
# 8   ifjluUv4VASwmFqEp8cWlQ  11:0-21:30       Wednesday
# 9   ifjluUv4VASwmFqEp8cWlQ  11:0-21:30        Thursday
# 10  ifjluUv4VASwmFqEp8cWlQ  11:0-21:30          Friday
# 11  ifjluUv4VASwmFqEp8cWlQ  11:0-21:30        Saturday
# 12  ifjluUv4VASwmFqEp8cWlQ  11:0-21:30          Sunday

# %% [markdown]
# len(np.unique(new_df.business_id))
# len(new_df)
# from pathlib import Path
# filepath = Path('C:/Users/aahuj/Desktop/628/new_df.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# new_df.to_csv(filepath)
# len(np.unique(data.business_id))
# len(data)
# from pathlib import Path
# filepath = Path('C:/Users/aahuj/Desktop/628/data.csv')
# filepath.parent.mkdir(parents=True, exist_ok=True)
# data.to_csv(filepath)
